# %%
import pickle

# %%
checkfilename = 'hmm_data/t_ok'

# %%
with open("labels.p", "rb") as fp:
    label = pickle.load(fp)
print label
# Out:
# ['name', '1', 'd', '7', 's', '2', 'y', 'p', 'i', '9', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 't', '8', 'u', 'x', '6', 'h', 'e', '5', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
with open(str(checkfilename)+".npy", "rb") as fp:
    seq = pickle.load(fp)
for i in range(len(seq)):
    print i, seq[i]
# Out:
# 0 [0, 26, 26, 26, 26, 32, 32, 32]
# 1 [32, 26, 26, 26, 32, 32, 32]
# 2 [32, 26, 26, 26, 32, 32, 32, 32]
# 3 [26, 26, 26, 32, 32, 32, 32]
# 4 [21, 31]
# 5 [31, 26, 26, 26, 34, 32, 32, 32]

# %%
kill = [4]

# %%
for offset, index in enumerate(kill):
  index -= offset
  del seq[index]

# %%
for i in range(len(seq)):
    print i, seq[i]
# Out:
# 0 [0, 26, 26, 26, 26, 32, 32, 32]
# 1 [32, 26, 26, 26, 32, 32, 32]
# 2 [32, 26, 26, 26, 32, 32, 32, 32]
# 3 [26, 26, 26, 32, 32, 32, 32]
# 4 [31, 26, 26, 26, 34, 32, 32, 32]

# %%
with open(str(checkfilename)+".npy", "wb") as fp:
    pickle.dump(seq, fp)
