# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t426.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (106265, 37)

# %%
# Parameters
learning_rate = 0.001
training_iters = 500000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==5):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.675240, Training Accuracy= 0.00000
# Iter 3200, Minibatch Loss= 3.552628, Training Accuracy= 0.00000
# Iter 4800, Minibatch Loss= 3.574344, Training Accuracy= 0.06250
# Iter 6400, Minibatch Loss= 3.624053, Training Accuracy= 0.00000
# Iter 8000, Minibatch Loss= 3.485640, Training Accuracy= 0.12500
# Iter 9600, Minibatch Loss= 3.600346, Training Accuracy= 0.00000
# Iter 11200, Minibatch Loss= 3.530152, Training Accuracy= 0.00000
# Iter 12800, Minibatch Loss= 3.563554, Training Accuracy= 0.06250
# Iter 14400, Minibatch Loss= 3.670781, Training Accuracy= 0.00000
# Iter 16000, Minibatch Loss= 3.579586, Training Accuracy= 0.06250
# Iter 17600, Minibatch Loss= 3.629677, Training Accuracy= 0.00000
# Iter 19200, Minibatch Loss= 3.401029, Training Accuracy= 0.06250
# Iter 20800, Minibatch Loss= 3.489229, Training Accuracy= 0.18750
# Iter 22400, Minibatch Loss= 3.577354, Training Accuracy= 0.00000
# Iter 24000, Minibatch Loss= 3.507383, Training Accuracy= 0.12500
# Iter 25600, Minibatch Loss= 3.375229, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.600178, Training Accuracy= 0.00000
# Iter 28800, Minibatch Loss= 3.580709, Training Accuracy= 0.06250
# Iter 30400, Minibatch Loss= 3.592166, Training Accuracy= 0.00000
# Iter 32000, Minibatch Loss= 3.541811, Training Accuracy= 0.06250
# Iter 33600, Minibatch Loss= 3.481711, Training Accuracy= 0.06250
# Iter 35200, Minibatch Loss= 3.571022, Training Accuracy= 0.06250
# Iter 36800, Minibatch Loss= 3.373946, Training Accuracy= 0.06250
# Iter 38400, Minibatch Loss= 3.584357, Training Accuracy= 0.00000
# Iter 40000, Minibatch Loss= 3.381756, Training Accuracy= 0.25000
# Iter 41600, Minibatch Loss= 3.567114, Training Accuracy= 0.06250
# Iter 43200, Minibatch Loss= 3.506556, Training Accuracy= 0.00000
# Iter 44800, Minibatch Loss= 3.434450, Training Accuracy= 0.06250
# Iter 46400, Minibatch Loss= 3.564056, Training Accuracy= 0.06250
# Iter 48000, Minibatch Loss= 3.422533, Training Accuracy= 0.18750
# Iter 49600, Minibatch Loss= 3.486671, Training Accuracy= 0.25000
# Iter 51200, Minibatch Loss= 3.564728, Training Accuracy= 0.00000
# Iter 52800, Minibatch Loss= 3.561710, Training Accuracy= 0.00000
# Iter 54400, Minibatch Loss= 3.518857, Training Accuracy= 0.12500
# Iter 56000, Minibatch Loss= 3.547378, Training Accuracy= 0.12500
# Iter 57600, Minibatch Loss= 3.442510, Training Accuracy= 0.06250
# Iter 59200, Minibatch Loss= 3.371420, Training Accuracy= 0.12500
# Iter 60800, Minibatch Loss= 3.460612, Training Accuracy= 0.12500
# Iter 62400, Minibatch Loss= 3.523044, Training Accuracy= 0.00000
# Iter 64000, Minibatch Loss= 3.344097, Training Accuracy= 0.12500
# Iter 65600, Minibatch Loss= 3.412870, Training Accuracy= 0.12500
# Iter 67200, Minibatch Loss= 3.323726, Training Accuracy= 0.12500
# Iter 68800, Minibatch Loss= 3.395556, Training Accuracy= 0.00000
# Iter 70400, Minibatch Loss= 3.193780, Training Accuracy= 0.25000
# Iter 72000, Minibatch Loss= 3.286114, Training Accuracy= 0.25000
# Iter 73600, Minibatch Loss= 3.066377, Training Accuracy= 0.37500
# Iter 75200, Minibatch Loss= 3.234029, Training Accuracy= 0.06250
# Iter 76800, Minibatch Loss= 3.336224, Training Accuracy= 0.06250
# Iter 78400, Minibatch Loss= 3.144255, Training Accuracy= 0.18750
# Iter 80000, Minibatch Loss= 3.288057, Training Accuracy= 0.12500
# Iter 81600, Minibatch Loss= 3.134507, Training Accuracy= 0.37500
# Iter 83200, Minibatch Loss= 3.080420, Training Accuracy= 0.31250
# Iter 84800, Minibatch Loss= 3.159825, Training Accuracy= 0.12500
# Iter 86400, Minibatch Loss= 3.018852, Training Accuracy= 0.12500
# Iter 88000, Minibatch Loss= 3.157185, Training Accuracy= 0.18750
# Iter 89600, Minibatch Loss= 3.025363, Training Accuracy= 0.25000
# Iter 91200, Minibatch Loss= 2.874617, Training Accuracy= 0.12500
# Iter 92800, Minibatch Loss= 2.993619, Training Accuracy= 0.25000
# Iter 94400, Minibatch Loss= 3.002401, Training Accuracy= 0.12500
# Iter 96000, Minibatch Loss= 2.983566, Training Accuracy= 0.00000
# Iter 97600, Minibatch Loss= 3.169922, Training Accuracy= 0.00000
# Iter 99200, Minibatch Loss= 2.859268, Training Accuracy= 0.12500
# Iter 100800, Minibatch Loss= 2.768513, Training Accuracy= 0.25000
# Iter 102400, Minibatch Loss= 2.664680, Training Accuracy= 0.31250
# Iter 104000, Minibatch Loss= 2.775264, Training Accuracy= 0.18750
# Iter 105600, Minibatch Loss= 2.619932, Training Accuracy= 0.31250
# Iter 107200, Minibatch Loss= 2.761561, Training Accuracy= 0.18750
# Iter 108800, Minibatch Loss= 3.130977, Training Accuracy= 0.06250
# Iter 110400, Minibatch Loss= 2.569436, Training Accuracy= 0.43750
# Iter 112000, Minibatch Loss= 2.445308, Training Accuracy= 0.31250
# Iter 113600, Minibatch Loss= 2.151434, Training Accuracy= 0.31250
# Iter 115200, Minibatch Loss= 2.351217, Training Accuracy= 0.37500
# Iter 116800, Minibatch Loss= 2.501054, Training Accuracy= 0.31250
# Iter 118400, Minibatch Loss= 2.188508, Training Accuracy= 0.50000
# Iter 120000, Minibatch Loss= 2.711757, Training Accuracy= 0.31250
# Iter 121600, Minibatch Loss= 2.519518, Training Accuracy= 0.12500
# Iter 123200, Minibatch Loss= 2.349645, Training Accuracy= 0.50000
# Iter 124800, Minibatch Loss= 2.208964, Training Accuracy= 0.25000
# Iter 126400, Minibatch Loss= 2.188035, Training Accuracy= 0.43750
# Iter 128000, Minibatch Loss= 2.154719, Training Accuracy= 0.31250
# Iter 129600, Minibatch Loss= 1.867872, Training Accuracy= 0.56250
# Iter 131200, Minibatch Loss= 2.386495, Training Accuracy= 0.18750
# Iter 132800, Minibatch Loss= 2.410847, Training Accuracy= 0.37500
# Iter 134400, Minibatch Loss= 2.119211, Training Accuracy= 0.56250
# Iter 136000, Minibatch Loss= 2.176169, Training Accuracy= 0.31250
# Iter 137600, Minibatch Loss= 2.116730, Training Accuracy= 0.31250
# Iter 139200, Minibatch Loss= 2.047939, Training Accuracy= 0.50000
# Iter 140800, Minibatch Loss= 2.580001, Training Accuracy= 0.50000
# Iter 142400, Minibatch Loss= 1.856578, Training Accuracy= 0.43750
# Iter 144000, Minibatch Loss= 1.659127, Training Accuracy= 0.62500
# Iter 145600, Minibatch Loss= 1.826474, Training Accuracy= 0.43750
# Iter 147200, Minibatch Loss= 2.046014, Training Accuracy= 0.43750
# Iter 148800, Minibatch Loss= 1.867951, Training Accuracy= 0.31250
# Iter 150400, Minibatch Loss= 1.729357, Training Accuracy= 0.43750
# Iter 152000, Minibatch Loss= 2.095191, Training Accuracy= 0.06250
# Iter 153600, Minibatch Loss= 1.893407, Training Accuracy= 0.50000
# Iter 155200, Minibatch Loss= 1.997955, Training Accuracy= 0.37500
# Iter 156800, Minibatch Loss= 1.812800, Training Accuracy= 0.43750
# Iter 158400, Minibatch Loss= 1.775393, Training Accuracy= 0.31250
# Iter 160000, Minibatch Loss= 1.476993, Training Accuracy= 0.68750
# Iter 161600, Minibatch Loss= 1.934741, Training Accuracy= 0.62500
# Iter 163200, Minibatch Loss= 1.743379, Training Accuracy= 0.37500
# Iter 164800, Minibatch Loss= 1.288489, Training Accuracy= 0.56250
# Iter 166400, Minibatch Loss= 1.949728, Training Accuracy= 0.43750
# Iter 168000, Minibatch Loss= 1.400530, Training Accuracy= 0.75000
# Iter 169600, Minibatch Loss= 1.237850, Training Accuracy= 0.81250
# Iter 171200, Minibatch Loss= 1.959178, Training Accuracy= 0.43750
# Iter 172800, Minibatch Loss= 1.445797, Training Accuracy= 0.62500
# Iter 174400, Minibatch Loss= 1.757562, Training Accuracy= 0.31250
# Iter 176000, Minibatch Loss= 1.516200, Training Accuracy= 0.43750
# Iter 177600, Minibatch Loss= 1.889968, Training Accuracy= 0.50000
# Iter 179200, Minibatch Loss= 1.533706, Training Accuracy= 0.37500
# Iter 180800, Minibatch Loss= 1.475616, Training Accuracy= 0.56250
# Iter 182400, Minibatch Loss= 1.763974, Training Accuracy= 0.50000
# Iter 184000, Minibatch Loss= 1.601208, Training Accuracy= 0.50000
# Iter 185600, Minibatch Loss= 1.196997, Training Accuracy= 0.62500
# Iter 187200, Minibatch Loss= 2.326434, Training Accuracy= 0.56250
# Iter 188800, Minibatch Loss= 1.552669, Training Accuracy= 0.43750
# Iter 190400, Minibatch Loss= 2.112542, Training Accuracy= 0.31250
# Iter 192000, Minibatch Loss= 1.344518, Training Accuracy= 0.50000
# Iter 193600, Minibatch Loss= 1.281442, Training Accuracy= 0.75000
# Iter 195200, Minibatch Loss= 1.062046, Training Accuracy= 0.68750
# Iter 196800, Minibatch Loss= 1.284179, Training Accuracy= 0.56250
# Iter 198400, Minibatch Loss= 1.119547, Training Accuracy= 0.62500
# Iter 200000, Minibatch Loss= 1.629374, Training Accuracy= 0.62500
# Iter 201600, Minibatch Loss= 0.845717, Training Accuracy= 0.75000
# Iter 203200, Minibatch Loss= 1.243626, Training Accuracy= 0.50000
# Iter 204800, Minibatch Loss= 1.830512, Training Accuracy= 0.43750
# Iter 206400, Minibatch Loss= 2.494751, Training Accuracy= 0.31250
# Iter 208000, Minibatch Loss= 1.064580, Training Accuracy= 0.68750
# Iter 209600, Minibatch Loss= 0.933116, Training Accuracy= 0.68750
# Iter 211200, Minibatch Loss= 0.883512, Training Accuracy= 0.75000
# Iter 212800, Minibatch Loss= 1.171546, Training Accuracy= 0.87500
# Iter 214400, Minibatch Loss= 1.526726, Training Accuracy= 0.56250
# Iter 216000, Minibatch Loss= 1.168359, Training Accuracy= 0.56250
# Iter 217600, Minibatch Loss= 1.200539, Training Accuracy= 0.56250
# Iter 219200, Minibatch Loss= 1.418255, Training Accuracy= 0.43750
# Iter 220800, Minibatch Loss= 1.774388, Training Accuracy= 0.50000
# Iter 222400, Minibatch Loss= 0.978399, Training Accuracy= 0.62500
# Iter 224000, Minibatch Loss= 0.951439, Training Accuracy= 0.75000
# Iter 225600, Minibatch Loss= 0.637060, Training Accuracy= 0.93750
# Iter 227200, Minibatch Loss= 0.806130, Training Accuracy= 0.81250
# Iter 228800, Minibatch Loss= 0.845366, Training Accuracy= 0.68750
# Iter 230400, Minibatch Loss= 1.130624, Training Accuracy= 0.62500
# Iter 232000, Minibatch Loss= 0.870953, Training Accuracy= 0.68750
# Iter 233600, Minibatch Loss= 1.463101, Training Accuracy= 0.50000
# Iter 235200, Minibatch Loss= 1.301444, Training Accuracy= 0.56250
# Iter 236800, Minibatch Loss= 1.255818, Training Accuracy= 0.50000
# Iter 238400, Minibatch Loss= 1.542618, Training Accuracy= 0.43750
# Iter 240000, Minibatch Loss= 1.078545, Training Accuracy= 0.56250
# Iter 241600, Minibatch Loss= 1.461359, Training Accuracy= 0.56250
# Iter 243200, Minibatch Loss= 0.737699, Training Accuracy= 0.75000
# Iter 244800, Minibatch Loss= 0.731882, Training Accuracy= 0.75000
# Iter 246400, Minibatch Loss= 1.011935, Training Accuracy= 0.56250
# Iter 248000, Minibatch Loss= 0.736330, Training Accuracy= 0.68750
# Iter 249600, Minibatch Loss= 0.632641, Training Accuracy= 0.81250
# Iter 251200, Minibatch Loss= 1.055780, Training Accuracy= 0.68750
# Iter 252800, Minibatch Loss= 1.030204, Training Accuracy= 0.75000
# Iter 254400, Minibatch Loss= 0.913247, Training Accuracy= 0.75000
# Iter 256000, Minibatch Loss= 0.514021, Training Accuracy= 0.93750
# Iter 257600, Minibatch Loss= 0.517733, Training Accuracy= 0.81250
# Iter 259200, Minibatch Loss= 1.082899, Training Accuracy= 0.75000
# Iter 260800, Minibatch Loss= 0.936535, Training Accuracy= 0.56250
# Iter 262400, Minibatch Loss= 0.803885, Training Accuracy= 0.75000
# Iter 264000, Minibatch Loss= 1.015253, Training Accuracy= 0.87500
# Iter 265600, Minibatch Loss= 1.056514, Training Accuracy= 0.75000
# Iter 267200, Minibatch Loss= 1.206046, Training Accuracy= 0.62500
# Iter 268800, Minibatch Loss= 0.854580, Training Accuracy= 0.81250
# Iter 270400, Minibatch Loss= 0.896311, Training Accuracy= 0.68750
# Iter 272000, Minibatch Loss= 0.913801, Training Accuracy= 0.62500
# Iter 273600, Minibatch Loss= 0.623308, Training Accuracy= 0.81250
# Iter 275200, Minibatch Loss= 0.657565, Training Accuracy= 0.81250
# Iter 276800, Minibatch Loss= 0.626046, Training Accuracy= 0.93750
# Iter 278400, Minibatch Loss= 1.013771, Training Accuracy= 0.62500
# Iter 280000, Minibatch Loss= 1.089644, Training Accuracy= 0.62500
# Iter 281600, Minibatch Loss= 0.760862, Training Accuracy= 0.68750
# Iter 283200, Minibatch Loss= 0.662326, Training Accuracy= 0.81250
# Iter 284800, Minibatch Loss= 0.965037, Training Accuracy= 0.68750
# Iter 286400, Minibatch Loss= 0.543728, Training Accuracy= 0.87500
# Iter 288000, Minibatch Loss= 0.679889, Training Accuracy= 0.81250
# Iter 289600, Minibatch Loss= 0.620858, Training Accuracy= 0.81250
# Iter 291200, Minibatch Loss= 0.547183, Training Accuracy= 0.87500
# Iter 292800, Minibatch Loss= 0.787564, Training Accuracy= 0.81250
# Iter 294400, Minibatch Loss= 0.407030, Training Accuracy= 0.87500
# Iter 296000, Minibatch Loss= 0.731304, Training Accuracy= 0.81250
# Iter 297600, Minibatch Loss= 0.413326, Training Accuracy= 0.93750
# Iter 299200, Minibatch Loss= 1.140342, Training Accuracy= 0.56250
# Iter 300800, Minibatch Loss= 0.263491, Training Accuracy= 0.93750
# Iter 302400, Minibatch Loss= 0.987197, Training Accuracy= 0.81250
# Iter 304000, Minibatch Loss= 0.579240, Training Accuracy= 0.75000
# Iter 305600, Minibatch Loss= 1.791742, Training Accuracy= 0.62500
# Iter 307200, Minibatch Loss= 0.452837, Training Accuracy= 0.87500
# Iter 308800, Minibatch Loss= 0.714047, Training Accuracy= 0.62500
# Iter 310400, Minibatch Loss= 0.649934, Training Accuracy= 0.81250
# Iter 312000, Minibatch Loss= 0.810359, Training Accuracy= 0.81250
# Iter 313600, Minibatch Loss= 0.486010, Training Accuracy= 0.87500
# Iter 315200, Minibatch Loss= 0.603999, Training Accuracy= 0.81250
# Iter 316800, Minibatch Loss= 0.676520, Training Accuracy= 0.68750
# Iter 318400, Minibatch Loss= 0.305696, Training Accuracy= 0.93750
# Iter 320000, Minibatch Loss= 0.900877, Training Accuracy= 0.68750
# Iter 321600, Minibatch Loss= 0.542585, Training Accuracy= 0.93750
# Iter 323200, Minibatch Loss= 0.639622, Training Accuracy= 0.75000
# Iter 324800, Minibatch Loss= 0.251526, Training Accuracy= 0.93750
# Iter 326400, Minibatch Loss= 0.802649, Training Accuracy= 0.81250
# Iter 328000, Minibatch Loss= 0.204484, Training Accuracy= 0.93750
# Iter 329600, Minibatch Loss= 0.196788, Training Accuracy= 1.00000
# Iter 331200, Minibatch Loss= 0.138903, Training Accuracy= 1.00000
# Iter 332800, Minibatch Loss= 0.944471, Training Accuracy= 0.68750
# Iter 334400, Minibatch Loss= 0.422671, Training Accuracy= 0.87500
# Iter 336000, Minibatch Loss= 0.482909, Training Accuracy= 0.81250
# Iter 337600, Minibatch Loss= 0.240623, Training Accuracy= 0.93750
# Iter 339200, Minibatch Loss= 0.637541, Training Accuracy= 0.62500
# Iter 340800, Minibatch Loss= 0.486957, Training Accuracy= 0.87500
# Iter 342400, Minibatch Loss= 0.700516, Training Accuracy= 0.75000
# Iter 344000, Minibatch Loss= 0.527086, Training Accuracy= 0.81250
# Iter 345600, Minibatch Loss= 0.353791, Training Accuracy= 0.87500
# Iter 347200, Minibatch Loss= 0.888894, Training Accuracy= 0.68750
# Iter 348800, Minibatch Loss= 0.350196, Training Accuracy= 0.93750
# Iter 350400, Minibatch Loss= 0.660427, Training Accuracy= 0.68750
# Iter 352000, Minibatch Loss= 0.774137, Training Accuracy= 0.75000
# Iter 353600, Minibatch Loss= 0.386569, Training Accuracy= 0.93750
# Iter 355200, Minibatch Loss= 0.631840, Training Accuracy= 0.75000
# Iter 356800, Minibatch Loss= 0.399348, Training Accuracy= 0.93750
# Iter 358400, Minibatch Loss= 0.615272, Training Accuracy= 0.75000
# Iter 360000, Minibatch Loss= 0.250318, Training Accuracy= 0.87500
# Iter 361600, Minibatch Loss= 0.904386, Training Accuracy= 0.62500
# Iter 363200, Minibatch Loss= 1.500731, Training Accuracy= 0.68750
# Iter 364800, Minibatch Loss= 1.035817, Training Accuracy= 0.68750
# Iter 366400, Minibatch Loss= 0.329630, Training Accuracy= 0.93750
# Iter 368000, Minibatch Loss= 0.464357, Training Accuracy= 0.87500
# Iter 369600, Minibatch Loss= 0.292186, Training Accuracy= 0.93750
# Iter 371200, Minibatch Loss= 0.507058, Training Accuracy= 0.87500
# Iter 372800, Minibatch Loss= 0.481111, Training Accuracy= 0.87500
# Iter 374400, Minibatch Loss= 0.911144, Training Accuracy= 0.81250
# Iter 376000, Minibatch Loss= 0.410246, Training Accuracy= 0.87500
# Iter 377600, Minibatch Loss= 0.218926, Training Accuracy= 1.00000
# Iter 379200, Minibatch Loss= 0.774069, Training Accuracy= 0.75000
# Iter 380800, Minibatch Loss= 0.191384, Training Accuracy= 0.93750
# Iter 382400, Minibatch Loss= 0.607831, Training Accuracy= 0.75000
# Iter 384000, Minibatch Loss= 0.384293, Training Accuracy= 0.87500
# Iter 385600, Minibatch Loss= 0.883777, Training Accuracy= 0.62500
# Iter 387200, Minibatch Loss= 0.497986, Training Accuracy= 0.81250
# Iter 388800, Minibatch Loss= 0.399757, Training Accuracy= 0.87500
# Iter 390400, Minibatch Loss= 0.361304, Training Accuracy= 0.87500
# Iter 392000, Minibatch Loss= 0.681191, Training Accuracy= 0.75000
# Iter 393600, Minibatch Loss= 0.579743, Training Accuracy= 0.75000
# Iter 395200, Minibatch Loss= 0.303801, Training Accuracy= 0.93750
# Iter 396800, Minibatch Loss= 0.284288, Training Accuracy= 0.93750
# Iter 398400, Minibatch Loss= 0.471750, Training Accuracy= 0.87500
# Iter 400000, Minibatch Loss= 0.178400, Training Accuracy= 0.93750
# Iter 401600, Minibatch Loss= 0.591901, Training Accuracy= 0.87500
# Iter 403200, Minibatch Loss= 0.635692, Training Accuracy= 0.81250
# Iter 404800, Minibatch Loss= 0.250381, Training Accuracy= 0.93750
# Iter 406400, Minibatch Loss= 1.174913, Training Accuracy= 0.75000
# Iter 408000, Minibatch Loss= 0.356473, Training Accuracy= 0.93750
# Iter 409600, Minibatch Loss= 0.082312, Training Accuracy= 1.00000
# Iter 411200, Minibatch Loss= 0.344833, Training Accuracy= 0.87500
# Iter 412800, Minibatch Loss= 0.270444, Training Accuracy= 0.87500
# Iter 414400, Minibatch Loss= 0.437344, Training Accuracy= 0.75000
# Iter 416000, Minibatch Loss= 0.231615, Training Accuracy= 1.00000
# Iter 417600, Minibatch Loss= 0.223260, Training Accuracy= 0.93750
# Iter 419200, Minibatch Loss= 0.286522, Training Accuracy= 0.93750
# Iter 420800, Minibatch Loss= 0.409036, Training Accuracy= 0.81250
# Iter 422400, Minibatch Loss= 0.228067, Training Accuracy= 0.93750
# Iter 424000, Minibatch Loss= 0.066715, Training Accuracy= 1.00000
# Iter 425600, Minibatch Loss= 0.416800, Training Accuracy= 0.81250
# Iter 427200, Minibatch Loss= 0.884273, Training Accuracy= 0.68750
# Iter 428800, Minibatch Loss= 0.312110, Training Accuracy= 0.93750
# Iter 430400, Minibatch Loss= 0.554926, Training Accuracy= 0.81250
# Iter 432000, Minibatch Loss= 0.990580, Training Accuracy= 0.50000
# Iter 433600, Minibatch Loss= 0.256768, Training Accuracy= 0.93750
# Iter 435200, Minibatch Loss= 0.260342, Training Accuracy= 0.87500
# Iter 436800, Minibatch Loss= 0.054045, Training Accuracy= 1.00000
# Iter 438400, Minibatch Loss= 0.515758, Training Accuracy= 0.68750
# Iter 440000, Minibatch Loss= 0.118965, Training Accuracy= 0.93750
# Iter 441600, Minibatch Loss= 0.177761, Training Accuracy= 1.00000
# Iter 443200, Minibatch Loss= 0.161295, Training Accuracy= 0.93750
# Iter 444800, Minibatch Loss= 0.103178, Training Accuracy= 0.93750
# Iter 446400, Minibatch Loss= 0.210866, Training Accuracy= 0.93750
# Iter 448000, Minibatch Loss= 0.220822, Training Accuracy= 0.93750
# Iter 449600, Minibatch Loss= 0.425659, Training Accuracy= 0.81250
# Iter 451200, Minibatch Loss= 0.228406, Training Accuracy= 0.93750
# Iter 452800, Minibatch Loss= 0.635916, Training Accuracy= 0.81250
# Iter 454400, Minibatch Loss= 0.270596, Training Accuracy= 0.87500
# Iter 456000, Minibatch Loss= 0.457390, Training Accuracy= 0.81250
# Iter 457600, Minibatch Loss= 0.305856, Training Accuracy= 0.87500
# Iter 459200, Minibatch Loss= 0.210343, Training Accuracy= 0.93750
# Iter 460800, Minibatch Loss= 0.765861, Training Accuracy= 0.68750
# Iter 462400, Minibatch Loss= 0.114617, Training Accuracy= 1.00000
# Iter 464000, Minibatch Loss= 0.070243, Training Accuracy= 1.00000
# Iter 465600, Minibatch Loss= 0.310030, Training Accuracy= 0.93750
# Iter 467200, Minibatch Loss= 0.159606, Training Accuracy= 0.93750
# Iter 468800, Minibatch Loss= 0.335124, Training Accuracy= 0.81250
# Iter 470400, Minibatch Loss= 0.152115, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.160305, Training Accuracy= 0.93750
# Iter 473600, Minibatch Loss= 0.208369, Training Accuracy= 0.93750
# Iter 475200, Minibatch Loss= 0.141511, Training Accuracy= 1.00000
# Iter 476800, Minibatch Loss= 0.463161, Training Accuracy= 0.81250
# Iter 478400, Minibatch Loss= 0.137355, Training Accuracy= 0.93750
# Iter 480000, Minibatch Loss= 0.158776, Training Accuracy= 0.93750
# Iter 481600, Minibatch Loss= 0.115312, Training Accuracy= 0.93750
# Iter 483200, Minibatch Loss= 0.210087, Training Accuracy= 0.87500
# Iter 484800, Minibatch Loss= 0.056823, Training Accuracy= 1.00000
# Iter 486400, Minibatch Loss= 0.064325, Training Accuracy= 1.00000
# Iter 488000, Minibatch Loss= 0.542619, Training Accuracy= 0.87500
# Iter 489600, Minibatch Loss= 0.335274, Training Accuracy= 0.87500
# Iter 491200, Minibatch Loss= 0.199042, Training Accuracy= 0.87500
# Iter 492800, Minibatch Loss= 0.499022, Training Accuracy= 0.87500
# Iter 494400, Minibatch Loss= 0.211146, Training Accuracy= 0.93750
# Iter 496000, Minibatch Loss= 0.297256, Training Accuracy= 0.87500
# Iter 497600, Minibatch Loss= 0.093322, Training Accuracy= 1.00000
# Iter 499200, Minibatch Loss= 0.139664, Training Accuracy= 0.93750
# Optimization Finished!
# Testing Accuracy: 0.778399

# %%
saver.save(sess, '../Model/NIN-Model-0426')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', '1', 'd', '7', 's', '2', 'y', 'p', 'i', '9', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 'you', 't', '8', 'u', 'x', '6', 'h', 'what', 'e', '5', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
