# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
import datetime
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t0630.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (181645, 53)

# %%
# Parameters
learning_rate = 0.001
#training_iters = 1600000
training_iters = 800000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.8 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
now1 = datetime.datetime.now()
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.2, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        now2 = datetime.datetime.now()
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc) + ", Time= " + str(now2-now1)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==8):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.910836, Training Accuracy= 0.06250, Time= 0:00:01.362864
# Iter 3200, Minibatch Loss= 4.000006, Training Accuracy= 0.06250, Time= 0:00:02.265575
# Iter 4800, Minibatch Loss= 3.959498, Training Accuracy= 0.00000, Time= 0:00:03.159373
# Iter 6400, Minibatch Loss= 3.919569, Training Accuracy= 0.00000, Time= 0:00:04.052509
# Iter 8000, Minibatch Loss= 4.002811, Training Accuracy= 0.00000, Time= 0:00:04.946849
# Iter 9600, Minibatch Loss= 3.975183, Training Accuracy= 0.00000, Time= 0:00:05.839292
# Iter 11200, Minibatch Loss= 3.902124, Training Accuracy= 0.00000, Time= 0:00:06.748570
# Iter 12800, Minibatch Loss= 3.973606, Training Accuracy= 0.00000, Time= 0:00:07.641255
# Iter 14400, Minibatch Loss= 3.955187, Training Accuracy= 0.06250, Time= 0:00:08.543556
# Iter 16000, Minibatch Loss= 3.958120, Training Accuracy= 0.00000, Time= 0:00:09.442224
# Iter 17600, Minibatch Loss= 3.973693, Training Accuracy= 0.00000, Time= 0:00:10.337457
# Iter 19200, Minibatch Loss= 3.899854, Training Accuracy= 0.12500, Time= 0:00:11.232413
# Iter 20800, Minibatch Loss= 3.933614, Training Accuracy= 0.06250, Time= 0:00:12.124161
# Iter 22400, Minibatch Loss= 3.963742, Training Accuracy= 0.00000, Time= 0:00:13.016601
# Iter 24000, Minibatch Loss= 3.959399, Training Accuracy= 0.00000, Time= 0:00:13.910071
# Iter 25600, Minibatch Loss= 3.958517, Training Accuracy= 0.06250, Time= 0:00:14.847220
# Iter 27200, Minibatch Loss= 3.913343, Training Accuracy= 0.18750, Time= 0:00:15.781021
# Iter 28800, Minibatch Loss= 3.927668, Training Accuracy= 0.00000, Time= 0:00:16.674164
# Iter 30400, Minibatch Loss= 3.918473, Training Accuracy= 0.06250, Time= 0:00:17.568086
# Iter 32000, Minibatch Loss= 3.885373, Training Accuracy= 0.12500, Time= 0:00:18.461034
# Iter 33600, Minibatch Loss= 3.917211, Training Accuracy= 0.00000, Time= 0:00:19.356918
# Iter 35200, Minibatch Loss= 3.966066, Training Accuracy= 0.06250, Time= 0:00:20.248803
# Iter 36800, Minibatch Loss= 3.976249, Training Accuracy= 0.00000, Time= 0:00:21.144200
# Iter 38400, Minibatch Loss= 3.945276, Training Accuracy= 0.06250, Time= 0:00:22.038871
# Iter 40000, Minibatch Loss= 3.934965, Training Accuracy= 0.00000, Time= 0:00:22.933021
# Iter 41600, Minibatch Loss= 3.973182, Training Accuracy= 0.00000, Time= 0:00:23.826980
# Iter 43200, Minibatch Loss= 3.955637, Training Accuracy= 0.06250, Time= 0:00:24.722055
# Iter 44800, Minibatch Loss= 3.959570, Training Accuracy= 0.00000, Time= 0:00:25.616032
# Iter 46400, Minibatch Loss= 3.976643, Training Accuracy= 0.00000, Time= 0:00:26.512284
# Iter 48000, Minibatch Loss= 3.965716, Training Accuracy= 0.00000, Time= 0:00:27.406219
# Iter 49600, Minibatch Loss= 3.943988, Training Accuracy= 0.12500, Time= 0:00:28.305805
# Iter 51200, Minibatch Loss= 3.913646, Training Accuracy= 0.06250, Time= 0:00:29.199310
# Iter 52800, Minibatch Loss= 3.928863, Training Accuracy= 0.00000, Time= 0:00:30.094501
# Iter 54400, Minibatch Loss= 3.899962, Training Accuracy= 0.06250, Time= 0:00:30.990577
# Iter 56000, Minibatch Loss= 3.969699, Training Accuracy= 0.00000, Time= 0:00:31.886080
# Iter 57600, Minibatch Loss= 3.981136, Training Accuracy= 0.00000, Time= 0:00:32.779947
# Iter 59200, Minibatch Loss= 3.951471, Training Accuracy= 0.00000, Time= 0:00:33.672168
# Iter 60800, Minibatch Loss= 3.923413, Training Accuracy= 0.12500, Time= 0:00:34.566886
# Iter 62400, Minibatch Loss= 3.954407, Training Accuracy= 0.00000, Time= 0:00:35.460561
# Iter 64000, Minibatch Loss= 3.940671, Training Accuracy= 0.00000, Time= 0:00:36.355010
# Iter 65600, Minibatch Loss= 3.951766, Training Accuracy= 0.00000, Time= 0:00:37.249427
# Iter 67200, Minibatch Loss= 3.944571, Training Accuracy= 0.06250, Time= 0:00:38.146305
# Iter 68800, Minibatch Loss= 3.930149, Training Accuracy= 0.12500, Time= 0:00:39.040899
# Iter 70400, Minibatch Loss= 3.926172, Training Accuracy= 0.06250, Time= 0:00:39.933973
# Iter 72000, Minibatch Loss= 3.973679, Training Accuracy= 0.00000, Time= 0:00:40.828692
# Iter 73600, Minibatch Loss= 3.944933, Training Accuracy= 0.06250, Time= 0:00:41.724338
# Iter 75200, Minibatch Loss= 3.931786, Training Accuracy= 0.00000, Time= 0:00:42.616402
# Iter 76800, Minibatch Loss= 3.906721, Training Accuracy= 0.12500, Time= 0:00:43.510695
# Iter 78400, Minibatch Loss= 3.888523, Training Accuracy= 0.06250, Time= 0:00:44.406818
# Iter 80000, Minibatch Loss= 3.946455, Training Accuracy= 0.00000, Time= 0:00:45.301298
# Iter 81600, Minibatch Loss= 3.958760, Training Accuracy= 0.06250, Time= 0:00:46.196084
# Iter 83200, Minibatch Loss= 3.937639, Training Accuracy= 0.00000, Time= 0:00:47.088665
# Iter 84800, Minibatch Loss= 3.954387, Training Accuracy= 0.06250, Time= 0:00:47.983334
# Iter 86400, Minibatch Loss= 3.934102, Training Accuracy= 0.00000, Time= 0:00:48.878074
# Iter 88000, Minibatch Loss= 3.944399, Training Accuracy= 0.06250, Time= 0:00:49.773011
# Iter 89600, Minibatch Loss= 3.888155, Training Accuracy= 0.00000, Time= 0:00:50.666799
# Iter 91200, Minibatch Loss= 3.917474, Training Accuracy= 0.00000, Time= 0:00:51.559447
# Iter 92800, Minibatch Loss= 3.919449, Training Accuracy= 0.06250, Time= 0:00:52.452980
# Iter 94400, Minibatch Loss= 3.941977, Training Accuracy= 0.00000, Time= 0:00:53.346591
# Iter 96000, Minibatch Loss= 3.918083, Training Accuracy= 0.06250, Time= 0:00:54.242442
# Iter 97600, Minibatch Loss= 3.927711, Training Accuracy= 0.00000, Time= 0:00:55.137202
# Iter 99200, Minibatch Loss= 3.963285, Training Accuracy= 0.06250, Time= 0:00:56.032867
# Iter 100800, Minibatch Loss= 3.935602, Training Accuracy= 0.06250, Time= 0:00:56.928452
# Iter 102400, Minibatch Loss= 3.888102, Training Accuracy= 0.12500, Time= 0:00:57.822905
# Iter 104000, Minibatch Loss= 3.903453, Training Accuracy= 0.00000, Time= 0:00:58.719603
# Iter 105600, Minibatch Loss= 3.929661, Training Accuracy= 0.00000, Time= 0:00:59.614862
# Iter 107200, Minibatch Loss= 3.922878, Training Accuracy= 0.00000, Time= 0:01:00.509354
# Iter 108800, Minibatch Loss= 3.898570, Training Accuracy= 0.06250, Time= 0:01:01.405405
# Iter 110400, Minibatch Loss= 3.909750, Training Accuracy= 0.06250, Time= 0:01:02.299748
# Iter 112000, Minibatch Loss= 3.933360, Training Accuracy= 0.06250, Time= 0:01:03.193069
# Iter 113600, Minibatch Loss= 3.936691, Training Accuracy= 0.00000, Time= 0:01:04.088741
# Iter 115200, Minibatch Loss= 3.879897, Training Accuracy= 0.06250, Time= 0:01:04.983816
# Iter 116800, Minibatch Loss= 3.901997, Training Accuracy= 0.06250, Time= 0:01:05.877913
# Iter 118400, Minibatch Loss= 3.876983, Training Accuracy= 0.06250, Time= 0:01:06.773548
# Iter 120000, Minibatch Loss= 3.915828, Training Accuracy= 0.00000, Time= 0:01:07.668306
# Iter 121600, Minibatch Loss= 3.912095, Training Accuracy= 0.06250, Time= 0:01:08.560981
# Iter 123200, Minibatch Loss= 3.862816, Training Accuracy= 0.37500, Time= 0:01:09.456573
# Iter 124800, Minibatch Loss= 3.973568, Training Accuracy= 0.00000, Time= 0:01:10.351570
# Iter 126400, Minibatch Loss= 3.946583, Training Accuracy= 0.00000, Time= 0:01:11.248217
# Iter 128000, Minibatch Loss= 3.946888, Training Accuracy= 0.00000, Time= 0:01:12.145159
# Iter 129600, Minibatch Loss= 3.951620, Training Accuracy= 0.00000, Time= 0:01:13.040308
# Iter 131200, Minibatch Loss= 3.902377, Training Accuracy= 0.00000, Time= 0:01:13.934075
# Iter 132800, Minibatch Loss= 3.919398, Training Accuracy= 0.00000, Time= 0:01:14.827040
# Iter 134400, Minibatch Loss= 3.909489, Training Accuracy= 0.00000, Time= 0:01:15.720495
# Iter 136000, Minibatch Loss= 3.987793, Training Accuracy= 0.00000, Time= 0:01:16.614738
# Iter 137600, Minibatch Loss= 3.839549, Training Accuracy= 0.18750, Time= 0:01:17.511955
# Iter 139200, Minibatch Loss= 3.887479, Training Accuracy= 0.06250, Time= 0:01:18.408999
# Iter 140800, Minibatch Loss= 3.913484, Training Accuracy= 0.06250, Time= 0:01:19.303250
# Iter 142400, Minibatch Loss= 3.846067, Training Accuracy= 0.06250, Time= 0:01:20.199336
# Iter 144000, Minibatch Loss= 3.873955, Training Accuracy= 0.12500, Time= 0:01:21.092981
# Iter 145600, Minibatch Loss= 3.934208, Training Accuracy= 0.00000, Time= 0:01:21.989157
# Iter 147200, Minibatch Loss= 3.914189, Training Accuracy= 0.12500, Time= 0:01:22.884061
# Iter 148800, Minibatch Loss= 3.949426, Training Accuracy= 0.12500, Time= 0:01:23.780384
# Iter 150400, Minibatch Loss= 3.885084, Training Accuracy= 0.00000, Time= 0:01:24.677026
# Iter 152000, Minibatch Loss= 3.934317, Training Accuracy= 0.06250, Time= 0:01:25.569827
# Iter 153600, Minibatch Loss= 3.934810, Training Accuracy= 0.06250, Time= 0:01:26.465489
# Iter 155200, Minibatch Loss= 3.884942, Training Accuracy= 0.00000, Time= 0:01:27.361702
# Iter 156800, Minibatch Loss= 3.910295, Training Accuracy= 0.00000, Time= 0:01:28.259459
# Iter 158400, Minibatch Loss= 3.915179, Training Accuracy= 0.12500, Time= 0:01:29.152623
# Iter 160000, Minibatch Loss= 3.907171, Training Accuracy= 0.00000, Time= 0:01:30.047056
# Iter 161600, Minibatch Loss= 3.868143, Training Accuracy= 0.06250, Time= 0:01:30.941627
# Iter 163200, Minibatch Loss= 3.859449, Training Accuracy= 0.06250, Time= 0:01:31.834713
# Iter 164800, Minibatch Loss= 3.807329, Training Accuracy= 0.18750, Time= 0:01:32.731666
# Iter 166400, Minibatch Loss= 3.881944, Training Accuracy= 0.06250, Time= 0:01:33.628041
# Iter 168000, Minibatch Loss= 3.765627, Training Accuracy= 0.06250, Time= 0:01:34.522062
# Iter 169600, Minibatch Loss= 3.802602, Training Accuracy= 0.18750, Time= 0:01:35.417975
# Iter 171200, Minibatch Loss= 3.689777, Training Accuracy= 0.00000, Time= 0:01:36.313508
# Iter 172800, Minibatch Loss= 3.846330, Training Accuracy= 0.06250, Time= 0:01:37.208935
# Iter 174400, Minibatch Loss= 3.857918, Training Accuracy= 0.12500, Time= 0:01:38.106530
# Iter 176000, Minibatch Loss= 3.907464, Training Accuracy= 0.00000, Time= 0:01:38.999976
# Iter 177600, Minibatch Loss= 3.831867, Training Accuracy= 0.06250, Time= 0:01:39.895857
# Iter 179200, Minibatch Loss= 3.847689, Training Accuracy= 0.06250, Time= 0:01:40.791186
# Iter 180800, Minibatch Loss= 3.801874, Training Accuracy= 0.18750, Time= 0:01:41.686607
# Iter 182400, Minibatch Loss= 3.818806, Training Accuracy= 0.06250, Time= 0:01:42.579350
# Iter 184000, Minibatch Loss= 3.440500, Training Accuracy= 0.12500, Time= 0:01:43.475465
# Iter 185600, Minibatch Loss= 3.644444, Training Accuracy= 0.06250, Time= 0:01:44.370534
# Iter 187200, Minibatch Loss= 3.552896, Training Accuracy= 0.06250, Time= 0:01:45.266851
# Iter 188800, Minibatch Loss= 3.671983, Training Accuracy= 0.12500, Time= 0:01:46.163827
# Iter 190400, Minibatch Loss= 3.685326, Training Accuracy= 0.06250, Time= 0:01:47.058425
# Iter 192000, Minibatch Loss= 3.623319, Training Accuracy= 0.12500, Time= 0:01:47.952208
# Iter 193600, Minibatch Loss= 3.734040, Training Accuracy= 0.06250, Time= 0:01:48.846938
# Iter 195200, Minibatch Loss= 3.706149, Training Accuracy= 0.06250, Time= 0:01:49.743103
# Iter 196800, Minibatch Loss= 3.624462, Training Accuracy= 0.00000, Time= 0:01:50.638613
# Iter 198400, Minibatch Loss= 3.461240, Training Accuracy= 0.18750, Time= 0:01:51.534188
# Iter 200000, Minibatch Loss= 3.389151, Training Accuracy= 0.12500, Time= 0:01:52.427803
# Iter 201600, Minibatch Loss= 3.594042, Training Accuracy= 0.06250, Time= 0:01:53.322990
# Iter 203200, Minibatch Loss= 3.502743, Training Accuracy= 0.18750, Time= 0:01:54.218239
# Iter 204800, Minibatch Loss= 3.415947, Training Accuracy= 0.06250, Time= 0:01:55.113451
# Iter 206400, Minibatch Loss= 3.699168, Training Accuracy= 0.06250, Time= 0:01:56.008800
# Iter 208000, Minibatch Loss= 3.534253, Training Accuracy= 0.00000, Time= 0:01:56.903895
# Iter 209600, Minibatch Loss= 3.563128, Training Accuracy= 0.12500, Time= 0:01:57.799119
# Iter 211200, Minibatch Loss= 3.424438, Training Accuracy= 0.06250, Time= 0:01:58.693749
# Iter 212800, Minibatch Loss= 3.444770, Training Accuracy= 0.06250, Time= 0:01:59.588589
# Iter 214400, Minibatch Loss= 3.491878, Training Accuracy= 0.00000, Time= 0:02:00.487966
# Iter 216000, Minibatch Loss= 3.533474, Training Accuracy= 0.06250, Time= 0:02:01.385561
# Iter 217600, Minibatch Loss= 3.413133, Training Accuracy= 0.18750, Time= 0:02:02.281328
# Iter 219200, Minibatch Loss= 3.601959, Training Accuracy= 0.12500, Time= 0:02:03.178281
# Iter 220800, Minibatch Loss= 3.167978, Training Accuracy= 0.18750, Time= 0:02:04.072188
# Iter 222400, Minibatch Loss= 3.415875, Training Accuracy= 0.12500, Time= 0:02:04.968764
# Iter 224000, Minibatch Loss= 3.553704, Training Accuracy= 0.25000, Time= 0:02:05.864543
# Iter 225600, Minibatch Loss= 3.409420, Training Accuracy= 0.18750, Time= 0:02:06.772213
# Iter 227200, Minibatch Loss= 3.676019, Training Accuracy= 0.06250, Time= 0:02:07.668979
# Iter 228800, Minibatch Loss= 3.319920, Training Accuracy= 0.12500, Time= 0:02:08.572386
# Iter 230400, Minibatch Loss= 3.355039, Training Accuracy= 0.12500, Time= 0:02:09.468792
# Iter 232000, Minibatch Loss= 3.207905, Training Accuracy= 0.12500, Time= 0:02:10.363274
# Iter 233600, Minibatch Loss= 3.085241, Training Accuracy= 0.00000, Time= 0:02:11.259040
# Iter 235200, Minibatch Loss= 3.158885, Training Accuracy= 0.12500, Time= 0:02:12.154134
# Iter 236800, Minibatch Loss= 3.665537, Training Accuracy= 0.00000, Time= 0:02:13.049934
# Iter 238400, Minibatch Loss= 3.452672, Training Accuracy= 0.12500, Time= 0:02:13.943479
# Iter 240000, Minibatch Loss= 3.395393, Training Accuracy= 0.06250, Time= 0:02:14.840190
# Iter 241600, Minibatch Loss= 3.583209, Training Accuracy= 0.00000, Time= 0:02:15.735117
# Iter 243200, Minibatch Loss= 3.478643, Training Accuracy= 0.00000, Time= 0:02:16.632191
# Iter 244800, Minibatch Loss= 3.451737, Training Accuracy= 0.00000, Time= 0:02:17.529349
# Iter 246400, Minibatch Loss= 3.288537, Training Accuracy= 0.12500, Time= 0:02:18.429754
# Iter 248000, Minibatch Loss= 2.685082, Training Accuracy= 0.18750, Time= 0:02:19.326976
# Iter 249600, Minibatch Loss= 3.247745, Training Accuracy= 0.06250, Time= 0:02:20.229273
# Iter 251200, Minibatch Loss= 3.323434, Training Accuracy= 0.00000, Time= 0:02:21.131575
# Iter 252800, Minibatch Loss= 3.052266, Training Accuracy= 0.18750, Time= 0:02:22.030795
# Iter 254400, Minibatch Loss= 2.855695, Training Accuracy= 0.25000, Time= 0:02:22.929664
# Iter 256000, Minibatch Loss= 3.100874, Training Accuracy= 0.25000, Time= 0:02:23.830457
# Iter 257600, Minibatch Loss= 2.712039, Training Accuracy= 0.25000, Time= 0:02:24.728098
# Iter 259200, Minibatch Loss= 2.873614, Training Accuracy= 0.18750, Time= 0:02:25.629105
# Iter 260800, Minibatch Loss= 3.396883, Training Accuracy= 0.12500, Time= 0:02:26.528964
# Iter 262400, Minibatch Loss= 3.088266, Training Accuracy= 0.25000, Time= 0:02:27.429481
# Iter 264000, Minibatch Loss= 3.061267, Training Accuracy= 0.12500, Time= 0:02:28.328876
# Iter 265600, Minibatch Loss= 2.534495, Training Accuracy= 0.43750, Time= 0:02:29.228711
# Iter 267200, Minibatch Loss= 3.332715, Training Accuracy= 0.12500, Time= 0:02:30.129724
# Iter 268800, Minibatch Loss= 3.421921, Training Accuracy= 0.00000, Time= 0:02:31.030577
# Iter 270400, Minibatch Loss= 3.245720, Training Accuracy= 0.12500, Time= 0:02:31.930445
# Iter 272000, Minibatch Loss= 2.961072, Training Accuracy= 0.37500, Time= 0:02:32.830845
# Iter 273600, Minibatch Loss= 2.792643, Training Accuracy= 0.25000, Time= 0:02:33.730075
# Iter 275200, Minibatch Loss= 3.478134, Training Accuracy= 0.12500, Time= 0:02:34.632358
# Iter 276800, Minibatch Loss= 2.929765, Training Accuracy= 0.18750, Time= 0:02:35.533648
# Iter 278400, Minibatch Loss= 3.322573, Training Accuracy= 0.00000, Time= 0:02:36.434344
# Iter 280000, Minibatch Loss= 2.606719, Training Accuracy= 0.25000, Time= 0:02:37.335192
# Iter 281600, Minibatch Loss= 3.056312, Training Accuracy= 0.31250, Time= 0:02:38.233113
# Iter 283200, Minibatch Loss= 2.675328, Training Accuracy= 0.25000, Time= 0:02:39.133457
# Iter 284800, Minibatch Loss= 2.945068, Training Accuracy= 0.12500, Time= 0:02:40.031251
# Iter 286400, Minibatch Loss= 3.297239, Training Accuracy= 0.00000, Time= 0:02:40.929931
# Iter 288000, Minibatch Loss= 3.235484, Training Accuracy= 0.06250, Time= 0:02:41.830141
# Iter 289600, Minibatch Loss= 2.936020, Training Accuracy= 0.31250, Time= 0:02:42.731000
# Iter 291200, Minibatch Loss= 2.885993, Training Accuracy= 0.12500, Time= 0:02:43.630442
# Iter 292800, Minibatch Loss= 3.110202, Training Accuracy= 0.25000, Time= 0:02:44.531529
# Iter 294400, Minibatch Loss= 3.061330, Training Accuracy= 0.06250, Time= 0:02:45.432251
# Iter 296000, Minibatch Loss= 2.714385, Training Accuracy= 0.31250, Time= 0:02:46.334199
# Iter 297600, Minibatch Loss= 2.979627, Training Accuracy= 0.18750, Time= 0:02:47.234417
# Iter 299200, Minibatch Loss= 3.612352, Training Accuracy= 0.18750, Time= 0:02:48.133215
# Iter 300800, Minibatch Loss= 2.747265, Training Accuracy= 0.12500, Time= 0:02:49.033979
# Iter 302400, Minibatch Loss= 2.978249, Training Accuracy= 0.18750, Time= 0:02:49.932580
# Iter 304000, Minibatch Loss= 3.319335, Training Accuracy= 0.06250, Time= 0:02:50.834513
# Iter 305600, Minibatch Loss= 2.841351, Training Accuracy= 0.06250, Time= 0:02:51.735902
# Iter 307200, Minibatch Loss= 2.552695, Training Accuracy= 0.25000, Time= 0:02:52.635975
# Iter 308800, Minibatch Loss= 2.748741, Training Accuracy= 0.25000, Time= 0:02:53.536536
# Iter 310400, Minibatch Loss= 3.880789, Training Accuracy= 0.06250, Time= 0:02:54.436915
# Iter 312000, Minibatch Loss= 3.339961, Training Accuracy= 0.12500, Time= 0:02:55.335845
# Iter 313600, Minibatch Loss= 2.903652, Training Accuracy= 0.25000, Time= 0:02:56.236408
# Iter 315200, Minibatch Loss= 3.180547, Training Accuracy= 0.12500, Time= 0:02:57.139799
# Iter 316800, Minibatch Loss= 2.995644, Training Accuracy= 0.18750, Time= 0:02:58.039413
# Iter 318400, Minibatch Loss= 3.092428, Training Accuracy= 0.06250, Time= 0:02:58.938100
# Iter 320000, Minibatch Loss= 3.384870, Training Accuracy= 0.31250, Time= 0:02:59.837361
# Iter 321600, Minibatch Loss= 2.714007, Training Accuracy= 0.25000, Time= 0:03:00.738563
# Iter 323200, Minibatch Loss= 3.569755, Training Accuracy= 0.00000, Time= 0:03:01.638614
# Iter 324800, Minibatch Loss= 2.711535, Training Accuracy= 0.12500, Time= 0:03:02.541040
# Iter 326400, Minibatch Loss= 2.711675, Training Accuracy= 0.18750, Time= 0:03:03.438578
# Iter 328000, Minibatch Loss= 2.859822, Training Accuracy= 0.12500, Time= 0:03:04.337873
# Iter 329600, Minibatch Loss= 3.349524, Training Accuracy= 0.18750, Time= 0:03:05.239242
# Iter 331200, Minibatch Loss= 2.665856, Training Accuracy= 0.37500, Time= 0:03:06.143037
# Iter 332800, Minibatch Loss= 2.997609, Training Accuracy= 0.37500, Time= 0:03:07.041792
# Iter 334400, Minibatch Loss= 3.058840, Training Accuracy= 0.18750, Time= 0:03:07.942871
# Iter 336000, Minibatch Loss= 2.341560, Training Accuracy= 0.31250, Time= 0:03:08.843516
# Iter 337600, Minibatch Loss= 3.625986, Training Accuracy= 0.06250, Time= 0:03:09.742989
# Iter 339200, Minibatch Loss= 2.336027, Training Accuracy= 0.43750, Time= 0:03:10.644364
# Iter 340800, Minibatch Loss= 3.413881, Training Accuracy= 0.12500, Time= 0:03:11.544768
# Iter 342400, Minibatch Loss= 2.383893, Training Accuracy= 0.25000, Time= 0:03:12.445483
# Iter 344000, Minibatch Loss= 2.297616, Training Accuracy= 0.31250, Time= 0:03:13.345938
# Iter 345600, Minibatch Loss= 2.501232, Training Accuracy= 0.25000, Time= 0:03:14.248656
# Iter 347200, Minibatch Loss= 2.484455, Training Accuracy= 0.25000, Time= 0:03:15.147627
# Iter 348800, Minibatch Loss= 3.206609, Training Accuracy= 0.06250, Time= 0:03:16.048913
# Iter 350400, Minibatch Loss= 2.692073, Training Accuracy= 0.25000, Time= 0:03:16.948327
# Iter 352000, Minibatch Loss= 2.541536, Training Accuracy= 0.25000, Time= 0:03:17.848637
# Iter 353600, Minibatch Loss= 2.491127, Training Accuracy= 0.18750, Time= 0:03:18.749335
# Iter 355200, Minibatch Loss= 3.493624, Training Accuracy= 0.06250, Time= 0:03:19.650218
# Iter 356800, Minibatch Loss= 2.798591, Training Accuracy= 0.31250, Time= 0:03:20.551981
# Iter 358400, Minibatch Loss= 2.799190, Training Accuracy= 0.18750, Time= 0:03:21.453667
# Iter 360000, Minibatch Loss= 2.920286, Training Accuracy= 0.18750, Time= 0:03:22.353870
# Iter 361600, Minibatch Loss= 2.534238, Training Accuracy= 0.31250, Time= 0:03:23.254491
# Iter 363200, Minibatch Loss= 2.609594, Training Accuracy= 0.25000, Time= 0:03:24.154871
# Iter 364800, Minibatch Loss= 2.226978, Training Accuracy= 0.31250, Time= 0:03:25.055145
# Iter 366400, Minibatch Loss= 2.347610, Training Accuracy= 0.31250, Time= 0:03:25.958039
# Iter 368000, Minibatch Loss= 2.604788, Training Accuracy= 0.31250, Time= 0:03:26.857949
# Iter 369600, Minibatch Loss= 2.447315, Training Accuracy= 0.25000, Time= 0:03:27.757922
# Iter 371200, Minibatch Loss= 2.639082, Training Accuracy= 0.25000, Time= 0:03:28.657628
# Iter 372800, Minibatch Loss= 2.875087, Training Accuracy= 0.25000, Time= 0:03:29.558225
# Iter 374400, Minibatch Loss= 2.259165, Training Accuracy= 0.25000, Time= 0:03:30.459876
# Iter 376000, Minibatch Loss= 3.098569, Training Accuracy= 0.06250, Time= 0:03:31.361781
# Iter 377600, Minibatch Loss= 2.683093, Training Accuracy= 0.25000, Time= 0:03:32.264260
# Iter 379200, Minibatch Loss= 2.598629, Training Accuracy= 0.31250, Time= 0:03:33.189010
# Iter 380800, Minibatch Loss= 2.930805, Training Accuracy= 0.18750, Time= 0:03:34.215960
# Iter 382400, Minibatch Loss= 2.407284, Training Accuracy= 0.18750, Time= 0:03:35.236814
# Iter 384000, Minibatch Loss= 2.422186, Training Accuracy= 0.31250, Time= 0:03:36.203620
# Iter 385600, Minibatch Loss= 2.525201, Training Accuracy= 0.18750, Time= 0:03:37.103081
# Iter 387200, Minibatch Loss= 2.064758, Training Accuracy= 0.37500, Time= 0:03:38.002419
# Iter 388800, Minibatch Loss= 2.531657, Training Accuracy= 0.25000, Time= 0:03:38.903635
# Iter 390400, Minibatch Loss= 2.458470, Training Accuracy= 0.18750, Time= 0:03:39.804069
# Iter 392000, Minibatch Loss= 1.814498, Training Accuracy= 0.50000, Time= 0:03:40.705120
# Iter 393600, Minibatch Loss= 2.189661, Training Accuracy= 0.31250, Time= 0:03:41.606477
# Iter 395200, Minibatch Loss= 2.437632, Training Accuracy= 0.25000, Time= 0:03:42.508798
# Iter 396800, Minibatch Loss= 2.660969, Training Accuracy= 0.25000, Time= 0:03:43.409213
# Iter 398400, Minibatch Loss= 2.715933, Training Accuracy= 0.37500, Time= 0:03:44.311475
# Iter 400000, Minibatch Loss= 2.762922, Training Accuracy= 0.25000, Time= 0:03:45.210719
# Iter 401600, Minibatch Loss= 2.029265, Training Accuracy= 0.43750, Time= 0:03:46.118352
# Iter 403200, Minibatch Loss= 2.443195, Training Accuracy= 0.12500, Time= 0:03:47.038787
# Iter 404800, Minibatch Loss= 1.961421, Training Accuracy= 0.43750, Time= 0:03:47.941748
# Iter 406400, Minibatch Loss= 2.314027, Training Accuracy= 0.25000, Time= 0:03:48.848561
# Iter 408000, Minibatch Loss= 2.692280, Training Accuracy= 0.31250, Time= 0:03:49.754575
# Iter 409600, Minibatch Loss= 2.474641, Training Accuracy= 0.31250, Time= 0:03:50.667080
# Iter 411200, Minibatch Loss= 2.327835, Training Accuracy= 0.37500, Time= 0:03:51.581980
# Iter 412800, Minibatch Loss= 2.731358, Training Accuracy= 0.25000, Time= 0:03:52.504112
# Iter 414400, Minibatch Loss= 2.751889, Training Accuracy= 0.25000, Time= 0:03:53.419940
# Iter 416000, Minibatch Loss= 2.381894, Training Accuracy= 0.18750, Time= 0:03:54.324847
# Iter 417600, Minibatch Loss= 2.703567, Training Accuracy= 0.31250, Time= 0:03:55.229520
# Iter 419200, Minibatch Loss= 2.739492, Training Accuracy= 0.25000, Time= 0:03:56.131507
# Iter 420800, Minibatch Loss= 2.343060, Training Accuracy= 0.31250, Time= 0:03:57.032155
# Iter 422400, Minibatch Loss= 2.022203, Training Accuracy= 0.25000, Time= 0:03:57.937566
# Iter 424000, Minibatch Loss= 2.281124, Training Accuracy= 0.37500, Time= 0:03:58.839777
# Iter 425600, Minibatch Loss= 2.748408, Training Accuracy= 0.12500, Time= 0:03:59.748158
# Iter 427200, Minibatch Loss= 2.438953, Training Accuracy= 0.18750, Time= 0:04:00.978740
# Iter 428800, Minibatch Loss= 2.261737, Training Accuracy= 0.25000, Time= 0:04:01.903801
# Iter 430400, Minibatch Loss= 1.967739, Training Accuracy= 0.62500, Time= 0:04:02.809125
# Iter 432000, Minibatch Loss= 2.688616, Training Accuracy= 0.12500, Time= 0:04:03.715501
# Iter 433600, Minibatch Loss= 2.365376, Training Accuracy= 0.12500, Time= 0:04:04.628580
# Iter 435200, Minibatch Loss= 2.304766, Training Accuracy= 0.31250, Time= 0:04:05.543541
# Iter 436800, Minibatch Loss= 2.469674, Training Accuracy= 0.25000, Time= 0:04:06.467948
# Iter 438400, Minibatch Loss= 2.567667, Training Accuracy= 0.25000, Time= 0:04:07.406896
# Iter 440000, Minibatch Loss= 2.044315, Training Accuracy= 0.31250, Time= 0:04:08.336833
# Iter 441600, Minibatch Loss= 1.844516, Training Accuracy= 0.56250, Time= 0:04:09.273955
# Iter 443200, Minibatch Loss= 2.207066, Training Accuracy= 0.25000, Time= 0:04:10.206852
# Iter 444800, Minibatch Loss= 1.946514, Training Accuracy= 0.37500, Time= 0:04:11.141258
# Iter 446400, Minibatch Loss= 2.172815, Training Accuracy= 0.37500, Time= 0:04:12.075965
# Iter 448000, Minibatch Loss= 2.367294, Training Accuracy= 0.18750, Time= 0:04:13.005070
# Iter 449600, Minibatch Loss= 2.146732, Training Accuracy= 0.31250, Time= 0:04:13.939877
# Iter 451200, Minibatch Loss= 2.527578, Training Accuracy= 0.31250, Time= 0:04:14.869636
# Iter 452800, Minibatch Loss= 1.992048, Training Accuracy= 0.43750, Time= 0:04:15.797087
# Iter 454400, Minibatch Loss= 2.532384, Training Accuracy= 0.18750, Time= 0:04:16.726640
# Iter 456000, Minibatch Loss= 2.375810, Training Accuracy= 0.31250, Time= 0:04:17.655148
# Iter 457600, Minibatch Loss= 2.798665, Training Accuracy= 0.25000, Time= 0:04:18.586636
# Iter 459200, Minibatch Loss= 2.035983, Training Accuracy= 0.31250, Time= 0:04:19.523358
# Iter 460800, Minibatch Loss= 2.303895, Training Accuracy= 0.18750, Time= 0:04:20.541072
# Iter 462400, Minibatch Loss= 2.253980, Training Accuracy= 0.18750, Time= 0:04:21.500675
# Iter 464000, Minibatch Loss= 1.838169, Training Accuracy= 0.37500, Time= 0:04:22.446838
# Iter 465600, Minibatch Loss= 1.903101, Training Accuracy= 0.31250, Time= 0:04:23.376076
# Iter 467200, Minibatch Loss= 2.180709, Training Accuracy= 0.25000, Time= 0:04:24.308324
# Iter 468800, Minibatch Loss= 2.837374, Training Accuracy= 0.25000, Time= 0:04:25.238267
# Iter 470400, Minibatch Loss= 2.160599, Training Accuracy= 0.25000, Time= 0:04:26.169590
# Iter 472000, Minibatch Loss= 2.181075, Training Accuracy= 0.37500, Time= 0:04:27.097078
# Iter 473600, Minibatch Loss= 2.197870, Training Accuracy= 0.25000, Time= 0:04:28.026582
# Iter 475200, Minibatch Loss= 2.120493, Training Accuracy= 0.31250, Time= 0:04:28.954535
# Iter 476800, Minibatch Loss= 2.337155, Training Accuracy= 0.18750, Time= 0:04:29.884603
# Iter 478400, Minibatch Loss= 2.661850, Training Accuracy= 0.25000, Time= 0:04:30.815285
# Iter 480000, Minibatch Loss= 1.939291, Training Accuracy= 0.37500, Time= 0:04:31.750421
# Iter 481600, Minibatch Loss= 2.357377, Training Accuracy= 0.37500, Time= 0:04:32.682500
# Iter 483200, Minibatch Loss= 2.129522, Training Accuracy= 0.37500, Time= 0:04:33.613264
# Iter 484800, Minibatch Loss= 2.056474, Training Accuracy= 0.50000, Time= 0:04:34.543394
# Iter 486400, Minibatch Loss= 1.551893, Training Accuracy= 0.75000, Time= 0:04:35.476513
# Iter 488000, Minibatch Loss= 2.878258, Training Accuracy= 0.31250, Time= 0:04:36.405115
# Iter 489600, Minibatch Loss= 2.045836, Training Accuracy= 0.31250, Time= 0:04:37.334743
# Iter 491200, Minibatch Loss= 1.868790, Training Accuracy= 0.50000, Time= 0:04:38.265086
# Iter 492800, Minibatch Loss= 2.470175, Training Accuracy= 0.12500, Time= 0:04:39.196819
# Iter 494400, Minibatch Loss= 1.972588, Training Accuracy= 0.43750, Time= 0:04:40.127009
# Iter 496000, Minibatch Loss= 2.071266, Training Accuracy= 0.37500, Time= 0:04:41.061387
# Iter 497600, Minibatch Loss= 1.833438, Training Accuracy= 0.37500, Time= 0:04:41.993026
# Iter 499200, Minibatch Loss= 2.208663, Training Accuracy= 0.37500, Time= 0:04:42.927917
# Iter 500800, Minibatch Loss= 2.133487, Training Accuracy= 0.37500, Time= 0:04:43.855929
# Iter 502400, Minibatch Loss= 1.713865, Training Accuracy= 0.50000, Time= 0:04:44.784139
# Iter 504000, Minibatch Loss= 1.996191, Training Accuracy= 0.18750, Time= 0:04:45.715659
# Iter 505600, Minibatch Loss= 2.100016, Training Accuracy= 0.43750, Time= 0:04:46.646852
# Iter 507200, Minibatch Loss= 2.360408, Training Accuracy= 0.18750, Time= 0:04:47.576028
# Iter 508800, Minibatch Loss= 2.102928, Training Accuracy= 0.25000, Time= 0:04:48.506569
# Iter 510400, Minibatch Loss= 1.772351, Training Accuracy= 0.56250, Time= 0:04:49.437748
# Iter 512000, Minibatch Loss= 2.233695, Training Accuracy= 0.25000, Time= 0:04:50.366297
# Iter 513600, Minibatch Loss= 2.386661, Training Accuracy= 0.31250, Time= 0:04:51.303714
# Iter 515200, Minibatch Loss= 1.666946, Training Accuracy= 0.43750, Time= 0:04:52.230888
# Iter 516800, Minibatch Loss= 1.986355, Training Accuracy= 0.50000, Time= 0:04:53.162850
# Iter 518400, Minibatch Loss= 1.861595, Training Accuracy= 0.50000, Time= 0:04:54.092208
# Iter 520000, Minibatch Loss= 2.038553, Training Accuracy= 0.37500, Time= 0:04:55.024195
# Iter 521600, Minibatch Loss= 2.039630, Training Accuracy= 0.25000, Time= 0:04:55.963021
# Iter 523200, Minibatch Loss= 1.269214, Training Accuracy= 0.62500, Time= 0:04:56.900147
# Iter 524800, Minibatch Loss= 1.680831, Training Accuracy= 0.68750, Time= 0:04:57.837243
# Iter 526400, Minibatch Loss= 2.043312, Training Accuracy= 0.37500, Time= 0:04:58.778482
# Iter 528000, Minibatch Loss= 1.896792, Training Accuracy= 0.43750, Time= 0:04:59.724048
# Iter 529600, Minibatch Loss= 1.920851, Training Accuracy= 0.43750, Time= 0:05:00.671260
# Iter 531200, Minibatch Loss= 2.143091, Training Accuracy= 0.43750, Time= 0:05:01.618615
# Iter 532800, Minibatch Loss= 1.786199, Training Accuracy= 0.37500, Time= 0:05:02.575814
# Iter 534400, Minibatch Loss= 1.854592, Training Accuracy= 0.37500, Time= 0:05:03.530396
# Iter 536000, Minibatch Loss= 1.232209, Training Accuracy= 0.56250, Time= 0:05:04.478316
# Iter 537600, Minibatch Loss= 1.655559, Training Accuracy= 0.50000, Time= 0:05:05.431662
# Iter 539200, Minibatch Loss= 2.121851, Training Accuracy= 0.31250, Time= 0:05:06.385300
# Iter 540800, Minibatch Loss= 2.624255, Training Accuracy= 0.31250, Time= 0:05:07.341819
# Iter 542400, Minibatch Loss= 1.594752, Training Accuracy= 0.31250, Time= 0:05:08.298096
# Iter 544000, Minibatch Loss= 1.830473, Training Accuracy= 0.56250, Time= 0:05:09.256706
# Iter 545600, Minibatch Loss= 1.627026, Training Accuracy= 0.56250, Time= 0:05:10.213583
# Iter 547200, Minibatch Loss= 2.151634, Training Accuracy= 0.25000, Time= 0:05:11.144932
# Iter 548800, Minibatch Loss= 2.134641, Training Accuracy= 0.18750, Time= 0:05:12.095537
# Iter 550400, Minibatch Loss= 1.610753, Training Accuracy= 0.43750, Time= 0:05:13.069103
# Iter 552000, Minibatch Loss= 1.662347, Training Accuracy= 0.43750, Time= 0:05:14.060753
# Iter 553600, Minibatch Loss= 1.571761, Training Accuracy= 0.56250, Time= 0:05:15.046060
# Iter 555200, Minibatch Loss= 1.810746, Training Accuracy= 0.37500, Time= 0:05:16.038986
# Iter 556800, Minibatch Loss= 2.132494, Training Accuracy= 0.50000, Time= 0:05:17.046185
# Iter 558400, Minibatch Loss= 1.692621, Training Accuracy= 0.50000, Time= 0:05:17.999126
# Iter 560000, Minibatch Loss= 2.218236, Training Accuracy= 0.37500, Time= 0:05:18.956558
# Iter 561600, Minibatch Loss= 1.362452, Training Accuracy= 0.37500, Time= 0:05:19.913090
# Iter 563200, Minibatch Loss= 1.453120, Training Accuracy= 0.56250, Time= 0:05:20.868650
# Iter 564800, Minibatch Loss= 1.781309, Training Accuracy= 0.43750, Time= 0:05:21.837158
# Iter 566400, Minibatch Loss= 2.293047, Training Accuracy= 0.37500, Time= 0:05:22.794812
# Iter 568000, Minibatch Loss= 1.589836, Training Accuracy= 0.62500, Time= 0:05:23.707537
# Iter 569600, Minibatch Loss= 1.504735, Training Accuracy= 0.50000, Time= 0:05:24.638216
# Iter 571200, Minibatch Loss= 1.494358, Training Accuracy= 0.62500, Time= 0:05:25.538393
# Iter 572800, Minibatch Loss= 1.746045, Training Accuracy= 0.43750, Time= 0:05:26.450660
# Iter 574400, Minibatch Loss= 1.442602, Training Accuracy= 0.56250, Time= 0:05:27.455679
# Iter 576000, Minibatch Loss= 1.722740, Training Accuracy= 0.43750, Time= 0:05:28.464888
# Iter 577600, Minibatch Loss= 1.925064, Training Accuracy= 0.50000, Time= 0:05:29.442643
# Iter 579200, Minibatch Loss= 2.202417, Training Accuracy= 0.25000, Time= 0:05:30.422002
# Iter 580800, Minibatch Loss= 1.510008, Training Accuracy= 0.56250, Time= 0:05:31.346872
# Iter 582400, Minibatch Loss= 1.108819, Training Accuracy= 0.75000, Time= 0:05:32.301324
# Iter 584000, Minibatch Loss= 1.303033, Training Accuracy= 0.56250, Time= 0:05:33.238775
# Iter 585600, Minibatch Loss= 2.064404, Training Accuracy= 0.62500, Time= 0:05:34.226091
# Iter 587200, Minibatch Loss= 2.613379, Training Accuracy= 0.18750, Time= 0:05:35.209000
# Iter 588800, Minibatch Loss= 1.546936, Training Accuracy= 0.37500, Time= 0:05:36.161341
# Iter 590400, Minibatch Loss= 2.347648, Training Accuracy= 0.31250, Time= 0:05:37.084418
# Iter 592000, Minibatch Loss= 1.696830, Training Accuracy= 0.43750, Time= 0:05:38.049404
# Iter 593600, Minibatch Loss= 1.571868, Training Accuracy= 0.43750, Time= 0:05:39.091323
# Iter 595200, Minibatch Loss= 1.384741, Training Accuracy= 0.56250, Time= 0:05:40.046462
# Iter 596800, Minibatch Loss= 1.496550, Training Accuracy= 0.56250, Time= 0:05:40.991510
# Iter 598400, Minibatch Loss= 1.286481, Training Accuracy= 0.56250, Time= 0:05:41.954483
# Iter 600000, Minibatch Loss= 1.432818, Training Accuracy= 0.50000, Time= 0:05:42.924164
# Iter 601600, Minibatch Loss= 1.833311, Training Accuracy= 0.37500, Time= 0:05:43.854986
# Iter 603200, Minibatch Loss= 1.397423, Training Accuracy= 0.50000, Time= 0:05:44.793566
# Iter 604800, Minibatch Loss= 1.547139, Training Accuracy= 0.50000, Time= 0:05:45.730889
# Iter 606400, Minibatch Loss= 1.287419, Training Accuracy= 0.56250, Time= 0:05:46.662196
# Iter 608000, Minibatch Loss= 1.885912, Training Accuracy= 0.31250, Time= 0:05:47.594583
# Iter 609600, Minibatch Loss= 1.307172, Training Accuracy= 0.62500, Time= 0:05:48.528316
# Iter 611200, Minibatch Loss= 1.133291, Training Accuracy= 0.62500, Time= 0:05:49.461918
# Iter 612800, Minibatch Loss= 1.417520, Training Accuracy= 0.56250, Time= 0:05:50.407209
# Iter 614400, Minibatch Loss= 1.830060, Training Accuracy= 0.43750, Time= 0:05:51.345043
# Iter 616000, Minibatch Loss= 0.582824, Training Accuracy= 0.87500, Time= 0:05:52.282574
# Iter 617600, Minibatch Loss= 1.913496, Training Accuracy= 0.25000, Time= 0:05:53.231188
# Iter 619200, Minibatch Loss= 1.392512, Training Accuracy= 0.56250, Time= 0:05:54.179303
# Iter 620800, Minibatch Loss= 1.359085, Training Accuracy= 0.50000, Time= 0:05:55.136765
# Iter 622400, Minibatch Loss= 1.721254, Training Accuracy= 0.62500, Time= 0:05:56.066592
# Iter 624000, Minibatch Loss= 1.399016, Training Accuracy= 0.56250, Time= 0:05:56.999369
# Iter 625600, Minibatch Loss= 2.149028, Training Accuracy= 0.43750, Time= 0:05:57.932518
# Iter 627200, Minibatch Loss= 1.888476, Training Accuracy= 0.43750, Time= 0:05:58.880675
# Iter 628800, Minibatch Loss= 1.397971, Training Accuracy= 0.50000, Time= 0:06:00.055035
# Iter 630400, Minibatch Loss= 1.077091, Training Accuracy= 0.50000, Time= 0:06:01.057926
# Iter 632000, Minibatch Loss= 1.619590, Training Accuracy= 0.68750, Time= 0:06:02.009391
# Iter 633600, Minibatch Loss= 1.594603, Training Accuracy= 0.68750, Time= 0:06:03.019148
# Iter 635200, Minibatch Loss= 1.066111, Training Accuracy= 0.62500, Time= 0:06:03.983398
# Iter 636800, Minibatch Loss= 1.891972, Training Accuracy= 0.37500, Time= 0:06:04.932242
# Iter 638400, Minibatch Loss= 1.479345, Training Accuracy= 0.50000, Time= 0:06:05.859975
# Iter 640000, Minibatch Loss= 1.286605, Training Accuracy= 0.68750, Time= 0:06:06.768013
# Iter 641600, Minibatch Loss= 1.505787, Training Accuracy= 0.56250, Time= 0:06:07.692229
# Iter 643200, Minibatch Loss= 1.849017, Training Accuracy= 0.68750, Time= 0:06:08.605852
# Iter 644800, Minibatch Loss= 1.594981, Training Accuracy= 0.31250, Time= 0:06:09.518336
# Iter 646400, Minibatch Loss= 1.460031, Training Accuracy= 0.50000, Time= 0:06:10.425310
# Iter 648000, Minibatch Loss= 1.065361, Training Accuracy= 0.68750, Time= 0:06:11.345334
# Iter 649600, Minibatch Loss= 0.702050, Training Accuracy= 0.81250, Time= 0:06:12.252548
# Iter 651200, Minibatch Loss= 1.683528, Training Accuracy= 0.68750, Time= 0:06:13.159165
# Iter 652800, Minibatch Loss= 1.064304, Training Accuracy= 0.68750, Time= 0:06:14.085554
# Iter 654400, Minibatch Loss= 2.095804, Training Accuracy= 0.56250, Time= 0:06:15.006795
# Iter 656000, Minibatch Loss= 1.736083, Training Accuracy= 0.43750, Time= 0:06:15.925372
# Iter 657600, Minibatch Loss= 1.257234, Training Accuracy= 0.56250, Time= 0:06:16.902672
# Iter 659200, Minibatch Loss= 1.905105, Training Accuracy= 0.37500, Time= 0:06:17.850431
# Iter 660800, Minibatch Loss= 0.749648, Training Accuracy= 0.87500, Time= 0:06:18.746160
# Iter 662400, Minibatch Loss= 1.407131, Training Accuracy= 0.43750, Time= 0:06:19.642268
# Iter 664000, Minibatch Loss= 1.368345, Training Accuracy= 0.50000, Time= 0:06:20.537315
# Iter 665600, Minibatch Loss= 1.190702, Training Accuracy= 0.68750, Time= 0:06:21.433168
# Iter 667200, Minibatch Loss= 1.113263, Training Accuracy= 0.62500, Time= 0:06:22.336080
# Iter 668800, Minibatch Loss= 1.264381, Training Accuracy= 0.62500, Time= 0:06:23.233710
# Iter 670400, Minibatch Loss= 1.070981, Training Accuracy= 0.75000, Time= 0:06:24.134417
# Iter 672000, Minibatch Loss= 1.058348, Training Accuracy= 0.68750, Time= 0:06:25.031716
# Iter 673600, Minibatch Loss= 1.025567, Training Accuracy= 0.75000, Time= 0:06:25.947303
# Iter 675200, Minibatch Loss= 1.482167, Training Accuracy= 0.62500, Time= 0:06:26.866326
# Iter 676800, Minibatch Loss= 2.071232, Training Accuracy= 0.50000, Time= 0:06:27.776418
# Iter 678400, Minibatch Loss= 2.095767, Training Accuracy= 0.62500, Time= 0:06:28.700164
# Iter 680000, Minibatch Loss= 1.225668, Training Accuracy= 0.56250, Time= 0:06:29.631909
# Iter 681600, Minibatch Loss= 1.334226, Training Accuracy= 0.62500, Time= 0:06:30.538620
# Iter 683200, Minibatch Loss= 1.822347, Training Accuracy= 0.50000, Time= 0:06:31.441495
# Iter 684800, Minibatch Loss= 1.548222, Training Accuracy= 0.56250, Time= 0:06:32.338795
# Iter 686400, Minibatch Loss= 1.164764, Training Accuracy= 0.56250, Time= 0:06:33.237288
# Iter 688000, Minibatch Loss= 1.149391, Training Accuracy= 0.68750, Time= 0:06:34.134192
# Iter 689600, Minibatch Loss= 1.575033, Training Accuracy= 0.62500, Time= 0:06:35.026537
# Iter 691200, Minibatch Loss= 2.007492, Training Accuracy= 0.56250, Time= 0:06:35.932439
# Iter 692800, Minibatch Loss= 1.075225, Training Accuracy= 0.68750, Time= 0:06:36.837118
# Iter 694400, Minibatch Loss= 1.040642, Training Accuracy= 0.62500, Time= 0:06:37.743899
# Iter 696000, Minibatch Loss= 1.350184, Training Accuracy= 0.75000, Time= 0:06:38.638084
# Iter 697600, Minibatch Loss= 1.553273, Training Accuracy= 0.56250, Time= 0:06:39.551294
# Iter 699200, Minibatch Loss= 1.062972, Training Accuracy= 0.68750, Time= 0:06:40.465258
# Iter 700800, Minibatch Loss= 1.699629, Training Accuracy= 0.56250, Time= 0:06:41.366913
# Iter 702400, Minibatch Loss= 1.617375, Training Accuracy= 0.50000, Time= 0:06:42.279928
# Iter 704000, Minibatch Loss= 1.837789, Training Accuracy= 0.56250, Time= 0:06:43.198367
# Iter 705600, Minibatch Loss= 1.474330, Training Accuracy= 0.37500, Time= 0:06:44.105130
# Iter 707200, Minibatch Loss= 1.236156, Training Accuracy= 0.56250, Time= 0:06:44.998155
# Iter 708800, Minibatch Loss= 1.304786, Training Accuracy= 0.75000, Time= 0:06:45.920975
# Iter 710400, Minibatch Loss= 1.167466, Training Accuracy= 0.68750, Time= 0:06:46.830853
# Iter 712000, Minibatch Loss= 1.407171, Training Accuracy= 0.68750, Time= 0:06:47.753871
# Iter 713600, Minibatch Loss= 1.187058, Training Accuracy= 0.56250, Time= 0:06:48.661499
# Iter 715200, Minibatch Loss= 0.617514, Training Accuracy= 0.81250, Time= 0:06:49.569944
# Iter 716800, Minibatch Loss= 2.013742, Training Accuracy= 0.56250, Time= 0:06:50.474091
# Iter 718400, Minibatch Loss= 1.381622, Training Accuracy= 0.68750, Time= 0:06:51.409965
# Iter 720000, Minibatch Loss= 0.970085, Training Accuracy= 0.75000, Time= 0:06:52.351548
# Iter 721600, Minibatch Loss= 1.479410, Training Accuracy= 0.62500, Time= 0:06:53.246925
# Iter 723200, Minibatch Loss= 1.243253, Training Accuracy= 0.62500, Time= 0:06:54.151308
# Iter 724800, Minibatch Loss= 1.193344, Training Accuracy= 0.62500, Time= 0:06:55.292942
# Iter 726400, Minibatch Loss= 1.750846, Training Accuracy= 0.75000, Time= 0:06:56.285414
# Iter 728000, Minibatch Loss= 0.806004, Training Accuracy= 0.81250, Time= 0:06:57.201572
# Iter 729600, Minibatch Loss= 1.565064, Training Accuracy= 0.50000, Time= 0:06:58.122853
# Iter 731200, Minibatch Loss= 1.520944, Training Accuracy= 0.43750, Time= 0:06:59.043025
# Iter 732800, Minibatch Loss= 1.053914, Training Accuracy= 0.62500, Time= 0:07:00.004322
# Iter 734400, Minibatch Loss= 0.848279, Training Accuracy= 0.68750, Time= 0:07:00.930150
# Iter 736000, Minibatch Loss= 1.261984, Training Accuracy= 0.68750, Time= 0:07:02.116148
# Iter 737600, Minibatch Loss= 1.855998, Training Accuracy= 0.62500, Time= 0:07:03.026381
# Iter 739200, Minibatch Loss= 1.405338, Training Accuracy= 0.56250, Time= 0:07:03.988382
# Iter 740800, Minibatch Loss= 1.339249, Training Accuracy= 0.68750, Time= 0:07:04.939302
# Iter 742400, Minibatch Loss= 0.913996, Training Accuracy= 0.68750, Time= 0:07:05.923824
# Iter 744000, Minibatch Loss= 0.938377, Training Accuracy= 0.81250, Time= 0:07:06.853984
# Iter 745600, Minibatch Loss= 1.368522, Training Accuracy= 0.50000, Time= 0:07:07.778010
# Iter 747200, Minibatch Loss= 1.035266, Training Accuracy= 0.62500, Time= 0:07:08.700787
# Iter 748800, Minibatch Loss= 0.624451, Training Accuracy= 0.68750, Time= 0:07:09.604838
# Iter 750400, Minibatch Loss= 0.726525, Training Accuracy= 0.81250, Time= 0:07:10.500157
# Iter 752000, Minibatch Loss= 1.144691, Training Accuracy= 0.68750, Time= 0:07:11.395410
# Iter 753600, Minibatch Loss= 1.042155, Training Accuracy= 0.68750, Time= 0:07:12.377005
# Iter 755200, Minibatch Loss= 1.371459, Training Accuracy= 0.62500, Time= 0:07:13.368264
# Iter 756800, Minibatch Loss= 1.863358, Training Accuracy= 0.31250, Time= 0:07:14.284057
# Iter 758400, Minibatch Loss= 0.814724, Training Accuracy= 0.75000, Time= 0:07:15.230663
# Iter 760000, Minibatch Loss= 1.342070, Training Accuracy= 0.50000, Time= 0:07:16.136061
# Iter 761600, Minibatch Loss= 1.716544, Training Accuracy= 0.50000, Time= 0:07:17.048632
# Iter 763200, Minibatch Loss= 0.791668, Training Accuracy= 0.75000, Time= 0:07:17.959054
# Iter 764800, Minibatch Loss= 0.942248, Training Accuracy= 0.56250, Time= 0:07:18.875563
# Iter 766400, Minibatch Loss= 0.949003, Training Accuracy= 0.68750, Time= 0:07:19.781490
# Iter 768000, Minibatch Loss= 1.626843, Training Accuracy= 0.62500, Time= 0:07:20.701199
# Iter 769600, Minibatch Loss= 1.682547, Training Accuracy= 0.62500, Time= 0:07:21.610994
# Iter 771200, Minibatch Loss= 0.618538, Training Accuracy= 0.81250, Time= 0:07:22.521698
# Iter 772800, Minibatch Loss= 1.250042, Training Accuracy= 0.43750, Time= 0:07:23.449034
# Iter 774400, Minibatch Loss= 1.169295, Training Accuracy= 0.62500, Time= 0:07:24.365312
# Iter 776000, Minibatch Loss= 0.839124, Training Accuracy= 0.68750, Time= 0:07:25.290156
# Iter 777600, Minibatch Loss= 0.767659, Training Accuracy= 0.56250, Time= 0:07:26.209140
# Iter 779200, Minibatch Loss= 1.457020, Training Accuracy= 0.68750, Time= 0:07:27.128681
# Iter 780800, Minibatch Loss= 0.666445, Training Accuracy= 0.75000, Time= 0:07:28.023713
# Iter 782400, Minibatch Loss= 0.560225, Training Accuracy= 0.81250, Time= 0:07:28.917225
# Iter 784000, Minibatch Loss= 1.377458, Training Accuracy= 0.56250, Time= 0:07:29.816999
# Iter 785600, Minibatch Loss= 1.596721, Training Accuracy= 0.56250, Time= 0:07:30.723708
# Iter 787200, Minibatch Loss= 1.160472, Training Accuracy= 0.68750, Time= 0:07:31.632462
# Iter 788800, Minibatch Loss= 2.242106, Training Accuracy= 0.56250, Time= 0:07:32.550675
# Iter 790400, Minibatch Loss= 1.411451, Training Accuracy= 0.62500, Time= 0:07:33.456095
# Iter 792000, Minibatch Loss= 1.517579, Training Accuracy= 0.50000, Time= 0:07:34.370897
# Iter 793600, Minibatch Loss= 1.216749, Training Accuracy= 0.50000, Time= 0:07:35.316818
# Iter 795200, Minibatch Loss= 0.912867, Training Accuracy= 0.75000, Time= 0:07:36.222864
# Iter 796800, Minibatch Loss= 0.801816, Training Accuracy= 0.62500, Time= 0:07:37.148128
# Iter 798400, Minibatch Loss= 1.452919, Training Accuracy= 0.56250, Time= 0:07:38.067084
# Optimization Finished!
# Testing Accuracy: 0.46921

# %%
saver.save(sess, '../Model/NIN-Model-0xx')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
