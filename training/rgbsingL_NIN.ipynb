# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t526.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (126263, 37)

# %%
# Parameters
learning_rate = 0.001
training_iters = 500000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-4})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==5):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.581072, Training Accuracy= 0.06250
# Iter 3200, Minibatch Loss= 3.592586, Training Accuracy= 0.06250
# Iter 4800, Minibatch Loss= 3.543694, Training Accuracy= 0.06250
# Iter 6400, Minibatch Loss= 3.509537, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.578080, Training Accuracy= 0.00000
# Iter 9600, Minibatch Loss= 3.436860, Training Accuracy= 0.06250
# Iter 11200, Minibatch Loss= 3.428022, Training Accuracy= 0.06250
# Iter 12800, Minibatch Loss= 3.380130, Training Accuracy= 0.12500
# Iter 14400, Minibatch Loss= 3.569063, Training Accuracy= 0.00000
# Iter 16000, Minibatch Loss= 3.596398, Training Accuracy= 0.06250
# Iter 17600, Minibatch Loss= 3.538341, Training Accuracy= 0.00000
# Iter 19200, Minibatch Loss= 3.605806, Training Accuracy= 0.00000
# Iter 20800, Minibatch Loss= 3.228472, Training Accuracy= 0.12500
# Iter 22400, Minibatch Loss= 3.610628, Training Accuracy= 0.00000
# Iter 24000, Minibatch Loss= 3.491526, Training Accuracy= 0.00000
# Iter 25600, Minibatch Loss= 3.582599, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.607837, Training Accuracy= 0.06250
# Iter 28800, Minibatch Loss= 3.564676, Training Accuracy= 0.12500
# Iter 30400, Minibatch Loss= 3.565324, Training Accuracy= 0.00000
# Iter 32000, Minibatch Loss= 3.507779, Training Accuracy= 0.12500
# Iter 33600, Minibatch Loss= 3.522234, Training Accuracy= 0.06250
# Iter 35200, Minibatch Loss= 3.164205, Training Accuracy= 0.06250
# Iter 36800, Minibatch Loss= 3.200781, Training Accuracy= 0.12500
# Iter 38400, Minibatch Loss= 3.286133, Training Accuracy= 0.06250
# Iter 40000, Minibatch Loss= 3.485334, Training Accuracy= 0.12500
# Iter 41600, Minibatch Loss= 2.834717, Training Accuracy= 0.12500
# Iter 43200, Minibatch Loss= 3.050879, Training Accuracy= 0.06250
# Iter 44800, Minibatch Loss= 2.790805, Training Accuracy= 0.31250
# Iter 46400, Minibatch Loss= 3.304550, Training Accuracy= 0.00000
# Iter 48000, Minibatch Loss= 2.917652, Training Accuracy= 0.25000
# Iter 49600, Minibatch Loss= 2.748116, Training Accuracy= 0.18750
# Iter 51200, Minibatch Loss= 2.426269, Training Accuracy= 0.31250
# Iter 52800, Minibatch Loss= 2.843817, Training Accuracy= 0.12500
# Iter 54400, Minibatch Loss= 2.305345, Training Accuracy= 0.18750
# Iter 56000, Minibatch Loss= 2.710826, Training Accuracy= 0.25000
# Iter 57600, Minibatch Loss= 2.135064, Training Accuracy= 0.31250
# Iter 59200, Minibatch Loss= 2.380061, Training Accuracy= 0.25000
# Iter 60800, Minibatch Loss= 2.691695, Training Accuracy= 0.18750
# Iter 62400, Minibatch Loss= 2.001919, Training Accuracy= 0.56250
# Iter 64000, Minibatch Loss= 2.164344, Training Accuracy= 0.37500
# Iter 65600, Minibatch Loss= 2.422373, Training Accuracy= 0.50000
# Iter 67200, Minibatch Loss= 2.073459, Training Accuracy= 0.37500
# Iter 68800, Minibatch Loss= 2.352496, Training Accuracy= 0.37500
# Iter 70400, Minibatch Loss= 2.203106, Training Accuracy= 0.43750
# Iter 72000, Minibatch Loss= 1.647099, Training Accuracy= 0.68750
# Iter 73600, Minibatch Loss= 1.745092, Training Accuracy= 0.31250
# Iter 75200, Minibatch Loss= 1.859490, Training Accuracy= 0.37500
# Iter 76800, Minibatch Loss= 1.862168, Training Accuracy= 0.50000
# Iter 78400, Minibatch Loss= 1.489974, Training Accuracy= 0.56250
# Iter 80000, Minibatch Loss= 1.849133, Training Accuracy= 0.50000
# Iter 81600, Minibatch Loss= 1.581642, Training Accuracy= 0.56250
# Iter 83200, Minibatch Loss= 0.658589, Training Accuracy= 0.87500
# Iter 84800, Minibatch Loss= 1.098148, Training Accuracy= 0.56250
# Iter 86400, Minibatch Loss= 1.885363, Training Accuracy= 0.50000
# Iter 88000, Minibatch Loss= 0.967190, Training Accuracy= 0.81250
# Iter 89600, Minibatch Loss= 1.572453, Training Accuracy= 0.50000
# Iter 91200, Minibatch Loss= 0.998395, Training Accuracy= 0.75000
# Iter 92800, Minibatch Loss= 1.040531, Training Accuracy= 0.68750
# Iter 94400, Minibatch Loss= 0.754324, Training Accuracy= 0.75000
# Iter 96000, Minibatch Loss= 1.670973, Training Accuracy= 0.62500
# Iter 97600, Minibatch Loss= 1.216836, Training Accuracy= 0.62500
# Iter 99200, Minibatch Loss= 0.449968, Training Accuracy= 0.87500
# Iter 100800, Minibatch Loss= 0.693100, Training Accuracy= 0.81250
# Iter 102400, Minibatch Loss= 0.418250, Training Accuracy= 0.87500
# Iter 104000, Minibatch Loss= 0.661600, Training Accuracy= 0.87500
# Iter 105600, Minibatch Loss= 1.004055, Training Accuracy= 0.56250
# Iter 107200, Minibatch Loss= 0.805768, Training Accuracy= 0.81250
# Iter 108800, Minibatch Loss= 0.918566, Training Accuracy= 0.68750
# Iter 110400, Minibatch Loss= 0.718155, Training Accuracy= 0.87500
# Iter 112000, Minibatch Loss= 1.157965, Training Accuracy= 0.81250
# Iter 113600, Minibatch Loss= 0.553970, Training Accuracy= 0.87500
# Iter 115200, Minibatch Loss= 0.232012, Training Accuracy= 1.00000
# Iter 116800, Minibatch Loss= 0.144604, Training Accuracy= 0.93750
# Iter 118400, Minibatch Loss= 0.898120, Training Accuracy= 0.75000
# Iter 120000, Minibatch Loss= 0.920157, Training Accuracy= 0.75000
# Iter 121600, Minibatch Loss= 0.147406, Training Accuracy= 1.00000
# Iter 123200, Minibatch Loss= 0.639787, Training Accuracy= 0.81250
# Iter 124800, Minibatch Loss= 0.741227, Training Accuracy= 0.87500
# Iter 126400, Minibatch Loss= 0.657637, Training Accuracy= 0.87500
# Iter 128000, Minibatch Loss= 0.160696, Training Accuracy= 0.93750
# Iter 129600, Minibatch Loss= 0.155429, Training Accuracy= 0.93750
# Iter 131200, Minibatch Loss= 0.228757, Training Accuracy= 0.93750
# Iter 132800, Minibatch Loss= 0.152171, Training Accuracy= 0.93750
# Iter 134400, Minibatch Loss= 0.614952, Training Accuracy= 0.81250
# Iter 136000, Minibatch Loss= 0.475435, Training Accuracy= 0.81250
# Iter 137600, Minibatch Loss= 0.733295, Training Accuracy= 0.81250
# Iter 139200, Minibatch Loss= 0.443097, Training Accuracy= 0.93750
# Iter 140800, Minibatch Loss= 0.458397, Training Accuracy= 0.87500
# Iter 142400, Minibatch Loss= 0.190419, Training Accuracy= 0.93750
# Iter 144000, Minibatch Loss= 0.324719, Training Accuracy= 0.93750
# Iter 145600, Minibatch Loss= 0.296853, Training Accuracy= 0.87500
# Iter 147200, Minibatch Loss= 0.175289, Training Accuracy= 0.93750
# Iter 148800, Minibatch Loss= 0.338973, Training Accuracy= 0.93750
# Iter 150400, Minibatch Loss= 0.293971, Training Accuracy= 0.81250
# Iter 152000, Minibatch Loss= 0.509104, Training Accuracy= 0.87500
# Iter 153600, Minibatch Loss= 0.260022, Training Accuracy= 0.93750
# Iter 155200, Minibatch Loss= 0.058937, Training Accuracy= 1.00000
# Iter 156800, Minibatch Loss= 0.083615, Training Accuracy= 1.00000
# Iter 158400, Minibatch Loss= 0.188738, Training Accuracy= 0.93750
# Iter 160000, Minibatch Loss= 0.407336, Training Accuracy= 0.81250
# Iter 161600, Minibatch Loss= 0.652415, Training Accuracy= 0.81250
# Iter 163200, Minibatch Loss= 0.173018, Training Accuracy= 0.93750
# Iter 164800, Minibatch Loss= 0.007624, Training Accuracy= 1.00000
# Iter 166400, Minibatch Loss= 0.109882, Training Accuracy= 1.00000
# Iter 168000, Minibatch Loss= 0.187335, Training Accuracy= 0.93750
# Iter 169600, Minibatch Loss= 0.919555, Training Accuracy= 0.87500
# Iter 171200, Minibatch Loss= 0.312792, Training Accuracy= 0.93750
# Iter 172800, Minibatch Loss= 0.482569, Training Accuracy= 0.87500
# Iter 174400, Minibatch Loss= 0.278144, Training Accuracy= 0.87500
# Iter 176000, Minibatch Loss= 0.261000, Training Accuracy= 0.93750
# Iter 177600, Minibatch Loss= 0.185158, Training Accuracy= 0.93750
# Iter 179200, Minibatch Loss= 0.030701, Training Accuracy= 1.00000
# Iter 180800, Minibatch Loss= 0.198595, Training Accuracy= 0.93750
# Iter 182400, Minibatch Loss= 0.086457, Training Accuracy= 1.00000
# Iter 184000, Minibatch Loss= 0.288254, Training Accuracy= 0.87500
# Iter 185600, Minibatch Loss= 0.028643, Training Accuracy= 1.00000
# Iter 187200, Minibatch Loss= 0.265563, Training Accuracy= 0.93750
# Iter 188800, Minibatch Loss= 0.061941, Training Accuracy= 1.00000
# Iter 190400, Minibatch Loss= 0.365568, Training Accuracy= 0.93750
# Iter 192000, Minibatch Loss= 0.119556, Training Accuracy= 1.00000
# Iter 193600, Minibatch Loss= 0.062045, Training Accuracy= 1.00000
# Iter 195200, Minibatch Loss= 0.329868, Training Accuracy= 0.93750
# Iter 196800, Minibatch Loss= 0.525072, Training Accuracy= 0.87500
# Iter 198400, Minibatch Loss= 0.579252, Training Accuracy= 0.87500
# Iter 200000, Minibatch Loss= 0.257867, Training Accuracy= 0.93750
# Iter 201600, Minibatch Loss= 0.057795, Training Accuracy= 1.00000
# Iter 203200, Minibatch Loss= 0.664396, Training Accuracy= 0.81250
# Iter 204800, Minibatch Loss= 0.115547, Training Accuracy= 0.93750
# Iter 206400, Minibatch Loss= 0.897587, Training Accuracy= 0.87500
# Iter 208000, Minibatch Loss= 0.105400, Training Accuracy= 1.00000
# Iter 209600, Minibatch Loss= 0.042641, Training Accuracy= 1.00000
# Iter 211200, Minibatch Loss= 0.220275, Training Accuracy= 0.93750
# Iter 212800, Minibatch Loss= 0.108216, Training Accuracy= 0.93750
# Iter 214400, Minibatch Loss= 0.170769, Training Accuracy= 0.93750
# Iter 216000, Minibatch Loss= 0.188496, Training Accuracy= 1.00000
# Iter 217600, Minibatch Loss= 0.082403, Training Accuracy= 1.00000
# Iter 219200, Minibatch Loss= 0.113855, Training Accuracy= 0.93750
# Iter 220800, Minibatch Loss= 0.053115, Training Accuracy= 1.00000
# Iter 222400, Minibatch Loss= 0.312952, Training Accuracy= 0.93750
# Iter 224000, Minibatch Loss= 0.041421, Training Accuracy= 1.00000
# Iter 225600, Minibatch Loss= 0.104656, Training Accuracy= 1.00000
# Iter 227200, Minibatch Loss= 0.247255, Training Accuracy= 0.93750
# Iter 228800, Minibatch Loss= 0.136157, Training Accuracy= 0.93750
# Iter 230400, Minibatch Loss= 0.326485, Training Accuracy= 0.87500
# Iter 232000, Minibatch Loss= 0.032334, Training Accuracy= 1.00000
# Iter 233600, Minibatch Loss= 0.012322, Training Accuracy= 1.00000
# Iter 235200, Minibatch Loss= 0.001041, Training Accuracy= 1.00000
# Iter 236800, Minibatch Loss= 0.016016, Training Accuracy= 1.00000
# Iter 238400, Minibatch Loss= 0.033577, Training Accuracy= 1.00000
# Iter 240000, Minibatch Loss= 0.003101, Training Accuracy= 1.00000
# Iter 241600, Minibatch Loss= 0.171456, Training Accuracy= 0.93750
# Iter 243200, Minibatch Loss= 0.036826, Training Accuracy= 1.00000
# Iter 244800, Minibatch Loss= 0.274342, Training Accuracy= 0.93750
# Iter 246400, Minibatch Loss= 0.754325, Training Accuracy= 0.81250
# Iter 248000, Minibatch Loss= 0.327543, Training Accuracy= 0.87500
# Iter 249600, Minibatch Loss= 0.137070, Training Accuracy= 0.93750
# Iter 251200, Minibatch Loss= 0.229768, Training Accuracy= 0.93750
# Iter 252800, Minibatch Loss= 0.221436, Training Accuracy= 0.93750
# Iter 254400, Minibatch Loss= 0.028244, Training Accuracy= 1.00000
# Iter 256000, Minibatch Loss= 0.011521, Training Accuracy= 1.00000
# Iter 257600, Minibatch Loss= 0.121497, Training Accuracy= 0.93750
# Iter 259200, Minibatch Loss= 0.149357, Training Accuracy= 0.93750
# Iter 260800, Minibatch Loss= 0.008004, Training Accuracy= 1.00000
# Iter 262400, Minibatch Loss= 0.011962, Training Accuracy= 1.00000
# Iter 264000, Minibatch Loss= 0.006958, Training Accuracy= 1.00000
# Iter 265600, Minibatch Loss= 0.136683, Training Accuracy= 0.93750
# Iter 267200, Minibatch Loss= 0.003868, Training Accuracy= 1.00000
# Iter 268800, Minibatch Loss= 0.013211, Training Accuracy= 1.00000
# Iter 270400, Minibatch Loss= 0.187311, Training Accuracy= 0.87500
# Iter 272000, Minibatch Loss= 0.099371, Training Accuracy= 0.93750
# Iter 273600, Minibatch Loss= 0.008646, Training Accuracy= 1.00000
# Iter 275200, Minibatch Loss= 0.014741, Training Accuracy= 1.00000
# Iter 276800, Minibatch Loss= 0.026982, Training Accuracy= 1.00000
# Iter 278400, Minibatch Loss= 0.302033, Training Accuracy= 0.87500
# Iter 280000, Minibatch Loss= 0.166328, Training Accuracy= 0.93750
# Iter 281600, Minibatch Loss= 0.010788, Training Accuracy= 1.00000
# Iter 283200, Minibatch Loss= 0.005989, Training Accuracy= 1.00000
# Iter 284800, Minibatch Loss= 0.005066, Training Accuracy= 1.00000
# Iter 286400, Minibatch Loss= 0.002366, Training Accuracy= 1.00000
# Iter 288000, Minibatch Loss= 0.043729, Training Accuracy= 1.00000
# Iter 289600, Minibatch Loss= 0.631998, Training Accuracy= 0.93750
# Iter 291200, Minibatch Loss= 0.130632, Training Accuracy= 1.00000
# Iter 292800, Minibatch Loss= 0.000334, Training Accuracy= 1.00000
# Iter 294400, Minibatch Loss= 0.033500, Training Accuracy= 1.00000
# Iter 296000, Minibatch Loss= 0.044330, Training Accuracy= 1.00000
# Iter 297600, Minibatch Loss= 0.042304, Training Accuracy= 1.00000
# Iter 299200, Minibatch Loss= 0.411202, Training Accuracy= 0.87500
# Iter 300800, Minibatch Loss= 0.063211, Training Accuracy= 0.93750
# Iter 302400, Minibatch Loss= 0.002436, Training Accuracy= 1.00000
# Iter 304000, Minibatch Loss= 0.037571, Training Accuracy= 1.00000
# Iter 305600, Minibatch Loss= 0.023674, Training Accuracy= 1.00000
# Iter 307200, Minibatch Loss= 0.066437, Training Accuracy= 0.93750
# Iter 308800, Minibatch Loss= 0.003724, Training Accuracy= 1.00000
# Iter 310400, Minibatch Loss= 0.018246, Training Accuracy= 1.00000
# Iter 312000, Minibatch Loss= 0.817789, Training Accuracy= 0.81250
# Iter 313600, Minibatch Loss= 0.021550, Training Accuracy= 1.00000
# Iter 315200, Minibatch Loss= 0.182468, Training Accuracy= 0.93750
# Iter 316800, Minibatch Loss= 0.419779, Training Accuracy= 0.93750
# Iter 318400, Minibatch Loss= 0.214631, Training Accuracy= 0.93750
# Iter 320000, Minibatch Loss= 0.008664, Training Accuracy= 1.00000
# Iter 321600, Minibatch Loss= 0.000881, Training Accuracy= 1.00000
# Iter 323200, Minibatch Loss= 0.028903, Training Accuracy= 1.00000
# Iter 324800, Minibatch Loss= 0.008782, Training Accuracy= 1.00000
# Iter 326400, Minibatch Loss= 0.828542, Training Accuracy= 0.87500
# Iter 328000, Minibatch Loss= 0.003725, Training Accuracy= 1.00000
# Iter 329600, Minibatch Loss= 0.117326, Training Accuracy= 0.93750
# Iter 331200, Minibatch Loss= 0.295753, Training Accuracy= 0.93750
# Iter 332800, Minibatch Loss= 0.316444, Training Accuracy= 0.93750
# Iter 334400, Minibatch Loss= 0.014575, Training Accuracy= 1.00000
# Iter 336000, Minibatch Loss= 0.004514, Training Accuracy= 1.00000
# Iter 337600, Minibatch Loss= 0.009850, Training Accuracy= 1.00000
# Iter 339200, Minibatch Loss= 0.119385, Training Accuracy= 1.00000
# Iter 340800, Minibatch Loss= 0.003912, Training Accuracy= 1.00000
# Iter 342400, Minibatch Loss= 0.129285, Training Accuracy= 0.87500
# Iter 344000, Minibatch Loss= 0.001934, Training Accuracy= 1.00000
# Iter 345600, Minibatch Loss= 0.016559, Training Accuracy= 1.00000
# Iter 347200, Minibatch Loss= 0.009115, Training Accuracy= 1.00000
# Iter 348800, Minibatch Loss= 0.173790, Training Accuracy= 0.93750
# Iter 350400, Minibatch Loss= 0.000589, Training Accuracy= 1.00000
# Iter 352000, Minibatch Loss= 0.018353, Training Accuracy= 1.00000
# Iter 353600, Minibatch Loss= 0.029732, Training Accuracy= 1.00000
# Iter 355200, Minibatch Loss= 0.139842, Training Accuracy= 0.93750
# Iter 356800, Minibatch Loss= 0.012659, Training Accuracy= 1.00000
# Iter 358400, Minibatch Loss= 0.000447, Training Accuracy= 1.00000
# Iter 360000, Minibatch Loss= 0.010544, Training Accuracy= 1.00000
# Iter 361600, Minibatch Loss= 0.017140, Training Accuracy= 1.00000
# Iter 363200, Minibatch Loss= 0.002009, Training Accuracy= 1.00000
# Iter 364800, Minibatch Loss= 0.024989, Training Accuracy= 1.00000
# Iter 366400, Minibatch Loss= 0.012549, Training Accuracy= 1.00000
# Iter 368000, Minibatch Loss= 0.067250, Training Accuracy= 0.93750
# Iter 369600, Minibatch Loss= 0.003802, Training Accuracy= 1.00000
# Iter 371200, Minibatch Loss= 0.000587, Training Accuracy= 1.00000
# Iter 372800, Minibatch Loss= 0.081071, Training Accuracy= 0.93750
# Iter 374400, Minibatch Loss= 0.014818, Training Accuracy= 1.00000
# Iter 376000, Minibatch Loss= 0.002589, Training Accuracy= 1.00000
# Iter 377600, Minibatch Loss= 0.063928, Training Accuracy= 1.00000
# Iter 379200, Minibatch Loss= 0.002023, Training Accuracy= 1.00000
# Iter 380800, Minibatch Loss= 0.000686, Training Accuracy= 1.00000
# Iter 382400, Minibatch Loss= 0.041283, Training Accuracy= 1.00000
# Iter 384000, Minibatch Loss= 0.332596, Training Accuracy= 0.93750
# Iter 385600, Minibatch Loss= 0.000508, Training Accuracy= 1.00000
# Iter 387200, Minibatch Loss= 0.039532, Training Accuracy= 1.00000
# Iter 388800, Minibatch Loss= 0.003468, Training Accuracy= 1.00000
# Iter 390400, Minibatch Loss= 0.089314, Training Accuracy= 0.93750
# Iter 392000, Minibatch Loss= 0.000807, Training Accuracy= 1.00000
# Iter 393600, Minibatch Loss= 0.345528, Training Accuracy= 0.93750
# Iter 395200, Minibatch Loss= 0.042602, Training Accuracy= 1.00000
# Iter 396800, Minibatch Loss= 0.028553, Training Accuracy= 1.00000
# Iter 398400, Minibatch Loss= 0.004490, Training Accuracy= 1.00000
# Iter 400000, Minibatch Loss= 0.000565, Training Accuracy= 1.00000
# Iter 401600, Minibatch Loss= 0.019480, Training Accuracy= 1.00000
# Iter 403200, Minibatch Loss= 0.018985, Training Accuracy= 1.00000
# Iter 404800, Minibatch Loss= 0.000418, Training Accuracy= 1.00000
# Iter 406400, Minibatch Loss= 0.000847, Training Accuracy= 1.00000
# Iter 408000, Minibatch Loss= 0.189044, Training Accuracy= 0.93750
# Iter 409600, Minibatch Loss= 0.005737, Training Accuracy= 1.00000
# Iter 411200, Minibatch Loss= 0.004788, Training Accuracy= 1.00000
# Iter 412800, Minibatch Loss= 0.009210, Training Accuracy= 1.00000
# Iter 414400, Minibatch Loss= 0.001660, Training Accuracy= 1.00000
# Iter 416000, Minibatch Loss= 0.006518, Training Accuracy= 1.00000
# Iter 417600, Minibatch Loss= 0.004245, Training Accuracy= 1.00000
# Iter 419200, Minibatch Loss= 0.066445, Training Accuracy= 1.00000
# Iter 420800, Minibatch Loss= 0.005584, Training Accuracy= 1.00000
# Iter 422400, Minibatch Loss= 0.001459, Training Accuracy= 1.00000
# Iter 424000, Minibatch Loss= 0.201469, Training Accuracy= 0.93750
# Iter 425600, Minibatch Loss= 0.005276, Training Accuracy= 1.00000
# Iter 427200, Minibatch Loss= 0.000697, Training Accuracy= 1.00000
# Iter 428800, Minibatch Loss= 0.006099, Training Accuracy= 1.00000
# Iter 430400, Minibatch Loss= 0.019881, Training Accuracy= 1.00000
# Iter 432000, Minibatch Loss= 0.008858, Training Accuracy= 1.00000
# Iter 433600, Minibatch Loss= 0.074209, Training Accuracy= 0.93750
# Iter 435200, Minibatch Loss= 0.000895, Training Accuracy= 1.00000
# Iter 436800, Minibatch Loss= 0.000590, Training Accuracy= 1.00000
# Iter 438400, Minibatch Loss= 0.001678, Training Accuracy= 1.00000
# Iter 440000, Minibatch Loss= 0.000392, Training Accuracy= 1.00000
# Iter 441600, Minibatch Loss= 0.118047, Training Accuracy= 0.93750
# Iter 443200, Minibatch Loss= 0.000285, Training Accuracy= 1.00000
# Iter 444800, Minibatch Loss= 0.001339, Training Accuracy= 1.00000
# Iter 446400, Minibatch Loss= 0.020001, Training Accuracy= 1.00000
# Iter 448000, Minibatch Loss= 0.000083, Training Accuracy= 1.00000
# Iter 449600, Minibatch Loss= 0.008765, Training Accuracy= 1.00000
# Iter 451200, Minibatch Loss= 0.001935, Training Accuracy= 1.00000
# Iter 452800, Minibatch Loss= 0.003539, Training Accuracy= 1.00000
# Iter 454400, Minibatch Loss= 0.040612, Training Accuracy= 1.00000
# Iter 456000, Minibatch Loss= 1.068400, Training Accuracy= 0.93750
# Iter 457600, Minibatch Loss= 0.007384, Training Accuracy= 1.00000
# Iter 459200, Minibatch Loss= 0.020557, Training Accuracy= 1.00000
# Iter 460800, Minibatch Loss= 0.003168, Training Accuracy= 1.00000
# Iter 462400, Minibatch Loss= 0.000307, Training Accuracy= 1.00000
# Iter 464000, Minibatch Loss= 0.004633, Training Accuracy= 1.00000
# Iter 465600, Minibatch Loss= 0.003233, Training Accuracy= 1.00000
# Iter 467200, Minibatch Loss= 0.000824, Training Accuracy= 1.00000
# Iter 468800, Minibatch Loss= 0.003749, Training Accuracy= 1.00000
# Iter 470400, Minibatch Loss= 0.001899, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.216986, Training Accuracy= 0.93750
# Iter 473600, Minibatch Loss= 0.005580, Training Accuracy= 1.00000
# Iter 475200, Minibatch Loss= 0.000231, Training Accuracy= 1.00000
# Iter 476800, Minibatch Loss= 0.005388, Training Accuracy= 1.00000
# Iter 478400, Minibatch Loss= 0.004118, Training Accuracy= 1.00000
# Iter 480000, Minibatch Loss= 0.002600, Training Accuracy= 1.00000
# Iter 481600, Minibatch Loss= 0.015561, Training Accuracy= 1.00000
# Iter 483200, Minibatch Loss= 0.003421, Training Accuracy= 1.00000
# Iter 484800, Minibatch Loss= 0.011819, Training Accuracy= 1.00000
# Iter 486400, Minibatch Loss= 0.000113, Training Accuracy= 1.00000
# Iter 488000, Minibatch Loss= 0.000024, Training Accuracy= 1.00000
# Iter 489600, Minibatch Loss= 0.003645, Training Accuracy= 1.00000
# Iter 491200, Minibatch Loss= 0.081545, Training Accuracy= 0.93750
# Iter 492800, Minibatch Loss= 0.001531, Training Accuracy= 1.00000
# Iter 494400, Minibatch Loss= 0.029609, Training Accuracy= 1.00000
# Iter 496000, Minibatch Loss= 0.003417, Training Accuracy= 1.00000
# Iter 497600, Minibatch Loss= 0.270602, Training Accuracy= 0.93750
# Iter 499200, Minibatch Loss= 0.004975, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.901254

# %%
saver.save(sess, '../Model/NIN-Model-0526')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', '1', 'd', '7', 's', '2', 'y', 'p', 'i', '9', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 'you', 't', '8', 'u', 'x', '6', 'h', 'what', 'e', '5', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
