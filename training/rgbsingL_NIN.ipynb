# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t0624.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (178716, 54)

# %%
# Parameters
learning_rate = 0.001
training_iters = 1600000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==8):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.913873, Training Accuracy= 0.06250
# Iter 3200, Minibatch Loss= 4.024475, Training Accuracy= 0.06250
# Iter 4800, Minibatch Loss= 3.893210, Training Accuracy= 0.12500
# Iter 6400, Minibatch Loss= 3.924210, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.956082, Training Accuracy= 0.00000
# Iter 9600, Minibatch Loss= 3.933439, Training Accuracy= 0.00000
# Iter 11200, Minibatch Loss= 3.929095, Training Accuracy= 0.00000
# Iter 12800, Minibatch Loss= 4.010681, Training Accuracy= 0.00000
# Iter 14400, Minibatch Loss= 3.745270, Training Accuracy= 0.06250
# Iter 16000, Minibatch Loss= 4.028928, Training Accuracy= 0.00000
# Iter 17600, Minibatch Loss= 3.877411, Training Accuracy= 0.06250
# Iter 19200, Minibatch Loss= 3.950993, Training Accuracy= 0.00000
# Iter 20800, Minibatch Loss= 3.942922, Training Accuracy= 0.06250
# Iter 22400, Minibatch Loss= 3.926951, Training Accuracy= 0.12500
# Iter 24000, Minibatch Loss= 3.899516, Training Accuracy= 0.00000
# Iter 25600, Minibatch Loss= 3.972884, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.874269, Training Accuracy= 0.00000
# Iter 28800, Minibatch Loss= 3.969990, Training Accuracy= 0.00000
# Iter 30400, Minibatch Loss= 3.943831, Training Accuracy= 0.00000
# Iter 32000, Minibatch Loss= 3.925433, Training Accuracy= 0.06250
# Iter 33600, Minibatch Loss= 3.960798, Training Accuracy= 0.06250
# Iter 35200, Minibatch Loss= 3.916184, Training Accuracy= 0.06250
# Iter 36800, Minibatch Loss= 3.856362, Training Accuracy= 0.06250
# Iter 38400, Minibatch Loss= 3.995863, Training Accuracy= 0.00000
# Iter 40000, Minibatch Loss= 3.969793, Training Accuracy= 0.00000
# Iter 41600, Minibatch Loss= 3.892056, Training Accuracy= 0.06250
# Iter 43200, Minibatch Loss= 3.969838, Training Accuracy= 0.00000
# Iter 44800, Minibatch Loss= 3.956699, Training Accuracy= 0.00000
# Iter 46400, Minibatch Loss= 3.990803, Training Accuracy= 0.06250
# Iter 48000, Minibatch Loss= 3.996047, Training Accuracy= 0.00000
# Iter 49600, Minibatch Loss= 3.990544, Training Accuracy= 0.06250
# Iter 51200, Minibatch Loss= 3.915380, Training Accuracy= 0.12500
# Iter 52800, Minibatch Loss= 3.918357, Training Accuracy= 0.06250
# Iter 54400, Minibatch Loss= 3.936532, Training Accuracy= 0.06250
# Iter 56000, Minibatch Loss= 3.869538, Training Accuracy= 0.06250
# Iter 57600, Minibatch Loss= 4.008194, Training Accuracy= 0.00000
# Iter 59200, Minibatch Loss= 3.964576, Training Accuracy= 0.00000
# Iter 60800, Minibatch Loss= 3.902382, Training Accuracy= 0.12500
# Iter 62400, Minibatch Loss= 3.895821, Training Accuracy= 0.12500
# Iter 64000, Minibatch Loss= 3.910162, Training Accuracy= 0.06250
# Iter 65600, Minibatch Loss= 3.862460, Training Accuracy= 0.06250
# Iter 67200, Minibatch Loss= 4.003531, Training Accuracy= 0.00000
# Iter 68800, Minibatch Loss= 3.953476, Training Accuracy= 0.06250
# Iter 70400, Minibatch Loss= 3.935389, Training Accuracy= 0.12500
# Iter 72000, Minibatch Loss= 3.934518, Training Accuracy= 0.06250
# Iter 73600, Minibatch Loss= 4.011935, Training Accuracy= 0.00000
# Iter 75200, Minibatch Loss= 3.991359, Training Accuracy= 0.00000
# Iter 76800, Minibatch Loss= 3.927909, Training Accuracy= 0.00000
# Iter 78400, Minibatch Loss= 3.898615, Training Accuracy= 0.06250
# Iter 80000, Minibatch Loss= 3.820631, Training Accuracy= 0.12500
# Iter 81600, Minibatch Loss= 3.977503, Training Accuracy= 0.06250
# Iter 83200, Minibatch Loss= 3.890915, Training Accuracy= 0.12500
# Iter 84800, Minibatch Loss= 3.995737, Training Accuracy= 0.00000
# Iter 86400, Minibatch Loss= 3.876014, Training Accuracy= 0.06250
# Iter 88000, Minibatch Loss= 3.815776, Training Accuracy= 0.06250
# Iter 89600, Minibatch Loss= 3.899117, Training Accuracy= 0.00000
# Iter 91200, Minibatch Loss= 3.942959, Training Accuracy= 0.00000
# Iter 92800, Minibatch Loss= 3.902977, Training Accuracy= 0.00000
# Iter 94400, Minibatch Loss= 3.871583, Training Accuracy= 0.06250
# Iter 96000, Minibatch Loss= 3.972936, Training Accuracy= 0.00000
# Iter 97600, Minibatch Loss= 3.983184, Training Accuracy= 0.00000
# Iter 99200, Minibatch Loss= 3.803351, Training Accuracy= 0.00000
# Iter 100800, Minibatch Loss= 3.870601, Training Accuracy= 0.06250
# Iter 102400, Minibatch Loss= 3.837107, Training Accuracy= 0.06250
# Iter 104000, Minibatch Loss= 3.707010, Training Accuracy= 0.00000
# Iter 105600, Minibatch Loss= 3.729223, Training Accuracy= 0.18750
# Iter 107200, Minibatch Loss= 3.744083, Training Accuracy= 0.25000
# Iter 108800, Minibatch Loss= 3.910109, Training Accuracy= 0.00000
# Iter 110400, Minibatch Loss= 3.898046, Training Accuracy= 0.00000
# Iter 112000, Minibatch Loss= 3.835456, Training Accuracy= 0.12500
# Iter 113600, Minibatch Loss= 3.751957, Training Accuracy= 0.06250
# Iter 115200, Minibatch Loss= 3.484522, Training Accuracy= 0.12500
# Iter 116800, Minibatch Loss= 3.816531, Training Accuracy= 0.06250
# Iter 118400, Minibatch Loss= 3.690622, Training Accuracy= 0.06250
# Iter 120000, Minibatch Loss= 3.774481, Training Accuracy= 0.00000
# Iter 121600, Minibatch Loss= 3.527533, Training Accuracy= 0.12500
# Iter 123200, Minibatch Loss= 3.607742, Training Accuracy= 0.12500
# Iter 124800, Minibatch Loss= 3.467700, Training Accuracy= 0.06250
# Iter 126400, Minibatch Loss= 3.544319, Training Accuracy= 0.18750
# Iter 128000, Minibatch Loss= 3.373790, Training Accuracy= 0.12500
# Iter 129600, Minibatch Loss= 3.231949, Training Accuracy= 0.12500
# Iter 131200, Minibatch Loss= 3.317709, Training Accuracy= 0.00000
# Iter 132800, Minibatch Loss= 3.825123, Training Accuracy= 0.06250
# Iter 134400, Minibatch Loss= 3.337889, Training Accuracy= 0.18750
# Iter 136000, Minibatch Loss= 3.366104, Training Accuracy= 0.00000
# Iter 137600, Minibatch Loss= 3.551906, Training Accuracy= 0.12500
# Iter 139200, Minibatch Loss= 3.270575, Training Accuracy= 0.18750
# Iter 140800, Minibatch Loss= 3.633244, Training Accuracy= 0.06250
# Iter 142400, Minibatch Loss= 3.214225, Training Accuracy= 0.00000
# Iter 144000, Minibatch Loss= 3.263469, Training Accuracy= 0.06250
# Iter 145600, Minibatch Loss= 3.328716, Training Accuracy= 0.12500
# Iter 147200, Minibatch Loss= 3.310607, Training Accuracy= 0.31250
# Iter 148800, Minibatch Loss= 3.735641, Training Accuracy= 0.00000
# Iter 150400, Minibatch Loss= 3.171296, Training Accuracy= 0.25000
# Iter 152000, Minibatch Loss= 3.260464, Training Accuracy= 0.12500
# Iter 153600, Minibatch Loss= 3.221002, Training Accuracy= 0.06250
# Iter 155200, Minibatch Loss= 3.036012, Training Accuracy= 0.18750
# Iter 156800, Minibatch Loss= 3.094452, Training Accuracy= 0.12500
# Iter 158400, Minibatch Loss= 2.960114, Training Accuracy= 0.31250
# Iter 160000, Minibatch Loss= 3.172332, Training Accuracy= 0.12500
# Iter 161600, Minibatch Loss= 3.222207, Training Accuracy= 0.00000
# Iter 163200, Minibatch Loss= 3.078486, Training Accuracy= 0.18750
# Iter 164800, Minibatch Loss= 2.941059, Training Accuracy= 0.43750
# Iter 166400, Minibatch Loss= 2.957167, Training Accuracy= 0.12500
# Iter 168000, Minibatch Loss= 2.625823, Training Accuracy= 0.31250
# Iter 169600, Minibatch Loss= 3.121009, Training Accuracy= 0.31250
# Iter 171200, Minibatch Loss= 2.924685, Training Accuracy= 0.31250
# Iter 172800, Minibatch Loss= 2.739769, Training Accuracy= 0.18750
# Iter 174400, Minibatch Loss= 3.020450, Training Accuracy= 0.31250
# Iter 176000, Minibatch Loss= 2.555966, Training Accuracy= 0.31250
# Iter 177600, Minibatch Loss= 2.825962, Training Accuracy= 0.12500
# Iter 179200, Minibatch Loss= 2.614730, Training Accuracy= 0.25000
# Iter 180800, Minibatch Loss= 2.897285, Training Accuracy= 0.25000
# Iter 182400, Minibatch Loss= 3.184594, Training Accuracy= 0.18750
# Iter 184000, Minibatch Loss= 3.368268, Training Accuracy= 0.18750
# Iter 185600, Minibatch Loss= 3.049778, Training Accuracy= 0.25000
# Iter 187200, Minibatch Loss= 2.732607, Training Accuracy= 0.31250
# Iter 188800, Minibatch Loss= 2.624127, Training Accuracy= 0.12500
# Iter 190400, Minibatch Loss= 3.053009, Training Accuracy= 0.12500
# Iter 192000, Minibatch Loss= 2.878291, Training Accuracy= 0.31250
# Iter 193600, Minibatch Loss= 2.763205, Training Accuracy= 0.18750
# Iter 195200, Minibatch Loss= 2.418612, Training Accuracy= 0.31250
# Iter 196800, Minibatch Loss= 3.005244, Training Accuracy= 0.25000
# Iter 198400, Minibatch Loss= 1.932003, Training Accuracy= 0.56250
# Iter 200000, Minibatch Loss= 2.719033, Training Accuracy= 0.12500
# Iter 201600, Minibatch Loss= 2.372387, Training Accuracy= 0.25000
# Iter 203200, Minibatch Loss= 2.602719, Training Accuracy= 0.25000
# Iter 204800, Minibatch Loss= 2.863952, Training Accuracy= 0.18750
# Iter 206400, Minibatch Loss= 2.836660, Training Accuracy= 0.12500
# Iter 208000, Minibatch Loss= 3.082554, Training Accuracy= 0.25000
# Iter 209600, Minibatch Loss= 2.834268, Training Accuracy= 0.31250
# Iter 211200, Minibatch Loss= 2.693373, Training Accuracy= 0.37500
# Iter 212800, Minibatch Loss= 2.333624, Training Accuracy= 0.25000
# Iter 214400, Minibatch Loss= 2.674603, Training Accuracy= 0.25000
# Iter 216000, Minibatch Loss= 1.838648, Training Accuracy= 0.56250
# Iter 217600, Minibatch Loss= 2.283420, Training Accuracy= 0.31250
# Iter 219200, Minibatch Loss= 3.012616, Training Accuracy= 0.12500
# Iter 220800, Minibatch Loss= 2.209307, Training Accuracy= 0.25000
# Iter 222400, Minibatch Loss= 3.321581, Training Accuracy= 0.25000
# Iter 224000, Minibatch Loss= 2.835784, Training Accuracy= 0.25000
# Iter 225600, Minibatch Loss= 2.103101, Training Accuracy= 0.50000
# Iter 227200, Minibatch Loss= 2.038000, Training Accuracy= 0.50000
# Iter 228800, Minibatch Loss= 2.777971, Training Accuracy= 0.25000
# Iter 230400, Minibatch Loss= 2.302304, Training Accuracy= 0.25000
# Iter 232000, Minibatch Loss= 2.667833, Training Accuracy= 0.18750
# Iter 233600, Minibatch Loss= 2.587262, Training Accuracy= 0.25000
# Iter 235200, Minibatch Loss= 1.995046, Training Accuracy= 0.50000
# Iter 236800, Minibatch Loss= 2.601304, Training Accuracy= 0.25000
# Iter 238400, Minibatch Loss= 1.884807, Training Accuracy= 0.50000
# Iter 240000, Minibatch Loss= 2.234089, Training Accuracy= 0.37500
# Iter 241600, Minibatch Loss= 1.750988, Training Accuracy= 0.50000
# Iter 243200, Minibatch Loss= 2.225797, Training Accuracy= 0.37500
# Iter 244800, Minibatch Loss= 1.860694, Training Accuracy= 0.31250
# Iter 246400, Minibatch Loss= 1.992888, Training Accuracy= 0.43750
# Iter 248000, Minibatch Loss= 2.238100, Training Accuracy= 0.50000
# Iter 249600, Minibatch Loss= 2.684127, Training Accuracy= 0.25000
# Iter 251200, Minibatch Loss= 2.478443, Training Accuracy= 0.18750
# Iter 252800, Minibatch Loss= 2.372938, Training Accuracy= 0.43750
# Iter 254400, Minibatch Loss= 1.950918, Training Accuracy= 0.25000
# Iter 256000, Minibatch Loss= 2.179491, Training Accuracy= 0.31250
# Iter 257600, Minibatch Loss= 2.461624, Training Accuracy= 0.37500
# Iter 259200, Minibatch Loss= 1.554005, Training Accuracy= 0.68750
# Iter 260800, Minibatch Loss= 2.356054, Training Accuracy= 0.37500
# Iter 262400, Minibatch Loss= 2.197879, Training Accuracy= 0.31250
# Iter 264000, Minibatch Loss= 1.749895, Training Accuracy= 0.56250
# Iter 265600, Minibatch Loss= 2.142032, Training Accuracy= 0.37500
# Iter 267200, Minibatch Loss= 2.209050, Training Accuracy= 0.50000
# Iter 268800, Minibatch Loss= 2.485078, Training Accuracy= 0.25000
# Iter 270400, Minibatch Loss= 2.151318, Training Accuracy= 0.25000
# Iter 272000, Minibatch Loss= 2.000557, Training Accuracy= 0.43750
# Iter 273600, Minibatch Loss= 2.190442, Training Accuracy= 0.37500
# Iter 275200, Minibatch Loss= 2.661819, Training Accuracy= 0.31250
# Iter 276800, Minibatch Loss= 2.593529, Training Accuracy= 0.25000
# Iter 278400, Minibatch Loss= 1.588062, Training Accuracy= 0.62500
# Iter 280000, Minibatch Loss= 1.979802, Training Accuracy= 0.43750
# Iter 281600, Minibatch Loss= 2.843628, Training Accuracy= 0.12500
# Iter 283200, Minibatch Loss= 2.485192, Training Accuracy= 0.31250
# Iter 284800, Minibatch Loss= 2.106754, Training Accuracy= 0.25000
# Iter 286400, Minibatch Loss= 2.279973, Training Accuracy= 0.37500
# Iter 288000, Minibatch Loss= 2.120129, Training Accuracy= 0.43750
# Iter 289600, Minibatch Loss= 1.994392, Training Accuracy= 0.43750
# Iter 291200, Minibatch Loss= 1.483729, Training Accuracy= 0.62500
# Iter 292800, Minibatch Loss= 1.228486, Training Accuracy= 0.62500
# Iter 294400, Minibatch Loss= 2.260450, Training Accuracy= 0.43750
# Iter 296000, Minibatch Loss= 1.650694, Training Accuracy= 0.50000
# Iter 297600, Minibatch Loss= 2.091596, Training Accuracy= 0.56250
# Iter 299200, Minibatch Loss= 1.918304, Training Accuracy= 0.43750
# Iter 300800, Minibatch Loss= 2.065704, Training Accuracy= 0.25000
# Iter 302400, Minibatch Loss= 1.962543, Training Accuracy= 0.50000
# Iter 304000, Minibatch Loss= 1.692508, Training Accuracy= 0.50000
# Iter 305600, Minibatch Loss= 1.917080, Training Accuracy= 0.56250
# Iter 307200, Minibatch Loss= 2.138955, Training Accuracy= 0.56250
# Iter 308800, Minibatch Loss= 2.119139, Training Accuracy= 0.31250
# Iter 310400, Minibatch Loss= 1.596090, Training Accuracy= 0.50000
# Iter 312000, Minibatch Loss= 2.080095, Training Accuracy= 0.50000
# Iter 313600, Minibatch Loss= 2.144257, Training Accuracy= 0.31250
# Iter 315200, Minibatch Loss= 1.711826, Training Accuracy= 0.56250
# Iter 316800, Minibatch Loss= 1.936485, Training Accuracy= 0.50000
# Iter 318400, Minibatch Loss= 1.771931, Training Accuracy= 0.37500
# Iter 320000, Minibatch Loss= 1.109468, Training Accuracy= 0.68750
# Iter 321600, Minibatch Loss= 1.815505, Training Accuracy= 0.68750
# Iter 323200, Minibatch Loss= 2.070740, Training Accuracy= 0.50000
# Iter 324800, Minibatch Loss= 1.849260, Training Accuracy= 0.50000
# Iter 326400, Minibatch Loss= 1.136554, Training Accuracy= 0.56250
# Iter 328000, Minibatch Loss= 2.085524, Training Accuracy= 0.43750
# Iter 329600, Minibatch Loss= 1.222500, Training Accuracy= 0.62500
# Iter 331200, Minibatch Loss= 1.326039, Training Accuracy= 0.56250
# Iter 332800, Minibatch Loss= 1.480080, Training Accuracy= 0.56250
# Iter 334400, Minibatch Loss= 1.798505, Training Accuracy= 0.43750
# Iter 336000, Minibatch Loss= 2.297519, Training Accuracy= 0.43750
# Iter 337600, Minibatch Loss= 1.469023, Training Accuracy= 0.56250
# Iter 339200, Minibatch Loss= 1.970888, Training Accuracy= 0.37500
# Iter 340800, Minibatch Loss= 1.372339, Training Accuracy= 0.50000
# Iter 342400, Minibatch Loss= 1.399626, Training Accuracy= 0.50000
# Iter 344000, Minibatch Loss= 1.234828, Training Accuracy= 0.56250
# Iter 345600, Minibatch Loss= 1.767425, Training Accuracy= 0.43750
# Iter 347200, Minibatch Loss= 1.725327, Training Accuracy= 0.50000
# Iter 348800, Minibatch Loss= 1.642029, Training Accuracy= 0.31250
# Iter 350400, Minibatch Loss= 1.828225, Training Accuracy= 0.50000
# Iter 352000, Minibatch Loss= 1.593064, Training Accuracy= 0.62500
# Iter 353600, Minibatch Loss= 1.421163, Training Accuracy= 0.75000
# Iter 355200, Minibatch Loss= 1.689894, Training Accuracy= 0.62500
# Iter 356800, Minibatch Loss= 1.362854, Training Accuracy= 0.56250
# Iter 358400, Minibatch Loss= 1.601780, Training Accuracy= 0.56250
# Iter 360000, Minibatch Loss= 1.397873, Training Accuracy= 0.56250
# Iter 361600, Minibatch Loss= 1.749797, Training Accuracy= 0.56250
# Iter 363200, Minibatch Loss= 1.229085, Training Accuracy= 0.56250
# Iter 364800, Minibatch Loss= 0.930198, Training Accuracy= 0.81250
# Iter 366400, Minibatch Loss= 0.856845, Training Accuracy= 0.75000
# Iter 368000, Minibatch Loss= 0.810481, Training Accuracy= 0.56250
# Iter 369600, Minibatch Loss= 1.622497, Training Accuracy= 0.43750
# Iter 371200, Minibatch Loss= 1.875686, Training Accuracy= 0.31250
# Iter 372800, Minibatch Loss= 2.202065, Training Accuracy= 0.62500
# Iter 374400, Minibatch Loss= 1.561510, Training Accuracy= 0.56250
# Iter 376000, Minibatch Loss= 1.517070, Training Accuracy= 0.68750
# Iter 377600, Minibatch Loss= 1.244612, Training Accuracy= 0.75000
# Iter 379200, Minibatch Loss= 1.364806, Training Accuracy= 0.68750
# Iter 380800, Minibatch Loss= 1.686849, Training Accuracy= 0.43750
# Iter 382400, Minibatch Loss= 0.974725, Training Accuracy= 0.68750
# Iter 384000, Minibatch Loss= 1.506609, Training Accuracy= 0.50000
# Iter 385600, Minibatch Loss= 1.935725, Training Accuracy= 0.62500
# Iter 387200, Minibatch Loss= 2.046026, Training Accuracy= 0.62500
# Iter 388800, Minibatch Loss= 1.399598, Training Accuracy= 0.56250
# Iter 390400, Minibatch Loss= 2.110833, Training Accuracy= 0.37500
# Iter 392000, Minibatch Loss= 1.567496, Training Accuracy= 0.43750
# Iter 393600, Minibatch Loss= 1.372535, Training Accuracy= 0.81250
# Iter 395200, Minibatch Loss= 0.624244, Training Accuracy= 0.87500
# Iter 396800, Minibatch Loss= 1.909674, Training Accuracy= 0.37500
# Iter 398400, Minibatch Loss= 1.065731, Training Accuracy= 0.56250
# Iter 400000, Minibatch Loss= 1.885425, Training Accuracy= 0.56250
# Iter 401600, Minibatch Loss= 0.896368, Training Accuracy= 0.68750
# Iter 403200, Minibatch Loss= 1.939989, Training Accuracy= 0.50000
# Iter 404800, Minibatch Loss= 0.791794, Training Accuracy= 0.81250
# Iter 406400, Minibatch Loss= 0.713570, Training Accuracy= 0.81250
# Iter 408000, Minibatch Loss= 1.054544, Training Accuracy= 0.62500
# Iter 409600, Minibatch Loss= 1.575657, Training Accuracy= 0.62500
# Iter 411200, Minibatch Loss= 1.082274, Training Accuracy= 0.62500
# Iter 412800, Minibatch Loss= 1.036059, Training Accuracy= 0.62500
# Iter 414400, Minibatch Loss= 1.549422, Training Accuracy= 0.62500
# Iter 416000, Minibatch Loss= 1.210738, Training Accuracy= 0.56250
# Iter 417600, Minibatch Loss= 1.170264, Training Accuracy= 0.50000
# Iter 419200, Minibatch Loss= 0.868836, Training Accuracy= 0.75000
# Iter 420800, Minibatch Loss= 1.032839, Training Accuracy= 0.68750
# Iter 422400, Minibatch Loss= 0.458762, Training Accuracy= 0.87500
# Iter 424000, Minibatch Loss= 1.697776, Training Accuracy= 0.43750
# Iter 425600, Minibatch Loss= 1.097724, Training Accuracy= 0.56250
# Iter 427200, Minibatch Loss= 0.826790, Training Accuracy= 0.62500
# Iter 428800, Minibatch Loss= 1.224391, Training Accuracy= 0.62500
# Iter 430400, Minibatch Loss= 2.449466, Training Accuracy= 0.43750
# Iter 432000, Minibatch Loss= 1.357268, Training Accuracy= 0.62500
# Iter 433600, Minibatch Loss= 1.841723, Training Accuracy= 0.50000
# Iter 435200, Minibatch Loss= 0.740813, Training Accuracy= 0.75000
# Iter 436800, Minibatch Loss= 0.895901, Training Accuracy= 0.62500
# Iter 438400, Minibatch Loss= 0.946847, Training Accuracy= 0.81250
# Iter 440000, Minibatch Loss= 0.867173, Training Accuracy= 0.75000
# Iter 441600, Minibatch Loss= 0.953731, Training Accuracy= 0.68750
# Iter 443200, Minibatch Loss= 1.484212, Training Accuracy= 0.56250
# Iter 444800, Minibatch Loss= 0.842797, Training Accuracy= 0.81250
# Iter 446400, Minibatch Loss= 1.180707, Training Accuracy= 0.68750
# Iter 448000, Minibatch Loss= 1.802197, Training Accuracy= 0.56250
# Iter 449600, Minibatch Loss= 0.503098, Training Accuracy= 0.81250
# Iter 451200, Minibatch Loss= 1.359321, Training Accuracy= 0.62500
# Iter 452800, Minibatch Loss= 0.828084, Training Accuracy= 0.68750
# Iter 454400, Minibatch Loss= 0.614699, Training Accuracy= 0.81250
# Iter 456000, Minibatch Loss= 1.309021, Training Accuracy= 0.68750
# Iter 457600, Minibatch Loss= 0.971654, Training Accuracy= 0.68750
# Iter 459200, Minibatch Loss= 0.918930, Training Accuracy= 0.81250
# Iter 460800, Minibatch Loss= 1.306927, Training Accuracy= 0.87500
# Iter 462400, Minibatch Loss= 0.885011, Training Accuracy= 0.75000
# Iter 464000, Minibatch Loss= 1.759296, Training Accuracy= 0.43750
# Iter 465600, Minibatch Loss= 0.862567, Training Accuracy= 0.68750
# Iter 467200, Minibatch Loss= 1.071227, Training Accuracy= 0.81250
# Iter 468800, Minibatch Loss= 0.833055, Training Accuracy= 0.68750
# Iter 470400, Minibatch Loss= 0.769413, Training Accuracy= 0.75000
# Iter 472000, Minibatch Loss= 1.102642, Training Accuracy= 0.62500
# Iter 473600, Minibatch Loss= 0.900745, Training Accuracy= 0.75000
# Iter 475200, Minibatch Loss= 1.189429, Training Accuracy= 0.62500
# Iter 476800, Minibatch Loss= 1.069210, Training Accuracy= 0.75000
# Iter 478400, Minibatch Loss= 0.287460, Training Accuracy= 0.93750
# Iter 480000, Minibatch Loss= 1.272335, Training Accuracy= 0.56250
# Iter 481600, Minibatch Loss= 0.448230, Training Accuracy= 0.93750
# Iter 483200, Minibatch Loss= 0.897262, Training Accuracy= 0.81250
# Iter 484800, Minibatch Loss= 1.207050, Training Accuracy= 0.68750
# Iter 486400, Minibatch Loss= 1.480980, Training Accuracy= 0.68750
# Iter 488000, Minibatch Loss= 1.090036, Training Accuracy= 0.68750
# Iter 489600, Minibatch Loss= 1.051404, Training Accuracy= 0.75000
# Iter 491200, Minibatch Loss= 0.709066, Training Accuracy= 0.81250
# Iter 492800, Minibatch Loss= 0.590524, Training Accuracy= 0.87500
# Iter 494400, Minibatch Loss= 1.145035, Training Accuracy= 0.50000
# Iter 496000, Minibatch Loss= 0.797505, Training Accuracy= 0.75000
# Iter 497600, Minibatch Loss= 0.662938, Training Accuracy= 0.81250
# Iter 499200, Minibatch Loss= 1.255173, Training Accuracy= 0.68750
# Iter 500800, Minibatch Loss= 1.573265, Training Accuracy= 0.56250
# Iter 502400, Minibatch Loss= 1.028897, Training Accuracy= 0.75000
# Iter 504000, Minibatch Loss= 0.860453, Training Accuracy= 0.75000
# Iter 505600, Minibatch Loss= 0.733089, Training Accuracy= 0.81250
# Iter 507200, Minibatch Loss= 0.989117, Training Accuracy= 0.75000
# Iter 508800, Minibatch Loss= 0.689620, Training Accuracy= 0.75000
# Iter 510400, Minibatch Loss= 1.075175, Training Accuracy= 0.56250
# Iter 512000, Minibatch Loss= 0.971575, Training Accuracy= 0.81250
# Iter 513600, Minibatch Loss= 1.061630, Training Accuracy= 0.56250
# Iter 515200, Minibatch Loss= 0.686201, Training Accuracy= 0.75000
# Iter 516800, Minibatch Loss= 1.033197, Training Accuracy= 0.68750
# Iter 518400, Minibatch Loss= 0.595249, Training Accuracy= 0.68750
# Iter 520000, Minibatch Loss= 0.646448, Training Accuracy= 0.75000
# Iter 521600, Minibatch Loss= 0.366676, Training Accuracy= 0.87500
# Iter 523200, Minibatch Loss= 0.571000, Training Accuracy= 0.81250
# Iter 524800, Minibatch Loss= 0.576899, Training Accuracy= 0.87500
# Iter 526400, Minibatch Loss= 0.706412, Training Accuracy= 0.81250
# Iter 528000, Minibatch Loss= 0.224334, Training Accuracy= 1.00000
# Iter 529600, Minibatch Loss= 1.265121, Training Accuracy= 0.56250
# Iter 531200, Minibatch Loss= 0.422483, Training Accuracy= 0.87500
# Iter 532800, Minibatch Loss= 0.668302, Training Accuracy= 0.87500
# Iter 534400, Minibatch Loss= 0.574210, Training Accuracy= 0.75000
# Iter 536000, Minibatch Loss= 1.026880, Training Accuracy= 0.68750
# Iter 537600, Minibatch Loss= 0.803889, Training Accuracy= 0.68750
# Iter 539200, Minibatch Loss= 0.719133, Training Accuracy= 0.68750
# Iter 540800, Minibatch Loss= 0.756262, Training Accuracy= 0.68750
# Iter 542400, Minibatch Loss= 0.570824, Training Accuracy= 0.87500
# Iter 544000, Minibatch Loss= 0.922648, Training Accuracy= 0.87500
# Iter 545600, Minibatch Loss= 0.511405, Training Accuracy= 0.81250
# Iter 547200, Minibatch Loss= 0.439821, Training Accuracy= 0.87500
# Iter 548800, Minibatch Loss= 0.547261, Training Accuracy= 0.81250
# Iter 550400, Minibatch Loss= 0.244559, Training Accuracy= 1.00000
# Iter 552000, Minibatch Loss= 0.808297, Training Accuracy= 0.87500
# Iter 553600, Minibatch Loss= 0.417235, Training Accuracy= 0.81250
# Iter 555200, Minibatch Loss= 0.942435, Training Accuracy= 0.87500
# Iter 556800, Minibatch Loss= 0.540299, Training Accuracy= 0.81250
# Iter 558400, Minibatch Loss= 0.463977, Training Accuracy= 0.87500
# Iter 560000, Minibatch Loss= 0.692416, Training Accuracy= 0.75000
# Iter 561600, Minibatch Loss= 0.620471, Training Accuracy= 0.87500
# Iter 563200, Minibatch Loss= 0.689115, Training Accuracy= 0.81250
# Iter 564800, Minibatch Loss= 1.895736, Training Accuracy= 0.56250
# Iter 566400, Minibatch Loss= 1.231154, Training Accuracy= 0.81250
# Iter 568000, Minibatch Loss= 0.755372, Training Accuracy= 0.75000
# Iter 569600, Minibatch Loss= 0.506697, Training Accuracy= 0.81250
# Iter 571200, Minibatch Loss= 0.136376, Training Accuracy= 1.00000
# Iter 572800, Minibatch Loss= 0.586730, Training Accuracy= 0.87500
# Iter 574400, Minibatch Loss= 0.308838, Training Accuracy= 1.00000
# Iter 576000, Minibatch Loss= 1.027574, Training Accuracy= 0.75000
# Iter 577600, Minibatch Loss= 0.882273, Training Accuracy= 0.68750
# Iter 579200, Minibatch Loss= 0.802205, Training Accuracy= 0.75000
# Iter 580800, Minibatch Loss= 0.797648, Training Accuracy= 0.68750
# Iter 582400, Minibatch Loss= 0.812018, Training Accuracy= 0.75000
# Iter 584000, Minibatch Loss= 0.286702, Training Accuracy= 0.87500
# Iter 585600, Minibatch Loss= 0.164020, Training Accuracy= 0.93750
# Iter 587200, Minibatch Loss= 0.650543, Training Accuracy= 0.81250
# Iter 588800, Minibatch Loss= 0.297126, Training Accuracy= 0.93750
# Iter 590400, Minibatch Loss= 0.520121, Training Accuracy= 0.81250
# Iter 592000, Minibatch Loss= 0.836465, Training Accuracy= 0.68750
# Iter 593600, Minibatch Loss= 0.881641, Training Accuracy= 0.75000
# Iter 595200, Minibatch Loss= 1.019533, Training Accuracy= 0.81250
# Iter 596800, Minibatch Loss= 0.880491, Training Accuracy= 0.81250
# Iter 598400, Minibatch Loss= 0.198714, Training Accuracy= 1.00000
# Iter 600000, Minibatch Loss= 1.343578, Training Accuracy= 0.68750
# Iter 601600, Minibatch Loss= 0.611668, Training Accuracy= 0.68750
# Iter 603200, Minibatch Loss= 0.283530, Training Accuracy= 0.87500
# Iter 604800, Minibatch Loss= 0.440021, Training Accuracy= 0.87500
# Iter 606400, Minibatch Loss= 0.382273, Training Accuracy= 0.93750
# Iter 608000, Minibatch Loss= 0.273865, Training Accuracy= 1.00000
# Iter 609600, Minibatch Loss= 0.313889, Training Accuracy= 0.93750
# Iter 611200, Minibatch Loss= 0.789833, Training Accuracy= 0.75000
# Iter 612800, Minibatch Loss= 0.482483, Training Accuracy= 0.87500
# Iter 614400, Minibatch Loss= 0.798073, Training Accuracy= 0.68750
# Iter 616000, Minibatch Loss= 0.708460, Training Accuracy= 0.68750
# Iter 617600, Minibatch Loss= 0.597439, Training Accuracy= 0.87500
# Iter 619200, Minibatch Loss= 0.868829, Training Accuracy= 0.75000
# Iter 620800, Minibatch Loss= 0.359168, Training Accuracy= 1.00000
# Iter 622400, Minibatch Loss= 0.573331, Training Accuracy= 0.87500
# Iter 624000, Minibatch Loss= 0.299406, Training Accuracy= 0.93750
# Iter 625600, Minibatch Loss= 0.682634, Training Accuracy= 0.68750
# Iter 627200, Minibatch Loss= 0.600562, Training Accuracy= 0.87500
# Iter 628800, Minibatch Loss= 0.978570, Training Accuracy= 0.81250
# Iter 630400, Minibatch Loss= 0.604883, Training Accuracy= 0.75000
# Iter 632000, Minibatch Loss= 0.872711, Training Accuracy= 0.75000
# Iter 633600, Minibatch Loss= 0.293101, Training Accuracy= 0.87500
# Iter 635200, Minibatch Loss= 0.723749, Training Accuracy= 0.75000
# Iter 636800, Minibatch Loss= 0.433520, Training Accuracy= 0.93750
# Iter 638400, Minibatch Loss= 0.954728, Training Accuracy= 0.81250
# Iter 640000, Minibatch Loss= 0.401641, Training Accuracy= 0.93750
# Iter 641600, Minibatch Loss= 0.900095, Training Accuracy= 0.56250
# Iter 643200, Minibatch Loss= 0.497175, Training Accuracy= 0.81250
# Iter 644800, Minibatch Loss= 0.435989, Training Accuracy= 0.87500
# Iter 646400, Minibatch Loss= 1.751400, Training Accuracy= 0.62500
# Iter 648000, Minibatch Loss= 0.675102, Training Accuracy= 0.81250
# Iter 649600, Minibatch Loss= 0.310724, Training Accuracy= 0.93750
# Iter 651200, Minibatch Loss= 0.329103, Training Accuracy= 0.93750
# Iter 652800, Minibatch Loss= 0.530986, Training Accuracy= 0.87500
# Iter 654400, Minibatch Loss= 0.494976, Training Accuracy= 0.81250
# Iter 656000, Minibatch Loss= 0.236900, Training Accuracy= 0.93750
# Iter 657600, Minibatch Loss= 0.239770, Training Accuracy= 0.87500
# Iter 659200, Minibatch Loss= 1.834612, Training Accuracy= 0.75000
# Iter 660800, Minibatch Loss= 0.476791, Training Accuracy= 0.75000
# Iter 662400, Minibatch Loss= 1.035097, Training Accuracy= 0.68750
# Iter 664000, Minibatch Loss= 0.727020, Training Accuracy= 0.81250
# Iter 665600, Minibatch Loss= 0.395114, Training Accuracy= 0.93750
# Iter 667200, Minibatch Loss= 0.327636, Training Accuracy= 1.00000
# Iter 668800, Minibatch Loss= 0.585428, Training Accuracy= 0.68750
# Iter 670400, Minibatch Loss= 1.235524, Training Accuracy= 0.68750
# Iter 672000, Minibatch Loss= 0.544661, Training Accuracy= 0.81250
# Iter 673600, Minibatch Loss= 0.860701, Training Accuracy= 0.75000
# Iter 675200, Minibatch Loss= 0.432915, Training Accuracy= 0.87500
# Iter 676800, Minibatch Loss= 1.008340, Training Accuracy= 0.75000
# Iter 678400, Minibatch Loss= 0.575267, Training Accuracy= 0.81250
# Iter 680000, Minibatch Loss= 0.443867, Training Accuracy= 0.81250
# Iter 681600, Minibatch Loss= 0.217145, Training Accuracy= 0.87500
# Iter 683200, Minibatch Loss= 0.283407, Training Accuracy= 0.87500
# Iter 684800, Minibatch Loss= 0.438394, Training Accuracy= 0.87500
# Iter 686400, Minibatch Loss= 0.902487, Training Accuracy= 0.75000
# Iter 688000, Minibatch Loss= 0.668853, Training Accuracy= 0.81250
# Iter 689600, Minibatch Loss= 0.713316, Training Accuracy= 0.75000
# Iter 691200, Minibatch Loss= 0.312961, Training Accuracy= 0.93750
# Iter 692800, Minibatch Loss= 0.137112, Training Accuracy= 0.93750
# Iter 694400, Minibatch Loss= 0.701760, Training Accuracy= 0.75000
# Iter 696000, Minibatch Loss= 1.490093, Training Accuracy= 0.75000
# Iter 697600, Minibatch Loss= 0.292188, Training Accuracy= 0.93750
# Iter 699200, Minibatch Loss= 0.873334, Training Accuracy= 0.75000
# Iter 700800, Minibatch Loss= 0.430543, Training Accuracy= 0.81250
# Iter 702400, Minibatch Loss= 0.198381, Training Accuracy= 0.93750
# Iter 704000, Minibatch Loss= 0.164239, Training Accuracy= 1.00000
# Iter 705600, Minibatch Loss= 0.297307, Training Accuracy= 0.93750
# Iter 707200, Minibatch Loss= 0.478806, Training Accuracy= 0.87500
# Iter 708800, Minibatch Loss= 0.309701, Training Accuracy= 0.93750
# Iter 710400, Minibatch Loss= 0.112539, Training Accuracy= 1.00000
# Iter 712000, Minibatch Loss= 0.509135, Training Accuracy= 0.87500
# Iter 713600, Minibatch Loss= 0.701045, Training Accuracy= 0.81250
# Iter 715200, Minibatch Loss= 0.496721, Training Accuracy= 0.81250
# Iter 716800, Minibatch Loss= 0.207867, Training Accuracy= 0.93750
# Iter 718400, Minibatch Loss= 0.388702, Training Accuracy= 0.93750
# Iter 720000, Minibatch Loss= 0.302989, Training Accuracy= 0.87500
# Iter 721600, Minibatch Loss= 0.481093, Training Accuracy= 0.81250
# Iter 723200, Minibatch Loss= 0.411228, Training Accuracy= 0.87500
# Iter 724800, Minibatch Loss= 0.440277, Training Accuracy= 0.81250
# Iter 726400, Minibatch Loss= 0.163268, Training Accuracy= 0.93750
# Iter 728000, Minibatch Loss= 0.339472, Training Accuracy= 0.93750
# Iter 729600, Minibatch Loss= 0.336001, Training Accuracy= 0.87500
# Iter 731200, Minibatch Loss= 0.391923, Training Accuracy= 0.81250
# Iter 732800, Minibatch Loss= 0.515378, Training Accuracy= 0.81250
# Iter 734400, Minibatch Loss= 0.348835, Training Accuracy= 0.87500
# Iter 736000, Minibatch Loss= 0.104375, Training Accuracy= 1.00000
# Iter 737600, Minibatch Loss= 0.518890, Training Accuracy= 0.87500
# Iter 739200, Minibatch Loss= 0.472473, Training Accuracy= 0.93750
# Iter 740800, Minibatch Loss= 0.715865, Training Accuracy= 0.81250
# Iter 742400, Minibatch Loss= 0.158047, Training Accuracy= 1.00000
# Iter 744000, Minibatch Loss= 0.280958, Training Accuracy= 0.93750
# Iter 745600, Minibatch Loss= 0.371201, Training Accuracy= 0.93750
# Iter 747200, Minibatch Loss= 0.489665, Training Accuracy= 0.87500
# Iter 748800, Minibatch Loss= 0.493884, Training Accuracy= 0.87500
# Iter 750400, Minibatch Loss= 0.279053, Training Accuracy= 0.87500
# Iter 752000, Minibatch Loss= 0.994596, Training Accuracy= 0.75000
# Iter 753600, Minibatch Loss= 0.147786, Training Accuracy= 0.93750
# Iter 755200, Minibatch Loss= 1.117683, Training Accuracy= 0.68750
# Iter 756800, Minibatch Loss= 0.718540, Training Accuracy= 0.62500
# Iter 758400, Minibatch Loss= 0.367975, Training Accuracy= 0.87500
# Iter 760000, Minibatch Loss= 0.424390, Training Accuracy= 0.75000
# Iter 761600, Minibatch Loss= 0.382081, Training Accuracy= 0.93750
# Iter 763200, Minibatch Loss= 0.310027, Training Accuracy= 0.93750
# Iter 764800, Minibatch Loss= 0.398243, Training Accuracy= 0.81250
# Iter 766400, Minibatch Loss= 0.693123, Training Accuracy= 0.75000
# Iter 768000, Minibatch Loss= 0.455960, Training Accuracy= 0.81250
# Iter 769600, Minibatch Loss= 1.137261, Training Accuracy= 0.87500
# Iter 771200, Minibatch Loss= 0.072328, Training Accuracy= 1.00000
# Iter 772800, Minibatch Loss= 0.591711, Training Accuracy= 0.81250
# Iter 774400, Minibatch Loss= 1.353512, Training Accuracy= 0.87500
# Iter 776000, Minibatch Loss= 0.662287, Training Accuracy= 0.75000
# Iter 777600, Minibatch Loss= 0.361773, Training Accuracy= 0.93750
# Iter 779200, Minibatch Loss= 0.397429, Training Accuracy= 0.81250
# Iter 780800, Minibatch Loss= 0.298971, Training Accuracy= 0.93750
# Iter 782400, Minibatch Loss= 0.072019, Training Accuracy= 1.00000
# Iter 784000, Minibatch Loss= 0.099184, Training Accuracy= 1.00000
# Iter 785600, Minibatch Loss= 0.361588, Training Accuracy= 0.87500
# Iter 787200, Minibatch Loss= 0.555767, Training Accuracy= 0.87500
# Iter 788800, Minibatch Loss= 0.758891, Training Accuracy= 0.62500
# Iter 790400, Minibatch Loss= 0.604557, Training Accuracy= 0.68750
# Iter 792000, Minibatch Loss= 1.084038, Training Accuracy= 0.62500
# Iter 793600, Minibatch Loss= 0.397383, Training Accuracy= 0.87500
# Iter 795200, Minibatch Loss= 0.306318, Training Accuracy= 0.87500
# Iter 796800, Minibatch Loss= 0.571328, Training Accuracy= 0.81250
# Iter 798400, Minibatch Loss= 0.396345, Training Accuracy= 0.87500
# Iter 800000, Minibatch Loss= 0.912026, Training Accuracy= 0.81250
# Iter 801600, Minibatch Loss= 0.355243, Training Accuracy= 0.87500
# Iter 803200, Minibatch Loss= 0.323923, Training Accuracy= 0.81250
# Iter 804800, Minibatch Loss= 0.366148, Training Accuracy= 0.87500
# Iter 806400, Minibatch Loss= 0.355387, Training Accuracy= 0.93750
# Iter 808000, Minibatch Loss= 0.257058, Training Accuracy= 0.93750
# Iter 809600, Minibatch Loss= 0.276864, Training Accuracy= 0.93750
# Iter 811200, Minibatch Loss= 0.228366, Training Accuracy= 0.93750
# Iter 812800, Minibatch Loss= 0.239609, Training Accuracy= 1.00000
# Iter 814400, Minibatch Loss= 0.257898, Training Accuracy= 0.93750
# Iter 816000, Minibatch Loss= 0.315923, Training Accuracy= 0.87500
# Iter 817600, Minibatch Loss= 0.249983, Training Accuracy= 0.93750
# Iter 819200, Minibatch Loss= 0.144974, Training Accuracy= 1.00000
# Iter 820800, Minibatch Loss= 0.630909, Training Accuracy= 0.93750
# Iter 822400, Minibatch Loss= 0.656319, Training Accuracy= 0.87500
# Iter 824000, Minibatch Loss= 0.531694, Training Accuracy= 0.93750
# Iter 825600, Minibatch Loss= 0.345669, Training Accuracy= 0.81250
# Iter 827200, Minibatch Loss= 0.282115, Training Accuracy= 0.87500
# Iter 828800, Minibatch Loss= 0.223112, Training Accuracy= 0.87500
# Iter 830400, Minibatch Loss= 0.120455, Training Accuracy= 0.93750
# Iter 832000, Minibatch Loss= 0.442147, Training Accuracy= 0.87500
# Iter 833600, Minibatch Loss= 0.129946, Training Accuracy= 0.93750
# Iter 835200, Minibatch Loss= 0.680180, Training Accuracy= 0.81250
# Iter 836800, Minibatch Loss= 0.305670, Training Accuracy= 0.93750
# Iter 838400, Minibatch Loss= 0.444963, Training Accuracy= 0.93750
# Iter 840000, Minibatch Loss= 1.050032, Training Accuracy= 0.81250
# Iter 841600, Minibatch Loss= 0.244797, Training Accuracy= 0.93750
# Iter 843200, Minibatch Loss= 0.624959, Training Accuracy= 0.87500
# Iter 844800, Minibatch Loss= 0.697885, Training Accuracy= 0.87500
# Iter 846400, Minibatch Loss= 0.748604, Training Accuracy= 0.81250
# Iter 848000, Minibatch Loss= 0.173162, Training Accuracy= 0.93750
# Iter 849600, Minibatch Loss= 0.571194, Training Accuracy= 0.81250
# Iter 851200, Minibatch Loss= 0.228795, Training Accuracy= 0.93750
# Iter 852800, Minibatch Loss= 0.332005, Training Accuracy= 0.87500
# Iter 854400, Minibatch Loss= 0.579859, Training Accuracy= 0.81250
# Iter 856000, Minibatch Loss= 0.211572, Training Accuracy= 0.93750
# Iter 857600, Minibatch Loss= 0.373534, Training Accuracy= 0.81250
# Iter 859200, Minibatch Loss= 0.213811, Training Accuracy= 0.93750
# Iter 860800, Minibatch Loss= 0.854060, Training Accuracy= 0.81250
# Iter 862400, Minibatch Loss= 1.030314, Training Accuracy= 0.81250
# Iter 864000, Minibatch Loss= 0.033683, Training Accuracy= 1.00000
# Iter 865600, Minibatch Loss= 0.365490, Training Accuracy= 0.93750
# Iter 867200, Minibatch Loss= 1.672169, Training Accuracy= 0.75000
# Iter 868800, Minibatch Loss= 0.584826, Training Accuracy= 0.68750
# Iter 870400, Minibatch Loss= 0.264681, Training Accuracy= 0.93750
# Iter 872000, Minibatch Loss= 0.303750, Training Accuracy= 0.81250
# Iter 873600, Minibatch Loss= 0.404124, Training Accuracy= 0.81250
# Iter 875200, Minibatch Loss= 0.459106, Training Accuracy= 0.87500
# Iter 876800, Minibatch Loss= 0.384503, Training Accuracy= 0.87500
# Iter 878400, Minibatch Loss= 0.171033, Training Accuracy= 0.93750
# Iter 880000, Minibatch Loss= 0.163196, Training Accuracy= 1.00000
# Iter 881600, Minibatch Loss= 0.387886, Training Accuracy= 0.81250
# Iter 883200, Minibatch Loss= 0.202842, Training Accuracy= 0.93750
# Iter 884800, Minibatch Loss= 0.253969, Training Accuracy= 0.93750
# Iter 886400, Minibatch Loss= 0.231138, Training Accuracy= 0.93750
# Iter 888000, Minibatch Loss= 0.520415, Training Accuracy= 0.81250
# Iter 889600, Minibatch Loss= 0.744231, Training Accuracy= 0.75000
# Iter 891200, Minibatch Loss= 0.836220, Training Accuracy= 0.87500
# Iter 892800, Minibatch Loss= 0.087354, Training Accuracy= 1.00000
# Iter 894400, Minibatch Loss= 0.278742, Training Accuracy= 0.93750
# Iter 896000, Minibatch Loss= 0.027019, Training Accuracy= 1.00000
# Iter 897600, Minibatch Loss= 0.552633, Training Accuracy= 0.75000
# Iter 899200, Minibatch Loss= 0.498982, Training Accuracy= 0.81250
# Iter 900800, Minibatch Loss= 0.239634, Training Accuracy= 0.93750
# Iter 902400, Minibatch Loss= 0.588484, Training Accuracy= 0.87500
# Iter 904000, Minibatch Loss= 0.151693, Training Accuracy= 1.00000
# Iter 905600, Minibatch Loss= 1.103604, Training Accuracy= 0.81250
# Iter 907200, Minibatch Loss= 1.020603, Training Accuracy= 0.81250
# Iter 908800, Minibatch Loss= 0.203611, Training Accuracy= 0.93750
# Iter 910400, Minibatch Loss= 0.163616, Training Accuracy= 1.00000
# Iter 912000, Minibatch Loss= 0.320338, Training Accuracy= 0.93750
# Iter 913600, Minibatch Loss= 0.306106, Training Accuracy= 0.87500
# Iter 915200, Minibatch Loss= 0.516239, Training Accuracy= 0.87500
# Iter 916800, Minibatch Loss= 0.120631, Training Accuracy= 0.93750
# Iter 918400, Minibatch Loss= 0.143852, Training Accuracy= 0.93750
# Iter 920000, Minibatch Loss= 0.811445, Training Accuracy= 0.93750
# Iter 921600, Minibatch Loss= 1.410867, Training Accuracy= 0.68750
# Iter 923200, Minibatch Loss= 0.155015, Training Accuracy= 0.93750
# Iter 924800, Minibatch Loss= 0.525929, Training Accuracy= 0.81250
# Iter 926400, Minibatch Loss= 0.084679, Training Accuracy= 1.00000
# Iter 928000, Minibatch Loss= 0.110743, Training Accuracy= 1.00000
# Iter 929600, Minibatch Loss= 0.827075, Training Accuracy= 0.87500
# Iter 931200, Minibatch Loss= 0.176333, Training Accuracy= 1.00000
# Iter 932800, Minibatch Loss= 0.245768, Training Accuracy= 0.93750
# Iter 934400, Minibatch Loss= 0.377432, Training Accuracy= 0.87500
# Iter 936000, Minibatch Loss= 0.382132, Training Accuracy= 0.87500
# Iter 937600, Minibatch Loss= 0.035411, Training Accuracy= 1.00000
# Iter 939200, Minibatch Loss= 0.418667, Training Accuracy= 0.75000
# Iter 940800, Minibatch Loss= 0.086348, Training Accuracy= 1.00000
# Iter 942400, Minibatch Loss= 0.261666, Training Accuracy= 0.87500
# Iter 944000, Minibatch Loss= 0.352719, Training Accuracy= 0.87500
# Iter 945600, Minibatch Loss= 0.523722, Training Accuracy= 0.81250
# Iter 947200, Minibatch Loss= 0.329586, Training Accuracy= 0.93750
# Iter 948800, Minibatch Loss= 0.087367, Training Accuracy= 1.00000
# Iter 950400, Minibatch Loss= 0.144784, Training Accuracy= 0.93750
# Iter 952000, Minibatch Loss= 1.060613, Training Accuracy= 0.75000
# Iter 953600, Minibatch Loss= 0.204951, Training Accuracy= 0.93750
# Iter 955200, Minibatch Loss= 0.055118, Training Accuracy= 1.00000
# Iter 956800, Minibatch Loss= 0.312815, Training Accuracy= 0.93750
# Iter 958400, Minibatch Loss= 0.165442, Training Accuracy= 1.00000
# Iter 960000, Minibatch Loss= 0.177886, Training Accuracy= 1.00000
# Iter 961600, Minibatch Loss= 0.085194, Training Accuracy= 0.93750
# Iter 963200, Minibatch Loss= 0.145949, Training Accuracy= 0.93750
# Iter 964800, Minibatch Loss= 0.090696, Training Accuracy= 1.00000
# Iter 966400, Minibatch Loss= 0.165264, Training Accuracy= 0.93750
# Iter 968000, Minibatch Loss= 0.115301, Training Accuracy= 0.93750
# Iter 969600, Minibatch Loss= 0.278521, Training Accuracy= 0.87500
# Iter 971200, Minibatch Loss= 0.153514, Training Accuracy= 0.93750
# Iter 972800, Minibatch Loss= 0.581039, Training Accuracy= 0.81250
# Iter 974400, Minibatch Loss= 0.373578, Training Accuracy= 0.87500
# Iter 976000, Minibatch Loss= 0.688999, Training Accuracy= 0.87500
# Iter 977600, Minibatch Loss= 0.145629, Training Accuracy= 1.00000
# Iter 979200, Minibatch Loss= 0.223775, Training Accuracy= 0.93750
# Iter 980800, Minibatch Loss= 0.853713, Training Accuracy= 0.81250
# Iter 982400, Minibatch Loss= 0.120240, Training Accuracy= 1.00000
# Iter 984000, Minibatch Loss= 0.311739, Training Accuracy= 0.93750
# Iter 985600, Minibatch Loss= 0.131021, Training Accuracy= 1.00000
# Iter 987200, Minibatch Loss= 0.337209, Training Accuracy= 0.87500
# Iter 988800, Minibatch Loss= 0.192966, Training Accuracy= 0.93750
# Iter 990400, Minibatch Loss= 0.270999, Training Accuracy= 0.87500
# Iter 992000, Minibatch Loss= 0.164269, Training Accuracy= 0.87500
# Iter 993600, Minibatch Loss= 0.216302, Training Accuracy= 0.87500
# Iter 995200, Minibatch Loss= 0.097015, Training Accuracy= 0.93750
# Iter 996800, Minibatch Loss= 0.081234, Training Accuracy= 1.00000
# Iter 998400, Minibatch Loss= 0.574922, Training Accuracy= 0.75000
# Iter 1000000, Minibatch Loss= 0.120939, Training Accuracy= 1.00000
# Iter 1001600, Minibatch Loss= 0.404801, Training Accuracy= 0.81250
# Iter 1003200, Minibatch Loss= 0.537193, Training Accuracy= 0.75000
# Iter 1004800, Minibatch Loss= 0.148062, Training Accuracy= 1.00000
# Iter 1006400, Minibatch Loss= 0.469329, Training Accuracy= 0.93750
# Iter 1008000, Minibatch Loss= 0.298749, Training Accuracy= 0.93750
# Iter 1009600, Minibatch Loss= 0.048716, Training Accuracy= 1.00000
# Iter 1011200, Minibatch Loss= 0.247035, Training Accuracy= 0.87500
# Iter 1012800, Minibatch Loss= 0.328825, Training Accuracy= 0.81250
# Iter 1014400, Minibatch Loss= 1.363437, Training Accuracy= 0.87500
# Iter 1016000, Minibatch Loss= 0.127111, Training Accuracy= 1.00000
# Iter 1017600, Minibatch Loss= 0.252600, Training Accuracy= 1.00000
# Iter 1019200, Minibatch Loss= 0.138903, Training Accuracy= 0.93750
# Iter 1020800, Minibatch Loss= 0.517723, Training Accuracy= 0.81250
# Iter 1022400, Minibatch Loss= 0.582563, Training Accuracy= 0.93750
# Iter 1024000, Minibatch Loss= 0.113910, Training Accuracy= 1.00000
# Iter 1025600, Minibatch Loss= 0.461252, Training Accuracy= 0.93750
# Iter 1027200, Minibatch Loss= 0.663398, Training Accuracy= 0.81250
# Iter 1028800, Minibatch Loss= 0.033237, Training Accuracy= 1.00000
# Iter 1030400, Minibatch Loss= 0.370830, Training Accuracy= 0.87500
# Iter 1032000, Minibatch Loss= 0.336019, Training Accuracy= 0.93750
# Iter 1033600, Minibatch Loss= 0.110722, Training Accuracy= 0.93750
# Iter 1035200, Minibatch Loss= 0.535871, Training Accuracy= 0.87500
# Iter 1036800, Minibatch Loss= 1.012988, Training Accuracy= 0.68750
# Iter 1038400, Minibatch Loss= 0.048742, Training Accuracy= 1.00000
# Iter 1040000, Minibatch Loss= 0.083803, Training Accuracy= 0.93750
# Iter 1041600, Minibatch Loss= 0.075439, Training Accuracy= 1.00000
# Iter 1043200, Minibatch Loss= 0.060846, Training Accuracy= 1.00000
# Iter 1044800, Minibatch Loss= 0.360135, Training Accuracy= 0.87500
# Iter 1046400, Minibatch Loss= 0.103563, Training Accuracy= 1.00000
# Iter 1048000, Minibatch Loss= 0.041360, Training Accuracy= 1.00000
# Iter 1049600, Minibatch Loss= 0.339448, Training Accuracy= 0.93750
# Iter 1051200, Minibatch Loss= 0.733271, Training Accuracy= 0.81250
# Iter 1052800, Minibatch Loss= 0.154133, Training Accuracy= 0.93750
# Iter 1054400, Minibatch Loss= 0.062393, Training Accuracy= 1.00000
# Iter 1056000, Minibatch Loss= 0.082999, Training Accuracy= 1.00000
# Iter 1057600, Minibatch Loss= 0.889097, Training Accuracy= 0.93750
# Iter 1059200, Minibatch Loss= 0.193870, Training Accuracy= 0.93750
# Iter 1060800, Minibatch Loss= 0.166907, Training Accuracy= 0.93750
# Iter 1062400, Minibatch Loss= 1.034348, Training Accuracy= 0.87500
# Iter 1064000, Minibatch Loss= 0.550080, Training Accuracy= 0.87500
# Iter 1065600, Minibatch Loss= 0.135608, Training Accuracy= 0.93750
# Iter 1067200, Minibatch Loss= 0.116372, Training Accuracy= 0.93750
# Iter 1068800, Minibatch Loss= 0.494733, Training Accuracy= 0.87500
# Iter 1070400, Minibatch Loss= 0.612097, Training Accuracy= 0.81250
# Iter 1072000, Minibatch Loss= 0.085955, Training Accuracy= 1.00000
# Iter 1073600, Minibatch Loss= 0.070956, Training Accuracy= 1.00000
# Iter 1075200, Minibatch Loss= 0.036803, Training Accuracy= 1.00000
# Iter 1076800, Minibatch Loss= 0.242236, Training Accuracy= 0.87500
# Iter 1078400, Minibatch Loss= 0.054881, Training Accuracy= 0.93750
# Iter 1080000, Minibatch Loss= 0.276795, Training Accuracy= 0.93750
# Iter 1081600, Minibatch Loss= 0.774627, Training Accuracy= 0.75000
# Iter 1083200, Minibatch Loss= 0.121858, Training Accuracy= 1.00000
# Iter 1084800, Minibatch Loss= 0.479411, Training Accuracy= 0.93750
# Iter 1086400, Minibatch Loss= 0.228066, Training Accuracy= 0.93750
# Iter 1088000, Minibatch Loss= 0.206862, Training Accuracy= 0.93750
# Iter 1089600, Minibatch Loss= 0.034830, Training Accuracy= 1.00000
# Iter 1091200, Minibatch Loss= 0.226576, Training Accuracy= 0.93750
# Iter 1092800, Minibatch Loss= 0.057006, Training Accuracy= 1.00000
# Iter 1094400, Minibatch Loss= 0.723164, Training Accuracy= 0.87500
# Iter 1096000, Minibatch Loss= 0.192764, Training Accuracy= 1.00000
# Iter 1097600, Minibatch Loss= 0.219876, Training Accuracy= 0.93750
# Iter 1099200, Minibatch Loss= 0.119015, Training Accuracy= 1.00000
# Iter 1100800, Minibatch Loss= 0.207258, Training Accuracy= 0.93750
# Iter 1102400, Minibatch Loss= 0.015342, Training Accuracy= 1.00000
# Iter 1104000, Minibatch Loss= 0.053437, Training Accuracy= 1.00000
# Iter 1105600, Minibatch Loss= 0.157248, Training Accuracy= 0.93750
# Iter 1107200, Minibatch Loss= 0.010310, Training Accuracy= 1.00000
# Iter 1108800, Minibatch Loss= 0.047219, Training Accuracy= 1.00000
# Iter 1110400, Minibatch Loss= 0.054355, Training Accuracy= 1.00000
# Iter 1112000, Minibatch Loss= 0.085033, Training Accuracy= 0.93750
# Iter 1113600, Minibatch Loss= 0.077351, Training Accuracy= 1.00000
# Iter 1115200, Minibatch Loss= 0.057956, Training Accuracy= 1.00000
# Iter 1116800, Minibatch Loss= 0.511706, Training Accuracy= 0.87500
# Iter 1118400, Minibatch Loss= 0.225377, Training Accuracy= 0.93750
# Iter 1120000, Minibatch Loss= 0.147399, Training Accuracy= 0.93750
# Iter 1121600, Minibatch Loss= 0.284631, Training Accuracy= 0.93750
# Iter 1123200, Minibatch Loss= 0.768571, Training Accuracy= 0.87500
# Iter 1124800, Minibatch Loss= 0.216328, Training Accuracy= 0.93750
# Iter 1126400, Minibatch Loss= 0.187587, Training Accuracy= 1.00000
# Iter 1128000, Minibatch Loss= 0.279795, Training Accuracy= 0.93750
# Iter 1129600, Minibatch Loss= 0.089831, Training Accuracy= 1.00000
# Iter 1131200, Minibatch Loss= 0.117787, Training Accuracy= 0.93750
# Iter 1132800, Minibatch Loss= 0.202838, Training Accuracy= 0.93750
# Iter 1134400, Minibatch Loss= 0.204351, Training Accuracy= 0.93750
# Iter 1136000, Minibatch Loss= 0.847869, Training Accuracy= 0.75000
# Iter 1137600, Minibatch Loss= 1.098122, Training Accuracy= 0.87500
# Iter 1139200, Minibatch Loss= 0.096664, Training Accuracy= 1.00000
# Iter 1140800, Minibatch Loss= 0.151056, Training Accuracy= 1.00000
# Iter 1142400, Minibatch Loss= 0.109383, Training Accuracy= 0.93750
# Iter 1144000, Minibatch Loss= 0.047710, Training Accuracy= 1.00000
# Iter 1145600, Minibatch Loss= 0.210139, Training Accuracy= 0.93750
# Iter 1147200, Minibatch Loss= 0.112926, Training Accuracy= 0.93750
# Iter 1148800, Minibatch Loss= 0.065366, Training Accuracy= 1.00000
# Iter 1150400, Minibatch Loss= 0.538324, Training Accuracy= 0.81250
# Iter 1152000, Minibatch Loss= 0.199217, Training Accuracy= 1.00000
# Iter 1153600, Minibatch Loss= 0.528655, Training Accuracy= 0.93750
# Iter 1155200, Minibatch Loss= 0.323384, Training Accuracy= 0.87500
# Iter 1156800, Minibatch Loss= 0.051167, Training Accuracy= 1.00000
# Iter 1158400, Minibatch Loss= 0.379180, Training Accuracy= 0.87500
# Iter 1160000, Minibatch Loss= 0.086173, Training Accuracy= 1.00000
# Iter 1161600, Minibatch Loss= 0.521745, Training Accuracy= 0.87500
# ...
# Iter 1219200, Minibatch Loss= 0.001273, Training Accuracy= 1.00000
# Iter 1220800, Minibatch Loss= 0.023483, Training Accuracy= 1.00000
# Iter 1222400, Minibatch Loss= 0.489424, Training Accuracy= 0.93750
# Iter 1224000, Minibatch Loss= 0.533789, Training Accuracy= 0.87500
# Iter 1225600, Minibatch Loss= 0.077619, Training Accuracy= 0.93750
# Iter 1227200, Minibatch Loss= 0.062326, Training Accuracy= 1.00000
# Iter 1228800, Minibatch Loss= 0.258048, Training Accuracy= 0.93750
# Iter 1230400, Minibatch Loss= 0.075473, Training Accuracy= 1.00000
# Iter 1232000, Minibatch Loss= 0.331989, Training Accuracy= 0.87500
# Iter 1233600, Minibatch Loss= 0.005701, Training Accuracy= 1.00000
# Iter 1235200, Minibatch Loss= 0.266815, Training Accuracy= 0.93750
# Iter 1236800, Minibatch Loss= 0.014399, Training Accuracy= 1.00000
# Iter 1238400, Minibatch Loss= 0.043012, Training Accuracy= 1.00000
# Iter 1240000, Minibatch Loss= 0.063628, Training Accuracy= 0.93750
# Iter 1241600, Minibatch Loss= 0.543339, Training Accuracy= 0.93750
# Iter 1243200, Minibatch Loss= 0.581464, Training Accuracy= 0.93750
# Iter 1244800, Minibatch Loss= 0.107433, Training Accuracy= 1.00000
# Iter 1246400, Minibatch Loss= 0.047504, Training Accuracy= 1.00000
# Iter 1248000, Minibatch Loss= 0.701566, Training Accuracy= 0.93750
# Iter 1249600, Minibatch Loss= 0.063312, Training Accuracy= 1.00000
# Iter 1251200, Minibatch Loss= 0.028329, Training Accuracy= 1.00000
# Iter 1252800, Minibatch Loss= 0.376807, Training Accuracy= 0.87500
# Iter 1254400, Minibatch Loss= 0.236962, Training Accuracy= 0.87500
# Iter 1256000, Minibatch Loss= 0.033637, Training Accuracy= 1.00000
# Iter 1257600, Minibatch Loss= 0.030006, Training Accuracy= 1.00000
# Iter 1259200, Minibatch Loss= 0.066853, Training Accuracy= 1.00000
# Iter 1260800, Minibatch Loss= 0.222045, Training Accuracy= 0.93750
# Iter 1262400, Minibatch Loss= 0.769403, Training Accuracy= 0.81250
# Iter 1264000, Minibatch Loss= 0.010217, Training Accuracy= 1.00000
# Iter 1265600, Minibatch Loss= 0.087546, Training Accuracy= 0.93750
# Iter 1267200, Minibatch Loss= 0.161008, Training Accuracy= 0.87500
# Iter 1268800, Minibatch Loss= 0.166333, Training Accuracy= 0.87500
# Iter 1270400, Minibatch Loss= 0.575416, Training Accuracy= 0.81250
# Iter 1272000, Minibatch Loss= 0.048252, Training Accuracy= 1.00000
# Iter 1273600, Minibatch Loss= 0.032847, Training Accuracy= 1.00000
# Iter 1275200, Minibatch Loss= 0.341263, Training Accuracy= 0.87500
# Iter 1276800, Minibatch Loss= 0.098583, Training Accuracy= 1.00000
# Iter 1278400, Minibatch Loss= 0.054368, Training Accuracy= 1.00000
# Iter 1280000, Minibatch Loss= 0.405809, Training Accuracy= 0.81250
# Iter 1281600, Minibatch Loss= 0.025700, Training Accuracy= 1.00000
# Iter 1283200, Minibatch Loss= 0.124014, Training Accuracy= 0.93750
# Iter 1284800, Minibatch Loss= 0.080121, Training Accuracy= 1.00000
# Iter 1286400, Minibatch Loss= 0.125143, Training Accuracy= 0.93750
# Iter 1288000, Minibatch Loss= 0.094380, Training Accuracy= 1.00000
# Iter 1289600, Minibatch Loss= 0.590727, Training Accuracy= 0.87500
# Iter 1291200, Minibatch Loss= 0.020135, Training Accuracy= 1.00000
# Iter 1292800, Minibatch Loss= 0.016145, Training Accuracy= 1.00000
# Iter 1294400, Minibatch Loss= 0.170253, Training Accuracy= 0.93750
# Iter 1296000, Minibatch Loss= 0.259583, Training Accuracy= 0.93750
# Iter 1297600, Minibatch Loss= 0.488408, Training Accuracy= 0.81250
# Iter 1299200, Minibatch Loss= 0.399037, Training Accuracy= 0.93750
# Iter 1300800, Minibatch Loss= 0.056182, Training Accuracy= 1.00000
# Iter 1302400, Minibatch Loss= 0.122480, Training Accuracy= 0.93750
# Iter 1304000, Minibatch Loss= 0.384381, Training Accuracy= 0.87500
# Iter 1305600, Minibatch Loss= 0.130566, Training Accuracy= 1.00000
# Iter 1307200, Minibatch Loss= 0.011136, Training Accuracy= 1.00000
# Iter 1308800, Minibatch Loss= 0.416412, Training Accuracy= 0.81250
# Iter 1310400, Minibatch Loss= 0.011867, Training Accuracy= 1.00000
# Iter 1312000, Minibatch Loss= 0.039998, Training Accuracy= 1.00000
# Iter 1313600, Minibatch Loss= 0.082690, Training Accuracy= 1.00000
# Iter 1315200, Minibatch Loss= 0.179100, Training Accuracy= 0.93750
# Iter 1316800, Minibatch Loss= 0.115059, Training Accuracy= 1.00000
# Iter 1318400, Minibatch Loss= 0.050551, Training Accuracy= 1.00000
# Iter 1320000, Minibatch Loss= 0.029638, Training Accuracy= 1.00000
# Iter 1321600, Minibatch Loss= 0.026381, Training Accuracy= 1.00000
# Iter 1323200, Minibatch Loss= 0.062262, Training Accuracy= 1.00000
# Iter 1324800, Minibatch Loss= 0.072568, Training Accuracy= 0.93750
# Iter 1326400, Minibatch Loss= 0.288196, Training Accuracy= 0.93750
# Iter 1328000, Minibatch Loss= 0.095452, Training Accuracy= 0.93750
# Iter 1329600, Minibatch Loss= 0.022575, Training Accuracy= 1.00000
# Iter 1331200, Minibatch Loss= 0.090243, Training Accuracy= 0.93750
# Iter 1332800, Minibatch Loss= 0.034797, Training Accuracy= 1.00000
# Iter 1334400, Minibatch Loss= 0.007952, Training Accuracy= 1.00000
# Iter 1336000, Minibatch Loss= 0.035840, Training Accuracy= 1.00000
# Iter 1337600, Minibatch Loss= 0.008255, Training Accuracy= 1.00000
# Iter 1339200, Minibatch Loss= 0.032651, Training Accuracy= 1.00000
# Iter 1340800, Minibatch Loss= 0.172507, Training Accuracy= 0.93750
# Iter 1342400, Minibatch Loss= 0.152060, Training Accuracy= 0.93750
# Iter 1344000, Minibatch Loss= 0.016281, Training Accuracy= 1.00000
# Iter 1345600, Minibatch Loss= 0.039959, Training Accuracy= 1.00000
# Iter 1347200, Minibatch Loss= 0.030676, Training Accuracy= 1.00000
# Iter 1348800, Minibatch Loss= 0.030633, Training Accuracy= 1.00000
# Iter 1350400, Minibatch Loss= 0.052579, Training Accuracy= 1.00000
# Iter 1352000, Minibatch Loss= 0.006996, Training Accuracy= 1.00000
# Iter 1353600, Minibatch Loss= 0.354527, Training Accuracy= 0.87500
# Iter 1355200, Minibatch Loss= 0.097019, Training Accuracy= 1.00000
# Iter 1356800, Minibatch Loss= 0.101959, Training Accuracy= 1.00000
# Iter 1358400, Minibatch Loss= 0.010831, Training Accuracy= 1.00000
# Iter 1360000, Minibatch Loss= 0.224873, Training Accuracy= 0.93750
# Iter 1361600, Minibatch Loss= 0.309857, Training Accuracy= 0.93750
# Iter 1363200, Minibatch Loss= 0.049574, Training Accuracy= 1.00000
# Iter 1364800, Minibatch Loss= 0.027140, Training Accuracy= 1.00000
# Iter 1366400, Minibatch Loss= 0.001349, Training Accuracy= 1.00000
# Iter 1368000, Minibatch Loss= 0.147633, Training Accuracy= 0.93750
# Iter 1369600, Minibatch Loss= 0.199711, Training Accuracy= 0.93750
# Iter 1371200, Minibatch Loss= 0.342127, Training Accuracy= 0.87500
# Iter 1372800, Minibatch Loss= 0.136320, Training Accuracy= 1.00000
# Iter 1374400, Minibatch Loss= 0.020489, Training Accuracy= 1.00000
# Iter 1376000, Minibatch Loss= 0.058243, Training Accuracy= 0.93750
# Iter 1377600, Minibatch Loss= 0.015775, Training Accuracy= 1.00000
# Iter 1379200, Minibatch Loss= 0.018437, Training Accuracy= 1.00000
# Iter 1380800, Minibatch Loss= 0.171871, Training Accuracy= 0.93750
# Iter 1382400, Minibatch Loss= 0.005741, Training Accuracy= 1.00000
# Iter 1384000, Minibatch Loss= 0.829059, Training Accuracy= 0.81250
# Iter 1385600, Minibatch Loss= 0.036116, Training Accuracy= 1.00000
# Iter 1387200, Minibatch Loss= 0.019434, Training Accuracy= 1.00000
# Iter 1388800, Minibatch Loss= 0.078078, Training Accuracy= 0.93750
# Iter 1390400, Minibatch Loss= 0.378093, Training Accuracy= 0.93750
# Iter 1392000, Minibatch Loss= 0.302055, Training Accuracy= 0.93750
# Iter 1393600, Minibatch Loss= 0.393852, Training Accuracy= 0.93750
# Iter 1395200, Minibatch Loss= 0.012741, Training Accuracy= 1.00000
# Iter 1396800, Minibatch Loss= 0.163596, Training Accuracy= 0.87500
# Iter 1398400, Minibatch Loss= 0.244112, Training Accuracy= 0.93750
# Iter 1400000, Minibatch Loss= 0.057503, Training Accuracy= 1.00000
# Iter 1401600, Minibatch Loss= 0.097139, Training Accuracy= 1.00000
# Iter 1403200, Minibatch Loss= 0.204343, Training Accuracy= 0.93750
# Iter 1404800, Minibatch Loss= 0.460056, Training Accuracy= 0.93750
# Iter 1406400, Minibatch Loss= 0.378240, Training Accuracy= 0.93750
# Iter 1408000, Minibatch Loss= 0.218608, Training Accuracy= 0.93750
# Iter 1409600, Minibatch Loss= 0.251669, Training Accuracy= 0.87500
# Iter 1411200, Minibatch Loss= 0.042498, Training Accuracy= 1.00000
# Iter 1412800, Minibatch Loss= 0.385603, Training Accuracy= 0.93750
# Iter 1414400, Minibatch Loss= 0.064845, Training Accuracy= 1.00000
# Iter 1416000, Minibatch Loss= 0.150665, Training Accuracy= 0.93750
# Iter 1417600, Minibatch Loss= 0.665388, Training Accuracy= 0.93750
# Iter 1419200, Minibatch Loss= 0.263973, Training Accuracy= 0.93750
# Iter 1420800, Minibatch Loss= 0.011254, Training Accuracy= 1.00000
# Iter 1422400, Minibatch Loss= 0.009359, Training Accuracy= 1.00000
# Iter 1424000, Minibatch Loss= 0.257466, Training Accuracy= 0.93750
# Iter 1425600, Minibatch Loss= 0.165503, Training Accuracy= 0.93750
# Iter 1427200, Minibatch Loss= 0.097130, Training Accuracy= 1.00000
# Iter 1428800, Minibatch Loss= 0.009994, Training Accuracy= 1.00000
# Iter 1430400, Minibatch Loss= 0.391902, Training Accuracy= 0.93750
# Iter 1432000, Minibatch Loss= 0.136340, Training Accuracy= 0.93750
# Iter 1433600, Minibatch Loss= 0.026731, Training Accuracy= 1.00000
# Iter 1435200, Minibatch Loss= 0.009826, Training Accuracy= 1.00000
# Iter 1436800, Minibatch Loss= 0.024553, Training Accuracy= 1.00000
# Iter 1438400, Minibatch Loss= 0.221581, Training Accuracy= 0.93750
# Iter 1440000, Minibatch Loss= 0.146821, Training Accuracy= 1.00000
# Iter 1441600, Minibatch Loss= 0.021731, Training Accuracy= 1.00000
# Iter 1443200, Minibatch Loss= 0.158882, Training Accuracy= 0.93750
# Iter 1444800, Minibatch Loss= 0.512023, Training Accuracy= 0.93750
# Iter 1446400, Minibatch Loss= 0.002714, Training Accuracy= 1.00000
# Iter 1448000, Minibatch Loss= 0.010312, Training Accuracy= 1.00000
# Iter 1449600, Minibatch Loss= 0.026990, Training Accuracy= 1.00000
# Iter 1451200, Minibatch Loss= 0.138093, Training Accuracy= 0.93750
# Iter 1452800, Minibatch Loss= 0.019783, Training Accuracy= 1.00000
# Iter 1454400, Minibatch Loss= 0.022241, Training Accuracy= 1.00000
# Iter 1456000, Minibatch Loss= 0.047282, Training Accuracy= 1.00000
# Iter 1457600, Minibatch Loss= 0.486600, Training Accuracy= 0.81250
# Iter 1459200, Minibatch Loss= 0.028798, Training Accuracy= 1.00000
# Iter 1460800, Minibatch Loss= 0.050620, Training Accuracy= 1.00000
# Iter 1462400, Minibatch Loss= 0.002931, Training Accuracy= 1.00000
# Iter 1464000, Minibatch Loss= 0.406573, Training Accuracy= 0.93750
# Iter 1465600, Minibatch Loss= 0.103891, Training Accuracy= 0.93750
# Iter 1467200, Minibatch Loss= 0.089213, Training Accuracy= 1.00000
# Iter 1468800, Minibatch Loss= 0.422592, Training Accuracy= 0.87500
# Iter 1470400, Minibatch Loss= 0.229454, Training Accuracy= 1.00000
# Iter 1472000, Minibatch Loss= 0.010283, Training Accuracy= 1.00000
# Iter 1473600, Minibatch Loss= 0.062692, Training Accuracy= 1.00000
# Iter 1475200, Minibatch Loss= 0.048208, Training Accuracy= 1.00000
# Iter 1476800, Minibatch Loss= 0.089260, Training Accuracy= 1.00000
# Iter 1478400, Minibatch Loss= 0.003447, Training Accuracy= 1.00000
# Iter 1480000, Minibatch Loss= 0.406994, Training Accuracy= 0.93750
# Iter 1481600, Minibatch Loss= 0.384279, Training Accuracy= 0.87500
# Iter 1483200, Minibatch Loss= 0.013997, Training Accuracy= 1.00000
# Iter 1484800, Minibatch Loss= 0.171541, Training Accuracy= 0.93750
# Iter 1486400, Minibatch Loss= 0.257315, Training Accuracy= 0.93750
# Iter 1488000, Minibatch Loss= 0.195912, Training Accuracy= 0.87500
# Iter 1489600, Minibatch Loss= 0.069466, Training Accuracy= 1.00000
# Iter 1491200, Minibatch Loss= 0.051008, Training Accuracy= 1.00000
# Iter 1492800, Minibatch Loss= 0.460158, Training Accuracy= 0.87500
# Iter 1494400, Minibatch Loss= 0.005346, Training Accuracy= 1.00000
# Iter 1496000, Minibatch Loss= 0.021326, Training Accuracy= 1.00000
# Iter 1497600, Minibatch Loss= 0.078061, Training Accuracy= 0.93750
# Iter 1499200, Minibatch Loss= 0.177870, Training Accuracy= 0.93750
# Iter 1500800, Minibatch Loss= 0.058928, Training Accuracy= 1.00000
# Iter 1502400, Minibatch Loss= 0.142195, Training Accuracy= 1.00000
# Iter 1504000, Minibatch Loss= 0.010719, Training Accuracy= 1.00000
# Iter 1505600, Minibatch Loss= 0.051176, Training Accuracy= 1.00000
# Iter 1507200, Minibatch Loss= 0.526045, Training Accuracy= 0.93750
# Iter 1508800, Minibatch Loss= 0.405478, Training Accuracy= 0.87500
# Iter 1510400, Minibatch Loss= 0.146082, Training Accuracy= 1.00000
# Iter 1512000, Minibatch Loss= 0.049668, Training Accuracy= 1.00000
# Iter 1513600, Minibatch Loss= 0.047288, Training Accuracy= 1.00000
# Iter 1515200, Minibatch Loss= 0.211338, Training Accuracy= 0.93750
# Iter 1516800, Minibatch Loss= 0.025926, Training Accuracy= 1.00000
# Iter 1518400, Minibatch Loss= 0.006829, Training Accuracy= 1.00000
# Iter 1520000, Minibatch Loss= 0.145145, Training Accuracy= 0.93750
# Iter 1521600, Minibatch Loss= 0.270878, Training Accuracy= 0.93750
# Iter 1523200, Minibatch Loss= 0.018212, Training Accuracy= 1.00000
# Iter 1524800, Minibatch Loss= 0.008056, Training Accuracy= 1.00000
# Iter 1526400, Minibatch Loss= 0.310114, Training Accuracy= 0.93750
# Iter 1528000, Minibatch Loss= 0.203898, Training Accuracy= 0.93750
# Iter 1529600, Minibatch Loss= 0.445785, Training Accuracy= 0.93750
# Iter 1531200, Minibatch Loss= 0.107210, Training Accuracy= 1.00000
# Iter 1532800, Minibatch Loss= 0.111049, Training Accuracy= 0.93750
# Iter 1534400, Minibatch Loss= 0.471846, Training Accuracy= 0.93750
# Iter 1536000, Minibatch Loss= 0.245752, Training Accuracy= 0.93750
# Iter 1537600, Minibatch Loss= 0.352961, Training Accuracy= 0.93750
# Iter 1539200, Minibatch Loss= 0.032953, Training Accuracy= 1.00000
# Iter 1540800, Minibatch Loss= 0.576907, Training Accuracy= 0.87500
# Iter 1542400, Minibatch Loss= 0.022585, Training Accuracy= 1.00000
# Iter 1544000, Minibatch Loss= 0.192628, Training Accuracy= 0.93750
# Iter 1545600, Minibatch Loss= 0.038134, Training Accuracy= 1.00000
# Iter 1547200, Minibatch Loss= 0.088028, Training Accuracy= 1.00000
# Iter 1548800, Minibatch Loss= 0.007096, Training Accuracy= 1.00000
# Iter 1550400, Minibatch Loss= 0.463343, Training Accuracy= 0.93750
# Iter 1552000, Minibatch Loss= 0.835661, Training Accuracy= 0.87500
# Iter 1553600, Minibatch Loss= 0.021991, Training Accuracy= 1.00000
# Iter 1555200, Minibatch Loss= 0.080390, Training Accuracy= 1.00000
# Iter 1556800, Minibatch Loss= 0.005021, Training Accuracy= 1.00000
# Iter 1558400, Minibatch Loss= 0.127653, Training Accuracy= 0.93750
# Iter 1560000, Minibatch Loss= 0.002286, Training Accuracy= 1.00000
# Iter 1561600, Minibatch Loss= 0.072148, Training Accuracy= 1.00000
# Iter 1563200, Minibatch Loss= 0.324746, Training Accuracy= 0.93750
# Iter 1564800, Minibatch Loss= 0.090326, Training Accuracy= 1.00000
# Iter 1566400, Minibatch Loss= 0.026467, Training Accuracy= 1.00000
# Iter 1568000, Minibatch Loss= 0.010652, Training Accuracy= 1.00000
# Iter 1569600, Minibatch Loss= 0.028973, Training Accuracy= 1.00000
# Iter 1571200, Minibatch Loss= 0.180559, Training Accuracy= 0.93750
# Iter 1572800, Minibatch Loss= 0.022968, Training Accuracy= 1.00000
# Iter 1574400, Minibatch Loss= 0.022726, Training Accuracy= 1.00000
# Iter 1576000, Minibatch Loss= 0.829443, Training Accuracy= 0.87500
# Iter 1577600, Minibatch Loss= 0.039805, Training Accuracy= 1.00000
# Iter 1579200, Minibatch Loss= 0.221795, Training Accuracy= 0.87500
# Iter 1580800, Minibatch Loss= 0.079933, Training Accuracy= 1.00000
# Iter 1582400, Minibatch Loss= 0.032906, Training Accuracy= 1.00000
# Iter 1584000, Minibatch Loss= 0.075046, Training Accuracy= 1.00000
# Iter 1585600, Minibatch Loss= 0.002564, Training Accuracy= 1.00000
# Iter 1587200, Minibatch Loss= 0.562759, Training Accuracy= 0.93750
# Iter 1588800, Minibatch Loss= 0.012700, Training Accuracy= 1.00000
# Iter 1590400, Minibatch Loss= 0.017345, Training Accuracy= 1.00000
# Iter 1592000, Minibatch Loss= 0.001371, Training Accuracy= 1.00000
# Iter 1593600, Minibatch Loss= 0.045943, Training Accuracy= 1.00000
# Iter 1595200, Minibatch Loss= 0.110657, Training Accuracy= 0.93750
# Iter 1596800, Minibatch Loss= 0.520737, Training Accuracy= 0.93750
# Iter 1598400, Minibatch Loss= 0.070143, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.849945

# %%
saver.save(sess, '../Model/NIN-Model-0624')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', 'hungry', 'want1', '1', 'd', '7', 's', '2', 'y', 'p', 'me', 'likeb2', 'i', '9', 'q', 'why2', 'nob1', 'sorry1', 'thanku1', 'want2', 'w', 'n', 'c', '3', 'g', 'v', 'time1', 'a', 'come', 'you', 'howd2', 'help_h2', 'unders1', 't', 'nob2', '8', 'u', 'x', '6', 'h', 'e', '5', 'o', '4', 'f', 'non', 'unders2', 'm', 'b', 'likeb1', 'r', 'l', 'howd1', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
