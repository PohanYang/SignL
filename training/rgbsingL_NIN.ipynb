# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
import datetime
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t0630.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (181645, 53)

# %%
# Parameters
learning_rate = 0.001
training_iters = 1600000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
now1 = datetime.datetime.now()
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        now2 = datetime.datetime.now()
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc) + ", Time= " + str(now2-now1)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==8):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.983764, Training Accuracy= 0.06250, Time= 0:00:01.972817
# Iter 3200, Minibatch Loss= 4.002318, Training Accuracy= 0.00000, Time= 0:00:02.864898
# Iter 4800, Minibatch Loss= 4.003904, Training Accuracy= 0.00000, Time= 0:00:03.750687
# Iter 6400, Minibatch Loss= 3.974510, Training Accuracy= 0.06250, Time= 0:00:04.640956
# Iter 8000, Minibatch Loss= 4.042873, Training Accuracy= 0.00000, Time= 0:00:05.529556
# Iter 9600, Minibatch Loss= 3.964223, Training Accuracy= 0.00000, Time= 0:00:06.416935
# Iter 11200, Minibatch Loss= 3.965842, Training Accuracy= 0.00000, Time= 0:00:07.304701
# Iter 12800, Minibatch Loss= 3.962353, Training Accuracy= 0.00000, Time= 0:00:08.193102
# Iter 14400, Minibatch Loss= 3.995130, Training Accuracy= 0.06250, Time= 0:00:09.080130
# Iter 16000, Minibatch Loss= 4.007793, Training Accuracy= 0.00000, Time= 0:00:09.969170
# Iter 17600, Minibatch Loss= 3.963549, Training Accuracy= 0.06250, Time= 0:00:10.857626
# Iter 19200, Minibatch Loss= 3.905847, Training Accuracy= 0.12500, Time= 0:00:11.746320
# Iter 20800, Minibatch Loss= 3.946120, Training Accuracy= 0.06250, Time= 0:00:12.634221
# Iter 22400, Minibatch Loss= 3.919645, Training Accuracy= 0.12500, Time= 0:00:13.522910
# Iter 24000, Minibatch Loss= 3.966303, Training Accuracy= 0.00000, Time= 0:00:14.412680
# Iter 25600, Minibatch Loss= 3.951087, Training Accuracy= 0.00000, Time= 0:00:15.300780
# Iter 27200, Minibatch Loss= 3.911198, Training Accuracy= 0.06250, Time= 0:00:16.186918
# Iter 28800, Minibatch Loss= 3.867486, Training Accuracy= 0.06250, Time= 0:00:17.076402
# Iter 30400, Minibatch Loss= 3.917749, Training Accuracy= 0.06250, Time= 0:00:17.963962
# Iter 32000, Minibatch Loss= 3.837404, Training Accuracy= 0.12500, Time= 0:00:18.854015
# Iter 33600, Minibatch Loss= 3.852879, Training Accuracy= 0.06250, Time= 0:00:19.743971
# Iter 35200, Minibatch Loss= 3.907599, Training Accuracy= 0.25000, Time= 0:00:20.632861
# Iter 36800, Minibatch Loss= 4.015760, Training Accuracy= 0.00000, Time= 0:00:21.523039
# Iter 38400, Minibatch Loss= 3.919493, Training Accuracy= 0.00000, Time= 0:00:22.412991
# Iter 40000, Minibatch Loss= 3.982531, Training Accuracy= 0.00000, Time= 0:00:23.300789
# Iter 41600, Minibatch Loss= 3.959621, Training Accuracy= 0.06250, Time= 0:00:24.191302
# Iter 43200, Minibatch Loss= 3.969499, Training Accuracy= 0.00000, Time= 0:00:25.080649
# Iter 44800, Minibatch Loss= 3.937507, Training Accuracy= 0.00000, Time= 0:00:25.970726
# Iter 46400, Minibatch Loss= 3.987431, Training Accuracy= 0.06250, Time= 0:00:26.860808
# Iter 48000, Minibatch Loss= 3.927761, Training Accuracy= 0.00000, Time= 0:00:27.751096
# Iter 49600, Minibatch Loss= 3.937581, Training Accuracy= 0.12500, Time= 0:00:28.640052
# Iter 51200, Minibatch Loss= 3.879110, Training Accuracy= 0.06250, Time= 0:00:29.530949
# Iter 52800, Minibatch Loss= 3.818387, Training Accuracy= 0.06250, Time= 0:00:30.420449
# Iter 54400, Minibatch Loss= 3.902953, Training Accuracy= 0.06250, Time= 0:00:31.311149
# Iter 56000, Minibatch Loss= 3.980355, Training Accuracy= 0.06250, Time= 0:00:32.201316
# Iter 57600, Minibatch Loss= 3.958240, Training Accuracy= 0.00000, Time= 0:00:33.090194
# Iter 59200, Minibatch Loss= 3.928910, Training Accuracy= 0.00000, Time= 0:00:33.979918
# Iter 60800, Minibatch Loss= 3.865578, Training Accuracy= 0.12500, Time= 0:00:34.870789
# Iter 62400, Minibatch Loss= 3.922305, Training Accuracy= 0.06250, Time= 0:00:35.763402
# Iter 64000, Minibatch Loss= 3.893544, Training Accuracy= 0.00000, Time= 0:00:36.650945
# Iter 65600, Minibatch Loss= 3.950740, Training Accuracy= 0.06250, Time= 0:00:37.541548
# Iter 67200, Minibatch Loss= 3.943625, Training Accuracy= 0.00000, Time= 0:00:38.430393
# Iter 68800, Minibatch Loss= 3.930939, Training Accuracy= 0.00000, Time= 0:00:39.317109
# Iter 70400, Minibatch Loss= 3.943856, Training Accuracy= 0.00000, Time= 0:00:40.209057
# Iter 72000, Minibatch Loss= 3.949453, Training Accuracy= 0.00000, Time= 0:00:41.099452
# Iter 73600, Minibatch Loss= 3.941973, Training Accuracy= 0.00000, Time= 0:00:41.991312
# Iter 75200, Minibatch Loss= 3.877031, Training Accuracy= 0.06250, Time= 0:00:42.883590
# Iter 76800, Minibatch Loss= 3.813423, Training Accuracy= 0.06250, Time= 0:00:43.774351
# Iter 78400, Minibatch Loss= 3.793055, Training Accuracy= 0.06250, Time= 0:00:44.663173
# Iter 80000, Minibatch Loss= 3.973721, Training Accuracy= 0.06250, Time= 0:00:45.552566
# Iter 81600, Minibatch Loss= 3.907897, Training Accuracy= 0.00000, Time= 0:00:46.442128
# Iter 83200, Minibatch Loss= 3.890430, Training Accuracy= 0.00000, Time= 0:00:47.331061
# Iter 84800, Minibatch Loss= 3.908396, Training Accuracy= 0.00000, Time= 0:00:48.223983
# Iter 86400, Minibatch Loss= 3.883878, Training Accuracy= 0.06250, Time= 0:00:49.113139
# Iter 88000, Minibatch Loss= 3.854927, Training Accuracy= 0.12500, Time= 0:00:50.003560
# Iter 89600, Minibatch Loss= 3.789072, Training Accuracy= 0.06250, Time= 0:00:50.893493
# Iter 91200, Minibatch Loss= 3.853406, Training Accuracy= 0.00000, Time= 0:00:51.782793
# Iter 92800, Minibatch Loss= 3.788418, Training Accuracy= 0.12500, Time= 0:00:52.674165
# Iter 94400, Minibatch Loss= 3.802903, Training Accuracy= 0.00000, Time= 0:00:53.563287
# Iter 96000, Minibatch Loss= 3.815876, Training Accuracy= 0.06250, Time= 0:00:54.452801
# Iter 97600, Minibatch Loss= 3.780359, Training Accuracy= 0.00000, Time= 0:00:55.342295
# Iter 99200, Minibatch Loss= 3.891663, Training Accuracy= 0.12500, Time= 0:00:56.231286
# Iter 100800, Minibatch Loss= 3.809750, Training Accuracy= 0.06250, Time= 0:00:57.121870
# Iter 102400, Minibatch Loss= 3.805854, Training Accuracy= 0.00000, Time= 0:00:58.011538
# Iter 104000, Minibatch Loss= 3.649222, Training Accuracy= 0.06250, Time= 0:00:58.903115
# Iter 105600, Minibatch Loss= 3.804050, Training Accuracy= 0.00000, Time= 0:00:59.793847
# Iter 107200, Minibatch Loss= 3.802334, Training Accuracy= 0.12500, Time= 0:01:00.684323
# Iter 108800, Minibatch Loss= 3.713015, Training Accuracy= 0.06250, Time= 0:01:01.574219
# Iter 110400, Minibatch Loss= 3.721964, Training Accuracy= 0.25000, Time= 0:01:02.466686
# Iter 112000, Minibatch Loss= 3.711061, Training Accuracy= 0.00000, Time= 0:01:03.356634
# Iter 113600, Minibatch Loss= 3.596516, Training Accuracy= 0.12500, Time= 0:01:04.247929
# Iter 115200, Minibatch Loss= 3.654646, Training Accuracy= 0.06250, Time= 0:01:05.137770
# Iter 116800, Minibatch Loss= 3.502589, Training Accuracy= 0.12500, Time= 0:01:06.025599
# Iter 118400, Minibatch Loss= 3.661362, Training Accuracy= 0.18750, Time= 0:01:06.913657
# Iter 120000, Minibatch Loss= 3.441932, Training Accuracy= 0.06250, Time= 0:01:07.804957
# Iter 121600, Minibatch Loss= 3.524719, Training Accuracy= 0.12500, Time= 0:01:08.697175
# Iter 123200, Minibatch Loss= 3.114525, Training Accuracy= 0.43750, Time= 0:01:09.588998
# Iter 124800, Minibatch Loss= 3.683505, Training Accuracy= 0.00000, Time= 0:01:10.479713
# Iter 126400, Minibatch Loss= 3.416564, Training Accuracy= 0.06250, Time= 0:01:11.370126
# Iter 128000, Minibatch Loss= 3.442278, Training Accuracy= 0.00000, Time= 0:01:12.260225
# Iter 129600, Minibatch Loss= 3.525204, Training Accuracy= 0.06250, Time= 0:01:13.156123
# Iter 131200, Minibatch Loss= 3.079111, Training Accuracy= 0.18750, Time= 0:01:14.048378
# Iter 132800, Minibatch Loss= 3.247249, Training Accuracy= 0.06250, Time= 0:01:14.939620
# Iter 134400, Minibatch Loss= 3.433932, Training Accuracy= 0.06250, Time= 0:01:15.830509
# Iter 136000, Minibatch Loss= 3.561113, Training Accuracy= 0.18750, Time= 0:01:16.724718
# Iter 137600, Minibatch Loss= 3.427670, Training Accuracy= 0.12500, Time= 0:01:17.616741
# Iter 139200, Minibatch Loss= 3.245586, Training Accuracy= 0.12500, Time= 0:01:18.508524
# Iter 140800, Minibatch Loss= 3.389510, Training Accuracy= 0.12500, Time= 0:01:19.401636
# Iter 142400, Minibatch Loss= 3.016663, Training Accuracy= 0.25000, Time= 0:01:20.296036
# Iter 144000, Minibatch Loss= 3.694057, Training Accuracy= 0.12500, Time= 0:01:21.188954
# Iter 145600, Minibatch Loss= 3.336045, Training Accuracy= 0.06250, Time= 0:01:22.081600
# Iter 147200, Minibatch Loss= 3.404285, Training Accuracy= 0.18750, Time= 0:01:22.975184
# Iter 148800, Minibatch Loss= 3.663595, Training Accuracy= 0.06250, Time= 0:01:23.868859
# Iter 150400, Minibatch Loss= 3.012269, Training Accuracy= 0.12500, Time= 0:01:24.761226
# Iter 152000, Minibatch Loss= 3.106601, Training Accuracy= 0.18750, Time= 0:01:25.653956
# Iter 153600, Minibatch Loss= 3.186471, Training Accuracy= 0.18750, Time= 0:01:26.549544
# Iter 155200, Minibatch Loss= 3.354375, Training Accuracy= 0.18750, Time= 0:01:27.442280
# Iter 156800, Minibatch Loss= 3.525741, Training Accuracy= 0.18750, Time= 0:01:28.336269
# Iter 158400, Minibatch Loss= 3.175821, Training Accuracy= 0.18750, Time= 0:01:29.228339
# Iter 160000, Minibatch Loss= 2.963822, Training Accuracy= 0.37500, Time= 0:01:30.122828
# Iter 161600, Minibatch Loss= 3.164771, Training Accuracy= 0.12500, Time= 0:01:31.014729
# Iter 163200, Minibatch Loss= 3.380993, Training Accuracy= 0.12500, Time= 0:01:31.908760
# Iter 164800, Minibatch Loss= 3.111305, Training Accuracy= 0.18750, Time= 0:01:32.800933
# Iter 166400, Minibatch Loss= 3.321703, Training Accuracy= 0.18750, Time= 0:01:33.694187
# Iter 168000, Minibatch Loss= 2.192052, Training Accuracy= 0.43750, Time= 0:01:34.588408
# Iter 169600, Minibatch Loss= 2.670760, Training Accuracy= 0.06250, Time= 0:01:35.480007
# Iter 171200, Minibatch Loss= 3.045800, Training Accuracy= 0.18750, Time= 0:01:36.373442
# Iter 172800, Minibatch Loss= 3.338229, Training Accuracy= 0.12500, Time= 0:01:37.265643
# Iter 174400, Minibatch Loss= 2.895401, Training Accuracy= 0.18750, Time= 0:01:38.160695
# Iter 176000, Minibatch Loss= 3.028098, Training Accuracy= 0.25000, Time= 0:01:39.052692
# Iter 177600, Minibatch Loss= 2.966521, Training Accuracy= 0.25000, Time= 0:01:39.945410
# Iter 179200, Minibatch Loss= 3.011662, Training Accuracy= 0.18750, Time= 0:01:40.848980
# Iter 180800, Minibatch Loss= 3.247377, Training Accuracy= 0.12500, Time= 0:01:41.745430
# Iter 182400, Minibatch Loss= 2.320566, Training Accuracy= 0.31250, Time= 0:01:42.638163
# Iter 184000, Minibatch Loss= 2.215338, Training Accuracy= 0.37500, Time= 0:01:43.538756
# Iter 185600, Minibatch Loss= 2.970063, Training Accuracy= 0.12500, Time= 0:01:44.431015
# Iter 187200, Minibatch Loss= 2.572791, Training Accuracy= 0.31250, Time= 0:01:45.325740
# Iter 188800, Minibatch Loss= 2.555840, Training Accuracy= 0.31250, Time= 0:01:46.218344
# Iter 190400, Minibatch Loss= 2.217427, Training Accuracy= 0.37500, Time= 0:01:47.109915
# Iter 192000, Minibatch Loss= 2.423605, Training Accuracy= 0.25000, Time= 0:01:48.001472
# Iter 193600, Minibatch Loss= 3.010947, Training Accuracy= 0.31250, Time= 0:01:48.893631
# Iter 195200, Minibatch Loss= 2.888128, Training Accuracy= 0.18750, Time= 0:01:49.783558
# Iter 196800, Minibatch Loss= 2.511554, Training Accuracy= 0.31250, Time= 0:01:50.675685
# Iter 198400, Minibatch Loss= 2.456928, Training Accuracy= 0.31250, Time= 0:01:51.567953
# Iter 200000, Minibatch Loss= 2.480575, Training Accuracy= 0.25000, Time= 0:01:52.461700
# Iter 201600, Minibatch Loss= 2.228438, Training Accuracy= 0.50000, Time= 0:01:53.354576
# Iter 203200, Minibatch Loss= 2.141204, Training Accuracy= 0.62500, Time= 0:01:54.246136
# Iter 204800, Minibatch Loss= 2.363198, Training Accuracy= 0.25000, Time= 0:01:55.138271
# Iter 206400, Minibatch Loss= 2.466774, Training Accuracy= 0.31250, Time= 0:01:56.031743
# Iter 208000, Minibatch Loss= 2.708029, Training Accuracy= 0.31250, Time= 0:01:56.925621
# Iter 209600, Minibatch Loss= 2.712389, Training Accuracy= 0.18750, Time= 0:01:57.818935
# Iter 211200, Minibatch Loss= 2.551749, Training Accuracy= 0.25000, Time= 0:01:58.712161
# Iter 212800, Minibatch Loss= 2.582253, Training Accuracy= 0.18750, Time= 0:01:59.605325
# Iter 214400, Minibatch Loss= 2.477487, Training Accuracy= 0.18750, Time= 0:02:00.498226
# Iter 216000, Minibatch Loss= 2.496379, Training Accuracy= 0.25000, Time= 0:02:01.391417
# Iter 217600, Minibatch Loss= 2.227993, Training Accuracy= 0.43750, Time= 0:02:02.289641
# Iter 219200, Minibatch Loss= 2.346359, Training Accuracy= 0.25000, Time= 0:02:03.182884
# Iter 220800, Minibatch Loss= 2.122072, Training Accuracy= 0.50000, Time= 0:02:04.075880
# Iter 222400, Minibatch Loss= 2.216358, Training Accuracy= 0.25000, Time= 0:02:04.966664
# Iter 224000, Minibatch Loss= 3.018256, Training Accuracy= 0.12500, Time= 0:02:05.861537
# Iter 225600, Minibatch Loss= 2.875476, Training Accuracy= 0.31250, Time= 0:02:06.754564
# Iter 227200, Minibatch Loss= 2.746552, Training Accuracy= 0.12500, Time= 0:02:07.648946
# Iter 228800, Minibatch Loss= 2.400978, Training Accuracy= 0.31250, Time= 0:02:08.541665
# Iter 230400, Minibatch Loss= 2.147215, Training Accuracy= 0.37500, Time= 0:02:09.436280
# Iter 232000, Minibatch Loss= 2.367674, Training Accuracy= 0.18750, Time= 0:02:10.329737
# Iter 233600, Minibatch Loss= 1.841897, Training Accuracy= 0.50000, Time= 0:02:11.224033
# Iter 235200, Minibatch Loss= 1.759114, Training Accuracy= 0.56250, Time= 0:02:12.119377
# Iter 236800, Minibatch Loss= 2.799910, Training Accuracy= 0.06250, Time= 0:02:13.014685
# Iter 238400, Minibatch Loss= 2.633646, Training Accuracy= 0.31250, Time= 0:02:13.907442
# Iter 240000, Minibatch Loss= 2.350661, Training Accuracy= 0.50000, Time= 0:02:14.800347
# Iter 241600, Minibatch Loss= 2.491668, Training Accuracy= 0.18750, Time= 0:02:15.692769
# Iter 243200, Minibatch Loss= 2.548183, Training Accuracy= 0.25000, Time= 0:02:16.587739
# Iter 244800, Minibatch Loss= 2.324175, Training Accuracy= 0.31250, Time= 0:02:17.481350
# Iter 246400, Minibatch Loss= 2.440377, Training Accuracy= 0.31250, Time= 0:02:18.378433
# Iter 248000, Minibatch Loss= 1.865368, Training Accuracy= 0.50000, Time= 0:02:19.271225
# Iter 249600, Minibatch Loss= 2.240180, Training Accuracy= 0.50000, Time= 0:02:20.164336
# Iter 251200, Minibatch Loss= 2.143918, Training Accuracy= 0.18750, Time= 0:02:21.058191
# Iter 252800, Minibatch Loss= 2.230819, Training Accuracy= 0.50000, Time= 0:02:21.949935
# Iter 254400, Minibatch Loss= 1.635528, Training Accuracy= 0.37500, Time= 0:02:22.840797
# Iter 256000, Minibatch Loss= 1.694787, Training Accuracy= 0.62500, Time= 0:02:23.736365
# Iter 257600, Minibatch Loss= 1.821320, Training Accuracy= 0.56250, Time= 0:02:24.629115
# Iter 259200, Minibatch Loss= 1.731330, Training Accuracy= 0.56250, Time= 0:02:25.523687
# Iter 260800, Minibatch Loss= 1.919902, Training Accuracy= 0.37500, Time= 0:02:26.416921
# Iter 262400, Minibatch Loss= 2.197091, Training Accuracy= 0.37500, Time= 0:02:27.310273
# Iter 264000, Minibatch Loss= 1.704337, Training Accuracy= 0.50000, Time= 0:02:28.205670
# Iter 265600, Minibatch Loss= 1.740175, Training Accuracy= 0.62500, Time= 0:02:29.100038
# Iter 267200, Minibatch Loss= 2.091460, Training Accuracy= 0.37500, Time= 0:02:29.993321
# Iter 268800, Minibatch Loss= 1.857364, Training Accuracy= 0.68750, Time= 0:02:30.885504
# Iter 270400, Minibatch Loss= 2.085795, Training Accuracy= 0.25000, Time= 0:02:31.778801
# Iter 272000, Minibatch Loss= 2.049425, Training Accuracy= 0.31250, Time= 0:02:32.672257
# Iter 273600, Minibatch Loss= 1.966423, Training Accuracy= 0.37500, Time= 0:02:33.566346
# Iter 275200, Minibatch Loss= 2.285378, Training Accuracy= 0.25000, Time= 0:02:34.461307
# Iter 276800, Minibatch Loss= 1.670043, Training Accuracy= 0.50000, Time= 0:02:35.353526
# Iter 278400, Minibatch Loss= 2.240422, Training Accuracy= 0.25000, Time= 0:02:36.248156
# Iter 280000, Minibatch Loss= 1.578477, Training Accuracy= 0.56250, Time= 0:02:37.140503
# Iter 281600, Minibatch Loss= 2.141037, Training Accuracy= 0.56250, Time= 0:02:38.036395
# Iter 283200, Minibatch Loss= 1.263940, Training Accuracy= 0.75000, Time= 0:02:38.928237
# Iter 284800, Minibatch Loss= 1.661897, Training Accuracy= 0.43750, Time= 0:02:39.823404
# Iter 286400, Minibatch Loss= 2.196377, Training Accuracy= 0.25000, Time= 0:02:40.717778
# Iter 288000, Minibatch Loss= 2.427981, Training Accuracy= 0.31250, Time= 0:02:41.611092
# Iter 289600, Minibatch Loss= 1.717839, Training Accuracy= 0.50000, Time= 0:02:42.504938
# Iter 291200, Minibatch Loss= 1.550470, Training Accuracy= 0.43750, Time= 0:02:43.397221
# Iter 292800, Minibatch Loss= 1.747988, Training Accuracy= 0.56250, Time= 0:02:44.292638
# Iter 294400, Minibatch Loss= 2.082498, Training Accuracy= 0.25000, Time= 0:02:45.187881
# Iter 296000, Minibatch Loss= 1.877411, Training Accuracy= 0.31250, Time= 0:02:46.079796
# Iter 297600, Minibatch Loss= 1.808327, Training Accuracy= 0.25000, Time= 0:02:46.972248
# Iter 299200, Minibatch Loss= 2.281588, Training Accuracy= 0.50000, Time= 0:02:47.867414
# Iter 300800, Minibatch Loss= 1.934886, Training Accuracy= 0.25000, Time= 0:02:48.758595
# Iter 302400, Minibatch Loss= 1.526790, Training Accuracy= 0.56250, Time= 0:02:49.652877
# Iter 304000, Minibatch Loss= 1.893390, Training Accuracy= 0.31250, Time= 0:02:50.547029
# Iter 305600, Minibatch Loss= 1.540764, Training Accuracy= 0.62500, Time= 0:02:51.439762
# Iter 307200, Minibatch Loss= 1.271266, Training Accuracy= 0.56250, Time= 0:02:52.332144
# Iter 308800, Minibatch Loss= 1.754748, Training Accuracy= 0.50000, Time= 0:02:53.226868
# Iter 310400, Minibatch Loss= 3.260742, Training Accuracy= 0.31250, Time= 0:02:54.120105
# Iter 312000, Minibatch Loss= 1.813801, Training Accuracy= 0.37500, Time= 0:02:55.016083
# Iter 313600, Minibatch Loss= 1.660520, Training Accuracy= 0.50000, Time= 0:02:55.910236
# Iter 315200, Minibatch Loss= 1.785706, Training Accuracy= 0.50000, Time= 0:02:56.804547
# Iter 316800, Minibatch Loss= 1.556740, Training Accuracy= 0.43750, Time= 0:02:57.697950
# Iter 318400, Minibatch Loss= 1.908559, Training Accuracy= 0.43750, Time= 0:02:58.592337
# Iter 320000, Minibatch Loss= 2.966781, Training Accuracy= 0.43750, Time= 0:02:59.486657
# Iter 321600, Minibatch Loss= 1.581065, Training Accuracy= 0.56250, Time= 0:03:00.379632
# Iter 323200, Minibatch Loss= 2.782291, Training Accuracy= 0.25000, Time= 0:03:01.273542
# Iter 324800, Minibatch Loss= 1.314874, Training Accuracy= 0.56250, Time= 0:03:02.169369
# Iter 326400, Minibatch Loss= 1.736689, Training Accuracy= 0.43750, Time= 0:03:03.064973
# Iter 328000, Minibatch Loss= 1.269392, Training Accuracy= 0.50000, Time= 0:03:03.958215
# Iter 329600, Minibatch Loss= 2.176061, Training Accuracy= 0.50000, Time= 0:03:04.852897
# Iter 331200, Minibatch Loss= 1.405713, Training Accuracy= 0.62500, Time= 0:03:05.745332
# Iter 332800, Minibatch Loss= 1.919931, Training Accuracy= 0.62500, Time= 0:03:06.639419
# Iter 334400, Minibatch Loss= 1.546291, Training Accuracy= 0.56250, Time= 0:03:07.535146
# Iter 336000, Minibatch Loss= 1.008082, Training Accuracy= 0.68750, Time= 0:03:08.429219
# Iter 337600, Minibatch Loss= 2.531082, Training Accuracy= 0.31250, Time= 0:03:09.322407
# Iter 339200, Minibatch Loss= 1.103185, Training Accuracy= 0.62500, Time= 0:03:10.219023
# Iter 340800, Minibatch Loss= 1.768265, Training Accuracy= 0.37500, Time= 0:03:11.111784
# Iter 342400, Minibatch Loss= 0.762272, Training Accuracy= 0.68750, Time= 0:03:12.006994
# Iter 344000, Minibatch Loss= 1.487564, Training Accuracy= 0.37500, Time= 0:03:12.899798
# Iter 345600, Minibatch Loss= 1.651829, Training Accuracy= 0.50000, Time= 0:03:13.792677
# Iter 347200, Minibatch Loss= 1.240837, Training Accuracy= 0.56250, Time= 0:03:14.685154
# Iter 348800, Minibatch Loss= 1.730849, Training Accuracy= 0.37500, Time= 0:03:15.580534
# Iter 350400, Minibatch Loss= 1.418754, Training Accuracy= 0.62500, Time= 0:03:16.473759
# Iter 352000, Minibatch Loss= 1.209449, Training Accuracy= 0.50000, Time= 0:03:17.367755
# Iter 353600, Minibatch Loss= 1.233948, Training Accuracy= 0.62500, Time= 0:03:18.262609
# Iter 355200, Minibatch Loss= 1.825020, Training Accuracy= 0.56250, Time= 0:03:19.157663
# Iter 356800, Minibatch Loss= 1.026384, Training Accuracy= 0.68750, Time= 0:03:20.052823
# Iter 358400, Minibatch Loss= 1.631076, Training Accuracy= 0.56250, Time= 0:03:20.945843
# Iter 360000, Minibatch Loss= 1.676006, Training Accuracy= 0.50000, Time= 0:03:21.840514
# Iter 361600, Minibatch Loss= 0.972837, Training Accuracy= 0.62500, Time= 0:03:22.735660
# Iter 363200, Minibatch Loss= 1.132115, Training Accuracy= 0.50000, Time= 0:03:23.629981
# Iter 364800, Minibatch Loss= 1.201267, Training Accuracy= 0.68750, Time= 0:03:24.525431
# Iter 366400, Minibatch Loss= 1.313895, Training Accuracy= 0.75000, Time= 0:03:25.420687
# Iter 368000, Minibatch Loss= 1.245229, Training Accuracy= 0.62500, Time= 0:03:26.312956
# Iter 369600, Minibatch Loss= 1.313106, Training Accuracy= 0.62500, Time= 0:03:27.208509
# Iter 371200, Minibatch Loss= 1.495501, Training Accuracy= 0.75000, Time= 0:03:28.104074
# Iter 372800, Minibatch Loss= 0.938838, Training Accuracy= 0.62500, Time= 0:03:28.996896
# Iter 374400, Minibatch Loss= 1.361369, Training Accuracy= 0.50000, Time= 0:03:29.893333
# Iter 376000, Minibatch Loss= 1.657053, Training Accuracy= 0.56250, Time= 0:03:30.788137
# Iter 377600, Minibatch Loss= 1.129703, Training Accuracy= 0.56250, Time= 0:03:31.682224
# Iter 379200, Minibatch Loss= 0.990709, Training Accuracy= 0.68750, Time= 0:03:32.575449
# Iter 380800, Minibatch Loss= 1.857165, Training Accuracy= 0.37500, Time= 0:03:33.471523
# Iter 382400, Minibatch Loss= 1.109938, Training Accuracy= 0.75000, Time= 0:03:34.364937
# Iter 384000, Minibatch Loss= 1.025850, Training Accuracy= 0.75000, Time= 0:03:35.259882
# Iter 385600, Minibatch Loss= 0.714208, Training Accuracy= 0.81250, Time= 0:03:36.154744
# Iter 387200, Minibatch Loss= 1.059610, Training Accuracy= 0.68750, Time= 0:03:37.047986
# Iter 388800, Minibatch Loss= 1.358753, Training Accuracy= 0.37500, Time= 0:03:37.943225
# Iter 390400, Minibatch Loss= 1.117405, Training Accuracy= 0.37500, Time= 0:03:38.837734
# Iter 392000, Minibatch Loss= 0.872001, Training Accuracy= 0.62500, Time= 0:03:39.730677
# Iter 393600, Minibatch Loss= 0.879285, Training Accuracy= 0.68750, Time= 0:03:40.627472
# Iter 395200, Minibatch Loss= 1.172901, Training Accuracy= 0.75000, Time= 0:03:41.532478
# Iter 396800, Minibatch Loss= 1.233248, Training Accuracy= 0.56250, Time= 0:03:42.426280
# Iter 398400, Minibatch Loss= 1.520761, Training Accuracy= 0.43750, Time= 0:03:43.328605
# Iter 400000, Minibatch Loss= 1.628616, Training Accuracy= 0.43750, Time= 0:03:44.223193
# Iter 401600, Minibatch Loss= 0.660603, Training Accuracy= 0.75000, Time= 0:03:45.116084
# Iter 403200, Minibatch Loss= 1.230116, Training Accuracy= 0.62500, Time= 0:03:46.010499
# Iter 404800, Minibatch Loss= 0.662011, Training Accuracy= 0.68750, Time= 0:03:46.905985
# Iter 406400, Minibatch Loss= 0.974141, Training Accuracy= 0.68750, Time= 0:03:47.800373
# Iter 408000, Minibatch Loss= 1.848219, Training Accuracy= 0.56250, Time= 0:03:48.694091
# Iter 409600, Minibatch Loss= 1.403716, Training Accuracy= 0.56250, Time= 0:03:49.587226
# Iter 411200, Minibatch Loss= 1.012960, Training Accuracy= 0.62500, Time= 0:03:50.479926
# Iter 412800, Minibatch Loss= 1.166222, Training Accuracy= 0.75000, Time= 0:03:51.375181
# Iter 414400, Minibatch Loss= 1.469019, Training Accuracy= 0.68750, Time= 0:03:52.269250
# Iter 416000, Minibatch Loss= 0.899418, Training Accuracy= 0.81250, Time= 0:03:53.164384
# Iter 417600, Minibatch Loss= 1.411005, Training Accuracy= 0.62500, Time= 0:03:54.058667
# Iter 419200, Minibatch Loss= 1.593807, Training Accuracy= 0.62500, Time= 0:03:54.949972
# Iter 420800, Minibatch Loss= 1.256064, Training Accuracy= 0.62500, Time= 0:03:55.844581
# Iter 422400, Minibatch Loss= 0.488223, Training Accuracy= 0.75000, Time= 0:03:56.736656
# Iter 424000, Minibatch Loss= 1.221207, Training Accuracy= 0.81250, Time= 0:03:57.631811
# Iter 425600, Minibatch Loss= 1.046334, Training Accuracy= 0.62500, Time= 0:03:58.529052
# Iter 427200, Minibatch Loss= 1.126473, Training Accuracy= 0.56250, Time= 0:03:59.422424
# Iter 428800, Minibatch Loss= 1.218807, Training Accuracy= 0.68750, Time= 0:04:00.318005
# Iter 430400, Minibatch Loss= 1.723302, Training Accuracy= 0.56250, Time= 0:04:01.213275
# Iter 432000, Minibatch Loss= 1.348711, Training Accuracy= 0.62500, Time= 0:04:02.107990
# Iter 433600, Minibatch Loss= 0.769075, Training Accuracy= 0.81250, Time= 0:04:03.003242
# Iter 435200, Minibatch Loss= 0.758341, Training Accuracy= 0.81250, Time= 0:04:03.899120
# Iter 436800, Minibatch Loss= 1.076479, Training Accuracy= 0.68750, Time= 0:04:04.792814
# Iter 438400, Minibatch Loss= 1.770655, Training Accuracy= 0.62500, Time= 0:04:05.686338
# Iter 440000, Minibatch Loss= 1.099049, Training Accuracy= 0.50000, Time= 0:04:06.582801
# Iter 441600, Minibatch Loss= 0.991248, Training Accuracy= 0.50000, Time= 0:04:07.475084
# Iter 443200, Minibatch Loss= 1.184849, Training Accuracy= 0.68750, Time= 0:04:08.369179
# Iter 444800, Minibatch Loss= 0.747641, Training Accuracy= 0.68750, Time= 0:04:09.263089
# Iter 446400, Minibatch Loss= 1.341778, Training Accuracy= 0.75000, Time= 0:04:10.155743
# Iter 448000, Minibatch Loss= 1.320105, Training Accuracy= 0.68750, Time= 0:04:11.049577
# Iter 449600, Minibatch Loss= 0.697613, Training Accuracy= 0.81250, Time= 0:04:11.944591
# Iter 451200, Minibatch Loss= 0.766031, Training Accuracy= 0.81250, Time= 0:04:12.837253
# Iter 452800, Minibatch Loss= 0.426987, Training Accuracy= 0.87500, Time= 0:04:13.731375
# Iter 454400, Minibatch Loss= 1.544072, Training Accuracy= 0.50000, Time= 0:04:14.624796
# Iter 456000, Minibatch Loss= 1.078554, Training Accuracy= 0.81250, Time= 0:04:15.517198
# Iter 457600, Minibatch Loss= 1.551728, Training Accuracy= 0.62500, Time= 0:04:16.409785
# Iter 459200, Minibatch Loss= 0.573639, Training Accuracy= 0.81250, Time= 0:04:17.306618
# Iter 460800, Minibatch Loss= 0.788658, Training Accuracy= 0.68750, Time= 0:04:18.200334
# Iter 462400, Minibatch Loss= 0.661282, Training Accuracy= 0.75000, Time= 0:04:19.094064
# Iter 464000, Minibatch Loss= 0.423968, Training Accuracy= 0.87500, Time= 0:04:19.986758
# Iter 465600, Minibatch Loss= 0.483512, Training Accuracy= 0.87500, Time= 0:04:20.881972
# Iter 467200, Minibatch Loss= 0.775266, Training Accuracy= 0.81250, Time= 0:04:21.776527
# Iter 468800, Minibatch Loss= 1.773130, Training Accuracy= 0.50000, Time= 0:04:22.669795
# Iter 470400, Minibatch Loss= 0.859125, Training Accuracy= 0.75000, Time= 0:04:23.565483
# Iter 472000, Minibatch Loss= 0.658311, Training Accuracy= 0.81250, Time= 0:04:24.459796
# Iter 473600, Minibatch Loss= 0.866789, Training Accuracy= 0.62500, Time= 0:04:25.352453
# Iter 475200, Minibatch Loss= 0.699355, Training Accuracy= 0.75000, Time= 0:04:26.244808
# Iter 476800, Minibatch Loss= 0.647827, Training Accuracy= 0.75000, Time= 0:04:27.137816
# Iter 478400, Minibatch Loss= 0.918181, Training Accuracy= 0.68750, Time= 0:04:28.030981
# Iter 480000, Minibatch Loss= 0.746887, Training Accuracy= 0.68750, Time= 0:04:28.926769
# Iter 481600, Minibatch Loss= 0.665181, Training Accuracy= 0.75000, Time= 0:04:29.818489
# Iter 483200, Minibatch Loss= 0.860002, Training Accuracy= 0.68750, Time= 0:04:30.712311
# Iter 484800, Minibatch Loss= 0.915641, Training Accuracy= 0.68750, Time= 0:04:31.606864
# Iter 486400, Minibatch Loss= 0.617932, Training Accuracy= 0.87500, Time= 0:04:32.502014
# Iter 488000, Minibatch Loss= 1.833074, Training Accuracy= 0.50000, Time= 0:04:33.396062
# Iter 489600, Minibatch Loss= 0.981927, Training Accuracy= 0.75000, Time= 0:04:34.289254
# Iter 491200, Minibatch Loss= 0.892181, Training Accuracy= 0.75000, Time= 0:04:35.182454
# Iter 492800, Minibatch Loss= 1.020141, Training Accuracy= 0.75000, Time= 0:04:36.078008
# Iter 494400, Minibatch Loss= 0.660748, Training Accuracy= 0.81250, Time= 0:04:36.969362
# Iter 496000, Minibatch Loss= 0.747817, Training Accuracy= 0.75000, Time= 0:04:37.863589
# Iter 497600, Minibatch Loss= 0.646116, Training Accuracy= 0.81250, Time= 0:04:38.757302
# Iter 499200, Minibatch Loss= 1.007475, Training Accuracy= 0.68750, Time= 0:04:39.650889
# Iter 500800, Minibatch Loss= 0.950661, Training Accuracy= 0.81250, Time= 0:04:40.544711
# Iter 502400, Minibatch Loss= 0.607860, Training Accuracy= 0.87500, Time= 0:04:41.439200
# Iter 504000, Minibatch Loss= 0.879016, Training Accuracy= 0.75000, Time= 0:04:42.333939
# Iter 505600, Minibatch Loss= 0.980726, Training Accuracy= 0.68750, Time= 0:04:43.227945
# Iter 507200, Minibatch Loss= 1.191570, Training Accuracy= 0.75000, Time= 0:04:44.119535
# Iter 508800, Minibatch Loss= 0.847788, Training Accuracy= 0.68750, Time= 0:04:45.012374
# Iter 510400, Minibatch Loss= 0.844178, Training Accuracy= 0.81250, Time= 0:04:45.906418
# Iter 512000, Minibatch Loss= 0.966512, Training Accuracy= 0.62500, Time= 0:04:46.801619
# Iter 513600, Minibatch Loss= 0.892310, Training Accuracy= 0.68750, Time= 0:04:47.694420
# Iter 515200, Minibatch Loss= 0.581300, Training Accuracy= 0.87500, Time= 0:04:48.586209
# Iter 516800, Minibatch Loss= 1.284544, Training Accuracy= 0.62500, Time= 0:04:49.477323
# Iter 518400, Minibatch Loss= 1.050683, Training Accuracy= 0.62500, Time= 0:04:50.371711
# Iter 520000, Minibatch Loss= 0.927213, Training Accuracy= 0.68750, Time= 0:04:51.265328
# Iter 521600, Minibatch Loss= 0.443698, Training Accuracy= 0.87500, Time= 0:04:52.157122
# Iter 523200, Minibatch Loss= 0.264825, Training Accuracy= 0.87500, Time= 0:04:53.052170
# Iter 524800, Minibatch Loss= 0.460171, Training Accuracy= 0.87500, Time= 0:04:53.944070
# Iter 526400, Minibatch Loss= 1.198596, Training Accuracy= 0.56250, Time= 0:04:54.838399
# Iter 528000, Minibatch Loss= 0.639420, Training Accuracy= 0.62500, Time= 0:04:55.731475
# Iter 529600, Minibatch Loss= 0.706433, Training Accuracy= 0.75000, Time= 0:04:56.623423
# Iter 531200, Minibatch Loss= 0.998259, Training Accuracy= 0.62500, Time= 0:04:57.517429
# Iter 532800, Minibatch Loss= 0.928274, Training Accuracy= 0.68750, Time= 0:04:58.412656
# Iter 534400, Minibatch Loss= 0.484530, Training Accuracy= 0.93750, Time= 0:04:59.305810
# Iter 536000, Minibatch Loss= 0.484038, Training Accuracy= 0.81250, Time= 0:05:00.198732
# Iter 537600, Minibatch Loss= 0.453991, Training Accuracy= 0.81250, Time= 0:05:01.090979
# Iter 539200, Minibatch Loss= 0.421363, Training Accuracy= 0.81250, Time= 0:05:01.985590
# Iter 540800, Minibatch Loss= 1.292047, Training Accuracy= 0.75000, Time= 0:05:02.880257
# Iter 542400, Minibatch Loss= 0.803911, Training Accuracy= 0.75000, Time= 0:05:03.773534
# Iter 544000, Minibatch Loss= 0.757657, Training Accuracy= 0.81250, Time= 0:05:04.668999
# Iter 545600, Minibatch Loss= 0.931169, Training Accuracy= 0.75000, Time= 0:05:05.564881
# Iter 547200, Minibatch Loss= 1.032229, Training Accuracy= 0.68750, Time= 0:05:06.458097
# Iter 548800, Minibatch Loss= 0.779469, Training Accuracy= 0.62500, Time= 0:05:07.351668
# Iter 550400, Minibatch Loss= 0.768015, Training Accuracy= 0.75000, Time= 0:05:08.246002
# Iter 552000, Minibatch Loss= 0.484565, Training Accuracy= 0.81250, Time= 0:05:09.137758
# Iter 553600, Minibatch Loss= 0.480018, Training Accuracy= 0.81250, Time= 0:05:10.031609
# Iter 555200, Minibatch Loss= 0.610008, Training Accuracy= 0.87500, Time= 0:05:10.925290
# Iter 556800, Minibatch Loss= 1.069868, Training Accuracy= 0.68750, Time= 0:05:11.819339
# Iter 558400, Minibatch Loss= 0.968669, Training Accuracy= 0.68750, Time= 0:05:12.713522
# Iter 560000, Minibatch Loss= 1.045338, Training Accuracy= 0.56250, Time= 0:05:13.607597
# Iter 561600, Minibatch Loss= 0.513728, Training Accuracy= 0.75000, Time= 0:05:14.501238
# Iter 563200, Minibatch Loss= 0.330004, Training Accuracy= 0.87500, Time= 0:05:15.394519
# Iter 564800, Minibatch Loss= 0.852934, Training Accuracy= 0.62500, Time= 0:05:16.288305
# Iter 566400, Minibatch Loss= 1.392791, Training Accuracy= 0.75000, Time= 0:05:17.183085
# Iter 568000, Minibatch Loss= 0.660946, Training Accuracy= 0.81250, Time= 0:05:18.076712
# Iter 569600, Minibatch Loss= 1.110453, Training Accuracy= 0.68750, Time= 0:05:18.969470
# Iter 571200, Minibatch Loss= 0.472500, Training Accuracy= 0.81250, Time= 0:05:19.863590
# Iter 572800, Minibatch Loss= 1.090806, Training Accuracy= 0.68750, Time= 0:05:20.758531
# Iter 574400, Minibatch Loss= 0.917166, Training Accuracy= 0.50000, Time= 0:05:21.652210
# Iter 576000, Minibatch Loss= 0.525659, Training Accuracy= 0.81250, Time= 0:05:22.545807
# Iter 577600, Minibatch Loss= 0.979368, Training Accuracy= 0.75000, Time= 0:05:23.439033
# Iter 579200, Minibatch Loss= 0.951654, Training Accuracy= 0.81250, Time= 0:05:24.331305
# Iter 580800, Minibatch Loss= 0.590344, Training Accuracy= 0.81250, Time= 0:05:25.226287
# Iter 582400, Minibatch Loss= 0.278838, Training Accuracy= 0.87500, Time= 0:05:26.119415
# Iter 584000, Minibatch Loss= 0.805840, Training Accuracy= 0.68750, Time= 0:05:27.013396
# Iter 585600, Minibatch Loss= 1.015549, Training Accuracy= 0.75000, Time= 0:05:27.906921
# Iter 587200, Minibatch Loss= 2.043192, Training Accuracy= 0.56250, Time= 0:05:28.800870
# Iter 588800, Minibatch Loss= 0.507706, Training Accuracy= 0.81250, Time= 0:05:29.695496
# Iter 590400, Minibatch Loss= 1.765859, Training Accuracy= 0.62500, Time= 0:05:30.590168
# Iter 592000, Minibatch Loss= 0.999264, Training Accuracy= 0.75000, Time= 0:05:31.484098
# Iter 593600, Minibatch Loss= 0.525070, Training Accuracy= 0.81250, Time= 0:05:32.378201
# Iter 595200, Minibatch Loss= 0.650134, Training Accuracy= 0.81250, Time= 0:05:33.271682
# Iter 596800, Minibatch Loss= 0.488129, Training Accuracy= 0.87500, Time= 0:05:34.165841
# Iter 598400, Minibatch Loss= 0.359251, Training Accuracy= 0.87500, Time= 0:05:35.062107
# Iter 600000, Minibatch Loss= 0.470760, Training Accuracy= 0.87500, Time= 0:05:35.954490
# Iter 601600, Minibatch Loss= 0.937003, Training Accuracy= 0.87500, Time= 0:05:36.847352
# Iter 603200, Minibatch Loss= 0.717130, Training Accuracy= 0.81250, Time= 0:05:37.741014
# Iter 604800, Minibatch Loss= 0.576092, Training Accuracy= 0.87500, Time= 0:05:38.634065
# Iter 606400, Minibatch Loss= 0.241416, Training Accuracy= 0.93750, Time= 0:05:39.527304
# Iter 608000, Minibatch Loss= 0.971280, Training Accuracy= 0.62500, Time= 0:05:40.423422
# Iter 609600, Minibatch Loss= 0.349455, Training Accuracy= 0.87500, Time= 0:05:41.326633
# Iter 611200, Minibatch Loss= 0.377454, Training Accuracy= 0.93750, Time= 0:05:42.219406
# Iter 612800, Minibatch Loss= 0.465741, Training Accuracy= 0.93750, Time= 0:05:43.123983
# Iter 614400, Minibatch Loss= 0.619629, Training Accuracy= 0.75000, Time= 0:05:44.015016
# Iter 616000, Minibatch Loss= 0.333705, Training Accuracy= 0.87500, Time= 0:05:44.909908
# Iter 617600, Minibatch Loss= 0.977694, Training Accuracy= 0.68750, Time= 0:05:45.805072
# Iter 619200, Minibatch Loss= 0.455109, Training Accuracy= 0.87500, Time= 0:05:46.699799
# Iter 620800, Minibatch Loss= 0.346332, Training Accuracy= 0.93750, Time= 0:05:47.595831
# Iter 622400, Minibatch Loss= 0.987083, Training Accuracy= 0.81250, Time= 0:05:48.489848
# Iter 624000, Minibatch Loss= 0.756415, Training Accuracy= 0.75000, Time= 0:05:49.383511
# Iter 625600, Minibatch Loss= 1.519012, Training Accuracy= 0.75000, Time= 0:05:50.276950
# Iter 627200, Minibatch Loss= 0.562144, Training Accuracy= 0.93750, Time= 0:05:51.171228
# Iter 628800, Minibatch Loss= 0.514024, Training Accuracy= 0.81250, Time= 0:05:52.065942
# Iter 630400, Minibatch Loss= 0.543564, Training Accuracy= 0.75000, Time= 0:05:52.960747
# Iter 632000, Minibatch Loss= 1.062037, Training Accuracy= 0.87500, Time= 0:05:53.855766
# Iter 633600, Minibatch Loss= 0.619558, Training Accuracy= 0.81250, Time= 0:05:54.750637
# Iter 635200, Minibatch Loss= 0.193208, Training Accuracy= 0.93750, Time= 0:05:55.645287
# Iter 636800, Minibatch Loss= 0.965675, Training Accuracy= 0.75000, Time= 0:05:56.538807
# Iter 638400, Minibatch Loss= 0.394307, Training Accuracy= 0.87500, Time= 0:05:57.432192
# Iter 640000, Minibatch Loss= 0.771528, Training Accuracy= 0.81250, Time= 0:05:58.325821
# Iter 641600, Minibatch Loss= 0.466011, Training Accuracy= 0.93750, Time= 0:05:59.219284
# Iter 643200, Minibatch Loss= 0.741040, Training Accuracy= 0.75000, Time= 0:06:00.110817
# Iter 644800, Minibatch Loss= 0.603254, Training Accuracy= 0.81250, Time= 0:06:01.003382
# Iter 646400, Minibatch Loss= 0.346970, Training Accuracy= 0.93750, Time= 0:06:01.897717
# Iter 648000, Minibatch Loss= 0.300090, Training Accuracy= 0.81250, Time= 0:06:02.789798
# Iter 649600, Minibatch Loss= 0.156561, Training Accuracy= 0.93750, Time= 0:06:03.681985
# Iter 651200, Minibatch Loss= 1.147088, Training Accuracy= 0.93750, Time= 0:06:04.576928
# Iter 652800, Minibatch Loss= 0.500892, Training Accuracy= 0.81250, Time= 0:06:05.469440
# Iter 654400, Minibatch Loss= 1.343574, Training Accuracy= 0.87500, Time= 0:06:06.363846
# Iter 656000, Minibatch Loss= 0.465359, Training Accuracy= 0.93750, Time= 0:06:07.258738
# Iter 657600, Minibatch Loss= 0.828043, Training Accuracy= 0.75000, Time= 0:06:08.153126
# Iter 659200, Minibatch Loss= 0.879014, Training Accuracy= 0.75000, Time= 0:06:09.047946
# Iter 660800, Minibatch Loss= 0.136016, Training Accuracy= 1.00000, Time= 0:06:09.941998
# Iter 662400, Minibatch Loss= 0.411297, Training Accuracy= 0.81250, Time= 0:06:10.834670
# Iter 664000, Minibatch Loss= 0.779499, Training Accuracy= 0.81250, Time= 0:06:11.729069
# Iter 665600, Minibatch Loss= 0.495208, Training Accuracy= 0.81250, Time= 0:06:12.622821
# Iter 667200, Minibatch Loss= 0.561125, Training Accuracy= 0.75000, Time= 0:06:13.513931
# Iter 668800, Minibatch Loss= 0.384696, Training Accuracy= 1.00000, Time= 0:06:14.406835
# Iter 670400, Minibatch Loss= 0.535527, Training Accuracy= 0.87500, Time= 0:06:15.298325
# Iter 672000, Minibatch Loss= 0.688095, Training Accuracy= 0.81250, Time= 0:06:16.192895
# Iter 673600, Minibatch Loss= 0.799798, Training Accuracy= 0.75000, Time= 0:06:17.086642
# Iter 675200, Minibatch Loss= 0.696387, Training Accuracy= 0.81250, Time= 0:06:17.981932
# Iter 676800, Minibatch Loss= 1.073333, Training Accuracy= 0.81250, Time= 0:06:18.876077
# Iter 678400, Minibatch Loss= 1.407000, Training Accuracy= 0.68750, Time= 0:06:19.770173
# Iter 680000, Minibatch Loss= 0.545576, Training Accuracy= 0.87500, Time= 0:06:20.664365
# Iter 681600, Minibatch Loss= 0.439259, Training Accuracy= 0.87500, Time= 0:06:21.557027
# Iter 683200, Minibatch Loss= 0.374688, Training Accuracy= 0.81250, Time= 0:06:22.450372
# Iter 684800, Minibatch Loss= 0.525508, Training Accuracy= 0.81250, Time= 0:06:23.343705
# Iter 686400, Minibatch Loss= 0.472595, Training Accuracy= 0.81250, Time= 0:06:24.239271
# Iter 688000, Minibatch Loss= 0.611426, Training Accuracy= 0.87500, Time= 0:06:25.132075
# Iter 689600, Minibatch Loss= 0.366255, Training Accuracy= 0.87500, Time= 0:06:26.024317
# Iter 691200, Minibatch Loss= 1.177014, Training Accuracy= 0.87500, Time= 0:06:26.918526
# Iter 692800, Minibatch Loss= 0.572916, Training Accuracy= 0.81250, Time= 0:06:27.811588
# Iter 694400, Minibatch Loss= 0.162021, Training Accuracy= 1.00000, Time= 0:06:28.703763
# Iter 696000, Minibatch Loss= 0.425491, Training Accuracy= 0.93750, Time= 0:06:29.595960
# Iter 697600, Minibatch Loss= 0.429701, Training Accuracy= 0.93750, Time= 0:06:30.488578
# Iter 699200, Minibatch Loss= 0.530702, Training Accuracy= 0.81250, Time= 0:06:31.384473
# Iter 700800, Minibatch Loss= 0.620414, Training Accuracy= 0.81250, Time= 0:06:32.278899
# Iter 702400, Minibatch Loss= 0.704538, Training Accuracy= 0.81250, Time= 0:06:33.172243
# Iter 704000, Minibatch Loss= 0.786607, Training Accuracy= 0.81250, Time= 0:06:34.065547
# Iter 705600, Minibatch Loss= 0.420695, Training Accuracy= 0.93750, Time= 0:06:34.960332
# Iter 707200, Minibatch Loss= 0.496328, Training Accuracy= 0.81250, Time= 0:06:35.853388
# Iter 708800, Minibatch Loss= 0.659136, Training Accuracy= 0.75000, Time= 0:06:36.747220
# Iter 710400, Minibatch Loss= 0.451800, Training Accuracy= 0.75000, Time= 0:06:37.640748
# Iter 712000, Minibatch Loss= 0.572150, Training Accuracy= 0.87500, Time= 0:06:38.536101
# Iter 713600, Minibatch Loss= 0.684332, Training Accuracy= 0.87500, Time= 0:06:39.429021
# Iter 715200, Minibatch Loss= 0.189957, Training Accuracy= 1.00000, Time= 0:06:40.325033
# Iter 716800, Minibatch Loss= 1.141357, Training Accuracy= 0.68750, Time= 0:06:41.219157
# Iter 718400, Minibatch Loss= 0.699133, Training Accuracy= 0.75000, Time= 0:06:42.112695
# Iter 720000, Minibatch Loss= 0.321271, Training Accuracy= 0.87500, Time= 0:06:43.006014
# Iter 721600, Minibatch Loss= 0.767574, Training Accuracy= 0.68750, Time= 0:06:43.898391
# Iter 723200, Minibatch Loss= 0.350620, Training Accuracy= 0.93750, Time= 0:06:44.791504
# Iter 724800, Minibatch Loss= 0.361524, Training Accuracy= 0.93750, Time= 0:06:45.685652
# Iter 726400, Minibatch Loss= 0.978067, Training Accuracy= 0.81250, Time= 0:06:46.580558
# Iter 728000, Minibatch Loss= 0.331648, Training Accuracy= 0.87500, Time= 0:06:47.475706
# Iter 729600, Minibatch Loss= 1.232921, Training Accuracy= 0.75000, Time= 0:06:48.368301
# Iter 731200, Minibatch Loss= 0.447810, Training Accuracy= 0.87500, Time= 0:06:49.261477
# Iter 732800, Minibatch Loss= 0.505400, Training Accuracy= 0.81250, Time= 0:06:50.155050
# Iter 734400, Minibatch Loss= 0.353388, Training Accuracy= 0.81250, Time= 0:06:51.048695
# Iter 736000, Minibatch Loss= 0.813712, Training Accuracy= 0.81250, Time= 0:06:51.940714
# Iter 737600, Minibatch Loss= 1.132722, Training Accuracy= 0.81250, Time= 0:06:52.834934
# Iter 739200, Minibatch Loss= 0.614225, Training Accuracy= 0.81250, Time= 0:06:53.731001
# Iter 740800, Minibatch Loss= 0.787983, Training Accuracy= 0.68750, Time= 0:06:54.623938
# Iter 742400, Minibatch Loss= 0.214448, Training Accuracy= 0.93750, Time= 0:06:55.516447
# Iter 744000, Minibatch Loss= 0.319622, Training Accuracy= 0.81250, Time= 0:06:56.409549
# Iter 745600, Minibatch Loss= 0.690845, Training Accuracy= 0.81250, Time= 0:06:57.301122
# Iter 747200, Minibatch Loss= 0.355871, Training Accuracy= 0.87500, Time= 0:06:58.194835
# Iter 748800, Minibatch Loss= 0.139864, Training Accuracy= 0.93750, Time= 0:06:59.088862
# Iter 750400, Minibatch Loss= 0.268848, Training Accuracy= 0.93750, Time= 0:06:59.983291
# Iter 752000, Minibatch Loss= 0.740747, Training Accuracy= 0.75000, Time= 0:07:00.879726
# Iter 753600, Minibatch Loss= 0.347894, Training Accuracy= 0.87500, Time= 0:07:01.774548
# Iter 755200, Minibatch Loss= 0.391519, Training Accuracy= 0.75000, Time= 0:07:02.668153
# Iter 756800, Minibatch Loss= 0.311384, Training Accuracy= 0.93750, Time= 0:07:03.560908
# Iter 758400, Minibatch Loss= 0.231140, Training Accuracy= 0.93750, Time= 0:07:04.453356
# Iter 760000, Minibatch Loss= 0.776759, Training Accuracy= 0.81250, Time= 0:07:05.346212
# Iter 761600, Minibatch Loss= 0.917809, Training Accuracy= 0.75000, Time= 0:07:06.240643
# Iter 763200, Minibatch Loss= 0.346189, Training Accuracy= 0.81250, Time= 0:07:07.135750
# Iter 764800, Minibatch Loss= 0.298184, Training Accuracy= 0.87500, Time= 0:07:08.031436
# Iter 766400, Minibatch Loss= 0.289522, Training Accuracy= 0.87500, Time= 0:07:08.923710
# Iter 768000, Minibatch Loss= 0.504420, Training Accuracy= 0.75000, Time= 0:07:09.816943
# Iter 769600, Minibatch Loss= 0.784469, Training Accuracy= 0.87500, Time= 0:07:10.709086
# Iter 771200, Minibatch Loss= 0.241578, Training Accuracy= 0.87500, Time= 0:07:11.603048
# Iter 772800, Minibatch Loss= 0.331745, Training Accuracy= 0.93750, Time= 0:07:12.495634
# Iter 774400, Minibatch Loss= 0.473009, Training Accuracy= 0.87500, Time= 0:07:13.389703
# Iter 776000, Minibatch Loss= 0.165726, Training Accuracy= 1.00000, Time= 0:07:14.284170
# Iter 777600, Minibatch Loss= 0.036472, Training Accuracy= 1.00000, Time= 0:07:15.177162
# Iter 779200, Minibatch Loss= 1.088021, Training Accuracy= 0.81250, Time= 0:07:16.071881
# Iter 780800, Minibatch Loss= 0.295453, Training Accuracy= 0.93750, Time= 0:07:16.965337
# Iter 782400, Minibatch Loss= 0.373593, Training Accuracy= 0.81250, Time= 0:07:17.858868
# Iter 784000, Minibatch Loss= 0.606013, Training Accuracy= 0.81250, Time= 0:07:18.751074
# Iter 785600, Minibatch Loss= 0.584579, Training Accuracy= 0.81250, Time= 0:07:19.644971
# Iter 787200, Minibatch Loss= 0.565785, Training Accuracy= 0.81250, Time= 0:07:20.538721
# Iter 788800, Minibatch Loss= 1.537843, Training Accuracy= 0.81250, Time= 0:07:21.432507
# Iter 790400, Minibatch Loss= 0.612555, Training Accuracy= 0.87500, Time= 0:07:22.326251
# Iter 792000, Minibatch Loss= 0.575120, Training Accuracy= 0.81250, Time= 0:07:23.220562
# Iter 793600, Minibatch Loss= 0.417177, Training Accuracy= 0.93750, Time= 0:07:24.116244
# Iter 795200, Minibatch Loss= 0.273934, Training Accuracy= 0.93750, Time= 0:07:25.013456
# Iter 796800, Minibatch Loss= 0.280865, Training Accuracy= 0.93750, Time= 0:07:25.908324
# Iter 798400, Minibatch Loss= 0.277829, Training Accuracy= 0.93750, Time= 0:07:26.802855
# Iter 800000, Minibatch Loss= 0.226707, Training Accuracy= 0.93750, Time= 0:07:27.696598
# Iter 801600, Minibatch Loss= 0.140289, Training Accuracy= 1.00000, Time= 0:07:28.591922
# Iter 803200, Minibatch Loss= 0.359567, Training Accuracy= 0.81250, Time= 0:07:29.485975
# Iter 804800, Minibatch Loss= 0.155890, Training Accuracy= 0.93750, Time= 0:07:30.378748
# Iter 806400, Minibatch Loss= 0.471498, Training Accuracy= 0.87500, Time= 0:07:31.271531
# Iter 808000, Minibatch Loss= 0.604937, Training Accuracy= 0.81250, Time= 0:07:32.165400
# Iter 809600, Minibatch Loss= 0.294101, Training Accuracy= 0.87500, Time= 0:07:33.058651
# Iter 811200, Minibatch Loss= 0.606205, Training Accuracy= 0.87500, Time= 0:07:33.953602
# Iter 812800, Minibatch Loss= 0.337914, Training Accuracy= 0.93750, Time= 0:07:34.847418
# Iter 814400, Minibatch Loss= 0.423536, Training Accuracy= 0.87500, Time= 0:07:35.738899
# Iter 816000, Minibatch Loss= 0.109073, Training Accuracy= 1.00000, Time= 0:07:36.632358
# Iter 817600, Minibatch Loss= 0.457725, Training Accuracy= 0.93750, Time= 0:07:37.526642
# Iter 819200, Minibatch Loss= 1.271448, Training Accuracy= 0.68750, Time= 0:07:38.421642
# Iter 820800, Minibatch Loss= 0.550126, Training Accuracy= 0.87500, Time= 0:07:39.314173
# Iter 822400, Minibatch Loss= 0.233044, Training Accuracy= 0.93750, Time= 0:07:40.208509
# Iter 824000, Minibatch Loss= 0.139633, Training Accuracy= 0.93750, Time= 0:07:41.114890
# Iter 825600, Minibatch Loss= 1.060940, Training Accuracy= 0.81250, Time= 0:07:42.009891
# Iter 827200, Minibatch Loss= 0.231158, Training Accuracy= 1.00000, Time= 0:07:42.913764
# Iter 828800, Minibatch Loss= 0.202127, Training Accuracy= 0.87500, Time= 0:07:43.807469
# Iter 830400, Minibatch Loss= 0.205551, Training Accuracy= 0.93750, Time= 0:07:44.702057
# Iter 832000, Minibatch Loss= 0.178055, Training Accuracy= 1.00000, Time= 0:07:45.597705
# Iter 833600, Minibatch Loss= 0.715388, Training Accuracy= 0.75000, Time= 0:07:46.491275
# Iter 835200, Minibatch Loss= 0.694815, Training Accuracy= 0.68750, Time= 0:07:47.384574
# Iter 836800, Minibatch Loss= 0.280262, Training Accuracy= 0.87500, Time= 0:07:48.280425
# Iter 838400, Minibatch Loss= 0.885232, Training Accuracy= 0.87500, Time= 0:07:49.172180
# Iter 840000, Minibatch Loss= 0.121108, Training Accuracy= 1.00000, Time= 0:07:50.066756
# Iter 841600, Minibatch Loss= 0.707417, Training Accuracy= 0.93750, Time= 0:07:50.961560
# Iter 843200, Minibatch Loss= 0.487275, Training Accuracy= 0.75000, Time= 0:07:51.855517
# Iter 844800, Minibatch Loss= 0.218331, Training Accuracy= 0.93750, Time= 0:07:52.749278
# Iter 846400, Minibatch Loss= 0.190144, Training Accuracy= 0.93750, Time= 0:07:53.644226
# Iter 848000, Minibatch Loss= 0.402463, Training Accuracy= 0.81250, Time= 0:07:54.538514
# Iter 849600, Minibatch Loss= 0.315023, Training Accuracy= 0.93750, Time= 0:07:55.430801
# Iter 851200, Minibatch Loss= 0.096054, Training Accuracy= 1.00000, Time= 0:07:56.324631
# Iter 852800, Minibatch Loss= 0.187099, Training Accuracy= 0.87500, Time= 0:07:57.217534
# Iter 854400, Minibatch Loss= 0.222655, Training Accuracy= 0.93750, Time= 0:07:58.110391
# Iter 856000, Minibatch Loss= 0.892899, Training Accuracy= 0.87500, Time= 0:07:59.003793
# Iter 857600, Minibatch Loss= 0.227414, Training Accuracy= 0.93750, Time= 0:07:59.898755
# Iter 859200, Minibatch Loss= 0.166523, Training Accuracy= 0.93750, Time= 0:08:00.792153
# Iter 860800, Minibatch Loss= 0.071488, Training Accuracy= 1.00000, Time= 0:08:01.686861
# Iter 862400, Minibatch Loss= 0.305730, Training Accuracy= 0.87500, Time= 0:08:02.580557
# Iter 864000, Minibatch Loss= 0.644937, Training Accuracy= 0.93750, Time= 0:08:03.474167
# Iter 865600, Minibatch Loss= 0.547652, Training Accuracy= 0.87500, Time= 0:08:04.367273
# Iter 867200, Minibatch Loss= 0.315368, Training Accuracy= 0.93750, Time= 0:08:05.262311
# Iter 868800, Minibatch Loss= 0.174667, Training Accuracy= 1.00000, Time= 0:08:06.156203
# Iter 870400, Minibatch Loss= 0.594415, Training Accuracy= 0.87500, Time= 0:08:07.050643
# Iter 872000, Minibatch Loss= 0.394657, Training Accuracy= 0.87500, Time= 0:08:07.945162
# Iter 873600, Minibatch Loss= 0.387246, Training Accuracy= 0.81250, Time= 0:08:08.841690
# ...
# Iter 1313600, Minibatch Loss= 0.451647, Training Accuracy= 0.87500, Time= 0:12:15.345661
# Iter 1315200, Minibatch Loss= 0.403140, Training Accuracy= 0.93750, Time= 0:12:16.241216
# Iter 1316800, Minibatch Loss= 0.162726, Training Accuracy= 1.00000, Time= 0:12:17.134854
# Iter 1318400, Minibatch Loss= 0.120471, Training Accuracy= 0.93750, Time= 0:12:18.029364
# Iter 1320000, Minibatch Loss= 0.217395, Training Accuracy= 0.87500, Time= 0:12:18.924138
# Iter 1321600, Minibatch Loss= 0.685617, Training Accuracy= 0.81250, Time= 0:12:19.818551
# Iter 1323200, Minibatch Loss= 0.471024, Training Accuracy= 0.87500, Time= 0:12:20.712888
# Iter 1324800, Minibatch Loss= 0.069456, Training Accuracy= 1.00000, Time= 0:12:21.606027
# Iter 1326400, Minibatch Loss= 0.006849, Training Accuracy= 1.00000, Time= 0:12:22.499658
# Iter 1328000, Minibatch Loss= 0.054617, Training Accuracy= 1.00000, Time= 0:12:23.393329
# Iter 1329600, Minibatch Loss= 0.652482, Training Accuracy= 0.87500, Time= 0:12:24.288068
# Iter 1331200, Minibatch Loss= 0.143162, Training Accuracy= 0.93750, Time= 0:12:25.182375
# Iter 1332800, Minibatch Loss= 0.414046, Training Accuracy= 0.93750, Time= 0:12:26.077944
# Iter 1334400, Minibatch Loss= 0.154614, Training Accuracy= 1.00000, Time= 0:12:26.972618
# Iter 1336000, Minibatch Loss= 0.106109, Training Accuracy= 1.00000, Time= 0:12:27.865659
# Iter 1337600, Minibatch Loss= 0.300243, Training Accuracy= 0.87500, Time= 0:12:28.762007
# Iter 1339200, Minibatch Loss= 0.419288, Training Accuracy= 0.93750, Time= 0:12:29.654633
# Iter 1340800, Minibatch Loss= 0.012550, Training Accuracy= 1.00000, Time= 0:12:30.548192
# Iter 1342400, Minibatch Loss= 0.223864, Training Accuracy= 0.93750, Time= 0:12:31.441257
# Iter 1344000, Minibatch Loss= 0.560069, Training Accuracy= 0.81250, Time= 0:12:32.334205
# Iter 1345600, Minibatch Loss= 0.179583, Training Accuracy= 0.93750, Time= 0:12:33.229177
# Iter 1347200, Minibatch Loss= 0.280421, Training Accuracy= 0.93750, Time= 0:12:34.121122
# Iter 1348800, Minibatch Loss= 0.082537, Training Accuracy= 1.00000, Time= 0:12:35.014797
# Iter 1350400, Minibatch Loss= 0.231869, Training Accuracy= 0.93750, Time= 0:12:35.909680
# Iter 1352000, Minibatch Loss= 0.043185, Training Accuracy= 1.00000, Time= 0:12:36.803256
# Iter 1353600, Minibatch Loss= 0.039306, Training Accuracy= 1.00000, Time= 0:12:37.698323
# Iter 1355200, Minibatch Loss= 0.006622, Training Accuracy= 1.00000, Time= 0:12:38.592731
# Iter 1356800, Minibatch Loss= 0.212992, Training Accuracy= 0.87500, Time= 0:12:39.486465
# Iter 1358400, Minibatch Loss= 0.026231, Training Accuracy= 1.00000, Time= 0:12:40.380363
# Iter 1360000, Minibatch Loss= 0.691253, Training Accuracy= 0.87500, Time= 0:12:41.276138
# Iter 1361600, Minibatch Loss= 0.021356, Training Accuracy= 1.00000, Time= 0:12:42.171678
# Iter 1363200, Minibatch Loss= 0.080627, Training Accuracy= 1.00000, Time= 0:12:43.064742
# Iter 1364800, Minibatch Loss= 0.665085, Training Accuracy= 0.81250, Time= 0:12:43.960195
# Iter 1366400, Minibatch Loss= 0.477187, Training Accuracy= 0.87500, Time= 0:12:44.856203
# Iter 1368000, Minibatch Loss= 0.107715, Training Accuracy= 1.00000, Time= 0:12:45.750156
# Iter 1369600, Minibatch Loss= 0.021801, Training Accuracy= 1.00000, Time= 0:12:46.644125
# Iter 1371200, Minibatch Loss= 0.073630, Training Accuracy= 1.00000, Time= 0:12:47.538209
# Iter 1372800, Minibatch Loss= 0.023435, Training Accuracy= 1.00000, Time= 0:12:48.431323
# Iter 1374400, Minibatch Loss= 0.031570, Training Accuracy= 1.00000, Time= 0:12:49.326387
# Iter 1376000, Minibatch Loss= 0.124021, Training Accuracy= 0.93750, Time= 0:12:50.220320
# Iter 1377600, Minibatch Loss= 0.406919, Training Accuracy= 0.93750, Time= 0:12:51.116616
# Iter 1379200, Minibatch Loss= 0.004440, Training Accuracy= 1.00000, Time= 0:12:52.009629
# Iter 1380800, Minibatch Loss= 0.360547, Training Accuracy= 0.87500, Time= 0:12:52.903249
# Iter 1382400, Minibatch Loss= 0.573131, Training Accuracy= 0.93750, Time= 0:12:53.800230
# Iter 1384000, Minibatch Loss= 0.012722, Training Accuracy= 1.00000, Time= 0:12:54.695172
# Iter 1385600, Minibatch Loss= 0.015586, Training Accuracy= 1.00000, Time= 0:12:55.587642
# Iter 1387200, Minibatch Loss= 0.131779, Training Accuracy= 0.93750, Time= 0:12:56.482733
# Iter 1388800, Minibatch Loss= 0.424320, Training Accuracy= 0.93750, Time= 0:12:57.375479
# Iter 1390400, Minibatch Loss= 0.332729, Training Accuracy= 0.93750, Time= 0:12:58.273096
# Iter 1392000, Minibatch Loss= 0.056085, Training Accuracy= 1.00000, Time= 0:12:59.167085
# Iter 1393600, Minibatch Loss= 0.629832, Training Accuracy= 0.81250, Time= 0:13:00.059819
# Iter 1395200, Minibatch Loss= 0.828105, Training Accuracy= 0.87500, Time= 0:13:00.951888
# Iter 1396800, Minibatch Loss= 0.025833, Training Accuracy= 1.00000, Time= 0:13:01.845546
# Iter 1398400, Minibatch Loss= 0.749972, Training Accuracy= 0.87500, Time= 0:13:02.739215
# Iter 1400000, Minibatch Loss= 0.157190, Training Accuracy= 0.93750, Time= 0:13:03.634193
# Iter 1401600, Minibatch Loss= 0.052618, Training Accuracy= 1.00000, Time= 0:13:04.530372
# Iter 1403200, Minibatch Loss= 0.390028, Training Accuracy= 0.87500, Time= 0:13:05.425805
# Iter 1404800, Minibatch Loss= 0.319076, Training Accuracy= 0.93750, Time= 0:13:06.318493
# Iter 1406400, Minibatch Loss= 0.068707, Training Accuracy= 1.00000, Time= 0:13:07.210576
# Iter 1408000, Minibatch Loss= 0.330977, Training Accuracy= 0.93750, Time= 0:13:08.104148
# Iter 1409600, Minibatch Loss= 0.044227, Training Accuracy= 1.00000, Time= 0:13:08.998522
# Iter 1411200, Minibatch Loss= 0.610988, Training Accuracy= 0.81250, Time= 0:13:09.892148
# Iter 1412800, Minibatch Loss= 0.095626, Training Accuracy= 1.00000, Time= 0:13:10.785979
# Iter 1414400, Minibatch Loss= 0.028710, Training Accuracy= 1.00000, Time= 0:13:11.680101
# Iter 1416000, Minibatch Loss= 0.095475, Training Accuracy= 0.93750, Time= 0:13:12.574143
# Iter 1417600, Minibatch Loss= 0.196373, Training Accuracy= 0.93750, Time= 0:13:13.466468
# Iter 1419200, Minibatch Loss= 0.063498, Training Accuracy= 1.00000, Time= 0:13:14.359972
# Iter 1420800, Minibatch Loss= 0.462806, Training Accuracy= 0.93750, Time= 0:13:15.254695
# Iter 1422400, Minibatch Loss= 0.059602, Training Accuracy= 1.00000, Time= 0:13:16.149291
# Iter 1424000, Minibatch Loss= 0.098212, Training Accuracy= 0.93750, Time= 0:13:17.042125
# Iter 1425600, Minibatch Loss= 0.037997, Training Accuracy= 1.00000, Time= 0:13:17.934765
# Iter 1427200, Minibatch Loss= 0.536040, Training Accuracy= 0.81250, Time= 0:13:18.829302
# Iter 1428800, Minibatch Loss= 0.008527, Training Accuracy= 1.00000, Time= 0:13:19.723057
# Iter 1430400, Minibatch Loss= 0.378321, Training Accuracy= 0.87500, Time= 0:13:20.617855
# Iter 1432000, Minibatch Loss= 0.377781, Training Accuracy= 0.87500, Time= 0:13:21.511790
# Iter 1433600, Minibatch Loss= 0.127455, Training Accuracy= 1.00000, Time= 0:13:22.405869
# Iter 1435200, Minibatch Loss= 0.017490, Training Accuracy= 1.00000, Time= 0:13:23.300204
# Iter 1436800, Minibatch Loss= 0.043520, Training Accuracy= 1.00000, Time= 0:13:24.195350
# Iter 1438400, Minibatch Loss= 0.552263, Training Accuracy= 0.81250, Time= 0:13:25.089259
# Iter 1440000, Minibatch Loss= 0.700193, Training Accuracy= 0.87500, Time= 0:13:25.984151
# Iter 1441600, Minibatch Loss= 0.055262, Training Accuracy= 1.00000, Time= 0:13:26.888972
# Iter 1443200, Minibatch Loss= 0.108951, Training Accuracy= 1.00000, Time= 0:13:27.896445
# Iter 1444800, Minibatch Loss= 0.007488, Training Accuracy= 1.00000, Time= 0:13:28.890873
# Iter 1446400, Minibatch Loss= 0.041278, Training Accuracy= 1.00000, Time= 0:13:29.835773
# Iter 1448000, Minibatch Loss= 0.382687, Training Accuracy= 0.93750, Time= 0:13:30.729909
# Iter 1449600, Minibatch Loss= 0.352871, Training Accuracy= 0.93750, Time= 0:13:31.627525
# Iter 1451200, Minibatch Loss= 0.128009, Training Accuracy= 0.93750, Time= 0:13:32.522945
# Iter 1452800, Minibatch Loss= 0.366735, Training Accuracy= 0.93750, Time= 0:13:33.417536
# Iter 1454400, Minibatch Loss= 0.083571, Training Accuracy= 1.00000, Time= 0:13:34.311341
# Iter 1456000, Minibatch Loss= 0.098492, Training Accuracy= 1.00000, Time= 0:13:35.206181
# Iter 1457600, Minibatch Loss= 0.034239, Training Accuracy= 1.00000, Time= 0:13:36.101757
# Iter 1459200, Minibatch Loss= 0.105420, Training Accuracy= 0.93750, Time= 0:13:36.996183
# Iter 1460800, Minibatch Loss= 0.129833, Training Accuracy= 0.93750, Time= 0:13:37.890374
# Iter 1462400, Minibatch Loss= 0.140170, Training Accuracy= 0.93750, Time= 0:13:38.784292
# Iter 1464000, Minibatch Loss= 0.397010, Training Accuracy= 0.93750, Time= 0:13:39.677413
# Iter 1465600, Minibatch Loss= 0.123535, Training Accuracy= 0.93750, Time= 0:13:40.573290
# Iter 1467200, Minibatch Loss= 0.393975, Training Accuracy= 0.87500, Time= 0:13:41.478760
# Iter 1468800, Minibatch Loss= 0.225840, Training Accuracy= 0.87500, Time= 0:13:42.373132
# Iter 1470400, Minibatch Loss= 0.199388, Training Accuracy= 0.93750, Time= 0:13:43.275510
# Iter 1472000, Minibatch Loss= 1.030402, Training Accuracy= 0.87500, Time= 0:13:44.169974
# Iter 1473600, Minibatch Loss= 0.364679, Training Accuracy= 0.93750, Time= 0:13:45.063596
# Iter 1475200, Minibatch Loss= 0.130488, Training Accuracy= 0.93750, Time= 0:13:45.957740
# Iter 1476800, Minibatch Loss= 0.207414, Training Accuracy= 0.93750, Time= 0:13:46.851117
# Iter 1478400, Minibatch Loss= 0.061928, Training Accuracy= 1.00000, Time= 0:13:47.743413
# Iter 1480000, Minibatch Loss= 0.152406, Training Accuracy= 0.93750, Time= 0:13:48.636260
# Iter 1481600, Minibatch Loss= 0.009652, Training Accuracy= 1.00000, Time= 0:13:49.528676
# Iter 1483200, Minibatch Loss= 0.083738, Training Accuracy= 1.00000, Time= 0:13:50.422813
# Iter 1484800, Minibatch Loss= 0.571124, Training Accuracy= 0.87500, Time= 0:13:51.317202
# Iter 1486400, Minibatch Loss= 0.805636, Training Accuracy= 0.87500, Time= 0:13:52.211373
# Iter 1488000, Minibatch Loss= 0.009597, Training Accuracy= 1.00000, Time= 0:13:53.102774
# Iter 1489600, Minibatch Loss= 0.062243, Training Accuracy= 1.00000, Time= 0:13:53.996467
# Iter 1491200, Minibatch Loss= 0.492899, Training Accuracy= 0.87500, Time= 0:13:54.888975
# Iter 1492800, Minibatch Loss= 0.092902, Training Accuracy= 1.00000, Time= 0:13:55.785577
# Iter 1494400, Minibatch Loss= 0.067679, Training Accuracy= 0.93750, Time= 0:13:56.678880
# Iter 1496000, Minibatch Loss= 0.405028, Training Accuracy= 0.81250, Time= 0:13:57.572736
# Iter 1497600, Minibatch Loss= 0.034671, Training Accuracy= 1.00000, Time= 0:13:58.468714
# Iter 1499200, Minibatch Loss= 0.218651, Training Accuracy= 0.93750, Time= 0:13:59.364358
# Iter 1500800, Minibatch Loss= 0.082341, Training Accuracy= 0.93750, Time= 0:14:00.258488
# Iter 1502400, Minibatch Loss= 0.826647, Training Accuracy= 0.87500, Time= 0:14:01.151989
# Iter 1504000, Minibatch Loss= 0.026555, Training Accuracy= 1.00000, Time= 0:14:02.045875
# Iter 1505600, Minibatch Loss= 0.148394, Training Accuracy= 0.93750, Time= 0:14:02.942109
# Iter 1507200, Minibatch Loss= 0.059802, Training Accuracy= 1.00000, Time= 0:14:03.834629
# Iter 1508800, Minibatch Loss= 0.003495, Training Accuracy= 1.00000, Time= 0:14:04.727149
# Iter 1510400, Minibatch Loss= 0.141642, Training Accuracy= 0.93750, Time= 0:14:05.623166
# Iter 1512000, Minibatch Loss= 0.259633, Training Accuracy= 0.93750, Time= 0:14:06.517237
# Iter 1513600, Minibatch Loss= 0.481515, Training Accuracy= 0.87500, Time= 0:14:07.411196
# Iter 1515200, Minibatch Loss= 0.445718, Training Accuracy= 0.87500, Time= 0:14:08.304240
# Iter 1516800, Minibatch Loss= 1.113908, Training Accuracy= 0.87500, Time= 0:14:09.199013
# Iter 1518400, Minibatch Loss= 0.355822, Training Accuracy= 0.93750, Time= 0:14:10.095508
# Iter 1520000, Minibatch Loss= 0.207067, Training Accuracy= 0.93750, Time= 0:14:10.989551
# Iter 1521600, Minibatch Loss= 0.012728, Training Accuracy= 1.00000, Time= 0:14:11.883152
# Iter 1523200, Minibatch Loss= 0.130628, Training Accuracy= 1.00000, Time= 0:14:12.777833
# Iter 1524800, Minibatch Loss= 0.173370, Training Accuracy= 0.93750, Time= 0:14:13.671577
# Iter 1526400, Minibatch Loss= 0.016271, Training Accuracy= 1.00000, Time= 0:14:14.565154
# Iter 1528000, Minibatch Loss= 0.418775, Training Accuracy= 0.81250, Time= 0:14:15.459072
# Iter 1529600, Minibatch Loss= 0.022401, Training Accuracy= 1.00000, Time= 0:14:16.352179
# Iter 1531200, Minibatch Loss= 0.014347, Training Accuracy= 1.00000, Time= 0:14:17.245675
# Iter 1532800, Minibatch Loss= 0.070117, Training Accuracy= 1.00000, Time= 0:14:18.139371
# Iter 1534400, Minibatch Loss= 0.054765, Training Accuracy= 1.00000, Time= 0:14:19.032895
# Iter 1536000, Minibatch Loss= 0.135419, Training Accuracy= 0.93750, Time= 0:14:19.927964
# Iter 1537600, Minibatch Loss= 0.282247, Training Accuracy= 0.93750, Time= 0:14:20.820487
# Iter 1539200, Minibatch Loss= 0.049102, Training Accuracy= 1.00000, Time= 0:14:21.714119
# Iter 1540800, Minibatch Loss= 0.025771, Training Accuracy= 1.00000, Time= 0:14:22.606043
# Iter 1542400, Minibatch Loss= 0.059931, Training Accuracy= 1.00000, Time= 0:14:23.499725
# Iter 1544000, Minibatch Loss= 0.041839, Training Accuracy= 1.00000, Time= 0:14:24.394539
# Iter 1545600, Minibatch Loss= 0.106155, Training Accuracy= 0.93750, Time= 0:14:25.287615
# Iter 1547200, Minibatch Loss= 0.404726, Training Accuracy= 0.93750, Time= 0:14:26.182236
# Iter 1548800, Minibatch Loss= 0.241697, Training Accuracy= 0.93750, Time= 0:14:27.076447
# Iter 1550400, Minibatch Loss= 0.176950, Training Accuracy= 0.87500, Time= 0:14:27.972661
# Iter 1552000, Minibatch Loss= 0.045126, Training Accuracy= 1.00000, Time= 0:14:28.867555
# Iter 1553600, Minibatch Loss= 0.100464, Training Accuracy= 0.93750, Time= 0:14:29.760881
# Iter 1555200, Minibatch Loss= 0.377124, Training Accuracy= 0.87500, Time= 0:14:30.654573
# Iter 1556800, Minibatch Loss= 0.012157, Training Accuracy= 1.00000, Time= 0:14:31.546763
# Iter 1558400, Minibatch Loss= 0.081930, Training Accuracy= 1.00000, Time= 0:14:32.442230
# Iter 1560000, Minibatch Loss= 0.003619, Training Accuracy= 1.00000, Time= 0:14:33.385849
# Iter 1561600, Minibatch Loss= 0.090352, Training Accuracy= 0.93750, Time= 0:14:34.351932
# Iter 1563200, Minibatch Loss= 0.387524, Training Accuracy= 0.87500, Time= 0:14:35.242077
# Iter 1564800, Minibatch Loss= 0.309218, Training Accuracy= 0.87500, Time= 0:14:36.137234
# Iter 1566400, Minibatch Loss= 0.506416, Training Accuracy= 0.87500, Time= 0:14:37.030433
# Iter 1568000, Minibatch Loss= 0.236684, Training Accuracy= 0.93750, Time= 0:14:37.922816
# Iter 1569600, Minibatch Loss= 0.082352, Training Accuracy= 1.00000, Time= 0:14:38.818743
# Iter 1571200, Minibatch Loss= 0.096885, Training Accuracy= 1.00000, Time= 0:14:39.713436
# Iter 1572800, Minibatch Loss= 0.052213, Training Accuracy= 1.00000, Time= 0:14:40.606963
# Iter 1574400, Minibatch Loss= 0.326734, Training Accuracy= 0.93750, Time= 0:14:41.501114
# Iter 1576000, Minibatch Loss= 0.034480, Training Accuracy= 1.00000, Time= 0:14:42.394649
# Iter 1577600, Minibatch Loss= 0.071415, Training Accuracy= 1.00000, Time= 0:14:43.288676
# Iter 1579200, Minibatch Loss= 0.206900, Training Accuracy= 0.93750, Time= 0:14:44.184950
# Iter 1580800, Minibatch Loss= 0.338472, Training Accuracy= 0.93750, Time= 0:14:45.080195
# Iter 1582400, Minibatch Loss= 0.113520, Training Accuracy= 0.93750, Time= 0:14:45.973579
# Iter 1584000, Minibatch Loss= 0.653766, Training Accuracy= 0.87500, Time= 0:14:46.871271
# Iter 1585600, Minibatch Loss= 0.321684, Training Accuracy= 0.93750, Time= 0:14:47.764073
# Iter 1587200, Minibatch Loss= 0.125339, Training Accuracy= 0.93750, Time= 0:14:48.658197
# Iter 1588800, Minibatch Loss= 0.062502, Training Accuracy= 1.00000, Time= 0:14:49.551503
# Iter 1590400, Minibatch Loss= 0.123856, Training Accuracy= 0.93750, Time= 0:14:50.446921
# Iter 1592000, Minibatch Loss= 0.084318, Training Accuracy= 1.00000, Time= 0:14:51.342683
# Iter 1593600, Minibatch Loss= 0.060601, Training Accuracy= 1.00000, Time= 0:14:52.235300
# Iter 1595200, Minibatch Loss= 0.180206, Training Accuracy= 0.93750, Time= 0:14:53.128997
# Iter 1596800, Minibatch Loss= 0.184477, Training Accuracy= 0.93750, Time= 0:14:54.020589
# Iter 1598400, Minibatch Loss= 0.072400, Training Accuracy= 1.00000, Time= 0:14:54.915551
# Optimization Finished!
# Testing Accuracy: 0.857766

# %%
saver.save(sess, '../Model/NIN-Model-0xx')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
