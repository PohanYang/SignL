# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t0602.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (119995, 35)

# %%
# Parameters
learning_rate = 0.001
training_iters = 1000000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==8):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.613311, Training Accuracy= 0.00000
# Iter 3200, Minibatch Loss= 3.471443, Training Accuracy= 0.00000
# Iter 4800, Minibatch Loss= 3.542514, Training Accuracy= 0.00000
# Iter 6400, Minibatch Loss= 3.463799, Training Accuracy= 0.00000
# Iter 8000, Minibatch Loss= 3.515412, Training Accuracy= 0.06250
# Iter 9600, Minibatch Loss= 3.553138, Training Accuracy= 0.00000
# Iter 11200, Minibatch Loss= 3.531367, Training Accuracy= 0.00000
# Iter 12800, Minibatch Loss= 3.537904, Training Accuracy= 0.00000
# Iter 14400, Minibatch Loss= 3.481242, Training Accuracy= 0.12500
# Iter 16000, Minibatch Loss= 3.529578, Training Accuracy= 0.12500
# Iter 17600, Minibatch Loss= 3.340617, Training Accuracy= 0.18750
# Iter 19200, Minibatch Loss= 3.456173, Training Accuracy= 0.12500
# Iter 20800, Minibatch Loss= 3.502955, Training Accuracy= 0.12500
# Iter 22400, Minibatch Loss= 3.484143, Training Accuracy= 0.12500
# Iter 24000, Minibatch Loss= 3.526800, Training Accuracy= 0.00000
# Iter 25600, Minibatch Loss= 3.524964, Training Accuracy= 0.00000
# Iter 27200, Minibatch Loss= 3.492610, Training Accuracy= 0.00000
# Iter 28800, Minibatch Loss= 3.559790, Training Accuracy= 0.00000
# Iter 30400, Minibatch Loss= 3.486583, Training Accuracy= 0.00000
# Iter 32000, Minibatch Loss= 3.457362, Training Accuracy= 0.18750
# Iter 33600, Minibatch Loss= 3.473456, Training Accuracy= 0.18750
# Iter 35200, Minibatch Loss= 3.511313, Training Accuracy= 0.00000
# Iter 36800, Minibatch Loss= 3.530529, Training Accuracy= 0.12500
# Iter 38400, Minibatch Loss= 3.435134, Training Accuracy= 0.12500
# Iter 40000, Minibatch Loss= 3.497450, Training Accuracy= 0.18750
# Iter 41600, Minibatch Loss= 3.567163, Training Accuracy= 0.06250
# Iter 43200, Minibatch Loss= 3.456339, Training Accuracy= 0.12500
# Iter 44800, Minibatch Loss= 3.472270, Training Accuracy= 0.18750
# Iter 46400, Minibatch Loss= 3.387420, Training Accuracy= 0.06250
# Iter 48000, Minibatch Loss= 3.377748, Training Accuracy= 0.12500
# Iter 49600, Minibatch Loss= 3.430555, Training Accuracy= 0.12500
# Iter 51200, Minibatch Loss= 3.356420, Training Accuracy= 0.12500
# Iter 52800, Minibatch Loss= 3.363713, Training Accuracy= 0.18750
# Iter 54400, Minibatch Loss= 3.138934, Training Accuracy= 0.18750
# Iter 56000, Minibatch Loss= 3.260369, Training Accuracy= 0.18750
# Iter 57600, Minibatch Loss= 3.544338, Training Accuracy= 0.06250
# Iter 59200, Minibatch Loss= 3.302620, Training Accuracy= 0.12500
# Iter 60800, Minibatch Loss= 3.429450, Training Accuracy= 0.06250
# Iter 62400, Minibatch Loss= 3.355305, Training Accuracy= 0.12500
# Iter 64000, Minibatch Loss= 3.357783, Training Accuracy= 0.12500
# Iter 65600, Minibatch Loss= 3.364628, Training Accuracy= 0.06250
# Iter 67200, Minibatch Loss= 3.288757, Training Accuracy= 0.12500
# Iter 68800, Minibatch Loss= 3.339455, Training Accuracy= 0.06250
# Iter 70400, Minibatch Loss= 3.040141, Training Accuracy= 0.25000
# Iter 72000, Minibatch Loss= 3.433404, Training Accuracy= 0.06250
# Iter 73600, Minibatch Loss= 3.302559, Training Accuracy= 0.12500
# Iter 75200, Minibatch Loss= 3.353834, Training Accuracy= 0.00000
# Iter 76800, Minibatch Loss= 3.374293, Training Accuracy= 0.12500
# Iter 78400, Minibatch Loss= 3.317537, Training Accuracy= 0.12500
# Iter 80000, Minibatch Loss= 3.241483, Training Accuracy= 0.00000
# Iter 81600, Minibatch Loss= 3.230525, Training Accuracy= 0.06250
# Iter 83200, Minibatch Loss= 3.300488, Training Accuracy= 0.06250
# Iter 84800, Minibatch Loss= 3.178173, Training Accuracy= 0.12500
# Iter 86400, Minibatch Loss= 3.316700, Training Accuracy= 0.12500
# Iter 88000, Minibatch Loss= 3.027511, Training Accuracy= 0.12500
# Iter 89600, Minibatch Loss= 3.238381, Training Accuracy= 0.06250
# Iter 91200, Minibatch Loss= 2.933485, Training Accuracy= 0.18750
# Iter 92800, Minibatch Loss= 3.209998, Training Accuracy= 0.18750
# Iter 94400, Minibatch Loss= 3.236436, Training Accuracy= 0.00000
# Iter 96000, Minibatch Loss= 3.174810, Training Accuracy= 0.18750
# Iter 97600, Minibatch Loss= 2.767730, Training Accuracy= 0.31250
# Iter 99200, Minibatch Loss= 2.951641, Training Accuracy= 0.12500
# Iter 100800, Minibatch Loss= 2.640203, Training Accuracy= 0.25000
# Iter 102400, Minibatch Loss= 2.307687, Training Accuracy= 0.31250
# Iter 104000, Minibatch Loss= 2.886591, Training Accuracy= 0.12500
# Iter 105600, Minibatch Loss= 2.813244, Training Accuracy= 0.12500
# Iter 107200, Minibatch Loss= 2.817244, Training Accuracy= 0.12500
# Iter 108800, Minibatch Loss= 2.374861, Training Accuracy= 0.37500
# Iter 110400, Minibatch Loss= 2.954493, Training Accuracy= 0.25000
# Iter 112000, Minibatch Loss= 2.770146, Training Accuracy= 0.12500
# Iter 113600, Minibatch Loss= 2.755903, Training Accuracy= 0.18750
# Iter 115200, Minibatch Loss= 2.709260, Training Accuracy= 0.25000
# Iter 116800, Minibatch Loss= 2.945773, Training Accuracy= 0.12500
# Iter 118400, Minibatch Loss= 2.640243, Training Accuracy= 0.25000
# Iter 120000, Minibatch Loss= 2.460226, Training Accuracy= 0.37500
# Iter 121600, Minibatch Loss= 2.370150, Training Accuracy= 0.31250
# Iter 123200, Minibatch Loss= 2.705068, Training Accuracy= 0.18750
# Iter 124800, Minibatch Loss= 2.261768, Training Accuracy= 0.25000
# Iter 126400, Minibatch Loss= 2.620636, Training Accuracy= 0.31250
# Iter 128000, Minibatch Loss= 2.765131, Training Accuracy= 0.25000
# Iter 129600, Minibatch Loss= 2.153297, Training Accuracy= 0.37500
# Iter 131200, Minibatch Loss= 2.474063, Training Accuracy= 0.25000
# Iter 132800, Minibatch Loss= 2.100797, Training Accuracy= 0.12500
# Iter 134400, Minibatch Loss= 2.646829, Training Accuracy= 0.18750
# Iter 136000, Minibatch Loss= 2.550880, Training Accuracy= 0.06250
# Iter 137600, Minibatch Loss= 2.390833, Training Accuracy= 0.31250
# Iter 139200, Minibatch Loss= 2.029365, Training Accuracy= 0.50000
# Iter 140800, Minibatch Loss= 2.202369, Training Accuracy= 0.37500
# Iter 142400, Minibatch Loss= 2.269511, Training Accuracy= 0.25000
# Iter 144000, Minibatch Loss= 2.015520, Training Accuracy= 0.43750
# Iter 145600, Minibatch Loss= 2.972343, Training Accuracy= 0.06250
# Iter 147200, Minibatch Loss= 2.354256, Training Accuracy= 0.31250
# Iter 148800, Minibatch Loss= 1.814773, Training Accuracy= 0.43750
# Iter 150400, Minibatch Loss= 2.274690, Training Accuracy= 0.12500
# Iter 152000, Minibatch Loss= 1.943695, Training Accuracy= 0.37500
# Iter 153600, Minibatch Loss= 1.957179, Training Accuracy= 0.31250
# Iter 155200, Minibatch Loss= 1.851035, Training Accuracy= 0.43750
# Iter 156800, Minibatch Loss= 2.273998, Training Accuracy= 0.43750
# Iter 158400, Minibatch Loss= 1.749177, Training Accuracy= 0.50000
# Iter 160000, Minibatch Loss= 1.517856, Training Accuracy= 0.62500
# Iter 161600, Minibatch Loss= 2.487222, Training Accuracy= 0.25000
# Iter 163200, Minibatch Loss= 2.095339, Training Accuracy= 0.25000
# Iter 164800, Minibatch Loss= 2.841555, Training Accuracy= 0.31250
# Iter 166400, Minibatch Loss= 2.243164, Training Accuracy= 0.50000
# Iter 168000, Minibatch Loss= 2.280077, Training Accuracy= 0.50000
# Iter 169600, Minibatch Loss= 1.939923, Training Accuracy= 0.18750
# Iter 171200, Minibatch Loss= 1.845029, Training Accuracy= 0.43750
# Iter 172800, Minibatch Loss= 2.149609, Training Accuracy= 0.37500
# Iter 174400, Minibatch Loss= 1.523746, Training Accuracy= 0.62500
# Iter 176000, Minibatch Loss= 2.023709, Training Accuracy= 0.37500
# Iter 177600, Minibatch Loss= 1.494457, Training Accuracy= 0.50000
# Iter 179200, Minibatch Loss= 1.599793, Training Accuracy= 0.43750
# Iter 180800, Minibatch Loss= 1.754288, Training Accuracy= 0.37500
# Iter 182400, Minibatch Loss= 2.184703, Training Accuracy= 0.31250
# Iter 184000, Minibatch Loss= 2.153947, Training Accuracy= 0.37500
# Iter 185600, Minibatch Loss= 1.151418, Training Accuracy= 0.68750
# Iter 187200, Minibatch Loss= 1.578931, Training Accuracy= 0.68750
# Iter 188800, Minibatch Loss= 1.768627, Training Accuracy= 0.62500
# Iter 190400, Minibatch Loss= 2.255112, Training Accuracy= 0.56250
# Iter 192000, Minibatch Loss= 1.860697, Training Accuracy= 0.43750
# Iter 193600, Minibatch Loss= 1.327144, Training Accuracy= 0.75000
# Iter 195200, Minibatch Loss= 1.310935, Training Accuracy= 0.43750
# Iter 196800, Minibatch Loss= 2.182316, Training Accuracy= 0.25000
# Iter 198400, Minibatch Loss= 1.472841, Training Accuracy= 0.68750
# Iter 200000, Minibatch Loss= 1.974305, Training Accuracy= 0.37500
# Iter 201600, Minibatch Loss= 2.014654, Training Accuracy= 0.37500
# Iter 203200, Minibatch Loss= 1.824622, Training Accuracy= 0.56250
# Iter 204800, Minibatch Loss= 1.210144, Training Accuracy= 0.68750
# Iter 206400, Minibatch Loss= 1.468591, Training Accuracy= 0.56250
# Iter 208000, Minibatch Loss= 1.181294, Training Accuracy= 0.50000
# Iter 209600, Minibatch Loss= 1.760875, Training Accuracy= 0.56250
# Iter 211200, Minibatch Loss= 1.681116, Training Accuracy= 0.56250
# Iter 212800, Minibatch Loss= 1.280571, Training Accuracy= 0.68750
# Iter 214400, Minibatch Loss= 1.412629, Training Accuracy= 0.50000
# Iter 216000, Minibatch Loss= 1.958066, Training Accuracy= 0.31250
# Iter 217600, Minibatch Loss= 1.249445, Training Accuracy= 0.81250
# Iter 219200, Minibatch Loss= 1.265908, Training Accuracy= 0.62500
# Iter 220800, Minibatch Loss= 1.816993, Training Accuracy= 0.62500
# Iter 222400, Minibatch Loss= 1.667310, Training Accuracy= 0.56250
# Iter 224000, Minibatch Loss= 1.268381, Training Accuracy= 0.68750
# Iter 225600, Minibatch Loss= 1.550910, Training Accuracy= 0.62500
# Iter 227200, Minibatch Loss= 1.640417, Training Accuracy= 0.56250
# Iter 228800, Minibatch Loss= 1.840557, Training Accuracy= 0.56250
# Iter 230400, Minibatch Loss= 1.755415, Training Accuracy= 0.50000
# Iter 232000, Minibatch Loss= 1.673969, Training Accuracy= 0.56250
# Iter 233600, Minibatch Loss= 1.349366, Training Accuracy= 0.62500
# Iter 235200, Minibatch Loss= 1.435708, Training Accuracy= 0.68750
# Iter 236800, Minibatch Loss= 1.372339, Training Accuracy= 0.68750
# Iter 238400, Minibatch Loss= 1.304796, Training Accuracy= 0.75000
# Iter 240000, Minibatch Loss= 0.984721, Training Accuracy= 0.68750
# Iter 241600, Minibatch Loss= 0.875311, Training Accuracy= 0.68750
# Iter 243200, Minibatch Loss= 0.897966, Training Accuracy= 0.68750
# Iter 244800, Minibatch Loss= 1.063900, Training Accuracy= 0.62500
# Iter 246400, Minibatch Loss= 0.729342, Training Accuracy= 0.87500
# Iter 248000, Minibatch Loss= 0.844477, Training Accuracy= 0.75000
# Iter 249600, Minibatch Loss= 1.054428, Training Accuracy= 0.68750
# Iter 251200, Minibatch Loss= 1.092332, Training Accuracy= 0.68750
# Iter 252800, Minibatch Loss= 0.530419, Training Accuracy= 0.87500
# Iter 254400, Minibatch Loss= 0.933598, Training Accuracy= 0.68750
# Iter 256000, Minibatch Loss= 1.141837, Training Accuracy= 0.75000
# Iter 257600, Minibatch Loss= 1.104946, Training Accuracy= 0.68750
# Iter 259200, Minibatch Loss= 2.095403, Training Accuracy= 0.43750
# Iter 260800, Minibatch Loss= 0.779828, Training Accuracy= 0.75000
# Iter 262400, Minibatch Loss= 0.743952, Training Accuracy= 0.81250
# Iter 264000, Minibatch Loss= 1.075738, Training Accuracy= 0.75000
# Iter 265600, Minibatch Loss= 1.012679, Training Accuracy= 0.62500
# Iter 267200, Minibatch Loss= 0.759148, Training Accuracy= 0.75000
# Iter 268800, Minibatch Loss= 0.668550, Training Accuracy= 0.81250
# Iter 270400, Minibatch Loss= 1.061733, Training Accuracy= 0.75000
# Iter 272000, Minibatch Loss= 0.859738, Training Accuracy= 0.75000
# Iter 273600, Minibatch Loss= 1.228413, Training Accuracy= 0.68750
# Iter 275200, Minibatch Loss= 1.254601, Training Accuracy= 0.56250
# Iter 276800, Minibatch Loss= 0.643760, Training Accuracy= 0.81250
# Iter 278400, Minibatch Loss= 0.800513, Training Accuracy= 0.75000
# Iter 280000, Minibatch Loss= 1.585143, Training Accuracy= 0.81250
# Iter 281600, Minibatch Loss= 1.178699, Training Accuracy= 0.68750
# Iter 283200, Minibatch Loss= 1.359770, Training Accuracy= 0.56250
# Iter 284800, Minibatch Loss= 1.234335, Training Accuracy= 0.68750
# Iter 286400, Minibatch Loss= 1.103382, Training Accuracy= 0.56250
# Iter 288000, Minibatch Loss= 1.136077, Training Accuracy= 0.87500
# Iter 289600, Minibatch Loss= 1.061292, Training Accuracy= 0.75000
# Iter 291200, Minibatch Loss= 0.570587, Training Accuracy= 0.87500
# Iter 292800, Minibatch Loss= 0.861076, Training Accuracy= 0.87500
# Iter 294400, Minibatch Loss= 0.983509, Training Accuracy= 0.56250
# Iter 296000, Minibatch Loss= 0.869519, Training Accuracy= 0.75000
# Iter 297600, Minibatch Loss= 0.701492, Training Accuracy= 0.81250
# Iter 299200, Minibatch Loss= 1.645419, Training Accuracy= 0.43750
# Iter 300800, Minibatch Loss= 0.566543, Training Accuracy= 0.81250
# Iter 302400, Minibatch Loss= 0.642957, Training Accuracy= 0.68750
# Iter 304000, Minibatch Loss= 0.832232, Training Accuracy= 0.81250
# Iter 305600, Minibatch Loss= 1.058805, Training Accuracy= 0.75000
# Iter 307200, Minibatch Loss= 1.192902, Training Accuracy= 0.68750
# Iter 308800, Minibatch Loss= 0.920661, Training Accuracy= 0.87500
# Iter 310400, Minibatch Loss= 0.877273, Training Accuracy= 0.75000
# Iter 312000, Minibatch Loss= 1.141854, Training Accuracy= 0.81250
# Iter 313600, Minibatch Loss= 1.212014, Training Accuracy= 0.68750
# Iter 315200, Minibatch Loss= 0.702813, Training Accuracy= 0.68750
# Iter 316800, Minibatch Loss= 0.531335, Training Accuracy= 0.93750
# Iter 318400, Minibatch Loss= 0.499389, Training Accuracy= 0.81250
# Iter 320000, Minibatch Loss= 1.093821, Training Accuracy= 0.68750
# Iter 321600, Minibatch Loss= 0.894551, Training Accuracy= 0.62500
# Iter 323200, Minibatch Loss= 0.652081, Training Accuracy= 0.75000
# Iter 324800, Minibatch Loss= 0.290012, Training Accuracy= 0.93750
# Iter 326400, Minibatch Loss= 1.393114, Training Accuracy= 0.62500
# Iter 328000, Minibatch Loss= 1.143703, Training Accuracy= 0.68750
# Iter 329600, Minibatch Loss= 0.705883, Training Accuracy= 0.81250
# Iter 331200, Minibatch Loss= 0.559369, Training Accuracy= 0.87500
# Iter 332800, Minibatch Loss= 0.961964, Training Accuracy= 0.75000
# Iter 334400, Minibatch Loss= 1.358990, Training Accuracy= 0.50000
# Iter 336000, Minibatch Loss= 0.421907, Training Accuracy= 0.93750
# Iter 337600, Minibatch Loss= 1.189291, Training Accuracy= 0.87500
# Iter 339200, Minibatch Loss= 0.750165, Training Accuracy= 0.75000
# Iter 340800, Minibatch Loss= 0.650640, Training Accuracy= 0.81250
# Iter 342400, Minibatch Loss= 0.477450, Training Accuracy= 0.81250
# Iter 344000, Minibatch Loss= 0.688250, Training Accuracy= 0.93750
# Iter 345600, Minibatch Loss= 0.726030, Training Accuracy= 0.81250
# Iter 347200, Minibatch Loss= 0.624737, Training Accuracy= 0.81250
# Iter 348800, Minibatch Loss= 0.547124, Training Accuracy= 0.75000
# Iter 350400, Minibatch Loss= 0.851030, Training Accuracy= 0.87500
# Iter 352000, Minibatch Loss= 0.560768, Training Accuracy= 0.81250
# Iter 353600, Minibatch Loss= 2.222934, Training Accuracy= 0.50000
# Iter 355200, Minibatch Loss= 0.640704, Training Accuracy= 0.81250
# Iter 356800, Minibatch Loss= 0.421577, Training Accuracy= 0.93750
# Iter 358400, Minibatch Loss= 0.368647, Training Accuracy= 0.81250
# Iter 360000, Minibatch Loss= 0.681900, Training Accuracy= 0.81250
# Iter 361600, Minibatch Loss= 0.328886, Training Accuracy= 0.93750
# Iter 363200, Minibatch Loss= 0.608541, Training Accuracy= 0.87500
# Iter 364800, Minibatch Loss= 0.535921, Training Accuracy= 0.81250
# Iter 366400, Minibatch Loss= 1.652936, Training Accuracy= 0.62500
# Iter 368000, Minibatch Loss= 0.642985, Training Accuracy= 0.75000
# Iter 369600, Minibatch Loss= 0.324134, Training Accuracy= 0.87500
# Iter 371200, Minibatch Loss= 0.554970, Training Accuracy= 0.81250
# Iter 372800, Minibatch Loss= 0.491734, Training Accuracy= 0.87500
# Iter 374400, Minibatch Loss= 0.806443, Training Accuracy= 0.75000
# Iter 376000, Minibatch Loss= 1.227673, Training Accuracy= 0.75000
# Iter 377600, Minibatch Loss= 1.043071, Training Accuracy= 0.68750
# Iter 379200, Minibatch Loss= 0.355308, Training Accuracy= 0.93750
# Iter 380800, Minibatch Loss= 0.479668, Training Accuracy= 0.75000
# Iter 382400, Minibatch Loss= 1.257896, Training Accuracy= 0.62500
# Iter 384000, Minibatch Loss= 0.738227, Training Accuracy= 0.68750
# Iter 385600, Minibatch Loss= 0.732694, Training Accuracy= 0.75000
# Iter 387200, Minibatch Loss= 0.249412, Training Accuracy= 0.87500
# Iter 388800, Minibatch Loss= 1.210516, Training Accuracy= 0.68750
# Iter 390400, Minibatch Loss= 0.422813, Training Accuracy= 0.87500
# Iter 392000, Minibatch Loss= 0.254579, Training Accuracy= 0.93750
# Iter 393600, Minibatch Loss= 1.115331, Training Accuracy= 0.75000
# Iter 395200, Minibatch Loss= 0.418889, Training Accuracy= 0.87500
# Iter 396800, Minibatch Loss= 0.531553, Training Accuracy= 0.75000
# Iter 398400, Minibatch Loss= 1.460561, Training Accuracy= 0.56250
# Iter 400000, Minibatch Loss= 0.575662, Training Accuracy= 0.81250
# Iter 401600, Minibatch Loss= 1.154518, Training Accuracy= 0.68750
# Iter 403200, Minibatch Loss= 0.542334, Training Accuracy= 0.81250
# Iter 404800, Minibatch Loss= 0.819343, Training Accuracy= 0.75000
# Iter 406400, Minibatch Loss= 0.765560, Training Accuracy= 0.75000
# Iter 408000, Minibatch Loss= 0.848580, Training Accuracy= 0.87500
# Iter 409600, Minibatch Loss= 0.722342, Training Accuracy= 0.62500
# Iter 411200, Minibatch Loss= 0.490733, Training Accuracy= 0.81250
# Iter 412800, Minibatch Loss= 0.392611, Training Accuracy= 0.93750
# Iter 414400, Minibatch Loss= 0.924149, Training Accuracy= 0.81250
# Iter 416000, Minibatch Loss= 0.254070, Training Accuracy= 0.93750
# Iter 417600, Minibatch Loss= 0.188113, Training Accuracy= 0.87500
# Iter 419200, Minibatch Loss= 0.373961, Training Accuracy= 0.87500
# Iter 420800, Minibatch Loss= 0.377260, Training Accuracy= 0.87500
# Iter 422400, Minibatch Loss= 0.615959, Training Accuracy= 0.81250
# Iter 424000, Minibatch Loss= 0.452571, Training Accuracy= 0.81250
# Iter 425600, Minibatch Loss= 0.266695, Training Accuracy= 0.93750
# Iter 427200, Minibatch Loss= 0.828198, Training Accuracy= 0.62500
# Iter 428800, Minibatch Loss= 1.017886, Training Accuracy= 0.68750
# Iter 430400, Minibatch Loss= 0.453328, Training Accuracy= 0.87500
# Iter 432000, Minibatch Loss= 0.425506, Training Accuracy= 0.87500
# Iter 433600, Minibatch Loss= 0.717983, Training Accuracy= 0.87500
# Iter 435200, Minibatch Loss= 0.355808, Training Accuracy= 0.93750
# Iter 436800, Minibatch Loss= 0.435788, Training Accuracy= 0.81250
# Iter 438400, Minibatch Loss= 0.360228, Training Accuracy= 0.87500
# Iter 440000, Minibatch Loss= 0.571146, Training Accuracy= 0.87500
# Iter 441600, Minibatch Loss= 0.427725, Training Accuracy= 0.93750
# Iter 443200, Minibatch Loss= 0.987103, Training Accuracy= 0.87500
# Iter 444800, Minibatch Loss= 0.311409, Training Accuracy= 0.87500
# Iter 446400, Minibatch Loss= 0.323411, Training Accuracy= 0.87500
# Iter 448000, Minibatch Loss= 0.707428, Training Accuracy= 0.81250
# Iter 449600, Minibatch Loss= 0.589440, Training Accuracy= 0.81250
# Iter 451200, Minibatch Loss= 0.628030, Training Accuracy= 0.75000
# Iter 452800, Minibatch Loss= 0.471472, Training Accuracy= 0.81250
# Iter 454400, Minibatch Loss= 0.485019, Training Accuracy= 0.87500
# Iter 456000, Minibatch Loss= 1.077580, Training Accuracy= 0.81250
# Iter 457600, Minibatch Loss= 0.902243, Training Accuracy= 0.75000
# Iter 459200, Minibatch Loss= 0.729706, Training Accuracy= 0.68750
# Iter 460800, Minibatch Loss= 0.596886, Training Accuracy= 0.87500
# Iter 462400, Minibatch Loss= 0.230140, Training Accuracy= 0.93750
# Iter 464000, Minibatch Loss= 0.352158, Training Accuracy= 0.75000
# Iter 465600, Minibatch Loss= 0.372832, Training Accuracy= 0.81250
# Iter 467200, Minibatch Loss= 0.187478, Training Accuracy= 0.93750
# Iter 468800, Minibatch Loss= 0.466118, Training Accuracy= 0.87500
# Iter 470400, Minibatch Loss= 0.171309, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.983928, Training Accuracy= 0.87500
# Iter 473600, Minibatch Loss= 0.575170, Training Accuracy= 0.93750
# Iter 475200, Minibatch Loss= 0.714316, Training Accuracy= 0.87500
# Iter 476800, Minibatch Loss= 0.333058, Training Accuracy= 0.81250
# Iter 478400, Minibatch Loss= 0.858372, Training Accuracy= 0.75000
# Iter 480000, Minibatch Loss= 0.280902, Training Accuracy= 0.93750
# Iter 481600, Minibatch Loss= 1.341002, Training Accuracy= 0.68750
# Iter 483200, Minibatch Loss= 0.470378, Training Accuracy= 0.81250
# Iter 484800, Minibatch Loss= 0.142590, Training Accuracy= 1.00000
# Iter 486400, Minibatch Loss= 0.493532, Training Accuracy= 0.93750
# Iter 488000, Minibatch Loss= 1.225798, Training Accuracy= 0.56250
# Iter 489600, Minibatch Loss= 0.622747, Training Accuracy= 0.81250
# Iter 491200, Minibatch Loss= 0.840815, Training Accuracy= 0.81250
# Iter 492800, Minibatch Loss= 0.661052, Training Accuracy= 0.68750
# Iter 494400, Minibatch Loss= 0.314967, Training Accuracy= 0.87500
# Iter 496000, Minibatch Loss= 1.141979, Training Accuracy= 0.75000
# Iter 497600, Minibatch Loss= 0.425724, Training Accuracy= 0.81250
# Iter 499200, Minibatch Loss= 0.751424, Training Accuracy= 0.68750
# Iter 500800, Minibatch Loss= 0.409653, Training Accuracy= 0.93750
# Iter 502400, Minibatch Loss= 0.944363, Training Accuracy= 0.81250
# Iter 504000, Minibatch Loss= 0.226907, Training Accuracy= 0.87500
# Iter 505600, Minibatch Loss= 0.286748, Training Accuracy= 0.93750
# Iter 507200, Minibatch Loss= 0.063022, Training Accuracy= 1.00000
# Iter 508800, Minibatch Loss= 0.358445, Training Accuracy= 0.87500
# Iter 510400, Minibatch Loss= 0.494082, Training Accuracy= 0.87500
# Iter 512000, Minibatch Loss= 0.525660, Training Accuracy= 0.87500
# Iter 513600, Minibatch Loss= 0.814752, Training Accuracy= 0.87500
# Iter 515200, Minibatch Loss= 0.487560, Training Accuracy= 0.81250
# Iter 516800, Minibatch Loss= 0.438795, Training Accuracy= 0.93750
# Iter 518400, Minibatch Loss= 0.098869, Training Accuracy= 0.93750
# Iter 520000, Minibatch Loss= 0.246742, Training Accuracy= 0.93750
# Iter 521600, Minibatch Loss= 0.284810, Training Accuracy= 0.87500
# Iter 523200, Minibatch Loss= 0.579427, Training Accuracy= 0.81250
# Iter 524800, Minibatch Loss= 0.474283, Training Accuracy= 0.87500
# Iter 526400, Minibatch Loss= 0.079690, Training Accuracy= 1.00000
# Iter 528000, Minibatch Loss= 0.955297, Training Accuracy= 0.87500
# Iter 529600, Minibatch Loss= 0.795417, Training Accuracy= 0.81250
# Iter 531200, Minibatch Loss= 1.016136, Training Accuracy= 0.81250
# Iter 532800, Minibatch Loss= 0.131678, Training Accuracy= 1.00000
# Iter 534400, Minibatch Loss= 0.336587, Training Accuracy= 0.87500
# Iter 536000, Minibatch Loss= 0.326701, Training Accuracy= 0.81250
# Iter 537600, Minibatch Loss= 0.267786, Training Accuracy= 0.93750
# Iter 539200, Minibatch Loss= 0.459351, Training Accuracy= 0.93750
# Iter 540800, Minibatch Loss= 0.192434, Training Accuracy= 0.93750
# Iter 542400, Minibatch Loss= 0.719280, Training Accuracy= 0.87500
# Iter 544000, Minibatch Loss= 0.150255, Training Accuracy= 0.93750
# Iter 545600, Minibatch Loss= 0.476492, Training Accuracy= 0.93750
# Iter 547200, Minibatch Loss= 0.324551, Training Accuracy= 0.93750
# Iter 548800, Minibatch Loss= 0.992265, Training Accuracy= 0.87500
# Iter 550400, Minibatch Loss= 0.873473, Training Accuracy= 0.87500
# Iter 552000, Minibatch Loss= 0.439061, Training Accuracy= 0.93750
# Iter 553600, Minibatch Loss= 0.286903, Training Accuracy= 0.93750
# Iter 555200, Minibatch Loss= 0.380626, Training Accuracy= 0.81250
# Iter 556800, Minibatch Loss= 0.240881, Training Accuracy= 0.93750
# Iter 558400, Minibatch Loss= 1.171720, Training Accuracy= 0.87500
# Iter 560000, Minibatch Loss= 0.075291, Training Accuracy= 1.00000
# Iter 561600, Minibatch Loss= 0.587187, Training Accuracy= 0.87500
# Iter 563200, Minibatch Loss= 0.228547, Training Accuracy= 0.93750
# Iter 564800, Minibatch Loss= 0.399612, Training Accuracy= 0.81250
# Iter 566400, Minibatch Loss= 0.367169, Training Accuracy= 0.87500
# Iter 568000, Minibatch Loss= 0.052491, Training Accuracy= 1.00000
# Iter 569600, Minibatch Loss= 0.244804, Training Accuracy= 0.93750
# Iter 571200, Minibatch Loss= 0.041069, Training Accuracy= 1.00000
# Iter 572800, Minibatch Loss= 0.605825, Training Accuracy= 0.87500
# Iter 574400, Minibatch Loss= 0.472625, Training Accuracy= 0.87500
# Iter 576000, Minibatch Loss= 0.754925, Training Accuracy= 0.87500
# Iter 577600, Minibatch Loss= 0.325884, Training Accuracy= 0.87500
# Iter 579200, Minibatch Loss= 0.373469, Training Accuracy= 0.93750
# Iter 580800, Minibatch Loss= 0.485549, Training Accuracy= 0.81250
# Iter 582400, Minibatch Loss= 0.149396, Training Accuracy= 1.00000
# Iter 584000, Minibatch Loss= 0.191023, Training Accuracy= 0.93750
# Iter 585600, Minibatch Loss= 0.611648, Training Accuracy= 0.87500
# Iter 587200, Minibatch Loss= 0.617045, Training Accuracy= 0.81250
# Iter 588800, Minibatch Loss= 0.619224, Training Accuracy= 0.87500
# Iter 590400, Minibatch Loss= 0.410404, Training Accuracy= 0.87500
# Iter 592000, Minibatch Loss= 0.787401, Training Accuracy= 0.87500
# Iter 593600, Minibatch Loss= 0.523576, Training Accuracy= 0.87500
# Iter 595200, Minibatch Loss= 0.249533, Training Accuracy= 0.93750
# Iter 596800, Minibatch Loss= 0.269710, Training Accuracy= 0.87500
# Iter 598400, Minibatch Loss= 0.228735, Training Accuracy= 0.93750
# Iter 600000, Minibatch Loss= 0.277472, Training Accuracy= 1.00000
# Iter 601600, Minibatch Loss= 0.118942, Training Accuracy= 0.93750
# Iter 603200, Minibatch Loss= 0.072231, Training Accuracy= 1.00000
# Iter 604800, Minibatch Loss= 0.320969, Training Accuracy= 0.81250
# Iter 606400, Minibatch Loss= 0.210420, Training Accuracy= 0.93750
# Iter 608000, Minibatch Loss= 0.445714, Training Accuracy= 0.81250
# Iter 609600, Minibatch Loss= 0.114045, Training Accuracy= 1.00000
# Iter 611200, Minibatch Loss= 0.450684, Training Accuracy= 0.81250
# Iter 612800, Minibatch Loss= 0.121153, Training Accuracy= 0.93750
# Iter 614400, Minibatch Loss= 1.028055, Training Accuracy= 0.75000
# Iter 616000, Minibatch Loss= 0.287876, Training Accuracy= 0.93750
# Iter 617600, Minibatch Loss= 0.361948, Training Accuracy= 0.93750
# Iter 619200, Minibatch Loss= 0.400504, Training Accuracy= 0.87500
# Iter 620800, Minibatch Loss= 0.273161, Training Accuracy= 0.87500
# Iter 622400, Minibatch Loss= 0.251239, Training Accuracy= 0.93750
# Iter 624000, Minibatch Loss= 0.594588, Training Accuracy= 0.87500
# Iter 625600, Minibatch Loss= 0.061032, Training Accuracy= 1.00000
# Iter 627200, Minibatch Loss= 0.211952, Training Accuracy= 0.93750
# Iter 628800, Minibatch Loss= 0.258035, Training Accuracy= 0.87500
# Iter 630400, Minibatch Loss= 0.088773, Training Accuracy= 1.00000
# Iter 632000, Minibatch Loss= 0.031356, Training Accuracy= 1.00000
# Iter 633600, Minibatch Loss= 0.448588, Training Accuracy= 0.81250
# Iter 635200, Minibatch Loss= 0.454481, Training Accuracy= 0.75000
# Iter 636800, Minibatch Loss= 0.118041, Training Accuracy= 1.00000
# Iter 638400, Minibatch Loss= 0.099276, Training Accuracy= 1.00000
# Iter 640000, Minibatch Loss= 0.239458, Training Accuracy= 1.00000
# Iter 641600, Minibatch Loss= 0.886731, Training Accuracy= 0.87500
# Iter 643200, Minibatch Loss= 0.233292, Training Accuracy= 0.87500
# Iter 644800, Minibatch Loss= 0.261507, Training Accuracy= 0.87500
# Iter 646400, Minibatch Loss= 0.053805, Training Accuracy= 1.00000
# Iter 648000, Minibatch Loss= 0.239783, Training Accuracy= 0.93750
# Iter 649600, Minibatch Loss= 0.366336, Training Accuracy= 0.87500
# Iter 651200, Minibatch Loss= 0.106264, Training Accuracy= 0.93750
# Iter 652800, Minibatch Loss= 0.317658, Training Accuracy= 0.93750
# Iter 654400, Minibatch Loss= 0.602221, Training Accuracy= 0.81250
# Iter 656000, Minibatch Loss= 0.457543, Training Accuracy= 0.75000
# Iter 657600, Minibatch Loss= 0.924570, Training Accuracy= 0.75000
# Iter 659200, Minibatch Loss= 0.412471, Training Accuracy= 0.93750
# Iter 660800, Minibatch Loss= 0.355789, Training Accuracy= 0.93750
# Iter 662400, Minibatch Loss= 0.162883, Training Accuracy= 1.00000
# Iter 664000, Minibatch Loss= 0.304723, Training Accuracy= 0.93750
# Iter 665600, Minibatch Loss= 0.144707, Training Accuracy= 0.93750
# Iter 667200, Minibatch Loss= 0.449556, Training Accuracy= 0.93750
# Iter 668800, Minibatch Loss= 0.304971, Training Accuracy= 0.87500
# Iter 670400, Minibatch Loss= 0.411205, Training Accuracy= 0.87500
# Iter 672000, Minibatch Loss= 0.177861, Training Accuracy= 0.93750
# Iter 673600, Minibatch Loss= 0.047714, Training Accuracy= 1.00000
# Iter 675200, Minibatch Loss= 0.048287, Training Accuracy= 1.00000
# Iter 676800, Minibatch Loss= 0.088629, Training Accuracy= 1.00000
# Iter 678400, Minibatch Loss= 0.219729, Training Accuracy= 0.93750
# Iter 680000, Minibatch Loss= 0.056931, Training Accuracy= 1.00000
# Iter 681600, Minibatch Loss= 0.174286, Training Accuracy= 0.93750
# Iter 683200, Minibatch Loss= 0.190558, Training Accuracy= 1.00000
# Iter 684800, Minibatch Loss= 0.132275, Training Accuracy= 0.93750
# Iter 686400, Minibatch Loss= 0.072431, Training Accuracy= 1.00000
# Iter 688000, Minibatch Loss= 0.077515, Training Accuracy= 1.00000
# Iter 689600, Minibatch Loss= 0.630491, Training Accuracy= 0.93750
# Iter 691200, Minibatch Loss= 0.279405, Training Accuracy= 0.87500
# Iter 692800, Minibatch Loss= 0.352917, Training Accuracy= 0.93750
# Iter 694400, Minibatch Loss= 0.258767, Training Accuracy= 0.93750
# Iter 696000, Minibatch Loss= 0.376339, Training Accuracy= 0.93750
# Iter 697600, Minibatch Loss= 0.198328, Training Accuracy= 0.93750
# Iter 699200, Minibatch Loss= 0.211687, Training Accuracy= 0.87500
# Iter 700800, Minibatch Loss= 0.337719, Training Accuracy= 0.93750
# Iter 702400, Minibatch Loss= 0.150569, Training Accuracy= 0.93750
# Iter 704000, Minibatch Loss= 0.770761, Training Accuracy= 0.75000
# Iter 705600, Minibatch Loss= 0.087971, Training Accuracy= 1.00000
# Iter 707200, Minibatch Loss= 0.030340, Training Accuracy= 1.00000
# Iter 708800, Minibatch Loss= 0.149570, Training Accuracy= 0.93750
# Iter 710400, Minibatch Loss= 0.170270, Training Accuracy= 0.93750
# Iter 712000, Minibatch Loss= 0.407201, Training Accuracy= 0.87500
# Iter 713600, Minibatch Loss= 0.034356, Training Accuracy= 1.00000
# Iter 715200, Minibatch Loss= 0.067778, Training Accuracy= 1.00000
# Iter 716800, Minibatch Loss= 0.060807, Training Accuracy= 1.00000
# Iter 718400, Minibatch Loss= 0.133005, Training Accuracy= 1.00000
# Iter 720000, Minibatch Loss= 0.132250, Training Accuracy= 0.93750
# Iter 721600, Minibatch Loss= 0.240917, Training Accuracy= 0.93750
# Iter 723200, Minibatch Loss= 0.034074, Training Accuracy= 1.00000
# Iter 724800, Minibatch Loss= 0.185793, Training Accuracy= 0.93750
# Iter 726400, Minibatch Loss= 0.080842, Training Accuracy= 1.00000
# Iter 728000, Minibatch Loss= 0.261094, Training Accuracy= 0.93750
# Iter 729600, Minibatch Loss= 0.013697, Training Accuracy= 1.00000
# Iter 731200, Minibatch Loss= 0.157152, Training Accuracy= 1.00000
# Iter 732800, Minibatch Loss= 0.133518, Training Accuracy= 0.93750
# Iter 734400, Minibatch Loss= 0.020643, Training Accuracy= 1.00000
# Iter 736000, Minibatch Loss= 0.023240, Training Accuracy= 1.00000
# Iter 737600, Minibatch Loss= 0.465844, Training Accuracy= 0.93750
# Iter 739200, Minibatch Loss= 0.177847, Training Accuracy= 0.93750
# Iter 740800, Minibatch Loss= 0.046511, Training Accuracy= 1.00000
# Iter 742400, Minibatch Loss= 0.133157, Training Accuracy= 0.93750
# Iter 744000, Minibatch Loss= 0.149755, Training Accuracy= 0.87500
# Iter 745600, Minibatch Loss= 0.259080, Training Accuracy= 0.87500
# Iter 747200, Minibatch Loss= 0.070357, Training Accuracy= 1.00000
# Iter 748800, Minibatch Loss= 0.993016, Training Accuracy= 0.81250
# Iter 750400, Minibatch Loss= 0.406272, Training Accuracy= 0.93750
# Iter 752000, Minibatch Loss= 0.153665, Training Accuracy= 0.93750
# Iter 753600, Minibatch Loss= 0.029512, Training Accuracy= 1.00000
# Iter 755200, Minibatch Loss= 0.045324, Training Accuracy= 1.00000
# Iter 756800, Minibatch Loss= 0.020439, Training Accuracy= 1.00000
# Iter 758400, Minibatch Loss= 0.096457, Training Accuracy= 1.00000
# Iter 760000, Minibatch Loss= 0.116673, Training Accuracy= 0.93750
# Iter 761600, Minibatch Loss= 0.356133, Training Accuracy= 0.87500
# Iter 763200, Minibatch Loss= 0.774162, Training Accuracy= 0.75000
# Iter 764800, Minibatch Loss= 0.287510, Training Accuracy= 0.93750
# Iter 766400, Minibatch Loss= 0.070069, Training Accuracy= 1.00000
# Iter 768000, Minibatch Loss= 0.104348, Training Accuracy= 0.93750
# Iter 769600, Minibatch Loss= 0.105502, Training Accuracy= 0.93750
# Iter 771200, Minibatch Loss= 0.777037, Training Accuracy= 0.75000
# Iter 772800, Minibatch Loss= 0.025628, Training Accuracy= 1.00000
# Iter 774400, Minibatch Loss= 0.194624, Training Accuracy= 0.93750
# Iter 776000, Minibatch Loss= 0.221630, Training Accuracy= 0.93750
# Iter 777600, Minibatch Loss= 0.113843, Training Accuracy= 1.00000
# Iter 779200, Minibatch Loss= 0.365178, Training Accuracy= 0.93750
# Iter 780800, Minibatch Loss= 1.316093, Training Accuracy= 0.93750
# Iter 782400, Minibatch Loss= 0.019769, Training Accuracy= 1.00000
# Iter 784000, Minibatch Loss= 0.020062, Training Accuracy= 1.00000
# Iter 785600, Minibatch Loss= 0.411738, Training Accuracy= 0.93750
# Iter 787200, Minibatch Loss= 0.240270, Training Accuracy= 0.93750
# Iter 788800, Minibatch Loss= 0.179876, Training Accuracy= 0.93750
# Iter 790400, Minibatch Loss= 0.026889, Training Accuracy= 1.00000
# Iter 792000, Minibatch Loss= 0.049675, Training Accuracy= 1.00000
# Iter 793600, Minibatch Loss= 0.013486, Training Accuracy= 1.00000
# Iter 795200, Minibatch Loss= 0.395327, Training Accuracy= 0.81250
# Iter 796800, Minibatch Loss= 0.044683, Training Accuracy= 1.00000
# Iter 798400, Minibatch Loss= 0.086348, Training Accuracy= 0.93750
# Iter 800000, Minibatch Loss= 0.160221, Training Accuracy= 0.93750
# Iter 801600, Minibatch Loss= 0.123184, Training Accuracy= 0.93750
# Iter 803200, Minibatch Loss= 0.437576, Training Accuracy= 0.93750
# Iter 804800, Minibatch Loss= 0.083082, Training Accuracy= 1.00000
# Iter 806400, Minibatch Loss= 0.050212, Training Accuracy= 1.00000
# Iter 808000, Minibatch Loss= 0.457057, Training Accuracy= 0.87500
# Iter 809600, Minibatch Loss= 0.043923, Training Accuracy= 1.00000
# Iter 811200, Minibatch Loss= 0.050711, Training Accuracy= 1.00000
# Iter 812800, Minibatch Loss= 0.075615, Training Accuracy= 1.00000
# Iter 814400, Minibatch Loss= 0.009562, Training Accuracy= 1.00000
# Iter 816000, Minibatch Loss= 0.164518, Training Accuracy= 0.93750
# Iter 817600, Minibatch Loss= 0.262137, Training Accuracy= 0.93750
# Iter 819200, Minibatch Loss= 0.045602, Training Accuracy= 1.00000
# Iter 820800, Minibatch Loss= 0.345805, Training Accuracy= 0.87500
# Iter 822400, Minibatch Loss= 0.067239, Training Accuracy= 1.00000
# Iter 824000, Minibatch Loss= 0.528108, Training Accuracy= 0.87500
# Iter 825600, Minibatch Loss= 0.605480, Training Accuracy= 0.87500
# Iter 827200, Minibatch Loss= 0.074074, Training Accuracy= 1.00000
# Iter 828800, Minibatch Loss= 0.075393, Training Accuracy= 1.00000
# Iter 830400, Minibatch Loss= 0.164068, Training Accuracy= 0.93750
# Iter 832000, Minibatch Loss= 0.369363, Training Accuracy= 0.93750
# Iter 833600, Minibatch Loss= 0.009293, Training Accuracy= 1.00000
# Iter 835200, Minibatch Loss= 0.392480, Training Accuracy= 0.87500
# Iter 836800, Minibatch Loss= 0.040855, Training Accuracy= 1.00000
# Iter 838400, Minibatch Loss= 0.265460, Training Accuracy= 0.93750
# Iter 840000, Minibatch Loss= 0.602355, Training Accuracy= 0.87500
# Iter 841600, Minibatch Loss= 0.335762, Training Accuracy= 0.93750
# Iter 843200, Minibatch Loss= 0.377774, Training Accuracy= 0.93750
# Iter 844800, Minibatch Loss= 0.037873, Training Accuracy= 1.00000
# Iter 846400, Minibatch Loss= 0.191379, Training Accuracy= 0.87500
# Iter 848000, Minibatch Loss= 0.458887, Training Accuracy= 0.93750
# Iter 849600, Minibatch Loss= 0.287094, Training Accuracy= 0.93750
# Iter 851200, Minibatch Loss= 0.448218, Training Accuracy= 0.93750
# Iter 852800, Minibatch Loss= 0.147157, Training Accuracy= 1.00000
# Iter 854400, Minibatch Loss= 0.048181, Training Accuracy= 1.00000
# Iter 856000, Minibatch Loss= 0.316680, Training Accuracy= 0.93750
# Iter 857600, Minibatch Loss= 0.016849, Training Accuracy= 1.00000
# Iter 859200, Minibatch Loss= 0.263156, Training Accuracy= 0.93750
# Iter 860800, Minibatch Loss= 0.495994, Training Accuracy= 0.87500
# Iter 862400, Minibatch Loss= 0.136930, Training Accuracy= 0.93750
# Iter 864000, Minibatch Loss= 0.317515, Training Accuracy= 0.93750
# Iter 865600, Minibatch Loss= 0.028842, Training Accuracy= 1.00000
# Iter 867200, Minibatch Loss= 0.247689, Training Accuracy= 0.93750
# Iter 868800, Minibatch Loss= 0.096356, Training Accuracy= 1.00000
# Iter 870400, Minibatch Loss= 0.020713, Training Accuracy= 1.00000
# Iter 872000, Minibatch Loss= 0.190492, Training Accuracy= 0.93750
# Iter 873600, Minibatch Loss= 0.025938, Training Accuracy= 1.00000
# Iter 875200, Minibatch Loss= 0.129416, Training Accuracy= 0.93750
# Iter 876800, Minibatch Loss= 0.010504, Training Accuracy= 1.00000
# Iter 878400, Minibatch Loss= 0.070571, Training Accuracy= 0.93750
# Iter 880000, Minibatch Loss= 0.133157, Training Accuracy= 1.00000
# Iter 881600, Minibatch Loss= 0.087342, Training Accuracy= 0.93750
# Iter 883200, Minibatch Loss= 0.005232, Training Accuracy= 1.00000
# Iter 884800, Minibatch Loss= 0.316520, Training Accuracy= 0.93750
# Iter 886400, Minibatch Loss= 0.537777, Training Accuracy= 0.87500
# Iter 888000, Minibatch Loss= 0.082789, Training Accuracy= 1.00000
# Iter 889600, Minibatch Loss= 0.262951, Training Accuracy= 0.87500
# Iter 891200, Minibatch Loss= 0.026654, Training Accuracy= 1.00000
# Iter 892800, Minibatch Loss= 0.753679, Training Accuracy= 0.81250
# Iter 894400, Minibatch Loss= 0.028659, Training Accuracy= 1.00000
# Iter 896000, Minibatch Loss= 0.044174, Training Accuracy= 1.00000
# Iter 897600, Minibatch Loss= 0.029168, Training Accuracy= 1.00000
# Iter 899200, Minibatch Loss= 0.545038, Training Accuracy= 0.93750
# Iter 900800, Minibatch Loss= 0.029947, Training Accuracy= 1.00000
# Iter 902400, Minibatch Loss= 0.020871, Training Accuracy= 1.00000
# Iter 904000, Minibatch Loss= 0.054929, Training Accuracy= 1.00000
# Iter 905600, Minibatch Loss= 0.110043, Training Accuracy= 1.00000
# Iter 907200, Minibatch Loss= 0.381225, Training Accuracy= 0.93750
# Iter 908800, Minibatch Loss= 0.026961, Training Accuracy= 1.00000
# Iter 910400, Minibatch Loss= 0.021369, Training Accuracy= 1.00000
# Iter 912000, Minibatch Loss= 0.786480, Training Accuracy= 0.87500
# Iter 913600, Minibatch Loss= 0.206787, Training Accuracy= 0.93750
# Iter 915200, Minibatch Loss= 0.013414, Training Accuracy= 1.00000
# Iter 916800, Minibatch Loss= 0.076939, Training Accuracy= 1.00000
# Iter 918400, Minibatch Loss= 0.028180, Training Accuracy= 1.00000
# Iter 920000, Minibatch Loss= 0.012297, Training Accuracy= 1.00000
# Iter 921600, Minibatch Loss= 0.160036, Training Accuracy= 0.93750
# Iter 923200, Minibatch Loss= 0.091866, Training Accuracy= 1.00000
# Iter 924800, Minibatch Loss= 0.366190, Training Accuracy= 0.87500
# Iter 926400, Minibatch Loss= 0.016077, Training Accuracy= 1.00000
# Iter 928000, Minibatch Loss= 0.344961, Training Accuracy= 0.93750
# Iter 929600, Minibatch Loss= 0.017405, Training Accuracy= 1.00000
# Iter 931200, Minibatch Loss= 0.135931, Training Accuracy= 0.93750
# Iter 932800, Minibatch Loss= 0.257015, Training Accuracy= 0.93750
# Iter 934400, Minibatch Loss= 0.225454, Training Accuracy= 0.87500
# Iter 936000, Minibatch Loss= 0.026889, Training Accuracy= 1.00000
# Iter 937600, Minibatch Loss= 0.090060, Training Accuracy= 0.93750
# Iter 939200, Minibatch Loss= 0.020474, Training Accuracy= 1.00000
# Iter 940800, Minibatch Loss= 0.860908, Training Accuracy= 0.81250
# Iter 942400, Minibatch Loss= 0.052167, Training Accuracy= 1.00000
# Iter 944000, Minibatch Loss= 0.651513, Training Accuracy= 0.81250
# Iter 945600, Minibatch Loss= 0.022739, Training Accuracy= 1.00000
# Iter 947200, Minibatch Loss= 0.043017, Training Accuracy= 1.00000
# Iter 948800, Minibatch Loss= 0.218502, Training Accuracy= 0.87500
# Iter 950400, Minibatch Loss= 0.040088, Training Accuracy= 1.00000
# Iter 952000, Minibatch Loss= 0.693645, Training Accuracy= 0.81250
# Iter 953600, Minibatch Loss= 1.094061, Training Accuracy= 0.87500
# Iter 955200, Minibatch Loss= 0.211180, Training Accuracy= 0.93750
# Iter 956800, Minibatch Loss= 0.175263, Training Accuracy= 0.93750
# Iter 958400, Minibatch Loss= 0.251110, Training Accuracy= 0.93750
# Iter 960000, Minibatch Loss= 0.044607, Training Accuracy= 1.00000
# Iter 961600, Minibatch Loss= 0.089503, Training Accuracy= 0.93750
# Iter 963200, Minibatch Loss= 0.100553, Training Accuracy= 1.00000
# Iter 964800, Minibatch Loss= 0.005657, Training Accuracy= 1.00000
# Iter 966400, Minibatch Loss= 0.067791, Training Accuracy= 1.00000
# Iter 968000, Minibatch Loss= 0.039344, Training Accuracy= 1.00000
# Iter 969600, Minibatch Loss= 0.034863, Training Accuracy= 1.00000
# Iter 971200, Minibatch Loss= 0.038493, Training Accuracy= 1.00000
# Iter 972800, Minibatch Loss= 0.292601, Training Accuracy= 0.93750
# Iter 974400, Minibatch Loss= 0.033979, Training Accuracy= 1.00000
# Iter 976000, Minibatch Loss= 0.055945, Training Accuracy= 1.00000
# Iter 977600, Minibatch Loss= 0.036239, Training Accuracy= 1.00000
# Iter 979200, Minibatch Loss= 0.425113, Training Accuracy= 0.93750
# Iter 980800, Minibatch Loss= 0.341083, Training Accuracy= 0.87500
# Iter 982400, Minibatch Loss= 0.020923, Training Accuracy= 1.00000
# Iter 984000, Minibatch Loss= 0.376471, Training Accuracy= 0.87500
# Iter 985600, Minibatch Loss= 0.300822, Training Accuracy= 0.87500
# Iter 987200, Minibatch Loss= 0.328364, Training Accuracy= 0.87500
# Iter 988800, Minibatch Loss= 0.183234, Training Accuracy= 0.87500
# Iter 990400, Minibatch Loss= 0.038964, Training Accuracy= 1.00000
# Iter 992000, Minibatch Loss= 0.018576, Training Accuracy= 1.00000
# Iter 993600, Minibatch Loss= 0.048872, Training Accuracy= 1.00000
# Iter 995200, Minibatch Loss= 0.212656, Training Accuracy= 0.93750
# Iter 996800, Minibatch Loss= 0.335588, Training Accuracy= 0.87500
# Iter 998400, Minibatch Loss= 0.475477, Training Accuracy= 0.93750
# Optimization Finished!
# Testing Accuracy: 0.84089

# %%
saver.save(sess, '../Model/NIN-Model-0602')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
