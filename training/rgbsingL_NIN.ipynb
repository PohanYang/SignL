# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t0630.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (181645, 53)

# %%
# Parameters
learning_rate = 0.001
training_iters = 1600000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==8):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.943949, Training Accuracy= 0.00000
# Iter 3200, Minibatch Loss= 4.072145, Training Accuracy= 0.00000
# Iter 4800, Minibatch Loss= 3.974617, Training Accuracy= 0.00000
# Iter 6400, Minibatch Loss= 3.974388, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.968690, Training Accuracy= 0.00000
# Iter 9600, Minibatch Loss= 3.940203, Training Accuracy= 0.06250
# Iter 11200, Minibatch Loss= 3.871490, Training Accuracy= 0.12500
# Iter 12800, Minibatch Loss= 3.989820, Training Accuracy= 0.00000
# Iter 14400, Minibatch Loss= 3.922819, Training Accuracy= 0.06250
# Iter 16000, Minibatch Loss= 3.941694, Training Accuracy= 0.06250
# Iter 17600, Minibatch Loss= 3.960812, Training Accuracy= 0.00000
# Iter 19200, Minibatch Loss= 3.910865, Training Accuracy= 0.12500
# Iter 20800, Minibatch Loss= 3.925848, Training Accuracy= 0.06250
# Iter 22400, Minibatch Loss= 3.938528, Training Accuracy= 0.06250
# Iter 24000, Minibatch Loss= 3.933536, Training Accuracy= 0.06250
# Iter 25600, Minibatch Loss= 3.942379, Training Accuracy= 0.00000
# Iter 27200, Minibatch Loss= 3.955967, Training Accuracy= 0.00000
# Iter 28800, Minibatch Loss= 3.889087, Training Accuracy= 0.06250
# Iter 30400, Minibatch Loss= 3.926853, Training Accuracy= 0.06250
# Iter 32000, Minibatch Loss= 3.912346, Training Accuracy= 0.12500
# Iter 33600, Minibatch Loss= 3.822520, Training Accuracy= 0.12500
# Iter 35200, Minibatch Loss= 3.913893, Training Accuracy= 0.00000
# Iter 36800, Minibatch Loss= 3.950128, Training Accuracy= 0.00000
# Iter 38400, Minibatch Loss= 3.928238, Training Accuracy= 0.06250
# Iter 40000, Minibatch Loss= 3.946122, Training Accuracy= 0.00000
# Iter 41600, Minibatch Loss= 3.957367, Training Accuracy= 0.00000
# Iter 43200, Minibatch Loss= 3.993404, Training Accuracy= 0.00000
# Iter 44800, Minibatch Loss= 3.934395, Training Accuracy= 0.00000
# Iter 46400, Minibatch Loss= 3.948599, Training Accuracy= 0.06250
# Iter 48000, Minibatch Loss= 3.987244, Training Accuracy= 0.00000
# Iter 49600, Minibatch Loss= 3.916310, Training Accuracy= 0.00000
# Iter 51200, Minibatch Loss= 3.909173, Training Accuracy= 0.06250
# Iter 52800, Minibatch Loss= 3.921840, Training Accuracy= 0.06250
# Iter 54400, Minibatch Loss= 3.838635, Training Accuracy= 0.06250
# Iter 56000, Minibatch Loss= 3.966118, Training Accuracy= 0.00000
# Iter 57600, Minibatch Loss= 3.991552, Training Accuracy= 0.00000
# Iter 59200, Minibatch Loss= 3.920692, Training Accuracy= 0.00000
# Iter 60800, Minibatch Loss= 3.902592, Training Accuracy= 0.06250
# Iter 62400, Minibatch Loss= 3.928484, Training Accuracy= 0.00000
# Iter 64000, Minibatch Loss= 3.927940, Training Accuracy= 0.00000
# Iter 65600, Minibatch Loss= 3.927898, Training Accuracy= 0.06250
# Iter 67200, Minibatch Loss= 3.945549, Training Accuracy= 0.00000
# Iter 68800, Minibatch Loss= 3.887565, Training Accuracy= 0.12500
# Iter 70400, Minibatch Loss= 3.905678, Training Accuracy= 0.00000
# Iter 72000, Minibatch Loss= 3.975000, Training Accuracy= 0.00000
# Iter 73600, Minibatch Loss= 3.983032, Training Accuracy= 0.00000
# Iter 75200, Minibatch Loss= 3.912586, Training Accuracy= 0.00000
# Iter 76800, Minibatch Loss= 3.868780, Training Accuracy= 0.12500
# Iter 78400, Minibatch Loss= 3.835791, Training Accuracy= 0.06250
# Iter 80000, Minibatch Loss= 3.950311, Training Accuracy= 0.00000
# Iter 81600, Minibatch Loss= 3.924601, Training Accuracy= 0.06250
# Iter 83200, Minibatch Loss= 3.937134, Training Accuracy= 0.00000
# Iter 84800, Minibatch Loss= 3.951790, Training Accuracy= 0.00000
# Iter 86400, Minibatch Loss= 3.895536, Training Accuracy= 0.12500
# Iter 88000, Minibatch Loss= 3.912578, Training Accuracy= 0.00000
# Iter 89600, Minibatch Loss= 3.865100, Training Accuracy= 0.12500
# Iter 91200, Minibatch Loss= 3.907936, Training Accuracy= 0.00000
# Iter 92800, Minibatch Loss= 3.816801, Training Accuracy= 0.06250
# Iter 94400, Minibatch Loss= 3.764526, Training Accuracy= 0.18750
# Iter 96000, Minibatch Loss= 3.804226, Training Accuracy= 0.06250
# Iter 97600, Minibatch Loss= 3.866349, Training Accuracy= 0.00000
# Iter 99200, Minibatch Loss= 3.900050, Training Accuracy= 0.12500
# Iter 100800, Minibatch Loss= 3.850377, Training Accuracy= 0.06250
# Iter 102400, Minibatch Loss= 3.859897, Training Accuracy= 0.12500
# Iter 104000, Minibatch Loss= 3.869859, Training Accuracy= 0.00000
# Iter 105600, Minibatch Loss= 3.835261, Training Accuracy= 0.06250
# Iter 107200, Minibatch Loss= 3.899566, Training Accuracy= 0.06250
# Iter 108800, Minibatch Loss= 3.797349, Training Accuracy= 0.12500
# Iter 110400, Minibatch Loss= 3.843324, Training Accuracy= 0.12500
# Iter 112000, Minibatch Loss= 3.810309, Training Accuracy= 0.00000
# Iter 113600, Minibatch Loss= 3.780785, Training Accuracy= 0.12500
# Iter 115200, Minibatch Loss= 3.790608, Training Accuracy= 0.06250
# Iter 116800, Minibatch Loss= 3.740706, Training Accuracy= 0.18750
# Iter 118400, Minibatch Loss= 3.807308, Training Accuracy= 0.06250
# Iter 120000, Minibatch Loss= 3.582982, Training Accuracy= 0.12500
# Iter 121600, Minibatch Loss= 3.659717, Training Accuracy= 0.25000
# Iter 123200, Minibatch Loss= 3.551077, Training Accuracy= 0.50000
# Iter 124800, Minibatch Loss= 3.676463, Training Accuracy= 0.06250
# Iter 126400, Minibatch Loss= 3.652997, Training Accuracy= 0.06250
# Iter 128000, Minibatch Loss= 3.544456, Training Accuracy= 0.18750
# Iter 129600, Minibatch Loss= 3.849226, Training Accuracy= 0.06250
# Iter 131200, Minibatch Loss= 3.661994, Training Accuracy= 0.06250
# Iter 132800, Minibatch Loss= 3.526185, Training Accuracy= 0.06250
# Iter 134400, Minibatch Loss= 3.697785, Training Accuracy= 0.12500
# Iter 136000, Minibatch Loss= 3.850247, Training Accuracy= 0.00000
# Iter 137600, Minibatch Loss= 3.551043, Training Accuracy= 0.12500
# Iter 139200, Minibatch Loss= 3.539759, Training Accuracy= 0.06250
# Iter 140800, Minibatch Loss= 3.627814, Training Accuracy= 0.12500
# Iter 142400, Minibatch Loss= 3.552775, Training Accuracy= 0.12500
# Iter 144000, Minibatch Loss= 3.605409, Training Accuracy= 0.06250
# Iter 145600, Minibatch Loss= 3.645306, Training Accuracy= 0.06250
# Iter 147200, Minibatch Loss= 3.348918, Training Accuracy= 0.18750
# Iter 148800, Minibatch Loss= 4.014547, Training Accuracy= 0.12500
# Iter 150400, Minibatch Loss= 3.371576, Training Accuracy= 0.25000
# Iter 152000, Minibatch Loss= 3.477586, Training Accuracy= 0.12500
# Iter 153600, Minibatch Loss= 3.545071, Training Accuracy= 0.06250
# Iter 155200, Minibatch Loss= 3.712050, Training Accuracy= 0.12500
# Iter 156800, Minibatch Loss= 3.966002, Training Accuracy= 0.12500
# Iter 158400, Minibatch Loss= 3.267337, Training Accuracy= 0.12500
# Iter 160000, Minibatch Loss= 3.371410, Training Accuracy= 0.31250
# Iter 161600, Minibatch Loss= 3.672305, Training Accuracy= 0.18750
# Iter 163200, Minibatch Loss= 3.738460, Training Accuracy= 0.06250
# Iter 164800, Minibatch Loss= 3.270485, Training Accuracy= 0.25000
# Iter 166400, Minibatch Loss= 3.761984, Training Accuracy= 0.12500
# Iter 168000, Minibatch Loss= 3.029527, Training Accuracy= 0.25000
# Iter 169600, Minibatch Loss= 3.095379, Training Accuracy= 0.25000
# Iter 171200, Minibatch Loss= 3.339680, Training Accuracy= 0.18750
# Iter 172800, Minibatch Loss= 3.552406, Training Accuracy= 0.12500
# Iter 174400, Minibatch Loss= 3.225850, Training Accuracy= 0.06250
# Iter 176000, Minibatch Loss= 3.429909, Training Accuracy= 0.18750
# Iter 177600, Minibatch Loss= 3.370030, Training Accuracy= 0.12500
# Iter 179200, Minibatch Loss= 3.251001, Training Accuracy= 0.12500
# Iter 180800, Minibatch Loss= 3.411866, Training Accuracy= 0.18750
# Iter 182400, Minibatch Loss= 2.829112, Training Accuracy= 0.37500
# Iter 184000, Minibatch Loss= 2.207401, Training Accuracy= 0.50000
# Iter 185600, Minibatch Loss= 3.160084, Training Accuracy= 0.25000
# Iter 187200, Minibatch Loss= 2.626908, Training Accuracy= 0.12500
# Iter 188800, Minibatch Loss= 2.933079, Training Accuracy= 0.25000
# Iter 190400, Minibatch Loss= 2.739654, Training Accuracy= 0.31250
# Iter 192000, Minibatch Loss= 2.597650, Training Accuracy= 0.25000
# Iter 193600, Minibatch Loss= 2.982579, Training Accuracy= 0.37500
# Iter 195200, Minibatch Loss= 3.287005, Training Accuracy= 0.25000
# Iter 196800, Minibatch Loss= 3.167359, Training Accuracy= 0.06250
# Iter 198400, Minibatch Loss= 2.597906, Training Accuracy= 0.43750
# Iter 200000, Minibatch Loss= 2.677212, Training Accuracy= 0.25000
# Iter 201600, Minibatch Loss= 2.750561, Training Accuracy= 0.31250
# Iter 203200, Minibatch Loss= 2.505935, Training Accuracy= 0.37500
# Iter 204800, Minibatch Loss= 2.670871, Training Accuracy= 0.18750
# Iter 206400, Minibatch Loss= 2.928010, Training Accuracy= 0.25000
# Iter 208000, Minibatch Loss= 2.705458, Training Accuracy= 0.31250
# Iter 209600, Minibatch Loss= 3.010653, Training Accuracy= 0.18750
# Iter 211200, Minibatch Loss= 2.667664, Training Accuracy= 0.31250
# Iter 212800, Minibatch Loss= 2.842883, Training Accuracy= 0.12500
# Iter 214400, Minibatch Loss= 2.577093, Training Accuracy= 0.37500
# Iter 216000, Minibatch Loss= 2.713087, Training Accuracy= 0.25000
# Iter 217600, Minibatch Loss= 2.536071, Training Accuracy= 0.18750
# Iter 219200, Minibatch Loss= 3.110173, Training Accuracy= 0.06250
# Iter 220800, Minibatch Loss= 2.468399, Training Accuracy= 0.43750
# Iter 222400, Minibatch Loss= 2.378996, Training Accuracy= 0.31250
# Iter 224000, Minibatch Loss= 3.068748, Training Accuracy= 0.18750
# Iter 225600, Minibatch Loss= 3.215861, Training Accuracy= 0.25000
# Iter 227200, Minibatch Loss= 3.073617, Training Accuracy= 0.18750
# Iter 228800, Minibatch Loss= 2.661500, Training Accuracy= 0.31250
# Iter 230400, Minibatch Loss= 2.590226, Training Accuracy= 0.18750
# Iter 232000, Minibatch Loss= 2.717666, Training Accuracy= 0.12500
# Iter 233600, Minibatch Loss= 1.978113, Training Accuracy= 0.50000
# Iter 235200, Minibatch Loss= 2.170238, Training Accuracy= 0.50000
# Iter 236800, Minibatch Loss= 2.874041, Training Accuracy= 0.06250
# Iter 238400, Minibatch Loss= 2.715179, Training Accuracy= 0.25000
# Iter 240000, Minibatch Loss= 2.754038, Training Accuracy= 0.43750
# Iter 241600, Minibatch Loss= 2.955806, Training Accuracy= 0.25000
# Iter 243200, Minibatch Loss= 2.809974, Training Accuracy= 0.18750
# Iter 244800, Minibatch Loss= 2.672522, Training Accuracy= 0.18750
# Iter 246400, Minibatch Loss= 2.683090, Training Accuracy= 0.25000
# Iter 248000, Minibatch Loss= 1.965047, Training Accuracy= 0.50000
# Iter 249600, Minibatch Loss= 2.372779, Training Accuracy= 0.37500
# Iter 251200, Minibatch Loss= 2.234263, Training Accuracy= 0.06250
# Iter 252800, Minibatch Loss= 2.539922, Training Accuracy= 0.43750
# Iter 254400, Minibatch Loss= 1.761875, Training Accuracy= 0.50000
# Iter 256000, Minibatch Loss= 2.133493, Training Accuracy= 0.25000
# Iter 257600, Minibatch Loss= 2.178771, Training Accuracy= 0.43750
# Iter 259200, Minibatch Loss= 2.308191, Training Accuracy= 0.25000
# Iter 260800, Minibatch Loss= 2.234200, Training Accuracy= 0.31250
# Iter 262400, Minibatch Loss= 2.343824, Training Accuracy= 0.25000
# Iter 264000, Minibatch Loss= 2.178629, Training Accuracy= 0.25000
# Iter 265600, Minibatch Loss= 1.989417, Training Accuracy= 0.37500
# Iter 267200, Minibatch Loss= 2.725506, Training Accuracy= 0.31250
# Iter 268800, Minibatch Loss= 2.235700, Training Accuracy= 0.37500
# Iter 270400, Minibatch Loss= 2.279766, Training Accuracy= 0.31250
# Iter 272000, Minibatch Loss= 2.288330, Training Accuracy= 0.31250
# Iter 273600, Minibatch Loss= 2.001616, Training Accuracy= 0.31250
# Iter 275200, Minibatch Loss= 2.500382, Training Accuracy= 0.31250
# Iter 276800, Minibatch Loss= 1.944636, Training Accuracy= 0.43750
# Iter 278400, Minibatch Loss= 2.555307, Training Accuracy= 0.18750
# Iter 280000, Minibatch Loss= 1.639151, Training Accuracy= 0.50000
# Iter 281600, Minibatch Loss= 2.607839, Training Accuracy= 0.37500
# Iter 283200, Minibatch Loss= 1.791523, Training Accuracy= 0.37500
# Iter 284800, Minibatch Loss= 1.662899, Training Accuracy= 0.56250
# Iter 286400, Minibatch Loss= 2.226567, Training Accuracy= 0.37500
# Iter 288000, Minibatch Loss= 2.455511, Training Accuracy= 0.37500
# Iter 289600, Minibatch Loss= 1.995460, Training Accuracy= 0.37500
# Iter 291200, Minibatch Loss= 1.978641, Training Accuracy= 0.43750
# Iter 292800, Minibatch Loss= 2.009472, Training Accuracy= 0.56250
# Iter 294400, Minibatch Loss= 2.248910, Training Accuracy= 0.25000
# Iter 296000, Minibatch Loss= 2.164412, Training Accuracy= 0.43750
# Iter 297600, Minibatch Loss= 1.867753, Training Accuracy= 0.50000
# Iter 299200, Minibatch Loss= 2.346307, Training Accuracy= 0.43750
# Iter 300800, Minibatch Loss= 2.000215, Training Accuracy= 0.37500
# Iter 302400, Minibatch Loss= 1.853338, Training Accuracy= 0.50000
# Iter 304000, Minibatch Loss= 2.276812, Training Accuracy= 0.25000
# Iter 305600, Minibatch Loss= 1.203585, Training Accuracy= 0.68750
# Iter 307200, Minibatch Loss= 1.685614, Training Accuracy= 0.50000
# Iter 308800, Minibatch Loss= 2.191013, Training Accuracy= 0.43750
# Iter 310400, Minibatch Loss= 3.036902, Training Accuracy= 0.25000
# Iter 312000, Minibatch Loss= 1.835146, Training Accuracy= 0.25000
# Iter 313600, Minibatch Loss= 1.800370, Training Accuracy= 0.31250
# Iter 315200, Minibatch Loss= 2.010537, Training Accuracy= 0.43750
# Iter 316800, Minibatch Loss= 1.815315, Training Accuracy= 0.56250
# Iter 318400, Minibatch Loss= 1.748551, Training Accuracy= 0.50000
# Iter 320000, Minibatch Loss= 2.599617, Training Accuracy= 0.50000
# Iter 321600, Minibatch Loss= 2.159743, Training Accuracy= 0.37500
# Iter 323200, Minibatch Loss= 2.793760, Training Accuracy= 0.37500
# Iter 324800, Minibatch Loss= 1.536891, Training Accuracy= 0.56250
# Iter 326400, Minibatch Loss= 1.868182, Training Accuracy= 0.50000
# Iter 328000, Minibatch Loss= 1.709135, Training Accuracy= 0.37500
# Iter 329600, Minibatch Loss= 2.542083, Training Accuracy= 0.25000
# Iter 331200, Minibatch Loss= 1.703420, Training Accuracy= 0.50000
# Iter 332800, Minibatch Loss= 2.196946, Training Accuracy= 0.62500
# Iter 334400, Minibatch Loss= 1.681145, Training Accuracy= 0.56250
# Iter 336000, Minibatch Loss= 1.246958, Training Accuracy= 0.56250
# Iter 337600, Minibatch Loss= 2.725913, Training Accuracy= 0.37500
# Iter 339200, Minibatch Loss= 1.181483, Training Accuracy= 0.62500
# Iter 340800, Minibatch Loss= 2.555835, Training Accuracy= 0.25000
# Iter 342400, Minibatch Loss= 0.866305, Training Accuracy= 0.81250
# Iter 344000, Minibatch Loss= 1.606742, Training Accuracy= 0.68750
# Iter 345600, Minibatch Loss= 1.926648, Training Accuracy= 0.50000
# Iter 347200, Minibatch Loss= 0.995676, Training Accuracy= 0.68750
# Iter 348800, Minibatch Loss= 2.102270, Training Accuracy= 0.43750
# Iter 350400, Minibatch Loss= 1.698624, Training Accuracy= 0.56250
# Iter 352000, Minibatch Loss= 1.299677, Training Accuracy= 0.50000
# Iter 353600, Minibatch Loss= 1.359561, Training Accuracy= 0.56250
# Iter 355200, Minibatch Loss= 2.498410, Training Accuracy= 0.31250
# Iter 356800, Minibatch Loss= 1.218900, Training Accuracy= 0.68750
# Iter 358400, Minibatch Loss= 1.614408, Training Accuracy= 0.62500
# Iter 360000, Minibatch Loss= 1.687108, Training Accuracy= 0.50000
# Iter 361600, Minibatch Loss= 1.392617, Training Accuracy= 0.56250
# Iter 363200, Minibatch Loss= 1.023647, Training Accuracy= 0.68750
# Iter 364800, Minibatch Loss= 1.129704, Training Accuracy= 0.62500
# Iter 366400, Minibatch Loss= 1.346499, Training Accuracy= 0.75000
# Iter 368000, Minibatch Loss= 1.206039, Training Accuracy= 0.43750
# Iter 369600, Minibatch Loss= 1.496304, Training Accuracy= 0.62500
# Iter 371200, Minibatch Loss= 1.716379, Training Accuracy= 0.56250
# Iter 372800, Minibatch Loss= 1.281013, Training Accuracy= 0.62500
# Iter 374400, Minibatch Loss= 1.451193, Training Accuracy= 0.56250
# Iter 376000, Minibatch Loss= 2.018774, Training Accuracy= 0.50000
# Iter 377600, Minibatch Loss= 1.456167, Training Accuracy= 0.56250
# Iter 379200, Minibatch Loss= 1.115764, Training Accuracy= 0.68750
# Iter 380800, Minibatch Loss= 2.057852, Training Accuracy= 0.37500
# Iter 382400, Minibatch Loss= 1.363084, Training Accuracy= 0.62500
# Iter 384000, Minibatch Loss= 0.921999, Training Accuracy= 0.93750
# Iter 385600, Minibatch Loss= 0.768292, Training Accuracy= 0.75000
# Iter 387200, Minibatch Loss= 0.875279, Training Accuracy= 0.75000
# Iter 388800, Minibatch Loss= 1.575167, Training Accuracy= 0.37500
# Iter 390400, Minibatch Loss= 1.451779, Training Accuracy= 0.68750
# Iter 392000, Minibatch Loss= 0.884695, Training Accuracy= 0.75000
# Iter 393600, Minibatch Loss= 1.120520, Training Accuracy= 0.68750
# Iter 395200, Minibatch Loss= 1.343471, Training Accuracy= 0.56250
# Iter 396800, Minibatch Loss= 1.453486, Training Accuracy= 0.62500
# Iter 398400, Minibatch Loss= 1.668046, Training Accuracy= 0.50000
# Iter 400000, Minibatch Loss= 1.691723, Training Accuracy= 0.37500
# Iter 401600, Minibatch Loss= 0.951058, Training Accuracy= 0.62500
# Iter 403200, Minibatch Loss= 1.513661, Training Accuracy= 0.56250
# Iter 404800, Minibatch Loss= 0.985409, Training Accuracy= 0.68750
# Iter 406400, Minibatch Loss= 1.014364, Training Accuracy= 0.68750
# Iter 408000, Minibatch Loss= 1.745820, Training Accuracy= 0.62500
# Iter 409600, Minibatch Loss= 1.915200, Training Accuracy= 0.50000
# Iter 411200, Minibatch Loss= 1.240397, Training Accuracy= 0.68750
# Iter 412800, Minibatch Loss= 1.083154, Training Accuracy= 0.68750
# Iter 414400, Minibatch Loss= 1.543368, Training Accuracy= 0.68750
# Iter 416000, Minibatch Loss= 0.883946, Training Accuracy= 0.81250
# Iter 417600, Minibatch Loss= 1.513686, Training Accuracy= 0.50000
# Iter 419200, Minibatch Loss= 1.549891, Training Accuracy= 0.56250
# Iter 420800, Minibatch Loss= 1.588992, Training Accuracy= 0.62500
# Iter 422400, Minibatch Loss= 0.835325, Training Accuracy= 0.81250
# Iter 424000, Minibatch Loss= 1.067286, Training Accuracy= 0.75000
# Iter 425600, Minibatch Loss= 1.405687, Training Accuracy= 0.62500
# Iter 427200, Minibatch Loss= 1.777693, Training Accuracy= 0.62500
# Iter 428800, Minibatch Loss= 1.336160, Training Accuracy= 0.75000
# Iter 430400, Minibatch Loss= 1.454315, Training Accuracy= 0.68750
# Iter 432000, Minibatch Loss= 1.397925, Training Accuracy= 0.50000
# Iter 433600, Minibatch Loss= 0.975836, Training Accuracy= 0.68750
# Iter 435200, Minibatch Loss= 0.571183, Training Accuracy= 0.87500
# Iter 436800, Minibatch Loss= 1.167810, Training Accuracy= 0.62500
# Iter 438400, Minibatch Loss= 1.711798, Training Accuracy= 0.43750
# Iter 440000, Minibatch Loss= 1.465447, Training Accuracy= 0.56250
# Iter 441600, Minibatch Loss= 1.117845, Training Accuracy= 0.75000
# Iter 443200, Minibatch Loss= 0.872327, Training Accuracy= 0.81250
# Iter 444800, Minibatch Loss= 0.929497, Training Accuracy= 0.62500
# Iter 446400, Minibatch Loss= 1.063983, Training Accuracy= 0.75000
# Iter 448000, Minibatch Loss= 1.119773, Training Accuracy= 0.87500
# Iter 449600, Minibatch Loss= 0.808280, Training Accuracy= 0.81250
# Iter 451200, Minibatch Loss= 1.240602, Training Accuracy= 0.68750
# Iter 452800, Minibatch Loss= 0.529019, Training Accuracy= 0.81250
# Iter 454400, Minibatch Loss= 1.440342, Training Accuracy= 0.50000
# Iter 456000, Minibatch Loss= 1.193436, Training Accuracy= 0.81250
# Iter 457600, Minibatch Loss= 2.001384, Training Accuracy= 0.56250
# Iter 459200, Minibatch Loss= 0.425640, Training Accuracy= 0.93750
# Iter 460800, Minibatch Loss= 1.034856, Training Accuracy= 0.68750
# Iter 462400, Minibatch Loss= 0.669709, Training Accuracy= 0.68750
# Iter 464000, Minibatch Loss= 0.597249, Training Accuracy= 0.81250
# Iter 465600, Minibatch Loss= 0.591036, Training Accuracy= 0.87500
# Iter 467200, Minibatch Loss= 0.890141, Training Accuracy= 0.68750
# Iter 468800, Minibatch Loss= 1.554263, Training Accuracy= 0.68750
# Iter 470400, Minibatch Loss= 1.305290, Training Accuracy= 0.62500
# Iter 472000, Minibatch Loss= 0.740217, Training Accuracy= 0.81250
# Iter 473600, Minibatch Loss= 0.944592, Training Accuracy= 0.68750
# Iter 475200, Minibatch Loss= 0.881159, Training Accuracy= 0.62500
# Iter 476800, Minibatch Loss= 0.771943, Training Accuracy= 0.75000
# Iter 478400, Minibatch Loss= 1.239514, Training Accuracy= 0.62500
# Iter 480000, Minibatch Loss= 1.023285, Training Accuracy= 0.62500
# Iter 481600, Minibatch Loss= 0.627655, Training Accuracy= 0.75000
# Iter 483200, Minibatch Loss= 0.758512, Training Accuracy= 0.68750
# Iter 484800, Minibatch Loss= 1.038310, Training Accuracy= 0.62500
# Iter 486400, Minibatch Loss= 0.665870, Training Accuracy= 0.75000
# Iter 488000, Minibatch Loss= 2.511666, Training Accuracy= 0.43750
# Iter 489600, Minibatch Loss= 1.224298, Training Accuracy= 0.75000
# Iter 491200, Minibatch Loss= 1.014580, Training Accuracy= 0.56250
# Iter 492800, Minibatch Loss= 1.194812, Training Accuracy= 0.56250
# Iter 494400, Minibatch Loss= 0.686887, Training Accuracy= 0.75000
# Iter 496000, Minibatch Loss= 0.878642, Training Accuracy= 0.75000
# Iter 497600, Minibatch Loss= 0.599175, Training Accuracy= 0.81250
# Iter 499200, Minibatch Loss= 1.260394, Training Accuracy= 0.56250
# Iter 500800, Minibatch Loss= 0.930732, Training Accuracy= 0.75000
# Iter 502400, Minibatch Loss= 0.556610, Training Accuracy= 0.75000
# Iter 504000, Minibatch Loss= 0.889327, Training Accuracy= 0.62500
# Iter 505600, Minibatch Loss= 0.826903, Training Accuracy= 0.68750
# Iter 507200, Minibatch Loss= 0.736560, Training Accuracy= 0.81250
# Iter 508800, Minibatch Loss= 0.855019, Training Accuracy= 0.68750
# Iter 510400, Minibatch Loss= 0.856863, Training Accuracy= 0.75000
# Iter 512000, Minibatch Loss= 1.126385, Training Accuracy= 0.62500
# Iter 513600, Minibatch Loss= 1.117191, Training Accuracy= 0.81250
# Iter 515200, Minibatch Loss= 0.625216, Training Accuracy= 0.75000
# Iter 516800, Minibatch Loss= 1.546483, Training Accuracy= 0.43750
# Iter 518400, Minibatch Loss= 0.847366, Training Accuracy= 0.81250
# Iter 520000, Minibatch Loss= 0.861264, Training Accuracy= 0.68750
# Iter 521600, Minibatch Loss= 0.508829, Training Accuracy= 0.87500
# Iter 523200, Minibatch Loss= 0.542498, Training Accuracy= 0.81250
# Iter 524800, Minibatch Loss= 0.579191, Training Accuracy= 0.81250
# Iter 526400, Minibatch Loss= 1.347887, Training Accuracy= 0.62500
# Iter 528000, Minibatch Loss= 0.939902, Training Accuracy= 0.62500
# Iter 529600, Minibatch Loss= 0.415296, Training Accuracy= 0.93750
# Iter 531200, Minibatch Loss= 1.163660, Training Accuracy= 0.75000
# Iter 532800, Minibatch Loss= 0.851146, Training Accuracy= 0.75000
# Iter 534400, Minibatch Loss= 0.905676, Training Accuracy= 0.75000
# Iter 536000, Minibatch Loss= 0.633038, Training Accuracy= 0.75000
# Iter 537600, Minibatch Loss= 0.320230, Training Accuracy= 0.93750
# Iter 539200, Minibatch Loss= 0.753245, Training Accuracy= 0.87500
# Iter 540800, Minibatch Loss= 1.636336, Training Accuracy= 0.62500
# Iter 542400, Minibatch Loss= 0.671660, Training Accuracy= 0.75000
# Iter 544000, Minibatch Loss= 0.816143, Training Accuracy= 0.68750
# Iter 545600, Minibatch Loss= 1.355182, Training Accuracy= 0.75000
# Iter 547200, Minibatch Loss= 1.486518, Training Accuracy= 0.68750
# Iter 548800, Minibatch Loss= 1.263368, Training Accuracy= 0.62500
# Iter 550400, Minibatch Loss= 1.157239, Training Accuracy= 0.56250
# Iter 552000, Minibatch Loss= 0.884151, Training Accuracy= 0.81250
# Iter 553600, Minibatch Loss= 0.527157, Training Accuracy= 0.75000
# Iter 555200, Minibatch Loss= 0.516585, Training Accuracy= 0.87500
# Iter 556800, Minibatch Loss= 1.133217, Training Accuracy= 0.62500
# Iter 558400, Minibatch Loss= 0.883651, Training Accuracy= 0.68750
# Iter 560000, Minibatch Loss= 1.278402, Training Accuracy= 0.62500
# Iter 561600, Minibatch Loss= 0.473157, Training Accuracy= 0.75000
# Iter 563200, Minibatch Loss= 0.442718, Training Accuracy= 0.87500
# Iter 564800, Minibatch Loss= 0.998243, Training Accuracy= 0.68750
# Iter 566400, Minibatch Loss= 1.896513, Training Accuracy= 0.68750
# Iter 568000, Minibatch Loss= 0.814548, Training Accuracy= 0.75000
# Iter 569600, Minibatch Loss= 0.816713, Training Accuracy= 0.75000
# Iter 571200, Minibatch Loss= 0.589804, Training Accuracy= 0.87500
# Iter 572800, Minibatch Loss= 1.252224, Training Accuracy= 0.62500
# Iter 574400, Minibatch Loss= 0.901097, Training Accuracy= 0.62500
# Iter 576000, Minibatch Loss= 1.120131, Training Accuracy= 0.75000
# Iter 577600, Minibatch Loss= 0.791103, Training Accuracy= 0.68750
# Iter 579200, Minibatch Loss= 0.808106, Training Accuracy= 0.87500
# Iter 580800, Minibatch Loss= 0.465223, Training Accuracy= 0.81250
# Iter 582400, Minibatch Loss= 0.256294, Training Accuracy= 0.93750
# Iter 584000, Minibatch Loss= 1.204774, Training Accuracy= 0.62500
# Iter 585600, Minibatch Loss= 1.173581, Training Accuracy= 0.81250
# Iter 587200, Minibatch Loss= 2.002533, Training Accuracy= 0.56250
# Iter 588800, Minibatch Loss= 0.443098, Training Accuracy= 0.87500
# Iter 590400, Minibatch Loss= 1.748585, Training Accuracy= 0.62500
# Iter 592000, Minibatch Loss= 0.762658, Training Accuracy= 0.81250
# Iter 593600, Minibatch Loss= 0.797957, Training Accuracy= 0.87500
# Iter 595200, Minibatch Loss= 0.555660, Training Accuracy= 0.68750
# Iter 596800, Minibatch Loss= 0.513716, Training Accuracy= 0.75000
# Iter 598400, Minibatch Loss= 0.351129, Training Accuracy= 0.87500
# Iter 600000, Minibatch Loss= 0.414996, Training Accuracy= 0.93750
# Iter 601600, Minibatch Loss= 0.874932, Training Accuracy= 0.81250
# Iter 603200, Minibatch Loss= 0.980165, Training Accuracy= 0.68750
# Iter 604800, Minibatch Loss= 0.866868, Training Accuracy= 0.75000
# Iter 606400, Minibatch Loss= 0.216881, Training Accuracy= 0.93750
# Iter 608000, Minibatch Loss= 1.022840, Training Accuracy= 0.56250
# Iter 609600, Minibatch Loss= 0.461007, Training Accuracy= 0.87500
# Iter 611200, Minibatch Loss= 0.610473, Training Accuracy= 0.87500
# Iter 612800, Minibatch Loss= 0.444251, Training Accuracy= 0.87500
# Iter 614400, Minibatch Loss= 1.005764, Training Accuracy= 0.75000
# Iter 616000, Minibatch Loss= 0.337941, Training Accuracy= 0.93750
# Iter 617600, Minibatch Loss= 1.166825, Training Accuracy= 0.62500
# Iter 619200, Minibatch Loss= 0.702882, Training Accuracy= 0.75000
# Iter 620800, Minibatch Loss= 0.417997, Training Accuracy= 0.87500
# Iter 622400, Minibatch Loss= 1.196710, Training Accuracy= 0.62500
# Iter 624000, Minibatch Loss= 0.652284, Training Accuracy= 0.81250
# Iter 625600, Minibatch Loss= 1.765084, Training Accuracy= 0.68750
# Iter 627200, Minibatch Loss= 0.392541, Training Accuracy= 0.87500
# Iter 628800, Minibatch Loss= 0.375699, Training Accuracy= 0.93750
# Iter 630400, Minibatch Loss= 0.313888, Training Accuracy= 0.87500
# Iter 632000, Minibatch Loss= 1.022714, Training Accuracy= 0.87500
# Iter 633600, Minibatch Loss= 0.456574, Training Accuracy= 0.87500
# Iter 635200, Minibatch Loss= 0.435959, Training Accuracy= 0.81250
# Iter 636800, Minibatch Loss= 0.804864, Training Accuracy= 0.93750
# Iter 638400, Minibatch Loss= 0.595392, Training Accuracy= 0.87500
# Iter 640000, Minibatch Loss= 1.052568, Training Accuracy= 0.75000
# Iter 641600, Minibatch Loss= 0.907200, Training Accuracy= 0.68750
# Iter 643200, Minibatch Loss= 0.739462, Training Accuracy= 0.81250
# Iter 644800, Minibatch Loss= 0.843590, Training Accuracy= 0.87500
# Iter 646400, Minibatch Loss= 0.465867, Training Accuracy= 0.81250
# Iter 648000, Minibatch Loss= 0.387022, Training Accuracy= 0.87500
# Iter 649600, Minibatch Loss= 0.182036, Training Accuracy= 0.93750
# Iter 651200, Minibatch Loss= 1.068040, Training Accuracy= 0.87500
# Iter 652800, Minibatch Loss= 0.509150, Training Accuracy= 0.81250
# Iter 654400, Minibatch Loss= 1.460274, Training Accuracy= 0.87500
# Iter 656000, Minibatch Loss= 0.440125, Training Accuracy= 0.93750
# Iter 657600, Minibatch Loss= 0.689776, Training Accuracy= 0.81250
# Iter 659200, Minibatch Loss= 0.918574, Training Accuracy= 0.75000
# Iter 660800, Minibatch Loss= 0.253819, Training Accuracy= 0.87500
# Iter 662400, Minibatch Loss= 0.351498, Training Accuracy= 1.00000
# Iter 664000, Minibatch Loss= 0.763226, Training Accuracy= 0.81250
# Iter 665600, Minibatch Loss= 0.474142, Training Accuracy= 0.87500
# Iter 667200, Minibatch Loss= 0.563933, Training Accuracy= 0.87500
# Iter 668800, Minibatch Loss= 0.324446, Training Accuracy= 0.93750
# Iter 670400, Minibatch Loss= 0.826997, Training Accuracy= 0.68750
# Iter 672000, Minibatch Loss= 0.711245, Training Accuracy= 0.81250
# Iter 673600, Minibatch Loss= 0.806119, Training Accuracy= 0.81250
# Iter 675200, Minibatch Loss= 0.723168, Training Accuracy= 0.75000
# Iter 676800, Minibatch Loss= 1.526169, Training Accuracy= 0.68750
# Iter 678400, Minibatch Loss= 1.175842, Training Accuracy= 0.75000
# Iter 680000, Minibatch Loss= 0.619556, Training Accuracy= 0.81250
# Iter 681600, Minibatch Loss= 0.700767, Training Accuracy= 0.75000
# Iter 683200, Minibatch Loss= 0.400795, Training Accuracy= 0.87500
# Iter 684800, Minibatch Loss= 0.512259, Training Accuracy= 0.81250
# Iter 686400, Minibatch Loss= 0.785309, Training Accuracy= 0.81250
# Iter 688000, Minibatch Loss= 0.609509, Training Accuracy= 0.75000
# Iter 689600, Minibatch Loss= 0.378770, Training Accuracy= 0.93750
# Iter 691200, Minibatch Loss= 1.231010, Training Accuracy= 0.68750
# Iter 692800, Minibatch Loss= 0.622283, Training Accuracy= 0.87500
# Iter 694400, Minibatch Loss= 0.277986, Training Accuracy= 0.93750
# Iter 696000, Minibatch Loss= 0.381628, Training Accuracy= 0.93750
# Iter 697600, Minibatch Loss= 0.515463, Training Accuracy= 0.81250
# Iter 699200, Minibatch Loss= 0.479587, Training Accuracy= 0.75000
# Iter 700800, Minibatch Loss= 0.438010, Training Accuracy= 0.81250
# Iter 702400, Minibatch Loss= 0.672023, Training Accuracy= 0.87500
# Iter 704000, Minibatch Loss= 0.824763, Training Accuracy= 0.81250
# Iter 705600, Minibatch Loss= 0.560955, Training Accuracy= 0.87500
# Iter 707200, Minibatch Loss= 0.401236, Training Accuracy= 0.87500
# Iter 708800, Minibatch Loss= 0.714248, Training Accuracy= 0.87500
# Iter 710400, Minibatch Loss= 0.420001, Training Accuracy= 0.87500
# Iter 712000, Minibatch Loss= 0.563120, Training Accuracy= 0.81250
# Iter 713600, Minibatch Loss= 0.427685, Training Accuracy= 0.87500
# Iter 715200, Minibatch Loss= 0.190296, Training Accuracy= 1.00000
# Iter 716800, Minibatch Loss= 1.065216, Training Accuracy= 0.56250
# Iter 718400, Minibatch Loss= 0.355703, Training Accuracy= 0.87500
# Iter 720000, Minibatch Loss= 0.314460, Training Accuracy= 0.87500
# Iter 721600, Minibatch Loss= 0.825475, Training Accuracy= 0.81250
# Iter 723200, Minibatch Loss= 0.240017, Training Accuracy= 0.93750
# Iter 724800, Minibatch Loss= 0.409439, Training Accuracy= 0.93750
# Iter 726400, Minibatch Loss= 1.290938, Training Accuracy= 0.81250
# Iter 728000, Minibatch Loss= 0.427630, Training Accuracy= 0.87500
# Iter 729600, Minibatch Loss= 1.231291, Training Accuracy= 0.81250
# Iter 731200, Minibatch Loss= 0.506666, Training Accuracy= 0.81250
# Iter 732800, Minibatch Loss= 0.660704, Training Accuracy= 0.75000
# Iter 734400, Minibatch Loss= 0.467541, Training Accuracy= 0.87500
# Iter 736000, Minibatch Loss= 0.699356, Training Accuracy= 0.75000
# Iter 737600, Minibatch Loss= 1.042633, Training Accuracy= 0.81250
# Iter 739200, Minibatch Loss= 0.660089, Training Accuracy= 0.81250
# Iter 740800, Minibatch Loss= 0.900396, Training Accuracy= 0.68750
# Iter 742400, Minibatch Loss= 0.198098, Training Accuracy= 1.00000
# Iter 744000, Minibatch Loss= 0.319707, Training Accuracy= 0.93750
# Iter 745600, Minibatch Loss= 0.945615, Training Accuracy= 0.81250
# Iter 747200, Minibatch Loss= 0.314540, Training Accuracy= 0.87500
# Iter 748800, Minibatch Loss= 0.121704, Training Accuracy= 1.00000
# Iter 750400, Minibatch Loss= 0.195441, Training Accuracy= 0.93750
# Iter 752000, Minibatch Loss= 0.611500, Training Accuracy= 0.75000
# Iter 753600, Minibatch Loss= 0.351816, Training Accuracy= 0.81250
# Iter 755200, Minibatch Loss= 0.492551, Training Accuracy= 0.87500
# Iter 756800, Minibatch Loss= 0.412241, Training Accuracy= 0.87500
# Iter 758400, Minibatch Loss= 0.182041, Training Accuracy= 0.93750
# Iter 760000, Minibatch Loss= 0.682420, Training Accuracy= 0.81250
# Iter 761600, Minibatch Loss= 1.070671, Training Accuracy= 0.81250
# Iter 763200, Minibatch Loss= 0.155598, Training Accuracy= 1.00000
# Iter 764800, Minibatch Loss= 0.233237, Training Accuracy= 0.93750
# Iter 766400, Minibatch Loss= 0.475963, Training Accuracy= 0.81250
# Iter 768000, Minibatch Loss= 0.378870, Training Accuracy= 0.93750
# Iter 769600, Minibatch Loss= 1.150501, Training Accuracy= 0.87500
# Iter 771200, Minibatch Loss= 0.498692, Training Accuracy= 0.87500
# Iter 772800, Minibatch Loss= 0.354483, Training Accuracy= 0.93750
# Iter 774400, Minibatch Loss= 0.459574, Training Accuracy= 0.93750
# Iter 776000, Minibatch Loss= 0.115649, Training Accuracy= 1.00000
# Iter 777600, Minibatch Loss= 0.075301, Training Accuracy= 1.00000
# Iter 779200, Minibatch Loss= 0.762187, Training Accuracy= 0.81250
# Iter 780800, Minibatch Loss= 0.335612, Training Accuracy= 0.87500
# Iter 782400, Minibatch Loss= 0.279666, Training Accuracy= 0.87500
# Iter 784000, Minibatch Loss= 0.550294, Training Accuracy= 0.81250
# Iter 785600, Minibatch Loss= 0.543948, Training Accuracy= 0.68750
# Iter 787200, Minibatch Loss= 0.415635, Training Accuracy= 0.87500
# Iter 788800, Minibatch Loss= 1.885519, Training Accuracy= 0.68750
# Iter 790400, Minibatch Loss= 0.578967, Training Accuracy= 0.81250
# Iter 792000, Minibatch Loss= 0.610060, Training Accuracy= 0.81250
# Iter 793600, Minibatch Loss= 0.343279, Training Accuracy= 0.93750
# Iter 795200, Minibatch Loss= 0.152736, Training Accuracy= 1.00000
# Iter 796800, Minibatch Loss= 0.435130, Training Accuracy= 0.87500
# Iter 798400, Minibatch Loss= 0.408568, Training Accuracy= 0.93750
# Iter 800000, Minibatch Loss= 0.219433, Training Accuracy= 0.93750
# Iter 801600, Minibatch Loss= 0.301311, Training Accuracy= 0.93750
# Iter 803200, Minibatch Loss= 0.286437, Training Accuracy= 0.87500
# Iter 804800, Minibatch Loss= 0.220874, Training Accuracy= 0.93750
# Iter 806400, Minibatch Loss= 0.705742, Training Accuracy= 0.75000
# Iter 808000, Minibatch Loss= 0.553373, Training Accuracy= 0.93750
# Iter 809600, Minibatch Loss= 0.316907, Training Accuracy= 0.87500
# Iter 811200, Minibatch Loss= 0.507382, Training Accuracy= 0.81250
# Iter 812800, Minibatch Loss= 0.350214, Training Accuracy= 0.93750
# Iter 814400, Minibatch Loss= 0.608082, Training Accuracy= 0.87500
# Iter 816000, Minibatch Loss= 0.089945, Training Accuracy= 1.00000
# Iter 817600, Minibatch Loss= 0.180464, Training Accuracy= 0.93750
# Iter 819200, Minibatch Loss= 1.119392, Training Accuracy= 0.75000
# Iter 820800, Minibatch Loss= 0.283150, Training Accuracy= 0.93750
# Iter 822400, Minibatch Loss= 0.225521, Training Accuracy= 0.93750
# Iter 824000, Minibatch Loss= 0.108550, Training Accuracy= 0.93750
# Iter 825600, Minibatch Loss= 0.931557, Training Accuracy= 0.81250
# Iter 827200, Minibatch Loss= 0.307567, Training Accuracy= 0.81250
# Iter 828800, Minibatch Loss= 0.342873, Training Accuracy= 0.93750
# Iter 830400, Minibatch Loss= 0.136507, Training Accuracy= 1.00000
# Iter 832000, Minibatch Loss= 0.164968, Training Accuracy= 1.00000
# Iter 833600, Minibatch Loss= 0.859087, Training Accuracy= 0.75000
# Iter 835200, Minibatch Loss= 0.693948, Training Accuracy= 0.62500
# Iter 836800, Minibatch Loss= 0.212638, Training Accuracy= 1.00000
# Iter 838400, Minibatch Loss= 0.979616, Training Accuracy= 0.81250
# Iter 840000, Minibatch Loss= 0.103875, Training Accuracy= 1.00000
# Iter 841600, Minibatch Loss= 0.886527, Training Accuracy= 0.81250
# Iter 843200, Minibatch Loss= 0.439147, Training Accuracy= 0.87500
# Iter 844800, Minibatch Loss= 0.497131, Training Accuracy= 0.93750
# Iter 846400, Minibatch Loss= 0.139184, Training Accuracy= 1.00000
# Iter 848000, Minibatch Loss= 0.421114, Training Accuracy= 0.81250
# Iter 849600, Minibatch Loss= 0.110151, Training Accuracy= 1.00000
# Iter 851200, Minibatch Loss= 0.068131, Training Accuracy= 1.00000
# Iter 852800, Minibatch Loss= 0.101178, Training Accuracy= 1.00000
# Iter 854400, Minibatch Loss= 0.349011, Training Accuracy= 0.93750
# Iter 856000, Minibatch Loss= 0.903197, Training Accuracy= 0.87500
# Iter 857600, Minibatch Loss= 0.221190, Training Accuracy= 0.93750
# Iter 859200, Minibatch Loss= 0.305442, Training Accuracy= 0.81250
# Iter 860800, Minibatch Loss= 0.048500, Training Accuracy= 1.00000
# Iter 862400, Minibatch Loss= 0.558379, Training Accuracy= 0.87500
# Iter 864000, Minibatch Loss= 0.339119, Training Accuracy= 0.87500
# Iter 865600, Minibatch Loss= 0.548046, Training Accuracy= 0.87500
# Iter 867200, Minibatch Loss= 0.766333, Training Accuracy= 0.68750
# Iter 868800, Minibatch Loss= 0.319690, Training Accuracy= 0.87500
# Iter 870400, Minibatch Loss= 0.564170, Training Accuracy= 0.87500
# Iter 872000, Minibatch Loss= 0.417622, Training Accuracy= 0.75000
# Iter 873600, Minibatch Loss= 0.360217, Training Accuracy= 0.81250
# Iter 875200, Minibatch Loss= 0.573188, Training Accuracy= 0.87500
# Iter 876800, Minibatch Loss= 0.441015, Training Accuracy= 0.93750
# Iter 878400, Minibatch Loss= 0.508720, Training Accuracy= 0.87500
# Iter 880000, Minibatch Loss= 0.148451, Training Accuracy= 1.00000
# Iter 881600, Minibatch Loss= 0.196721, Training Accuracy= 1.00000
# Iter 883200, Minibatch Loss= 0.605941, Training Accuracy= 0.87500
# Iter 884800, Minibatch Loss= 0.406138, Training Accuracy= 0.81250
# Iter 886400, Minibatch Loss= 0.335384, Training Accuracy= 0.93750
# Iter 888000, Minibatch Loss= 0.120360, Training Accuracy= 1.00000
# Iter 889600, Minibatch Loss= 0.556445, Training Accuracy= 0.93750
# Iter 891200, Minibatch Loss= 0.748470, Training Accuracy= 0.81250
# Iter 892800, Minibatch Loss= 0.487083, Training Accuracy= 0.93750
# Iter 894400, Minibatch Loss= 0.855282, Training Accuracy= 0.81250
# Iter 896000, Minibatch Loss= 0.398773, Training Accuracy= 0.87500
# Iter 897600, Minibatch Loss= 0.410506, Training Accuracy= 0.87500
# Iter 899200, Minibatch Loss= 0.050365, Training Accuracy= 1.00000
# Iter 900800, Minibatch Loss= 0.953905, Training Accuracy= 0.75000
# Iter 902400, Minibatch Loss= 0.478310, Training Accuracy= 0.81250
# Iter 904000, Minibatch Loss= 0.123502, Training Accuracy= 1.00000
# Iter 905600, Minibatch Loss= 0.804316, Training Accuracy= 0.87500
# Iter 907200, Minibatch Loss= 0.099012, Training Accuracy= 1.00000
# Iter 908800, Minibatch Loss= 0.114779, Training Accuracy= 1.00000
# Iter 910400, Minibatch Loss= 0.945500, Training Accuracy= 0.87500
# Iter 912000, Minibatch Loss= 0.202554, Training Accuracy= 0.93750
# Iter 913600, Minibatch Loss= 0.209988, Training Accuracy= 0.93750
# Iter 915200, Minibatch Loss= 0.254496, Training Accuracy= 0.93750
# Iter 916800, Minibatch Loss= 0.373972, Training Accuracy= 0.75000
# Iter 918400, Minibatch Loss= 0.390366, Training Accuracy= 0.93750
# Iter 920000, Minibatch Loss= 0.286986, Training Accuracy= 0.93750
# Iter 921600, Minibatch Loss= 0.822614, Training Accuracy= 0.87500
# Iter 923200, Minibatch Loss= 0.153865, Training Accuracy= 0.93750
# Iter 924800, Minibatch Loss= 0.187883, Training Accuracy= 0.93750
# Iter 926400, Minibatch Loss= 1.040349, Training Accuracy= 0.68750
# Iter 928000, Minibatch Loss= 0.805108, Training Accuracy= 0.87500
# Iter 929600, Minibatch Loss= 0.084095, Training Accuracy= 1.00000
# Iter 931200, Minibatch Loss= 0.262923, Training Accuracy= 0.93750
# Iter 932800, Minibatch Loss= 0.587858, Training Accuracy= 0.87500
# Iter 934400, Minibatch Loss= 0.527996, Training Accuracy= 0.81250
# Iter 936000, Minibatch Loss= 0.067039, Training Accuracy= 1.00000
# Iter 937600, Minibatch Loss= 0.101619, Training Accuracy= 1.00000
# Iter 939200, Minibatch Loss= 0.163132, Training Accuracy= 0.93750
# Iter 940800, Minibatch Loss= 0.783551, Training Accuracy= 0.87500
# Iter 942400, Minibatch Loss= 0.197252, Training Accuracy= 0.93750
# Iter 944000, Minibatch Loss= 0.465440, Training Accuracy= 0.87500
# Iter 945600, Minibatch Loss= 0.524881, Training Accuracy= 0.87500
# Iter 947200, Minibatch Loss= 0.235926, Training Accuracy= 0.93750
# Iter 948800, Minibatch Loss= 0.033401, Training Accuracy= 1.00000
# Iter 950400, Minibatch Loss= 0.673623, Training Accuracy= 0.87500
# Iter 952000, Minibatch Loss= 0.701047, Training Accuracy= 0.81250
# Iter 953600, Minibatch Loss= 0.323979, Training Accuracy= 0.81250
# Iter 955200, Minibatch Loss= 0.921358, Training Accuracy= 0.81250
# Iter 956800, Minibatch Loss= 0.308041, Training Accuracy= 0.93750
# Iter 958400, Minibatch Loss= 1.029424, Training Accuracy= 0.75000
# Iter 960000, Minibatch Loss= 0.681847, Training Accuracy= 0.75000
# Iter 961600, Minibatch Loss= 0.204722, Training Accuracy= 0.93750
# Iter 963200, Minibatch Loss= 0.480664, Training Accuracy= 0.75000
# Iter 964800, Minibatch Loss= 0.189159, Training Accuracy= 0.93750
# Iter 966400, Minibatch Loss= 0.244370, Training Accuracy= 0.87500
# Iter 968000, Minibatch Loss= 0.757255, Training Accuracy= 0.81250
# Iter 969600, Minibatch Loss= 0.098027, Training Accuracy= 1.00000
# Iter 971200, Minibatch Loss= 0.871148, Training Accuracy= 0.87500
# Iter 972800, Minibatch Loss= 0.348803, Training Accuracy= 0.87500
# Iter 974400, Minibatch Loss= 0.218208, Training Accuracy= 0.87500
# Iter 976000, Minibatch Loss= 0.152506, Training Accuracy= 1.00000
# Iter 977600, Minibatch Loss= 0.243200, Training Accuracy= 0.93750
# Iter 979200, Minibatch Loss= 0.961231, Training Accuracy= 0.87500
# Iter 980800, Minibatch Loss= 0.308781, Training Accuracy= 0.93750
# Iter 982400, Minibatch Loss= 0.608091, Training Accuracy= 0.87500
# Iter 984000, Minibatch Loss= 0.178680, Training Accuracy= 0.93750
# Iter 985600, Minibatch Loss= 0.538136, Training Accuracy= 0.93750
# Iter 987200, Minibatch Loss= 0.456207, Training Accuracy= 0.87500
# Iter 988800, Minibatch Loss= 0.854542, Training Accuracy= 0.68750
# Iter 990400, Minibatch Loss= 0.147438, Training Accuracy= 0.93750
# Iter 992000, Minibatch Loss= 0.134830, Training Accuracy= 1.00000
# Iter 993600, Minibatch Loss= 0.638792, Training Accuracy= 0.93750
# Iter 995200, Minibatch Loss= 0.127856, Training Accuracy= 1.00000
# Iter 996800, Minibatch Loss= 0.353440, Training Accuracy= 0.87500
# Iter 998400, Minibatch Loss= 0.149837, Training Accuracy= 1.00000
# Iter 1000000, Minibatch Loss= 0.450731, Training Accuracy= 0.93750
# Iter 1001600, Minibatch Loss= 0.028913, Training Accuracy= 1.00000
# Iter 1003200, Minibatch Loss= 0.122826, Training Accuracy= 1.00000
# Iter 1004800, Minibatch Loss= 0.035153, Training Accuracy= 1.00000
# Iter 1006400, Minibatch Loss= 0.482624, Training Accuracy= 0.87500
# Iter 1008000, Minibatch Loss= 0.037662, Training Accuracy= 1.00000
# Iter 1009600, Minibatch Loss= 0.510223, Training Accuracy= 0.93750
# Iter 1011200, Minibatch Loss= 0.208834, Training Accuracy= 0.87500
# Iter 1012800, Minibatch Loss= 0.320938, Training Accuracy= 0.93750
# Iter 1014400, Minibatch Loss= 0.556007, Training Accuracy= 0.87500
# Iter 1016000, Minibatch Loss= 0.412133, Training Accuracy= 0.81250
# Iter 1017600, Minibatch Loss= 0.188355, Training Accuracy= 1.00000
# Iter 1019200, Minibatch Loss= 0.309931, Training Accuracy= 0.93750
# Iter 1020800, Minibatch Loss= 0.277965, Training Accuracy= 0.93750
# Iter 1022400, Minibatch Loss= 0.055259, Training Accuracy= 1.00000
# Iter 1024000, Minibatch Loss= 0.324651, Training Accuracy= 0.93750
# Iter 1025600, Minibatch Loss= 0.086375, Training Accuracy= 1.00000
# Iter 1027200, Minibatch Loss= 0.671215, Training Accuracy= 0.81250
# Iter 1028800, Minibatch Loss= 0.328823, Training Accuracy= 0.81250
# Iter 1030400, Minibatch Loss= 0.914057, Training Accuracy= 0.81250
# Iter 1032000, Minibatch Loss= 0.201138, Training Accuracy= 1.00000
# Iter 1033600, Minibatch Loss= 0.140476, Training Accuracy= 1.00000
# Iter 1035200, Minibatch Loss= 0.112194, Training Accuracy= 1.00000
# Iter 1036800, Minibatch Loss= 0.449524, Training Accuracy= 0.87500
# Iter 1038400, Minibatch Loss= 0.577757, Training Accuracy= 0.87500
# Iter 1040000, Minibatch Loss= 0.326677, Training Accuracy= 0.93750
# Iter 1041600, Minibatch Loss= 0.038418, Training Accuracy= 1.00000
# Iter 1043200, Minibatch Loss= 0.281087, Training Accuracy= 0.81250
# Iter 1044800, Minibatch Loss= 0.625386, Training Accuracy= 0.87500
# Iter 1046400, Minibatch Loss= 0.187116, Training Accuracy= 0.93750
# Iter 1048000, Minibatch Loss= 0.028747, Training Accuracy= 1.00000
# Iter 1049600, Minibatch Loss= 0.134028, Training Accuracy= 0.93750
# Iter 1051200, Minibatch Loss= 0.175179, Training Accuracy= 1.00000
# Iter 1052800, Minibatch Loss= 0.190953, Training Accuracy= 0.93750
# Iter 1054400, Minibatch Loss= 0.102643, Training Accuracy= 1.00000
# Iter 1056000, Minibatch Loss= 0.018189, Training Accuracy= 1.00000
# Iter 1057600, Minibatch Loss= 0.427377, Training Accuracy= 0.93750
# Iter 1059200, Minibatch Loss= 0.065188, Training Accuracy= 1.00000
# Iter 1060800, Minibatch Loss= 0.149695, Training Accuracy= 0.93750
# Iter 1062400, Minibatch Loss= 0.062797, Training Accuracy= 1.00000
# Iter 1064000, Minibatch Loss= 0.039168, Training Accuracy= 1.00000
# Iter 1065600, Minibatch Loss= 0.875764, Training Accuracy= 0.87500
# Iter 1067200, Minibatch Loss= 0.855554, Training Accuracy= 0.81250
# Iter 1068800, Minibatch Loss= 0.448289, Training Accuracy= 0.75000
# Iter 1070400, Minibatch Loss= 0.093648, Training Accuracy= 1.00000
# Iter 1072000, Minibatch Loss= 0.175820, Training Accuracy= 0.93750
# Iter 1073600, Minibatch Loss= 0.063681, Training Accuracy= 1.00000
# Iter 1075200, Minibatch Loss= 0.511166, Training Accuracy= 0.81250
# Iter 1076800, Minibatch Loss= 0.106100, Training Accuracy= 1.00000
# Iter 1078400, Minibatch Loss= 0.034177, Training Accuracy= 1.00000
# Iter 1080000, Minibatch Loss= 0.071576, Training Accuracy= 1.00000
# Iter 1081600, Minibatch Loss= 0.397153, Training Accuracy= 0.81250
# Iter 1083200, Minibatch Loss= 0.190042, Training Accuracy= 0.93750
# Iter 1084800, Minibatch Loss= 0.079252, Training Accuracy= 1.00000
# Iter 1086400, Minibatch Loss= 0.223077, Training Accuracy= 0.87500
# Iter 1088000, Minibatch Loss= 0.433049, Training Accuracy= 0.93750
# Iter 1089600, Minibatch Loss= 0.150305, Training Accuracy= 0.93750
# Iter 1091200, Minibatch Loss= 0.123173, Training Accuracy= 1.00000
# Iter 1092800, Minibatch Loss= 0.072389, Training Accuracy= 1.00000
# Iter 1094400, Minibatch Loss= 0.120594, Training Accuracy= 0.93750
# Iter 1096000, Minibatch Loss= 0.053484, Training Accuracy= 1.00000
# Iter 1097600, Minibatch Loss= 0.278482, Training Accuracy= 0.93750
# Iter 1099200, Minibatch Loss= 0.019587, Training Accuracy= 1.00000
# Iter 1100800, Minibatch Loss= 0.208129, Training Accuracy= 0.87500
# Iter 1102400, Minibatch Loss= 0.108199, Training Accuracy= 0.93750
# Iter 1104000, Minibatch Loss= 0.206127, Training Accuracy= 0.87500
# Iter 1105600, Minibatch Loss= 0.324687, Training Accuracy= 0.93750
# Iter 1107200, Minibatch Loss= 0.155235, Training Accuracy= 1.00000
# Iter 1108800, Minibatch Loss= 0.059109, Training Accuracy= 1.00000
# Iter 1110400, Minibatch Loss= 0.387349, Training Accuracy= 0.87500
# Iter 1112000, Minibatch Loss= 0.125588, Training Accuracy= 0.93750
# Iter 1113600, Minibatch Loss= 0.568658, Training Accuracy= 0.87500
# Iter 1115200, Minibatch Loss= 0.101127, Training Accuracy= 0.93750
# Iter 1116800, Minibatch Loss= 0.187849, Training Accuracy= 0.93750
# Iter 1118400, Minibatch Loss= 0.243075, Training Accuracy= 0.87500
# Iter 1120000, Minibatch Loss= 0.454272, Training Accuracy= 0.93750
# Iter 1121600, Minibatch Loss= 0.243382, Training Accuracy= 0.93750
# Iter 1123200, Minibatch Loss= 0.005179, Training Accuracy= 1.00000
# Iter 1124800, Minibatch Loss= 0.308006, Training Accuracy= 0.87500
# Iter 1126400, Minibatch Loss= 0.096351, Training Accuracy= 1.00000
# Iter 1128000, Minibatch Loss= 0.114013, Training Accuracy= 0.93750
# Iter 1129600, Minibatch Loss= 0.075218, Training Accuracy= 1.00000
# Iter 1131200, Minibatch Loss= 0.100743, Training Accuracy= 1.00000
# Iter 1132800, Minibatch Loss= 0.204402, Training Accuracy= 0.93750
# Iter 1134400, Minibatch Loss= 0.468091, Training Accuracy= 0.93750
# Iter 1136000, Minibatch Loss= 0.105048, Training Accuracy= 0.93750
# Iter 1137600, Minibatch Loss= 0.109288, Training Accuracy= 1.00000
# Iter 1139200, Minibatch Loss= 0.826869, Training Accuracy= 0.87500
# Iter 1140800, Minibatch Loss= 0.351725, Training Accuracy= 0.93750
# Iter 1142400, Minibatch Loss= 0.285327, Training Accuracy= 0.93750
# Iter 1144000, Minibatch Loss= 0.427072, Training Accuracy= 0.87500
# Iter 1145600, Minibatch Loss= 0.215970, Training Accuracy= 0.87500
# Iter 1147200, Minibatch Loss= 0.338342, Training Accuracy= 0.87500
# Iter 1148800, Minibatch Loss= 0.055366, Training Accuracy= 1.00000
# Iter 1150400, Minibatch Loss= 0.134319, Training Accuracy= 0.93750
# Iter 1152000, Minibatch Loss= 0.495490, Training Accuracy= 0.87500
# Iter 1153600, Minibatch Loss= 0.074213, Training Accuracy= 1.00000
# Iter 1155200, Minibatch Loss= 0.031315, Training Accuracy= 1.00000
# Iter 1156800, Minibatch Loss= 0.016124, Training Accuracy= 1.00000
# Iter 1158400, Minibatch Loss= 0.127133, Training Accuracy= 1.00000
# Iter 1160000, Minibatch Loss= 0.126395, Training Accuracy= 1.00000
# Iter 1161600, Minibatch Loss= 0.053775, Training Accuracy= 1.00000
# ...
# Iter 1219200, Minibatch Loss= 1.011154, Training Accuracy= 0.87500
# Iter 1220800, Minibatch Loss= 0.672137, Training Accuracy= 0.87500
# Iter 1222400, Minibatch Loss= 0.121636, Training Accuracy= 1.00000
# Iter 1224000, Minibatch Loss= 0.124411, Training Accuracy= 0.93750
# Iter 1225600, Minibatch Loss= 0.036763, Training Accuracy= 1.00000
# Iter 1227200, Minibatch Loss= 0.026763, Training Accuracy= 1.00000
# Iter 1228800, Minibatch Loss= 0.022096, Training Accuracy= 1.00000
# Iter 1230400, Minibatch Loss= 0.090825, Training Accuracy= 0.93750
# Iter 1232000, Minibatch Loss= 0.292263, Training Accuracy= 0.93750
# Iter 1233600, Minibatch Loss= 0.088550, Training Accuracy= 1.00000
# Iter 1235200, Minibatch Loss= 0.089768, Training Accuracy= 0.93750
# Iter 1236800, Minibatch Loss= 0.051373, Training Accuracy= 1.00000
# Iter 1238400, Minibatch Loss= 0.472985, Training Accuracy= 0.87500
# Iter 1240000, Minibatch Loss= 0.090317, Training Accuracy= 1.00000
# Iter 1241600, Minibatch Loss= 0.117719, Training Accuracy= 1.00000
# Iter 1243200, Minibatch Loss= 0.348762, Training Accuracy= 0.87500
# Iter 1244800, Minibatch Loss= 0.151108, Training Accuracy= 0.93750
# Iter 1246400, Minibatch Loss= 0.218206, Training Accuracy= 0.93750
# Iter 1248000, Minibatch Loss= 0.019700, Training Accuracy= 1.00000
# Iter 1249600, Minibatch Loss= 0.063260, Training Accuracy= 1.00000
# Iter 1251200, Minibatch Loss= 0.136780, Training Accuracy= 0.93750
# Iter 1252800, Minibatch Loss= 0.085460, Training Accuracy= 1.00000
# Iter 1254400, Minibatch Loss= 0.215845, Training Accuracy= 0.93750
# Iter 1256000, Minibatch Loss= 0.153740, Training Accuracy= 1.00000
# Iter 1257600, Minibatch Loss= 0.130420, Training Accuracy= 0.93750
# Iter 1259200, Minibatch Loss= 0.144977, Training Accuracy= 1.00000
# Iter 1260800, Minibatch Loss= 0.903985, Training Accuracy= 0.75000
# Iter 1262400, Minibatch Loss= 0.245825, Training Accuracy= 0.87500
# Iter 1264000, Minibatch Loss= 0.131137, Training Accuracy= 1.00000
# Iter 1265600, Minibatch Loss= 0.022057, Training Accuracy= 1.00000
# Iter 1267200, Minibatch Loss= 0.454644, Training Accuracy= 0.93750
# Iter 1268800, Minibatch Loss= 0.039922, Training Accuracy= 1.00000
# Iter 1270400, Minibatch Loss= 0.192238, Training Accuracy= 1.00000
# Iter 1272000, Minibatch Loss= 0.305378, Training Accuracy= 0.81250
# Iter 1273600, Minibatch Loss= 0.092757, Training Accuracy= 1.00000
# Iter 1275200, Minibatch Loss= 0.054611, Training Accuracy= 1.00000
# Iter 1276800, Minibatch Loss= 0.029864, Training Accuracy= 1.00000
# Iter 1278400, Minibatch Loss= 0.460846, Training Accuracy= 0.93750
# Iter 1280000, Minibatch Loss= 0.129813, Training Accuracy= 0.93750
# Iter 1281600, Minibatch Loss= 0.115484, Training Accuracy= 0.93750
# Iter 1283200, Minibatch Loss= 0.049587, Training Accuracy= 1.00000
# Iter 1284800, Minibatch Loss= 0.046759, Training Accuracy= 1.00000
# Iter 1286400, Minibatch Loss= 0.156345, Training Accuracy= 0.93750
# Iter 1288000, Minibatch Loss= 0.563382, Training Accuracy= 0.87500
# Iter 1289600, Minibatch Loss= 0.309591, Training Accuracy= 0.87500
# Iter 1291200, Minibatch Loss= 0.038853, Training Accuracy= 1.00000
# Iter 1292800, Minibatch Loss= 0.346772, Training Accuracy= 0.87500
# Iter 1294400, Minibatch Loss= 0.153587, Training Accuracy= 0.93750
# Iter 1296000, Minibatch Loss= 0.103770, Training Accuracy= 1.00000
# Iter 1297600, Minibatch Loss= 0.033654, Training Accuracy= 1.00000
# Iter 1299200, Minibatch Loss= 0.055801, Training Accuracy= 1.00000
# Iter 1300800, Minibatch Loss= 0.027899, Training Accuracy= 1.00000
# Iter 1302400, Minibatch Loss= 0.107202, Training Accuracy= 0.93750
# Iter 1304000, Minibatch Loss= 0.091207, Training Accuracy= 0.93750
# Iter 1305600, Minibatch Loss= 0.224156, Training Accuracy= 0.93750
# Iter 1307200, Minibatch Loss= 0.023819, Training Accuracy= 1.00000
# Iter 1308800, Minibatch Loss= 0.190561, Training Accuracy= 0.93750
# Iter 1310400, Minibatch Loss= 0.357730, Training Accuracy= 0.93750
# Iter 1312000, Minibatch Loss= 0.079094, Training Accuracy= 1.00000
# Iter 1313600, Minibatch Loss= 0.520914, Training Accuracy= 0.87500
# Iter 1315200, Minibatch Loss= 0.408442, Training Accuracy= 0.87500
# Iter 1316800, Minibatch Loss= 0.132454, Training Accuracy= 0.93750
# Iter 1318400, Minibatch Loss= 0.259632, Training Accuracy= 0.87500
# Iter 1320000, Minibatch Loss= 0.109495, Training Accuracy= 0.93750
# Iter 1321600, Minibatch Loss= 0.086992, Training Accuracy= 0.93750
# Iter 1323200, Minibatch Loss= 0.418636, Training Accuracy= 0.93750
# Iter 1324800, Minibatch Loss= 0.029498, Training Accuracy= 1.00000
# Iter 1326400, Minibatch Loss= 0.021663, Training Accuracy= 1.00000
# Iter 1328000, Minibatch Loss= 0.125738, Training Accuracy= 0.93750
# Iter 1329600, Minibatch Loss= 0.625977, Training Accuracy= 0.81250
# Iter 1331200, Minibatch Loss= 0.080413, Training Accuracy= 1.00000
# Iter 1332800, Minibatch Loss= 0.085509, Training Accuracy= 1.00000
# Iter 1334400, Minibatch Loss= 0.060957, Training Accuracy= 1.00000
# Iter 1336000, Minibatch Loss= 0.107442, Training Accuracy= 0.93750
# Iter 1337600, Minibatch Loss= 0.073504, Training Accuracy= 1.00000
# Iter 1339200, Minibatch Loss= 0.045464, Training Accuracy= 1.00000
# Iter 1340800, Minibatch Loss= 0.019628, Training Accuracy= 1.00000
# Iter 1342400, Minibatch Loss= 0.270346, Training Accuracy= 0.87500
# Iter 1344000, Minibatch Loss= 0.530153, Training Accuracy= 0.87500
# Iter 1345600, Minibatch Loss= 0.153771, Training Accuracy= 1.00000
# Iter 1347200, Minibatch Loss= 0.191543, Training Accuracy= 0.93750
# Iter 1348800, Minibatch Loss= 0.047148, Training Accuracy= 1.00000
# Iter 1350400, Minibatch Loss= 0.227142, Training Accuracy= 0.93750
# Iter 1352000, Minibatch Loss= 0.052218, Training Accuracy= 1.00000
# Iter 1353600, Minibatch Loss= 0.201570, Training Accuracy= 0.93750
# Iter 1355200, Minibatch Loss= 0.014419, Training Accuracy= 1.00000
# Iter 1356800, Minibatch Loss= 0.112627, Training Accuracy= 0.93750
# Iter 1358400, Minibatch Loss= 0.020262, Training Accuracy= 1.00000
# Iter 1360000, Minibatch Loss= 0.705987, Training Accuracy= 0.81250
# Iter 1361600, Minibatch Loss= 0.008004, Training Accuracy= 1.00000
# Iter 1363200, Minibatch Loss= 0.129340, Training Accuracy= 0.93750
# Iter 1364800, Minibatch Loss= 0.504936, Training Accuracy= 0.93750
# Iter 1366400, Minibatch Loss= 0.358409, Training Accuracy= 0.93750
# Iter 1368000, Minibatch Loss= 0.089601, Training Accuracy= 1.00000
# Iter 1369600, Minibatch Loss= 0.015376, Training Accuracy= 1.00000
# Iter 1371200, Minibatch Loss= 0.120155, Training Accuracy= 1.00000
# Iter 1372800, Minibatch Loss= 0.031444, Training Accuracy= 1.00000
# Iter 1374400, Minibatch Loss= 0.048828, Training Accuracy= 1.00000
# Iter 1376000, Minibatch Loss= 0.081728, Training Accuracy= 1.00000
# Iter 1377600, Minibatch Loss= 0.632932, Training Accuracy= 0.93750
# Iter 1379200, Minibatch Loss= 0.006785, Training Accuracy= 1.00000
# Iter 1380800, Minibatch Loss= 0.097198, Training Accuracy= 1.00000
# Iter 1382400, Minibatch Loss= 0.962675, Training Accuracy= 0.93750
# Iter 1384000, Minibatch Loss= 0.030038, Training Accuracy= 1.00000
# Iter 1385600, Minibatch Loss= 0.020604, Training Accuracy= 1.00000
# Iter 1387200, Minibatch Loss= 0.097844, Training Accuracy= 0.93750
# Iter 1388800, Minibatch Loss= 0.439582, Training Accuracy= 0.93750
# Iter 1390400, Minibatch Loss= 0.018006, Training Accuracy= 1.00000
# Iter 1392000, Minibatch Loss= 0.024521, Training Accuracy= 1.00000
# Iter 1393600, Minibatch Loss= 0.394678, Training Accuracy= 0.87500
# Iter 1395200, Minibatch Loss= 0.454228, Training Accuracy= 0.87500
# Iter 1396800, Minibatch Loss= 0.028046, Training Accuracy= 1.00000
# Iter 1398400, Minibatch Loss= 0.401636, Training Accuracy= 0.93750
# Iter 1400000, Minibatch Loss= 0.261466, Training Accuracy= 0.93750
# Iter 1401600, Minibatch Loss= 0.063756, Training Accuracy= 1.00000
# Iter 1403200, Minibatch Loss= 0.372509, Training Accuracy= 0.93750
# Iter 1404800, Minibatch Loss= 0.010352, Training Accuracy= 1.00000
# Iter 1406400, Minibatch Loss= 0.100765, Training Accuracy= 1.00000
# Iter 1408000, Minibatch Loss= 0.390991, Training Accuracy= 0.93750
# Iter 1409600, Minibatch Loss= 0.042162, Training Accuracy= 1.00000
# Iter 1411200, Minibatch Loss= 0.568241, Training Accuracy= 0.81250
# Iter 1412800, Minibatch Loss= 0.180495, Training Accuracy= 0.87500
# Iter 1414400, Minibatch Loss= 0.051819, Training Accuracy= 1.00000
# Iter 1416000, Minibatch Loss= 0.162553, Training Accuracy= 0.93750
# Iter 1417600, Minibatch Loss= 0.112558, Training Accuracy= 0.93750
# Iter 1419200, Minibatch Loss= 0.218217, Training Accuracy= 0.93750
# Iter 1420800, Minibatch Loss= 0.526789, Training Accuracy= 0.87500
# Iter 1422400, Minibatch Loss= 0.077852, Training Accuracy= 1.00000
# Iter 1424000, Minibatch Loss= 0.140918, Training Accuracy= 1.00000
# Iter 1425600, Minibatch Loss= 0.014598, Training Accuracy= 1.00000
# Iter 1427200, Minibatch Loss= 0.204825, Training Accuracy= 0.87500
# Iter 1428800, Minibatch Loss= 0.005925, Training Accuracy= 1.00000
# Iter 1430400, Minibatch Loss= 0.361364, Training Accuracy= 0.93750
# Iter 1432000, Minibatch Loss= 0.240736, Training Accuracy= 0.93750
# Iter 1433600, Minibatch Loss= 0.066143, Training Accuracy= 1.00000
# Iter 1435200, Minibatch Loss= 0.007164, Training Accuracy= 1.00000
# Iter 1436800, Minibatch Loss= 0.029779, Training Accuracy= 1.00000
# Iter 1438400, Minibatch Loss= 0.635119, Training Accuracy= 0.81250
# Iter 1440000, Minibatch Loss= 0.703056, Training Accuracy= 0.87500
# Iter 1441600, Minibatch Loss= 0.028248, Training Accuracy= 1.00000
# Iter 1443200, Minibatch Loss= 0.138892, Training Accuracy= 1.00000
# Iter 1444800, Minibatch Loss= 0.072207, Training Accuracy= 0.93750
# Iter 1446400, Minibatch Loss= 0.026048, Training Accuracy= 1.00000
# Iter 1448000, Minibatch Loss= 0.398060, Training Accuracy= 0.87500
# Iter 1449600, Minibatch Loss= 0.041129, Training Accuracy= 1.00000
# Iter 1451200, Minibatch Loss= 0.079856, Training Accuracy= 1.00000
# Iter 1452800, Minibatch Loss= 0.405638, Training Accuracy= 0.93750
# Iter 1454400, Minibatch Loss= 0.073437, Training Accuracy= 1.00000
# Iter 1456000, Minibatch Loss= 0.074741, Training Accuracy= 0.93750
# Iter 1457600, Minibatch Loss= 0.050757, Training Accuracy= 1.00000
# Iter 1459200, Minibatch Loss= 0.084261, Training Accuracy= 0.93750
# Iter 1460800, Minibatch Loss= 0.064006, Training Accuracy= 1.00000
# Iter 1462400, Minibatch Loss= 0.198449, Training Accuracy= 0.93750
# Iter 1464000, Minibatch Loss= 0.051303, Training Accuracy= 1.00000
# Iter 1465600, Minibatch Loss= 0.067999, Training Accuracy= 1.00000
# Iter 1467200, Minibatch Loss= 0.344789, Training Accuracy= 0.87500
# Iter 1468800, Minibatch Loss= 0.498282, Training Accuracy= 0.87500
# Iter 1470400, Minibatch Loss= 0.190423, Training Accuracy= 0.93750
# Iter 1472000, Minibatch Loss= 0.796526, Training Accuracy= 0.87500
# Iter 1473600, Minibatch Loss= 0.381463, Training Accuracy= 0.93750
# Iter 1475200, Minibatch Loss= 0.043013, Training Accuracy= 1.00000
# Iter 1476800, Minibatch Loss= 0.216485, Training Accuracy= 0.87500
# Iter 1478400, Minibatch Loss= 0.060981, Training Accuracy= 1.00000
# Iter 1480000, Minibatch Loss= 0.224601, Training Accuracy= 0.93750
# Iter 1481600, Minibatch Loss= 0.010046, Training Accuracy= 1.00000
# Iter 1483200, Minibatch Loss= 0.176693, Training Accuracy= 0.93750
# Iter 1484800, Minibatch Loss= 0.542698, Training Accuracy= 0.93750
# Iter 1486400, Minibatch Loss= 0.806713, Training Accuracy= 0.81250
# Iter 1488000, Minibatch Loss= 0.014203, Training Accuracy= 1.00000
# Iter 1489600, Minibatch Loss= 0.159665, Training Accuracy= 0.93750
# Iter 1491200, Minibatch Loss= 0.248752, Training Accuracy= 0.87500
# Iter 1492800, Minibatch Loss= 0.097626, Training Accuracy= 1.00000
# Iter 1494400, Minibatch Loss= 0.044116, Training Accuracy= 1.00000
# Iter 1496000, Minibatch Loss= 0.443960, Training Accuracy= 0.87500
# Iter 1497600, Minibatch Loss= 0.071375, Training Accuracy= 1.00000
# Iter 1499200, Minibatch Loss= 0.158866, Training Accuracy= 0.93750
# Iter 1500800, Minibatch Loss= 0.087903, Training Accuracy= 0.93750
# Iter 1502400, Minibatch Loss= 0.871094, Training Accuracy= 0.87500
# Iter 1504000, Minibatch Loss= 0.013240, Training Accuracy= 1.00000
# Iter 1505600, Minibatch Loss= 0.057996, Training Accuracy= 0.93750
# Iter 1507200, Minibatch Loss= 0.049098, Training Accuracy= 1.00000
# Iter 1508800, Minibatch Loss= 0.015346, Training Accuracy= 1.00000
# Iter 1510400, Minibatch Loss= 0.221164, Training Accuracy= 0.87500
# Iter 1512000, Minibatch Loss= 0.295509, Training Accuracy= 0.93750
# Iter 1513600, Minibatch Loss= 0.247066, Training Accuracy= 0.93750
# Iter 1515200, Minibatch Loss= 0.466355, Training Accuracy= 0.87500
# Iter 1516800, Minibatch Loss= 0.497388, Training Accuracy= 0.93750
# Iter 1518400, Minibatch Loss= 0.349897, Training Accuracy= 0.93750
# Iter 1520000, Minibatch Loss= 0.114225, Training Accuracy= 0.93750
# Iter 1521600, Minibatch Loss= 0.024002, Training Accuracy= 1.00000
# Iter 1523200, Minibatch Loss= 0.088961, Training Accuracy= 1.00000
# Iter 1524800, Minibatch Loss= 0.104176, Training Accuracy= 1.00000
# Iter 1526400, Minibatch Loss= 0.008752, Training Accuracy= 1.00000
# Iter 1528000, Minibatch Loss= 0.595542, Training Accuracy= 0.81250
# Iter 1529600, Minibatch Loss= 0.029936, Training Accuracy= 1.00000
# Iter 1531200, Minibatch Loss= 0.016407, Training Accuracy= 1.00000
# Iter 1532800, Minibatch Loss= 0.247548, Training Accuracy= 0.93750
# Iter 1534400, Minibatch Loss= 0.048272, Training Accuracy= 1.00000
# Iter 1536000, Minibatch Loss= 0.092030, Training Accuracy= 0.93750
# Iter 1537600, Minibatch Loss= 0.481756, Training Accuracy= 0.93750
# Iter 1539200, Minibatch Loss= 0.041436, Training Accuracy= 1.00000
# Iter 1540800, Minibatch Loss= 0.010953, Training Accuracy= 1.00000
# Iter 1542400, Minibatch Loss= 0.098290, Training Accuracy= 0.93750
# Iter 1544000, Minibatch Loss= 0.034318, Training Accuracy= 1.00000
# Iter 1545600, Minibatch Loss= 0.144955, Training Accuracy= 0.93750
# Iter 1547200, Minibatch Loss= 0.036527, Training Accuracy= 1.00000
# Iter 1548800, Minibatch Loss= 0.258044, Training Accuracy= 0.87500
# Iter 1550400, Minibatch Loss= 0.100167, Training Accuracy= 0.93750
# Iter 1552000, Minibatch Loss= 0.037409, Training Accuracy= 1.00000
# Iter 1553600, Minibatch Loss= 0.118584, Training Accuracy= 0.93750
# Iter 1555200, Minibatch Loss= 0.319948, Training Accuracy= 0.93750
# Iter 1556800, Minibatch Loss= 0.044023, Training Accuracy= 1.00000
# Iter 1558400, Minibatch Loss= 0.225976, Training Accuracy= 0.93750
# Iter 1560000, Minibatch Loss= 0.012406, Training Accuracy= 1.00000
# Iter 1561600, Minibatch Loss= 0.061133, Training Accuracy= 1.00000
# Iter 1563200, Minibatch Loss= 0.403321, Training Accuracy= 0.87500
# Iter 1564800, Minibatch Loss= 0.234088, Training Accuracy= 0.87500
# Iter 1566400, Minibatch Loss= 0.517039, Training Accuracy= 0.87500
# Iter 1568000, Minibatch Loss= 0.186043, Training Accuracy= 0.93750
# Iter 1569600, Minibatch Loss= 0.116939, Training Accuracy= 0.93750
# Iter 1571200, Minibatch Loss= 0.082836, Training Accuracy= 1.00000
# Iter 1572800, Minibatch Loss= 0.075114, Training Accuracy= 0.93750
# Iter 1574400, Minibatch Loss= 0.427299, Training Accuracy= 0.93750
# Iter 1576000, Minibatch Loss= 0.245637, Training Accuracy= 0.93750
# Iter 1577600, Minibatch Loss= 0.087850, Training Accuracy= 1.00000
# Iter 1579200, Minibatch Loss= 0.426831, Training Accuracy= 0.87500
# Iter 1580800, Minibatch Loss= 0.055047, Training Accuracy= 1.00000
# Iter 1582400, Minibatch Loss= 0.014629, Training Accuracy= 1.00000
# Iter 1584000, Minibatch Loss= 0.292708, Training Accuracy= 0.93750
# Iter 1585600, Minibatch Loss= 0.019091, Training Accuracy= 1.00000
# Iter 1587200, Minibatch Loss= 0.043059, Training Accuracy= 1.00000
# Iter 1588800, Minibatch Loss= 0.089767, Training Accuracy= 1.00000
# Iter 1590400, Minibatch Loss= 0.035243, Training Accuracy= 1.00000
# Iter 1592000, Minibatch Loss= 0.044037, Training Accuracy= 1.00000
# Iter 1593600, Minibatch Loss= 0.014432, Training Accuracy= 1.00000
# Iter 1595200, Minibatch Loss= 0.072613, Training Accuracy= 1.00000
# Iter 1596800, Minibatch Loss= 0.138223, Training Accuracy= 0.93750
# Iter 1598400, Minibatch Loss= 0.107789, Training Accuracy= 0.93750
# Optimization Finished!
# Testing Accuracy: 0.86703

# %%
saver.save(sess, '../Model/NIN-Model-0630')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', 'hungry', 'want1', '1', 'd', '7', 's', '2', 'y', 'p', 'me', 'likeb2', 'i', '9', 'q', 'why2', 'nob1', 'sorry1', 'thanku1', 'want2', 'w', 'n', 'c', '3', 'g', 'v', 'time1', 'a', 'come', 'you', 'howd2', 'unders1', 't', 'nob2', '8', 'u', 'x', '6', 'h', 'e', '5', 'o', '4', 'f', 'non', 'unders2', 'm', 'b', 'likeb1', 'r', 'l', 'howd1', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e160990c3004> in <module>()
#       1 filename = 'rgbdata/testing/6_491.png'
# ----> 2 testing(filename)
#
# <ipython-input-13-2a1024f6a0f3> in testing(filename)
#       1 def testing(filename):
# ----> 2     stest_images = get_pic(filename)
#       3     print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})
#
# NameError: global name 'get_pic' is not defined

# %%
path = 'rgbdata/testing'
testing_all(path)
