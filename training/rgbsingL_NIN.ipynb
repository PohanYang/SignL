# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t0602.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (119995, 35)

# %%
# Parameters
learning_rate = 0.001
training_iters = 1600000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==8):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.336117, Training Accuracy= 0.18750
# Iter 3200, Minibatch Loss= 3.553461, Training Accuracy= 0.00000
# Iter 4800, Minibatch Loss= 3.510469, Training Accuracy= 0.12500
# Iter 6400, Minibatch Loss= 3.537517, Training Accuracy= 0.00000
# Iter 8000, Minibatch Loss= 3.488588, Training Accuracy= 0.06250
# Iter 9600, Minibatch Loss= 3.516881, Training Accuracy= 0.06250
# Iter 11200, Minibatch Loss= 3.486225, Training Accuracy= 0.00000
# Iter 12800, Minibatch Loss= 3.461751, Training Accuracy= 0.06250
# Iter 14400, Minibatch Loss= 3.417205, Training Accuracy= 0.06250
# Iter 16000, Minibatch Loss= 3.472460, Training Accuracy= 0.12500
# Iter 17600, Minibatch Loss= 3.444093, Training Accuracy= 0.12500
# Iter 19200, Minibatch Loss= 3.417858, Training Accuracy= 0.12500
# Iter 20800, Minibatch Loss= 3.505997, Training Accuracy= 0.00000
# Iter 22400, Minibatch Loss= 3.506618, Training Accuracy= 0.00000
# Iter 24000, Minibatch Loss= 3.509462, Training Accuracy= 0.00000
# Iter 25600, Minibatch Loss= 3.526517, Training Accuracy= 0.00000
# Iter 27200, Minibatch Loss= 3.501766, Training Accuracy= 0.00000
# Iter 28800, Minibatch Loss= 3.495849, Training Accuracy= 0.06250
# Iter 30400, Minibatch Loss= 3.458614, Training Accuracy= 0.06250
# Iter 32000, Minibatch Loss= 3.513180, Training Accuracy= 0.00000
# Iter 33600, Minibatch Loss= 3.514248, Training Accuracy= 0.00000
# Iter 35200, Minibatch Loss= 3.470282, Training Accuracy= 0.00000
# Iter 36800, Minibatch Loss= 3.568270, Training Accuracy= 0.00000
# Iter 38400, Minibatch Loss= 3.376887, Training Accuracy= 0.06250
# Iter 40000, Minibatch Loss= 3.435303, Training Accuracy= 0.00000
# Iter 41600, Minibatch Loss= 3.503142, Training Accuracy= 0.12500
# Iter 43200, Minibatch Loss= 3.476588, Training Accuracy= 0.00000
# Iter 44800, Minibatch Loss= 3.502105, Training Accuracy= 0.12500
# Iter 46400, Minibatch Loss= 3.404751, Training Accuracy= 0.06250
# Iter 48000, Minibatch Loss= 3.391882, Training Accuracy= 0.06250
# Iter 49600, Minibatch Loss= 3.445636, Training Accuracy= 0.06250
# Iter 51200, Minibatch Loss= 3.339973, Training Accuracy= 0.12500
# Iter 52800, Minibatch Loss= 3.491498, Training Accuracy= 0.12500
# Iter 54400, Minibatch Loss= 3.297646, Training Accuracy= 0.12500
# Iter 56000, Minibatch Loss= 3.272215, Training Accuracy= 0.25000
# Iter 57600, Minibatch Loss= 3.551366, Training Accuracy= 0.00000
# Iter 59200, Minibatch Loss= 3.348319, Training Accuracy= 0.25000
# Iter 60800, Minibatch Loss= 3.466586, Training Accuracy= 0.06250
# Iter 62400, Minibatch Loss= 3.342882, Training Accuracy= 0.18750
# Iter 64000, Minibatch Loss= 3.475510, Training Accuracy= 0.00000
# Iter 65600, Minibatch Loss= 3.364406, Training Accuracy= 0.06250
# Iter 67200, Minibatch Loss= 3.388633, Training Accuracy= 0.00000
# Iter 68800, Minibatch Loss= 3.392220, Training Accuracy= 0.06250
# Iter 70400, Minibatch Loss= 3.174506, Training Accuracy= 0.18750
# Iter 72000, Minibatch Loss= 3.454386, Training Accuracy= 0.00000
# Iter 73600, Minibatch Loss= 3.389698, Training Accuracy= 0.12500
# Iter 75200, Minibatch Loss= 3.413245, Training Accuracy= 0.12500
# Iter 76800, Minibatch Loss= 3.369418, Training Accuracy= 0.06250
# Iter 78400, Minibatch Loss= 3.339252, Training Accuracy= 0.12500
# Iter 80000, Minibatch Loss= 3.329197, Training Accuracy= 0.18750
# Iter 81600, Minibatch Loss= 3.397187, Training Accuracy= 0.12500
# Iter 83200, Minibatch Loss= 3.344650, Training Accuracy= 0.00000
# Iter 84800, Minibatch Loss= 3.243292, Training Accuracy= 0.00000
# Iter 86400, Minibatch Loss= 3.375404, Training Accuracy= 0.06250
# Iter 88000, Minibatch Loss= 3.033706, Training Accuracy= 0.12500
# Iter 89600, Minibatch Loss= 3.306806, Training Accuracy= 0.06250
# Iter 91200, Minibatch Loss= 2.986493, Training Accuracy= 0.06250
# Iter 92800, Minibatch Loss= 3.225960, Training Accuracy= 0.18750
# Iter 94400, Minibatch Loss= 3.233992, Training Accuracy= 0.12500
# Iter 96000, Minibatch Loss= 3.149906, Training Accuracy= 0.12500
# Iter 97600, Minibatch Loss= 2.900353, Training Accuracy= 0.18750
# Iter 99200, Minibatch Loss= 3.079579, Training Accuracy= 0.12500
# Iter 100800, Minibatch Loss= 2.774268, Training Accuracy= 0.31250
# Iter 102400, Minibatch Loss= 2.201915, Training Accuracy= 0.37500
# Iter 104000, Minibatch Loss= 2.838162, Training Accuracy= 0.06250
# Iter 105600, Minibatch Loss= 2.891779, Training Accuracy= 0.12500
# Iter 107200, Minibatch Loss= 2.836479, Training Accuracy= 0.18750
# Iter 108800, Minibatch Loss= 2.554193, Training Accuracy= 0.25000
# Iter 110400, Minibatch Loss= 2.905594, Training Accuracy= 0.25000
# Iter 112000, Minibatch Loss= 2.534325, Training Accuracy= 0.18750
# Iter 113600, Minibatch Loss= 2.798798, Training Accuracy= 0.18750
# Iter 115200, Minibatch Loss= 2.740419, Training Accuracy= 0.37500
# Iter 116800, Minibatch Loss= 2.830549, Training Accuracy= 0.18750
# Iter 118400, Minibatch Loss= 2.569697, Training Accuracy= 0.18750
# Iter 120000, Minibatch Loss= 2.603148, Training Accuracy= 0.25000
# Iter 121600, Minibatch Loss= 2.544515, Training Accuracy= 0.25000
# Iter 123200, Minibatch Loss= 2.638484, Training Accuracy= 0.31250
# Iter 124800, Minibatch Loss= 2.322775, Training Accuracy= 0.31250
# Iter 126400, Minibatch Loss= 2.449756, Training Accuracy= 0.25000
# Iter 128000, Minibatch Loss= 2.977791, Training Accuracy= 0.18750
# Iter 129600, Minibatch Loss= 2.126763, Training Accuracy= 0.50000
# Iter 131200, Minibatch Loss= 2.251123, Training Accuracy= 0.25000
# Iter 132800, Minibatch Loss= 2.085284, Training Accuracy= 0.25000
# Iter 134400, Minibatch Loss= 2.247854, Training Accuracy= 0.37500
# Iter 136000, Minibatch Loss= 2.439873, Training Accuracy= 0.12500
# Iter 137600, Minibatch Loss= 2.310597, Training Accuracy= 0.25000
# Iter 139200, Minibatch Loss= 2.073100, Training Accuracy= 0.31250
# Iter 140800, Minibatch Loss= 1.913431, Training Accuracy= 0.50000
# Iter 142400, Minibatch Loss= 2.074793, Training Accuracy= 0.37500
# Iter 144000, Minibatch Loss= 1.989966, Training Accuracy= 0.31250
# Iter 145600, Minibatch Loss= 2.996006, Training Accuracy= 0.00000
# Iter 147200, Minibatch Loss= 2.427676, Training Accuracy= 0.25000
# Iter 148800, Minibatch Loss= 1.888098, Training Accuracy= 0.43750
# Iter 150400, Minibatch Loss= 2.207060, Training Accuracy= 0.31250
# Iter 152000, Minibatch Loss= 2.045025, Training Accuracy= 0.43750
# Iter 153600, Minibatch Loss= 1.972019, Training Accuracy= 0.56250
# Iter 155200, Minibatch Loss= 1.875443, Training Accuracy= 0.50000
# Iter 156800, Minibatch Loss= 1.943010, Training Accuracy= 0.56250
# Iter 158400, Minibatch Loss= 1.597626, Training Accuracy= 0.56250
# Iter 160000, Minibatch Loss= 1.566822, Training Accuracy= 0.31250
# Iter 161600, Minibatch Loss= 2.279653, Training Accuracy= 0.25000
# Iter 163200, Minibatch Loss= 1.870435, Training Accuracy= 0.31250
# Iter 164800, Minibatch Loss= 2.333457, Training Accuracy= 0.37500
# Iter 166400, Minibatch Loss= 2.187642, Training Accuracy= 0.56250
# Iter 168000, Minibatch Loss= 2.435398, Training Accuracy= 0.31250
# Iter 169600, Minibatch Loss= 1.663705, Training Accuracy= 0.56250
# Iter 171200, Minibatch Loss= 1.666311, Training Accuracy= 0.50000
# Iter 172800, Minibatch Loss= 2.122489, Training Accuracy= 0.31250
# Iter 174400, Minibatch Loss= 1.102966, Training Accuracy= 0.68750
# Iter 176000, Minibatch Loss= 1.830794, Training Accuracy= 0.43750
# Iter 177600, Minibatch Loss= 1.477160, Training Accuracy= 0.43750
# Iter 179200, Minibatch Loss= 1.650569, Training Accuracy= 0.37500
# Iter 180800, Minibatch Loss= 1.586678, Training Accuracy= 0.62500
# Iter 182400, Minibatch Loss= 1.952850, Training Accuracy= 0.56250
# Iter 184000, Minibatch Loss= 1.908990, Training Accuracy= 0.43750
# Iter 185600, Minibatch Loss= 1.190262, Training Accuracy= 0.56250
# Iter 187200, Minibatch Loss= 1.494629, Training Accuracy= 0.62500
# Iter 188800, Minibatch Loss= 2.023912, Training Accuracy= 0.31250
# Iter 190400, Minibatch Loss= 2.346667, Training Accuracy= 0.56250
# Iter 192000, Minibatch Loss= 1.871632, Training Accuracy= 0.43750
# Iter 193600, Minibatch Loss= 1.436502, Training Accuracy= 0.56250
# Iter 195200, Minibatch Loss= 1.224866, Training Accuracy= 0.62500
# Iter 196800, Minibatch Loss= 2.006720, Training Accuracy= 0.43750
# Iter 198400, Minibatch Loss= 1.424623, Training Accuracy= 0.50000
# Iter 200000, Minibatch Loss= 2.062629, Training Accuracy= 0.37500
# Iter 201600, Minibatch Loss= 1.879223, Training Accuracy= 0.43750
# Iter 203200, Minibatch Loss= 1.701718, Training Accuracy= 0.56250
# Iter 204800, Minibatch Loss= 1.251309, Training Accuracy= 0.56250
# Iter 206400, Minibatch Loss= 1.630386, Training Accuracy= 0.50000
# Iter 208000, Minibatch Loss= 1.171039, Training Accuracy= 0.56250
# Iter 209600, Minibatch Loss= 1.641460, Training Accuracy= 0.50000
# Iter 211200, Minibatch Loss= 1.785256, Training Accuracy= 0.56250
# Iter 212800, Minibatch Loss= 1.311579, Training Accuracy= 0.56250
# Iter 214400, Minibatch Loss= 1.490685, Training Accuracy= 0.37500
# Iter 216000, Minibatch Loss= 1.551335, Training Accuracy= 0.56250
# Iter 217600, Minibatch Loss= 1.172799, Training Accuracy= 0.56250
# Iter 219200, Minibatch Loss= 1.132284, Training Accuracy= 0.68750
# Iter 220800, Minibatch Loss= 1.220864, Training Accuracy= 0.62500
# Iter 222400, Minibatch Loss= 1.706955, Training Accuracy= 0.50000
# Iter 224000, Minibatch Loss= 1.087582, Training Accuracy= 0.75000
# Iter 225600, Minibatch Loss= 1.352544, Training Accuracy= 0.68750
# Iter 227200, Minibatch Loss= 1.511883, Training Accuracy= 0.50000
# Iter 228800, Minibatch Loss= 1.761481, Training Accuracy= 0.68750
# Iter 230400, Minibatch Loss= 1.468657, Training Accuracy= 0.62500
# Iter 232000, Minibatch Loss= 1.621232, Training Accuracy= 0.56250
# Iter 233600, Minibatch Loss= 1.308477, Training Accuracy= 0.56250
# Iter 235200, Minibatch Loss= 1.287261, Training Accuracy= 0.68750
# Iter 236800, Minibatch Loss= 1.145533, Training Accuracy= 0.75000
# Iter 238400, Minibatch Loss= 0.855774, Training Accuracy= 0.62500
# Iter 240000, Minibatch Loss= 1.243855, Training Accuracy= 0.81250
# Iter 241600, Minibatch Loss= 0.834592, Training Accuracy= 0.62500
# Iter 243200, Minibatch Loss= 0.935614, Training Accuracy= 0.62500
# Iter 244800, Minibatch Loss= 1.155548, Training Accuracy= 0.56250
# Iter 246400, Minibatch Loss= 0.681251, Training Accuracy= 0.87500
# Iter 248000, Minibatch Loss= 0.592140, Training Accuracy= 0.93750
# Iter 249600, Minibatch Loss= 0.962192, Training Accuracy= 0.75000
# Iter 251200, Minibatch Loss= 0.944486, Training Accuracy= 0.75000
# Iter 252800, Minibatch Loss= 0.407498, Training Accuracy= 0.93750
# Iter 254400, Minibatch Loss= 0.798266, Training Accuracy= 0.62500
# Iter 256000, Minibatch Loss= 1.095801, Training Accuracy= 0.68750
# Iter 257600, Minibatch Loss= 1.070207, Training Accuracy= 0.68750
# Iter 259200, Minibatch Loss= 1.815289, Training Accuracy= 0.75000
# Iter 260800, Minibatch Loss= 0.692336, Training Accuracy= 0.81250
# Iter 262400, Minibatch Loss= 0.519231, Training Accuracy= 0.87500
# Iter 264000, Minibatch Loss= 0.986355, Training Accuracy= 0.81250
# Iter 265600, Minibatch Loss= 0.745931, Training Accuracy= 0.93750
# Iter 267200, Minibatch Loss= 0.836900, Training Accuracy= 0.75000
# Iter 268800, Minibatch Loss= 0.929710, Training Accuracy= 0.68750
# Iter 270400, Minibatch Loss= 1.257722, Training Accuracy= 0.68750
# Iter 272000, Minibatch Loss= 0.695178, Training Accuracy= 0.81250
# Iter 273600, Minibatch Loss= 1.240281, Training Accuracy= 0.68750
# Iter 275200, Minibatch Loss= 1.084270, Training Accuracy= 0.75000
# Iter 276800, Minibatch Loss= 0.584596, Training Accuracy= 0.81250
# Iter 278400, Minibatch Loss= 0.838094, Training Accuracy= 0.68750
# Iter 280000, Minibatch Loss= 1.612563, Training Accuracy= 0.68750
# Iter 281600, Minibatch Loss= 0.834388, Training Accuracy= 0.81250
# Iter 283200, Minibatch Loss= 1.423121, Training Accuracy= 0.68750
# Iter 284800, Minibatch Loss= 1.008610, Training Accuracy= 0.75000
# Iter 286400, Minibatch Loss= 0.600853, Training Accuracy= 0.75000
# Iter 288000, Minibatch Loss= 0.924939, Training Accuracy= 0.93750
# Iter 289600, Minibatch Loss= 1.028179, Training Accuracy= 0.75000
# Iter 291200, Minibatch Loss= 0.740922, Training Accuracy= 0.81250
# Iter 292800, Minibatch Loss= 0.644517, Training Accuracy= 0.81250
# Iter 294400, Minibatch Loss= 0.857996, Training Accuracy= 0.68750
# Iter 296000, Minibatch Loss= 0.831171, Training Accuracy= 0.81250
# Iter 297600, Minibatch Loss= 0.814821, Training Accuracy= 0.75000
# Iter 299200, Minibatch Loss= 1.289277, Training Accuracy= 0.62500
# Iter 300800, Minibatch Loss= 0.564995, Training Accuracy= 0.75000
# Iter 302400, Minibatch Loss= 0.797102, Training Accuracy= 0.62500
# Iter 304000, Minibatch Loss= 0.880241, Training Accuracy= 0.75000
# Iter 305600, Minibatch Loss= 1.158556, Training Accuracy= 0.81250
# Iter 307200, Minibatch Loss= 1.361775, Training Accuracy= 0.62500
# Iter 308800, Minibatch Loss= 0.730063, Training Accuracy= 0.87500
# Iter 310400, Minibatch Loss= 0.760396, Training Accuracy= 0.75000
# Iter 312000, Minibatch Loss= 0.842445, Training Accuracy= 0.75000
# Iter 313600, Minibatch Loss= 1.453771, Training Accuracy= 0.62500
# Iter 315200, Minibatch Loss= 0.685334, Training Accuracy= 0.75000
# Iter 316800, Minibatch Loss= 0.754548, Training Accuracy= 0.75000
# Iter 318400, Minibatch Loss= 0.634532, Training Accuracy= 0.87500
# Iter 320000, Minibatch Loss= 1.143591, Training Accuracy= 0.81250
# Iter 321600, Minibatch Loss= 0.813332, Training Accuracy= 0.75000
# Iter 323200, Minibatch Loss= 1.013302, Training Accuracy= 0.68750
# Iter 324800, Minibatch Loss= 0.322637, Training Accuracy= 0.87500
# Iter 326400, Minibatch Loss= 1.381084, Training Accuracy= 0.50000
# Iter 328000, Minibatch Loss= 1.108446, Training Accuracy= 0.75000
# Iter 329600, Minibatch Loss= 0.801884, Training Accuracy= 0.75000
# Iter 331200, Minibatch Loss= 0.444986, Training Accuracy= 0.93750
# Iter 332800, Minibatch Loss= 0.706730, Training Accuracy= 0.68750
# Iter 334400, Minibatch Loss= 0.845879, Training Accuracy= 0.75000
# Iter 336000, Minibatch Loss= 0.345639, Training Accuracy= 0.93750
# Iter 337600, Minibatch Loss= 0.786577, Training Accuracy= 0.75000
# Iter 339200, Minibatch Loss= 0.731928, Training Accuracy= 0.68750
# Iter 340800, Minibatch Loss= 0.677084, Training Accuracy= 0.75000
# Iter 342400, Minibatch Loss= 0.580299, Training Accuracy= 0.81250
# Iter 344000, Minibatch Loss= 0.848409, Training Accuracy= 0.93750
# Iter 345600, Minibatch Loss= 0.565405, Training Accuracy= 0.87500
# Iter 347200, Minibatch Loss= 0.625745, Training Accuracy= 0.81250
# Iter 348800, Minibatch Loss= 0.455910, Training Accuracy= 0.81250
# Iter 350400, Minibatch Loss= 0.455747, Training Accuracy= 0.87500
# Iter 352000, Minibatch Loss= 0.514322, Training Accuracy= 0.75000
# Iter 353600, Minibatch Loss= 2.373089, Training Accuracy= 0.56250
# Iter 355200, Minibatch Loss= 0.593048, Training Accuracy= 0.81250
# Iter 356800, Minibatch Loss= 0.336408, Training Accuracy= 0.87500
# Iter 358400, Minibatch Loss= 0.397919, Training Accuracy= 0.87500
# Iter 360000, Minibatch Loss= 0.826570, Training Accuracy= 0.75000
# Iter 361600, Minibatch Loss= 0.137124, Training Accuracy= 1.00000
# Iter 363200, Minibatch Loss= 0.764960, Training Accuracy= 0.81250
# Iter 364800, Minibatch Loss= 0.572114, Training Accuracy= 0.81250
# Iter 366400, Minibatch Loss= 1.056493, Training Accuracy= 0.62500
# Iter 368000, Minibatch Loss= 0.610548, Training Accuracy= 0.75000
# Iter 369600, Minibatch Loss= 0.387761, Training Accuracy= 0.81250
# Iter 371200, Minibatch Loss= 0.573170, Training Accuracy= 0.93750
# Iter 372800, Minibatch Loss= 0.420495, Training Accuracy= 0.81250
# Iter 374400, Minibatch Loss= 0.422620, Training Accuracy= 0.81250
# Iter 376000, Minibatch Loss= 0.792838, Training Accuracy= 0.75000
# Iter 377600, Minibatch Loss= 0.886992, Training Accuracy= 0.68750
# Iter 379200, Minibatch Loss= 0.528718, Training Accuracy= 0.87500
# Iter 380800, Minibatch Loss= 0.479593, Training Accuracy= 0.81250
# Iter 382400, Minibatch Loss= 0.797577, Training Accuracy= 0.68750
# Iter 384000, Minibatch Loss= 0.744730, Training Accuracy= 0.75000
# Iter 385600, Minibatch Loss= 0.732365, Training Accuracy= 0.75000
# Iter 387200, Minibatch Loss= 0.245647, Training Accuracy= 0.87500
# Iter 388800, Minibatch Loss= 0.621860, Training Accuracy= 0.87500
# Iter 390400, Minibatch Loss= 0.314343, Training Accuracy= 0.93750
# Iter 392000, Minibatch Loss= 0.359114, Training Accuracy= 0.93750
# Iter 393600, Minibatch Loss= 0.794539, Training Accuracy= 0.68750
# Iter 395200, Minibatch Loss= 0.285710, Training Accuracy= 0.87500
# Iter 396800, Minibatch Loss= 0.840452, Training Accuracy= 0.62500
# Iter 398400, Minibatch Loss= 1.382429, Training Accuracy= 0.62500
# Iter 400000, Minibatch Loss= 0.730300, Training Accuracy= 0.81250
# Iter 401600, Minibatch Loss= 1.293535, Training Accuracy= 0.75000
# Iter 403200, Minibatch Loss= 0.386537, Training Accuracy= 0.93750
# Iter 404800, Minibatch Loss= 0.806444, Training Accuracy= 0.75000
# Iter 406400, Minibatch Loss= 0.704428, Training Accuracy= 0.81250
# Iter 408000, Minibatch Loss= 0.861530, Training Accuracy= 0.87500
# Iter 409600, Minibatch Loss= 0.625715, Training Accuracy= 0.81250
# Iter 411200, Minibatch Loss= 0.410866, Training Accuracy= 0.87500
# Iter 412800, Minibatch Loss= 0.378084, Training Accuracy= 0.93750
# Iter 414400, Minibatch Loss= 0.478405, Training Accuracy= 0.81250
# Iter 416000, Minibatch Loss= 0.216516, Training Accuracy= 0.93750
# Iter 417600, Minibatch Loss= 0.162432, Training Accuracy= 0.93750
# Iter 419200, Minibatch Loss= 0.173685, Training Accuracy= 0.93750
# Iter 420800, Minibatch Loss= 0.421958, Training Accuracy= 0.87500
# Iter 422400, Minibatch Loss= 0.597316, Training Accuracy= 0.75000
# Iter 424000, Minibatch Loss= 0.499467, Training Accuracy= 0.81250
# Iter 425600, Minibatch Loss= 0.170655, Training Accuracy= 1.00000
# Iter 427200, Minibatch Loss= 0.802687, Training Accuracy= 0.62500
# Iter 428800, Minibatch Loss= 1.120405, Training Accuracy= 0.68750
# Iter 430400, Minibatch Loss= 0.440014, Training Accuracy= 0.93750
# Iter 432000, Minibatch Loss= 0.257360, Training Accuracy= 0.93750
# Iter 433600, Minibatch Loss= 0.811973, Training Accuracy= 0.75000
# Iter 435200, Minibatch Loss= 0.192807, Training Accuracy= 0.87500
# Iter 436800, Minibatch Loss= 0.532526, Training Accuracy= 0.75000
# Iter 438400, Minibatch Loss= 0.380038, Training Accuracy= 0.87500
# Iter 440000, Minibatch Loss= 0.341844, Training Accuracy= 0.93750
# Iter 441600, Minibatch Loss= 0.392453, Training Accuracy= 0.81250
# Iter 443200, Minibatch Loss= 0.611487, Training Accuracy= 0.87500
# Iter 444800, Minibatch Loss= 0.309803, Training Accuracy= 0.87500
# Iter 446400, Minibatch Loss= 0.369016, Training Accuracy= 0.81250
# Iter 448000, Minibatch Loss= 0.913188, Training Accuracy= 0.75000
# Iter 449600, Minibatch Loss= 0.405013, Training Accuracy= 0.87500
# Iter 451200, Minibatch Loss= 0.504132, Training Accuracy= 0.87500
# Iter 452800, Minibatch Loss= 0.590876, Training Accuracy= 0.75000
# Iter 454400, Minibatch Loss= 0.390772, Training Accuracy= 0.87500
# Iter 456000, Minibatch Loss= 1.008832, Training Accuracy= 0.75000
# Iter 457600, Minibatch Loss= 1.084836, Training Accuracy= 0.75000
# Iter 459200, Minibatch Loss= 0.696670, Training Accuracy= 0.81250
# Iter 460800, Minibatch Loss= 0.563274, Training Accuracy= 0.75000
# Iter 462400, Minibatch Loss= 0.350235, Training Accuracy= 0.87500
# Iter 464000, Minibatch Loss= 0.392210, Training Accuracy= 0.81250
# Iter 465600, Minibatch Loss= 0.208975, Training Accuracy= 0.93750
# Iter 467200, Minibatch Loss= 0.146601, Training Accuracy= 0.93750
# Iter 468800, Minibatch Loss= 0.432513, Training Accuracy= 0.81250
# Iter 470400, Minibatch Loss= 0.167453, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.598193, Training Accuracy= 0.81250
# Iter 473600, Minibatch Loss= 0.628500, Training Accuracy= 0.93750
# Iter 475200, Minibatch Loss= 0.746888, Training Accuracy= 0.87500
# Iter 476800, Minibatch Loss= 0.221627, Training Accuracy= 0.93750
# Iter 478400, Minibatch Loss= 1.107417, Training Accuracy= 0.68750
# Iter 480000, Minibatch Loss= 0.087664, Training Accuracy= 1.00000
# Iter 481600, Minibatch Loss= 0.995043, Training Accuracy= 0.68750
# Iter 483200, Minibatch Loss= 0.446636, Training Accuracy= 0.87500
# Iter 484800, Minibatch Loss= 0.197537, Training Accuracy= 1.00000
# Iter 486400, Minibatch Loss= 0.453527, Training Accuracy= 0.87500
# Iter 488000, Minibatch Loss= 0.746905, Training Accuracy= 0.68750
# Iter 489600, Minibatch Loss= 0.686263, Training Accuracy= 0.75000
# Iter 491200, Minibatch Loss= 0.253076, Training Accuracy= 0.93750
# Iter 492800, Minibatch Loss= 0.491031, Training Accuracy= 0.87500
# Iter 494400, Minibatch Loss= 0.425336, Training Accuracy= 0.87500
# Iter 496000, Minibatch Loss= 0.601018, Training Accuracy= 0.68750
# Iter 497600, Minibatch Loss= 0.538296, Training Accuracy= 0.81250
# Iter 499200, Minibatch Loss= 0.910420, Training Accuracy= 0.75000
# Iter 500800, Minibatch Loss= 0.371665, Training Accuracy= 0.87500
# Iter 502400, Minibatch Loss= 0.368185, Training Accuracy= 0.87500
# Iter 504000, Minibatch Loss= 0.169052, Training Accuracy= 0.87500
# Iter 505600, Minibatch Loss= 0.376743, Training Accuracy= 0.87500
# Iter 507200, Minibatch Loss= 0.025114, Training Accuracy= 1.00000
# Iter 508800, Minibatch Loss= 0.387072, Training Accuracy= 0.87500
# Iter 510400, Minibatch Loss= 0.269521, Training Accuracy= 0.87500
# Iter 512000, Minibatch Loss= 0.318807, Training Accuracy= 0.93750
# Iter 513600, Minibatch Loss= 0.258987, Training Accuracy= 0.93750
# Iter 515200, Minibatch Loss= 0.390256, Training Accuracy= 0.87500
# Iter 516800, Minibatch Loss= 0.615175, Training Accuracy= 0.87500
# Iter 518400, Minibatch Loss= 0.139689, Training Accuracy= 0.93750
# Iter 520000, Minibatch Loss= 0.240425, Training Accuracy= 0.87500
# Iter 521600, Minibatch Loss= 0.254553, Training Accuracy= 0.87500
# Iter 523200, Minibatch Loss= 0.646436, Training Accuracy= 0.93750
# Iter 524800, Minibatch Loss= 0.626501, Training Accuracy= 0.81250
# Iter 526400, Minibatch Loss= 0.134273, Training Accuracy= 1.00000
# Iter 528000, Minibatch Loss= 0.466773, Training Accuracy= 0.81250
# Iter 529600, Minibatch Loss= 0.759349, Training Accuracy= 0.87500
# Iter 531200, Minibatch Loss= 0.539908, Training Accuracy= 0.87500
# Iter 532800, Minibatch Loss= 0.263329, Training Accuracy= 0.93750
# Iter 534400, Minibatch Loss= 0.391723, Training Accuracy= 0.87500
# Iter 536000, Minibatch Loss= 0.443691, Training Accuracy= 0.81250
# Iter 537600, Minibatch Loss= 0.251868, Training Accuracy= 0.93750
# Iter 539200, Minibatch Loss= 0.340076, Training Accuracy= 0.93750
# Iter 540800, Minibatch Loss= 0.085747, Training Accuracy= 1.00000
# Iter 542400, Minibatch Loss= 0.313071, Training Accuracy= 0.87500
# Iter 544000, Minibatch Loss= 0.102813, Training Accuracy= 1.00000
# Iter 545600, Minibatch Loss= 0.448743, Training Accuracy= 0.93750
# Iter 547200, Minibatch Loss= 0.335355, Training Accuracy= 0.93750
# Iter 548800, Minibatch Loss= 0.440989, Training Accuracy= 0.87500
# Iter 550400, Minibatch Loss= 0.225039, Training Accuracy= 0.87500
# Iter 552000, Minibatch Loss= 0.227767, Training Accuracy= 0.93750
# Iter 553600, Minibatch Loss= 0.214040, Training Accuracy= 0.93750
# Iter 555200, Minibatch Loss= 0.639440, Training Accuracy= 0.87500
# Iter 556800, Minibatch Loss= 0.264466, Training Accuracy= 0.93750
# Iter 558400, Minibatch Loss= 1.223583, Training Accuracy= 0.87500
# Iter 560000, Minibatch Loss= 0.058541, Training Accuracy= 1.00000
# Iter 561600, Minibatch Loss= 0.821469, Training Accuracy= 0.87500
# Iter 563200, Minibatch Loss= 0.152759, Training Accuracy= 1.00000
# Iter 564800, Minibatch Loss= 0.547827, Training Accuracy= 0.87500
# Iter 566400, Minibatch Loss= 0.319902, Training Accuracy= 0.87500
# Iter 568000, Minibatch Loss= 0.022164, Training Accuracy= 1.00000
# Iter 569600, Minibatch Loss= 0.266946, Training Accuracy= 0.93750
# Iter 571200, Minibatch Loss= 0.035924, Training Accuracy= 1.00000
# Iter 572800, Minibatch Loss= 0.534420, Training Accuracy= 0.87500
# Iter 574400, Minibatch Loss= 0.508936, Training Accuracy= 0.87500
# Iter 576000, Minibatch Loss= 0.675700, Training Accuracy= 0.93750
# Iter 577600, Minibatch Loss= 0.083159, Training Accuracy= 1.00000
# Iter 579200, Minibatch Loss= 0.422733, Training Accuracy= 0.87500
# Iter 580800, Minibatch Loss= 0.739331, Training Accuracy= 0.75000
# Iter 582400, Minibatch Loss= 0.090867, Training Accuracy= 1.00000
# Iter 584000, Minibatch Loss= 0.218842, Training Accuracy= 0.93750
# Iter 585600, Minibatch Loss= 0.678301, Training Accuracy= 0.87500
# Iter 587200, Minibatch Loss= 0.684225, Training Accuracy= 0.87500
# Iter 588800, Minibatch Loss= 0.598051, Training Accuracy= 0.87500
# Iter 590400, Minibatch Loss= 0.277860, Training Accuracy= 0.87500
# Iter 592000, Minibatch Loss= 0.669467, Training Accuracy= 0.87500
# Iter 593600, Minibatch Loss= 0.191013, Training Accuracy= 0.93750
# Iter 595200, Minibatch Loss= 0.187561, Training Accuracy= 0.93750
# Iter 596800, Minibatch Loss= 0.153796, Training Accuracy= 1.00000
# Iter 598400, Minibatch Loss= 0.152458, Training Accuracy= 0.93750
# Iter 600000, Minibatch Loss= 0.293172, Training Accuracy= 0.93750
# Iter 601600, Minibatch Loss= 0.110938, Training Accuracy= 0.93750
# Iter 603200, Minibatch Loss= 0.044788, Training Accuracy= 1.00000
# Iter 604800, Minibatch Loss= 0.183540, Training Accuracy= 0.93750
# Iter 606400, Minibatch Loss= 0.164019, Training Accuracy= 0.93750
# Iter 608000, Minibatch Loss= 0.778204, Training Accuracy= 0.81250
# Iter 609600, Minibatch Loss= 0.322552, Training Accuracy= 0.93750
# Iter 611200, Minibatch Loss= 0.404313, Training Accuracy= 0.87500
# Iter 612800, Minibatch Loss= 0.101399, Training Accuracy= 0.93750
# Iter 614400, Minibatch Loss= 0.409921, Training Accuracy= 0.93750
# Iter 616000, Minibatch Loss= 0.272878, Training Accuracy= 0.87500
# Iter 617600, Minibatch Loss= 0.298846, Training Accuracy= 0.81250
# Iter 619200, Minibatch Loss= 0.335091, Training Accuracy= 0.93750
# Iter 620800, Minibatch Loss= 0.305333, Training Accuracy= 0.93750
# Iter 622400, Minibatch Loss= 0.265783, Training Accuracy= 0.93750
# Iter 624000, Minibatch Loss= 0.628972, Training Accuracy= 0.81250
# Iter 625600, Minibatch Loss= 0.208223, Training Accuracy= 0.87500
# Iter 627200, Minibatch Loss= 0.304113, Training Accuracy= 0.93750
# Iter 628800, Minibatch Loss= 0.301930, Training Accuracy= 0.93750
# Iter 630400, Minibatch Loss= 0.348295, Training Accuracy= 0.81250
# Iter 632000, Minibatch Loss= 0.013138, Training Accuracy= 1.00000
# Iter 633600, Minibatch Loss= 0.265968, Training Accuracy= 0.87500
# Iter 635200, Minibatch Loss= 0.318861, Training Accuracy= 0.81250
# Iter 636800, Minibatch Loss= 0.081174, Training Accuracy= 1.00000
# Iter 638400, Minibatch Loss= 0.119545, Training Accuracy= 1.00000
# Iter 640000, Minibatch Loss= 0.072351, Training Accuracy= 1.00000
# Iter 641600, Minibatch Loss= 1.090384, Training Accuracy= 0.87500
# Iter 643200, Minibatch Loss= 0.269777, Training Accuracy= 0.87500
# Iter 644800, Minibatch Loss= 0.162650, Training Accuracy= 0.93750
# Iter 646400, Minibatch Loss= 0.021664, Training Accuracy= 1.00000
# Iter 648000, Minibatch Loss= 0.291270, Training Accuracy= 0.87500
# Iter 649600, Minibatch Loss= 0.423925, Training Accuracy= 0.81250
# Iter 651200, Minibatch Loss= 0.138443, Training Accuracy= 0.93750
# Iter 652800, Minibatch Loss= 0.368016, Training Accuracy= 0.87500
# Iter 654400, Minibatch Loss= 0.603656, Training Accuracy= 0.68750
# Iter 656000, Minibatch Loss= 0.543079, Training Accuracy= 0.87500
# Iter 657600, Minibatch Loss= 0.952486, Training Accuracy= 0.62500
# Iter 659200, Minibatch Loss= 0.554684, Training Accuracy= 0.87500
# Iter 660800, Minibatch Loss= 0.151210, Training Accuracy= 1.00000
# Iter 662400, Minibatch Loss= 0.143223, Training Accuracy= 1.00000
# Iter 664000, Minibatch Loss= 0.333670, Training Accuracy= 0.93750
# Iter 665600, Minibatch Loss= 0.312887, Training Accuracy= 0.93750
# Iter 667200, Minibatch Loss= 0.194968, Training Accuracy= 0.93750
# Iter 668800, Minibatch Loss= 0.406508, Training Accuracy= 0.87500
# Iter 670400, Minibatch Loss= 0.499891, Training Accuracy= 0.93750
# Iter 672000, Minibatch Loss= 0.194124, Training Accuracy= 0.87500
# Iter 673600, Minibatch Loss= 0.048178, Training Accuracy= 1.00000
# Iter 675200, Minibatch Loss= 0.080573, Training Accuracy= 1.00000
# Iter 676800, Minibatch Loss= 0.033048, Training Accuracy= 1.00000
# Iter 678400, Minibatch Loss= 0.139277, Training Accuracy= 0.93750
# Iter 680000, Minibatch Loss= 0.076475, Training Accuracy= 1.00000
# Iter 681600, Minibatch Loss= 0.150934, Training Accuracy= 0.93750
# Iter 683200, Minibatch Loss= 0.426661, Training Accuracy= 0.81250
# Iter 684800, Minibatch Loss= 0.093145, Training Accuracy= 0.93750
# Iter 686400, Minibatch Loss= 0.111456, Training Accuracy= 0.93750
# Iter 688000, Minibatch Loss= 0.104485, Training Accuracy= 0.93750
# Iter 689600, Minibatch Loss= 0.309447, Training Accuracy= 0.93750
# Iter 691200, Minibatch Loss= 0.283213, Training Accuracy= 0.87500
# Iter 692800, Minibatch Loss= 0.252849, Training Accuracy= 0.93750
# Iter 694400, Minibatch Loss= 0.216269, Training Accuracy= 0.93750
# Iter 696000, Minibatch Loss= 0.204734, Training Accuracy= 1.00000
# Iter 697600, Minibatch Loss= 0.035553, Training Accuracy= 1.00000
# Iter 699200, Minibatch Loss= 0.214036, Training Accuracy= 0.87500
# Iter 700800, Minibatch Loss= 0.293634, Training Accuracy= 0.93750
# Iter 702400, Minibatch Loss= 0.142118, Training Accuracy= 0.93750
# Iter 704000, Minibatch Loss= 0.261196, Training Accuracy= 0.93750
# Iter 705600, Minibatch Loss= 0.107459, Training Accuracy= 1.00000
# Iter 707200, Minibatch Loss= 0.011200, Training Accuracy= 1.00000
# Iter 708800, Minibatch Loss= 0.083507, Training Accuracy= 1.00000
# Iter 710400, Minibatch Loss= 0.096095, Training Accuracy= 1.00000
# Iter 712000, Minibatch Loss= 0.447124, Training Accuracy= 0.87500
# Iter 713600, Minibatch Loss= 0.027635, Training Accuracy= 1.00000
# Iter 715200, Minibatch Loss= 0.146725, Training Accuracy= 1.00000
# Iter 716800, Minibatch Loss= 0.029463, Training Accuracy= 1.00000
# Iter 718400, Minibatch Loss= 0.113310, Training Accuracy= 1.00000
# Iter 720000, Minibatch Loss= 0.147229, Training Accuracy= 0.93750
# Iter 721600, Minibatch Loss= 0.161166, Training Accuracy= 0.93750
# Iter 723200, Minibatch Loss= 0.029158, Training Accuracy= 1.00000
# Iter 724800, Minibatch Loss= 0.290367, Training Accuracy= 0.93750
# Iter 726400, Minibatch Loss= 0.172362, Training Accuracy= 0.87500
# Iter 728000, Minibatch Loss= 0.216161, Training Accuracy= 0.87500
# Iter 729600, Minibatch Loss= 0.049324, Training Accuracy= 1.00000
# Iter 731200, Minibatch Loss= 0.146977, Training Accuracy= 0.93750
# Iter 732800, Minibatch Loss= 0.119191, Training Accuracy= 0.93750
# Iter 734400, Minibatch Loss= 0.025835, Training Accuracy= 1.00000
# Iter 736000, Minibatch Loss= 0.071930, Training Accuracy= 1.00000
# Iter 737600, Minibatch Loss= 0.223356, Training Accuracy= 0.93750
# Iter 739200, Minibatch Loss= 0.088842, Training Accuracy= 0.93750
# Iter 740800, Minibatch Loss= 0.238743, Training Accuracy= 0.93750
# Iter 742400, Minibatch Loss= 0.071608, Training Accuracy= 1.00000
# Iter 744000, Minibatch Loss= 0.072972, Training Accuracy= 1.00000
# Iter 745600, Minibatch Loss= 0.236081, Training Accuracy= 0.87500
# Iter 747200, Minibatch Loss= 0.056945, Training Accuracy= 1.00000
# Iter 748800, Minibatch Loss= 0.729336, Training Accuracy= 0.81250
# Iter 750400, Minibatch Loss= 0.106423, Training Accuracy= 0.93750
# Iter 752000, Minibatch Loss= 0.123311, Training Accuracy= 0.93750
# Iter 753600, Minibatch Loss= 0.116806, Training Accuracy= 0.93750
# Iter 755200, Minibatch Loss= 0.024950, Training Accuracy= 1.00000
# Iter 756800, Minibatch Loss= 0.019955, Training Accuracy= 1.00000
# Iter 758400, Minibatch Loss= 0.069651, Training Accuracy= 0.93750
# Iter 760000, Minibatch Loss= 0.152225, Training Accuracy= 0.93750
# Iter 761600, Minibatch Loss= 0.193518, Training Accuracy= 0.93750
# Iter 763200, Minibatch Loss= 0.829980, Training Accuracy= 0.81250
# Iter 764800, Minibatch Loss= 0.144489, Training Accuracy= 0.93750
# Iter 766400, Minibatch Loss= 0.029197, Training Accuracy= 1.00000
# Iter 768000, Minibatch Loss= 0.097967, Training Accuracy= 0.93750
# Iter 769600, Minibatch Loss= 0.072834, Training Accuracy= 1.00000
# Iter 771200, Minibatch Loss= 0.257664, Training Accuracy= 0.93750
# Iter 772800, Minibatch Loss= 0.023938, Training Accuracy= 1.00000
# Iter 774400, Minibatch Loss= 0.338061, Training Accuracy= 0.87500
# Iter 776000, Minibatch Loss= 0.060665, Training Accuracy= 1.00000
# Iter 777600, Minibatch Loss= 0.129920, Training Accuracy= 0.93750
# Iter 779200, Minibatch Loss= 0.133565, Training Accuracy= 1.00000
# Iter 780800, Minibatch Loss= 1.225277, Training Accuracy= 0.93750
# Iter 782400, Minibatch Loss= 0.013913, Training Accuracy= 1.00000
# Iter 784000, Minibatch Loss= 0.013842, Training Accuracy= 1.00000
# Iter 785600, Minibatch Loss= 0.177099, Training Accuracy= 0.93750
# Iter 787200, Minibatch Loss= 0.227632, Training Accuracy= 0.93750
# Iter 788800, Minibatch Loss= 0.143194, Training Accuracy= 1.00000
# Iter 790400, Minibatch Loss= 0.037570, Training Accuracy= 1.00000
# Iter 792000, Minibatch Loss= 0.087097, Training Accuracy= 1.00000
# Iter 793600, Minibatch Loss= 0.018068, Training Accuracy= 1.00000
# Iter 795200, Minibatch Loss= 0.307770, Training Accuracy= 0.87500
# Iter 796800, Minibatch Loss= 0.036749, Training Accuracy= 1.00000
# Iter 798400, Minibatch Loss= 0.058247, Training Accuracy= 0.93750
# Iter 800000, Minibatch Loss= 0.126218, Training Accuracy= 0.93750
# Iter 801600, Minibatch Loss= 0.133378, Training Accuracy= 1.00000
# Iter 803200, Minibatch Loss= 0.263662, Training Accuracy= 0.87500
# Iter 804800, Minibatch Loss= 0.083038, Training Accuracy= 1.00000
# Iter 806400, Minibatch Loss= 0.055271, Training Accuracy= 1.00000
# Iter 808000, Minibatch Loss= 0.068761, Training Accuracy= 0.93750
# Iter 809600, Minibatch Loss= 0.021523, Training Accuracy= 1.00000
# Iter 811200, Minibatch Loss= 0.025903, Training Accuracy= 1.00000
# Iter 812800, Minibatch Loss= 0.091572, Training Accuracy= 1.00000
# Iter 814400, Minibatch Loss= 0.031354, Training Accuracy= 1.00000
# Iter 816000, Minibatch Loss= 0.150033, Training Accuracy= 0.93750
# Iter 817600, Minibatch Loss= 0.192294, Training Accuracy= 0.93750
# Iter 819200, Minibatch Loss= 0.141140, Training Accuracy= 0.93750
# Iter 820800, Minibatch Loss= 0.122105, Training Accuracy= 0.93750
# Iter 822400, Minibatch Loss= 0.056096, Training Accuracy= 1.00000
# Iter 824000, Minibatch Loss= 0.459866, Training Accuracy= 0.87500
# Iter 825600, Minibatch Loss= 0.493461, Training Accuracy= 0.81250
# Iter 827200, Minibatch Loss= 0.015121, Training Accuracy= 1.00000
# Iter 828800, Minibatch Loss= 0.036722, Training Accuracy= 1.00000
# Iter 830400, Minibatch Loss= 0.067351, Training Accuracy= 1.00000
# Iter 832000, Minibatch Loss= 0.257736, Training Accuracy= 0.93750
# Iter 833600, Minibatch Loss= 0.007332, Training Accuracy= 1.00000
# Iter 835200, Minibatch Loss= 0.484157, Training Accuracy= 0.93750
# Iter 836800, Minibatch Loss= 0.046911, Training Accuracy= 1.00000
# Iter 838400, Minibatch Loss= 0.052431, Training Accuracy= 1.00000
# Iter 840000, Minibatch Loss= 0.193045, Training Accuracy= 0.93750
# Iter 841600, Minibatch Loss= 0.178711, Training Accuracy= 0.93750
# Iter 843200, Minibatch Loss= 0.044874, Training Accuracy= 1.00000
# Iter 844800, Minibatch Loss= 0.077185, Training Accuracy= 0.93750
# Iter 846400, Minibatch Loss= 0.220327, Training Accuracy= 0.87500
# Iter 848000, Minibatch Loss= 0.224451, Training Accuracy= 0.93750
# Iter 849600, Minibatch Loss= 0.268700, Training Accuracy= 0.93750
# Iter 851200, Minibatch Loss= 0.109834, Training Accuracy= 0.93750
# Iter 852800, Minibatch Loss= 0.174718, Training Accuracy= 0.93750
# Iter 854400, Minibatch Loss= 0.038533, Training Accuracy= 1.00000
# Iter 856000, Minibatch Loss= 0.082573, Training Accuracy= 1.00000
# Iter 857600, Minibatch Loss= 0.024969, Training Accuracy= 1.00000
# Iter 859200, Minibatch Loss= 0.381106, Training Accuracy= 0.87500
# Iter 860800, Minibatch Loss= 0.473695, Training Accuracy= 0.93750
# Iter 862400, Minibatch Loss= 0.084925, Training Accuracy= 1.00000
# Iter 864000, Minibatch Loss= 0.046676, Training Accuracy= 1.00000
# Iter 865600, Minibatch Loss= 0.031699, Training Accuracy= 1.00000
# Iter 867200, Minibatch Loss= 0.021095, Training Accuracy= 1.00000
# Iter 868800, Minibatch Loss= 0.081914, Training Accuracy= 0.93750
# Iter 870400, Minibatch Loss= 0.032054, Training Accuracy= 1.00000
# Iter 872000, Minibatch Loss= 0.276739, Training Accuracy= 0.93750
# Iter 873600, Minibatch Loss= 0.036117, Training Accuracy= 1.00000
# Iter 875200, Minibatch Loss= 0.227180, Training Accuracy= 0.93750
# Iter 876800, Minibatch Loss= 0.041210, Training Accuracy= 1.00000
# Iter 878400, Minibatch Loss= 0.016107, Training Accuracy= 1.00000
# Iter 880000, Minibatch Loss= 0.037198, Training Accuracy= 1.00000
# Iter 881600, Minibatch Loss= 0.166113, Training Accuracy= 0.93750
# Iter 883200, Minibatch Loss= 0.001032, Training Accuracy= 1.00000
# Iter 884800, Minibatch Loss= 0.040161, Training Accuracy= 1.00000
# Iter 886400, Minibatch Loss= 0.215250, Training Accuracy= 0.93750
# Iter 888000, Minibatch Loss= 0.115718, Training Accuracy= 0.93750
# Iter 889600, Minibatch Loss= 0.182065, Training Accuracy= 0.93750
# Iter 891200, Minibatch Loss= 0.010188, Training Accuracy= 1.00000
# Iter 892800, Minibatch Loss= 0.806162, Training Accuracy= 0.81250
# Iter 894400, Minibatch Loss= 0.030053, Training Accuracy= 1.00000
# Iter 896000, Minibatch Loss= 0.022982, Training Accuracy= 1.00000
# Iter 897600, Minibatch Loss= 0.047171, Training Accuracy= 1.00000
# Iter 899200, Minibatch Loss= 0.013865, Training Accuracy= 1.00000
# Iter 900800, Minibatch Loss= 0.028134, Training Accuracy= 1.00000
# Iter 902400, Minibatch Loss= 0.062168, Training Accuracy= 1.00000
# Iter 904000, Minibatch Loss= 0.077676, Training Accuracy= 0.93750
# Iter 905600, Minibatch Loss= 0.151990, Training Accuracy= 0.93750
# Iter 907200, Minibatch Loss= 0.071758, Training Accuracy= 0.93750
# Iter 908800, Minibatch Loss= 0.057301, Training Accuracy= 1.00000
# Iter 910400, Minibatch Loss= 0.007399, Training Accuracy= 1.00000
# Iter 912000, Minibatch Loss= 0.401070, Training Accuracy= 0.87500
# Iter 913600, Minibatch Loss= 0.307321, Training Accuracy= 0.93750
# Iter 915200, Minibatch Loss= 0.048152, Training Accuracy= 1.00000
# Iter 916800, Minibatch Loss= 0.017608, Training Accuracy= 1.00000
# Iter 918400, Minibatch Loss= 0.066692, Training Accuracy= 1.00000
# Iter 920000, Minibatch Loss= 0.009255, Training Accuracy= 1.00000
# Iter 921600, Minibatch Loss= 0.029604, Training Accuracy= 1.00000
# Iter 923200, Minibatch Loss= 0.177283, Training Accuracy= 0.93750
# Iter 924800, Minibatch Loss= 0.217524, Training Accuracy= 0.93750
# Iter 926400, Minibatch Loss= 0.030159, Training Accuracy= 1.00000
# Iter 928000, Minibatch Loss= 0.163086, Training Accuracy= 0.93750
# Iter 929600, Minibatch Loss= 0.041435, Training Accuracy= 1.00000
# Iter 931200, Minibatch Loss= 0.214886, Training Accuracy= 0.93750
# Iter 932800, Minibatch Loss= 0.058346, Training Accuracy= 1.00000
# Iter 934400, Minibatch Loss= 0.118266, Training Accuracy= 0.93750
# Iter 936000, Minibatch Loss= 0.017406, Training Accuracy= 1.00000
# Iter 937600, Minibatch Loss= 0.096211, Training Accuracy= 1.00000
# Iter 939200, Minibatch Loss= 0.028340, Training Accuracy= 1.00000
# Iter 940800, Minibatch Loss= 0.380449, Training Accuracy= 0.93750
# Iter 942400, Minibatch Loss= 0.015884, Training Accuracy= 1.00000
# Iter 944000, Minibatch Loss= 0.284164, Training Accuracy= 0.93750
# Iter 945600, Minibatch Loss= 0.030307, Training Accuracy= 1.00000
# Iter 947200, Minibatch Loss= 0.084295, Training Accuracy= 0.93750
# Iter 948800, Minibatch Loss= 0.028708, Training Accuracy= 1.00000
# Iter 950400, Minibatch Loss= 0.151139, Training Accuracy= 0.93750
# Iter 952000, Minibatch Loss= 0.523642, Training Accuracy= 0.81250
# Iter 953600, Minibatch Loss= 0.921984, Training Accuracy= 0.87500
# Iter 955200, Minibatch Loss= 0.681917, Training Accuracy= 0.81250
# Iter 956800, Minibatch Loss= 0.044308, Training Accuracy= 1.00000
# Iter 958400, Minibatch Loss= 0.504288, Training Accuracy= 0.93750
# Iter 960000, Minibatch Loss= 0.055975, Training Accuracy= 1.00000
# Iter 961600, Minibatch Loss= 0.017873, Training Accuracy= 1.00000
# Iter 963200, Minibatch Loss= 0.125642, Training Accuracy= 1.00000
# Iter 964800, Minibatch Loss= 0.011609, Training Accuracy= 1.00000
# Iter 966400, Minibatch Loss= 0.063837, Training Accuracy= 1.00000
# Iter 968000, Minibatch Loss= 0.054064, Training Accuracy= 1.00000
# Iter 969600, Minibatch Loss= 0.023075, Training Accuracy= 1.00000
# Iter 971200, Minibatch Loss= 0.019681, Training Accuracy= 1.00000
# Iter 972800, Minibatch Loss= 0.211211, Training Accuracy= 0.93750
# Iter 974400, Minibatch Loss= 0.005133, Training Accuracy= 1.00000
# Iter 976000, Minibatch Loss= 0.034852, Training Accuracy= 1.00000
# Iter 977600, Minibatch Loss= 0.011308, Training Accuracy= 1.00000
# Iter 979200, Minibatch Loss= 0.166749, Training Accuracy= 0.93750
# Iter 980800, Minibatch Loss= 0.249940, Training Accuracy= 0.87500
# Iter 982400, Minibatch Loss= 0.014159, Training Accuracy= 1.00000
# Iter 984000, Minibatch Loss= 0.178849, Training Accuracy= 0.87500
# Iter 985600, Minibatch Loss= 0.143472, Training Accuracy= 0.93750
# Iter 987200, Minibatch Loss= 0.316202, Training Accuracy= 0.87500
# Iter 988800, Minibatch Loss= 0.099175, Training Accuracy= 0.93750
# Iter 990400, Minibatch Loss= 0.090208, Training Accuracy= 0.93750
# Iter 992000, Minibatch Loss= 0.020143, Training Accuracy= 1.00000
# Iter 993600, Minibatch Loss= 0.018249, Training Accuracy= 1.00000
# Iter 995200, Minibatch Loss= 0.212338, Training Accuracy= 0.87500
# Iter 996800, Minibatch Loss= 0.264631, Training Accuracy= 0.93750
# Iter 998400, Minibatch Loss= 0.493244, Training Accuracy= 0.93750
# Iter 1000000, Minibatch Loss= 0.051910, Training Accuracy= 1.00000
# Iter 1001600, Minibatch Loss= 0.213691, Training Accuracy= 0.93750
# Iter 1003200, Minibatch Loss= 0.118371, Training Accuracy= 0.87500
# Iter 1004800, Minibatch Loss= 0.021371, Training Accuracy= 1.00000
# Iter 1006400, Minibatch Loss= 0.078902, Training Accuracy= 1.00000
# Iter 1008000, Minibatch Loss= 0.070358, Training Accuracy= 1.00000
# Iter 1009600, Minibatch Loss= 0.044924, Training Accuracy= 1.00000
# Iter 1011200, Minibatch Loss= 0.018140, Training Accuracy= 1.00000
# Iter 1012800, Minibatch Loss= 0.011853, Training Accuracy= 1.00000
# Iter 1014400, Minibatch Loss= 0.021976, Training Accuracy= 1.00000
# Iter 1016000, Minibatch Loss= 0.058247, Training Accuracy= 1.00000
# Iter 1017600, Minibatch Loss= 0.038893, Training Accuracy= 1.00000
# Iter 1019200, Minibatch Loss= 0.036110, Training Accuracy= 1.00000
# Iter 1020800, Minibatch Loss= 0.051549, Training Accuracy= 1.00000
# Iter 1022400, Minibatch Loss= 0.107426, Training Accuracy= 0.93750
# Iter 1024000, Minibatch Loss= 0.523085, Training Accuracy= 0.75000
# Iter 1025600, Minibatch Loss= 0.026554, Training Accuracy= 1.00000
# Iter 1027200, Minibatch Loss= 0.009079, Training Accuracy= 1.00000
# Iter 1028800, Minibatch Loss= 0.003367, Training Accuracy= 1.00000
# Iter 1030400, Minibatch Loss= 0.045295, Training Accuracy= 1.00000
# Iter 1032000, Minibatch Loss= 0.001194, Training Accuracy= 1.00000
# Iter 1033600, Minibatch Loss= 0.069238, Training Accuracy= 1.00000
# Iter 1035200, Minibatch Loss= 0.059815, Training Accuracy= 0.93750
# Iter 1036800, Minibatch Loss= 0.158170, Training Accuracy= 0.93750
# Iter 1038400, Minibatch Loss= 0.020750, Training Accuracy= 1.00000
# Iter 1040000, Minibatch Loss= 0.011685, Training Accuracy= 1.00000
# Iter 1041600, Minibatch Loss= 0.020590, Training Accuracy= 1.00000
# Iter 1043200, Minibatch Loss= 0.023520, Training Accuracy= 1.00000
# Iter 1044800, Minibatch Loss= 0.005564, Training Accuracy= 1.00000
# Iter 1046400, Minibatch Loss= 0.007919, Training Accuracy= 1.00000
# Iter 1048000, Minibatch Loss= 0.049198, Training Accuracy= 1.00000
# Iter 1049600, Minibatch Loss= 0.425695, Training Accuracy= 0.87500
# Iter 1051200, Minibatch Loss= 0.279420, Training Accuracy= 0.93750
# Iter 1052800, Minibatch Loss= 0.002944, Training Accuracy= 1.00000
# Iter 1054400, Minibatch Loss= 0.272112, Training Accuracy= 0.93750
# Iter 1056000, Minibatch Loss= 0.141855, Training Accuracy= 0.93750
# Iter 1057600, Minibatch Loss= 0.235137, Training Accuracy= 0.93750
# Iter 1059200, Minibatch Loss= 0.139078, Training Accuracy= 0.93750
# Iter 1060800, Minibatch Loss= 0.102883, Training Accuracy= 0.93750
# Iter 1062400, Minibatch Loss= 0.009316, Training Accuracy= 1.00000
# Iter 1064000, Minibatch Loss= 0.168265, Training Accuracy= 0.93750
# Iter 1065600, Minibatch Loss= 0.122764, Training Accuracy= 0.93750
# Iter 1067200, Minibatch Loss= 0.031481, Training Accuracy= 1.00000
# Iter 1068800, Minibatch Loss= 0.013514, Training Accuracy= 1.00000
# Iter 1070400, Minibatch Loss= 0.040264, Training Accuracy= 1.00000
# Iter 1072000, Minibatch Loss= 0.012728, Training Accuracy= 1.00000
# Iter 1073600, Minibatch Loss= 0.427965, Training Accuracy= 0.93750
# Iter 1075200, Minibatch Loss= 0.012248, Training Accuracy= 1.00000
# Iter 1076800, Minibatch Loss= 0.087367, Training Accuracy= 0.93750
# Iter 1078400, Minibatch Loss= 0.008691, Training Accuracy= 1.00000
# Iter 1080000, Minibatch Loss= 0.007239, Training Accuracy= 1.00000
# Iter 1081600, Minibatch Loss= 0.047952, Training Accuracy= 1.00000
# Iter 1083200, Minibatch Loss= 0.176135, Training Accuracy= 0.93750
# Iter 1084800, Minibatch Loss= 0.009779, Training Accuracy= 1.00000
# Iter 1086400, Minibatch Loss= 0.030241, Training Accuracy= 1.00000
# Iter 1088000, Minibatch Loss= 0.049123, Training Accuracy= 1.00000
# Iter 1089600, Minibatch Loss= 0.123005, Training Accuracy= 0.93750
# Iter 1091200, Minibatch Loss= 0.315178, Training Accuracy= 0.87500
# Iter 1092800, Minibatch Loss= 0.022131, Training Accuracy= 1.00000
# Iter 1094400, Minibatch Loss= 0.201532, Training Accuracy= 0.93750
# Iter 1096000, Minibatch Loss= 0.027896, Training Accuracy= 1.00000
# Iter 1097600, Minibatch Loss= 0.334207, Training Accuracy= 0.93750
# Iter 1099200, Minibatch Loss= 0.029165, Training Accuracy= 1.00000
# Iter 1100800, Minibatch Loss= 0.174276, Training Accuracy= 0.87500
# Iter 1102400, Minibatch Loss= 0.153829, Training Accuracy= 0.87500
# Iter 1104000, Minibatch Loss= 0.000410, Training Accuracy= 1.00000
# Iter 1105600, Minibatch Loss= 0.035046, Training Accuracy= 1.00000
# Iter 1107200, Minibatch Loss= 0.049096, Training Accuracy= 1.00000
# Iter 1108800, Minibatch Loss= 0.018120, Training Accuracy= 1.00000
# Iter 1110400, Minibatch Loss= 0.023282, Training Accuracy= 1.00000
# Iter 1112000, Minibatch Loss= 0.131492, Training Accuracy= 1.00000
# Iter 1113600, Minibatch Loss= 0.071608, Training Accuracy= 1.00000
# Iter 1115200, Minibatch Loss= 0.009132, Training Accuracy= 1.00000
# Iter 1116800, Minibatch Loss= 0.050856, Training Accuracy= 1.00000
# Iter 1118400, Minibatch Loss= 0.182076, Training Accuracy= 0.93750
# Iter 1120000, Minibatch Loss= 0.569708, Training Accuracy= 0.93750
# Iter 1121600, Minibatch Loss= 0.006087, Training Accuracy= 1.00000
# Iter 1123200, Minibatch Loss= 0.007088, Training Accuracy= 1.00000
# Iter 1124800, Minibatch Loss= 0.129872, Training Accuracy= 0.93750
# Iter 1126400, Minibatch Loss= 0.021468, Training Accuracy= 1.00000
# Iter 1128000, Minibatch Loss= 0.010751, Training Accuracy= 1.00000
# Iter 1129600, Minibatch Loss= 0.009413, Training Accuracy= 1.00000
# Iter 1131200, Minibatch Loss= 0.148182, Training Accuracy= 0.93750
# Iter 1132800, Minibatch Loss= 0.071779, Training Accuracy= 1.00000
# Iter 1134400, Minibatch Loss= 0.005125, Training Accuracy= 1.00000
# Iter 1136000, Minibatch Loss= 0.033623, Training Accuracy= 1.00000
# Iter 1137600, Minibatch Loss= 0.368432, Training Accuracy= 0.93750
# Iter 1139200, Minibatch Loss= 0.127511, Training Accuracy= 0.93750
# Iter 1140800, Minibatch Loss= 0.020845, Training Accuracy= 1.00000
# Iter 1142400, Minibatch Loss= 0.002198, Training Accuracy= 1.00000
# Iter 1144000, Minibatch Loss= 0.074516, Training Accuracy= 0.93750
# Iter 1145600, Minibatch Loss= 0.017926, Training Accuracy= 1.00000
# Iter 1147200, Minibatch Loss= 0.297127, Training Accuracy= 0.87500
# Iter 1148800, Minibatch Loss= 0.003504, Training Accuracy= 1.00000
# Iter 1150400, Minibatch Loss= 0.024227, Training Accuracy= 1.00000
# Iter 1152000, Minibatch Loss= 0.386849, Training Accuracy= 0.87500
# Iter 1153600, Minibatch Loss= 0.079828, Training Accuracy= 0.93750
# Iter 1155200, Minibatch Loss= 0.151703, Training Accuracy= 0.93750
# Iter 1156800, Minibatch Loss= 0.016440, Training Accuracy= 1.00000
# Iter 1158400, Minibatch Loss= 0.030990, Training Accuracy= 1.00000
# Iter 1160000, Minibatch Loss= 0.013157, Training Accuracy= 1.00000
# Iter 1161600, Minibatch Loss= 0.059814, Training Accuracy= 1.00000
# ...
# Iter 1219200, Minibatch Loss= 0.007209, Training Accuracy= 1.00000
# Iter 1220800, Minibatch Loss= 0.026254, Training Accuracy= 1.00000
# Iter 1222400, Minibatch Loss= 0.056243, Training Accuracy= 1.00000
# Iter 1224000, Minibatch Loss= 0.062185, Training Accuracy= 1.00000
# Iter 1225600, Minibatch Loss= 0.004638, Training Accuracy= 1.00000
# Iter 1227200, Minibatch Loss= 0.048383, Training Accuracy= 1.00000
# Iter 1228800, Minibatch Loss= 0.637237, Training Accuracy= 0.87500
# Iter 1230400, Minibatch Loss= 0.268486, Training Accuracy= 0.93750
# Iter 1232000, Minibatch Loss= 0.013465, Training Accuracy= 1.00000
# Iter 1233600, Minibatch Loss= 0.086513, Training Accuracy= 0.93750
# Iter 1235200, Minibatch Loss= 0.508756, Training Accuracy= 0.87500
# Iter 1236800, Minibatch Loss= 0.007008, Training Accuracy= 1.00000
# Iter 1238400, Minibatch Loss= 0.043754, Training Accuracy= 1.00000
# Iter 1240000, Minibatch Loss= 0.005592, Training Accuracy= 1.00000
# Iter 1241600, Minibatch Loss= 0.001327, Training Accuracy= 1.00000
# Iter 1243200, Minibatch Loss= 0.001620, Training Accuracy= 1.00000
# Iter 1244800, Minibatch Loss= 0.107515, Training Accuracy= 0.93750
# Iter 1246400, Minibatch Loss= 0.166997, Training Accuracy= 0.93750
# Iter 1248000, Minibatch Loss= 0.322351, Training Accuracy= 0.93750
# Iter 1249600, Minibatch Loss= 0.027344, Training Accuracy= 1.00000
# Iter 1251200, Minibatch Loss= 0.043166, Training Accuracy= 1.00000
# Iter 1252800, Minibatch Loss= 0.276499, Training Accuracy= 0.93750
# Iter 1254400, Minibatch Loss= 0.009976, Training Accuracy= 1.00000
# Iter 1256000, Minibatch Loss= 0.010405, Training Accuracy= 1.00000
# Iter 1257600, Minibatch Loss= 0.112650, Training Accuracy= 0.93750
# Iter 1259200, Minibatch Loss= 0.161347, Training Accuracy= 0.87500
# Iter 1260800, Minibatch Loss= 0.243015, Training Accuracy= 0.87500
# Iter 1262400, Minibatch Loss= 0.026029, Training Accuracy= 1.00000
# Iter 1264000, Minibatch Loss= 0.005800, Training Accuracy= 1.00000
# Iter 1265600, Minibatch Loss= 0.007317, Training Accuracy= 1.00000
# Iter 1267200, Minibatch Loss= 0.001389, Training Accuracy= 1.00000
# Iter 1268800, Minibatch Loss= 0.149028, Training Accuracy= 0.93750
# Iter 1270400, Minibatch Loss= 0.057323, Training Accuracy= 1.00000
# Iter 1272000, Minibatch Loss= 0.140701, Training Accuracy= 0.93750
# Iter 1273600, Minibatch Loss= 0.002483, Training Accuracy= 1.00000
# Iter 1275200, Minibatch Loss= 0.009976, Training Accuracy= 1.00000
# Iter 1276800, Minibatch Loss= 0.014011, Training Accuracy= 1.00000
# Iter 1278400, Minibatch Loss= 0.014483, Training Accuracy= 1.00000
# Iter 1280000, Minibatch Loss= 0.044793, Training Accuracy= 1.00000
# Iter 1281600, Minibatch Loss= 0.060931, Training Accuracy= 1.00000
# Iter 1283200, Minibatch Loss= 0.025636, Training Accuracy= 1.00000
# Iter 1284800, Minibatch Loss= 0.001887, Training Accuracy= 1.00000
# Iter 1286400, Minibatch Loss= 0.001947, Training Accuracy= 1.00000
# Iter 1288000, Minibatch Loss= 0.017412, Training Accuracy= 1.00000
# Iter 1289600, Minibatch Loss= 0.006886, Training Accuracy= 1.00000
# Iter 1291200, Minibatch Loss= 0.241114, Training Accuracy= 0.93750
# Iter 1292800, Minibatch Loss= 0.081914, Training Accuracy= 0.93750
# Iter 1294400, Minibatch Loss= 0.014280, Training Accuracy= 1.00000
# Iter 1296000, Minibatch Loss= 0.003112, Training Accuracy= 1.00000
# Iter 1297600, Minibatch Loss= 0.448990, Training Accuracy= 0.87500
# Iter 1299200, Minibatch Loss= 0.062995, Training Accuracy= 1.00000
# Iter 1300800, Minibatch Loss= 0.033897, Training Accuracy= 1.00000
# Iter 1302400, Minibatch Loss= 0.197568, Training Accuracy= 0.87500
# Iter 1304000, Minibatch Loss= 0.012597, Training Accuracy= 1.00000
# Iter 1305600, Minibatch Loss= 0.004952, Training Accuracy= 1.00000
# Iter 1307200, Minibatch Loss= 0.042604, Training Accuracy= 1.00000
# Iter 1308800, Minibatch Loss= 0.157839, Training Accuracy= 0.93750
# Iter 1310400, Minibatch Loss= 0.006103, Training Accuracy= 1.00000
# Iter 1312000, Minibatch Loss= 0.000709, Training Accuracy= 1.00000
# Iter 1313600, Minibatch Loss= 0.026119, Training Accuracy= 1.00000
# Iter 1315200, Minibatch Loss= 0.006008, Training Accuracy= 1.00000
# Iter 1316800, Minibatch Loss= 0.879376, Training Accuracy= 0.87500
# Iter 1318400, Minibatch Loss= 0.026169, Training Accuracy= 1.00000
# Iter 1320000, Minibatch Loss= 0.003502, Training Accuracy= 1.00000
# Iter 1321600, Minibatch Loss= 0.025562, Training Accuracy= 1.00000
# Iter 1323200, Minibatch Loss= 0.018794, Training Accuracy= 1.00000
# Iter 1324800, Minibatch Loss= 0.005907, Training Accuracy= 1.00000
# Iter 1326400, Minibatch Loss= 0.014358, Training Accuracy= 1.00000
# Iter 1328000, Minibatch Loss= 0.001430, Training Accuracy= 1.00000
# Iter 1329600, Minibatch Loss= 0.026650, Training Accuracy= 1.00000
# Iter 1331200, Minibatch Loss= 0.108185, Training Accuracy= 0.93750
# Iter 1332800, Minibatch Loss= 0.007423, Training Accuracy= 1.00000
# Iter 1334400, Minibatch Loss= 0.036215, Training Accuracy= 1.00000
# Iter 1336000, Minibatch Loss= 0.063563, Training Accuracy= 0.93750
# Iter 1337600, Minibatch Loss= 0.003359, Training Accuracy= 1.00000
# Iter 1339200, Minibatch Loss= 0.051148, Training Accuracy= 1.00000
# Iter 1340800, Minibatch Loss= 0.004523, Training Accuracy= 1.00000
# Iter 1342400, Minibatch Loss= 0.001281, Training Accuracy= 1.00000
# Iter 1344000, Minibatch Loss= 0.009297, Training Accuracy= 1.00000
# Iter 1345600, Minibatch Loss= 0.002483, Training Accuracy= 1.00000
# Iter 1347200, Minibatch Loss= 0.029433, Training Accuracy= 1.00000
# Iter 1348800, Minibatch Loss= 0.062704, Training Accuracy= 1.00000
# Iter 1350400, Minibatch Loss= 0.011384, Training Accuracy= 1.00000
# Iter 1352000, Minibatch Loss= 0.035664, Training Accuracy= 1.00000
# Iter 1353600, Minibatch Loss= 0.096173, Training Accuracy= 1.00000
# Iter 1355200, Minibatch Loss= 0.046215, Training Accuracy= 1.00000
# Iter 1356800, Minibatch Loss= 0.047858, Training Accuracy= 1.00000
# Iter 1358400, Minibatch Loss= 0.057532, Training Accuracy= 1.00000
# Iter 1360000, Minibatch Loss= 0.019634, Training Accuracy= 1.00000
# Iter 1361600, Minibatch Loss= 0.093078, Training Accuracy= 0.93750
# Iter 1363200, Minibatch Loss= 0.065872, Training Accuracy= 0.93750
# Iter 1364800, Minibatch Loss= 0.134260, Training Accuracy= 0.93750
# Iter 1366400, Minibatch Loss= 0.057069, Training Accuracy= 1.00000
# Iter 1368000, Minibatch Loss= 0.032363, Training Accuracy= 1.00000
# Iter 1369600, Minibatch Loss= 0.032943, Training Accuracy= 1.00000
# Iter 1371200, Minibatch Loss= 0.001232, Training Accuracy= 1.00000
# Iter 1372800, Minibatch Loss= 0.621210, Training Accuracy= 0.93750
# Iter 1374400, Minibatch Loss= 0.079816, Training Accuracy= 1.00000
# Iter 1376000, Minibatch Loss= 0.003312, Training Accuracy= 1.00000
# Iter 1377600, Minibatch Loss= 0.014940, Training Accuracy= 1.00000
# Iter 1379200, Minibatch Loss= 0.005890, Training Accuracy= 1.00000
# Iter 1380800, Minibatch Loss= 0.000877, Training Accuracy= 1.00000
# Iter 1382400, Minibatch Loss= 0.025886, Training Accuracy= 1.00000
# Iter 1384000, Minibatch Loss= 0.033364, Training Accuracy= 1.00000
# Iter 1385600, Minibatch Loss= 0.013977, Training Accuracy= 1.00000
# Iter 1387200, Minibatch Loss= 0.057949, Training Accuracy= 1.00000
# Iter 1388800, Minibatch Loss= 0.065666, Training Accuracy= 1.00000
# Iter 1390400, Minibatch Loss= 0.010795, Training Accuracy= 1.00000
# Iter 1392000, Minibatch Loss= 0.014010, Training Accuracy= 1.00000
# Iter 1393600, Minibatch Loss= 0.001479, Training Accuracy= 1.00000
# Iter 1395200, Minibatch Loss= 0.152826, Training Accuracy= 0.93750
# Iter 1396800, Minibatch Loss= 0.010680, Training Accuracy= 1.00000
# Iter 1398400, Minibatch Loss= 0.001267, Training Accuracy= 1.00000
# Iter 1400000, Minibatch Loss= 0.002672, Training Accuracy= 1.00000
# Iter 1401600, Minibatch Loss= 0.082556, Training Accuracy= 0.93750
# Iter 1403200, Minibatch Loss= 0.006875, Training Accuracy= 1.00000
# Iter 1404800, Minibatch Loss= 0.030408, Training Accuracy= 1.00000
# Iter 1406400, Minibatch Loss= 0.016352, Training Accuracy= 1.00000
# Iter 1408000, Minibatch Loss= 0.003973, Training Accuracy= 1.00000
# Iter 1409600, Minibatch Loss= 0.502262, Training Accuracy= 0.93750
# Iter 1411200, Minibatch Loss= 0.020616, Training Accuracy= 1.00000
# Iter 1412800, Minibatch Loss= 0.119856, Training Accuracy= 0.93750
# Iter 1414400, Minibatch Loss= 0.002835, Training Accuracy= 1.00000
# Iter 1416000, Minibatch Loss= 0.033216, Training Accuracy= 1.00000
# Iter 1417600, Minibatch Loss= 0.296789, Training Accuracy= 0.87500
# Iter 1419200, Minibatch Loss= 0.050264, Training Accuracy= 0.93750
# Iter 1420800, Minibatch Loss= 0.045825, Training Accuracy= 1.00000
# Iter 1422400, Minibatch Loss= 0.018161, Training Accuracy= 1.00000
# Iter 1424000, Minibatch Loss= 0.026139, Training Accuracy= 1.00000
# Iter 1425600, Minibatch Loss= 0.033522, Training Accuracy= 1.00000
# Iter 1427200, Minibatch Loss= 0.009345, Training Accuracy= 1.00000
# Iter 1428800, Minibatch Loss= 0.006621, Training Accuracy= 1.00000
# Iter 1430400, Minibatch Loss= 0.011370, Training Accuracy= 1.00000
# Iter 1432000, Minibatch Loss= 0.060980, Training Accuracy= 0.93750
# Iter 1433600, Minibatch Loss= 0.046720, Training Accuracy= 1.00000
# Iter 1435200, Minibatch Loss= 0.352006, Training Accuracy= 0.93750
# Iter 1436800, Minibatch Loss= 0.003003, Training Accuracy= 1.00000
# Iter 1438400, Minibatch Loss= 0.013772, Training Accuracy= 1.00000
# Iter 1440000, Minibatch Loss= 0.342570, Training Accuracy= 0.93750
# Iter 1441600, Minibatch Loss= 0.159122, Training Accuracy= 0.93750
# Iter 1443200, Minibatch Loss= 0.019046, Training Accuracy= 1.00000
# Iter 1444800, Minibatch Loss= 0.065118, Training Accuracy= 0.93750
# Iter 1446400, Minibatch Loss= 0.003803, Training Accuracy= 1.00000
# Iter 1448000, Minibatch Loss= 0.052173, Training Accuracy= 1.00000
# Iter 1449600, Minibatch Loss= 0.018558, Training Accuracy= 1.00000
# Iter 1451200, Minibatch Loss= 0.005298, Training Accuracy= 1.00000
# Iter 1452800, Minibatch Loss= 0.010582, Training Accuracy= 1.00000
# Iter 1454400, Minibatch Loss= 0.067012, Training Accuracy= 0.93750
# Iter 1456000, Minibatch Loss= 0.044973, Training Accuracy= 1.00000
# Iter 1457600, Minibatch Loss= 0.005986, Training Accuracy= 1.00000
# Iter 1459200, Minibatch Loss= 0.104307, Training Accuracy= 0.93750
# Iter 1460800, Minibatch Loss= 0.005008, Training Accuracy= 1.00000
# Iter 1462400, Minibatch Loss= 0.090875, Training Accuracy= 1.00000
# Iter 1464000, Minibatch Loss= 0.034749, Training Accuracy= 1.00000
# Iter 1465600, Minibatch Loss= 0.039687, Training Accuracy= 1.00000
# Iter 1467200, Minibatch Loss= 0.008503, Training Accuracy= 1.00000
# Iter 1468800, Minibatch Loss= 0.004975, Training Accuracy= 1.00000
# Iter 1470400, Minibatch Loss= 0.008801, Training Accuracy= 1.00000
# Iter 1472000, Minibatch Loss= 0.036099, Training Accuracy= 1.00000
# Iter 1473600, Minibatch Loss= 0.012778, Training Accuracy= 1.00000
# Iter 1475200, Minibatch Loss= 0.006532, Training Accuracy= 1.00000
# Iter 1476800, Minibatch Loss= 0.009802, Training Accuracy= 1.00000
# Iter 1478400, Minibatch Loss= 0.012883, Training Accuracy= 1.00000
# Iter 1480000, Minibatch Loss= 0.005609, Training Accuracy= 1.00000
# Iter 1481600, Minibatch Loss= 0.017340, Training Accuracy= 1.00000
# Iter 1483200, Minibatch Loss= 0.002904, Training Accuracy= 1.00000
# Iter 1484800, Minibatch Loss= 0.014368, Training Accuracy= 1.00000
# Iter 1486400, Minibatch Loss= 0.267665, Training Accuracy= 0.93750
# Iter 1488000, Minibatch Loss= 0.037670, Training Accuracy= 1.00000
# Iter 1489600, Minibatch Loss= 0.006704, Training Accuracy= 1.00000
# Iter 1491200, Minibatch Loss= 0.288529, Training Accuracy= 0.93750
# Iter 1492800, Minibatch Loss= 0.017804, Training Accuracy= 1.00000
# Iter 1494400, Minibatch Loss= 0.067605, Training Accuracy= 0.93750
# Iter 1496000, Minibatch Loss= 0.010732, Training Accuracy= 1.00000
# Iter 1497600, Minibatch Loss= 0.012199, Training Accuracy= 1.00000
# Iter 1499200, Minibatch Loss= 0.004712, Training Accuracy= 1.00000
# Iter 1500800, Minibatch Loss= 0.065855, Training Accuracy= 0.93750
# Iter 1502400, Minibatch Loss= 0.045053, Training Accuracy= 1.00000
# Iter 1504000, Minibatch Loss= 0.002999, Training Accuracy= 1.00000
# Iter 1505600, Minibatch Loss= 0.004891, Training Accuracy= 1.00000
# Iter 1507200, Minibatch Loss= 0.053387, Training Accuracy= 1.00000
# Iter 1508800, Minibatch Loss= 0.044270, Training Accuracy= 1.00000
# Iter 1510400, Minibatch Loss= 0.002188, Training Accuracy= 1.00000
# Iter 1512000, Minibatch Loss= 0.007000, Training Accuracy= 1.00000
# Iter 1513600, Minibatch Loss= 0.001183, Training Accuracy= 1.00000
# Iter 1515200, Minibatch Loss= 0.014999, Training Accuracy= 1.00000
# Iter 1516800, Minibatch Loss= 0.067939, Training Accuracy= 1.00000
# Iter 1518400, Minibatch Loss= 0.002829, Training Accuracy= 1.00000
# Iter 1520000, Minibatch Loss= 0.000814, Training Accuracy= 1.00000
# Iter 1521600, Minibatch Loss= 0.203502, Training Accuracy= 0.93750
# Iter 1523200, Minibatch Loss= 0.111207, Training Accuracy= 0.93750
# Iter 1524800, Minibatch Loss= 0.008448, Training Accuracy= 1.00000
# Iter 1526400, Minibatch Loss= 0.138711, Training Accuracy= 0.93750
# Iter 1528000, Minibatch Loss= 0.000632, Training Accuracy= 1.00000
# Iter 1529600, Minibatch Loss= 0.001875, Training Accuracy= 1.00000
# Iter 1531200, Minibatch Loss= 0.012083, Training Accuracy= 1.00000
# Iter 1532800, Minibatch Loss= 0.007687, Training Accuracy= 1.00000
# Iter 1534400, Minibatch Loss= 0.008661, Training Accuracy= 1.00000
# Iter 1536000, Minibatch Loss= 0.006889, Training Accuracy= 1.00000
# Iter 1537600, Minibatch Loss= 0.000160, Training Accuracy= 1.00000
# Iter 1539200, Minibatch Loss= 0.010698, Training Accuracy= 1.00000
# Iter 1540800, Minibatch Loss= 0.007507, Training Accuracy= 1.00000
# Iter 1542400, Minibatch Loss= 0.001938, Training Accuracy= 1.00000
# Iter 1544000, Minibatch Loss= 0.008700, Training Accuracy= 1.00000
# Iter 1545600, Minibatch Loss= 0.020208, Training Accuracy= 1.00000
# Iter 1547200, Minibatch Loss= 0.004801, Training Accuracy= 1.00000
# Iter 1548800, Minibatch Loss= 0.010053, Training Accuracy= 1.00000
# Iter 1550400, Minibatch Loss= 0.007661, Training Accuracy= 1.00000
# Iter 1552000, Minibatch Loss= 0.000196, Training Accuracy= 1.00000
# Iter 1553600, Minibatch Loss= 0.009244, Training Accuracy= 1.00000
# Iter 1555200, Minibatch Loss= 0.008170, Training Accuracy= 1.00000
# Iter 1556800, Minibatch Loss= 0.021208, Training Accuracy= 1.00000
# Iter 1558400, Minibatch Loss= 0.070516, Training Accuracy= 1.00000
# Iter 1560000, Minibatch Loss= 0.585872, Training Accuracy= 0.93750
# Iter 1561600, Minibatch Loss= 0.020282, Training Accuracy= 1.00000
# Iter 1563200, Minibatch Loss= 0.009087, Training Accuracy= 1.00000
# Iter 1564800, Minibatch Loss= 0.017944, Training Accuracy= 1.00000
# Iter 1566400, Minibatch Loss= 0.005328, Training Accuracy= 1.00000
# Iter 1568000, Minibatch Loss= 0.018784, Training Accuracy= 1.00000
# Iter 1569600, Minibatch Loss= 0.004574, Training Accuracy= 1.00000
# Iter 1571200, Minibatch Loss= 0.020529, Training Accuracy= 1.00000
# Iter 1572800, Minibatch Loss= 0.080169, Training Accuracy= 0.93750
# Iter 1574400, Minibatch Loss= 0.089661, Training Accuracy= 0.93750
# Iter 1576000, Minibatch Loss= 0.101635, Training Accuracy= 1.00000
# Iter 1577600, Minibatch Loss= 0.025148, Training Accuracy= 1.00000
# Iter 1579200, Minibatch Loss= 0.000391, Training Accuracy= 1.00000
# Iter 1580800, Minibatch Loss= 0.002792, Training Accuracy= 1.00000
# Iter 1582400, Minibatch Loss= 0.235508, Training Accuracy= 0.93750
# Iter 1584000, Minibatch Loss= 0.009228, Training Accuracy= 1.00000
# Iter 1585600, Minibatch Loss= 0.109523, Training Accuracy= 0.93750
# Iter 1587200, Minibatch Loss= 0.011463, Training Accuracy= 1.00000
# Iter 1588800, Minibatch Loss= 0.366323, Training Accuracy= 0.93750
# Iter 1590400, Minibatch Loss= 0.026323, Training Accuracy= 1.00000
# Iter 1592000, Minibatch Loss= 0.014781, Training Accuracy= 1.00000
# Iter 1593600, Minibatch Loss= 0.006671, Training Accuracy= 1.00000
# Iter 1595200, Minibatch Loss= 0.155967, Training Accuracy= 0.93750
# Iter 1596800, Minibatch Loss= 0.001320, Training Accuracy= 1.00000
# Iter 1598400, Minibatch Loss= 0.018255, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.928277

# %%
saver.save(sess, '../Model/NIN-Model-0602')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', '1', 'd', '7', 's', '2', 'y', 'p', 'i', '9', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 't', '8', 'u', 'x', '6', 'h', 'e', '5', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
