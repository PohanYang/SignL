# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t0626.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (186209, 54)

# %%
# Parameters
learning_rate = 0.001
training_iters = 1600000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==8):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 4.100258, Training Accuracy= 0.00000
# Iter 3200, Minibatch Loss= 3.988804, Training Accuracy= 0.00000
# Iter 4800, Minibatch Loss= 4.034755, Training Accuracy= 0.00000
# Iter 6400, Minibatch Loss= 3.950185, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.958410, Training Accuracy= 0.00000
# Iter 9600, Minibatch Loss= 3.988078, Training Accuracy= 0.00000
# Iter 11200, Minibatch Loss= 3.963798, Training Accuracy= 0.06250
# Iter 12800, Minibatch Loss= 3.957526, Training Accuracy= 0.06250
# Iter 14400, Minibatch Loss= 3.991432, Training Accuracy= 0.00000
# Iter 16000, Minibatch Loss= 4.013293, Training Accuracy= 0.00000
# Iter 17600, Minibatch Loss= 4.002620, Training Accuracy= 0.00000
# Iter 19200, Minibatch Loss= 3.990267, Training Accuracy= 0.00000
# Iter 20800, Minibatch Loss= 3.968761, Training Accuracy= 0.00000
# Iter 22400, Minibatch Loss= 3.983709, Training Accuracy= 0.00000
# Iter 24000, Minibatch Loss= 3.983361, Training Accuracy= 0.06250
# Iter 25600, Minibatch Loss= 3.974149, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.950452, Training Accuracy= 0.00000
# Iter 28800, Minibatch Loss= 3.984342, Training Accuracy= 0.00000
# Iter 30400, Minibatch Loss= 4.015537, Training Accuracy= 0.00000
# Iter 32000, Minibatch Loss= 3.992003, Training Accuracy= 0.00000
# Iter 33600, Minibatch Loss= 3.980519, Training Accuracy= 0.06250
# Iter 35200, Minibatch Loss= 3.927304, Training Accuracy= 0.12500
# Iter 36800, Minibatch Loss= 3.990706, Training Accuracy= 0.00000
# Iter 38400, Minibatch Loss= 3.954224, Training Accuracy= 0.00000
# Iter 40000, Minibatch Loss= 3.993219, Training Accuracy= 0.00000
# Iter 41600, Minibatch Loss= 3.879600, Training Accuracy= 0.00000
# Iter 43200, Minibatch Loss= 4.019984, Training Accuracy= 0.00000
# Iter 44800, Minibatch Loss= 3.945203, Training Accuracy= 0.06250
# Iter 46400, Minibatch Loss= 4.012238, Training Accuracy= 0.06250
# Iter 48000, Minibatch Loss= 3.952150, Training Accuracy= 0.00000
# Iter 49600, Minibatch Loss= 3.984555, Training Accuracy= 0.06250
# Iter 51200, Minibatch Loss= 3.938415, Training Accuracy= 0.00000
# Iter 52800, Minibatch Loss= 3.974419, Training Accuracy= 0.00000
# Iter 54400, Minibatch Loss= 3.948787, Training Accuracy= 0.12500
# Iter 56000, Minibatch Loss= 3.954502, Training Accuracy= 0.12500
# Iter 57600, Minibatch Loss= 3.951234, Training Accuracy= 0.00000
# Iter 59200, Minibatch Loss= 3.919824, Training Accuracy= 0.12500
# Iter 60800, Minibatch Loss= 3.992967, Training Accuracy= 0.00000
# Iter 62400, Minibatch Loss= 3.910945, Training Accuracy= 0.06250
# Iter 64000, Minibatch Loss= 4.003902, Training Accuracy= 0.00000
# Iter 65600, Minibatch Loss= 3.929270, Training Accuracy= 0.12500
# Iter 67200, Minibatch Loss= 3.943830, Training Accuracy= 0.00000
# Iter 68800, Minibatch Loss= 3.880868, Training Accuracy= 0.12500
# Iter 70400, Minibatch Loss= 3.933402, Training Accuracy= 0.06250
# Iter 72000, Minibatch Loss= 3.988444, Training Accuracy= 0.00000
# Iter 73600, Minibatch Loss= 4.009635, Training Accuracy= 0.00000
# Iter 75200, Minibatch Loss= 3.906134, Training Accuracy= 0.06250
# Iter 76800, Minibatch Loss= 3.931087, Training Accuracy= 0.00000
# Iter 78400, Minibatch Loss= 3.929416, Training Accuracy= 0.00000
# Iter 80000, Minibatch Loss= 3.935585, Training Accuracy= 0.00000
# Iter 81600, Minibatch Loss= 3.930331, Training Accuracy= 0.00000
# Iter 83200, Minibatch Loss= 3.889971, Training Accuracy= 0.12500
# Iter 84800, Minibatch Loss= 3.916739, Training Accuracy= 0.06250
# Iter 86400, Minibatch Loss= 3.867538, Training Accuracy= 0.00000
# Iter 88000, Minibatch Loss= 3.925690, Training Accuracy= 0.00000
# Iter 89600, Minibatch Loss= 3.890866, Training Accuracy= 0.00000
# Iter 91200, Minibatch Loss= 3.923304, Training Accuracy= 0.18750
# Iter 92800, Minibatch Loss= 3.959269, Training Accuracy= 0.06250
# Iter 94400, Minibatch Loss= 3.935261, Training Accuracy= 0.06250
# Iter 96000, Minibatch Loss= 3.842440, Training Accuracy= 0.18750
# Iter 97600, Minibatch Loss= 3.842518, Training Accuracy= 0.12500
# Iter 99200, Minibatch Loss= 3.746480, Training Accuracy= 0.25000
# Iter 100800, Minibatch Loss= 3.832302, Training Accuracy= 0.18750
# Iter 102400, Minibatch Loss= 3.710995, Training Accuracy= 0.18750
# Iter 104000, Minibatch Loss= 3.838109, Training Accuracy= 0.06250
# Iter 105600, Minibatch Loss= 3.835627, Training Accuracy= 0.00000
# Iter 107200, Minibatch Loss= 3.654162, Training Accuracy= 0.18750
# Iter 108800, Minibatch Loss= 3.922754, Training Accuracy= 0.00000
# Iter 110400, Minibatch Loss= 3.790215, Training Accuracy= 0.12500
# Iter 112000, Minibatch Loss= 3.790909, Training Accuracy= 0.06250
# Iter 113600, Minibatch Loss= 3.826753, Training Accuracy= 0.18750
# Iter 115200, Minibatch Loss= 3.825751, Training Accuracy= 0.06250
# Iter 116800, Minibatch Loss= 3.801608, Training Accuracy= 0.00000
# Iter 118400, Minibatch Loss= 3.644667, Training Accuracy= 0.12500
# Iter 120000, Minibatch Loss= 3.655464, Training Accuracy= 0.18750
# Iter 121600, Minibatch Loss= 3.743732, Training Accuracy= 0.06250
# Iter 123200, Minibatch Loss= 3.433764, Training Accuracy= 0.18750
# Iter 124800, Minibatch Loss= 3.592509, Training Accuracy= 0.12500
# Iter 126400, Minibatch Loss= 3.530442, Training Accuracy= 0.18750
# Iter 128000, Minibatch Loss= 3.615462, Training Accuracy= 0.12500
# Iter 129600, Minibatch Loss= 3.355960, Training Accuracy= 0.12500
# Iter 131200, Minibatch Loss= 3.411284, Training Accuracy= 0.12500
# Iter 132800, Minibatch Loss= 3.493715, Training Accuracy= 0.06250
# Iter 134400, Minibatch Loss= 3.461990, Training Accuracy= 0.12500
# Iter 136000, Minibatch Loss= 3.416414, Training Accuracy= 0.12500
# Iter 137600, Minibatch Loss= 3.124094, Training Accuracy= 0.31250
# Iter 139200, Minibatch Loss= 3.360068, Training Accuracy= 0.12500
# Iter 140800, Minibatch Loss= 3.505707, Training Accuracy= 0.00000
# Iter 142400, Minibatch Loss= 3.819812, Training Accuracy= 0.06250
# Iter 144000, Minibatch Loss= 3.462984, Training Accuracy= 0.06250
# Iter 145600, Minibatch Loss= 3.380831, Training Accuracy= 0.12500
# Iter 147200, Minibatch Loss= 2.979223, Training Accuracy= 0.18750
# Iter 148800, Minibatch Loss= 3.296882, Training Accuracy= 0.06250
# Iter 150400, Minibatch Loss= 2.849524, Training Accuracy= 0.31250
# Iter 152000, Minibatch Loss= 2.896159, Training Accuracy= 0.18750
# Iter 153600, Minibatch Loss= 2.945467, Training Accuracy= 0.18750
# Iter 155200, Minibatch Loss= 3.318950, Training Accuracy= 0.00000
# Iter 156800, Minibatch Loss= 3.405766, Training Accuracy= 0.12500
# Iter 158400, Minibatch Loss= 3.479905, Training Accuracy= 0.12500
# Iter 160000, Minibatch Loss= 3.192652, Training Accuracy= 0.12500
# Iter 161600, Minibatch Loss= 3.132998, Training Accuracy= 0.18750
# Iter 163200, Minibatch Loss= 3.102596, Training Accuracy= 0.18750
# Iter 164800, Minibatch Loss= 3.414555, Training Accuracy= 0.06250
# Iter 166400, Minibatch Loss= 3.610856, Training Accuracy= 0.18750
# Iter 168000, Minibatch Loss= 3.225392, Training Accuracy= 0.12500
# Iter 169600, Minibatch Loss= 3.051340, Training Accuracy= 0.31250
# Iter 171200, Minibatch Loss= 2.984661, Training Accuracy= 0.18750
# Iter 172800, Minibatch Loss= 3.116188, Training Accuracy= 0.18750
# Iter 174400, Minibatch Loss= 3.039003, Training Accuracy= 0.18750
# Iter 176000, Minibatch Loss= 2.549367, Training Accuracy= 0.37500
# Iter 177600, Minibatch Loss= 2.904750, Training Accuracy= 0.25000
# Iter 179200, Minibatch Loss= 2.609530, Training Accuracy= 0.31250
# Iter 180800, Minibatch Loss= 3.125660, Training Accuracy= 0.18750
# Iter 182400, Minibatch Loss= 2.808673, Training Accuracy= 0.25000
# Iter 184000, Minibatch Loss= 2.670196, Training Accuracy= 0.31250
# Iter 185600, Minibatch Loss= 3.207825, Training Accuracy= 0.12500
# Iter 187200, Minibatch Loss= 2.783603, Training Accuracy= 0.25000
# Iter 188800, Minibatch Loss= 3.093345, Training Accuracy= 0.18750
# Iter 190400, Minibatch Loss= 3.148077, Training Accuracy= 0.25000
# Iter 192000, Minibatch Loss= 2.830309, Training Accuracy= 0.12500
# Iter 193600, Minibatch Loss= 2.902610, Training Accuracy= 0.12500
# Iter 195200, Minibatch Loss= 2.364290, Training Accuracy= 0.37500
# Iter 196800, Minibatch Loss= 2.702526, Training Accuracy= 0.31250
# Iter 198400, Minibatch Loss= 2.645691, Training Accuracy= 0.37500
# Iter 200000, Minibatch Loss= 2.682890, Training Accuracy= 0.18750
# Iter 201600, Minibatch Loss= 3.145408, Training Accuracy= 0.12500
# Iter 203200, Minibatch Loss= 3.167020, Training Accuracy= 0.25000
# Iter 204800, Minibatch Loss= 2.833236, Training Accuracy= 0.06250
# Iter 206400, Minibatch Loss= 3.130093, Training Accuracy= 0.18750
# Iter 208000, Minibatch Loss= 2.749753, Training Accuracy= 0.25000
# Iter 209600, Minibatch Loss= 3.088169, Training Accuracy= 0.06250
# Iter 211200, Minibatch Loss= 2.153664, Training Accuracy= 0.37500
# Iter 212800, Minibatch Loss= 2.478701, Training Accuracy= 0.25000
# Iter 214400, Minibatch Loss= 2.702894, Training Accuracy= 0.12500
# Iter 216000, Minibatch Loss= 2.360877, Training Accuracy= 0.25000
# Iter 217600, Minibatch Loss= 2.390037, Training Accuracy= 0.31250
# Iter 219200, Minibatch Loss= 1.931729, Training Accuracy= 0.50000
# Iter 220800, Minibatch Loss= 2.378751, Training Accuracy= 0.37500
# Iter 222400, Minibatch Loss= 2.557381, Training Accuracy= 0.37500
# Iter 224000, Minibatch Loss= 2.501395, Training Accuracy= 0.37500
# Iter 225600, Minibatch Loss= 2.120973, Training Accuracy= 0.43750
# Iter 227200, Minibatch Loss= 2.847645, Training Accuracy= 0.12500
# Iter 228800, Minibatch Loss= 2.506696, Training Accuracy= 0.25000
# Iter 230400, Minibatch Loss= 2.825569, Training Accuracy= 0.12500
# Iter 232000, Minibatch Loss= 2.145770, Training Accuracy= 0.43750
# Iter 233600, Minibatch Loss= 2.175518, Training Accuracy= 0.37500
# Iter 235200, Minibatch Loss= 2.301567, Training Accuracy= 0.31250
# Iter 236800, Minibatch Loss= 2.125008, Training Accuracy= 0.43750
# Iter 238400, Minibatch Loss= 2.557661, Training Accuracy= 0.25000
# Iter 240000, Minibatch Loss= 2.460905, Training Accuracy= 0.37500
# Iter 241600, Minibatch Loss= 1.991931, Training Accuracy= 0.37500
# Iter 243200, Minibatch Loss= 2.201463, Training Accuracy= 0.37500
# Iter 244800, Minibatch Loss= 1.964669, Training Accuracy= 0.56250
# Iter 246400, Minibatch Loss= 2.615929, Training Accuracy= 0.37500
# Iter 248000, Minibatch Loss= 2.128810, Training Accuracy= 0.43750
# Iter 249600, Minibatch Loss= 2.288173, Training Accuracy= 0.25000
# Iter 251200, Minibatch Loss= 2.292374, Training Accuracy= 0.31250
# Iter 252800, Minibatch Loss= 2.513680, Training Accuracy= 0.18750
# Iter 254400, Minibatch Loss= 1.701505, Training Accuracy= 0.50000
# Iter 256000, Minibatch Loss= 2.346560, Training Accuracy= 0.43750
# Iter 257600, Minibatch Loss= 2.827009, Training Accuracy= 0.25000
# Iter 259200, Minibatch Loss= 2.009844, Training Accuracy= 0.43750
# Iter 260800, Minibatch Loss= 3.104774, Training Accuracy= 0.25000
# Iter 262400, Minibatch Loss= 2.136871, Training Accuracy= 0.31250
# Iter 264000, Minibatch Loss= 1.922701, Training Accuracy= 0.37500
# Iter 265600, Minibatch Loss= 2.575214, Training Accuracy= 0.31250
# Iter 267200, Minibatch Loss= 1.753711, Training Accuracy= 0.56250
# Iter 268800, Minibatch Loss= 2.066621, Training Accuracy= 0.43750
# Iter 270400, Minibatch Loss= 2.436538, Training Accuracy= 0.37500
# Iter 272000, Minibatch Loss= 1.951434, Training Accuracy= 0.25000
# Iter 273600, Minibatch Loss= 1.809249, Training Accuracy= 0.50000
# Iter 275200, Minibatch Loss= 2.002237, Training Accuracy= 0.56250
# Iter 276800, Minibatch Loss= 1.602698, Training Accuracy= 0.62500
# Iter 278400, Minibatch Loss= 1.946157, Training Accuracy= 0.31250
# Iter 280000, Minibatch Loss= 2.316920, Training Accuracy= 0.18750
# Iter 281600, Minibatch Loss= 1.723931, Training Accuracy= 0.37500
# Iter 283200, Minibatch Loss= 2.039571, Training Accuracy= 0.37500
# Iter 284800, Minibatch Loss= 1.935001, Training Accuracy= 0.25000
# Iter 286400, Minibatch Loss= 1.774878, Training Accuracy= 0.50000
# Iter 288000, Minibatch Loss= 1.847762, Training Accuracy= 0.25000
# Iter 289600, Minibatch Loss= 1.931632, Training Accuracy= 0.43750
# Iter 291200, Minibatch Loss= 2.060390, Training Accuracy= 0.50000
# Iter 292800, Minibatch Loss= 2.317686, Training Accuracy= 0.43750
# Iter 294400, Minibatch Loss= 1.418336, Training Accuracy= 0.62500
# Iter 296000, Minibatch Loss= 1.941855, Training Accuracy= 0.50000
# Iter 297600, Minibatch Loss= 1.450320, Training Accuracy= 0.68750
# Iter 299200, Minibatch Loss= 1.303472, Training Accuracy= 0.68750
# Iter 300800, Minibatch Loss= 1.638374, Training Accuracy= 0.50000
# Iter 302400, Minibatch Loss= 1.505614, Training Accuracy= 0.68750
# Iter 304000, Minibatch Loss= 2.058957, Training Accuracy= 0.62500
# Iter 305600, Minibatch Loss= 1.662541, Training Accuracy= 0.50000
# Iter 307200, Minibatch Loss= 2.079879, Training Accuracy= 0.37500
# Iter 308800, Minibatch Loss= 1.605258, Training Accuracy= 0.50000
# Iter 310400, Minibatch Loss= 1.444287, Training Accuracy= 0.56250
# Iter 312000, Minibatch Loss= 2.087806, Training Accuracy= 0.37500
# Iter 313600, Minibatch Loss= 1.591478, Training Accuracy= 0.62500
# Iter 315200, Minibatch Loss= 1.449102, Training Accuracy= 0.68750
# Iter 316800, Minibatch Loss= 1.794022, Training Accuracy= 0.50000
# Iter 318400, Minibatch Loss= 1.633912, Training Accuracy= 0.43750
# Iter 320000, Minibatch Loss= 1.330919, Training Accuracy= 0.56250
# Iter 321600, Minibatch Loss= 2.010640, Training Accuracy= 0.43750
# Iter 323200, Minibatch Loss= 1.958475, Training Accuracy= 0.50000
# Iter 324800, Minibatch Loss= 1.202613, Training Accuracy= 0.56250
# Iter 326400, Minibatch Loss= 1.116368, Training Accuracy= 0.68750
# Iter 328000, Minibatch Loss= 1.377588, Training Accuracy= 0.50000
# Iter 329600, Minibatch Loss= 1.896497, Training Accuracy= 0.50000
# Iter 331200, Minibatch Loss= 1.702493, Training Accuracy= 0.50000
# Iter 332800, Minibatch Loss= 1.193440, Training Accuracy= 0.62500
# Iter 334400, Minibatch Loss= 1.137669, Training Accuracy= 0.75000
# Iter 336000, Minibatch Loss= 1.798562, Training Accuracy= 0.68750
# Iter 337600, Minibatch Loss= 1.218421, Training Accuracy= 0.62500
# Iter 339200, Minibatch Loss= 2.366395, Training Accuracy= 0.56250
# Iter 340800, Minibatch Loss= 1.633701, Training Accuracy= 0.68750
# Iter 342400, Minibatch Loss= 1.698454, Training Accuracy= 0.50000
# Iter 344000, Minibatch Loss= 1.682804, Training Accuracy= 0.56250
# Iter 345600, Minibatch Loss= 1.804379, Training Accuracy= 0.50000
# Iter 347200, Minibatch Loss= 2.162188, Training Accuracy= 0.25000
# Iter 348800, Minibatch Loss= 1.452238, Training Accuracy= 0.50000
# Iter 350400, Minibatch Loss= 1.792378, Training Accuracy= 0.50000
# Iter 352000, Minibatch Loss= 1.221584, Training Accuracy= 0.37500
# Iter 353600, Minibatch Loss= 1.767726, Training Accuracy= 0.50000
# Iter 355200, Minibatch Loss= 1.120554, Training Accuracy= 0.56250
# Iter 356800, Minibatch Loss= 1.502421, Training Accuracy= 0.68750
# Iter 358400, Minibatch Loss= 1.166199, Training Accuracy= 0.50000
# Iter 360000, Minibatch Loss= 1.751989, Training Accuracy= 0.56250
# Iter 361600, Minibatch Loss= 1.032421, Training Accuracy= 0.81250
# Iter 363200, Minibatch Loss= 1.594998, Training Accuracy= 0.43750
# Iter 364800, Minibatch Loss= 1.327861, Training Accuracy= 0.56250
# Iter 366400, Minibatch Loss= 1.735051, Training Accuracy= 0.43750
# Iter 368000, Minibatch Loss= 2.414578, Training Accuracy= 0.56250
# Iter 369600, Minibatch Loss= 1.502995, Training Accuracy= 0.56250
# Iter 371200, Minibatch Loss= 1.397656, Training Accuracy= 0.68750
# Iter 372800, Minibatch Loss= 1.213302, Training Accuracy= 0.75000
# Iter 374400, Minibatch Loss= 1.168839, Training Accuracy= 0.62500
# Iter 376000, Minibatch Loss= 1.517621, Training Accuracy= 0.50000
# Iter 377600, Minibatch Loss= 0.792200, Training Accuracy= 0.75000
# Iter 379200, Minibatch Loss= 1.085286, Training Accuracy= 0.62500
# Iter 380800, Minibatch Loss= 1.305669, Training Accuracy= 0.62500
# Iter 382400, Minibatch Loss= 0.867156, Training Accuracy= 0.68750
# Iter 384000, Minibatch Loss= 1.096294, Training Accuracy= 0.62500
# Iter 385600, Minibatch Loss= 1.155580, Training Accuracy= 0.62500
# Iter 387200, Minibatch Loss= 1.610882, Training Accuracy= 0.50000
# Iter 388800, Minibatch Loss= 1.600626, Training Accuracy= 0.56250
# Iter 390400, Minibatch Loss= 0.787913, Training Accuracy= 0.87500
# Iter 392000, Minibatch Loss= 1.342759, Training Accuracy= 0.75000
# Iter 393600, Minibatch Loss= 1.224395, Training Accuracy= 0.75000
# Iter 395200, Minibatch Loss= 1.642606, Training Accuracy= 0.37500
# Iter 396800, Minibatch Loss= 0.725316, Training Accuracy= 0.81250
# Iter 398400, Minibatch Loss= 1.104286, Training Accuracy= 0.75000
# Iter 400000, Minibatch Loss= 0.935790, Training Accuracy= 0.62500
# Iter 401600, Minibatch Loss= 1.109730, Training Accuracy= 0.56250
# Iter 403200, Minibatch Loss= 1.949474, Training Accuracy= 0.50000
# Iter 404800, Minibatch Loss= 1.013393, Training Accuracy= 0.62500
# Iter 406400, Minibatch Loss= 1.085391, Training Accuracy= 0.68750
# Iter 408000, Minibatch Loss= 1.048846, Training Accuracy= 0.62500
# Iter 409600, Minibatch Loss= 1.006363, Training Accuracy= 0.75000
# Iter 411200, Minibatch Loss= 0.692524, Training Accuracy= 0.87500
# Iter 412800, Minibatch Loss= 1.178436, Training Accuracy= 0.75000
# Iter 414400, Minibatch Loss= 1.690125, Training Accuracy= 0.56250
# Iter 416000, Minibatch Loss= 0.756712, Training Accuracy= 0.81250
# Iter 417600, Minibatch Loss= 1.496135, Training Accuracy= 0.50000
# Iter 419200, Minibatch Loss= 0.779544, Training Accuracy= 0.68750
# Iter 420800, Minibatch Loss= 0.977243, Training Accuracy= 0.62500
# Iter 422400, Minibatch Loss= 2.021645, Training Accuracy= 0.31250
# Iter 424000, Minibatch Loss= 1.264128, Training Accuracy= 0.68750
# Iter 425600, Minibatch Loss= 1.646953, Training Accuracy= 0.68750
# Iter 427200, Minibatch Loss= 0.872776, Training Accuracy= 0.75000
# Iter 428800, Minibatch Loss= 0.789375, Training Accuracy= 0.75000
# Iter 430400, Minibatch Loss= 0.696234, Training Accuracy= 0.75000
# Iter 432000, Minibatch Loss= 1.460924, Training Accuracy= 0.68750
# Iter 433600, Minibatch Loss= 1.144074, Training Accuracy= 0.56250
# Iter 435200, Minibatch Loss= 0.232834, Training Accuracy= 1.00000
# Iter 436800, Minibatch Loss= 1.089066, Training Accuracy= 0.68750
# Iter 438400, Minibatch Loss= 1.771797, Training Accuracy= 0.56250
# Iter 440000, Minibatch Loss= 0.909572, Training Accuracy= 0.68750
# Iter 441600, Minibatch Loss= 1.436558, Training Accuracy= 0.75000
# Iter 443200, Minibatch Loss= 1.093952, Training Accuracy= 0.68750
# Iter 444800, Minibatch Loss= 0.878525, Training Accuracy= 0.68750
# Iter 446400, Minibatch Loss= 0.822116, Training Accuracy= 0.68750
# Iter 448000, Minibatch Loss= 1.320770, Training Accuracy= 0.56250
# Iter 449600, Minibatch Loss= 1.453015, Training Accuracy= 0.68750
# Iter 451200, Minibatch Loss= 1.278805, Training Accuracy= 0.75000
# Iter 452800, Minibatch Loss= 0.926084, Training Accuracy= 0.56250
# Iter 454400, Minibatch Loss= 0.471508, Training Accuracy= 0.87500
# Iter 456000, Minibatch Loss= 0.860696, Training Accuracy= 0.68750
# Iter 457600, Minibatch Loss= 0.741739, Training Accuracy= 0.81250
# Iter 459200, Minibatch Loss= 1.069821, Training Accuracy= 0.81250
# Iter 460800, Minibatch Loss= 0.969959, Training Accuracy= 0.62500
# Iter 462400, Minibatch Loss= 0.902767, Training Accuracy= 0.75000
# Iter 464000, Minibatch Loss= 0.569673, Training Accuracy= 0.81250
# Iter 465600, Minibatch Loss= 0.585194, Training Accuracy= 0.81250
# Iter 467200, Minibatch Loss= 1.546615, Training Accuracy= 0.62500
# Iter 468800, Minibatch Loss= 0.896269, Training Accuracy= 0.68750
# Iter 470400, Minibatch Loss= 0.851320, Training Accuracy= 0.68750
# Iter 472000, Minibatch Loss= 0.497680, Training Accuracy= 0.93750
# Iter 473600, Minibatch Loss= 0.825028, Training Accuracy= 0.75000
# Iter 475200, Minibatch Loss= 1.154387, Training Accuracy= 0.56250
# Iter 476800, Minibatch Loss= 1.189375, Training Accuracy= 0.68750
# Iter 478400, Minibatch Loss= 0.563846, Training Accuracy= 0.81250
# Iter 480000, Minibatch Loss= 1.621249, Training Accuracy= 0.81250
# Iter 481600, Minibatch Loss= 1.130713, Training Accuracy= 0.75000
# Iter 483200, Minibatch Loss= 1.358421, Training Accuracy= 0.68750
# Iter 484800, Minibatch Loss= 1.217015, Training Accuracy= 0.68750
# Iter 486400, Minibatch Loss= 1.022869, Training Accuracy= 0.75000
# Iter 488000, Minibatch Loss= 0.974938, Training Accuracy= 0.56250
# Iter 489600, Minibatch Loss= 1.374905, Training Accuracy= 0.62500
# Iter 491200, Minibatch Loss= 1.003200, Training Accuracy= 0.68750
# Iter 492800, Minibatch Loss= 0.608110, Training Accuracy= 0.75000
# Iter 494400, Minibatch Loss= 1.001138, Training Accuracy= 0.81250
# Iter 496000, Minibatch Loss= 0.822394, Training Accuracy= 0.75000
# Iter 497600, Minibatch Loss= 1.405609, Training Accuracy= 0.62500
# Iter 499200, Minibatch Loss= 0.545031, Training Accuracy= 0.81250
# Iter 500800, Minibatch Loss= 0.640996, Training Accuracy= 0.81250
# Iter 502400, Minibatch Loss= 0.790274, Training Accuracy= 0.68750
# Iter 504000, Minibatch Loss= 0.584381, Training Accuracy= 0.87500
# Iter 505600, Minibatch Loss= 0.706443, Training Accuracy= 0.75000
# Iter 507200, Minibatch Loss= 0.746917, Training Accuracy= 0.87500
# Iter 508800, Minibatch Loss= 0.986856, Training Accuracy= 0.75000
# Iter 510400, Minibatch Loss= 0.765137, Training Accuracy= 0.75000
# Iter 512000, Minibatch Loss= 1.115931, Training Accuracy= 0.56250
# Iter 513600, Minibatch Loss= 0.556964, Training Accuracy= 0.81250
# Iter 515200, Minibatch Loss= 0.745563, Training Accuracy= 0.68750
# Iter 516800, Minibatch Loss= 0.967177, Training Accuracy= 0.56250
# Iter 518400, Minibatch Loss= 0.705892, Training Accuracy= 0.68750
# Iter 520000, Minibatch Loss= 0.691859, Training Accuracy= 0.81250
# Iter 521600, Minibatch Loss= 0.496651, Training Accuracy= 0.81250
# Iter 523200, Minibatch Loss= 1.091082, Training Accuracy= 0.62500
# Iter 524800, Minibatch Loss= 0.830337, Training Accuracy= 0.68750
# Iter 526400, Minibatch Loss= 0.874948, Training Accuracy= 0.81250
# Iter 528000, Minibatch Loss= 0.748636, Training Accuracy= 0.75000
# Iter 529600, Minibatch Loss= 0.788845, Training Accuracy= 0.81250
# Iter 531200, Minibatch Loss= 0.706411, Training Accuracy= 0.75000
# Iter 532800, Minibatch Loss= 0.246141, Training Accuracy= 0.87500
# Iter 534400, Minibatch Loss= 0.628073, Training Accuracy= 0.62500
# Iter 536000, Minibatch Loss= 0.913611, Training Accuracy= 0.75000
# Iter 537600, Minibatch Loss= 0.489019, Training Accuracy= 0.93750
# Iter 539200, Minibatch Loss= 0.944865, Training Accuracy= 0.68750
# Iter 540800, Minibatch Loss= 0.726606, Training Accuracy= 0.75000
# Iter 542400, Minibatch Loss= 0.426908, Training Accuracy= 0.87500
# Iter 544000, Minibatch Loss= 0.523356, Training Accuracy= 0.87500
# Iter 545600, Minibatch Loss= 0.766286, Training Accuracy= 0.75000
# Iter 547200, Minibatch Loss= 1.358667, Training Accuracy= 0.62500
# Iter 548800, Minibatch Loss= 1.231091, Training Accuracy= 0.56250
# Iter 550400, Minibatch Loss= 1.741906, Training Accuracy= 0.68750
# Iter 552000, Minibatch Loss= 0.805243, Training Accuracy= 0.81250
# Iter 553600, Minibatch Loss= 1.312874, Training Accuracy= 0.62500
# Iter 555200, Minibatch Loss= 1.303120, Training Accuracy= 0.68750
# Iter 556800, Minibatch Loss= 0.605830, Training Accuracy= 0.75000
# Iter 558400, Minibatch Loss= 1.216296, Training Accuracy= 0.62500
# Iter 560000, Minibatch Loss= 0.567938, Training Accuracy= 0.81250
# Iter 561600, Minibatch Loss= 0.590310, Training Accuracy= 0.87500
# Iter 563200, Minibatch Loss= 0.443562, Training Accuracy= 0.87500
# Iter 564800, Minibatch Loss= 0.524694, Training Accuracy= 0.81250
# Iter 566400, Minibatch Loss= 0.409551, Training Accuracy= 0.93750
# Iter 568000, Minibatch Loss= 0.718366, Training Accuracy= 0.81250
# Iter 569600, Minibatch Loss= 0.390528, Training Accuracy= 0.87500
# Iter 571200, Minibatch Loss= 0.631781, Training Accuracy= 0.75000
# Iter 572800, Minibatch Loss= 0.755421, Training Accuracy= 0.75000
# Iter 574400, Minibatch Loss= 1.060067, Training Accuracy= 0.87500
# Iter 576000, Minibatch Loss= 0.864204, Training Accuracy= 0.68750
# Iter 577600, Minibatch Loss= 0.348025, Training Accuracy= 0.93750
# Iter 579200, Minibatch Loss= 0.351905, Training Accuracy= 0.93750
# Iter 580800, Minibatch Loss= 0.804916, Training Accuracy= 0.75000
# Iter 582400, Minibatch Loss= 0.557392, Training Accuracy= 0.81250
# Iter 584000, Minibatch Loss= 0.343135, Training Accuracy= 0.87500
# Iter 585600, Minibatch Loss= 0.600521, Training Accuracy= 0.87500
# Iter 587200, Minibatch Loss= 0.326905, Training Accuracy= 1.00000
# Iter 588800, Minibatch Loss= 0.764832, Training Accuracy= 0.93750
# Iter 590400, Minibatch Loss= 0.678437, Training Accuracy= 0.87500
# Iter 592000, Minibatch Loss= 0.437966, Training Accuracy= 0.93750
# Iter 593600, Minibatch Loss= 0.946410, Training Accuracy= 0.81250
# Iter 595200, Minibatch Loss= 0.928306, Training Accuracy= 0.81250
# Iter 596800, Minibatch Loss= 0.499509, Training Accuracy= 0.87500
# Iter 598400, Minibatch Loss= 0.536034, Training Accuracy= 0.81250
# Iter 600000, Minibatch Loss= 0.508785, Training Accuracy= 0.87500
# Iter 601600, Minibatch Loss= 1.059130, Training Accuracy= 0.81250
# Iter 603200, Minibatch Loss= 0.474193, Training Accuracy= 0.81250
# Iter 604800, Minibatch Loss= 0.388336, Training Accuracy= 0.81250
# Iter 606400, Minibatch Loss= 0.504363, Training Accuracy= 0.87500
# Iter 608000, Minibatch Loss= 0.353040, Training Accuracy= 0.87500
# Iter 609600, Minibatch Loss= 0.799929, Training Accuracy= 0.75000
# Iter 611200, Minibatch Loss= 1.158086, Training Accuracy= 0.68750
# Iter 612800, Minibatch Loss= 0.725914, Training Accuracy= 0.81250
# Iter 614400, Minibatch Loss= 0.853770, Training Accuracy= 0.68750
# Iter 616000, Minibatch Loss= 0.350140, Training Accuracy= 0.87500
# Iter 617600, Minibatch Loss= 0.576709, Training Accuracy= 0.87500
# Iter 619200, Minibatch Loss= 0.913793, Training Accuracy= 0.81250
# Iter 620800, Minibatch Loss= 1.049335, Training Accuracy= 0.81250
# Iter 622400, Minibatch Loss= 0.300429, Training Accuracy= 0.87500
# Iter 624000, Minibatch Loss= 0.617150, Training Accuracy= 0.75000
# Iter 625600, Minibatch Loss= 0.511970, Training Accuracy= 0.81250
# Iter 627200, Minibatch Loss= 0.634059, Training Accuracy= 0.87500
# Iter 628800, Minibatch Loss= 0.566814, Training Accuracy= 0.87500
# Iter 630400, Minibatch Loss= 0.743707, Training Accuracy= 0.68750
# Iter 632000, Minibatch Loss= 1.125486, Training Accuracy= 0.75000
# Iter 633600, Minibatch Loss= 0.658292, Training Accuracy= 0.81250
# Iter 635200, Minibatch Loss= 0.765128, Training Accuracy= 0.93750
# Iter 636800, Minibatch Loss= 0.244025, Training Accuracy= 0.87500
# Iter 638400, Minibatch Loss= 0.655600, Training Accuracy= 0.75000
# Iter 640000, Minibatch Loss= 0.683603, Training Accuracy= 0.81250
# Iter 641600, Minibatch Loss= 0.468252, Training Accuracy= 0.87500
# Iter 643200, Minibatch Loss= 0.381672, Training Accuracy= 0.87500
# Iter 644800, Minibatch Loss= 1.200480, Training Accuracy= 0.75000
# Iter 646400, Minibatch Loss= 0.707196, Training Accuracy= 0.87500
# Iter 648000, Minibatch Loss= 0.278447, Training Accuracy= 0.93750
# Iter 649600, Minibatch Loss= 0.986339, Training Accuracy= 0.87500
# Iter 651200, Minibatch Loss= 0.377023, Training Accuracy= 0.93750
# Iter 652800, Minibatch Loss= 0.542711, Training Accuracy= 0.87500
# Iter 654400, Minibatch Loss= 0.730548, Training Accuracy= 0.87500
# Iter 656000, Minibatch Loss= 0.391994, Training Accuracy= 0.87500
# Iter 657600, Minibatch Loss= 0.099638, Training Accuracy= 1.00000
# Iter 659200, Minibatch Loss= 0.565751, Training Accuracy= 0.68750
# Iter 660800, Minibatch Loss= 0.254774, Training Accuracy= 0.87500
# Iter 662400, Minibatch Loss= 0.906696, Training Accuracy= 0.81250
# Iter 664000, Minibatch Loss= 0.720828, Training Accuracy= 0.68750
# Iter 665600, Minibatch Loss= 0.334442, Training Accuracy= 0.87500
# Iter 667200, Minibatch Loss= 1.500671, Training Accuracy= 0.62500
# Iter 668800, Minibatch Loss= 1.250531, Training Accuracy= 0.75000
# Iter 670400, Minibatch Loss= 0.799657, Training Accuracy= 0.68750
# Iter 672000, Minibatch Loss= 1.008505, Training Accuracy= 0.75000
# Iter 673600, Minibatch Loss= 0.495166, Training Accuracy= 0.75000
# Iter 675200, Minibatch Loss= 0.636432, Training Accuracy= 0.75000
# Iter 676800, Minibatch Loss= 0.848508, Training Accuracy= 0.75000
# Iter 678400, Minibatch Loss= 0.820555, Training Accuracy= 0.81250
# Iter 680000, Minibatch Loss= 0.252060, Training Accuracy= 0.93750
# Iter 681600, Minibatch Loss= 0.220600, Training Accuracy= 0.93750
# Iter 683200, Minibatch Loss= 0.209960, Training Accuracy= 0.93750
# Iter 684800, Minibatch Loss= 0.475302, Training Accuracy= 0.87500
# Iter 686400, Minibatch Loss= 0.711203, Training Accuracy= 0.68750
# Iter 688000, Minibatch Loss= 1.121447, Training Accuracy= 0.68750
# Iter 689600, Minibatch Loss= 0.437520, Training Accuracy= 0.87500
# Iter 691200, Minibatch Loss= 0.369598, Training Accuracy= 0.87500
# Iter 692800, Minibatch Loss= 0.482014, Training Accuracy= 0.81250
# Iter 694400, Minibatch Loss= 0.520021, Training Accuracy= 0.87500
# Iter 696000, Minibatch Loss= 0.620078, Training Accuracy= 0.87500
# Iter 697600, Minibatch Loss= 1.229247, Training Accuracy= 0.75000
# Iter 699200, Minibatch Loss= 0.162653, Training Accuracy= 1.00000
# Iter 700800, Minibatch Loss= 1.256790, Training Accuracy= 0.68750
# Iter 702400, Minibatch Loss= 0.501244, Training Accuracy= 0.93750
# Iter 704000, Minibatch Loss= 0.423680, Training Accuracy= 0.93750
# Iter 705600, Minibatch Loss= 0.330405, Training Accuracy= 0.93750
# Iter 707200, Minibatch Loss= 0.682936, Training Accuracy= 0.75000
# Iter 708800, Minibatch Loss= 0.635150, Training Accuracy= 0.62500
# Iter 710400, Minibatch Loss= 0.276165, Training Accuracy= 0.93750
# Iter 712000, Minibatch Loss= 0.361140, Training Accuracy= 0.81250
# Iter 713600, Minibatch Loss= 0.338685, Training Accuracy= 0.87500
# Iter 715200, Minibatch Loss= 0.448095, Training Accuracy= 0.87500
# Iter 716800, Minibatch Loss= 0.152634, Training Accuracy= 1.00000
# Iter 718400, Minibatch Loss= 0.340851, Training Accuracy= 0.87500
# Iter 720000, Minibatch Loss= 0.476411, Training Accuracy= 0.81250
# Iter 721600, Minibatch Loss= 0.428647, Training Accuracy= 0.93750
# Iter 723200, Minibatch Loss= 0.092595, Training Accuracy= 1.00000
# Iter 724800, Minibatch Loss= 1.335676, Training Accuracy= 0.75000
# Iter 726400, Minibatch Loss= 0.426854, Training Accuracy= 0.81250
# Iter 728000, Minibatch Loss= 0.584880, Training Accuracy= 0.81250
# Iter 729600, Minibatch Loss= 0.725130, Training Accuracy= 0.75000
# Iter 731200, Minibatch Loss= 0.965277, Training Accuracy= 0.81250
# Iter 732800, Minibatch Loss= 0.818487, Training Accuracy= 0.81250
# Iter 734400, Minibatch Loss= 0.467466, Training Accuracy= 0.81250
# Iter 736000, Minibatch Loss= 0.770546, Training Accuracy= 0.81250
# Iter 737600, Minibatch Loss= 0.622489, Training Accuracy= 0.87500
# Iter 739200, Minibatch Loss= 0.212519, Training Accuracy= 0.87500
# Iter 740800, Minibatch Loss= 0.502881, Training Accuracy= 0.81250
# Iter 742400, Minibatch Loss= 0.345737, Training Accuracy= 0.87500
# Iter 744000, Minibatch Loss= 0.117097, Training Accuracy= 1.00000
# Iter 745600, Minibatch Loss= 0.417259, Training Accuracy= 0.81250
# Iter 747200, Minibatch Loss= 0.933637, Training Accuracy= 0.87500
# Iter 748800, Minibatch Loss= 0.484423, Training Accuracy= 0.87500
# Iter 750400, Minibatch Loss= 0.818007, Training Accuracy= 0.75000
# Iter 752000, Minibatch Loss= 0.510009, Training Accuracy= 0.81250
# Iter 753600, Minibatch Loss= 1.043136, Training Accuracy= 0.62500
# Iter 755200, Minibatch Loss= 0.519225, Training Accuracy= 0.87500
# Iter 756800, Minibatch Loss= 0.513848, Training Accuracy= 0.93750
# Iter 758400, Minibatch Loss= 0.979199, Training Accuracy= 0.87500
# Iter 760000, Minibatch Loss= 0.637600, Training Accuracy= 0.87500
# Iter 761600, Minibatch Loss= 0.577863, Training Accuracy= 0.87500
# Iter 763200, Minibatch Loss= 0.278136, Training Accuracy= 0.93750
# Iter 764800, Minibatch Loss= 0.691346, Training Accuracy= 0.87500
# Iter 766400, Minibatch Loss= 0.378882, Training Accuracy= 0.87500
# Iter 768000, Minibatch Loss= 0.207896, Training Accuracy= 0.93750
# Iter 769600, Minibatch Loss= 0.356356, Training Accuracy= 0.81250
# Iter 771200, Minibatch Loss= 1.009734, Training Accuracy= 0.81250
# Iter 772800, Minibatch Loss= 0.224391, Training Accuracy= 0.93750
# Iter 774400, Minibatch Loss= 0.566012, Training Accuracy= 0.93750
# Iter 776000, Minibatch Loss= 0.991729, Training Accuracy= 0.87500
# Iter 777600, Minibatch Loss= 1.293832, Training Accuracy= 0.75000
# Iter 779200, Minibatch Loss= 0.300453, Training Accuracy= 0.87500
# Iter 780800, Minibatch Loss= 0.223913, Training Accuracy= 0.87500
# Iter 782400, Minibatch Loss= 0.521042, Training Accuracy= 0.81250
# Iter 784000, Minibatch Loss= 1.001680, Training Accuracy= 0.81250
# Iter 785600, Minibatch Loss= 0.115494, Training Accuracy= 1.00000
# Iter 787200, Minibatch Loss= 0.371735, Training Accuracy= 0.87500
# Iter 788800, Minibatch Loss= 0.453109, Training Accuracy= 0.75000
# Iter 790400, Minibatch Loss= 1.043635, Training Accuracy= 0.81250
# Iter 792000, Minibatch Loss= 0.352492, Training Accuracy= 0.87500
# Iter 793600, Minibatch Loss= 0.931138, Training Accuracy= 0.87500
# Iter 795200, Minibatch Loss= 0.271442, Training Accuracy= 0.87500
# Iter 796800, Minibatch Loss= 0.267835, Training Accuracy= 0.93750
# Iter 798400, Minibatch Loss= 0.435223, Training Accuracy= 0.75000
# Iter 800000, Minibatch Loss= 0.466823, Training Accuracy= 0.87500
# Iter 801600, Minibatch Loss= 0.286619, Training Accuracy= 0.87500
# Iter 803200, Minibatch Loss= 0.173250, Training Accuracy= 0.93750
# Iter 804800, Minibatch Loss= 0.480781, Training Accuracy= 0.81250
# Iter 806400, Minibatch Loss= 0.650527, Training Accuracy= 0.87500
# Iter 808000, Minibatch Loss= 0.559084, Training Accuracy= 0.87500
# Iter 809600, Minibatch Loss= 0.711572, Training Accuracy= 0.87500
# Iter 811200, Minibatch Loss= 0.161499, Training Accuracy= 0.93750
# Iter 812800, Minibatch Loss= 0.370283, Training Accuracy= 0.87500
# Iter 814400, Minibatch Loss= 0.129807, Training Accuracy= 1.00000
# Iter 816000, Minibatch Loss= 0.364183, Training Accuracy= 0.93750
# Iter 817600, Minibatch Loss= 0.304883, Training Accuracy= 0.87500
# Iter 819200, Minibatch Loss= 0.206119, Training Accuracy= 0.93750
# Iter 820800, Minibatch Loss= 0.354675, Training Accuracy= 0.93750
# Iter 822400, Minibatch Loss= 0.399554, Training Accuracy= 0.81250
# Iter 824000, Minibatch Loss= 0.263848, Training Accuracy= 0.87500
# Iter 825600, Minibatch Loss= 0.108433, Training Accuracy= 1.00000
# Iter 827200, Minibatch Loss= 0.393184, Training Accuracy= 0.87500
# Iter 828800, Minibatch Loss= 1.066775, Training Accuracy= 0.75000
# Iter 830400, Minibatch Loss= 0.313457, Training Accuracy= 0.87500
# Iter 832000, Minibatch Loss= 0.429020, Training Accuracy= 0.81250
# Iter 833600, Minibatch Loss= 0.193390, Training Accuracy= 0.87500
# Iter 835200, Minibatch Loss= 0.621393, Training Accuracy= 0.81250
# Iter 836800, Minibatch Loss= 1.345445, Training Accuracy= 0.68750
# Iter 838400, Minibatch Loss= 0.258181, Training Accuracy= 0.87500
# Iter 840000, Minibatch Loss= 0.383463, Training Accuracy= 0.87500
# Iter 841600, Minibatch Loss= 0.328525, Training Accuracy= 0.93750
# Iter 843200, Minibatch Loss= 0.091707, Training Accuracy= 1.00000
# Iter 844800, Minibatch Loss= 0.828649, Training Accuracy= 0.87500
# Iter 846400, Minibatch Loss= 0.170453, Training Accuracy= 0.93750
# Iter 848000, Minibatch Loss= 0.250570, Training Accuracy= 0.93750
# Iter 849600, Minibatch Loss= 0.546645, Training Accuracy= 0.93750
# Iter 851200, Minibatch Loss= 0.661505, Training Accuracy= 0.81250
# Iter 852800, Minibatch Loss= 0.239120, Training Accuracy= 0.87500
# Iter 854400, Minibatch Loss= 0.359810, Training Accuracy= 0.93750
# Iter 856000, Minibatch Loss= 0.329186, Training Accuracy= 0.81250
# Iter 857600, Minibatch Loss= 0.244528, Training Accuracy= 0.87500
# Iter 859200, Minibatch Loss= 0.325701, Training Accuracy= 0.93750
# Iter 860800, Minibatch Loss= 0.426161, Training Accuracy= 0.87500
# Iter 862400, Minibatch Loss= 0.236616, Training Accuracy= 0.93750
# Iter 864000, Minibatch Loss= 0.089653, Training Accuracy= 1.00000
# Iter 865600, Minibatch Loss= 0.162104, Training Accuracy= 0.93750
# Iter 867200, Minibatch Loss= 1.026890, Training Accuracy= 0.68750
# Iter 868800, Minibatch Loss= 0.438542, Training Accuracy= 0.87500
# Iter 870400, Minibatch Loss= 0.653176, Training Accuracy= 0.93750
# Iter 872000, Minibatch Loss= 0.376808, Training Accuracy= 0.87500
# Iter 873600, Minibatch Loss= 0.270342, Training Accuracy= 0.87500
# Iter 875200, Minibatch Loss= 0.288138, Training Accuracy= 0.93750
# Iter 876800, Minibatch Loss= 1.404779, Training Accuracy= 0.75000
# Iter 878400, Minibatch Loss= 0.548555, Training Accuracy= 0.81250
# Iter 880000, Minibatch Loss= 0.285834, Training Accuracy= 0.93750
# Iter 881600, Minibatch Loss= 0.715229, Training Accuracy= 0.93750
# Iter 883200, Minibatch Loss= 0.077713, Training Accuracy= 1.00000
# Iter 884800, Minibatch Loss= 0.133199, Training Accuracy= 0.93750
# Iter 886400, Minibatch Loss= 0.649014, Training Accuracy= 0.75000
# Iter 888000, Minibatch Loss= 0.556944, Training Accuracy= 0.93750
# Iter 889600, Minibatch Loss= 0.279471, Training Accuracy= 0.93750
# Iter 891200, Minibatch Loss= 0.420121, Training Accuracy= 0.93750
# Iter 892800, Minibatch Loss= 0.371938, Training Accuracy= 0.87500
# Iter 894400, Minibatch Loss= 0.438625, Training Accuracy= 0.87500
# Iter 896000, Minibatch Loss= 0.393516, Training Accuracy= 0.75000
# Iter 897600, Minibatch Loss= 0.511482, Training Accuracy= 0.81250
# Iter 899200, Minibatch Loss= 0.719825, Training Accuracy= 0.87500
# Iter 900800, Minibatch Loss= 0.085904, Training Accuracy= 1.00000
# Iter 902400, Minibatch Loss= 0.496914, Training Accuracy= 0.81250
# Iter 904000, Minibatch Loss= 0.403585, Training Accuracy= 0.93750
# Iter 905600, Minibatch Loss= 0.230448, Training Accuracy= 0.93750
# Iter 907200, Minibatch Loss= 0.158855, Training Accuracy= 1.00000
# Iter 908800, Minibatch Loss= 0.701938, Training Accuracy= 0.87500
# Iter 910400, Minibatch Loss= 0.306076, Training Accuracy= 0.93750
# Iter 912000, Minibatch Loss= 0.100852, Training Accuracy= 1.00000
# Iter 913600, Minibatch Loss= 0.567910, Training Accuracy= 0.81250
# Iter 915200, Minibatch Loss= 0.304396, Training Accuracy= 0.93750
# Iter 916800, Minibatch Loss= 0.911273, Training Accuracy= 0.81250
# Iter 918400, Minibatch Loss= 0.383302, Training Accuracy= 0.87500
# Iter 920000, Minibatch Loss= 0.325138, Training Accuracy= 0.87500
# Iter 921600, Minibatch Loss= 0.104588, Training Accuracy= 1.00000
# Iter 923200, Minibatch Loss= 0.734135, Training Accuracy= 0.87500
# Iter 924800, Minibatch Loss= 0.804020, Training Accuracy= 0.75000
# Iter 926400, Minibatch Loss= 0.162535, Training Accuracy= 0.93750
# Iter 928000, Minibatch Loss= 0.485683, Training Accuracy= 0.93750
# Iter 929600, Minibatch Loss= 0.206701, Training Accuracy= 0.93750
# Iter 931200, Minibatch Loss= 0.537548, Training Accuracy= 0.75000
# Iter 932800, Minibatch Loss= 0.263962, Training Accuracy= 0.93750
# Iter 934400, Minibatch Loss= 0.173642, Training Accuracy= 0.93750
# Iter 936000, Minibatch Loss= 0.135657, Training Accuracy= 1.00000
# Iter 937600, Minibatch Loss= 0.744391, Training Accuracy= 0.81250
# Iter 939200, Minibatch Loss= 0.180935, Training Accuracy= 0.93750
# Iter 940800, Minibatch Loss= 0.256005, Training Accuracy= 0.81250
# Iter 942400, Minibatch Loss= 0.341817, Training Accuracy= 0.87500
# Iter 944000, Minibatch Loss= 0.379531, Training Accuracy= 0.93750
# Iter 945600, Minibatch Loss= 0.725098, Training Accuracy= 0.75000
# Iter 947200, Minibatch Loss= 0.368624, Training Accuracy= 0.93750
# Iter 948800, Minibatch Loss= 0.438122, Training Accuracy= 0.87500
# Iter 950400, Minibatch Loss= 0.800501, Training Accuracy= 0.81250
# Iter 952000, Minibatch Loss= 0.179631, Training Accuracy= 0.93750
# Iter 953600, Minibatch Loss= 0.661085, Training Accuracy= 0.87500
# Iter 955200, Minibatch Loss= 0.480025, Training Accuracy= 0.81250
# Iter 956800, Minibatch Loss= 0.125031, Training Accuracy= 1.00000
# Iter 958400, Minibatch Loss= 0.360383, Training Accuracy= 0.81250
# Iter 960000, Minibatch Loss= 0.197555, Training Accuracy= 0.93750
# Iter 961600, Minibatch Loss= 0.217245, Training Accuracy= 0.93750
# Iter 963200, Minibatch Loss= 0.967148, Training Accuracy= 0.87500
# Iter 964800, Minibatch Loss= 0.067298, Training Accuracy= 1.00000
# Iter 966400, Minibatch Loss= 0.077481, Training Accuracy= 0.93750
# Iter 968000, Minibatch Loss= 0.183332, Training Accuracy= 0.93750
# Iter 969600, Minibatch Loss= 0.364304, Training Accuracy= 0.87500
# Iter 971200, Minibatch Loss= 2.083727, Training Accuracy= 0.62500
# Iter 972800, Minibatch Loss= 0.707135, Training Accuracy= 0.81250
# Iter 974400, Minibatch Loss= 0.656255, Training Accuracy= 0.87500
# Iter 976000, Minibatch Loss= 0.182227, Training Accuracy= 1.00000
# Iter 977600, Minibatch Loss= 0.232007, Training Accuracy= 0.93750
# Iter 979200, Minibatch Loss= 0.222545, Training Accuracy= 0.93750
# Iter 980800, Minibatch Loss= 1.031608, Training Accuracy= 0.87500
# Iter 982400, Minibatch Loss= 0.074808, Training Accuracy= 1.00000
# Iter 984000, Minibatch Loss= 0.214743, Training Accuracy= 0.93750
# Iter 985600, Minibatch Loss= 0.059794, Training Accuracy= 1.00000
# Iter 987200, Minibatch Loss= 0.063281, Training Accuracy= 1.00000
# Iter 988800, Minibatch Loss= 0.366938, Training Accuracy= 0.87500
# Iter 990400, Minibatch Loss= 0.075559, Training Accuracy= 1.00000
# Iter 992000, Minibatch Loss= 0.303917, Training Accuracy= 0.93750
# Iter 993600, Minibatch Loss= 0.446225, Training Accuracy= 0.75000
# Iter 995200, Minibatch Loss= 0.241762, Training Accuracy= 0.93750
# Iter 996800, Minibatch Loss= 0.079257, Training Accuracy= 1.00000
# Iter 998400, Minibatch Loss= 0.241290, Training Accuracy= 1.00000
# Iter 1000000, Minibatch Loss= 0.601278, Training Accuracy= 0.87500
# Iter 1001600, Minibatch Loss= 0.173408, Training Accuracy= 0.93750
# Iter 1003200, Minibatch Loss= 0.506545, Training Accuracy= 0.81250
# Iter 1004800, Minibatch Loss= 0.048735, Training Accuracy= 1.00000
# Iter 1006400, Minibatch Loss= 0.094987, Training Accuracy= 1.00000
# Iter 1008000, Minibatch Loss= 0.156846, Training Accuracy= 1.00000
# Iter 1009600, Minibatch Loss= 0.207926, Training Accuracy= 0.87500
# Iter 1011200, Minibatch Loss= 0.022071, Training Accuracy= 1.00000
# Iter 1012800, Minibatch Loss= 0.331185, Training Accuracy= 0.93750
# Iter 1014400, Minibatch Loss= 0.318399, Training Accuracy= 0.87500
# Iter 1016000, Minibatch Loss= 0.165811, Training Accuracy= 0.93750
# Iter 1017600, Minibatch Loss= 0.503098, Training Accuracy= 0.75000
# Iter 1019200, Minibatch Loss= 0.463305, Training Accuracy= 0.81250
# Iter 1020800, Minibatch Loss= 0.157022, Training Accuracy= 0.93750
# Iter 1022400, Minibatch Loss= 0.048822, Training Accuracy= 1.00000
# Iter 1024000, Minibatch Loss= 0.378689, Training Accuracy= 0.93750
# Iter 1025600, Minibatch Loss= 0.180128, Training Accuracy= 1.00000
# Iter 1027200, Minibatch Loss= 0.183762, Training Accuracy= 0.93750
# Iter 1028800, Minibatch Loss= 0.071951, Training Accuracy= 1.00000
# Iter 1030400, Minibatch Loss= 0.212771, Training Accuracy= 0.87500
# Iter 1032000, Minibatch Loss= 0.451191, Training Accuracy= 0.87500
# Iter 1033600, Minibatch Loss= 0.190272, Training Accuracy= 0.93750
# Iter 1035200, Minibatch Loss= 0.835076, Training Accuracy= 0.81250
# Iter 1036800, Minibatch Loss= 0.055601, Training Accuracy= 1.00000
# Iter 1038400, Minibatch Loss= 0.116820, Training Accuracy= 0.93750
# Iter 1040000, Minibatch Loss= 0.477557, Training Accuracy= 0.87500
# Iter 1041600, Minibatch Loss= 0.099566, Training Accuracy= 1.00000
# Iter 1043200, Minibatch Loss= 0.655990, Training Accuracy= 0.93750
# Iter 1044800, Minibatch Loss= 0.155262, Training Accuracy= 0.93750
# Iter 1046400, Minibatch Loss= 0.466245, Training Accuracy= 0.87500
# Iter 1048000, Minibatch Loss= 0.161781, Training Accuracy= 1.00000
# Iter 1049600, Minibatch Loss= 0.312815, Training Accuracy= 0.93750
# Iter 1051200, Minibatch Loss= 0.139624, Training Accuracy= 0.93750
# Iter 1052800, Minibatch Loss= 0.035409, Training Accuracy= 1.00000
# Iter 1054400, Minibatch Loss= 0.092060, Training Accuracy= 1.00000
# Iter 1056000, Minibatch Loss= 0.025323, Training Accuracy= 1.00000
# Iter 1057600, Minibatch Loss= 0.213539, Training Accuracy= 0.93750
# Iter 1059200, Minibatch Loss= 0.031798, Training Accuracy= 1.00000
# Iter 1060800, Minibatch Loss= 0.298539, Training Accuracy= 0.93750
# Iter 1062400, Minibatch Loss= 0.102092, Training Accuracy= 0.93750
# Iter 1064000, Minibatch Loss= 0.195328, Training Accuracy= 0.93750
# Iter 1065600, Minibatch Loss= 0.307346, Training Accuracy= 0.93750
# Iter 1067200, Minibatch Loss= 0.216476, Training Accuracy= 0.93750
# Iter 1068800, Minibatch Loss= 0.153322, Training Accuracy= 1.00000
# Iter 1070400, Minibatch Loss= 0.037231, Training Accuracy= 1.00000
# Iter 1072000, Minibatch Loss= 0.136799, Training Accuracy= 1.00000
# Iter 1073600, Minibatch Loss= 0.202363, Training Accuracy= 0.87500
# Iter 1075200, Minibatch Loss= 0.139371, Training Accuracy= 0.93750
# Iter 1076800, Minibatch Loss= 0.650774, Training Accuracy= 0.93750
# Iter 1078400, Minibatch Loss= 0.210506, Training Accuracy= 0.93750
# Iter 1080000, Minibatch Loss= 0.177082, Training Accuracy= 0.87500
# Iter 1081600, Minibatch Loss= 0.228752, Training Accuracy= 0.93750
# Iter 1083200, Minibatch Loss= 0.434702, Training Accuracy= 0.93750
# Iter 1084800, Minibatch Loss= 0.071056, Training Accuracy= 1.00000
# Iter 1086400, Minibatch Loss= 0.680845, Training Accuracy= 0.81250
# Iter 1088000, Minibatch Loss= 0.114651, Training Accuracy= 1.00000
# Iter 1089600, Minibatch Loss= 0.476981, Training Accuracy= 0.87500
# Iter 1091200, Minibatch Loss= 0.208349, Training Accuracy= 0.93750
# Iter 1092800, Minibatch Loss= 0.063150, Training Accuracy= 1.00000
# Iter 1094400, Minibatch Loss= 0.017213, Training Accuracy= 1.00000
# Iter 1096000, Minibatch Loss= 0.037321, Training Accuracy= 1.00000
# Iter 1097600, Minibatch Loss= 0.033526, Training Accuracy= 1.00000
# Iter 1099200, Minibatch Loss= 0.272229, Training Accuracy= 0.93750
# Iter 1100800, Minibatch Loss= 0.268453, Training Accuracy= 0.93750
# Iter 1102400, Minibatch Loss= 0.093551, Training Accuracy= 1.00000
# Iter 1104000, Minibatch Loss= 0.136299, Training Accuracy= 1.00000
# Iter 1105600, Minibatch Loss= 0.160059, Training Accuracy= 0.93750
# Iter 1107200, Minibatch Loss= 0.614411, Training Accuracy= 0.87500
# Iter 1108800, Minibatch Loss= 0.602534, Training Accuracy= 0.87500
# Iter 1110400, Minibatch Loss= 0.438296, Training Accuracy= 0.93750
# Iter 1112000, Minibatch Loss= 0.152032, Training Accuracy= 0.93750
# Iter 1113600, Minibatch Loss= 0.061507, Training Accuracy= 1.00000
# Iter 1115200, Minibatch Loss= 0.186031, Training Accuracy= 0.93750
# Iter 1116800, Minibatch Loss= 0.209019, Training Accuracy= 0.93750
# Iter 1118400, Minibatch Loss= 0.351161, Training Accuracy= 0.93750
# Iter 1120000, Minibatch Loss= 0.025805, Training Accuracy= 1.00000
# Iter 1121600, Minibatch Loss= 0.093806, Training Accuracy= 1.00000
# Iter 1123200, Minibatch Loss= 0.095386, Training Accuracy= 1.00000
# Iter 1124800, Minibatch Loss= 0.105070, Training Accuracy= 1.00000
# Iter 1126400, Minibatch Loss= 0.158239, Training Accuracy= 0.93750
# Iter 1128000, Minibatch Loss= 0.029371, Training Accuracy= 1.00000
# Iter 1129600, Minibatch Loss= 0.859453, Training Accuracy= 0.87500
# Iter 1131200, Minibatch Loss= 0.212298, Training Accuracy= 0.87500
# Iter 1132800, Minibatch Loss= 0.197146, Training Accuracy= 0.93750
# Iter 1134400, Minibatch Loss= 0.191101, Training Accuracy= 0.93750
# Iter 1136000, Minibatch Loss= 0.171628, Training Accuracy= 0.93750
# Iter 1137600, Minibatch Loss= 0.091649, Training Accuracy= 1.00000
# Iter 1139200, Minibatch Loss= 0.119999, Training Accuracy= 1.00000
# Iter 1140800, Minibatch Loss= 0.075175, Training Accuracy= 1.00000
# Iter 1142400, Minibatch Loss= 0.666658, Training Accuracy= 0.87500
# Iter 1144000, Minibatch Loss= 0.038023, Training Accuracy= 1.00000
# Iter 1145600, Minibatch Loss= 0.032286, Training Accuracy= 1.00000
# Iter 1147200, Minibatch Loss= 0.115722, Training Accuracy= 1.00000
# Iter 1148800, Minibatch Loss= 0.055427, Training Accuracy= 1.00000
# Iter 1150400, Minibatch Loss= 0.344076, Training Accuracy= 0.87500
# Iter 1152000, Minibatch Loss= 0.431736, Training Accuracy= 0.87500
# Iter 1153600, Minibatch Loss= 0.548413, Training Accuracy= 0.81250
# Iter 1155200, Minibatch Loss= 0.464297, Training Accuracy= 0.93750
# Iter 1156800, Minibatch Loss= 0.113650, Training Accuracy= 0.93750
# Iter 1158400, Minibatch Loss= 0.529594, Training Accuracy= 0.93750
# Iter 1160000, Minibatch Loss= 0.078780, Training Accuracy= 1.00000
# Iter 1161600, Minibatch Loss= 0.281074, Training Accuracy= 0.87500
# ...
# Iter 1219200, Minibatch Loss= 0.521319, Training Accuracy= 0.93750
# Iter 1220800, Minibatch Loss= 0.072996, Training Accuracy= 1.00000
# Iter 1222400, Minibatch Loss= 0.154876, Training Accuracy= 0.93750
# Iter 1224000, Minibatch Loss= 0.037299, Training Accuracy= 1.00000
# Iter 1225600, Minibatch Loss= 0.118672, Training Accuracy= 1.00000
# Iter 1227200, Minibatch Loss= 0.218618, Training Accuracy= 0.93750
# Iter 1228800, Minibatch Loss= 0.023997, Training Accuracy= 1.00000
# Iter 1230400, Minibatch Loss= 0.219769, Training Accuracy= 0.93750
# Iter 1232000, Minibatch Loss= 0.402498, Training Accuracy= 0.93750
# Iter 1233600, Minibatch Loss= 0.483055, Training Accuracy= 0.87500
# Iter 1235200, Minibatch Loss= 0.048297, Training Accuracy= 1.00000
# Iter 1236800, Minibatch Loss= 0.076469, Training Accuracy= 1.00000
# Iter 1238400, Minibatch Loss= 0.248797, Training Accuracy= 0.93750
# Iter 1240000, Minibatch Loss= 0.042446, Training Accuracy= 1.00000
# Iter 1241600, Minibatch Loss= 0.162991, Training Accuracy= 0.93750
# Iter 1243200, Minibatch Loss= 0.045239, Training Accuracy= 1.00000
# Iter 1244800, Minibatch Loss= 0.189797, Training Accuracy= 0.93750
# Iter 1246400, Minibatch Loss= 0.412791, Training Accuracy= 0.87500
# Iter 1248000, Minibatch Loss= 0.024617, Training Accuracy= 1.00000
# Iter 1249600, Minibatch Loss= 0.154813, Training Accuracy= 0.93750
# Iter 1251200, Minibatch Loss= 0.382004, Training Accuracy= 0.87500
# Iter 1252800, Minibatch Loss= 0.659909, Training Accuracy= 0.87500
# Iter 1254400, Minibatch Loss= 0.043313, Training Accuracy= 1.00000
# Iter 1256000, Minibatch Loss= 0.207383, Training Accuracy= 0.93750
# Iter 1257600, Minibatch Loss= 0.150329, Training Accuracy= 0.93750
# Iter 1259200, Minibatch Loss= 0.753733, Training Accuracy= 0.75000
# Iter 1260800, Minibatch Loss= 0.015146, Training Accuracy= 1.00000
# Iter 1262400, Minibatch Loss= 0.073805, Training Accuracy= 1.00000
# Iter 1264000, Minibatch Loss= 0.704837, Training Accuracy= 0.93750
# Iter 1265600, Minibatch Loss= 0.269049, Training Accuracy= 0.93750
# Iter 1267200, Minibatch Loss= 0.750009, Training Accuracy= 0.87500
# Iter 1268800, Minibatch Loss= 0.350706, Training Accuracy= 0.93750
# Iter 1270400, Minibatch Loss= 0.035611, Training Accuracy= 1.00000
# Iter 1272000, Minibatch Loss= 0.783951, Training Accuracy= 0.87500
# Iter 1273600, Minibatch Loss= 0.158878, Training Accuracy= 0.87500
# Iter 1275200, Minibatch Loss= 0.185758, Training Accuracy= 0.93750
# Iter 1276800, Minibatch Loss= 0.296885, Training Accuracy= 0.87500
# Iter 1278400, Minibatch Loss= 0.016089, Training Accuracy= 1.00000
# Iter 1280000, Minibatch Loss= 0.086373, Training Accuracy= 1.00000
# Iter 1281600, Minibatch Loss= 0.151039, Training Accuracy= 0.93750
# Iter 1283200, Minibatch Loss= 0.084986, Training Accuracy= 0.93750
# Iter 1284800, Minibatch Loss= 0.055949, Training Accuracy= 1.00000
# Iter 1286400, Minibatch Loss= 0.058918, Training Accuracy= 1.00000
# Iter 1288000, Minibatch Loss= 0.246230, Training Accuracy= 0.93750
# Iter 1289600, Minibatch Loss= 0.162255, Training Accuracy= 0.93750
# Iter 1291200, Minibatch Loss= 0.115521, Training Accuracy= 1.00000
# Iter 1292800, Minibatch Loss= 0.118783, Training Accuracy= 0.93750
# Iter 1294400, Minibatch Loss= 0.206892, Training Accuracy= 0.93750
# Iter 1296000, Minibatch Loss= 0.189988, Training Accuracy= 0.93750
# Iter 1297600, Minibatch Loss= 0.196237, Training Accuracy= 0.93750
# Iter 1299200, Minibatch Loss= 0.031157, Training Accuracy= 1.00000
# Iter 1300800, Minibatch Loss= 0.055385, Training Accuracy= 1.00000
# Iter 1302400, Minibatch Loss= 0.026078, Training Accuracy= 1.00000
# Iter 1304000, Minibatch Loss= 0.016972, Training Accuracy= 1.00000
# Iter 1305600, Minibatch Loss= 0.366937, Training Accuracy= 0.87500
# Iter 1307200, Minibatch Loss= 0.371329, Training Accuracy= 0.93750
# Iter 1308800, Minibatch Loss= 0.012174, Training Accuracy= 1.00000
# Iter 1310400, Minibatch Loss= 0.173247, Training Accuracy= 1.00000
# Iter 1312000, Minibatch Loss= 0.205940, Training Accuracy= 0.93750
# Iter 1313600, Minibatch Loss= 0.057903, Training Accuracy= 1.00000
# Iter 1315200, Minibatch Loss= 0.108675, Training Accuracy= 0.93750
# Iter 1316800, Minibatch Loss= 0.115214, Training Accuracy= 0.93750
# Iter 1318400, Minibatch Loss= 0.311199, Training Accuracy= 0.93750
# Iter 1320000, Minibatch Loss= 0.412706, Training Accuracy= 0.87500
# Iter 1321600, Minibatch Loss= 0.012955, Training Accuracy= 1.00000
# Iter 1323200, Minibatch Loss= 0.308521, Training Accuracy= 0.93750
# Iter 1324800, Minibatch Loss= 0.150004, Training Accuracy= 0.93750
# Iter 1326400, Minibatch Loss= 0.095533, Training Accuracy= 0.93750
# Iter 1328000, Minibatch Loss= 0.018807, Training Accuracy= 1.00000
# Iter 1329600, Minibatch Loss= 0.406672, Training Accuracy= 0.93750
# Iter 1331200, Minibatch Loss= 0.061912, Training Accuracy= 1.00000
# Iter 1332800, Minibatch Loss= 0.396143, Training Accuracy= 0.87500
# Iter 1334400, Minibatch Loss= 0.132915, Training Accuracy= 0.93750
# Iter 1336000, Minibatch Loss= 0.031794, Training Accuracy= 1.00000
# Iter 1337600, Minibatch Loss= 0.515240, Training Accuracy= 0.87500
# Iter 1339200, Minibatch Loss= 0.211201, Training Accuracy= 0.87500
# Iter 1340800, Minibatch Loss= 0.039640, Training Accuracy= 1.00000
# Iter 1342400, Minibatch Loss= 0.037243, Training Accuracy= 1.00000
# Iter 1344000, Minibatch Loss= 0.438789, Training Accuracy= 0.93750
# Iter 1345600, Minibatch Loss= 0.237323, Training Accuracy= 0.87500
# Iter 1347200, Minibatch Loss= 0.046801, Training Accuracy= 1.00000
# Iter 1348800, Minibatch Loss= 0.220832, Training Accuracy= 0.87500
# Iter 1350400, Minibatch Loss= 0.469105, Training Accuracy= 0.93750
# Iter 1352000, Minibatch Loss= 0.284757, Training Accuracy= 0.93750
# Iter 1353600, Minibatch Loss= 0.522600, Training Accuracy= 0.87500
# Iter 1355200, Minibatch Loss= 0.433016, Training Accuracy= 0.93750
# Iter 1356800, Minibatch Loss= 0.041229, Training Accuracy= 1.00000
# Iter 1358400, Minibatch Loss= 0.052964, Training Accuracy= 1.00000
# Iter 1360000, Minibatch Loss= 0.078353, Training Accuracy= 1.00000
# Iter 1361600, Minibatch Loss= 0.054192, Training Accuracy= 1.00000
# Iter 1363200, Minibatch Loss= 0.172745, Training Accuracy= 0.93750
# Iter 1364800, Minibatch Loss= 0.210540, Training Accuracy= 0.93750
# Iter 1366400, Minibatch Loss= 0.126170, Training Accuracy= 1.00000
# Iter 1368000, Minibatch Loss= 0.497659, Training Accuracy= 0.87500
# Iter 1369600, Minibatch Loss= 0.209833, Training Accuracy= 0.87500
# Iter 1371200, Minibatch Loss= 0.091538, Training Accuracy= 1.00000
# Iter 1372800, Minibatch Loss= 0.034062, Training Accuracy= 1.00000
# Iter 1374400, Minibatch Loss= 0.107790, Training Accuracy= 0.93750
# Iter 1376000, Minibatch Loss= 0.143473, Training Accuracy= 0.93750
# Iter 1377600, Minibatch Loss= 0.071633, Training Accuracy= 1.00000
# Iter 1379200, Minibatch Loss= 0.006151, Training Accuracy= 1.00000
# Iter 1380800, Minibatch Loss= 0.044358, Training Accuracy= 1.00000
# Iter 1382400, Minibatch Loss= 0.045136, Training Accuracy= 1.00000
# Iter 1384000, Minibatch Loss= 0.052963, Training Accuracy= 1.00000
# Iter 1385600, Minibatch Loss= 0.103789, Training Accuracy= 1.00000
# Iter 1387200, Minibatch Loss= 0.013757, Training Accuracy= 1.00000
# Iter 1388800, Minibatch Loss= 0.030454, Training Accuracy= 1.00000
# Iter 1390400, Minibatch Loss= 0.165977, Training Accuracy= 0.87500
# Iter 1392000, Minibatch Loss= 0.119447, Training Accuracy= 1.00000
# Iter 1393600, Minibatch Loss= 0.071188, Training Accuracy= 1.00000
# Iter 1395200, Minibatch Loss= 0.041420, Training Accuracy= 1.00000
# Iter 1396800, Minibatch Loss= 0.087228, Training Accuracy= 1.00000
# Iter 1398400, Minibatch Loss= 0.058510, Training Accuracy= 1.00000
# Iter 1400000, Minibatch Loss= 0.096741, Training Accuracy= 0.93750
# Iter 1401600, Minibatch Loss= 0.103723, Training Accuracy= 0.93750
# Iter 1403200, Minibatch Loss= 0.021581, Training Accuracy= 1.00000
# Iter 1404800, Minibatch Loss= 0.216907, Training Accuracy= 0.87500
# Iter 1406400, Minibatch Loss= 0.427177, Training Accuracy= 0.93750
# Iter 1408000, Minibatch Loss= 0.323491, Training Accuracy= 0.93750
# Iter 1409600, Minibatch Loss= 0.049542, Training Accuracy= 1.00000
# Iter 1411200, Minibatch Loss= 0.801530, Training Accuracy= 0.87500
# Iter 1412800, Minibatch Loss= 0.032615, Training Accuracy= 1.00000
# Iter 1414400, Minibatch Loss= 0.019288, Training Accuracy= 1.00000
# Iter 1416000, Minibatch Loss= 0.012637, Training Accuracy= 1.00000
# Iter 1417600, Minibatch Loss= 0.170733, Training Accuracy= 0.93750
# Iter 1419200, Minibatch Loss= 0.026308, Training Accuracy= 1.00000
# Iter 1420800, Minibatch Loss= 0.050458, Training Accuracy= 1.00000
# Iter 1422400, Minibatch Loss= 0.092856, Training Accuracy= 0.93750
# Iter 1424000, Minibatch Loss= 0.064985, Training Accuracy= 1.00000
# Iter 1425600, Minibatch Loss= 0.277052, Training Accuracy= 0.93750
# Iter 1427200, Minibatch Loss= 0.116853, Training Accuracy= 0.93750
# Iter 1428800, Minibatch Loss= 0.036093, Training Accuracy= 1.00000
# Iter 1430400, Minibatch Loss= 0.265139, Training Accuracy= 0.93750
# Iter 1432000, Minibatch Loss= 0.005304, Training Accuracy= 1.00000
# Iter 1433600, Minibatch Loss= 0.053618, Training Accuracy= 1.00000
# Iter 1435200, Minibatch Loss= 0.345062, Training Accuracy= 0.93750
# Iter 1436800, Minibatch Loss= 0.045718, Training Accuracy= 1.00000
# Iter 1438400, Minibatch Loss= 0.172807, Training Accuracy= 0.93750
# Iter 1440000, Minibatch Loss= 0.175693, Training Accuracy= 0.87500
# Iter 1441600, Minibatch Loss= 0.012860, Training Accuracy= 1.00000
# Iter 1443200, Minibatch Loss= 0.669438, Training Accuracy= 0.87500
# Iter 1444800, Minibatch Loss= 0.039254, Training Accuracy= 1.00000
# Iter 1446400, Minibatch Loss= 0.006900, Training Accuracy= 1.00000
# Iter 1448000, Minibatch Loss= 0.055550, Training Accuracy= 1.00000
# Iter 1449600, Minibatch Loss= 0.056356, Training Accuracy= 1.00000
# Iter 1451200, Minibatch Loss= 0.052240, Training Accuracy= 1.00000
# Iter 1452800, Minibatch Loss= 0.769201, Training Accuracy= 0.81250
# Iter 1454400, Minibatch Loss= 0.333566, Training Accuracy= 0.87500
# Iter 1456000, Minibatch Loss= 0.482852, Training Accuracy= 0.87500
# Iter 1457600, Minibatch Loss= 0.018860, Training Accuracy= 1.00000
# Iter 1459200, Minibatch Loss= 0.022563, Training Accuracy= 1.00000
# Iter 1460800, Minibatch Loss= 0.491602, Training Accuracy= 0.93750
# Iter 1462400, Minibatch Loss= 0.390473, Training Accuracy= 0.93750
# Iter 1464000, Minibatch Loss= 0.204645, Training Accuracy= 0.93750
# Iter 1465600, Minibatch Loss= 0.029000, Training Accuracy= 1.00000
# Iter 1467200, Minibatch Loss= 0.409237, Training Accuracy= 0.87500
# Iter 1468800, Minibatch Loss= 0.021042, Training Accuracy= 1.00000
# Iter 1470400, Minibatch Loss= 0.182741, Training Accuracy= 0.93750
# Iter 1472000, Minibatch Loss= 0.057005, Training Accuracy= 0.93750
# Iter 1473600, Minibatch Loss= 0.212014, Training Accuracy= 0.93750
# Iter 1475200, Minibatch Loss= 0.053169, Training Accuracy= 1.00000
# Iter 1476800, Minibatch Loss= 0.009806, Training Accuracy= 1.00000
# Iter 1478400, Minibatch Loss= 0.002675, Training Accuracy= 1.00000
# Iter 1480000, Minibatch Loss= 0.101511, Training Accuracy= 0.93750
# Iter 1481600, Minibatch Loss= 0.801806, Training Accuracy= 0.93750
# Iter 1483200, Minibatch Loss= 0.030884, Training Accuracy= 1.00000
# Iter 1484800, Minibatch Loss= 0.024326, Training Accuracy= 1.00000
# Iter 1486400, Minibatch Loss= 0.051456, Training Accuracy= 1.00000
# Iter 1488000, Minibatch Loss= 0.073604, Training Accuracy= 1.00000
# Iter 1489600, Minibatch Loss= 0.371188, Training Accuracy= 0.93750
# Iter 1491200, Minibatch Loss= 0.012995, Training Accuracy= 1.00000
# Iter 1492800, Minibatch Loss= 0.157475, Training Accuracy= 0.93750
# Iter 1494400, Minibatch Loss= 0.007725, Training Accuracy= 1.00000
# Iter 1496000, Minibatch Loss= 0.041018, Training Accuracy= 1.00000
# Iter 1497600, Minibatch Loss= 0.011227, Training Accuracy= 1.00000
# Iter 1499200, Minibatch Loss= 0.035052, Training Accuracy= 1.00000
# Iter 1500800, Minibatch Loss= 0.533508, Training Accuracy= 0.93750
# Iter 1502400, Minibatch Loss= 0.448482, Training Accuracy= 0.93750
# Iter 1504000, Minibatch Loss= 0.041259, Training Accuracy= 1.00000
# Iter 1505600, Minibatch Loss= 0.035605, Training Accuracy= 1.00000
# Iter 1507200, Minibatch Loss= 0.149857, Training Accuracy= 0.93750
# Iter 1508800, Minibatch Loss= 0.007883, Training Accuracy= 1.00000
# Iter 1510400, Minibatch Loss= 0.589361, Training Accuracy= 0.93750
# Iter 1512000, Minibatch Loss= 0.980410, Training Accuracy= 0.81250
# Iter 1513600, Minibatch Loss= 0.032511, Training Accuracy= 1.00000
# Iter 1515200, Minibatch Loss= 0.416889, Training Accuracy= 0.93750
# Iter 1516800, Minibatch Loss= 0.095601, Training Accuracy= 1.00000
# Iter 1518400, Minibatch Loss= 0.023410, Training Accuracy= 1.00000
# Iter 1520000, Minibatch Loss= 0.063656, Training Accuracy= 1.00000
# Iter 1521600, Minibatch Loss= 0.142331, Training Accuracy= 0.93750
# Iter 1523200, Minibatch Loss= 0.012756, Training Accuracy= 1.00000
# Iter 1524800, Minibatch Loss= 0.463037, Training Accuracy= 0.87500
# Iter 1526400, Minibatch Loss= 0.036011, Training Accuracy= 1.00000
# Iter 1528000, Minibatch Loss= 0.076684, Training Accuracy= 1.00000
# Iter 1529600, Minibatch Loss= 0.015281, Training Accuracy= 1.00000
# Iter 1531200, Minibatch Loss= 0.149786, Training Accuracy= 0.93750
# Iter 1532800, Minibatch Loss= 0.034985, Training Accuracy= 1.00000
# Iter 1534400, Minibatch Loss= 0.023671, Training Accuracy= 1.00000
# Iter 1536000, Minibatch Loss= 0.226279, Training Accuracy= 0.87500
# Iter 1537600, Minibatch Loss= 0.005284, Training Accuracy= 1.00000
# Iter 1539200, Minibatch Loss= 0.068410, Training Accuracy= 1.00000
# Iter 1540800, Minibatch Loss= 0.401103, Training Accuracy= 0.87500
# Iter 1542400, Minibatch Loss= 0.028923, Training Accuracy= 1.00000
# Iter 1544000, Minibatch Loss= 0.069285, Training Accuracy= 1.00000
# Iter 1545600, Minibatch Loss= 0.033662, Training Accuracy= 1.00000
# Iter 1547200, Minibatch Loss= 0.009749, Training Accuracy= 1.00000
# Iter 1548800, Minibatch Loss= 0.245795, Training Accuracy= 0.93750
# Iter 1550400, Minibatch Loss= 0.034882, Training Accuracy= 1.00000
# Iter 1552000, Minibatch Loss= 0.423230, Training Accuracy= 0.87500
# Iter 1553600, Minibatch Loss= 0.387047, Training Accuracy= 0.93750
# Iter 1555200, Minibatch Loss= 0.033926, Training Accuracy= 1.00000
# Iter 1556800, Minibatch Loss= 0.122289, Training Accuracy= 0.93750
# Iter 1558400, Minibatch Loss= 0.005190, Training Accuracy= 1.00000
# Iter 1560000, Minibatch Loss= 0.003561, Training Accuracy= 1.00000
# Iter 1561600, Minibatch Loss= 0.128283, Training Accuracy= 0.93750
# Iter 1563200, Minibatch Loss= 0.038746, Training Accuracy= 1.00000
# Iter 1564800, Minibatch Loss= 0.124801, Training Accuracy= 0.93750
# Iter 1566400, Minibatch Loss= 0.051837, Training Accuracy= 1.00000
# Iter 1568000, Minibatch Loss= 0.127717, Training Accuracy= 0.93750
# Iter 1569600, Minibatch Loss= 0.443493, Training Accuracy= 0.87500
# Iter 1571200, Minibatch Loss= 0.275961, Training Accuracy= 0.93750
# Iter 1572800, Minibatch Loss= 0.050171, Training Accuracy= 1.00000
# Iter 1574400, Minibatch Loss= 0.000527, Training Accuracy= 1.00000
# Iter 1576000, Minibatch Loss= 0.020215, Training Accuracy= 1.00000
# Iter 1577600, Minibatch Loss= 0.351662, Training Accuracy= 0.93750
# Iter 1579200, Minibatch Loss= 0.027579, Training Accuracy= 1.00000
# Iter 1580800, Minibatch Loss= 0.095303, Training Accuracy= 0.93750
# Iter 1582400, Minibatch Loss= 0.031316, Training Accuracy= 1.00000
# Iter 1584000, Minibatch Loss= 0.046365, Training Accuracy= 1.00000
# Iter 1585600, Minibatch Loss= 0.132100, Training Accuracy= 0.93750
# Iter 1587200, Minibatch Loss= 0.527724, Training Accuracy= 0.87500
# Iter 1588800, Minibatch Loss= 0.504709, Training Accuracy= 0.87500
# Iter 1590400, Minibatch Loss= 0.027888, Training Accuracy= 1.00000
# Iter 1592000, Minibatch Loss= 0.075310, Training Accuracy= 0.93750
# Iter 1593600, Minibatch Loss= 0.026696, Training Accuracy= 1.00000
# Iter 1595200, Minibatch Loss= 0.012446, Training Accuracy= 1.00000
# Iter 1596800, Minibatch Loss= 0.180190, Training Accuracy= 0.93750
# Iter 1598400, Minibatch Loss= 0.513336, Training Accuracy= 0.93750
# Optimization Finished!
# Testing Accuracy: 0.825625

# %%
saver.save(sess, '../Model/NIN-Model-0626')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', 'hungry', 'want1', '1', 'd', '7', 's', '2', 'y', 'p', 'me', 'likeb2', 'i', '9', 'q', 'why2', 'nob1', 'sorry1', 'thanku1', 'want2', 'w', 'n', 'c', '3', 'g', 'v', 'time1', 'a', 'come', 'you', 'howd2', 'help_h2', 'unders1', 't', 'nob2', '8', 'u', 'x', '6', 'h', 'e', '5', 'o', '4', 'f', 'non', 'unders2', 'm', 'b', 'likeb1', 'r', 'l', 'howd1', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
