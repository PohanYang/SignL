# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t504.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (118972, 37)

# %%
# Parameters
learning_rate = 0.001
training_iters = 500000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-4})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==5):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.571721, Training Accuracy= 0.12500
# Iter 3200, Minibatch Loss= 3.465716, Training Accuracy= 0.00000
# Iter 4800, Minibatch Loss= 3.512283, Training Accuracy= 0.12500
# Iter 6400, Minibatch Loss= 3.546900, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.602306, Training Accuracy= 0.06250
# Iter 9600, Minibatch Loss= 3.512714, Training Accuracy= 0.12500
# Iter 11200, Minibatch Loss= 3.575206, Training Accuracy= 0.06250
# Iter 12800, Minibatch Loss= 3.583254, Training Accuracy= 0.00000
# Iter 14400, Minibatch Loss= 3.559955, Training Accuracy= 0.00000
# Iter 16000, Minibatch Loss= 3.333540, Training Accuracy= 0.12500
# Iter 17600, Minibatch Loss= 3.608637, Training Accuracy= 0.00000
# Iter 19200, Minibatch Loss= 3.490427, Training Accuracy= 0.12500
# Iter 20800, Minibatch Loss= 3.615375, Training Accuracy= 0.06250
# Iter 22400, Minibatch Loss= 3.253533, Training Accuracy= 0.18750
# Iter 24000, Minibatch Loss= 3.616812, Training Accuracy= 0.06250
# Iter 25600, Minibatch Loss= 3.457541, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.502521, Training Accuracy= 0.00000
# Iter 28800, Minibatch Loss= 3.039045, Training Accuracy= 0.31250
# Iter 30400, Minibatch Loss= 3.160547, Training Accuracy= 0.12500
# Iter 32000, Minibatch Loss= 3.529161, Training Accuracy= 0.00000
# Iter 33600, Minibatch Loss= 3.224333, Training Accuracy= 0.18750
# Iter 35200, Minibatch Loss= 3.570591, Training Accuracy= 0.00000
# Iter 36800, Minibatch Loss= 3.504736, Training Accuracy= 0.12500
# Iter 38400, Minibatch Loss= 2.882722, Training Accuracy= 0.25000
# Iter 40000, Minibatch Loss= 3.246862, Training Accuracy= 0.00000
# Iter 41600, Minibatch Loss= 3.533487, Training Accuracy= 0.06250
# Iter 43200, Minibatch Loss= 3.176625, Training Accuracy= 0.12500
# Iter 44800, Minibatch Loss= 3.337560, Training Accuracy= 0.06250
# Iter 46400, Minibatch Loss= 3.253517, Training Accuracy= 0.25000
# Iter 48000, Minibatch Loss= 3.152367, Training Accuracy= 0.18750
# Iter 49600, Minibatch Loss= 3.275457, Training Accuracy= 0.06250
# Iter 51200, Minibatch Loss= 2.622662, Training Accuracy= 0.25000
# Iter 52800, Minibatch Loss= 3.318511, Training Accuracy= 0.06250
# Iter 54400, Minibatch Loss= 3.166884, Training Accuracy= 0.06250
# Iter 56000, Minibatch Loss= 3.036121, Training Accuracy= 0.25000
# Iter 57600, Minibatch Loss= 2.796449, Training Accuracy= 0.31250
# Iter 59200, Minibatch Loss= 2.957827, Training Accuracy= 0.25000
# Iter 60800, Minibatch Loss= 2.622276, Training Accuracy= 0.18750
# Iter 62400, Minibatch Loss= 2.750176, Training Accuracy= 0.06250
# Iter 64000, Minibatch Loss= 2.252120, Training Accuracy= 0.31250
# Iter 65600, Minibatch Loss= 2.896957, Training Accuracy= 0.18750
# Iter 67200, Minibatch Loss= 2.347352, Training Accuracy= 0.25000
# Iter 68800, Minibatch Loss= 2.435781, Training Accuracy= 0.18750
# Iter 70400, Minibatch Loss= 2.166038, Training Accuracy= 0.50000
# Iter 72000, Minibatch Loss= 2.095929, Training Accuracy= 0.43750
# Iter 73600, Minibatch Loss= 2.837758, Training Accuracy= 0.18750
# Iter 75200, Minibatch Loss= 2.358116, Training Accuracy= 0.31250
# Iter 76800, Minibatch Loss= 2.344790, Training Accuracy= 0.31250
# Iter 78400, Minibatch Loss= 2.092704, Training Accuracy= 0.31250
# Iter 80000, Minibatch Loss= 2.244418, Training Accuracy= 0.12500
# Iter 81600, Minibatch Loss= 2.662150, Training Accuracy= 0.25000
# Iter 83200, Minibatch Loss= 2.218713, Training Accuracy= 0.31250
# Iter 84800, Minibatch Loss= 2.257074, Training Accuracy= 0.25000
# Iter 86400, Minibatch Loss= 1.674485, Training Accuracy= 0.50000
# Iter 88000, Minibatch Loss= 2.156687, Training Accuracy= 0.56250
# Iter 89600, Minibatch Loss= 1.858824, Training Accuracy= 0.37500
# Iter 91200, Minibatch Loss= 1.201866, Training Accuracy= 0.50000
# Iter 92800, Minibatch Loss= 0.912671, Training Accuracy= 0.87500
# Iter 94400, Minibatch Loss= 1.283854, Training Accuracy= 0.56250
# Iter 96000, Minibatch Loss= 1.407186, Training Accuracy= 0.50000
# Iter 97600, Minibatch Loss= 1.391391, Training Accuracy= 0.50000
# Iter 99200, Minibatch Loss= 1.217416, Training Accuracy= 0.68750
# Iter 100800, Minibatch Loss= 1.537764, Training Accuracy= 0.62500
# Iter 102400, Minibatch Loss= 1.051628, Training Accuracy= 0.68750
# Iter 104000, Minibatch Loss= 0.982875, Training Accuracy= 0.68750
# Iter 105600, Minibatch Loss= 0.858421, Training Accuracy= 0.68750
# Iter 107200, Minibatch Loss= 0.967567, Training Accuracy= 0.56250
# Iter 108800, Minibatch Loss= 0.636069, Training Accuracy= 0.68750
# Iter 110400, Minibatch Loss= 0.859471, Training Accuracy= 0.75000
# Iter 112000, Minibatch Loss= 0.662349, Training Accuracy= 0.81250
# Iter 113600, Minibatch Loss= 0.838361, Training Accuracy= 0.75000
# Iter 115200, Minibatch Loss= 0.568997, Training Accuracy= 0.93750
# Iter 116800, Minibatch Loss= 0.600308, Training Accuracy= 0.75000
# Iter 118400, Minibatch Loss= 0.461131, Training Accuracy= 0.87500
# Iter 120000, Minibatch Loss= 0.442036, Training Accuracy= 0.87500
# Iter 121600, Minibatch Loss= 0.291046, Training Accuracy= 0.87500
# Iter 123200, Minibatch Loss= 0.272900, Training Accuracy= 1.00000
# Iter 124800, Minibatch Loss= 0.467281, Training Accuracy= 0.81250
# Iter 126400, Minibatch Loss= 0.397893, Training Accuracy= 0.87500
# Iter 128000, Minibatch Loss= 0.759598, Training Accuracy= 0.68750
# Iter 129600, Minibatch Loss= 0.372123, Training Accuracy= 0.93750
# Iter 131200, Minibatch Loss= 0.430535, Training Accuracy= 0.93750
# Iter 132800, Minibatch Loss= 0.354838, Training Accuracy= 0.87500
# Iter 134400, Minibatch Loss= 0.221436, Training Accuracy= 0.93750
# Iter 136000, Minibatch Loss= 0.153988, Training Accuracy= 0.93750
# Iter 137600, Minibatch Loss= 0.317433, Training Accuracy= 0.87500
# Iter 139200, Minibatch Loss= 0.425329, Training Accuracy= 0.81250
# Iter 140800, Minibatch Loss= 0.319188, Training Accuracy= 0.87500
# Iter 142400, Minibatch Loss= 0.310745, Training Accuracy= 0.93750
# Iter 144000, Minibatch Loss= 0.194486, Training Accuracy= 1.00000
# Iter 145600, Minibatch Loss= 0.549796, Training Accuracy= 0.81250
# Iter 147200, Minibatch Loss= 0.389108, Training Accuracy= 0.93750
# Iter 148800, Minibatch Loss= 0.104743, Training Accuracy= 0.93750
# Iter 150400, Minibatch Loss= 0.789757, Training Accuracy= 0.75000
# Iter 152000, Minibatch Loss= 0.058882, Training Accuracy= 1.00000
# Iter 153600, Minibatch Loss= 0.206932, Training Accuracy= 0.93750
# Iter 155200, Minibatch Loss= 1.229988, Training Accuracy= 0.81250
# Iter 156800, Minibatch Loss= 0.188453, Training Accuracy= 0.93750
# Iter 158400, Minibatch Loss= 0.284603, Training Accuracy= 0.93750
# Iter 160000, Minibatch Loss= 0.285928, Training Accuracy= 0.93750
# Iter 161600, Minibatch Loss= 0.406572, Training Accuracy= 0.87500
# Iter 163200, Minibatch Loss= 0.583514, Training Accuracy= 0.87500
# Iter 164800, Minibatch Loss= 0.353265, Training Accuracy= 0.87500
# Iter 166400, Minibatch Loss= 0.737286, Training Accuracy= 0.87500
# Iter 168000, Minibatch Loss= 0.370389, Training Accuracy= 0.75000
# Iter 169600, Minibatch Loss= 0.080873, Training Accuracy= 1.00000
# Iter 171200, Minibatch Loss= 0.197987, Training Accuracy= 0.93750
# Iter 172800, Minibatch Loss= 0.058134, Training Accuracy= 1.00000
# Iter 174400, Minibatch Loss= 0.106334, Training Accuracy= 1.00000
# Iter 176000, Minibatch Loss= 0.032425, Training Accuracy= 1.00000
# Iter 177600, Minibatch Loss= 0.148522, Training Accuracy= 0.93750
# Iter 179200, Minibatch Loss= 0.063650, Training Accuracy= 1.00000
# Iter 180800, Minibatch Loss= 0.174189, Training Accuracy= 0.93750
# Iter 182400, Minibatch Loss= 0.228969, Training Accuracy= 0.87500
# Iter 184000, Minibatch Loss= 0.368628, Training Accuracy= 0.87500
# Iter 185600, Minibatch Loss= 0.101182, Training Accuracy= 0.93750
# Iter 187200, Minibatch Loss= 0.249970, Training Accuracy= 0.93750
# Iter 188800, Minibatch Loss= 0.152736, Training Accuracy= 0.93750
# Iter 190400, Minibatch Loss= 0.098204, Training Accuracy= 1.00000
# Iter 192000, Minibatch Loss= 0.235390, Training Accuracy= 0.93750
# Iter 193600, Minibatch Loss= 0.209447, Training Accuracy= 0.87500
# Iter 195200, Minibatch Loss= 0.696481, Training Accuracy= 0.81250
# Iter 196800, Minibatch Loss= 0.053581, Training Accuracy= 1.00000
# Iter 198400, Minibatch Loss= 0.132474, Training Accuracy= 1.00000
# Iter 200000, Minibatch Loss= 0.070574, Training Accuracy= 1.00000
# Iter 201600, Minibatch Loss= 0.013120, Training Accuracy= 1.00000
# Iter 203200, Minibatch Loss= 0.037238, Training Accuracy= 1.00000
# Iter 204800, Minibatch Loss= 0.205697, Training Accuracy= 0.93750
# Iter 206400, Minibatch Loss= 0.052081, Training Accuracy= 1.00000
# Iter 208000, Minibatch Loss= 0.037035, Training Accuracy= 1.00000
# Iter 209600, Minibatch Loss= 0.186823, Training Accuracy= 0.93750
# Iter 211200, Minibatch Loss= 0.003998, Training Accuracy= 1.00000
# Iter 212800, Minibatch Loss= 0.064158, Training Accuracy= 1.00000
# Iter 214400, Minibatch Loss= 0.201093, Training Accuracy= 0.93750
# Iter 216000, Minibatch Loss= 0.057643, Training Accuracy= 1.00000
# Iter 217600, Minibatch Loss= 0.100383, Training Accuracy= 0.93750
# Iter 219200, Minibatch Loss= 0.102932, Training Accuracy= 0.93750
# Iter 220800, Minibatch Loss= 0.008777, Training Accuracy= 1.00000
# Iter 222400, Minibatch Loss= 0.087113, Training Accuracy= 0.93750
# Iter 224000, Minibatch Loss= 0.014242, Training Accuracy= 1.00000
# Iter 225600, Minibatch Loss= 0.049905, Training Accuracy= 1.00000
# Iter 227200, Minibatch Loss= 0.729150, Training Accuracy= 0.93750
# Iter 228800, Minibatch Loss= 0.266531, Training Accuracy= 0.93750
# Iter 230400, Minibatch Loss= 0.190424, Training Accuracy= 0.87500
# Iter 232000, Minibatch Loss= 0.018652, Training Accuracy= 1.00000
# Iter 233600, Minibatch Loss= 0.022962, Training Accuracy= 1.00000
# Iter 235200, Minibatch Loss= 0.042264, Training Accuracy= 1.00000
# Iter 236800, Minibatch Loss= 0.017795, Training Accuracy= 1.00000
# Iter 238400, Minibatch Loss= 0.666967, Training Accuracy= 0.87500
# Iter 240000, Minibatch Loss= 0.006231, Training Accuracy= 1.00000
# Iter 241600, Minibatch Loss= 0.023448, Training Accuracy= 1.00000
# Iter 243200, Minibatch Loss= 0.012056, Training Accuracy= 1.00000
# Iter 244800, Minibatch Loss= 0.023211, Training Accuracy= 1.00000
# Iter 246400, Minibatch Loss= 0.013757, Training Accuracy= 1.00000
# Iter 248000, Minibatch Loss= 0.036180, Training Accuracy= 1.00000
# Iter 249600, Minibatch Loss= 0.036166, Training Accuracy= 1.00000
# Iter 251200, Minibatch Loss= 0.009084, Training Accuracy= 1.00000
# Iter 252800, Minibatch Loss= 0.052977, Training Accuracy= 1.00000
# Iter 254400, Minibatch Loss= 0.114118, Training Accuracy= 0.93750
# Iter 256000, Minibatch Loss= 0.211719, Training Accuracy= 0.93750
# Iter 257600, Minibatch Loss= 0.011020, Training Accuracy= 1.00000
# Iter 259200, Minibatch Loss= 0.206110, Training Accuracy= 0.93750
# Iter 260800, Minibatch Loss= 0.041713, Training Accuracy= 1.00000
# Iter 262400, Minibatch Loss= 0.272942, Training Accuracy= 0.93750
# Iter 264000, Minibatch Loss= 0.293266, Training Accuracy= 0.93750
# Iter 265600, Minibatch Loss= 0.021057, Training Accuracy= 1.00000
# Iter 267200, Minibatch Loss= 0.005606, Training Accuracy= 1.00000
# Iter 268800, Minibatch Loss= 0.037630, Training Accuracy= 1.00000
# Iter 270400, Minibatch Loss= 0.012930, Training Accuracy= 1.00000
# Iter 272000, Minibatch Loss= 0.055012, Training Accuracy= 1.00000
# Iter 273600, Minibatch Loss= 0.002378, Training Accuracy= 1.00000
# Iter 275200, Minibatch Loss= 0.469714, Training Accuracy= 0.93750
# Iter 276800, Minibatch Loss= 0.001045, Training Accuracy= 1.00000
# Iter 278400, Minibatch Loss= 0.024539, Training Accuracy= 1.00000
# Iter 280000, Minibatch Loss= 0.034618, Training Accuracy= 1.00000
# Iter 281600, Minibatch Loss= 0.013486, Training Accuracy= 1.00000
# Iter 283200, Minibatch Loss= 0.001478, Training Accuracy= 1.00000
# Iter 284800, Minibatch Loss= 0.535795, Training Accuracy= 0.87500
# Iter 286400, Minibatch Loss= 0.066835, Training Accuracy= 0.93750
# Iter 288000, Minibatch Loss= 0.013850, Training Accuracy= 1.00000
# Iter 289600, Minibatch Loss= 0.229566, Training Accuracy= 0.93750
# Iter 291200, Minibatch Loss= 0.008418, Training Accuracy= 1.00000
# Iter 292800, Minibatch Loss= 0.047088, Training Accuracy= 1.00000
# Iter 294400, Minibatch Loss= 0.018351, Training Accuracy= 1.00000
# Iter 296000, Minibatch Loss= 0.013627, Training Accuracy= 1.00000
# Iter 297600, Minibatch Loss= 0.038143, Training Accuracy= 1.00000
# Iter 299200, Minibatch Loss= 0.318126, Training Accuracy= 0.93750
# Iter 300800, Minibatch Loss= 0.010816, Training Accuracy= 1.00000
# Iter 302400, Minibatch Loss= 0.002222, Training Accuracy= 1.00000
# Iter 304000, Minibatch Loss= 0.000611, Training Accuracy= 1.00000
# Iter 305600, Minibatch Loss= 0.001646, Training Accuracy= 1.00000
# Iter 307200, Minibatch Loss= 0.009235, Training Accuracy= 1.00000
# Iter 308800, Minibatch Loss= 0.056023, Training Accuracy= 1.00000
# Iter 310400, Minibatch Loss= 0.080024, Training Accuracy= 1.00000
# Iter 312000, Minibatch Loss= 0.002377, Training Accuracy= 1.00000
# Iter 313600, Minibatch Loss= 0.006586, Training Accuracy= 1.00000
# Iter 315200, Minibatch Loss= 0.023788, Training Accuracy= 1.00000
# Iter 316800, Minibatch Loss= 0.001605, Training Accuracy= 1.00000
# Iter 318400, Minibatch Loss= 0.877655, Training Accuracy= 0.93750
# Iter 320000, Minibatch Loss= 0.004804, Training Accuracy= 1.00000
# Iter 321600, Minibatch Loss= 0.017713, Training Accuracy= 1.00000
# Iter 323200, Minibatch Loss= 0.010982, Training Accuracy= 1.00000
# Iter 324800, Minibatch Loss= 0.023503, Training Accuracy= 1.00000
# Iter 326400, Minibatch Loss= 0.004205, Training Accuracy= 1.00000
# Iter 328000, Minibatch Loss= 0.012872, Training Accuracy= 1.00000
# Iter 329600, Minibatch Loss= 0.001016, Training Accuracy= 1.00000
# Iter 331200, Minibatch Loss= 0.003625, Training Accuracy= 1.00000
# Iter 332800, Minibatch Loss= 0.041000, Training Accuracy= 1.00000
# Iter 334400, Minibatch Loss= 0.007360, Training Accuracy= 1.00000
# Iter 336000, Minibatch Loss= 0.001374, Training Accuracy= 1.00000
# Iter 337600, Minibatch Loss= 0.000591, Training Accuracy= 1.00000
# Iter 339200, Minibatch Loss= 0.009660, Training Accuracy= 1.00000
# Iter 340800, Minibatch Loss= 0.015660, Training Accuracy= 1.00000
# Iter 342400, Minibatch Loss= 0.040354, Training Accuracy= 1.00000
# Iter 344000, Minibatch Loss= 0.008882, Training Accuracy= 1.00000
# Iter 345600, Minibatch Loss= 0.093212, Training Accuracy= 1.00000
# Iter 347200, Minibatch Loss= 0.019735, Training Accuracy= 1.00000
# Iter 348800, Minibatch Loss= 0.036503, Training Accuracy= 1.00000
# Iter 350400, Minibatch Loss= 0.021918, Training Accuracy= 1.00000
# Iter 352000, Minibatch Loss= 0.004600, Training Accuracy= 1.00000
# Iter 353600, Minibatch Loss= 0.002098, Training Accuracy= 1.00000
# Iter 355200, Minibatch Loss= 0.019731, Training Accuracy= 1.00000
# Iter 356800, Minibatch Loss= 0.002170, Training Accuracy= 1.00000
# Iter 358400, Minibatch Loss= 0.000788, Training Accuracy= 1.00000
# Iter 360000, Minibatch Loss= 0.003772, Training Accuracy= 1.00000
# Iter 361600, Minibatch Loss= 0.016568, Training Accuracy= 1.00000
# Iter 363200, Minibatch Loss= 0.000407, Training Accuracy= 1.00000
# Iter 364800, Minibatch Loss= 0.003717, Training Accuracy= 1.00000
# Iter 366400, Minibatch Loss= 0.029565, Training Accuracy= 1.00000
# Iter 368000, Minibatch Loss= 0.000294, Training Accuracy= 1.00000
# Iter 369600, Minibatch Loss= 0.016911, Training Accuracy= 1.00000
# Iter 371200, Minibatch Loss= 0.003248, Training Accuracy= 1.00000
# Iter 372800, Minibatch Loss= 0.024146, Training Accuracy= 1.00000
# Iter 374400, Minibatch Loss= 0.003700, Training Accuracy= 1.00000
# Iter 376000, Minibatch Loss= 0.066822, Training Accuracy= 1.00000
# Iter 377600, Minibatch Loss= 0.017875, Training Accuracy= 1.00000
# Iter 379200, Minibatch Loss= 0.098399, Training Accuracy= 0.93750
# Iter 380800, Minibatch Loss= 0.033604, Training Accuracy= 1.00000
# Iter 382400, Minibatch Loss= 0.001040, Training Accuracy= 1.00000
# Iter 384000, Minibatch Loss= 0.001077, Training Accuracy= 1.00000
# Iter 385600, Minibatch Loss= 0.003416, Training Accuracy= 1.00000
# Iter 387200, Minibatch Loss= 0.000384, Training Accuracy= 1.00000
# Iter 388800, Minibatch Loss= 0.002085, Training Accuracy= 1.00000
# Iter 390400, Minibatch Loss= 0.002932, Training Accuracy= 1.00000
# Iter 392000, Minibatch Loss= 0.016522, Training Accuracy= 1.00000
# Iter 393600, Minibatch Loss= 0.022003, Training Accuracy= 1.00000
# Iter 395200, Minibatch Loss= 0.004478, Training Accuracy= 1.00000
# Iter 396800, Minibatch Loss= 0.249009, Training Accuracy= 0.93750
# Iter 398400, Minibatch Loss= 0.002544, Training Accuracy= 1.00000
# Iter 400000, Minibatch Loss= 0.150770, Training Accuracy= 0.93750
# Iter 401600, Minibatch Loss= 0.003537, Training Accuracy= 1.00000
# Iter 403200, Minibatch Loss= 0.005945, Training Accuracy= 1.00000
# Iter 404800, Minibatch Loss= 0.059909, Training Accuracy= 0.93750
# Iter 406400, Minibatch Loss= 0.002940, Training Accuracy= 1.00000
# Iter 408000, Minibatch Loss= 0.030784, Training Accuracy= 1.00000
# Iter 409600, Minibatch Loss= 0.036752, Training Accuracy= 1.00000
# Iter 411200, Minibatch Loss= 0.059526, Training Accuracy= 0.93750
# Iter 412800, Minibatch Loss= 0.032002, Training Accuracy= 1.00000
# Iter 414400, Minibatch Loss= 0.007641, Training Accuracy= 1.00000
# Iter 416000, Minibatch Loss= 0.000658, Training Accuracy= 1.00000
# Iter 417600, Minibatch Loss= 0.128883, Training Accuracy= 0.93750
# Iter 419200, Minibatch Loss= 0.028335, Training Accuracy= 1.00000
# Iter 420800, Minibatch Loss= 0.086595, Training Accuracy= 0.93750
# Iter 422400, Minibatch Loss= 0.329308, Training Accuracy= 0.93750
# Iter 424000, Minibatch Loss= 0.004371, Training Accuracy= 1.00000
# Iter 425600, Minibatch Loss= 0.001658, Training Accuracy= 1.00000
# Iter 427200, Minibatch Loss= 0.016023, Training Accuracy= 1.00000
# Iter 428800, Minibatch Loss= 0.005235, Training Accuracy= 1.00000
# Iter 430400, Minibatch Loss= 0.015622, Training Accuracy= 1.00000
# Iter 432000, Minibatch Loss= 0.059540, Training Accuracy= 1.00000
# Iter 433600, Minibatch Loss= 0.001048, Training Accuracy= 1.00000
# Iter 435200, Minibatch Loss= 0.000267, Training Accuracy= 1.00000
# Iter 436800, Minibatch Loss= 0.009201, Training Accuracy= 1.00000
# Iter 438400, Minibatch Loss= 0.000202, Training Accuracy= 1.00000
# Iter 440000, Minibatch Loss= 0.005336, Training Accuracy= 1.00000
# Iter 441600, Minibatch Loss= 0.080246, Training Accuracy= 1.00000
# Iter 443200, Minibatch Loss= 0.003243, Training Accuracy= 1.00000
# Iter 444800, Minibatch Loss= 0.022134, Training Accuracy= 1.00000
# Iter 446400, Minibatch Loss= 0.000682, Training Accuracy= 1.00000
# Iter 448000, Minibatch Loss= 0.001907, Training Accuracy= 1.00000
# Iter 449600, Minibatch Loss= 0.002608, Training Accuracy= 1.00000
# Iter 451200, Minibatch Loss= 0.000280, Training Accuracy= 1.00000
# Iter 452800, Minibatch Loss= 0.000226, Training Accuracy= 1.00000
# Iter 454400, Minibatch Loss= 0.005069, Training Accuracy= 1.00000
# Iter 456000, Minibatch Loss= 0.000586, Training Accuracy= 1.00000
# Iter 457600, Minibatch Loss= 0.002570, Training Accuracy= 1.00000
# Iter 459200, Minibatch Loss= 0.036227, Training Accuracy= 1.00000
# Iter 460800, Minibatch Loss= 0.001190, Training Accuracy= 1.00000
# Iter 462400, Minibatch Loss= 0.015866, Training Accuracy= 1.00000
# Iter 464000, Minibatch Loss= 0.003806, Training Accuracy= 1.00000
# Iter 465600, Minibatch Loss= 0.121956, Training Accuracy= 0.93750
# Iter 467200, Minibatch Loss= 0.027733, Training Accuracy= 1.00000
# Iter 468800, Minibatch Loss= 0.063211, Training Accuracy= 1.00000
# Iter 470400, Minibatch Loss= 0.000874, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.003192, Training Accuracy= 1.00000
# Iter 473600, Minibatch Loss= 0.001466, Training Accuracy= 1.00000
# Iter 475200, Minibatch Loss= 0.009476, Training Accuracy= 1.00000
# Iter 476800, Minibatch Loss= 0.019300, Training Accuracy= 1.00000
# Iter 478400, Minibatch Loss= 0.067460, Training Accuracy= 1.00000
# Iter 480000, Minibatch Loss= 0.003084, Training Accuracy= 1.00000
# Iter 481600, Minibatch Loss= 0.000107, Training Accuracy= 1.00000
# Iter 483200, Minibatch Loss= 0.002627, Training Accuracy= 1.00000
# Iter 484800, Minibatch Loss= 0.000821, Training Accuracy= 1.00000
# Iter 486400, Minibatch Loss= 0.020145, Training Accuracy= 1.00000
# Iter 488000, Minibatch Loss= 0.000476, Training Accuracy= 1.00000
# Iter 489600, Minibatch Loss= 0.002466, Training Accuracy= 1.00000
# Iter 491200, Minibatch Loss= 0.039848, Training Accuracy= 1.00000
# Iter 492800, Minibatch Loss= 0.014109, Training Accuracy= 1.00000
# Iter 494400, Minibatch Loss= 0.011180, Training Accuracy= 1.00000
# Iter 496000, Minibatch Loss= 0.060871, Training Accuracy= 0.93750
# Iter 497600, Minibatch Loss= 0.000325, Training Accuracy= 1.00000
# Iter 499200, Minibatch Loss= 0.003919, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.90599

# %%
saver.save(sess, '../Model/NIN-Model-0504-2')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', '1', 'd', '7', 's', '2', 'y', 'p', 'i', '9', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 'you', 't', '8', 'u', 'x', '6', 'h', 'what', 'e', '5', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
