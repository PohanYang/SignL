# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t420.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (102014, 33)

# %%
# Parameters
learning_rate = 0.001
training_iters = 500000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-4})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==5):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.443773, Training Accuracy= 0.06250
# Iter 3200, Minibatch Loss= 3.457139, Training Accuracy= 0.06250
# Iter 4800, Minibatch Loss= 3.425009, Training Accuracy= 0.06250
# Iter 6400, Minibatch Loss= 3.427082, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.432234, Training Accuracy= 0.06250
# Iter 9600, Minibatch Loss= 3.479368, Training Accuracy= 0.18750
# Iter 11200, Minibatch Loss= 3.358499, Training Accuracy= 0.06250
# Iter 12800, Minibatch Loss= 3.472433, Training Accuracy= 0.06250
# Iter 14400, Minibatch Loss= 3.480756, Training Accuracy= 0.06250
# Iter 16000, Minibatch Loss= 3.045114, Training Accuracy= 0.18750
# Iter 17600, Minibatch Loss= 3.470488, Training Accuracy= 0.06250
# Iter 19200, Minibatch Loss= 3.478804, Training Accuracy= 0.06250
# Iter 20800, Minibatch Loss= 3.284603, Training Accuracy= 0.18750
# Iter 22400, Minibatch Loss= 3.314569, Training Accuracy= 0.06250
# Iter 24000, Minibatch Loss= 3.243896, Training Accuracy= 0.12500
# Iter 25600, Minibatch Loss= 3.312177, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.256544, Training Accuracy= 0.06250
# Iter 28800, Minibatch Loss= 3.439032, Training Accuracy= 0.06250
# Iter 30400, Minibatch Loss= 3.481696, Training Accuracy= 0.18750
# Iter 32000, Minibatch Loss= 3.197309, Training Accuracy= 0.06250
# Iter 33600, Minibatch Loss= 3.202423, Training Accuracy= 0.18750
# Iter 35200, Minibatch Loss= 3.419710, Training Accuracy= 0.00000
# Iter 36800, Minibatch Loss= 3.384001, Training Accuracy= 0.18750
# Iter 38400, Minibatch Loss= 3.425779, Training Accuracy= 0.12500
# Iter 40000, Minibatch Loss= 2.963902, Training Accuracy= 0.18750
# Iter 41600, Minibatch Loss= 3.410820, Training Accuracy= 0.06250
# Iter 43200, Minibatch Loss= 3.139322, Training Accuracy= 0.00000
# Iter 44800, Minibatch Loss= 3.104040, Training Accuracy= 0.12500
# Iter 46400, Minibatch Loss= 3.514166, Training Accuracy= 0.00000
# Iter 48000, Minibatch Loss= 3.109479, Training Accuracy= 0.18750
# Iter 49600, Minibatch Loss= 3.141823, Training Accuracy= 0.00000
# Iter 51200, Minibatch Loss= 2.894276, Training Accuracy= 0.25000
# Iter 52800, Minibatch Loss= 3.013791, Training Accuracy= 0.06250
# Iter 54400, Minibatch Loss= 3.103101, Training Accuracy= 0.12500
# Iter 56000, Minibatch Loss= 3.070909, Training Accuracy= 0.25000
# Iter 57600, Minibatch Loss= 3.322138, Training Accuracy= 0.18750
# Iter 59200, Minibatch Loss= 3.090567, Training Accuracy= 0.25000
# Iter 60800, Minibatch Loss= 2.833392, Training Accuracy= 0.12500
# Iter 62400, Minibatch Loss= 2.995318, Training Accuracy= 0.18750
# Iter 64000, Minibatch Loss= 2.790118, Training Accuracy= 0.18750
# Iter 65600, Minibatch Loss= 2.903971, Training Accuracy= 0.25000
# Iter 67200, Minibatch Loss= 2.775418, Training Accuracy= 0.37500
# Iter 68800, Minibatch Loss= 2.966970, Training Accuracy= 0.18750
# Iter 70400, Minibatch Loss= 2.942428, Training Accuracy= 0.25000
# Iter 72000, Minibatch Loss= 2.739068, Training Accuracy= 0.25000
# Iter 73600, Minibatch Loss= 2.909588, Training Accuracy= 0.12500
# Iter 75200, Minibatch Loss= 2.690980, Training Accuracy= 0.25000
# Iter 76800, Minibatch Loss= 2.710434, Training Accuracy= 0.31250
# Iter 78400, Minibatch Loss= 2.254918, Training Accuracy= 0.31250
# Iter 80000, Minibatch Loss= 2.721571, Training Accuracy= 0.25000
# Iter 81600, Minibatch Loss= 2.220129, Training Accuracy= 0.31250
# Iter 83200, Minibatch Loss= 2.241534, Training Accuracy= 0.25000
# Iter 84800, Minibatch Loss= 2.423735, Training Accuracy= 0.18750
# Iter 86400, Minibatch Loss= 2.215822, Training Accuracy= 0.31250
# Iter 88000, Minibatch Loss= 2.401469, Training Accuracy= 0.18750
# Iter 89600, Minibatch Loss= 1.818536, Training Accuracy= 0.62500
# Iter 91200, Minibatch Loss= 2.144247, Training Accuracy= 0.50000
# Iter 92800, Minibatch Loss= 1.476643, Training Accuracy= 0.75000
# Iter 94400, Minibatch Loss= 1.792748, Training Accuracy= 0.62500
# Iter 96000, Minibatch Loss= 1.745348, Training Accuracy= 0.62500
# Iter 97600, Minibatch Loss= 1.705276, Training Accuracy= 0.43750
# Iter 99200, Minibatch Loss= 1.653053, Training Accuracy= 0.56250
# Iter 100800, Minibatch Loss= 1.357419, Training Accuracy= 0.62500
# Iter 102400, Minibatch Loss= 1.077351, Training Accuracy= 0.62500
# Iter 104000, Minibatch Loss= 0.855357, Training Accuracy= 0.68750
# Iter 105600, Minibatch Loss= 1.763181, Training Accuracy= 0.68750
# Iter 107200, Minibatch Loss= 1.530453, Training Accuracy= 0.43750
# Iter 108800, Minibatch Loss= 1.877528, Training Accuracy= 0.43750
# Iter 110400, Minibatch Loss= 1.161783, Training Accuracy= 0.62500
# Iter 112000, Minibatch Loss= 1.203224, Training Accuracy= 0.56250
# Iter 113600, Minibatch Loss= 0.565611, Training Accuracy= 0.93750
# Iter 115200, Minibatch Loss= 1.151251, Training Accuracy= 0.62500
# Iter 116800, Minibatch Loss= 1.177645, Training Accuracy= 0.68750
# Iter 118400, Minibatch Loss= 1.082428, Training Accuracy= 0.56250
# Iter 120000, Minibatch Loss= 0.814329, Training Accuracy= 0.75000
# Iter 121600, Minibatch Loss= 1.406705, Training Accuracy= 0.56250
# Iter 123200, Minibatch Loss= 0.408374, Training Accuracy= 0.93750
# Iter 124800, Minibatch Loss= 0.962368, Training Accuracy= 0.62500
# Iter 126400, Minibatch Loss= 0.797519, Training Accuracy= 0.81250
# Iter 128000, Minibatch Loss= 0.960920, Training Accuracy= 0.62500
# Iter 129600, Minibatch Loss= 0.550424, Training Accuracy= 0.81250
# Iter 131200, Minibatch Loss= 1.058906, Training Accuracy= 0.75000
# Iter 132800, Minibatch Loss= 0.368922, Training Accuracy= 0.81250
# Iter 134400, Minibatch Loss= 0.621405, Training Accuracy= 0.81250
# Iter 136000, Minibatch Loss= 0.564566, Training Accuracy= 0.62500
# Iter 137600, Minibatch Loss= 0.424092, Training Accuracy= 0.93750
# Iter 139200, Minibatch Loss= 0.588771, Training Accuracy= 0.81250
# Iter 140800, Minibatch Loss= 0.293415, Training Accuracy= 0.87500
# Iter 142400, Minibatch Loss= 0.379989, Training Accuracy= 0.93750
# Iter 144000, Minibatch Loss= 0.307644, Training Accuracy= 0.81250
# Iter 145600, Minibatch Loss= 0.410052, Training Accuracy= 0.87500
# Iter 147200, Minibatch Loss= 0.295407, Training Accuracy= 0.87500
# Iter 148800, Minibatch Loss= 0.160001, Training Accuracy= 0.87500
# Iter 150400, Minibatch Loss= 0.258876, Training Accuracy= 0.87500
# Iter 152000, Minibatch Loss= 0.524584, Training Accuracy= 0.87500
# Iter 153600, Minibatch Loss= 0.668814, Training Accuracy= 0.87500
# Iter 155200, Minibatch Loss= 0.938684, Training Accuracy= 0.81250
# Iter 156800, Minibatch Loss= 0.261199, Training Accuracy= 0.93750
# Iter 158400, Minibatch Loss= 0.502312, Training Accuracy= 0.87500
# Iter 160000, Minibatch Loss= 0.161351, Training Accuracy= 1.00000
# Iter 161600, Minibatch Loss= 0.370820, Training Accuracy= 0.93750
# Iter 163200, Minibatch Loss= 0.606834, Training Accuracy= 0.75000
# Iter 164800, Minibatch Loss= 0.301209, Training Accuracy= 0.81250
# Iter 166400, Minibatch Loss= 0.606533, Training Accuracy= 0.87500
# Iter 168000, Minibatch Loss= 0.052734, Training Accuracy= 1.00000
# Iter 169600, Minibatch Loss= 0.185047, Training Accuracy= 0.93750
# Iter 171200, Minibatch Loss= 0.141083, Training Accuracy= 1.00000
# Iter 172800, Minibatch Loss= 0.024295, Training Accuracy= 1.00000
# Iter 174400, Minibatch Loss= 0.246508, Training Accuracy= 0.93750
# Iter 176000, Minibatch Loss= 0.083384, Training Accuracy= 1.00000
# Iter 177600, Minibatch Loss= 0.047204, Training Accuracy= 1.00000
# Iter 179200, Minibatch Loss= 0.328172, Training Accuracy= 0.93750
# Iter 180800, Minibatch Loss= 0.100739, Training Accuracy= 0.93750
# Iter 182400, Minibatch Loss= 0.243695, Training Accuracy= 0.93750
# Iter 184000, Minibatch Loss= 0.249877, Training Accuracy= 0.93750
# Iter 185600, Minibatch Loss= 0.123818, Training Accuracy= 1.00000
# Iter 187200, Minibatch Loss= 0.131232, Training Accuracy= 0.93750
# Iter 188800, Minibatch Loss= 0.389702, Training Accuracy= 0.93750
# Iter 190400, Minibatch Loss= 0.024970, Training Accuracy= 1.00000
# Iter 192000, Minibatch Loss= 0.006208, Training Accuracy= 1.00000
# Iter 193600, Minibatch Loss= 0.063846, Training Accuracy= 1.00000
# Iter 195200, Minibatch Loss= 0.168749, Training Accuracy= 0.93750
# Iter 196800, Minibatch Loss= 0.078009, Training Accuracy= 1.00000
# Iter 198400, Minibatch Loss= 0.105029, Training Accuracy= 0.93750
# Iter 200000, Minibatch Loss= 0.090859, Training Accuracy= 1.00000
# Iter 201600, Minibatch Loss= 0.082837, Training Accuracy= 1.00000
# Iter 203200, Minibatch Loss= 0.081101, Training Accuracy= 0.93750
# Iter 204800, Minibatch Loss= 0.042884, Training Accuracy= 1.00000
# Iter 206400, Minibatch Loss= 0.034526, Training Accuracy= 1.00000
# Iter 208000, Minibatch Loss= 0.127955, Training Accuracy= 0.93750
# Iter 209600, Minibatch Loss= 0.007964, Training Accuracy= 1.00000
# Iter 211200, Minibatch Loss= 0.069483, Training Accuracy= 1.00000
# Iter 212800, Minibatch Loss= 0.425005, Training Accuracy= 0.87500
# Iter 214400, Minibatch Loss= 0.061474, Training Accuracy= 1.00000
# Iter 216000, Minibatch Loss= 0.318459, Training Accuracy= 0.93750
# Iter 217600, Minibatch Loss= 0.021785, Training Accuracy= 1.00000
# Iter 219200, Minibatch Loss= 0.345554, Training Accuracy= 0.93750
# Iter 220800, Minibatch Loss= 0.070342, Training Accuracy= 1.00000
# Iter 222400, Minibatch Loss= 0.021895, Training Accuracy= 1.00000
# Iter 224000, Minibatch Loss= 0.021953, Training Accuracy= 1.00000
# Iter 225600, Minibatch Loss= 0.052330, Training Accuracy= 1.00000
# Iter 227200, Minibatch Loss= 0.092007, Training Accuracy= 1.00000
# Iter 228800, Minibatch Loss= 0.082977, Training Accuracy= 1.00000
# Iter 230400, Minibatch Loss= 0.127148, Training Accuracy= 0.93750
# Iter 232000, Minibatch Loss= 0.003507, Training Accuracy= 1.00000
# Iter 233600, Minibatch Loss= 0.004114, Training Accuracy= 1.00000
# Iter 235200, Minibatch Loss= 0.267111, Training Accuracy= 0.93750
# Iter 236800, Minibatch Loss= 0.000845, Training Accuracy= 1.00000
# Iter 238400, Minibatch Loss= 0.008255, Training Accuracy= 1.00000
# Iter 240000, Minibatch Loss= 0.007077, Training Accuracy= 1.00000
# Iter 241600, Minibatch Loss= 0.014521, Training Accuracy= 1.00000
# Iter 243200, Minibatch Loss= 0.011368, Training Accuracy= 1.00000
# Iter 244800, Minibatch Loss= 0.007361, Training Accuracy= 1.00000
# Iter 246400, Minibatch Loss= 0.012782, Training Accuracy= 1.00000
# Iter 248000, Minibatch Loss= 0.029493, Training Accuracy= 1.00000
# Iter 249600, Minibatch Loss= 0.052345, Training Accuracy= 1.00000
# Iter 251200, Minibatch Loss= 0.008997, Training Accuracy= 1.00000
# Iter 252800, Minibatch Loss= 0.008863, Training Accuracy= 1.00000
# Iter 254400, Minibatch Loss= 0.011732, Training Accuracy= 1.00000
# Iter 256000, Minibatch Loss= 0.015300, Training Accuracy= 1.00000
# Iter 257600, Minibatch Loss= 0.167174, Training Accuracy= 0.87500
# Iter 259200, Minibatch Loss= 0.022795, Training Accuracy= 1.00000
# Iter 260800, Minibatch Loss= 0.012769, Training Accuracy= 1.00000
# Iter 262400, Minibatch Loss= 0.004887, Training Accuracy= 1.00000
# Iter 264000, Minibatch Loss= 0.020256, Training Accuracy= 1.00000
# Iter 265600, Minibatch Loss= 0.048010, Training Accuracy= 1.00000
# Iter 267200, Minibatch Loss= 0.009256, Training Accuracy= 1.00000
# Iter 268800, Minibatch Loss= 0.121404, Training Accuracy= 0.93750
# Iter 270400, Minibatch Loss= 0.066022, Training Accuracy= 0.93750
# Iter 272000, Minibatch Loss= 0.002013, Training Accuracy= 1.00000
# Iter 273600, Minibatch Loss= 0.082944, Training Accuracy= 0.93750
# Iter 275200, Minibatch Loss= 0.041577, Training Accuracy= 1.00000
# Iter 276800, Minibatch Loss= 0.005613, Training Accuracy= 1.00000
# Iter 278400, Minibatch Loss= 0.007118, Training Accuracy= 1.00000
# Iter 280000, Minibatch Loss= 0.062087, Training Accuracy= 1.00000
# Iter 281600, Minibatch Loss= 0.020122, Training Accuracy= 1.00000
# Iter 283200, Minibatch Loss= 0.373749, Training Accuracy= 0.93750
# Iter 284800, Minibatch Loss= 0.247696, Training Accuracy= 0.93750
# Iter 286400, Minibatch Loss= 0.010857, Training Accuracy= 1.00000
# Iter 288000, Minibatch Loss= 0.001609, Training Accuracy= 1.00000
# Iter 289600, Minibatch Loss= 0.002183, Training Accuracy= 1.00000
# Iter 291200, Minibatch Loss= 0.001578, Training Accuracy= 1.00000
# Iter 292800, Minibatch Loss= 0.384938, Training Accuracy= 0.93750
# Iter 294400, Minibatch Loss= 0.353014, Training Accuracy= 0.87500
# Iter 296000, Minibatch Loss= 0.006397, Training Accuracy= 1.00000
# Iter 297600, Minibatch Loss= 0.106882, Training Accuracy= 1.00000
# Iter 299200, Minibatch Loss= 0.035711, Training Accuracy= 1.00000
# Iter 300800, Minibatch Loss= 0.026206, Training Accuracy= 1.00000
# Iter 302400, Minibatch Loss= 0.131832, Training Accuracy= 0.93750
# Iter 304000, Minibatch Loss= 0.031026, Training Accuracy= 1.00000
# Iter 305600, Minibatch Loss= 0.009846, Training Accuracy= 1.00000
# Iter 307200, Minibatch Loss= 0.126801, Training Accuracy= 0.87500
# Iter 308800, Minibatch Loss= 0.211690, Training Accuracy= 0.93750
# Iter 310400, Minibatch Loss= 0.040216, Training Accuracy= 1.00000
# Iter 312000, Minibatch Loss= 0.514718, Training Accuracy= 0.93750
# Iter 313600, Minibatch Loss= 0.000834, Training Accuracy= 1.00000
# Iter 315200, Minibatch Loss= 0.001151, Training Accuracy= 1.00000
# Iter 316800, Minibatch Loss= 0.007837, Training Accuracy= 1.00000
# Iter 318400, Minibatch Loss= 0.002248, Training Accuracy= 1.00000
# Iter 320000, Minibatch Loss= 0.003592, Training Accuracy= 1.00000
# Iter 321600, Minibatch Loss= 0.012340, Training Accuracy= 1.00000
# Iter 323200, Minibatch Loss= 0.012356, Training Accuracy= 1.00000
# Iter 324800, Minibatch Loss= 0.002341, Training Accuracy= 1.00000
# Iter 326400, Minibatch Loss= 0.409228, Training Accuracy= 0.87500
# Iter 328000, Minibatch Loss= 0.010945, Training Accuracy= 1.00000
# Iter 329600, Minibatch Loss= 0.006836, Training Accuracy= 1.00000
# Iter 331200, Minibatch Loss= 0.001691, Training Accuracy= 1.00000
# Iter 332800, Minibatch Loss= 0.099807, Training Accuracy= 0.93750
# Iter 334400, Minibatch Loss= 0.020745, Training Accuracy= 1.00000
# Iter 336000, Minibatch Loss= 0.157288, Training Accuracy= 0.93750
# Iter 337600, Minibatch Loss= 0.010580, Training Accuracy= 1.00000
# Iter 339200, Minibatch Loss= 0.008459, Training Accuracy= 1.00000
# Iter 340800, Minibatch Loss= 0.073626, Training Accuracy= 0.93750
# Iter 342400, Minibatch Loss= 0.022271, Training Accuracy= 1.00000
# Iter 344000, Minibatch Loss= 0.002765, Training Accuracy= 1.00000
# Iter 345600, Minibatch Loss= 0.018133, Training Accuracy= 1.00000
# Iter 347200, Minibatch Loss= 0.172795, Training Accuracy= 0.87500
# Iter 348800, Minibatch Loss= 0.010572, Training Accuracy= 1.00000
# Iter 350400, Minibatch Loss= 0.049082, Training Accuracy= 1.00000
# Iter 352000, Minibatch Loss= 0.001627, Training Accuracy= 1.00000
# Iter 353600, Minibatch Loss= 0.004536, Training Accuracy= 1.00000
# Iter 355200, Minibatch Loss= 0.068910, Training Accuracy= 0.93750
# Iter 356800, Minibatch Loss= 0.113583, Training Accuracy= 0.93750
# Iter 358400, Minibatch Loss= 0.003841, Training Accuracy= 1.00000
# Iter 360000, Minibatch Loss= 0.000515, Training Accuracy= 1.00000
# Iter 361600, Minibatch Loss= 0.010320, Training Accuracy= 1.00000
# Iter 363200, Minibatch Loss= 0.000194, Training Accuracy= 1.00000
# Iter 364800, Minibatch Loss= 0.000868, Training Accuracy= 1.00000
# Iter 366400, Minibatch Loss= 0.419130, Training Accuracy= 0.93750
# Iter 368000, Minibatch Loss= 0.056401, Training Accuracy= 1.00000
# Iter 369600, Minibatch Loss= 0.001591, Training Accuracy= 1.00000
# Iter 371200, Minibatch Loss= 0.001975, Training Accuracy= 1.00000
# Iter 372800, Minibatch Loss= 0.100342, Training Accuracy= 0.93750
# Iter 374400, Minibatch Loss= 0.000697, Training Accuracy= 1.00000
# Iter 376000, Minibatch Loss= 0.003265, Training Accuracy= 1.00000
# Iter 377600, Minibatch Loss= 0.001504, Training Accuracy= 1.00000
# Iter 379200, Minibatch Loss= 0.050389, Training Accuracy= 1.00000
# Iter 380800, Minibatch Loss= 0.005410, Training Accuracy= 1.00000
# Iter 382400, Minibatch Loss= 0.006285, Training Accuracy= 1.00000
# Iter 384000, Minibatch Loss= 0.011776, Training Accuracy= 1.00000
# Iter 385600, Minibatch Loss= 0.000054, Training Accuracy= 1.00000
# Iter 387200, Minibatch Loss= 0.054375, Training Accuracy= 1.00000
# Iter 388800, Minibatch Loss= 0.004898, Training Accuracy= 1.00000
# Iter 390400, Minibatch Loss= 0.023307, Training Accuracy= 1.00000
# Iter 392000, Minibatch Loss= 0.002945, Training Accuracy= 1.00000
# Iter 393600, Minibatch Loss= 0.000148, Training Accuracy= 1.00000
# Iter 395200, Minibatch Loss= 0.002611, Training Accuracy= 1.00000
# Iter 396800, Minibatch Loss= 0.157771, Training Accuracy= 0.93750
# Iter 398400, Minibatch Loss= 0.002724, Training Accuracy= 1.00000
# Iter 400000, Minibatch Loss= 0.109492, Training Accuracy= 0.93750
# Iter 401600, Minibatch Loss= 0.000892, Training Accuracy= 1.00000
# Iter 403200, Minibatch Loss= 0.004505, Training Accuracy= 1.00000
# Iter 404800, Minibatch Loss= 0.004770, Training Accuracy= 1.00000
# Iter 406400, Minibatch Loss= 0.000659, Training Accuracy= 1.00000
# Iter 408000, Minibatch Loss= 0.080934, Training Accuracy= 1.00000
# Iter 409600, Minibatch Loss= 0.008380, Training Accuracy= 1.00000
# Iter 411200, Minibatch Loss= 0.001463, Training Accuracy= 1.00000
# Iter 412800, Minibatch Loss= 0.034633, Training Accuracy= 1.00000
# Iter 414400, Minibatch Loss= 0.015048, Training Accuracy= 1.00000
# Iter 416000, Minibatch Loss= 0.033918, Training Accuracy= 1.00000
# Iter 417600, Minibatch Loss= 0.007258, Training Accuracy= 1.00000
# Iter 419200, Minibatch Loss= 0.000078, Training Accuracy= 1.00000
# Iter 420800, Minibatch Loss= 0.080252, Training Accuracy= 0.93750
# Iter 422400, Minibatch Loss= 0.000128, Training Accuracy= 1.00000
# Iter 424000, Minibatch Loss= 0.152100, Training Accuracy= 0.93750
# Iter 425600, Minibatch Loss= 0.206767, Training Accuracy= 0.93750
# Iter 427200, Minibatch Loss= 0.003534, Training Accuracy= 1.00000
# Iter 428800, Minibatch Loss= 0.007133, Training Accuracy= 1.00000
# Iter 430400, Minibatch Loss= 0.000042, Training Accuracy= 1.00000
# Iter 432000, Minibatch Loss= 0.002604, Training Accuracy= 1.00000
# Iter 433600, Minibatch Loss= 0.001071, Training Accuracy= 1.00000
# Iter 435200, Minibatch Loss= 0.000337, Training Accuracy= 1.00000
# Iter 436800, Minibatch Loss= 0.201406, Training Accuracy= 0.93750
# Iter 438400, Minibatch Loss= 0.349716, Training Accuracy= 0.93750
# Iter 440000, Minibatch Loss= 0.000813, Training Accuracy= 1.00000
# Iter 441600, Minibatch Loss= 0.003554, Training Accuracy= 1.00000
# Iter 443200, Minibatch Loss= 0.016295, Training Accuracy= 1.00000
# Iter 444800, Minibatch Loss= 0.011692, Training Accuracy= 1.00000
# Iter 446400, Minibatch Loss= 0.000427, Training Accuracy= 1.00000
# Iter 448000, Minibatch Loss= 0.000383, Training Accuracy= 1.00000
# Iter 449600, Minibatch Loss= 0.000486, Training Accuracy= 1.00000
# Iter 451200, Minibatch Loss= 0.005301, Training Accuracy= 1.00000
# Iter 452800, Minibatch Loss= 0.000053, Training Accuracy= 1.00000
# Iter 454400, Minibatch Loss= 0.022780, Training Accuracy= 1.00000
# Iter 456000, Minibatch Loss= 0.003054, Training Accuracy= 1.00000
# Iter 457600, Minibatch Loss= 0.000490, Training Accuracy= 1.00000
# Iter 459200, Minibatch Loss= 0.011386, Training Accuracy= 1.00000
# Iter 460800, Minibatch Loss= 0.000404, Training Accuracy= 1.00000
# Iter 462400, Minibatch Loss= 0.000033, Training Accuracy= 1.00000
# Iter 464000, Minibatch Loss= 0.016630, Training Accuracy= 1.00000
# Iter 465600, Minibatch Loss= 0.001418, Training Accuracy= 1.00000
# Iter 467200, Minibatch Loss= 0.031142, Training Accuracy= 1.00000
# Iter 468800, Minibatch Loss= 0.000671, Training Accuracy= 1.00000
# Iter 470400, Minibatch Loss= 0.016137, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.000463, Training Accuracy= 1.00000
# Iter 473600, Minibatch Loss= 0.000033, Training Accuracy= 1.00000
# Iter 475200, Minibatch Loss= 0.001073, Training Accuracy= 1.00000
# Iter 476800, Minibatch Loss= 0.004963, Training Accuracy= 1.00000
# Iter 478400, Minibatch Loss= 0.001323, Training Accuracy= 1.00000
# Iter 480000, Minibatch Loss= 0.001621, Training Accuracy= 1.00000
# Iter 481600, Minibatch Loss= 0.000022, Training Accuracy= 1.00000
# Iter 483200, Minibatch Loss= 0.000026, Training Accuracy= 1.00000
# Iter 484800, Minibatch Loss= 0.819787, Training Accuracy= 0.93750
# Iter 486400, Minibatch Loss= 0.000332, Training Accuracy= 1.00000
# Iter 488000, Minibatch Loss= 0.007594, Training Accuracy= 1.00000
# Iter 489600, Minibatch Loss= 0.000636, Training Accuracy= 1.00000
# Iter 491200, Minibatch Loss= 0.006990, Training Accuracy= 1.00000
# Iter 492800, Minibatch Loss= 0.001440, Training Accuracy= 1.00000
# Iter 494400, Minibatch Loss= 0.000206, Training Accuracy= 1.00000
# Iter 496000, Minibatch Loss= 0.000205, Training Accuracy= 1.00000
# Iter 497600, Minibatch Loss= 0.001283, Training Accuracy= 1.00000
# Iter 499200, Minibatch Loss= 0.000489, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.906887

# %%
saver.save(sess, '../Model/NIN-Model-0420')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', '1', 'd', 's', '2', 'y', 'p', 'i', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 'you', 'my', 't', 'u', 'x', 'h', 'what', 'e', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
