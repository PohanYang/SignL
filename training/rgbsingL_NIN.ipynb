# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t426.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (106265, 37)

# %%
# Parameters
learning_rate = 0.001
training_iters = 500000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==5):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.520315, Training Accuracy= 0.12500
# Iter 3200, Minibatch Loss= 3.550116, Training Accuracy= 0.00000
# Iter 4800, Minibatch Loss= 3.440132, Training Accuracy= 0.06250
# Iter 6400, Minibatch Loss= 3.642188, Training Accuracy= 0.00000
# Iter 8000, Minibatch Loss= 3.528486, Training Accuracy= 0.00000
# Iter 9600, Minibatch Loss= 3.573589, Training Accuracy= 0.06250
# Iter 11200, Minibatch Loss= 3.602878, Training Accuracy= 0.00000
# Iter 12800, Minibatch Loss= 3.522413, Training Accuracy= 0.18750
# Iter 14400, Minibatch Loss= 3.542047, Training Accuracy= 0.00000
# Iter 16000, Minibatch Loss= 3.548942, Training Accuracy= 0.06250
# Iter 17600, Minibatch Loss= 3.530902, Training Accuracy= 0.00000
# Iter 19200, Minibatch Loss= 3.600704, Training Accuracy= 0.00000
# Iter 20800, Minibatch Loss= 3.585769, Training Accuracy= 0.06250
# Iter 22400, Minibatch Loss= 3.474830, Training Accuracy= 0.12500
# Iter 24000, Minibatch Loss= 3.574449, Training Accuracy= 0.00000
# Iter 25600, Minibatch Loss= 3.554019, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.533424, Training Accuracy= 0.06250
# Iter 28800, Minibatch Loss= 3.593631, Training Accuracy= 0.06250
# Iter 30400, Minibatch Loss= 3.544211, Training Accuracy= 0.12500
# Iter 32000, Minibatch Loss= 3.507702, Training Accuracy= 0.06250
# Iter 33600, Minibatch Loss= 3.579330, Training Accuracy= 0.06250
# Iter 35200, Minibatch Loss= 3.573990, Training Accuracy= 0.00000
# Iter 36800, Minibatch Loss= 3.425061, Training Accuracy= 0.06250
# Iter 38400, Minibatch Loss= 3.561958, Training Accuracy= 0.12500
# Iter 40000, Minibatch Loss= 3.476571, Training Accuracy= 0.06250
# Iter 41600, Minibatch Loss= 3.634637, Training Accuracy= 0.00000
# Iter 43200, Minibatch Loss= 3.549248, Training Accuracy= 0.06250
# Iter 44800, Minibatch Loss= 3.501019, Training Accuracy= 0.06250
# Iter 46400, Minibatch Loss= 3.574143, Training Accuracy= 0.00000
# Iter 48000, Minibatch Loss= 3.432725, Training Accuracy= 0.18750
# Iter 49600, Minibatch Loss= 3.507720, Training Accuracy= 0.00000
# Iter 51200, Minibatch Loss= 3.658232, Training Accuracy= 0.00000
# Iter 52800, Minibatch Loss= 3.643967, Training Accuracy= 0.00000
# Iter 54400, Minibatch Loss= 3.483160, Training Accuracy= 0.00000
# Iter 56000, Minibatch Loss= 3.520136, Training Accuracy= 0.06250
# Iter 57600, Minibatch Loss= 3.520667, Training Accuracy= 0.12500
# Iter 59200, Minibatch Loss= 3.571284, Training Accuracy= 0.00000
# Iter 60800, Minibatch Loss= 3.548585, Training Accuracy= 0.06250
# Iter 62400, Minibatch Loss= 3.499770, Training Accuracy= 0.00000
# Iter 64000, Minibatch Loss= 3.438220, Training Accuracy= 0.06250
# Iter 65600, Minibatch Loss= 3.341734, Training Accuracy= 0.06250
# Iter 67200, Minibatch Loss= 3.339113, Training Accuracy= 0.12500
# Iter 68800, Minibatch Loss= 3.364023, Training Accuracy= 0.12500
# Iter 70400, Minibatch Loss= 3.196573, Training Accuracy= 0.18750
# Iter 72000, Minibatch Loss= 3.364864, Training Accuracy= 0.06250
# Iter 73600, Minibatch Loss= 3.172349, Training Accuracy= 0.12500
# Iter 75200, Minibatch Loss= 3.288331, Training Accuracy= 0.06250
# Iter 76800, Minibatch Loss= 3.235224, Training Accuracy= 0.06250
# Iter 78400, Minibatch Loss= 3.161989, Training Accuracy= 0.18750
# Iter 80000, Minibatch Loss= 3.292277, Training Accuracy= 0.25000
# Iter 81600, Minibatch Loss= 3.246676, Training Accuracy= 0.12500
# Iter 83200, Minibatch Loss= 3.314450, Training Accuracy= 0.12500
# Iter 84800, Minibatch Loss= 3.116748, Training Accuracy= 0.06250
# Iter 86400, Minibatch Loss= 3.024120, Training Accuracy= 0.00000
# Iter 88000, Minibatch Loss= 3.198585, Training Accuracy= 0.12500
# Iter 89600, Minibatch Loss= 3.131514, Training Accuracy= 0.12500
# Iter 91200, Minibatch Loss= 3.096051, Training Accuracy= 0.06250
# Iter 92800, Minibatch Loss= 2.915653, Training Accuracy= 0.18750
# Iter 94400, Minibatch Loss= 3.233180, Training Accuracy= 0.12500
# Iter 96000, Minibatch Loss= 3.066276, Training Accuracy= 0.06250
# Iter 97600, Minibatch Loss= 3.302128, Training Accuracy= 0.06250
# Iter 99200, Minibatch Loss= 2.905183, Training Accuracy= 0.06250
# Iter 100800, Minibatch Loss= 2.760648, Training Accuracy= 0.18750
# Iter 102400, Minibatch Loss= 2.689846, Training Accuracy= 0.18750
# Iter 104000, Minibatch Loss= 2.964305, Training Accuracy= 0.25000
# Iter 105600, Minibatch Loss= 2.846223, Training Accuracy= 0.12500
# Iter 107200, Minibatch Loss= 3.011801, Training Accuracy= 0.12500
# Iter 108800, Minibatch Loss= 3.290417, Training Accuracy= 0.06250
# Iter 110400, Minibatch Loss= 2.657654, Training Accuracy= 0.18750
# Iter 112000, Minibatch Loss= 2.888125, Training Accuracy= 0.00000
# Iter 113600, Minibatch Loss= 2.471825, Training Accuracy= 0.25000
# Iter 115200, Minibatch Loss= 2.522860, Training Accuracy= 0.18750
# Iter 116800, Minibatch Loss= 2.641620, Training Accuracy= 0.12500
# Iter 118400, Minibatch Loss= 2.233936, Training Accuracy= 0.56250
# Iter 120000, Minibatch Loss= 2.923841, Training Accuracy= 0.12500
# Iter 121600, Minibatch Loss= 2.570173, Training Accuracy= 0.18750
# Iter 123200, Minibatch Loss= 2.471135, Training Accuracy= 0.31250
# Iter 124800, Minibatch Loss= 2.562347, Training Accuracy= 0.31250
# Iter 126400, Minibatch Loss= 2.294854, Training Accuracy= 0.25000
# Iter 128000, Minibatch Loss= 2.222230, Training Accuracy= 0.25000
# Iter 129600, Minibatch Loss= 2.225203, Training Accuracy= 0.43750
# Iter 131200, Minibatch Loss= 2.856530, Training Accuracy= 0.12500
# Iter 132800, Minibatch Loss= 2.957438, Training Accuracy= 0.31250
# Iter 134400, Minibatch Loss= 2.441989, Training Accuracy= 0.25000
# Iter 136000, Minibatch Loss= 2.310248, Training Accuracy= 0.25000
# Iter 137600, Minibatch Loss= 2.671953, Training Accuracy= 0.31250
# Iter 139200, Minibatch Loss= 2.196215, Training Accuracy= 0.43750
# Iter 140800, Minibatch Loss= 3.095218, Training Accuracy= 0.12500
# Iter 142400, Minibatch Loss= 2.133502, Training Accuracy= 0.37500
# Iter 144000, Minibatch Loss= 1.661812, Training Accuracy= 0.56250
# Iter 145600, Minibatch Loss= 2.044278, Training Accuracy= 0.37500
# Iter 147200, Minibatch Loss= 2.170576, Training Accuracy= 0.31250
# Iter 148800, Minibatch Loss= 2.012225, Training Accuracy= 0.43750
# Iter 150400, Minibatch Loss= 1.891171, Training Accuracy= 0.43750
# Iter 152000, Minibatch Loss= 2.447484, Training Accuracy= 0.12500
# Iter 153600, Minibatch Loss= 2.196955, Training Accuracy= 0.43750
# Iter 155200, Minibatch Loss= 1.726887, Training Accuracy= 0.50000
# Iter 156800, Minibatch Loss= 2.022611, Training Accuracy= 0.43750
# Iter 158400, Minibatch Loss= 1.984124, Training Accuracy= 0.43750
# Iter 160000, Minibatch Loss= 1.761664, Training Accuracy= 0.37500
# Iter 161600, Minibatch Loss= 1.731291, Training Accuracy= 0.56250
# Iter 163200, Minibatch Loss= 1.993958, Training Accuracy= 0.37500
# Iter 164800, Minibatch Loss= 1.517442, Training Accuracy= 0.43750
# Iter 166400, Minibatch Loss= 2.214036, Training Accuracy= 0.43750
# Iter 168000, Minibatch Loss= 1.737934, Training Accuracy= 0.43750
# Iter 169600, Minibatch Loss= 1.537621, Training Accuracy= 0.50000
# Iter 171200, Minibatch Loss= 1.922531, Training Accuracy= 0.37500
# Iter 172800, Minibatch Loss= 1.911452, Training Accuracy= 0.43750
# Iter 174400, Minibatch Loss= 2.418916, Training Accuracy= 0.31250
# Iter 176000, Minibatch Loss= 1.576238, Training Accuracy= 0.50000
# Iter 177600, Minibatch Loss= 1.750859, Training Accuracy= 0.56250
# Iter 179200, Minibatch Loss= 1.709735, Training Accuracy= 0.50000
# Iter 180800, Minibatch Loss= 1.769984, Training Accuracy= 0.18750
# Iter 182400, Minibatch Loss= 1.430177, Training Accuracy= 0.62500
# Iter 184000, Minibatch Loss= 1.914613, Training Accuracy= 0.31250
# Iter 185600, Minibatch Loss= 1.691116, Training Accuracy= 0.43750
# Iter 187200, Minibatch Loss= 2.701368, Training Accuracy= 0.50000
# Iter 188800, Minibatch Loss= 1.509454, Training Accuracy= 0.56250
# Iter 190400, Minibatch Loss= 1.998528, Training Accuracy= 0.25000
# Iter 192000, Minibatch Loss= 1.300927, Training Accuracy= 0.62500
# Iter 193600, Minibatch Loss= 1.551466, Training Accuracy= 0.68750
# Iter 195200, Minibatch Loss= 1.604118, Training Accuracy= 0.56250
# Iter 196800, Minibatch Loss= 1.304972, Training Accuracy= 0.56250
# Iter 198400, Minibatch Loss= 1.540147, Training Accuracy= 0.43750
# Iter 200000, Minibatch Loss= 1.786630, Training Accuracy= 0.50000
# Iter 201600, Minibatch Loss= 0.839933, Training Accuracy= 0.68750
# Iter 203200, Minibatch Loss= 1.296872, Training Accuracy= 0.62500
# Iter 204800, Minibatch Loss= 1.888119, Training Accuracy= 0.43750
# Iter 206400, Minibatch Loss= 2.468673, Training Accuracy= 0.31250
# Iter 208000, Minibatch Loss= 1.259584, Training Accuracy= 0.68750
# Iter 209600, Minibatch Loss= 1.113976, Training Accuracy= 0.56250
# Iter 211200, Minibatch Loss= 1.042437, Training Accuracy= 0.62500
# Iter 212800, Minibatch Loss= 1.286849, Training Accuracy= 0.68750
# Iter 214400, Minibatch Loss= 1.535859, Training Accuracy= 0.43750
# Iter 216000, Minibatch Loss= 1.280967, Training Accuracy= 0.56250
# Iter 217600, Minibatch Loss= 1.443808, Training Accuracy= 0.56250
# Iter 219200, Minibatch Loss= 1.402652, Training Accuracy= 0.62500
# Iter 220800, Minibatch Loss= 1.524444, Training Accuracy= 0.50000
# Iter 222400, Minibatch Loss= 0.990152, Training Accuracy= 0.68750
# Iter 224000, Minibatch Loss= 1.027740, Training Accuracy= 0.62500
# Iter 225600, Minibatch Loss= 0.905951, Training Accuracy= 0.56250
# Iter 227200, Minibatch Loss= 0.867627, Training Accuracy= 0.81250
# Iter 228800, Minibatch Loss= 1.007422, Training Accuracy= 0.68750
# Iter 230400, Minibatch Loss= 1.330055, Training Accuracy= 0.56250
# Iter 232000, Minibatch Loss= 0.878419, Training Accuracy= 0.68750
# Iter 233600, Minibatch Loss= 1.615259, Training Accuracy= 0.50000
# Iter 235200, Minibatch Loss= 1.371221, Training Accuracy= 0.62500
# Iter 236800, Minibatch Loss= 1.379617, Training Accuracy= 0.56250
# Iter 238400, Minibatch Loss= 1.380905, Training Accuracy= 0.62500
# Iter 240000, Minibatch Loss= 0.745622, Training Accuracy= 0.68750
# Iter 241600, Minibatch Loss= 1.479445, Training Accuracy= 0.43750
# Iter 243200, Minibatch Loss= 0.893995, Training Accuracy= 0.75000
# Iter 244800, Minibatch Loss= 0.786244, Training Accuracy= 0.81250
# Iter 246400, Minibatch Loss= 1.074686, Training Accuracy= 0.75000
# Iter 248000, Minibatch Loss= 1.125617, Training Accuracy= 0.50000
# Iter 249600, Minibatch Loss= 0.826931, Training Accuracy= 0.75000
# Iter 251200, Minibatch Loss= 1.091525, Training Accuracy= 0.81250
# Iter 252800, Minibatch Loss= 1.150334, Training Accuracy= 0.68750
# Iter 254400, Minibatch Loss= 0.871787, Training Accuracy= 0.68750
# Iter 256000, Minibatch Loss= 0.634365, Training Accuracy= 0.87500
# Iter 257600, Minibatch Loss= 0.925451, Training Accuracy= 0.81250
# Iter 259200, Minibatch Loss= 0.983807, Training Accuracy= 0.68750
# Iter 260800, Minibatch Loss= 0.669939, Training Accuracy= 0.68750
# Iter 262400, Minibatch Loss= 0.986354, Training Accuracy= 0.75000
# Iter 264000, Minibatch Loss= 0.850334, Training Accuracy= 0.75000
# Iter 265600, Minibatch Loss= 1.727587, Training Accuracy= 0.62500
# Iter 267200, Minibatch Loss= 1.733839, Training Accuracy= 0.62500
# Iter 268800, Minibatch Loss= 1.321586, Training Accuracy= 0.56250
# Iter 270400, Minibatch Loss= 0.792173, Training Accuracy= 0.68750
# Iter 272000, Minibatch Loss= 0.838195, Training Accuracy= 0.75000
# Iter 273600, Minibatch Loss= 0.908085, Training Accuracy= 0.62500
# Iter 275200, Minibatch Loss= 0.718845, Training Accuracy= 0.68750
# Iter 276800, Minibatch Loss= 0.740939, Training Accuracy= 0.81250
# Iter 278400, Minibatch Loss= 1.112457, Training Accuracy= 0.50000
# Iter 280000, Minibatch Loss= 1.362400, Training Accuracy= 0.56250
# Iter 281600, Minibatch Loss= 1.158808, Training Accuracy= 0.68750
# Iter 283200, Minibatch Loss= 0.996202, Training Accuracy= 0.68750
# Iter 284800, Minibatch Loss= 1.199079, Training Accuracy= 0.62500
# Iter 286400, Minibatch Loss= 0.872304, Training Accuracy= 0.68750
# Iter 288000, Minibatch Loss= 0.834331, Training Accuracy= 0.75000
# Iter 289600, Minibatch Loss= 0.887838, Training Accuracy= 0.62500
# Iter 291200, Minibatch Loss= 0.655343, Training Accuracy= 0.87500
# Iter 292800, Minibatch Loss= 1.013451, Training Accuracy= 0.75000
# Iter 294400, Minibatch Loss= 0.660427, Training Accuracy= 0.75000
# Iter 296000, Minibatch Loss= 0.859154, Training Accuracy= 0.75000
# Iter 297600, Minibatch Loss= 0.604263, Training Accuracy= 0.68750
# Iter 299200, Minibatch Loss= 1.465764, Training Accuracy= 0.68750
# Iter 300800, Minibatch Loss= 0.446331, Training Accuracy= 0.87500
# Iter 302400, Minibatch Loss= 1.040234, Training Accuracy= 0.81250
# Iter 304000, Minibatch Loss= 0.687071, Training Accuracy= 0.75000
# Iter 305600, Minibatch Loss= 1.999177, Training Accuracy= 0.50000
# Iter 307200, Minibatch Loss= 1.119666, Training Accuracy= 0.81250
# Iter 308800, Minibatch Loss= 0.939382, Training Accuracy= 0.62500
# Iter 310400, Minibatch Loss= 0.859068, Training Accuracy= 0.62500
# Iter 312000, Minibatch Loss= 1.082245, Training Accuracy= 0.62500
# Iter 313600, Minibatch Loss= 0.453999, Training Accuracy= 0.93750
# Iter 315200, Minibatch Loss= 0.673305, Training Accuracy= 0.81250
# Iter 316800, Minibatch Loss= 0.873096, Training Accuracy= 0.75000
# Iter 318400, Minibatch Loss= 0.559688, Training Accuracy= 0.81250
# Iter 320000, Minibatch Loss= 1.328986, Training Accuracy= 0.62500
# Iter 321600, Minibatch Loss= 0.635625, Training Accuracy= 0.87500
# Iter 323200, Minibatch Loss= 1.211354, Training Accuracy= 0.62500
# Iter 324800, Minibatch Loss= 0.480886, Training Accuracy= 0.87500
# Iter 326400, Minibatch Loss= 1.016417, Training Accuracy= 0.75000
# Iter 328000, Minibatch Loss= 0.419696, Training Accuracy= 0.93750
# Iter 329600, Minibatch Loss= 0.291686, Training Accuracy= 0.87500
# Iter 331200, Minibatch Loss= 0.533455, Training Accuracy= 0.87500
# Iter 332800, Minibatch Loss= 1.130594, Training Accuracy= 0.62500
# Iter 334400, Minibatch Loss= 0.480900, Training Accuracy= 0.81250
# Iter 336000, Minibatch Loss= 0.566218, Training Accuracy= 0.81250
# Iter 337600, Minibatch Loss= 0.424371, Training Accuracy= 0.87500
# Iter 339200, Minibatch Loss= 0.897884, Training Accuracy= 0.75000
# Iter 340800, Minibatch Loss= 0.503391, Training Accuracy= 0.87500
# Iter 342400, Minibatch Loss= 0.737738, Training Accuracy= 0.75000
# Iter 344000, Minibatch Loss= 1.074176, Training Accuracy= 0.68750
# Iter 345600, Minibatch Loss= 0.598052, Training Accuracy= 0.81250
# Iter 347200, Minibatch Loss= 0.708775, Training Accuracy= 0.81250
# Iter 348800, Minibatch Loss= 0.305459, Training Accuracy= 1.00000
# Iter 350400, Minibatch Loss= 0.883679, Training Accuracy= 0.62500
# Iter 352000, Minibatch Loss= 0.961736, Training Accuracy= 0.75000
# Iter 353600, Minibatch Loss= 0.684641, Training Accuracy= 0.81250
# Iter 355200, Minibatch Loss= 0.438317, Training Accuracy= 0.81250
# Iter 356800, Minibatch Loss= 0.451314, Training Accuracy= 0.87500
# Iter 358400, Minibatch Loss= 0.808716, Training Accuracy= 0.81250
# Iter 360000, Minibatch Loss= 0.485242, Training Accuracy= 0.93750
# Iter 361600, Minibatch Loss= 0.804737, Training Accuracy= 0.75000
# Iter 363200, Minibatch Loss= 1.390844, Training Accuracy= 0.68750
# Iter 364800, Minibatch Loss= 1.135572, Training Accuracy= 0.68750
# Iter 366400, Minibatch Loss= 0.280627, Training Accuracy= 0.93750
# Iter 368000, Minibatch Loss= 0.544121, Training Accuracy= 0.81250
# Iter 369600, Minibatch Loss= 0.216848, Training Accuracy= 0.93750
# Iter 371200, Minibatch Loss= 0.667492, Training Accuracy= 0.81250
# Iter 372800, Minibatch Loss= 0.790489, Training Accuracy= 0.75000
# Iter 374400, Minibatch Loss= 1.019794, Training Accuracy= 0.93750
# Iter 376000, Minibatch Loss= 0.234089, Training Accuracy= 0.87500
# Iter 377600, Minibatch Loss= 0.314060, Training Accuracy= 0.87500
# Iter 379200, Minibatch Loss= 0.789692, Training Accuracy= 0.81250
# Iter 380800, Minibatch Loss= 0.168083, Training Accuracy= 1.00000
# Iter 382400, Minibatch Loss= 0.390600, Training Accuracy= 0.87500
# Iter 384000, Minibatch Loss= 0.494674, Training Accuracy= 0.68750
# Iter 385600, Minibatch Loss= 0.795574, Training Accuracy= 0.75000
# Iter 387200, Minibatch Loss= 0.657474, Training Accuracy= 0.81250
# Iter 388800, Minibatch Loss= 0.752504, Training Accuracy= 0.87500
# Iter 390400, Minibatch Loss= 0.388330, Training Accuracy= 0.81250
# Iter 392000, Minibatch Loss= 0.892902, Training Accuracy= 0.75000
# Iter 393600, Minibatch Loss= 0.537262, Training Accuracy= 0.81250
# Iter 395200, Minibatch Loss= 0.329491, Training Accuracy= 0.93750
# Iter 396800, Minibatch Loss= 0.491536, Training Accuracy= 0.81250
# Iter 398400, Minibatch Loss= 0.475810, Training Accuracy= 0.93750
# Iter 400000, Minibatch Loss= 0.123582, Training Accuracy= 1.00000
# Iter 401600, Minibatch Loss= 0.928569, Training Accuracy= 0.87500
# Iter 403200, Minibatch Loss= 0.635567, Training Accuracy= 0.81250
# Iter 404800, Minibatch Loss= 0.367615, Training Accuracy= 0.81250
# Iter 406400, Minibatch Loss= 0.734887, Training Accuracy= 0.87500
# Iter 408000, Minibatch Loss= 0.126176, Training Accuracy= 1.00000
# Iter 409600, Minibatch Loss= 0.193326, Training Accuracy= 0.93750
# Iter 411200, Minibatch Loss= 0.411987, Training Accuracy= 0.87500
# Iter 412800, Minibatch Loss= 0.367567, Training Accuracy= 0.87500
# Iter 414400, Minibatch Loss= 0.510301, Training Accuracy= 0.87500
# Iter 416000, Minibatch Loss= 0.356657, Training Accuracy= 0.81250
# Iter 417600, Minibatch Loss= 0.291481, Training Accuracy= 0.93750
# Iter 419200, Minibatch Loss= 0.282811, Training Accuracy= 0.93750
# Iter 420800, Minibatch Loss= 0.778123, Training Accuracy= 0.68750
# Iter 422400, Minibatch Loss= 0.296065, Training Accuracy= 0.87500
# Iter 424000, Minibatch Loss= 0.077644, Training Accuracy= 1.00000
# Iter 425600, Minibatch Loss= 0.519808, Training Accuracy= 0.87500
# Iter 427200, Minibatch Loss= 0.837864, Training Accuracy= 0.68750
# Iter 428800, Minibatch Loss= 0.492917, Training Accuracy= 0.93750
# Iter 430400, Minibatch Loss= 0.590844, Training Accuracy= 0.81250
# Iter 432000, Minibatch Loss= 0.881399, Training Accuracy= 0.62500
# Iter 433600, Minibatch Loss= 0.645977, Training Accuracy= 0.81250
# Iter 435200, Minibatch Loss= 0.913015, Training Accuracy= 0.68750
# Iter 436800, Minibatch Loss= 0.024674, Training Accuracy= 1.00000
# Iter 438400, Minibatch Loss= 0.530937, Training Accuracy= 0.68750
# Iter 440000, Minibatch Loss= 0.141686, Training Accuracy= 1.00000
# Iter 441600, Minibatch Loss= 0.191857, Training Accuracy= 0.93750
# Iter 443200, Minibatch Loss= 0.505000, Training Accuracy= 0.87500
# Iter 444800, Minibatch Loss= 0.132135, Training Accuracy= 0.93750
# Iter 446400, Minibatch Loss= 0.158215, Training Accuracy= 1.00000
# Iter 448000, Minibatch Loss= 0.450843, Training Accuracy= 0.87500
# Iter 449600, Minibatch Loss= 0.226050, Training Accuracy= 1.00000
# Iter 451200, Minibatch Loss= 0.500886, Training Accuracy= 0.87500
# Iter 452800, Minibatch Loss= 0.554621, Training Accuracy= 0.75000
# Iter 454400, Minibatch Loss= 0.504246, Training Accuracy= 0.75000
# Iter 456000, Minibatch Loss= 0.613295, Training Accuracy= 0.81250
# Iter 457600, Minibatch Loss= 0.277809, Training Accuracy= 0.87500
# Iter 459200, Minibatch Loss= 0.291571, Training Accuracy= 0.87500
# Iter 460800, Minibatch Loss= 0.475056, Training Accuracy= 0.87500
# Iter 462400, Minibatch Loss= 0.065655, Training Accuracy= 1.00000
# Iter 464000, Minibatch Loss= 0.140446, Training Accuracy= 0.93750
# Iter 465600, Minibatch Loss= 0.402152, Training Accuracy= 0.87500
# Iter 467200, Minibatch Loss= 0.215042, Training Accuracy= 0.87500
# Iter 468800, Minibatch Loss= 0.489633, Training Accuracy= 0.81250
# Iter 470400, Minibatch Loss= 0.100259, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.139534, Training Accuracy= 0.93750
# Iter 473600, Minibatch Loss= 0.123639, Training Accuracy= 1.00000
# Iter 475200, Minibatch Loss= 0.247818, Training Accuracy= 0.81250
# Iter 476800, Minibatch Loss= 0.559942, Training Accuracy= 0.81250
# Iter 478400, Minibatch Loss= 0.170237, Training Accuracy= 0.87500
# Iter 480000, Minibatch Loss= 0.147308, Training Accuracy= 0.93750
# Iter 481600, Minibatch Loss= 0.145321, Training Accuracy= 0.93750
# Iter 483200, Minibatch Loss= 0.271684, Training Accuracy= 0.93750
# Iter 484800, Minibatch Loss= 0.116440, Training Accuracy= 1.00000
# Iter 486400, Minibatch Loss= 0.224334, Training Accuracy= 0.93750
# Iter 488000, Minibatch Loss= 0.732476, Training Accuracy= 0.87500
# Iter 489600, Minibatch Loss= 0.406355, Training Accuracy= 0.93750
# Iter 491200, Minibatch Loss= 0.080780, Training Accuracy= 1.00000
# Iter 492800, Minibatch Loss= 0.813568, Training Accuracy= 0.68750
# Iter 494400, Minibatch Loss= 0.110570, Training Accuracy= 1.00000
# Iter 496000, Minibatch Loss= 0.174320, Training Accuracy= 0.87500
# Iter 497600, Minibatch Loss= 0.296182, Training Accuracy= 0.81250
# Iter 499200, Minibatch Loss= 0.174871, Training Accuracy= 0.93750
# Optimization Finished!
# Testing Accuracy: 0.716946

# %%
saver.save(sess, '../Model/NIN-Model-0426')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', '1', 'd', '7', 's', '2', 'y', 'p', 'i', '9', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 'you', 't', '8', 'u', 'x', '6', 'h', 'what', 'e', '5', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
