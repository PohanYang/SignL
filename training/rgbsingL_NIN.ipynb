# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t502.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (110229, 37)

# %%
# Parameters
learning_rate = 0.001
training_iters = 500000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-4})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==5):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.618698, Training Accuracy= 0.00000
# Iter 3200, Minibatch Loss= 3.547473, Training Accuracy= 0.06250
# Iter 4800, Minibatch Loss= 3.603175, Training Accuracy= 0.06250
# Iter 6400, Minibatch Loss= 3.600800, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.554976, Training Accuracy= 0.18750
# Iter 9600, Minibatch Loss= 3.562271, Training Accuracy= 0.00000
# Iter 11200, Minibatch Loss= 3.404574, Training Accuracy= 0.06250
# Iter 12800, Minibatch Loss= 3.490312, Training Accuracy= 0.06250
# Iter 14400, Minibatch Loss= 3.619904, Training Accuracy= 0.00000
# Iter 16000, Minibatch Loss= 3.576787, Training Accuracy= 0.12500
# Iter 17600, Minibatch Loss= 3.496710, Training Accuracy= 0.18750
# Iter 19200, Minibatch Loss= 3.577824, Training Accuracy= 0.06250
# Iter 20800, Minibatch Loss= 3.557095, Training Accuracy= 0.12500
# Iter 22400, Minibatch Loss= 3.304437, Training Accuracy= 0.25000
# Iter 24000, Minibatch Loss= 3.592786, Training Accuracy= 0.06250
# Iter 25600, Minibatch Loss= 3.623602, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.232573, Training Accuracy= 0.18750
# Iter 28800, Minibatch Loss= 3.638239, Training Accuracy= 0.00000
# Iter 30400, Minibatch Loss= 3.591820, Training Accuracy= 0.00000
# Iter 32000, Minibatch Loss= 3.490847, Training Accuracy= 0.00000
# Iter 33600, Minibatch Loss= 3.357609, Training Accuracy= 0.00000
# Iter 35200, Minibatch Loss= 3.601265, Training Accuracy= 0.12500
# Iter 36800, Minibatch Loss= 3.555081, Training Accuracy= 0.06250
# Iter 38400, Minibatch Loss= 3.415668, Training Accuracy= 0.00000
# Iter 40000, Minibatch Loss= 3.212446, Training Accuracy= 0.06250
# Iter 41600, Minibatch Loss= 3.455684, Training Accuracy= 0.18750
# Iter 43200, Minibatch Loss= 3.259106, Training Accuracy= 0.12500
# Iter 44800, Minibatch Loss= 3.249729, Training Accuracy= 0.00000
# Iter 46400, Minibatch Loss= 3.466274, Training Accuracy= 0.00000
# Iter 48000, Minibatch Loss= 3.185166, Training Accuracy= 0.00000
# Iter 49600, Minibatch Loss= 3.086313, Training Accuracy= 0.00000
# Iter 51200, Minibatch Loss= 2.451455, Training Accuracy= 0.18750
# Iter 52800, Minibatch Loss= 2.646156, Training Accuracy= 0.18750
# Iter 54400, Minibatch Loss= 2.771638, Training Accuracy= 0.12500
# Iter 56000, Minibatch Loss= 2.831858, Training Accuracy= 0.06250
# Iter 57600, Minibatch Loss= 2.998576, Training Accuracy= 0.06250
# Iter 59200, Minibatch Loss= 2.172406, Training Accuracy= 0.25000
# Iter 60800, Minibatch Loss= 2.691844, Training Accuracy= 0.18750
# Iter 62400, Minibatch Loss= 2.822977, Training Accuracy= 0.00000
# Iter 64000, Minibatch Loss= 2.710151, Training Accuracy= 0.31250
# Iter 65600, Minibatch Loss= 1.947264, Training Accuracy= 0.37500
# Iter 67200, Minibatch Loss= 2.886131, Training Accuracy= 0.12500
# Iter 68800, Minibatch Loss= 2.121072, Training Accuracy= 0.37500
# Iter 70400, Minibatch Loss= 1.912709, Training Accuracy= 0.31250
# Iter 72000, Minibatch Loss= 2.060368, Training Accuracy= 0.31250
# Iter 73600, Minibatch Loss= 2.188962, Training Accuracy= 0.37500
# Iter 75200, Minibatch Loss= 2.924304, Training Accuracy= 0.50000
# Iter 76800, Minibatch Loss= 1.840527, Training Accuracy= 0.31250
# Iter 78400, Minibatch Loss= 1.324933, Training Accuracy= 0.68750
# Iter 80000, Minibatch Loss= 1.430609, Training Accuracy= 0.43750
# Iter 81600, Minibatch Loss= 1.733168, Training Accuracy= 0.43750
# Iter 83200, Minibatch Loss= 1.094153, Training Accuracy= 0.68750
# Iter 84800, Minibatch Loss= 2.202934, Training Accuracy= 0.50000
# Iter 86400, Minibatch Loss= 1.261765, Training Accuracy= 0.62500
# Iter 88000, Minibatch Loss= 1.246196, Training Accuracy= 0.56250
# Iter 89600, Minibatch Loss= 1.562085, Training Accuracy= 0.43750
# Iter 91200, Minibatch Loss= 1.688125, Training Accuracy= 0.62500
# Iter 92800, Minibatch Loss= 1.633747, Training Accuracy= 0.62500
# Iter 94400, Minibatch Loss= 0.970690, Training Accuracy= 0.68750
# Iter 96000, Minibatch Loss= 1.346844, Training Accuracy= 0.62500
# Iter 97600, Minibatch Loss= 1.266250, Training Accuracy= 0.50000
# Iter 99200, Minibatch Loss= 0.822598, Training Accuracy= 0.81250
# Iter 100800, Minibatch Loss= 1.553972, Training Accuracy= 0.81250
# Iter 102400, Minibatch Loss= 1.698008, Training Accuracy= 0.43750
# Iter 104000, Minibatch Loss= 0.422627, Training Accuracy= 0.81250
# Iter 105600, Minibatch Loss= 0.256104, Training Accuracy= 1.00000
# Iter 107200, Minibatch Loss= 0.600988, Training Accuracy= 0.75000
# Iter 108800, Minibatch Loss= 0.404391, Training Accuracy= 0.81250
# Iter 110400, Minibatch Loss= 0.855918, Training Accuracy= 0.75000
# Iter 112000, Minibatch Loss= 0.169444, Training Accuracy= 0.93750
# Iter 113600, Minibatch Loss= 0.064718, Training Accuracy= 1.00000
# Iter 115200, Minibatch Loss= 0.584934, Training Accuracy= 0.81250
# Iter 116800, Minibatch Loss= 0.657523, Training Accuracy= 0.75000
# Iter 118400, Minibatch Loss= 0.485252, Training Accuracy= 0.81250
# Iter 120000, Minibatch Loss= 0.349688, Training Accuracy= 0.87500
# Iter 121600, Minibatch Loss= 0.352916, Training Accuracy= 0.81250
# Iter 123200, Minibatch Loss= 0.413319, Training Accuracy= 0.87500
# Iter 124800, Minibatch Loss= 0.193525, Training Accuracy= 0.87500
# Iter 126400, Minibatch Loss= 0.333410, Training Accuracy= 0.93750
# Iter 128000, Minibatch Loss= 0.086703, Training Accuracy= 1.00000
# Iter 129600, Minibatch Loss= 0.584737, Training Accuracy= 0.87500
# Iter 131200, Minibatch Loss= 0.698175, Training Accuracy= 0.81250
# Iter 132800, Minibatch Loss= 0.059245, Training Accuracy= 1.00000
# Iter 134400, Minibatch Loss= 0.303116, Training Accuracy= 0.93750
# Iter 136000, Minibatch Loss= 0.040105, Training Accuracy= 1.00000
# Iter 137600, Minibatch Loss= 0.393273, Training Accuracy= 0.81250
# Iter 139200, Minibatch Loss= 0.114440, Training Accuracy= 0.93750
# Iter 140800, Minibatch Loss= 0.347679, Training Accuracy= 0.87500
# Iter 142400, Minibatch Loss= 0.064187, Training Accuracy= 1.00000
# Iter 144000, Minibatch Loss= 0.196924, Training Accuracy= 0.93750
# Iter 145600, Minibatch Loss= 0.414248, Training Accuracy= 0.87500
# Iter 147200, Minibatch Loss= 0.309331, Training Accuracy= 0.87500
# Iter 148800, Minibatch Loss= 0.350055, Training Accuracy= 0.87500
# Iter 150400, Minibatch Loss= 0.073264, Training Accuracy= 1.00000
# Iter 152000, Minibatch Loss= 0.088134, Training Accuracy= 1.00000
# Iter 153600, Minibatch Loss= 0.410380, Training Accuracy= 0.87500
# Iter 155200, Minibatch Loss= 0.111762, Training Accuracy= 0.93750
# Iter 156800, Minibatch Loss= 0.292978, Training Accuracy= 0.87500
# Iter 158400, Minibatch Loss= 0.374305, Training Accuracy= 0.87500
# Iter 160000, Minibatch Loss= 0.049858, Training Accuracy= 1.00000
# Iter 161600, Minibatch Loss= 0.054928, Training Accuracy= 1.00000
# Iter 163200, Minibatch Loss= 0.073542, Training Accuracy= 0.93750
# Iter 164800, Minibatch Loss= 0.420161, Training Accuracy= 0.87500
# Iter 166400, Minibatch Loss= 0.119466, Training Accuracy= 0.93750
# Iter 168000, Minibatch Loss= 0.161675, Training Accuracy= 0.93750
# Iter 169600, Minibatch Loss= 0.164276, Training Accuracy= 0.93750
# Iter 171200, Minibatch Loss= 0.005515, Training Accuracy= 1.00000
# Iter 172800, Minibatch Loss= 0.150714, Training Accuracy= 1.00000
# Iter 174400, Minibatch Loss= 0.162692, Training Accuracy= 0.93750
# Iter 176000, Minibatch Loss= 0.032750, Training Accuracy= 1.00000
# Iter 177600, Minibatch Loss= 0.830531, Training Accuracy= 0.87500
# Iter 179200, Minibatch Loss= 0.205277, Training Accuracy= 0.93750
# Iter 180800, Minibatch Loss= 0.045122, Training Accuracy= 1.00000
# Iter 182400, Minibatch Loss= 0.072602, Training Accuracy= 0.93750
# Iter 184000, Minibatch Loss= 0.051371, Training Accuracy= 1.00000
# Iter 185600, Minibatch Loss= 0.112262, Training Accuracy= 0.93750
# Iter 187200, Minibatch Loss= 0.435843, Training Accuracy= 0.93750
# Iter 188800, Minibatch Loss= 0.023958, Training Accuracy= 1.00000
# Iter 190400, Minibatch Loss= 0.157631, Training Accuracy= 0.93750
# Iter 192000, Minibatch Loss= 0.394162, Training Accuracy= 0.87500
# Iter 193600, Minibatch Loss= 0.031889, Training Accuracy= 1.00000
# Iter 195200, Minibatch Loss= 0.236155, Training Accuracy= 0.93750
# Iter 196800, Minibatch Loss= 0.020252, Training Accuracy= 1.00000
# Iter 198400, Minibatch Loss= 0.007070, Training Accuracy= 1.00000
# Iter 200000, Minibatch Loss= 0.028129, Training Accuracy= 1.00000
# Iter 201600, Minibatch Loss= 0.031463, Training Accuracy= 1.00000
# Iter 203200, Minibatch Loss= 0.032157, Training Accuracy= 1.00000
# Iter 204800, Minibatch Loss= 0.006040, Training Accuracy= 1.00000
# Iter 206400, Minibatch Loss= 0.002362, Training Accuracy= 1.00000
# Iter 208000, Minibatch Loss= 0.076927, Training Accuracy= 1.00000
# Iter 209600, Minibatch Loss= 0.331575, Training Accuracy= 1.00000
# Iter 211200, Minibatch Loss= 0.060161, Training Accuracy= 1.00000
# Iter 212800, Minibatch Loss= 0.115388, Training Accuracy= 0.93750
# Iter 214400, Minibatch Loss= 0.071318, Training Accuracy= 0.93750
# Iter 216000, Minibatch Loss= 0.101648, Training Accuracy= 0.93750
# Iter 217600, Minibatch Loss= 0.019954, Training Accuracy= 1.00000
# Iter 219200, Minibatch Loss= 0.022425, Training Accuracy= 1.00000
# Iter 220800, Minibatch Loss= 0.044935, Training Accuracy= 1.00000
# Iter 222400, Minibatch Loss= 0.005889, Training Accuracy= 1.00000
# Iter 224000, Minibatch Loss= 0.176983, Training Accuracy= 0.93750
# Iter 225600, Minibatch Loss= 0.014738, Training Accuracy= 1.00000
# Iter 227200, Minibatch Loss= 0.002729, Training Accuracy= 1.00000
# Iter 228800, Minibatch Loss= 0.014278, Training Accuracy= 1.00000
# Iter 230400, Minibatch Loss= 0.029868, Training Accuracy= 1.00000
# Iter 232000, Minibatch Loss= 0.005096, Training Accuracy= 1.00000
# Iter 233600, Minibatch Loss= 0.010644, Training Accuracy= 1.00000
# Iter 235200, Minibatch Loss= 0.055105, Training Accuracy= 1.00000
# Iter 236800, Minibatch Loss= 0.670380, Training Accuracy= 0.87500
# Iter 238400, Minibatch Loss= 0.030992, Training Accuracy= 1.00000
# Iter 240000, Minibatch Loss= 0.005579, Training Accuracy= 1.00000
# Iter 241600, Minibatch Loss= 0.250270, Training Accuracy= 0.93750
# Iter 243200, Minibatch Loss= 0.002972, Training Accuracy= 1.00000
# Iter 244800, Minibatch Loss= 0.086985, Training Accuracy= 1.00000
# Iter 246400, Minibatch Loss= 0.222560, Training Accuracy= 0.93750
# Iter 248000, Minibatch Loss= 0.108995, Training Accuracy= 0.93750
# Iter 249600, Minibatch Loss= 0.051493, Training Accuracy= 1.00000
# Iter 251200, Minibatch Loss= 0.035743, Training Accuracy= 1.00000
# Iter 252800, Minibatch Loss= 0.029598, Training Accuracy= 1.00000
# Iter 254400, Minibatch Loss= 0.008859, Training Accuracy= 1.00000
# Iter 256000, Minibatch Loss= 0.020348, Training Accuracy= 1.00000
# Iter 257600, Minibatch Loss= 0.003394, Training Accuracy= 1.00000
# Iter 259200, Minibatch Loss= 0.001258, Training Accuracy= 1.00000
# Iter 260800, Minibatch Loss= 0.043099, Training Accuracy= 1.00000
# Iter 262400, Minibatch Loss= 0.032993, Training Accuracy= 1.00000
# Iter 264000, Minibatch Loss= 0.016621, Training Accuracy= 1.00000
# Iter 265600, Minibatch Loss= 0.082659, Training Accuracy= 0.93750
# Iter 267200, Minibatch Loss= 0.112595, Training Accuracy= 0.93750
# Iter 268800, Minibatch Loss= 0.006064, Training Accuracy= 1.00000
# Iter 270400, Minibatch Loss= 0.019728, Training Accuracy= 1.00000
# Iter 272000, Minibatch Loss= 0.001366, Training Accuracy= 1.00000
# Iter 273600, Minibatch Loss= 0.000408, Training Accuracy= 1.00000
# Iter 275200, Minibatch Loss= 0.013304, Training Accuracy= 1.00000
# Iter 276800, Minibatch Loss= 0.032179, Training Accuracy= 1.00000
# Iter 278400, Minibatch Loss= 0.006273, Training Accuracy= 1.00000
# Iter 280000, Minibatch Loss= 0.004366, Training Accuracy= 1.00000
# Iter 281600, Minibatch Loss= 0.086059, Training Accuracy= 0.93750
# Iter 283200, Minibatch Loss= 0.001958, Training Accuracy= 1.00000
# Iter 284800, Minibatch Loss= 0.006239, Training Accuracy= 1.00000
# Iter 286400, Minibatch Loss= 0.019775, Training Accuracy= 1.00000
# Iter 288000, Minibatch Loss= 0.010347, Training Accuracy= 1.00000
# Iter 289600, Minibatch Loss= 0.044401, Training Accuracy= 1.00000
# Iter 291200, Minibatch Loss= 0.049378, Training Accuracy= 1.00000
# Iter 292800, Minibatch Loss= 0.190075, Training Accuracy= 0.93750
# Iter 294400, Minibatch Loss= 0.049195, Training Accuracy= 1.00000
# Iter 296000, Minibatch Loss= 0.007818, Training Accuracy= 1.00000
# Iter 297600, Minibatch Loss= 0.118523, Training Accuracy= 0.93750
# Iter 299200, Minibatch Loss= 0.007327, Training Accuracy= 1.00000
# Iter 300800, Minibatch Loss= 0.003779, Training Accuracy= 1.00000
# Iter 302400, Minibatch Loss= 0.000922, Training Accuracy= 1.00000
# Iter 304000, Minibatch Loss= 0.058775, Training Accuracy= 0.93750
# Iter 305600, Minibatch Loss= 0.126967, Training Accuracy= 0.93750
# Iter 307200, Minibatch Loss= 0.038015, Training Accuracy= 1.00000
# Iter 308800, Minibatch Loss= 0.071339, Training Accuracy= 1.00000
# Iter 310400, Minibatch Loss= 0.032625, Training Accuracy= 1.00000
# Iter 312000, Minibatch Loss= 0.103276, Training Accuracy= 0.93750
# Iter 313600, Minibatch Loss= 0.002022, Training Accuracy= 1.00000
# Iter 315200, Minibatch Loss= 0.001143, Training Accuracy= 1.00000
# Iter 316800, Minibatch Loss= 0.001213, Training Accuracy= 1.00000
# Iter 318400, Minibatch Loss= 0.144207, Training Accuracy= 0.93750
# Iter 320000, Minibatch Loss= 0.025669, Training Accuracy= 1.00000
# Iter 321600, Minibatch Loss= 0.036279, Training Accuracy= 1.00000
# Iter 323200, Minibatch Loss= 0.005991, Training Accuracy= 1.00000
# Iter 324800, Minibatch Loss= 0.027059, Training Accuracy= 1.00000
# Iter 326400, Minibatch Loss= 0.001889, Training Accuracy= 1.00000
# Iter 328000, Minibatch Loss= 0.118403, Training Accuracy= 0.93750
# Iter 329600, Minibatch Loss= 0.009629, Training Accuracy= 1.00000
# Iter 331200, Minibatch Loss= 0.026104, Training Accuracy= 1.00000
# Iter 332800, Minibatch Loss= 0.000632, Training Accuracy= 1.00000
# Iter 334400, Minibatch Loss= 0.000410, Training Accuracy= 1.00000
# Iter 336000, Minibatch Loss= 0.014988, Training Accuracy= 1.00000
# Iter 337600, Minibatch Loss= 0.001389, Training Accuracy= 1.00000
# Iter 339200, Minibatch Loss= 0.023953, Training Accuracy= 1.00000
# Iter 340800, Minibatch Loss= 0.079499, Training Accuracy= 0.93750
# Iter 342400, Minibatch Loss= 0.064380, Training Accuracy= 1.00000
# Iter 344000, Minibatch Loss= 0.074724, Training Accuracy= 1.00000
# Iter 345600, Minibatch Loss= 0.001921, Training Accuracy= 1.00000
# Iter 347200, Minibatch Loss= 0.003857, Training Accuracy= 1.00000
# Iter 348800, Minibatch Loss= 0.003913, Training Accuracy= 1.00000
# Iter 350400, Minibatch Loss= 0.042329, Training Accuracy= 1.00000
# Iter 352000, Minibatch Loss= 0.015681, Training Accuracy= 1.00000
# Iter 353600, Minibatch Loss= 0.014129, Training Accuracy= 1.00000
# Iter 355200, Minibatch Loss= 0.014054, Training Accuracy= 1.00000
# Iter 356800, Minibatch Loss= 0.001960, Training Accuracy= 1.00000
# Iter 358400, Minibatch Loss= 0.001729, Training Accuracy= 1.00000
# Iter 360000, Minibatch Loss= 0.056194, Training Accuracy= 1.00000
# Iter 361600, Minibatch Loss= 0.000518, Training Accuracy= 1.00000
# Iter 363200, Minibatch Loss= 0.000310, Training Accuracy= 1.00000
# Iter 364800, Minibatch Loss= 0.000048, Training Accuracy= 1.00000
# Iter 366400, Minibatch Loss= 0.000579, Training Accuracy= 1.00000
# Iter 368000, Minibatch Loss= 0.170573, Training Accuracy= 0.93750
# Iter 369600, Minibatch Loss= 0.003460, Training Accuracy= 1.00000
# Iter 371200, Minibatch Loss= 0.001504, Training Accuracy= 1.00000
# Iter 372800, Minibatch Loss= 0.000348, Training Accuracy= 1.00000
# Iter 374400, Minibatch Loss= 0.001544, Training Accuracy= 1.00000
# Iter 376000, Minibatch Loss= 0.059360, Training Accuracy= 1.00000
# Iter 377600, Minibatch Loss= 0.009734, Training Accuracy= 1.00000
# Iter 379200, Minibatch Loss= 0.012314, Training Accuracy= 1.00000
# Iter 380800, Minibatch Loss= 0.000778, Training Accuracy= 1.00000
# Iter 382400, Minibatch Loss= 0.002694, Training Accuracy= 1.00000
# Iter 384000, Minibatch Loss= 0.001999, Training Accuracy= 1.00000
# Iter 385600, Minibatch Loss= 0.012707, Training Accuracy= 1.00000
# Iter 387200, Minibatch Loss= 0.003679, Training Accuracy= 1.00000
# Iter 388800, Minibatch Loss= 0.005985, Training Accuracy= 1.00000
# Iter 390400, Minibatch Loss= 0.003717, Training Accuracy= 1.00000
# Iter 392000, Minibatch Loss= 0.011014, Training Accuracy= 1.00000
# Iter 393600, Minibatch Loss= 0.001339, Training Accuracy= 1.00000
# Iter 395200, Minibatch Loss= 0.005333, Training Accuracy= 1.00000
# Iter 396800, Minibatch Loss= 0.000288, Training Accuracy= 1.00000
# Iter 398400, Minibatch Loss= 0.001927, Training Accuracy= 1.00000
# Iter 400000, Minibatch Loss= 0.008401, Training Accuracy= 1.00000
# Iter 401600, Minibatch Loss= 0.000479, Training Accuracy= 1.00000
# Iter 403200, Minibatch Loss= 0.001987, Training Accuracy= 1.00000
# Iter 404800, Minibatch Loss= 0.074311, Training Accuracy= 0.93750
# Iter 406400, Minibatch Loss= 0.000859, Training Accuracy= 1.00000
# Iter 408000, Minibatch Loss= 0.001380, Training Accuracy= 1.00000
# Iter 409600, Minibatch Loss= 0.004638, Training Accuracy= 1.00000
# Iter 411200, Minibatch Loss= 0.723224, Training Accuracy= 0.93750
# Iter 412800, Minibatch Loss= 0.000420, Training Accuracy= 1.00000
# Iter 414400, Minibatch Loss= 0.045310, Training Accuracy= 0.93750
# Iter 416000, Minibatch Loss= 0.000859, Training Accuracy= 1.00000
# Iter 417600, Minibatch Loss= 0.007824, Training Accuracy= 1.00000
# Iter 419200, Minibatch Loss= 0.001392, Training Accuracy= 1.00000
# Iter 420800, Minibatch Loss= 0.002179, Training Accuracy= 1.00000
# Iter 422400, Minibatch Loss= 0.002468, Training Accuracy= 1.00000
# Iter 424000, Minibatch Loss= 0.000994, Training Accuracy= 1.00000
# Iter 425600, Minibatch Loss= 0.082696, Training Accuracy= 0.93750
# Iter 427200, Minibatch Loss= 0.006888, Training Accuracy= 1.00000
# Iter 428800, Minibatch Loss= 0.003712, Training Accuracy= 1.00000
# Iter 430400, Minibatch Loss= 0.000264, Training Accuracy= 1.00000
# Iter 432000, Minibatch Loss= 0.000074, Training Accuracy= 1.00000
# Iter 433600, Minibatch Loss= 0.000989, Training Accuracy= 1.00000
# Iter 435200, Minibatch Loss= 0.001115, Training Accuracy= 1.00000
# Iter 436800, Minibatch Loss= 0.002064, Training Accuracy= 1.00000
# Iter 438400, Minibatch Loss= 0.000850, Training Accuracy= 1.00000
# Iter 440000, Minibatch Loss= 0.001500, Training Accuracy= 1.00000
# Iter 441600, Minibatch Loss= 0.090826, Training Accuracy= 0.93750
# Iter 443200, Minibatch Loss= 0.000909, Training Accuracy= 1.00000
# Iter 444800, Minibatch Loss= 0.000230, Training Accuracy= 1.00000
# Iter 446400, Minibatch Loss= 0.007560, Training Accuracy= 1.00000
# Iter 448000, Minibatch Loss= 0.005606, Training Accuracy= 1.00000
# Iter 449600, Minibatch Loss= 0.004679, Training Accuracy= 1.00000
# Iter 451200, Minibatch Loss= 0.224192, Training Accuracy= 0.93750
# Iter 452800, Minibatch Loss= 0.000035, Training Accuracy= 1.00000
# Iter 454400, Minibatch Loss= 0.000682, Training Accuracy= 1.00000
# Iter 456000, Minibatch Loss= 0.000801, Training Accuracy= 1.00000
# Iter 457600, Minibatch Loss= 0.001309, Training Accuracy= 1.00000
# Iter 459200, Minibatch Loss= 0.000370, Training Accuracy= 1.00000
# Iter 460800, Minibatch Loss= 0.000048, Training Accuracy= 1.00000
# Iter 462400, Minibatch Loss= 0.237051, Training Accuracy= 0.93750
# Iter 464000, Minibatch Loss= 0.001478, Training Accuracy= 1.00000
# Iter 465600, Minibatch Loss= 0.001614, Training Accuracy= 1.00000
# Iter 467200, Minibatch Loss= 0.000423, Training Accuracy= 1.00000
# Iter 468800, Minibatch Loss= 0.002877, Training Accuracy= 1.00000
# Iter 470400, Minibatch Loss= 0.002508, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.001498, Training Accuracy= 1.00000
# Iter 473600, Minibatch Loss= 0.002889, Training Accuracy= 1.00000
# Iter 475200, Minibatch Loss= 0.000734, Training Accuracy= 1.00000
# Iter 476800, Minibatch Loss= 0.000459, Training Accuracy= 1.00000
# Iter 478400, Minibatch Loss= 0.002919, Training Accuracy= 1.00000
# Iter 480000, Minibatch Loss= 0.000138, Training Accuracy= 1.00000
# Iter 481600, Minibatch Loss= 0.000071, Training Accuracy= 1.00000
# Iter 483200, Minibatch Loss= 0.000096, Training Accuracy= 1.00000
# Iter 484800, Minibatch Loss= 0.000090, Training Accuracy= 1.00000
# Iter 486400, Minibatch Loss= 0.025899, Training Accuracy= 1.00000
# Iter 488000, Minibatch Loss= 0.002523, Training Accuracy= 1.00000
# Iter 489600, Minibatch Loss= 0.141676, Training Accuracy= 0.93750
# Iter 491200, Minibatch Loss= 0.000147, Training Accuracy= 1.00000
# Iter 492800, Minibatch Loss= 0.005374, Training Accuracy= 1.00000
# Iter 494400, Minibatch Loss= 0.028552, Training Accuracy= 1.00000
# Iter 496000, Minibatch Loss= 0.032088, Training Accuracy= 1.00000
# Iter 497600, Minibatch Loss= 0.000251, Training Accuracy= 1.00000
# Iter 499200, Minibatch Loss= 0.000119, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.893178

# %%
saver.save(sess, '../Model/NIN-Model-0502')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', '1', 'd', '7', 's', '2', 'y', 'p', 'i', '9', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 'you', 't', '8', 'u', 'x', '6', 'h', 'what', 'e', '5', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
