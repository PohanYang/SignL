# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t503.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (113843, 37)

# %%
# Parameters
learning_rate = 0.001
training_iters = 500000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-4})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==5):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.480396, Training Accuracy= 0.25000
# Iter 3200, Minibatch Loss= 3.541951, Training Accuracy= 0.06250
# Iter 4800, Minibatch Loss= 3.599087, Training Accuracy= 0.00000
# Iter 6400, Minibatch Loss= 3.591459, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.424350, Training Accuracy= 0.06250
# Iter 9600, Minibatch Loss= 3.555368, Training Accuracy= 0.06250
# Iter 11200, Minibatch Loss= 3.421796, Training Accuracy= 0.12500
# Iter 12800, Minibatch Loss= 3.572050, Training Accuracy= 0.06250
# Iter 14400, Minibatch Loss= 3.505992, Training Accuracy= 0.06250
# Iter 16000, Minibatch Loss= 3.498180, Training Accuracy= 0.06250
# Iter 17600, Minibatch Loss= 3.223368, Training Accuracy= 0.06250
# Iter 19200, Minibatch Loss= 3.527019, Training Accuracy= 0.06250
# Iter 20800, Minibatch Loss= 3.635145, Training Accuracy= 0.06250
# Iter 22400, Minibatch Loss= 3.575400, Training Accuracy= 0.06250
# Iter 24000, Minibatch Loss= 3.481383, Training Accuracy= 0.06250
# Iter 25600, Minibatch Loss= 3.522795, Training Accuracy= 0.12500
# Iter 27200, Minibatch Loss= 3.194945, Training Accuracy= 0.06250
# Iter 28800, Minibatch Loss= 3.405504, Training Accuracy= 0.12500
# Iter 30400, Minibatch Loss= 3.208201, Training Accuracy= 0.12500
# Iter 32000, Minibatch Loss= 3.289032, Training Accuracy= 0.06250
# Iter 33600, Minibatch Loss= 3.219601, Training Accuracy= 0.00000
# Iter 35200, Minibatch Loss= 3.390083, Training Accuracy= 0.12500
# Iter 36800, Minibatch Loss= 3.099660, Training Accuracy= 0.12500
# Iter 38400, Minibatch Loss= 3.084317, Training Accuracy= 0.12500
# Iter 40000, Minibatch Loss= 3.248921, Training Accuracy= 0.00000
# Iter 41600, Minibatch Loss= 3.364515, Training Accuracy= 0.12500
# Iter 43200, Minibatch Loss= 3.462592, Training Accuracy= 0.06250
# Iter 44800, Minibatch Loss= 2.952940, Training Accuracy= 0.06250
# Iter 46400, Minibatch Loss= 2.297930, Training Accuracy= 0.37500
# Iter 48000, Minibatch Loss= 2.590837, Training Accuracy= 0.43750
# Iter 49600, Minibatch Loss= 2.078808, Training Accuracy= 0.37500
# Iter 51200, Minibatch Loss= 3.458761, Training Accuracy= 0.06250
# Iter 52800, Minibatch Loss= 2.813154, Training Accuracy= 0.12500
# Iter 54400, Minibatch Loss= 2.519089, Training Accuracy= 0.18750
# Iter 56000, Minibatch Loss= 2.704720, Training Accuracy= 0.12500
# Iter 57600, Minibatch Loss= 2.751155, Training Accuracy= 0.25000
# Iter 59200, Minibatch Loss= 2.066772, Training Accuracy= 0.50000
# Iter 60800, Minibatch Loss= 2.206010, Training Accuracy= 0.43750
# Iter 62400, Minibatch Loss= 2.064908, Training Accuracy= 0.37500
# Iter 64000, Minibatch Loss= 2.162117, Training Accuracy= 0.56250
# Iter 65600, Minibatch Loss= 2.274031, Training Accuracy= 0.25000
# Iter 67200, Minibatch Loss= 2.021396, Training Accuracy= 0.43750
# Iter 68800, Minibatch Loss= 1.808098, Training Accuracy= 0.50000
# Iter 70400, Minibatch Loss= 2.064167, Training Accuracy= 0.56250
# Iter 72000, Minibatch Loss= 1.405276, Training Accuracy= 0.62500
# Iter 73600, Minibatch Loss= 2.157997, Training Accuracy= 0.37500
# Iter 75200, Minibatch Loss= 1.568051, Training Accuracy= 0.62500
# Iter 76800, Minibatch Loss= 1.929526, Training Accuracy= 0.37500
# Iter 78400, Minibatch Loss= 1.596392, Training Accuracy= 0.50000
# Iter 80000, Minibatch Loss= 1.201230, Training Accuracy= 0.56250
# Iter 81600, Minibatch Loss= 0.972574, Training Accuracy= 0.87500
# Iter 83200, Minibatch Loss= 1.875393, Training Accuracy= 0.37500
# Iter 84800, Minibatch Loss= 1.442193, Training Accuracy= 0.75000
# Iter 86400, Minibatch Loss= 1.575728, Training Accuracy= 0.50000
# Iter 88000, Minibatch Loss= 1.454075, Training Accuracy= 0.56250
# Iter 89600, Minibatch Loss= 1.095152, Training Accuracy= 0.68750
# Iter 91200, Minibatch Loss= 1.362733, Training Accuracy= 0.50000
# Iter 92800, Minibatch Loss= 1.592165, Training Accuracy= 0.56250
# Iter 94400, Minibatch Loss= 1.478207, Training Accuracy= 0.62500
# Iter 96000, Minibatch Loss= 1.406529, Training Accuracy= 0.56250
# Iter 97600, Minibatch Loss= 0.995765, Training Accuracy= 0.81250
# Iter 99200, Minibatch Loss= 0.779994, Training Accuracy= 0.81250
# Iter 100800, Minibatch Loss= 0.868502, Training Accuracy= 0.68750
# Iter 102400, Minibatch Loss= 0.506358, Training Accuracy= 0.87500
# Iter 104000, Minibatch Loss= 1.629009, Training Accuracy= 0.68750
# Iter 105600, Minibatch Loss= 0.837980, Training Accuracy= 0.81250
# Iter 107200, Minibatch Loss= 0.455681, Training Accuracy= 0.93750
# Iter 108800, Minibatch Loss= 1.190086, Training Accuracy= 0.75000
# Iter 110400, Minibatch Loss= 0.483664, Training Accuracy= 0.81250
# Iter 112000, Minibatch Loss= 0.122768, Training Accuracy= 1.00000
# Iter 113600, Minibatch Loss= 0.707106, Training Accuracy= 0.93750
# Iter 115200, Minibatch Loss= 0.531120, Training Accuracy= 0.87500
# Iter 116800, Minibatch Loss= 0.923988, Training Accuracy= 0.68750
# Iter 118400, Minibatch Loss= 0.483185, Training Accuracy= 0.93750
# Iter 120000, Minibatch Loss= 0.193780, Training Accuracy= 1.00000
# Iter 121600, Minibatch Loss= 0.970500, Training Accuracy= 0.68750
# Iter 123200, Minibatch Loss= 1.140226, Training Accuracy= 0.68750
# Iter 124800, Minibatch Loss= 0.729724, Training Accuracy= 0.81250
# Iter 126400, Minibatch Loss= 0.410822, Training Accuracy= 0.81250
# Iter 128000, Minibatch Loss= 1.172265, Training Accuracy= 0.87500
# Iter 129600, Minibatch Loss= 0.122657, Training Accuracy= 1.00000
# Iter 131200, Minibatch Loss= 0.390917, Training Accuracy= 0.93750
# Iter 132800, Minibatch Loss= 0.208901, Training Accuracy= 0.87500
# Iter 134400, Minibatch Loss= 0.145589, Training Accuracy= 1.00000
# Iter 136000, Minibatch Loss= 0.082580, Training Accuracy= 1.00000
# Iter 137600, Minibatch Loss= 0.336285, Training Accuracy= 0.93750
# Iter 139200, Minibatch Loss= 0.257241, Training Accuracy= 0.93750
# Iter 140800, Minibatch Loss= 0.103361, Training Accuracy= 1.00000
# Iter 142400, Minibatch Loss= 0.128696, Training Accuracy= 1.00000
# Iter 144000, Minibatch Loss= 0.723343, Training Accuracy= 0.75000
# Iter 145600, Minibatch Loss= 0.249233, Training Accuracy= 1.00000
# Iter 147200, Minibatch Loss= 0.378673, Training Accuracy= 1.00000
# Iter 148800, Minibatch Loss= 0.190387, Training Accuracy= 0.93750
# Iter 150400, Minibatch Loss= 0.064440, Training Accuracy= 1.00000
# Iter 152000, Minibatch Loss= 0.092563, Training Accuracy= 1.00000
# Iter 153600, Minibatch Loss= 1.216928, Training Accuracy= 0.87500
# Iter 155200, Minibatch Loss= 0.086544, Training Accuracy= 1.00000
# Iter 156800, Minibatch Loss= 0.242441, Training Accuracy= 0.93750
# Iter 158400, Minibatch Loss= 0.168325, Training Accuracy= 0.93750
# Iter 160000, Minibatch Loss= 0.222134, Training Accuracy= 0.93750
# Iter 161600, Minibatch Loss= 0.217412, Training Accuracy= 0.93750
# Iter 163200, Minibatch Loss= 0.622983, Training Accuracy= 0.81250
# Iter 164800, Minibatch Loss= 0.315042, Training Accuracy= 0.93750
# Iter 166400, Minibatch Loss= 0.984502, Training Accuracy= 0.81250
# Iter 168000, Minibatch Loss= 0.094709, Training Accuracy= 1.00000
# Iter 169600, Minibatch Loss= 0.076772, Training Accuracy= 1.00000
# Iter 171200, Minibatch Loss= 0.152077, Training Accuracy= 1.00000
# Iter 172800, Minibatch Loss= 0.891312, Training Accuracy= 0.75000
# Iter 174400, Minibatch Loss= 0.042875, Training Accuracy= 1.00000
# Iter 176000, Minibatch Loss= 0.196915, Training Accuracy= 0.93750
# Iter 177600, Minibatch Loss= 0.225007, Training Accuracy= 1.00000
# Iter 179200, Minibatch Loss= 0.366282, Training Accuracy= 0.93750
# Iter 180800, Minibatch Loss= 0.347306, Training Accuracy= 0.93750
# Iter 182400, Minibatch Loss= 0.366686, Training Accuracy= 0.87500
# Iter 184000, Minibatch Loss= 0.144502, Training Accuracy= 0.93750
# Iter 185600, Minibatch Loss= 0.265598, Training Accuracy= 0.87500
# Iter 187200, Minibatch Loss= 0.006888, Training Accuracy= 1.00000
# Iter 188800, Minibatch Loss= 0.324789, Training Accuracy= 0.87500
# Iter 190400, Minibatch Loss= 0.013083, Training Accuracy= 1.00000
# Iter 192000, Minibatch Loss= 0.110751, Training Accuracy= 0.93750
# Iter 193600, Minibatch Loss= 0.187270, Training Accuracy= 0.87500
# Iter 195200, Minibatch Loss= 0.185892, Training Accuracy= 0.87500
# Iter 196800, Minibatch Loss= 0.108578, Training Accuracy= 1.00000
# Iter 198400, Minibatch Loss= 0.050253, Training Accuracy= 1.00000
# Iter 200000, Minibatch Loss= 0.015959, Training Accuracy= 1.00000
# Iter 201600, Minibatch Loss= 0.372526, Training Accuracy= 0.87500
# Iter 203200, Minibatch Loss= 0.129643, Training Accuracy= 1.00000
# Iter 204800, Minibatch Loss= 0.481552, Training Accuracy= 0.93750
# Iter 206400, Minibatch Loss= 0.566917, Training Accuracy= 0.93750
# Iter 208000, Minibatch Loss= 0.110977, Training Accuracy= 1.00000
# Iter 209600, Minibatch Loss= 0.121782, Training Accuracy= 1.00000
# Iter 211200, Minibatch Loss= 0.098915, Training Accuracy= 0.93750
# Iter 212800, Minibatch Loss= 0.047959, Training Accuracy= 1.00000
# Iter 214400, Minibatch Loss= 0.043309, Training Accuracy= 1.00000
# Iter 216000, Minibatch Loss= 0.694377, Training Accuracy= 0.81250
# Iter 217600, Minibatch Loss= 0.032263, Training Accuracy= 1.00000
# Iter 219200, Minibatch Loss= 0.084567, Training Accuracy= 1.00000
# Iter 220800, Minibatch Loss= 0.051033, Training Accuracy= 1.00000
# Iter 222400, Minibatch Loss= 0.053301, Training Accuracy= 1.00000
# Iter 224000, Minibatch Loss= 0.039203, Training Accuracy= 1.00000
# Iter 225600, Minibatch Loss= 0.191556, Training Accuracy= 0.93750
# Iter 227200, Minibatch Loss= 0.027713, Training Accuracy= 1.00000
# Iter 228800, Minibatch Loss= 0.124738, Training Accuracy= 0.93750
# Iter 230400, Minibatch Loss= 0.003703, Training Accuracy= 1.00000
# Iter 232000, Minibatch Loss= 0.010785, Training Accuracy= 1.00000
# Iter 233600, Minibatch Loss= 0.027882, Training Accuracy= 1.00000
# Iter 235200, Minibatch Loss= 0.027608, Training Accuracy= 1.00000
# Iter 236800, Minibatch Loss= 0.003823, Training Accuracy= 1.00000
# Iter 238400, Minibatch Loss= 0.096605, Training Accuracy= 0.93750
# Iter 240000, Minibatch Loss= 0.533567, Training Accuracy= 0.93750
# Iter 241600, Minibatch Loss= 0.087881, Training Accuracy= 1.00000
# Iter 243200, Minibatch Loss= 0.015345, Training Accuracy= 1.00000
# Iter 244800, Minibatch Loss= 0.013367, Training Accuracy= 1.00000
# Iter 246400, Minibatch Loss= 0.138110, Training Accuracy= 1.00000
# Iter 248000, Minibatch Loss= 0.188140, Training Accuracy= 0.93750
# Iter 249600, Minibatch Loss= 0.007477, Training Accuracy= 1.00000
# Iter 251200, Minibatch Loss= 0.006940, Training Accuracy= 1.00000
# Iter 252800, Minibatch Loss= 0.496076, Training Accuracy= 0.87500
# Iter 254400, Minibatch Loss= 0.021091, Training Accuracy= 1.00000
# Iter 256000, Minibatch Loss= 0.148964, Training Accuracy= 0.93750
# Iter 257600, Minibatch Loss= 0.013574, Training Accuracy= 1.00000
# Iter 259200, Minibatch Loss= 0.091168, Training Accuracy= 0.93750
# Iter 260800, Minibatch Loss= 0.014725, Training Accuracy= 1.00000
# Iter 262400, Minibatch Loss= 0.011187, Training Accuracy= 1.00000
# Iter 264000, Minibatch Loss= 0.002847, Training Accuracy= 1.00000
# Iter 265600, Minibatch Loss= 0.009930, Training Accuracy= 1.00000
# Iter 267200, Minibatch Loss= 0.090875, Training Accuracy= 1.00000
# Iter 268800, Minibatch Loss= 0.239692, Training Accuracy= 0.93750
# Iter 270400, Minibatch Loss= 0.005965, Training Accuracy= 1.00000
# Iter 272000, Minibatch Loss= 0.076616, Training Accuracy= 1.00000
# Iter 273600, Minibatch Loss= 0.075833, Training Accuracy= 1.00000
# Iter 275200, Minibatch Loss= 0.024463, Training Accuracy= 1.00000
# Iter 276800, Minibatch Loss= 0.529477, Training Accuracy= 0.87500
# Iter 278400, Minibatch Loss= 0.042355, Training Accuracy= 1.00000
# Iter 280000, Minibatch Loss= 0.011175, Training Accuracy= 1.00000
# Iter 281600, Minibatch Loss= 0.002747, Training Accuracy= 1.00000
# Iter 283200, Minibatch Loss= 0.054404, Training Accuracy= 1.00000
# Iter 284800, Minibatch Loss= 0.017863, Training Accuracy= 1.00000
# Iter 286400, Minibatch Loss= 0.161701, Training Accuracy= 0.93750
# Iter 288000, Minibatch Loss= 0.037331, Training Accuracy= 1.00000
# Iter 289600, Minibatch Loss= 0.010561, Training Accuracy= 1.00000
# Iter 291200, Minibatch Loss= 0.003188, Training Accuracy= 1.00000
# Iter 292800, Minibatch Loss= 0.034454, Training Accuracy= 1.00000
# Iter 294400, Minibatch Loss= 0.269832, Training Accuracy= 0.93750
# Iter 296000, Minibatch Loss= 0.098157, Training Accuracy= 0.93750
# Iter 297600, Minibatch Loss= 0.070051, Training Accuracy= 1.00000
# Iter 299200, Minibatch Loss= 0.134388, Training Accuracy= 0.93750
# Iter 300800, Minibatch Loss= 0.018424, Training Accuracy= 1.00000
# Iter 302400, Minibatch Loss= 0.123162, Training Accuracy= 0.93750
# Iter 304000, Minibatch Loss= 0.271764, Training Accuracy= 0.93750
# Iter 305600, Minibatch Loss= 0.018130, Training Accuracy= 1.00000
# Iter 307200, Minibatch Loss= 0.385844, Training Accuracy= 0.93750
# Iter 308800, Minibatch Loss= 0.000980, Training Accuracy= 1.00000
# Iter 310400, Minibatch Loss= 0.014136, Training Accuracy= 1.00000
# Iter 312000, Minibatch Loss= 0.035090, Training Accuracy= 1.00000
# Iter 313600, Minibatch Loss= 0.006457, Training Accuracy= 1.00000
# Iter 315200, Minibatch Loss= 0.001081, Training Accuracy= 1.00000
# Iter 316800, Minibatch Loss= 0.007615, Training Accuracy= 1.00000
# Iter 318400, Minibatch Loss= 0.022956, Training Accuracy= 1.00000
# Iter 320000, Minibatch Loss= 0.006028, Training Accuracy= 1.00000
# Iter 321600, Minibatch Loss= 0.018617, Training Accuracy= 1.00000
# Iter 323200, Minibatch Loss= 0.001376, Training Accuracy= 1.00000
# Iter 324800, Minibatch Loss= 0.006045, Training Accuracy= 1.00000
# Iter 326400, Minibatch Loss= 0.000810, Training Accuracy= 1.00000
# Iter 328000, Minibatch Loss= 0.005405, Training Accuracy= 1.00000
# Iter 329600, Minibatch Loss= 0.014491, Training Accuracy= 1.00000
# Iter 331200, Minibatch Loss= 0.004004, Training Accuracy= 1.00000
# Iter 332800, Minibatch Loss= 0.007176, Training Accuracy= 1.00000
# Iter 334400, Minibatch Loss= 0.348503, Training Accuracy= 0.87500
# Iter 336000, Minibatch Loss= 0.010498, Training Accuracy= 1.00000
# Iter 337600, Minibatch Loss= 0.000576, Training Accuracy= 1.00000
# Iter 339200, Minibatch Loss= 0.040008, Training Accuracy= 1.00000
# Iter 340800, Minibatch Loss= 0.014503, Training Accuracy= 1.00000
# Iter 342400, Minibatch Loss= 0.003043, Training Accuracy= 1.00000
# Iter 344000, Minibatch Loss= 0.014903, Training Accuracy= 1.00000
# Iter 345600, Minibatch Loss= 0.004680, Training Accuracy= 1.00000
# Iter 347200, Minibatch Loss= 0.011840, Training Accuracy= 1.00000
# Iter 348800, Minibatch Loss= 0.048684, Training Accuracy= 1.00000
# Iter 350400, Minibatch Loss= 0.014494, Training Accuracy= 1.00000
# Iter 352000, Minibatch Loss= 0.008924, Training Accuracy= 1.00000
# Iter 353600, Minibatch Loss= 0.004298, Training Accuracy= 1.00000
# Iter 355200, Minibatch Loss= 0.095246, Training Accuracy= 0.93750
# Iter 356800, Minibatch Loss= 0.090001, Training Accuracy= 0.93750
# Iter 358400, Minibatch Loss= 0.003509, Training Accuracy= 1.00000
# Iter 360000, Minibatch Loss= 0.000499, Training Accuracy= 1.00000
# Iter 361600, Minibatch Loss= 0.016636, Training Accuracy= 1.00000
# Iter 363200, Minibatch Loss= 0.010956, Training Accuracy= 1.00000
# Iter 364800, Minibatch Loss= 0.011444, Training Accuracy= 1.00000
# Iter 366400, Minibatch Loss= 0.012505, Training Accuracy= 1.00000
# Iter 368000, Minibatch Loss= 0.017623, Training Accuracy= 1.00000
# Iter 369600, Minibatch Loss= 0.009581, Training Accuracy= 1.00000
# Iter 371200, Minibatch Loss= 0.047626, Training Accuracy= 1.00000
# Iter 372800, Minibatch Loss= 0.003115, Training Accuracy= 1.00000
# Iter 374400, Minibatch Loss= 0.036464, Training Accuracy= 1.00000
# Iter 376000, Minibatch Loss= 0.004227, Training Accuracy= 1.00000
# Iter 377600, Minibatch Loss= 0.040920, Training Accuracy= 1.00000
# Iter 379200, Minibatch Loss= 0.034595, Training Accuracy= 1.00000
# Iter 380800, Minibatch Loss= 0.019797, Training Accuracy= 1.00000
# Iter 382400, Minibatch Loss= 0.009325, Training Accuracy= 1.00000
# Iter 384000, Minibatch Loss= 0.008933, Training Accuracy= 1.00000
# Iter 385600, Minibatch Loss= 0.191452, Training Accuracy= 0.93750
# Iter 387200, Minibatch Loss= 0.002104, Training Accuracy= 1.00000
# Iter 388800, Minibatch Loss= 0.002970, Training Accuracy= 1.00000
# Iter 390400, Minibatch Loss= 0.039318, Training Accuracy= 1.00000
# Iter 392000, Minibatch Loss= 0.009321, Training Accuracy= 1.00000
# Iter 393600, Minibatch Loss= 0.002295, Training Accuracy= 1.00000
# Iter 395200, Minibatch Loss= 0.003939, Training Accuracy= 1.00000
# Iter 396800, Minibatch Loss= 0.186385, Training Accuracy= 0.87500
# Iter 398400, Minibatch Loss= 0.013709, Training Accuracy= 1.00000
# Iter 400000, Minibatch Loss= 0.001563, Training Accuracy= 1.00000
# Iter 401600, Minibatch Loss= 0.000402, Training Accuracy= 1.00000
# Iter 403200, Minibatch Loss= 0.290654, Training Accuracy= 0.93750
# Iter 404800, Minibatch Loss= 0.448568, Training Accuracy= 0.87500
# Iter 406400, Minibatch Loss= 0.001010, Training Accuracy= 1.00000
# Iter 408000, Minibatch Loss= 0.000212, Training Accuracy= 1.00000
# Iter 409600, Minibatch Loss= 0.001475, Training Accuracy= 1.00000
# Iter 411200, Minibatch Loss= 0.078101, Training Accuracy= 0.93750
# Iter 412800, Minibatch Loss= 0.027262, Training Accuracy= 1.00000
# Iter 414400, Minibatch Loss= 0.012669, Training Accuracy= 1.00000
# Iter 416000, Minibatch Loss= 0.000665, Training Accuracy= 1.00000
# Iter 417600, Minibatch Loss= 0.029017, Training Accuracy= 1.00000
# Iter 419200, Minibatch Loss= 0.001590, Training Accuracy= 1.00000
# Iter 420800, Minibatch Loss= 0.014564, Training Accuracy= 1.00000
# Iter 422400, Minibatch Loss= 0.001941, Training Accuracy= 1.00000
# Iter 424000, Minibatch Loss= 0.072389, Training Accuracy= 1.00000
# Iter 425600, Minibatch Loss= 0.002911, Training Accuracy= 1.00000
# Iter 427200, Minibatch Loss= 0.000810, Training Accuracy= 1.00000
# Iter 428800, Minibatch Loss= 0.006803, Training Accuracy= 1.00000
# Iter 430400, Minibatch Loss= 0.000092, Training Accuracy= 1.00000
# Iter 432000, Minibatch Loss= 0.018411, Training Accuracy= 1.00000
# Iter 433600, Minibatch Loss= 0.025259, Training Accuracy= 1.00000
# Iter 435200, Minibatch Loss= 0.019765, Training Accuracy= 1.00000
# Iter 436800, Minibatch Loss= 0.005218, Training Accuracy= 1.00000
# Iter 438400, Minibatch Loss= 0.008758, Training Accuracy= 1.00000
# Iter 440000, Minibatch Loss= 0.061887, Training Accuracy= 1.00000
# Iter 441600, Minibatch Loss= 0.001415, Training Accuracy= 1.00000
# Iter 443200, Minibatch Loss= 0.455547, Training Accuracy= 0.93750
# Iter 444800, Minibatch Loss= 0.022883, Training Accuracy= 1.00000
# Iter 446400, Minibatch Loss= 0.222172, Training Accuracy= 0.93750
# Iter 448000, Minibatch Loss= 0.000476, Training Accuracy= 1.00000
# Iter 449600, Minibatch Loss= 0.000414, Training Accuracy= 1.00000
# Iter 451200, Minibatch Loss= 0.003703, Training Accuracy= 1.00000
# Iter 452800, Minibatch Loss= 0.016204, Training Accuracy= 1.00000
# Iter 454400, Minibatch Loss= 0.002992, Training Accuracy= 1.00000
# Iter 456000, Minibatch Loss= 0.001514, Training Accuracy= 1.00000
# Iter 457600, Minibatch Loss= 0.007243, Training Accuracy= 1.00000
# Iter 459200, Minibatch Loss= 0.097899, Training Accuracy= 0.93750
# Iter 460800, Minibatch Loss= 0.000124, Training Accuracy= 1.00000
# Iter 462400, Minibatch Loss= 0.001117, Training Accuracy= 1.00000
# Iter 464000, Minibatch Loss= 0.026025, Training Accuracy= 1.00000
# Iter 465600, Minibatch Loss= 0.000496, Training Accuracy= 1.00000
# Iter 467200, Minibatch Loss= 0.325408, Training Accuracy= 0.93750
# Iter 468800, Minibatch Loss= 0.016075, Training Accuracy= 1.00000
# Iter 470400, Minibatch Loss= 0.009822, Training Accuracy= 1.00000
# Iter 472000, Minibatch Loss= 0.001196, Training Accuracy= 1.00000
# Iter 473600, Minibatch Loss= 0.001159, Training Accuracy= 1.00000
# Iter 475200, Minibatch Loss= 0.587540, Training Accuracy= 0.93750
# Iter 476800, Minibatch Loss= 0.001848, Training Accuracy= 1.00000
# Iter 478400, Minibatch Loss= 0.000908, Training Accuracy= 1.00000
# Iter 480000, Minibatch Loss= 0.020616, Training Accuracy= 1.00000
# Iter 481600, Minibatch Loss= 0.083575, Training Accuracy= 0.93750
# Iter 483200, Minibatch Loss= 0.002745, Training Accuracy= 1.00000
# Iter 484800, Minibatch Loss= 0.002092, Training Accuracy= 1.00000
# Iter 486400, Minibatch Loss= 0.193770, Training Accuracy= 0.93750
# Iter 488000, Minibatch Loss= 0.000008, Training Accuracy= 1.00000
# Iter 489600, Minibatch Loss= 0.009800, Training Accuracy= 1.00000
# Iter 491200, Minibatch Loss= 0.001181, Training Accuracy= 1.00000
# Iter 492800, Minibatch Loss= 0.292264, Training Accuracy= 0.93750
# Iter 494400, Minibatch Loss= 0.000903, Training Accuracy= 1.00000
# Iter 496000, Minibatch Loss= 0.065569, Training Accuracy= 1.00000
# Iter 497600, Minibatch Loss= 0.027515, Training Accuracy= 1.00000
# Iter 499200, Minibatch Loss= 0.000884, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.953044

# %%
saver.save(sess, '../Model/NIN-Model-0504')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', '1', 'd', '7', 's', '2', 'y', 'p', 'i', '9', 'q', 'w', 'n', 'c', '3', 'g', 'v', 'a', 'you', 't', '8', 'u', 'x', '6', 'h', 'what', 'e', '5', 'o', '4', 'f', 'non', 'm', 'b', 'r', 'l', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
