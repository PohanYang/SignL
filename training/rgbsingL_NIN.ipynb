# %%
import numpy as np
import random
import os
import glob
import tensorflow as tf
import math
import pickle
#import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

# %%
loadname = '../../class/t619.p'
class signLClass:
        def __init__(self):
                self.data = [np.zeros(1),np.zeros(1)]
                self.testdata = [np.zeros(1),np.zeros(1)]
                self.labels = []
                self.testlabels = []
                self.first = True
                self.testfirst = True
        def add_image(self, image, label):
                if self.first == False:
                        tmp_image = self.data[1]
                        tmp_label = self.data[0]
                self.data[1] = image
                self.data[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.first == False:
                        self.data[1] = np.vstack((tmp_image, self.data[1]))
                        self.data[0] = np.vstack((tmp_label, self.data[0]))
                self.first = False
        def add_test_image(self, image, label):
                if self.testfirst == False:
                        tmp_image = self.testdata[1]
                        tmp_label = self.testdata[0]
                self.testdata[1] = image
                self.testdata[0] = label
                #self.data[1] = np.reshape(self.data[1], [-1, 50, 60, 3])
                #self.data[0] = self.data[0].reshape((1,kind))
                if self.testfirst == False:
                        self.testdata[1] = np.vstack((tmp_image, self.testdata[1]))
                        self.testdata[0] = np.vstack((tmp_label, self.testdata[0]))
                self.testfirst = False
        def train(self, n, batch_size):
                return signL.data[1][n:n+batch_size]
        def label(self, n, batch_size):
                return signL.data[0][n:n+batch_size]

def load_class(signL, loadname):
    signL = pickle.load(open(loadname, "rb"))
    return signL
signL = signLClass()
signL = load_class(signL, loadname)
print "Training data class named 'signL'. "
# Out:
# Training data class named 'signL'.

# %%
print signL.data[0].shape
# Out:
# (142165, 55)

# %%
# Parameters
learning_rate = 0.001
training_iters = 1600000
batch_size = 16
display_step = 100
SEED = 448

# Network Parameters
n_input = 9000 # MNIST data input (img shape: 50*60*3)
n_classes = len(signL.labels) # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# %%
def weight_variable(shape):
    initial = tf.random_normal(shape, stddev=0.05, dtype=tf.float32)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0, shape=shape,dtype=tf.float32)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_3x3(x):
    return tf.nn.max_pool(x, ksize=[1,3,3,1], strides=[1,2,2,1], padding='SAME')

# %%
x = tf.placeholder(tf.float32, [None, 50, 60, 3], name = 'placeholder_x')
#x_28 = tf.reshape(x, shape=[-1, 28, 28, 3])
x_28 = tf.image.resize_images(x, [28,28])

y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32, name = 'keep_prob') #dropout (keep probability)
#x_image = tf.reshape(x, [-1, 28, 28, 1])

W_conv1 = weight_variable([5,5, 3, 192])
b_conv1 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(x_28, W_conv1) + b_conv1)
## MLP-1-1##
W_MLP11 = weight_variable([1,1, 192, 160])
b_MLP11 = bias_variable([160])
output = tf.nn.relu(conv2d(output, W_MLP11) + b_MLP11)
## MLP-1-2##
W_MLP12 = weight_variable([1,1, 160, 96])
b_MLP12 = bias_variable([96])
output = tf.nn.relu(conv2d(output, W_MLP12) + b_MLP12)
##Max pooling##
output = max_pool_3x3(output)                     
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv2 layer ##
W_conv2 = weight_variable([5,5, 96, 192])
b_conv2 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv2) + b_conv2)
## MLP-2-1##
W_MLP21 = weight_variable([1,1, 192, 192])
b_MLP21 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP21) + b_MLP21)
## MLP-2-2##
W_MLP22 = weight_variable([1,1, 192, 192])
b_MLP22 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP22) + b_MLP22)
##Max pooling##
output = max_pool_3x3(output)    
## dropout ##
output = tf.nn.dropout(output, keep_prob)

## conv3 layer ##
W_conv3 = weight_variable([3,3, 192, 192])
b_conv3 = tf.Variable(tf.random_normal([192], stddev=0.01, dtype=tf.float32), name = 'Variable')
output = tf.nn.relu(conv2d(output, W_conv3) + b_conv3)
## MLP-2-1##
W_MLP31 = weight_variable([1,1, 192, 192])
b_MLP31 = bias_variable([192])
output = tf.nn.relu(conv2d(output, W_MLP31) + b_MLP31)
## MLP-2-2##
W_MLP32 = weight_variable([1,1, 192, n_classes])
b_MLP32 = bias_variable([n_classes])
output = tf.nn.relu(conv2d(output, W_MLP32) + b_MLP32)
##global average##
output = tf.nn.avg_pool(output, ksize=[1,7,7,1], strides=[1,1,1,1], padding='VALID')
# [n_samples, 1, 1, 10] ->> [n_samples, 1*1*10]

with tf.name_scope("pred"):
    output = tf.reshape(output, [-1, 1*1*n_classes])

# %%
#this code demostrate how to schedule step-wise learning rate in a simple way
learning_rate = tf.placeholder(tf.float32)
# the loss function 
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=output))
# optimizer Adam
train_step = tf.train.AdamOptimizer(learning_rate, 0.9).minimize(cross_entropy)
# prediction
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
trainset = ['signL','signL2.p']

# %%
# Initializing the variables
init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()
sess=tf.Session()
sess.run(init)
step = 1
bloss = 0
br=0
while step * batch_size < training_iters:
    batch_xs = signL.train(step, batch_size)
    batch_ys = signL.label(step, batch_size)
    sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.4, learning_rate: 1e-5})
    if step % display_step == 0:
        # Calculate batch accuracy
        acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        # Calculate batch loss
        loss = sess.run(cross_entropy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
        print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc)
        if(loss>bloss):
            br+=1
        else:
            br = 0
        bloss = loss
        if(br==8):
            break;
    step += 1
print "Optimization Finished!"
# Test model
test_images = signL.testdata[1]
test_labels = signL.testdata[0]
# Calculate accuracy for 256 mnist test images
print "Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_images, y: test_labels, keep_prob: 1.})
# Out:
# Iter 1600, Minibatch Loss= 3.976053, Training Accuracy= 0.06250
# Iter 3200, Minibatch Loss= 3.950017, Training Accuracy= 0.06250
# Iter 4800, Minibatch Loss= 3.885298, Training Accuracy= 0.06250
# Iter 6400, Minibatch Loss= 3.927711, Training Accuracy= 0.06250
# Iter 8000, Minibatch Loss= 3.830426, Training Accuracy= 0.06250
# Iter 9600, Minibatch Loss= 3.811371, Training Accuracy= 0.06250
# Iter 11200, Minibatch Loss= 3.783754, Training Accuracy= 0.18750
# Iter 12800, Minibatch Loss= 3.895732, Training Accuracy= 0.12500
# Iter 14400, Minibatch Loss= 3.977774, Training Accuracy= 0.00000
# Iter 16000, Minibatch Loss= 3.903624, Training Accuracy= 0.06250
# Iter 17600, Minibatch Loss= 4.019162, Training Accuracy= 0.00000
# Iter 19200, Minibatch Loss= 3.865272, Training Accuracy= 0.00000
# Iter 20800, Minibatch Loss= 3.843069, Training Accuracy= 0.12500
# Iter 22400, Minibatch Loss= 3.869997, Training Accuracy= 0.06250
# Iter 24000, Minibatch Loss= 3.865931, Training Accuracy= 0.06250
# Iter 25600, Minibatch Loss= 3.998080, Training Accuracy= 0.06250
# Iter 27200, Minibatch Loss= 3.933761, Training Accuracy= 0.00000
# Iter 28800, Minibatch Loss= 3.835874, Training Accuracy= 0.06250
# Iter 30400, Minibatch Loss= 3.925684, Training Accuracy= 0.06250
# Iter 32000, Minibatch Loss= 3.874063, Training Accuracy= 0.12500
# Iter 33600, Minibatch Loss= 4.000304, Training Accuracy= 0.06250
# Iter 35200, Minibatch Loss= 3.950000, Training Accuracy= 0.06250
# Iter 36800, Minibatch Loss= 3.893974, Training Accuracy= 0.06250
# Iter 38400, Minibatch Loss= 3.867613, Training Accuracy= 0.00000
# Iter 40000, Minibatch Loss= 3.950721, Training Accuracy= 0.00000
# Iter 41600, Minibatch Loss= 3.931833, Training Accuracy= 0.06250
# Iter 43200, Minibatch Loss= 3.812458, Training Accuracy= 0.00000
# Iter 44800, Minibatch Loss= 3.867499, Training Accuracy= 0.12500
# Iter 46400, Minibatch Loss= 3.808156, Training Accuracy= 0.00000
# Iter 48000, Minibatch Loss= 3.911518, Training Accuracy= 0.00000
# Iter 49600, Minibatch Loss= 3.829538, Training Accuracy= 0.06250
# Iter 51200, Minibatch Loss= 3.770566, Training Accuracy= 0.12500
# Iter 52800, Minibatch Loss= 3.862703, Training Accuracy= 0.00000
# Iter 54400, Minibatch Loss= 3.851645, Training Accuracy= 0.18750
# Iter 56000, Minibatch Loss= 3.834236, Training Accuracy= 0.12500
# Iter 57600, Minibatch Loss= 3.860528, Training Accuracy= 0.06250
# Iter 59200, Minibatch Loss= 3.888095, Training Accuracy= 0.00000
# Iter 60800, Minibatch Loss= 3.789083, Training Accuracy= 0.12500
# Iter 62400, Minibatch Loss= 3.816381, Training Accuracy= 0.12500
# Iter 64000, Minibatch Loss= 4.029798, Training Accuracy= 0.00000
# Iter 65600, Minibatch Loss= 3.930035, Training Accuracy= 0.00000
# Iter 67200, Minibatch Loss= 3.831983, Training Accuracy= 0.00000
# Iter 68800, Minibatch Loss= 3.759462, Training Accuracy= 0.00000
# Iter 70400, Minibatch Loss= 3.767876, Training Accuracy= 0.18750
# Iter 72000, Minibatch Loss= 3.793835, Training Accuracy= 0.06250
# Iter 73600, Minibatch Loss= 3.688320, Training Accuracy= 0.18750
# Iter 75200, Minibatch Loss= 3.905917, Training Accuracy= 0.12500
# Iter 76800, Minibatch Loss= 3.606498, Training Accuracy= 0.06250
# Iter 78400, Minibatch Loss= 3.844093, Training Accuracy= 0.06250
# Iter 80000, Minibatch Loss= 3.652476, Training Accuracy= 0.12500
# Iter 81600, Minibatch Loss= 3.661998, Training Accuracy= 0.06250
# Iter 83200, Minibatch Loss= 3.780009, Training Accuracy= 0.00000
# Iter 84800, Minibatch Loss= 3.837792, Training Accuracy= 0.00000
# Iter 86400, Minibatch Loss= 3.785006, Training Accuracy= 0.00000
# Iter 88000, Minibatch Loss= 3.536603, Training Accuracy= 0.12500
# Iter 89600, Minibatch Loss= 3.745645, Training Accuracy= 0.06250
# Iter 91200, Minibatch Loss= 3.670765, Training Accuracy= 0.25000
# Iter 92800, Minibatch Loss= 3.623314, Training Accuracy= 0.06250
# Iter 94400, Minibatch Loss= 3.866763, Training Accuracy= 0.00000
# Iter 96000, Minibatch Loss= 3.619367, Training Accuracy= 0.06250
# Iter 97600, Minibatch Loss= 3.719406, Training Accuracy= 0.06250
# Iter 99200, Minibatch Loss= 3.665831, Training Accuracy= 0.06250
# Iter 100800, Minibatch Loss= 3.405388, Training Accuracy= 0.06250
# Iter 102400, Minibatch Loss= 3.601116, Training Accuracy= 0.12500
# Iter 104000, Minibatch Loss= 3.547134, Training Accuracy= 0.18750
# Iter 105600, Minibatch Loss= 3.363050, Training Accuracy= 0.18750
# Iter 107200, Minibatch Loss= 3.443341, Training Accuracy= 0.25000
# Iter 108800, Minibatch Loss= 3.592851, Training Accuracy= 0.25000
# Iter 110400, Minibatch Loss= 3.605804, Training Accuracy= 0.12500
# Iter 112000, Minibatch Loss= 3.526238, Training Accuracy= 0.12500
# Iter 113600, Minibatch Loss= 3.515719, Training Accuracy= 0.18750
# Iter 115200, Minibatch Loss= 3.754902, Training Accuracy= 0.12500
# Iter 116800, Minibatch Loss= 3.450001, Training Accuracy= 0.12500
# Iter 118400, Minibatch Loss= 3.605706, Training Accuracy= 0.06250
# Iter 120000, Minibatch Loss= 3.717069, Training Accuracy= 0.18750
# Iter 121600, Minibatch Loss= 3.796963, Training Accuracy= 0.00000
# Iter 123200, Minibatch Loss= 3.580945, Training Accuracy= 0.06250
# Iter 124800, Minibatch Loss= 3.566810, Training Accuracy= 0.31250
# Iter 126400, Minibatch Loss= 3.459295, Training Accuracy= 0.12500
# Iter 128000, Minibatch Loss= 3.166229, Training Accuracy= 0.31250
# Iter 129600, Minibatch Loss= 3.735129, Training Accuracy= 0.18750
# Iter 131200, Minibatch Loss= 3.217005, Training Accuracy= 0.12500
# Iter 132800, Minibatch Loss= 3.428746, Training Accuracy= 0.25000
# Iter 134400, Minibatch Loss= 3.509494, Training Accuracy= 0.12500
# Iter 136000, Minibatch Loss= 2.906085, Training Accuracy= 0.25000
# Iter 137600, Minibatch Loss= 3.255800, Training Accuracy= 0.06250
# Iter 139200, Minibatch Loss= 3.554639, Training Accuracy= 0.12500
# Iter 140800, Minibatch Loss= 3.079590, Training Accuracy= 0.25000
# Iter 142400, Minibatch Loss= 3.313164, Training Accuracy= 0.06250
# Iter 144000, Minibatch Loss= 2.919943, Training Accuracy= 0.18750
# Iter 145600, Minibatch Loss= 3.228796, Training Accuracy= 0.12500
# Iter 147200, Minibatch Loss= 3.260781, Training Accuracy= 0.06250
# Iter 148800, Minibatch Loss= 2.925298, Training Accuracy= 0.12500
# Iter 150400, Minibatch Loss= 3.348919, Training Accuracy= 0.12500
# Iter 152000, Minibatch Loss= 2.513820, Training Accuracy= 0.37500
# Iter 153600, Minibatch Loss= 3.243883, Training Accuracy= 0.18750
# Iter 155200, Minibatch Loss= 2.779826, Training Accuracy= 0.43750
# Iter 156800, Minibatch Loss= 2.806260, Training Accuracy= 0.25000
# Iter 158400, Minibatch Loss= 2.638154, Training Accuracy= 0.31250
# Iter 160000, Minibatch Loss= 3.012659, Training Accuracy= 0.25000
# Iter 161600, Minibatch Loss= 3.217350, Training Accuracy= 0.18750
# Iter 163200, Minibatch Loss= 3.516382, Training Accuracy= 0.12500
# Iter 164800, Minibatch Loss= 2.929798, Training Accuracy= 0.25000
# Iter 166400, Minibatch Loss= 2.580988, Training Accuracy= 0.31250
# Iter 168000, Minibatch Loss= 2.994794, Training Accuracy= 0.06250
# Iter 169600, Minibatch Loss= 2.646172, Training Accuracy= 0.37500
# Iter 171200, Minibatch Loss= 2.048754, Training Accuracy= 0.31250
# Iter 172800, Minibatch Loss= 2.980821, Training Accuracy= 0.18750
# Iter 174400, Minibatch Loss= 2.739550, Training Accuracy= 0.25000
# Iter 176000, Minibatch Loss= 2.787595, Training Accuracy= 0.25000
# Iter 177600, Minibatch Loss= 2.530772, Training Accuracy= 0.31250
# Iter 179200, Minibatch Loss= 2.435766, Training Accuracy= 0.37500
# Iter 180800, Minibatch Loss= 2.598082, Training Accuracy= 0.31250
# Iter 182400, Minibatch Loss= 2.245188, Training Accuracy= 0.43750
# Iter 184000, Minibatch Loss= 2.939095, Training Accuracy= 0.25000
# Iter 185600, Minibatch Loss= 2.766315, Training Accuracy= 0.25000
# Iter 187200, Minibatch Loss= 2.500863, Training Accuracy= 0.37500
# Iter 188800, Minibatch Loss= 2.474655, Training Accuracy= 0.31250
# Iter 190400, Minibatch Loss= 2.311530, Training Accuracy= 0.31250
# Iter 192000, Minibatch Loss= 2.048591, Training Accuracy= 0.37500
# Iter 193600, Minibatch Loss= 2.450355, Training Accuracy= 0.31250
# Iter 195200, Minibatch Loss= 2.738461, Training Accuracy= 0.25000
# Iter 196800, Minibatch Loss= 3.042807, Training Accuracy= 0.18750
# Iter 198400, Minibatch Loss= 2.589052, Training Accuracy= 0.37500
# Iter 200000, Minibatch Loss= 2.595578, Training Accuracy= 0.31250
# Iter 201600, Minibatch Loss= 2.704057, Training Accuracy= 0.31250
# Iter 203200, Minibatch Loss= 2.215002, Training Accuracy= 0.37500
# Iter 204800, Minibatch Loss= 2.659246, Training Accuracy= 0.37500
# Iter 206400, Minibatch Loss= 2.440024, Training Accuracy= 0.25000
# Iter 208000, Minibatch Loss= 2.408885, Training Accuracy= 0.37500
# Iter 209600, Minibatch Loss= 2.170102, Training Accuracy= 0.31250
# Iter 211200, Minibatch Loss= 3.240263, Training Accuracy= 0.18750
# Iter 212800, Minibatch Loss= 2.884222, Training Accuracy= 0.18750
# Iter 214400, Minibatch Loss= 2.517231, Training Accuracy= 0.25000
# Iter 216000, Minibatch Loss= 2.319935, Training Accuracy= 0.25000
# Iter 217600, Minibatch Loss= 2.415920, Training Accuracy= 0.43750
# Iter 219200, Minibatch Loss= 2.042194, Training Accuracy= 0.43750
# Iter 220800, Minibatch Loss= 2.552551, Training Accuracy= 0.43750
# Iter 222400, Minibatch Loss= 2.494853, Training Accuracy= 0.50000
# Iter 224000, Minibatch Loss= 2.308340, Training Accuracy= 0.31250
# Iter 225600, Minibatch Loss= 2.086889, Training Accuracy= 0.43750
# Iter 227200, Minibatch Loss= 2.343759, Training Accuracy= 0.43750
# Iter 228800, Minibatch Loss= 2.170443, Training Accuracy= 0.43750
# Iter 230400, Minibatch Loss= 2.422580, Training Accuracy= 0.31250
# Iter 232000, Minibatch Loss= 2.083647, Training Accuracy= 0.56250
# Iter 233600, Minibatch Loss= 1.970075, Training Accuracy= 0.25000
# Iter 235200, Minibatch Loss= 2.322355, Training Accuracy= 0.37500
# Iter 236800, Minibatch Loss= 2.273821, Training Accuracy= 0.25000
# Iter 238400, Minibatch Loss= 2.068879, Training Accuracy= 0.50000
# Iter 240000, Minibatch Loss= 3.006289, Training Accuracy= 0.31250
# Iter 241600, Minibatch Loss= 1.394665, Training Accuracy= 0.50000
# Iter 243200, Minibatch Loss= 2.572174, Training Accuracy= 0.50000
# Iter 244800, Minibatch Loss= 1.775759, Training Accuracy= 0.56250
# Iter 246400, Minibatch Loss= 1.862850, Training Accuracy= 0.56250
# Iter 248000, Minibatch Loss= 2.697991, Training Accuracy= 0.37500
# Iter 249600, Minibatch Loss= 2.062558, Training Accuracy= 0.25000
# Iter 251200, Minibatch Loss= 2.081482, Training Accuracy= 0.50000
# Iter 252800, Minibatch Loss= 1.925090, Training Accuracy= 0.37500
# Iter 254400, Minibatch Loss= 1.983507, Training Accuracy= 0.37500
# Iter 256000, Minibatch Loss= 1.827675, Training Accuracy= 0.43750
# Iter 257600, Minibatch Loss= 2.131610, Training Accuracy= 0.43750
# Iter 259200, Minibatch Loss= 2.274950, Training Accuracy= 0.31250
# Iter 260800, Minibatch Loss= 1.567307, Training Accuracy= 0.50000
# Iter 262400, Minibatch Loss= 2.643780, Training Accuracy= 0.37500
# Iter 264000, Minibatch Loss= 1.720670, Training Accuracy= 0.37500
# Iter 265600, Minibatch Loss= 2.161797, Training Accuracy= 0.56250
# Iter 267200, Minibatch Loss= 1.433911, Training Accuracy= 0.56250
# Iter 268800, Minibatch Loss= 1.503151, Training Accuracy= 0.62500
# Iter 270400, Minibatch Loss= 2.564548, Training Accuracy= 0.43750
# Iter 272000, Minibatch Loss= 1.581313, Training Accuracy= 0.62500
# Iter 273600, Minibatch Loss= 1.843690, Training Accuracy= 0.50000
# Iter 275200, Minibatch Loss= 2.779347, Training Accuracy= 0.31250
# Iter 276800, Minibatch Loss= 1.977004, Training Accuracy= 0.43750
# Iter 278400, Minibatch Loss= 2.309439, Training Accuracy= 0.37500
# Iter 280000, Minibatch Loss= 1.715852, Training Accuracy= 0.50000
# Iter 281600, Minibatch Loss= 1.411248, Training Accuracy= 0.56250
# Iter 283200, Minibatch Loss= 1.591954, Training Accuracy= 0.56250
# Iter 284800, Minibatch Loss= 1.153945, Training Accuracy= 0.50000
# Iter 286400, Minibatch Loss= 1.169222, Training Accuracy= 0.62500
# Iter 288000, Minibatch Loss= 1.482244, Training Accuracy= 0.62500
# Iter 289600, Minibatch Loss= 1.262858, Training Accuracy= 0.62500
# Iter 291200, Minibatch Loss= 1.985118, Training Accuracy= 0.43750
# Iter 292800, Minibatch Loss= 1.695939, Training Accuracy= 0.62500
# Iter 294400, Minibatch Loss= 1.006542, Training Accuracy= 0.75000
# Iter 296000, Minibatch Loss= 1.246145, Training Accuracy= 0.68750
# Iter 297600, Minibatch Loss= 1.648543, Training Accuracy= 0.50000
# Iter 299200, Minibatch Loss= 1.795004, Training Accuracy= 0.50000
# Iter 300800, Minibatch Loss= 2.538834, Training Accuracy= 0.50000
# Iter 302400, Minibatch Loss= 2.242680, Training Accuracy= 0.37500
# Iter 304000, Minibatch Loss= 1.387857, Training Accuracy= 0.37500
# Iter 305600, Minibatch Loss= 1.547395, Training Accuracy= 0.68750
# Iter 307200, Minibatch Loss= 1.224440, Training Accuracy= 0.56250
# Iter 308800, Minibatch Loss= 1.474825, Training Accuracy= 0.37500
# Iter 310400, Minibatch Loss= 1.455881, Training Accuracy= 0.62500
# Iter 312000, Minibatch Loss= 0.904196, Training Accuracy= 0.81250
# Iter 313600, Minibatch Loss= 1.106486, Training Accuracy= 0.68750
# Iter 315200, Minibatch Loss= 1.936627, Training Accuracy= 0.50000
# Iter 316800, Minibatch Loss= 0.957395, Training Accuracy= 0.75000
# Iter 318400, Minibatch Loss= 1.364897, Training Accuracy= 0.68750
# Iter 320000, Minibatch Loss= 1.316785, Training Accuracy= 0.81250
# Iter 321600, Minibatch Loss= 0.654679, Training Accuracy= 0.75000
# Iter 323200, Minibatch Loss= 1.984738, Training Accuracy= 0.56250
# Iter 324800, Minibatch Loss= 1.611959, Training Accuracy= 0.56250
# Iter 326400, Minibatch Loss= 1.155081, Training Accuracy= 0.62500
# Iter 328000, Minibatch Loss= 1.185381, Training Accuracy= 0.68750
# Iter 329600, Minibatch Loss= 2.998419, Training Accuracy= 0.43750
# Iter 331200, Minibatch Loss= 1.143923, Training Accuracy= 0.56250
# Iter 332800, Minibatch Loss= 1.361341, Training Accuracy= 0.50000
# Iter 334400, Minibatch Loss= 1.570315, Training Accuracy= 0.43750
# Iter 336000, Minibatch Loss= 1.837109, Training Accuracy= 0.62500
# Iter 337600, Minibatch Loss= 1.487389, Training Accuracy= 0.56250
# Iter 339200, Minibatch Loss= 1.455675, Training Accuracy= 0.62500
# Iter 340800, Minibatch Loss= 1.148112, Training Accuracy= 0.68750
# Iter 342400, Minibatch Loss= 1.154284, Training Accuracy= 0.62500
# Iter 344000, Minibatch Loss= 1.465531, Training Accuracy= 0.62500
# Iter 345600, Minibatch Loss= 0.681177, Training Accuracy= 0.81250
# Iter 347200, Minibatch Loss= 0.586144, Training Accuracy= 0.75000
# Iter 348800, Minibatch Loss= 1.095988, Training Accuracy= 0.50000
# Iter 350400, Minibatch Loss= 1.105573, Training Accuracy= 0.56250
# Iter 352000, Minibatch Loss= 0.927982, Training Accuracy= 0.68750
# Iter 353600, Minibatch Loss= 1.482462, Training Accuracy= 0.68750
# Iter 355200, Minibatch Loss= 1.510700, Training Accuracy= 0.62500
# Iter 356800, Minibatch Loss= 1.346166, Training Accuracy= 0.56250
# Iter 358400, Minibatch Loss= 0.945603, Training Accuracy= 0.68750
# Iter 360000, Minibatch Loss= 0.882105, Training Accuracy= 0.68750
# Iter 361600, Minibatch Loss= 0.648511, Training Accuracy= 0.81250
# Iter 363200, Minibatch Loss= 0.830121, Training Accuracy= 0.75000
# Iter 364800, Minibatch Loss= 2.105216, Training Accuracy= 0.56250
# Iter 366400, Minibatch Loss= 1.418928, Training Accuracy= 0.56250
# Iter 368000, Minibatch Loss= 0.701223, Training Accuracy= 0.87500
# Iter 369600, Minibatch Loss= 0.981398, Training Accuracy= 0.81250
# Iter 371200, Minibatch Loss= 0.862458, Training Accuracy= 0.75000
# Iter 372800, Minibatch Loss= 0.575001, Training Accuracy= 0.87500
# Iter 374400, Minibatch Loss= 0.779753, Training Accuracy= 0.87500
# Iter 376000, Minibatch Loss= 0.905214, Training Accuracy= 0.75000
# Iter 377600, Minibatch Loss= 1.190578, Training Accuracy= 0.56250
# Iter 379200, Minibatch Loss= 0.658390, Training Accuracy= 0.81250
# Iter 380800, Minibatch Loss= 1.448516, Training Accuracy= 0.68750
# Iter 382400, Minibatch Loss= 0.790623, Training Accuracy= 0.68750
# Iter 384000, Minibatch Loss= 0.688873, Training Accuracy= 0.75000
# Iter 385600, Minibatch Loss= 0.967606, Training Accuracy= 0.62500
# Iter 387200, Minibatch Loss= 0.764061, Training Accuracy= 0.75000
# Iter 388800, Minibatch Loss= 1.313210, Training Accuracy= 0.68750
# Iter 390400, Minibatch Loss= 0.803508, Training Accuracy= 0.75000
# Iter 392000, Minibatch Loss= 0.955346, Training Accuracy= 0.75000
# Iter 393600, Minibatch Loss= 1.215804, Training Accuracy= 0.75000
# Iter 395200, Minibatch Loss= 0.726040, Training Accuracy= 0.62500
# Iter 396800, Minibatch Loss= 1.118500, Training Accuracy= 0.68750
# Iter 398400, Minibatch Loss= 0.551194, Training Accuracy= 0.75000
# Iter 400000, Minibatch Loss= 0.616143, Training Accuracy= 0.81250
# Iter 401600, Minibatch Loss= 0.769372, Training Accuracy= 0.75000
# Iter 403200, Minibatch Loss= 0.691477, Training Accuracy= 0.75000
# Iter 404800, Minibatch Loss= 1.850938, Training Accuracy= 0.62500
# Iter 406400, Minibatch Loss= 0.911652, Training Accuracy= 0.68750
# Iter 408000, Minibatch Loss= 0.556181, Training Accuracy= 0.87500
# Iter 409600, Minibatch Loss= 0.616829, Training Accuracy= 0.81250
# Iter 411200, Minibatch Loss= 0.905395, Training Accuracy= 0.75000
# Iter 412800, Minibatch Loss= 0.539732, Training Accuracy= 0.75000
# Iter 414400, Minibatch Loss= 0.647976, Training Accuracy= 0.81250
# Iter 416000, Minibatch Loss= 0.773686, Training Accuracy= 0.81250
# Iter 417600, Minibatch Loss= 1.000736, Training Accuracy= 0.87500
# Iter 419200, Minibatch Loss= 0.868911, Training Accuracy= 0.62500
# Iter 420800, Minibatch Loss= 1.819951, Training Accuracy= 0.62500
# Iter 422400, Minibatch Loss= 0.526771, Training Accuracy= 0.75000
# Iter 424000, Minibatch Loss= 1.908949, Training Accuracy= 0.56250
# Iter 425600, Minibatch Loss= 0.863282, Training Accuracy= 0.68750
# Iter 427200, Minibatch Loss= 1.063605, Training Accuracy= 0.68750
# Iter 428800, Minibatch Loss= 0.907838, Training Accuracy= 0.75000
# Iter 430400, Minibatch Loss= 0.282529, Training Accuracy= 0.93750
# Iter 432000, Minibatch Loss= 0.558250, Training Accuracy= 0.75000
# Iter 433600, Minibatch Loss= 0.864010, Training Accuracy= 0.62500
# Iter 435200, Minibatch Loss= 0.512931, Training Accuracy= 0.81250
# Iter 436800, Minibatch Loss= 0.551009, Training Accuracy= 0.87500
# Iter 438400, Minibatch Loss= 0.971610, Training Accuracy= 0.62500
# Iter 440000, Minibatch Loss= 1.161789, Training Accuracy= 0.62500
# Iter 441600, Minibatch Loss= 0.501942, Training Accuracy= 0.87500
# Iter 443200, Minibatch Loss= 0.770028, Training Accuracy= 0.75000
# Iter 444800, Minibatch Loss= 0.787244, Training Accuracy= 0.75000
# Iter 446400, Minibatch Loss= 0.331827, Training Accuracy= 1.00000
# Iter 448000, Minibatch Loss= 2.133084, Training Accuracy= 0.62500
# Iter 449600, Minibatch Loss= 1.488670, Training Accuracy= 0.62500
# Iter 451200, Minibatch Loss= 1.520797, Training Accuracy= 0.62500
# Iter 452800, Minibatch Loss= 0.987792, Training Accuracy= 0.68750
# Iter 454400, Minibatch Loss= 0.570776, Training Accuracy= 0.81250
# Iter 456000, Minibatch Loss= 0.404166, Training Accuracy= 0.87500
# Iter 457600, Minibatch Loss= 0.965064, Training Accuracy= 0.62500
# Iter 459200, Minibatch Loss= 0.492451, Training Accuracy= 0.75000
# Iter 460800, Minibatch Loss= 1.212835, Training Accuracy= 0.68750
# Iter 462400, Minibatch Loss= 1.186033, Training Accuracy= 0.62500
# Iter 464000, Minibatch Loss= 1.200667, Training Accuracy= 0.75000
# Iter 465600, Minibatch Loss= 0.391123, Training Accuracy= 0.87500
# Iter 467200, Minibatch Loss= 0.402132, Training Accuracy= 0.87500
# Iter 468800, Minibatch Loss= 1.346345, Training Accuracy= 0.81250
# Iter 470400, Minibatch Loss= 0.688759, Training Accuracy= 0.75000
# Iter 472000, Minibatch Loss= 1.245026, Training Accuracy= 0.75000
# Iter 473600, Minibatch Loss= 0.891513, Training Accuracy= 0.81250
# Iter 475200, Minibatch Loss= 0.343001, Training Accuracy= 0.93750
# Iter 476800, Minibatch Loss= 0.463837, Training Accuracy= 0.87500
# Iter 478400, Minibatch Loss= 0.373293, Training Accuracy= 0.87500
# Iter 480000, Minibatch Loss= 1.010578, Training Accuracy= 0.56250
# Iter 481600, Minibatch Loss= 0.626746, Training Accuracy= 0.81250
# Iter 483200, Minibatch Loss= 0.667218, Training Accuracy= 0.75000
# Iter 484800, Minibatch Loss= 0.921361, Training Accuracy= 0.68750
# Iter 486400, Minibatch Loss= 0.827087, Training Accuracy= 0.81250
# Iter 488000, Minibatch Loss= 0.627574, Training Accuracy= 0.87500
# Iter 489600, Minibatch Loss= 0.445374, Training Accuracy= 0.87500
# Iter 491200, Minibatch Loss= 1.213334, Training Accuracy= 0.75000
# Iter 492800, Minibatch Loss= 0.671877, Training Accuracy= 0.81250
# Iter 494400, Minibatch Loss= 0.990622, Training Accuracy= 0.68750
# Iter 496000, Minibatch Loss= 0.799725, Training Accuracy= 0.75000
# Iter 497600, Minibatch Loss= 0.660027, Training Accuracy= 0.62500
# Iter 499200, Minibatch Loss= 1.235477, Training Accuracy= 0.75000
# Iter 500800, Minibatch Loss= 0.556360, Training Accuracy= 0.93750
# Iter 502400, Minibatch Loss= 0.332290, Training Accuracy= 0.93750
# Iter 504000, Minibatch Loss= 0.700917, Training Accuracy= 0.75000
# Iter 505600, Minibatch Loss= 0.760827, Training Accuracy= 0.75000
# Iter 507200, Minibatch Loss= 0.311881, Training Accuracy= 0.81250
# Iter 508800, Minibatch Loss= 0.314170, Training Accuracy= 0.87500
# Iter 510400, Minibatch Loss= 0.656072, Training Accuracy= 0.87500
# Iter 512000, Minibatch Loss= 1.174949, Training Accuracy= 0.75000
# Iter 513600, Minibatch Loss= 0.489324, Training Accuracy= 0.87500
# Iter 515200, Minibatch Loss= 0.273841, Training Accuracy= 0.87500
# Iter 516800, Minibatch Loss= 0.995199, Training Accuracy= 0.81250
# Iter 518400, Minibatch Loss= 0.658544, Training Accuracy= 0.81250
# Iter 520000, Minibatch Loss= 0.608614, Training Accuracy= 0.87500
# Iter 521600, Minibatch Loss= 0.656926, Training Accuracy= 0.81250
# Iter 523200, Minibatch Loss= 0.588709, Training Accuracy= 0.81250
# Iter 524800, Minibatch Loss= 0.353986, Training Accuracy= 0.93750
# Iter 526400, Minibatch Loss= 0.637707, Training Accuracy= 0.87500
# Iter 528000, Minibatch Loss= 0.722221, Training Accuracy= 0.81250
# Iter 529600, Minibatch Loss= 0.207741, Training Accuracy= 1.00000
# Iter 531200, Minibatch Loss= 0.184906, Training Accuracy= 0.93750
# Iter 532800, Minibatch Loss= 0.410643, Training Accuracy= 0.81250
# Iter 534400, Minibatch Loss= 0.427238, Training Accuracy= 0.87500
# Iter 536000, Minibatch Loss= 1.164408, Training Accuracy= 0.68750
# Iter 537600, Minibatch Loss= 0.132904, Training Accuracy= 1.00000
# Iter 539200, Minibatch Loss= 0.671314, Training Accuracy= 0.75000
# Iter 540800, Minibatch Loss= 0.681330, Training Accuracy= 0.75000
# Iter 542400, Minibatch Loss= 0.658635, Training Accuracy= 0.81250
# Iter 544000, Minibatch Loss= 0.500361, Training Accuracy= 0.87500
# Iter 545600, Minibatch Loss= 0.524526, Training Accuracy= 0.87500
# Iter 547200, Minibatch Loss= 0.786842, Training Accuracy= 0.81250
# Iter 548800, Minibatch Loss= 1.556115, Training Accuracy= 0.81250
# Iter 550400, Minibatch Loss= 0.363903, Training Accuracy= 0.87500
# Iter 552000, Minibatch Loss= 0.071262, Training Accuracy= 1.00000
# Iter 553600, Minibatch Loss= 0.246222, Training Accuracy= 1.00000
# Iter 555200, Minibatch Loss= 0.940419, Training Accuracy= 0.87500
# Iter 556800, Minibatch Loss= 0.346850, Training Accuracy= 0.93750
# Iter 558400, Minibatch Loss= 0.441544, Training Accuracy= 0.87500
# Iter 560000, Minibatch Loss= 0.620577, Training Accuracy= 0.75000
# Iter 561600, Minibatch Loss= 0.403768, Training Accuracy= 0.81250
# Iter 563200, Minibatch Loss= 0.229779, Training Accuracy= 0.93750
# Iter 564800, Minibatch Loss= 0.159793, Training Accuracy= 0.93750
# Iter 566400, Minibatch Loss= 0.843160, Training Accuracy= 0.81250
# Iter 568000, Minibatch Loss= 1.866383, Training Accuracy= 0.68750
# Iter 569600, Minibatch Loss= 1.042619, Training Accuracy= 0.87500
# Iter 571200, Minibatch Loss= 0.403593, Training Accuracy= 0.87500
# Iter 572800, Minibatch Loss= 0.416673, Training Accuracy= 0.81250
# Iter 574400, Minibatch Loss= 0.799466, Training Accuracy= 0.75000
# Iter 576000, Minibatch Loss= 0.895507, Training Accuracy= 0.87500
# Iter 577600, Minibatch Loss= 0.348816, Training Accuracy= 0.87500
# Iter 579200, Minibatch Loss= 0.572385, Training Accuracy= 0.87500
# Iter 580800, Minibatch Loss= 0.400848, Training Accuracy= 0.87500
# Iter 582400, Minibatch Loss= 0.088681, Training Accuracy= 1.00000
# Iter 584000, Minibatch Loss= 0.309866, Training Accuracy= 0.93750
# Iter 585600, Minibatch Loss= 0.289961, Training Accuracy= 0.93750
# Iter 587200, Minibatch Loss= 0.354790, Training Accuracy= 0.81250
# Iter 588800, Minibatch Loss= 0.887712, Training Accuracy= 0.81250
# Iter 590400, Minibatch Loss= 0.376518, Training Accuracy= 0.87500
# Iter 592000, Minibatch Loss= 0.264046, Training Accuracy= 0.93750
# Iter 593600, Minibatch Loss= 0.782969, Training Accuracy= 0.81250
# Iter 595200, Minibatch Loss= 0.375651, Training Accuracy= 0.87500
# Iter 596800, Minibatch Loss= 0.113140, Training Accuracy= 1.00000
# Iter 598400, Minibatch Loss= 0.660448, Training Accuracy= 0.75000
# Iter 600000, Minibatch Loss= 0.387745, Training Accuracy= 0.81250
# Iter 601600, Minibatch Loss= 0.499310, Training Accuracy= 0.87500
# Iter 603200, Minibatch Loss= 0.717488, Training Accuracy= 0.87500
# Iter 604800, Minibatch Loss= 0.229956, Training Accuracy= 0.87500
# Iter 606400, Minibatch Loss= 1.168255, Training Accuracy= 0.81250
# Iter 608000, Minibatch Loss= 0.431234, Training Accuracy= 0.81250
# Iter 609600, Minibatch Loss= 1.256750, Training Accuracy= 0.81250
# Iter 611200, Minibatch Loss= 0.881711, Training Accuracy= 0.68750
# Iter 612800, Minibatch Loss= 0.935866, Training Accuracy= 0.75000
# Iter 614400, Minibatch Loss= 0.444933, Training Accuracy= 0.81250
# Iter 616000, Minibatch Loss= 0.536806, Training Accuracy= 0.87500
# Iter 617600, Minibatch Loss= 0.756314, Training Accuracy= 0.75000
# Iter 619200, Minibatch Loss= 0.190695, Training Accuracy= 0.93750
# Iter 620800, Minibatch Loss= 0.301385, Training Accuracy= 0.87500
# Iter 622400, Minibatch Loss= 0.616975, Training Accuracy= 0.87500
# Iter 624000, Minibatch Loss= 0.322676, Training Accuracy= 0.87500
# Iter 625600, Minibatch Loss= 0.317451, Training Accuracy= 0.87500
# Iter 627200, Minibatch Loss= 0.170653, Training Accuracy= 0.93750
# Iter 628800, Minibatch Loss= 0.509959, Training Accuracy= 0.75000
# Iter 630400, Minibatch Loss= 0.867793, Training Accuracy= 0.81250
# Iter 632000, Minibatch Loss= 0.233980, Training Accuracy= 0.93750
# Iter 633600, Minibatch Loss= 0.386741, Training Accuracy= 0.93750
# Iter 635200, Minibatch Loss= 0.509937, Training Accuracy= 0.87500
# Iter 636800, Minibatch Loss= 0.106836, Training Accuracy= 0.93750
# Iter 638400, Minibatch Loss= 0.903757, Training Accuracy= 0.81250
# Iter 640000, Minibatch Loss= 0.372473, Training Accuracy= 0.75000
# Iter 641600, Minibatch Loss= 1.479901, Training Accuracy= 0.75000
# Iter 643200, Minibatch Loss= 0.437862, Training Accuracy= 0.87500
# Iter 644800, Minibatch Loss= 0.406339, Training Accuracy= 0.93750
# Iter 646400, Minibatch Loss= 0.698810, Training Accuracy= 0.87500
# Iter 648000, Minibatch Loss= 0.121160, Training Accuracy= 1.00000
# Iter 649600, Minibatch Loss= 0.303923, Training Accuracy= 0.93750
# Iter 651200, Minibatch Loss= 0.760052, Training Accuracy= 0.75000
# Iter 652800, Minibatch Loss= 0.074942, Training Accuracy= 1.00000
# Iter 654400, Minibatch Loss= 0.464045, Training Accuracy= 0.81250
# Iter 656000, Minibatch Loss= 1.363314, Training Accuracy= 0.68750
# Iter 657600, Minibatch Loss= 0.188829, Training Accuracy= 1.00000
# Iter 659200, Minibatch Loss= 0.395572, Training Accuracy= 0.87500
# Iter 660800, Minibatch Loss= 0.265256, Training Accuracy= 0.93750
# Iter 662400, Minibatch Loss= 0.046246, Training Accuracy= 1.00000
# Iter 664000, Minibatch Loss= 0.132438, Training Accuracy= 1.00000
# Iter 665600, Minibatch Loss= 0.303833, Training Accuracy= 0.87500
# Iter 667200, Minibatch Loss= 0.698127, Training Accuracy= 0.75000
# Iter 668800, Minibatch Loss= 0.066515, Training Accuracy= 1.00000
# Iter 670400, Minibatch Loss= 0.325067, Training Accuracy= 0.81250
# Iter 672000, Minibatch Loss= 0.036150, Training Accuracy= 1.00000
# Iter 673600, Minibatch Loss= 1.137457, Training Accuracy= 0.81250
# Iter 675200, Minibatch Loss= 0.135017, Training Accuracy= 0.93750
# Iter 676800, Minibatch Loss= 0.205657, Training Accuracy= 0.93750
# Iter 678400, Minibatch Loss= 0.198281, Training Accuracy= 0.93750
# Iter 680000, Minibatch Loss= 0.276987, Training Accuracy= 0.87500
# Iter 681600, Minibatch Loss= 0.771183, Training Accuracy= 0.87500
# Iter 683200, Minibatch Loss= 0.369011, Training Accuracy= 0.87500
# Iter 684800, Minibatch Loss= 0.407649, Training Accuracy= 0.81250
# Iter 686400, Minibatch Loss= 0.591618, Training Accuracy= 0.68750
# Iter 688000, Minibatch Loss= 0.277941, Training Accuracy= 0.87500
# Iter 689600, Minibatch Loss= 0.535577, Training Accuracy= 0.81250
# Iter 691200, Minibatch Loss= 0.158856, Training Accuracy= 0.93750
# Iter 692800, Minibatch Loss= 0.043685, Training Accuracy= 1.00000
# Iter 694400, Minibatch Loss= 0.412021, Training Accuracy= 0.81250
# Iter 696000, Minibatch Loss= 0.337195, Training Accuracy= 0.93750
# Iter 697600, Minibatch Loss= 0.554504, Training Accuracy= 0.81250
# Iter 699200, Minibatch Loss= 0.225753, Training Accuracy= 0.93750
# Iter 700800, Minibatch Loss= 0.473404, Training Accuracy= 0.81250
# Iter 702400, Minibatch Loss= 1.261454, Training Accuracy= 0.81250
# Iter 704000, Minibatch Loss= 0.396122, Training Accuracy= 0.81250
# Iter 705600, Minibatch Loss= 0.178794, Training Accuracy= 0.93750
# Iter 707200, Minibatch Loss= 0.958755, Training Accuracy= 0.87500
# Iter 708800, Minibatch Loss= 0.104457, Training Accuracy= 1.00000
# Iter 710400, Minibatch Loss= 0.230343, Training Accuracy= 0.93750
# Iter 712000, Minibatch Loss= 0.371091, Training Accuracy= 0.93750
# Iter 713600, Minibatch Loss= 0.036369, Training Accuracy= 1.00000
# Iter 715200, Minibatch Loss= 0.297148, Training Accuracy= 0.93750
# Iter 716800, Minibatch Loss= 0.202965, Training Accuracy= 0.93750
# Iter 718400, Minibatch Loss= 0.619831, Training Accuracy= 0.68750
# Iter 720000, Minibatch Loss= 0.093239, Training Accuracy= 1.00000
# Iter 721600, Minibatch Loss= 0.184935, Training Accuracy= 0.93750
# Iter 723200, Minibatch Loss= 0.309979, Training Accuracy= 0.87500
# Iter 724800, Minibatch Loss= 0.321072, Training Accuracy= 0.87500
# Iter 726400, Minibatch Loss= 0.206394, Training Accuracy= 1.00000
# Iter 728000, Minibatch Loss= 0.372983, Training Accuracy= 0.81250
# Iter 729600, Minibatch Loss= 0.422627, Training Accuracy= 0.87500
# Iter 731200, Minibatch Loss= 0.132501, Training Accuracy= 1.00000
# Iter 732800, Minibatch Loss= 0.237401, Training Accuracy= 0.93750
# Iter 734400, Minibatch Loss= 0.261559, Training Accuracy= 0.87500
# Iter 736000, Minibatch Loss= 0.221223, Training Accuracy= 0.93750
# Iter 737600, Minibatch Loss= 0.091046, Training Accuracy= 1.00000
# Iter 739200, Minibatch Loss= 0.192510, Training Accuracy= 0.93750
# Iter 740800, Minibatch Loss= 0.666906, Training Accuracy= 0.81250
# Iter 742400, Minibatch Loss= 0.305145, Training Accuracy= 0.93750
# Iter 744000, Minibatch Loss= 0.103999, Training Accuracy= 1.00000
# Iter 745600, Minibatch Loss= 0.391018, Training Accuracy= 0.81250
# Iter 747200, Minibatch Loss= 0.243579, Training Accuracy= 0.93750
# Iter 748800, Minibatch Loss= 0.183658, Training Accuracy= 0.93750
# Iter 750400, Minibatch Loss= 0.186901, Training Accuracy= 0.93750
# Iter 752000, Minibatch Loss= 0.417070, Training Accuracy= 0.93750
# Iter 753600, Minibatch Loss= 0.301041, Training Accuracy= 0.81250
# Iter 755200, Minibatch Loss= 0.658463, Training Accuracy= 0.87500
# Iter 756800, Minibatch Loss= 0.366399, Training Accuracy= 0.81250
# Iter 758400, Minibatch Loss= 0.383066, Training Accuracy= 0.87500
# Iter 760000, Minibatch Loss= 0.409735, Training Accuracy= 0.87500
# Iter 761600, Minibatch Loss= 0.325637, Training Accuracy= 0.87500
# Iter 763200, Minibatch Loss= 0.327638, Training Accuracy= 0.93750
# Iter 764800, Minibatch Loss= 0.236639, Training Accuracy= 0.93750
# Iter 766400, Minibatch Loss= 0.668468, Training Accuracy= 0.75000
# Iter 768000, Minibatch Loss= 0.135812, Training Accuracy= 0.93750
# Iter 769600, Minibatch Loss= 0.945492, Training Accuracy= 0.87500
# Iter 771200, Minibatch Loss= 0.364783, Training Accuracy= 0.87500
# Iter 772800, Minibatch Loss= 1.078801, Training Accuracy= 0.93750
# Iter 774400, Minibatch Loss= 0.113951, Training Accuracy= 1.00000
# Iter 776000, Minibatch Loss= 0.147052, Training Accuracy= 0.93750
# Iter 777600, Minibatch Loss= 1.150238, Training Accuracy= 0.93750
# Iter 779200, Minibatch Loss= 0.106262, Training Accuracy= 1.00000
# Iter 780800, Minibatch Loss= 0.464200, Training Accuracy= 0.87500
# Iter 782400, Minibatch Loss= 0.096042, Training Accuracy= 1.00000
# Iter 784000, Minibatch Loss= 0.219023, Training Accuracy= 0.93750
# Iter 785600, Minibatch Loss= 0.098225, Training Accuracy= 0.93750
# Iter 787200, Minibatch Loss= 0.323422, Training Accuracy= 0.81250
# Iter 788800, Minibatch Loss= 0.306680, Training Accuracy= 0.87500
# Iter 790400, Minibatch Loss= 0.076807, Training Accuracy= 1.00000
# Iter 792000, Minibatch Loss= 0.426348, Training Accuracy= 0.75000
# Iter 793600, Minibatch Loss= 0.842472, Training Accuracy= 0.81250
# Iter 795200, Minibatch Loss= 0.238155, Training Accuracy= 0.93750
# Iter 796800, Minibatch Loss= 0.268530, Training Accuracy= 0.87500
# Iter 798400, Minibatch Loss= 0.043211, Training Accuracy= 1.00000
# Iter 800000, Minibatch Loss= 0.217703, Training Accuracy= 1.00000
# Iter 801600, Minibatch Loss= 0.176123, Training Accuracy= 0.93750
# Iter 803200, Minibatch Loss= 0.058288, Training Accuracy= 1.00000
# Iter 804800, Minibatch Loss= 0.153385, Training Accuracy= 0.93750
# Iter 806400, Minibatch Loss= 0.437525, Training Accuracy= 0.93750
# Iter 808000, Minibatch Loss= 0.180424, Training Accuracy= 0.87500
# Iter 809600, Minibatch Loss= 0.270368, Training Accuracy= 0.87500
# Iter 811200, Minibatch Loss= 0.136334, Training Accuracy= 1.00000
# Iter 812800, Minibatch Loss= 0.114777, Training Accuracy= 0.93750
# Iter 814400, Minibatch Loss= 0.223514, Training Accuracy= 0.93750
# Iter 816000, Minibatch Loss= 0.352548, Training Accuracy= 0.87500
# Iter 817600, Minibatch Loss= 0.082587, Training Accuracy= 1.00000
# Iter 819200, Minibatch Loss= 0.834874, Training Accuracy= 0.81250
# Iter 820800, Minibatch Loss= 0.131979, Training Accuracy= 1.00000
# Iter 822400, Minibatch Loss= 0.123813, Training Accuracy= 0.93750
# Iter 824000, Minibatch Loss= 0.556541, Training Accuracy= 0.81250
# Iter 825600, Minibatch Loss= 0.270939, Training Accuracy= 0.93750
# Iter 827200, Minibatch Loss= 0.140299, Training Accuracy= 0.93750
# Iter 828800, Minibatch Loss= 0.695908, Training Accuracy= 0.87500
# Iter 830400, Minibatch Loss= 0.109785, Training Accuracy= 1.00000
# Iter 832000, Minibatch Loss= 0.203012, Training Accuracy= 0.93750
# Iter 833600, Minibatch Loss= 0.270038, Training Accuracy= 0.87500
# Iter 835200, Minibatch Loss= 0.470173, Training Accuracy= 0.81250
# Iter 836800, Minibatch Loss= 0.764435, Training Accuracy= 0.81250
# Iter 838400, Minibatch Loss= 0.290632, Training Accuracy= 0.93750
# Iter 840000, Minibatch Loss= 0.779902, Training Accuracy= 0.81250
# Iter 841600, Minibatch Loss= 0.120772, Training Accuracy= 1.00000
# Iter 843200, Minibatch Loss= 0.166628, Training Accuracy= 0.93750
# Iter 844800, Minibatch Loss= 0.360582, Training Accuracy= 0.93750
# Iter 846400, Minibatch Loss= 0.343427, Training Accuracy= 0.87500
# Iter 848000, Minibatch Loss= 0.220139, Training Accuracy= 0.87500
# Iter 849600, Minibatch Loss= 0.334110, Training Accuracy= 0.93750
# Iter 851200, Minibatch Loss= 0.812123, Training Accuracy= 0.87500
# Iter 852800, Minibatch Loss= 0.348414, Training Accuracy= 0.81250
# Iter 854400, Minibatch Loss= 0.694411, Training Accuracy= 0.81250
# Iter 856000, Minibatch Loss= 0.062381, Training Accuracy= 1.00000
# Iter 857600, Minibatch Loss= 0.077146, Training Accuracy= 1.00000
# Iter 859200, Minibatch Loss= 0.061674, Training Accuracy= 1.00000
# Iter 860800, Minibatch Loss= 0.329647, Training Accuracy= 0.93750
# Iter 862400, Minibatch Loss= 0.243891, Training Accuracy= 0.93750
# Iter 864000, Minibatch Loss= 1.418849, Training Accuracy= 0.75000
# Iter 865600, Minibatch Loss= 0.053165, Training Accuracy= 0.93750
# Iter 867200, Minibatch Loss= 0.336434, Training Accuracy= 0.93750
# Iter 868800, Minibatch Loss= 0.552804, Training Accuracy= 0.81250
# Iter 870400, Minibatch Loss= 0.122890, Training Accuracy= 0.93750
# Iter 872000, Minibatch Loss= 0.122271, Training Accuracy= 0.93750
# Iter 873600, Minibatch Loss= 0.036648, Training Accuracy= 1.00000
# Iter 875200, Minibatch Loss= 0.056933, Training Accuracy= 1.00000
# Iter 876800, Minibatch Loss= 0.845915, Training Accuracy= 0.81250
# Iter 878400, Minibatch Loss= 0.090803, Training Accuracy= 1.00000
# Iter 880000, Minibatch Loss= 0.158852, Training Accuracy= 0.93750
# Iter 881600, Minibatch Loss= 0.124055, Training Accuracy= 0.93750
# Iter 883200, Minibatch Loss= 0.707808, Training Accuracy= 0.87500
# Iter 884800, Minibatch Loss= 0.214431, Training Accuracy= 0.87500
# Iter 886400, Minibatch Loss= 0.224933, Training Accuracy= 0.93750
# Iter 888000, Minibatch Loss= 0.084055, Training Accuracy= 1.00000
# Iter 889600, Minibatch Loss= 0.175865, Training Accuracy= 0.93750
# Iter 891200, Minibatch Loss= 0.051821, Training Accuracy= 1.00000
# Iter 892800, Minibatch Loss= 1.041146, Training Accuracy= 0.81250
# Iter 894400, Minibatch Loss= 0.296682, Training Accuracy= 0.93750
# Iter 896000, Minibatch Loss= 0.406280, Training Accuracy= 0.93750
# Iter 897600, Minibatch Loss= 0.140822, Training Accuracy= 0.87500
# Iter 899200, Minibatch Loss= 0.035301, Training Accuracy= 1.00000
# Iter 900800, Minibatch Loss= 0.160619, Training Accuracy= 0.87500
# Iter 902400, Minibatch Loss= 0.019986, Training Accuracy= 1.00000
# Iter 904000, Minibatch Loss= 0.868637, Training Accuracy= 0.87500
# Iter 905600, Minibatch Loss= 0.203739, Training Accuracy= 0.93750
# Iter 907200, Minibatch Loss= 0.055667, Training Accuracy= 1.00000
# Iter 908800, Minibatch Loss= 0.064559, Training Accuracy= 1.00000
# Iter 910400, Minibatch Loss= 0.523212, Training Accuracy= 0.93750
# Iter 912000, Minibatch Loss= 0.277599, Training Accuracy= 0.93750
# Iter 913600, Minibatch Loss= 0.351512, Training Accuracy= 0.87500
# Iter 915200, Minibatch Loss= 0.073537, Training Accuracy= 1.00000
# Iter 916800, Minibatch Loss= 0.038524, Training Accuracy= 1.00000
# Iter 918400, Minibatch Loss= 0.116598, Training Accuracy= 0.93750
# Iter 920000, Minibatch Loss= 0.035092, Training Accuracy= 1.00000
# Iter 921600, Minibatch Loss= 0.020734, Training Accuracy= 1.00000
# Iter 923200, Minibatch Loss= 0.354359, Training Accuracy= 0.87500
# Iter 924800, Minibatch Loss= 0.068594, Training Accuracy= 1.00000
# Iter 926400, Minibatch Loss= 0.056197, Training Accuracy= 1.00000
# Iter 928000, Minibatch Loss= 0.296164, Training Accuracy= 0.87500
# Iter 929600, Minibatch Loss= 0.079998, Training Accuracy= 1.00000
# Iter 931200, Minibatch Loss= 0.021497, Training Accuracy= 1.00000
# Iter 932800, Minibatch Loss= 0.043337, Training Accuracy= 1.00000
# Iter 934400, Minibatch Loss= 0.055533, Training Accuracy= 1.00000
# Iter 936000, Minibatch Loss= 0.039384, Training Accuracy= 1.00000
# Iter 937600, Minibatch Loss= 0.166364, Training Accuracy= 0.93750
# Iter 939200, Minibatch Loss= 0.167482, Training Accuracy= 0.87500
# Iter 940800, Minibatch Loss= 0.040626, Training Accuracy= 1.00000
# Iter 942400, Minibatch Loss= 0.759277, Training Accuracy= 0.87500
# Iter 944000, Minibatch Loss= 0.551496, Training Accuracy= 0.87500
# Iter 945600, Minibatch Loss= 0.039031, Training Accuracy= 1.00000
# Iter 947200, Minibatch Loss= 0.168125, Training Accuracy= 1.00000
# Iter 948800, Minibatch Loss= 0.076367, Training Accuracy= 1.00000
# Iter 950400, Minibatch Loss= 0.119755, Training Accuracy= 1.00000
# Iter 952000, Minibatch Loss= 0.510391, Training Accuracy= 0.93750
# Iter 953600, Minibatch Loss= 0.040555, Training Accuracy= 1.00000
# Iter 955200, Minibatch Loss= 0.077088, Training Accuracy= 1.00000
# Iter 956800, Minibatch Loss= 0.032432, Training Accuracy= 1.00000
# Iter 958400, Minibatch Loss= 0.129405, Training Accuracy= 0.93750
# Iter 960000, Minibatch Loss= 0.068286, Training Accuracy= 1.00000
# Iter 961600, Minibatch Loss= 0.534892, Training Accuracy= 0.87500
# Iter 963200, Minibatch Loss= 0.163989, Training Accuracy= 0.87500
# Iter 964800, Minibatch Loss= 0.271113, Training Accuracy= 0.87500
# Iter 966400, Minibatch Loss= 0.132131, Training Accuracy= 0.93750
# Iter 968000, Minibatch Loss= 0.240742, Training Accuracy= 0.93750
# Iter 969600, Minibatch Loss= 0.570789, Training Accuracy= 0.81250
# Iter 971200, Minibatch Loss= 0.802472, Training Accuracy= 0.81250
# Iter 972800, Minibatch Loss= 0.100349, Training Accuracy= 1.00000
# Iter 974400, Minibatch Loss= 0.032157, Training Accuracy= 1.00000
# Iter 976000, Minibatch Loss= 0.194964, Training Accuracy= 0.93750
# Iter 977600, Minibatch Loss= 0.182970, Training Accuracy= 0.93750
# Iter 979200, Minibatch Loss= 0.598321, Training Accuracy= 0.93750
# Iter 980800, Minibatch Loss= 0.085603, Training Accuracy= 1.00000
# Iter 982400, Minibatch Loss= 0.093964, Training Accuracy= 1.00000
# Iter 984000, Minibatch Loss= 0.547693, Training Accuracy= 0.93750
# Iter 985600, Minibatch Loss= 0.055619, Training Accuracy= 1.00000
# Iter 987200, Minibatch Loss= 0.203804, Training Accuracy= 0.93750
# Iter 988800, Minibatch Loss= 0.856269, Training Accuracy= 0.87500
# Iter 990400, Minibatch Loss= 0.222155, Training Accuracy= 0.93750
# Iter 992000, Minibatch Loss= 0.081583, Training Accuracy= 1.00000
# Iter 993600, Minibatch Loss= 0.068346, Training Accuracy= 1.00000
# Iter 995200, Minibatch Loss= 0.388499, Training Accuracy= 0.93750
# Iter 996800, Minibatch Loss= 0.535877, Training Accuracy= 0.87500
# Iter 998400, Minibatch Loss= 0.391568, Training Accuracy= 0.93750
# Iter 1000000, Minibatch Loss= 0.128598, Training Accuracy= 0.93750
# Iter 1001600, Minibatch Loss= 0.079853, Training Accuracy= 1.00000
# Iter 1003200, Minibatch Loss= 0.141173, Training Accuracy= 0.93750
# Iter 1004800, Minibatch Loss= 0.056309, Training Accuracy= 1.00000
# Iter 1006400, Minibatch Loss= 0.313613, Training Accuracy= 0.93750
# Iter 1008000, Minibatch Loss= 0.233955, Training Accuracy= 0.93750
# Iter 1009600, Minibatch Loss= 1.258780, Training Accuracy= 0.87500
# Iter 1011200, Minibatch Loss= 0.209624, Training Accuracy= 0.93750
# Iter 1012800, Minibatch Loss= 0.045402, Training Accuracy= 1.00000
# Iter 1014400, Minibatch Loss= 0.360216, Training Accuracy= 0.93750
# Iter 1016000, Minibatch Loss= 0.068516, Training Accuracy= 1.00000
# Iter 1017600, Minibatch Loss= 0.049688, Training Accuracy= 1.00000
# Iter 1019200, Minibatch Loss= 0.562770, Training Accuracy= 0.81250
# Iter 1020800, Minibatch Loss= 0.361744, Training Accuracy= 0.87500
# Iter 1022400, Minibatch Loss= 0.614082, Training Accuracy= 0.87500
# Iter 1024000, Minibatch Loss= 0.188840, Training Accuracy= 0.93750
# Iter 1025600, Minibatch Loss= 0.050928, Training Accuracy= 1.00000
# Iter 1027200, Minibatch Loss= 0.180442, Training Accuracy= 0.93750
# Iter 1028800, Minibatch Loss= 0.281762, Training Accuracy= 0.87500
# Iter 1030400, Minibatch Loss= 0.225716, Training Accuracy= 0.93750
# Iter 1032000, Minibatch Loss= 0.753564, Training Accuracy= 0.87500
# Iter 1033600, Minibatch Loss= 0.435046, Training Accuracy= 0.93750
# Iter 1035200, Minibatch Loss= 0.056394, Training Accuracy= 1.00000
# Iter 1036800, Minibatch Loss= 0.243013, Training Accuracy= 0.87500
# Iter 1038400, Minibatch Loss= 0.296345, Training Accuracy= 0.87500
# Iter 1040000, Minibatch Loss= 0.062748, Training Accuracy= 1.00000
# Iter 1041600, Minibatch Loss= 0.006024, Training Accuracy= 1.00000
# Iter 1043200, Minibatch Loss= 0.008036, Training Accuracy= 1.00000
# Iter 1044800, Minibatch Loss= 0.049432, Training Accuracy= 1.00000
# Iter 1046400, Minibatch Loss= 0.028857, Training Accuracy= 1.00000
# Iter 1048000, Minibatch Loss= 0.289363, Training Accuracy= 0.87500
# Iter 1049600, Minibatch Loss= 0.095260, Training Accuracy= 0.93750
# Iter 1051200, Minibatch Loss= 0.078036, Training Accuracy= 1.00000
# Iter 1052800, Minibatch Loss= 0.184486, Training Accuracy= 0.87500
# Iter 1054400, Minibatch Loss= 0.052692, Training Accuracy= 1.00000
# Iter 1056000, Minibatch Loss= 0.059869, Training Accuracy= 1.00000
# Iter 1057600, Minibatch Loss= 0.301376, Training Accuracy= 0.93750
# Iter 1059200, Minibatch Loss= 0.094833, Training Accuracy= 1.00000
# Iter 1060800, Minibatch Loss= 0.006186, Training Accuracy= 1.00000
# Iter 1062400, Minibatch Loss= 0.002472, Training Accuracy= 1.00000
# Iter 1064000, Minibatch Loss= 0.117278, Training Accuracy= 0.93750
# Iter 1065600, Minibatch Loss= 0.052369, Training Accuracy= 1.00000
# Iter 1067200, Minibatch Loss= 0.086362, Training Accuracy= 1.00000
# Iter 1068800, Minibatch Loss= 0.007804, Training Accuracy= 1.00000
# Iter 1070400, Minibatch Loss= 0.283621, Training Accuracy= 0.87500
# Iter 1072000, Minibatch Loss= 0.273683, Training Accuracy= 0.93750
# Iter 1073600, Minibatch Loss= 0.313746, Training Accuracy= 0.93750
# Iter 1075200, Minibatch Loss= 0.146198, Training Accuracy= 0.93750
# Iter 1076800, Minibatch Loss= 0.056386, Training Accuracy= 1.00000
# Iter 1078400, Minibatch Loss= 0.044316, Training Accuracy= 1.00000
# Iter 1080000, Minibatch Loss= 0.114670, Training Accuracy= 0.93750
# Iter 1081600, Minibatch Loss= 0.069930, Training Accuracy= 1.00000
# Iter 1083200, Minibatch Loss= 0.068951, Training Accuracy= 1.00000
# Iter 1084800, Minibatch Loss= 0.186370, Training Accuracy= 0.87500
# Iter 1086400, Minibatch Loss= 0.113713, Training Accuracy= 0.93750
# Iter 1088000, Minibatch Loss= 0.384806, Training Accuracy= 0.93750
# Iter 1089600, Minibatch Loss= 0.198176, Training Accuracy= 0.93750
# Iter 1091200, Minibatch Loss= 0.021555, Training Accuracy= 1.00000
# Iter 1092800, Minibatch Loss= 0.056318, Training Accuracy= 1.00000
# Iter 1094400, Minibatch Loss= 0.072280, Training Accuracy= 1.00000
# Iter 1096000, Minibatch Loss= 0.138294, Training Accuracy= 0.93750
# Iter 1097600, Minibatch Loss= 0.064043, Training Accuracy= 1.00000
# Iter 1099200, Minibatch Loss= 0.266967, Training Accuracy= 0.93750
# Iter 1100800, Minibatch Loss= 0.249914, Training Accuracy= 0.87500
# Iter 1102400, Minibatch Loss= 0.381266, Training Accuracy= 0.93750
# Iter 1104000, Minibatch Loss= 0.014012, Training Accuracy= 1.00000
# Iter 1105600, Minibatch Loss= 0.010733, Training Accuracy= 1.00000
# Iter 1107200, Minibatch Loss= 0.013686, Training Accuracy= 1.00000
# Iter 1108800, Minibatch Loss= 0.298035, Training Accuracy= 0.87500
# Iter 1110400, Minibatch Loss= 0.029659, Training Accuracy= 1.00000
# Iter 1112000, Minibatch Loss= 0.235081, Training Accuracy= 0.87500
# Iter 1113600, Minibatch Loss= 0.865084, Training Accuracy= 0.93750
# Iter 1115200, Minibatch Loss= 0.067767, Training Accuracy= 1.00000
# Iter 1116800, Minibatch Loss= 0.012551, Training Accuracy= 1.00000
# Iter 1118400, Minibatch Loss= 0.274902, Training Accuracy= 0.93750
# Iter 1120000, Minibatch Loss= 0.093922, Training Accuracy= 1.00000
# Iter 1121600, Minibatch Loss= 0.384702, Training Accuracy= 0.93750
# Iter 1123200, Minibatch Loss= 0.246164, Training Accuracy= 0.93750
# Iter 1124800, Minibatch Loss= 0.379782, Training Accuracy= 0.93750
# Iter 1126400, Minibatch Loss= 0.212343, Training Accuracy= 0.87500
# Iter 1128000, Minibatch Loss= 0.053447, Training Accuracy= 1.00000
# Iter 1129600, Minibatch Loss= 0.136680, Training Accuracy= 0.93750
# Iter 1131200, Minibatch Loss= 0.044241, Training Accuracy= 1.00000
# Iter 1132800, Minibatch Loss= 0.045762, Training Accuracy= 1.00000
# Iter 1134400, Minibatch Loss= 0.004823, Training Accuracy= 1.00000
# Iter 1136000, Minibatch Loss= 0.002842, Training Accuracy= 1.00000
# Iter 1137600, Minibatch Loss= 0.005482, Training Accuracy= 1.00000
# Iter 1139200, Minibatch Loss= 0.006366, Training Accuracy= 1.00000
# Iter 1140800, Minibatch Loss= 0.285654, Training Accuracy= 0.93750
# Iter 1142400, Minibatch Loss= 0.048160, Training Accuracy= 0.93750
# Iter 1144000, Minibatch Loss= 0.029966, Training Accuracy= 1.00000
# Iter 1145600, Minibatch Loss= 0.008437, Training Accuracy= 1.00000
# Iter 1147200, Minibatch Loss= 0.141482, Training Accuracy= 0.93750
# Iter 1148800, Minibatch Loss= 0.449147, Training Accuracy= 0.87500
# Iter 1150400, Minibatch Loss= 0.371882, Training Accuracy= 0.81250
# Iter 1152000, Minibatch Loss= 0.102567, Training Accuracy= 1.00000
# Iter 1153600, Minibatch Loss= 0.289264, Training Accuracy= 0.93750
# Iter 1155200, Minibatch Loss= 0.081178, Training Accuracy= 1.00000
# Iter 1156800, Minibatch Loss= 0.871796, Training Accuracy= 0.81250
# Iter 1158400, Minibatch Loss= 0.067888, Training Accuracy= 1.00000
# Iter 1160000, Minibatch Loss= 0.043026, Training Accuracy= 1.00000
# Iter 1161600, Minibatch Loss= 0.022171, Training Accuracy= 1.00000
# ...
# Iter 1219200, Minibatch Loss= 0.039278, Training Accuracy= 1.00000
# Iter 1220800, Minibatch Loss= 0.035295, Training Accuracy= 1.00000
# Iter 1222400, Minibatch Loss= 0.046712, Training Accuracy= 1.00000
# Iter 1224000, Minibatch Loss= 0.026975, Training Accuracy= 1.00000
# Iter 1225600, Minibatch Loss= 0.064143, Training Accuracy= 1.00000
# Iter 1227200, Minibatch Loss= 0.025353, Training Accuracy= 1.00000
# Iter 1228800, Minibatch Loss= 0.624170, Training Accuracy= 0.87500
# Iter 1230400, Minibatch Loss= 0.025795, Training Accuracy= 1.00000
# Iter 1232000, Minibatch Loss= 0.027879, Training Accuracy= 1.00000
# Iter 1233600, Minibatch Loss= 0.015935, Training Accuracy= 1.00000
# Iter 1235200, Minibatch Loss= 0.011688, Training Accuracy= 1.00000
# Iter 1236800, Minibatch Loss= 0.121149, Training Accuracy= 1.00000
# Iter 1238400, Minibatch Loss= 0.050736, Training Accuracy= 1.00000
# Iter 1240000, Minibatch Loss= 1.169414, Training Accuracy= 0.81250
# Iter 1241600, Minibatch Loss= 0.443694, Training Accuracy= 0.93750
# Iter 1243200, Minibatch Loss= 0.008460, Training Accuracy= 1.00000
# Iter 1244800, Minibatch Loss= 0.021557, Training Accuracy= 1.00000
# Iter 1246400, Minibatch Loss= 0.015945, Training Accuracy= 1.00000
# Iter 1248000, Minibatch Loss= 0.140588, Training Accuracy= 0.93750
# Iter 1249600, Minibatch Loss= 0.479364, Training Accuracy= 0.81250
# Iter 1251200, Minibatch Loss= 0.035633, Training Accuracy= 1.00000
# Iter 1252800, Minibatch Loss= 0.004412, Training Accuracy= 1.00000
# Iter 1254400, Minibatch Loss= 0.177636, Training Accuracy= 0.93750
# Iter 1256000, Minibatch Loss= 0.179247, Training Accuracy= 0.93750
# Iter 1257600, Minibatch Loss= 0.073267, Training Accuracy= 1.00000
# Iter 1259200, Minibatch Loss= 0.015467, Training Accuracy= 1.00000
# Iter 1260800, Minibatch Loss= 0.030696, Training Accuracy= 1.00000
# Iter 1262400, Minibatch Loss= 0.051971, Training Accuracy= 1.00000
# Iter 1264000, Minibatch Loss= 0.133866, Training Accuracy= 0.93750
# Iter 1265600, Minibatch Loss= 0.042141, Training Accuracy= 1.00000
# Iter 1267200, Minibatch Loss= 0.218521, Training Accuracy= 0.93750
# Iter 1268800, Minibatch Loss= 0.041500, Training Accuracy= 1.00000
# Iter 1270400, Minibatch Loss= 0.049163, Training Accuracy= 1.00000
# Iter 1272000, Minibatch Loss= 0.062661, Training Accuracy= 1.00000
# Iter 1273600, Minibatch Loss= 0.615239, Training Accuracy= 0.93750
# Iter 1275200, Minibatch Loss= 0.022645, Training Accuracy= 1.00000
# Iter 1276800, Minibatch Loss= 0.459920, Training Accuracy= 0.93750
# Iter 1278400, Minibatch Loss= 0.183243, Training Accuracy= 0.93750
# Iter 1280000, Minibatch Loss= 0.107128, Training Accuracy= 0.93750
# Iter 1281600, Minibatch Loss= 0.030983, Training Accuracy= 1.00000
# Iter 1283200, Minibatch Loss= 0.003916, Training Accuracy= 1.00000
# Iter 1284800, Minibatch Loss= 0.044169, Training Accuracy= 1.00000
# Iter 1286400, Minibatch Loss= 0.004781, Training Accuracy= 1.00000
# Iter 1288000, Minibatch Loss= 0.059516, Training Accuracy= 1.00000
# Iter 1289600, Minibatch Loss= 0.052243, Training Accuracy= 1.00000
# Iter 1291200, Minibatch Loss= 0.045595, Training Accuracy= 1.00000
# Iter 1292800, Minibatch Loss= 0.126025, Training Accuracy= 0.93750
# Iter 1294400, Minibatch Loss= 0.033710, Training Accuracy= 1.00000
# Iter 1296000, Minibatch Loss= 0.378270, Training Accuracy= 0.87500
# Iter 1297600, Minibatch Loss= 0.048521, Training Accuracy= 1.00000
# Iter 1299200, Minibatch Loss= 0.119678, Training Accuracy= 0.93750
# Iter 1300800, Minibatch Loss= 0.033936, Training Accuracy= 1.00000
# Iter 1302400, Minibatch Loss= 0.185278, Training Accuracy= 0.93750
# Iter 1304000, Minibatch Loss= 0.047723, Training Accuracy= 1.00000
# Iter 1305600, Minibatch Loss= 0.126373, Training Accuracy= 0.93750
# Iter 1307200, Minibatch Loss= 0.045485, Training Accuracy= 1.00000
# Iter 1308800, Minibatch Loss= 0.028796, Training Accuracy= 1.00000
# Iter 1310400, Minibatch Loss= 0.036703, Training Accuracy= 1.00000
# Iter 1312000, Minibatch Loss= 0.449414, Training Accuracy= 0.87500
# Iter 1313600, Minibatch Loss= 0.206850, Training Accuracy= 0.93750
# Iter 1315200, Minibatch Loss= 0.150299, Training Accuracy= 1.00000
# Iter 1316800, Minibatch Loss= 0.016835, Training Accuracy= 1.00000
# Iter 1318400, Minibatch Loss= 0.039602, Training Accuracy= 1.00000
# Iter 1320000, Minibatch Loss= 0.007190, Training Accuracy= 1.00000
# Iter 1321600, Minibatch Loss= 0.170073, Training Accuracy= 0.93750
# Iter 1323200, Minibatch Loss= 0.132373, Training Accuracy= 0.93750
# Iter 1324800, Minibatch Loss= 0.286529, Training Accuracy= 0.93750
# Iter 1326400, Minibatch Loss= 0.172408, Training Accuracy= 1.00000
# Iter 1328000, Minibatch Loss= 0.062884, Training Accuracy= 1.00000
# Iter 1329600, Minibatch Loss= 0.002035, Training Accuracy= 1.00000
# Iter 1331200, Minibatch Loss= 0.017840, Training Accuracy= 1.00000
# Iter 1332800, Minibatch Loss= 0.037913, Training Accuracy= 1.00000
# Iter 1334400, Minibatch Loss= 0.170945, Training Accuracy= 0.93750
# Iter 1336000, Minibatch Loss= 0.001356, Training Accuracy= 1.00000
# Iter 1337600, Minibatch Loss= 0.005532, Training Accuracy= 1.00000
# Iter 1339200, Minibatch Loss= 0.050413, Training Accuracy= 0.93750
# Iter 1340800, Minibatch Loss= 0.104824, Training Accuracy= 1.00000
# Iter 1342400, Minibatch Loss= 0.213613, Training Accuracy= 0.93750
# Iter 1344000, Minibatch Loss= 0.420639, Training Accuracy= 0.93750
# Iter 1345600, Minibatch Loss= 0.069605, Training Accuracy= 0.93750
# Iter 1347200, Minibatch Loss= 0.007980, Training Accuracy= 1.00000
# Iter 1348800, Minibatch Loss= 0.005466, Training Accuracy= 1.00000
# Iter 1350400, Minibatch Loss= 0.003961, Training Accuracy= 1.00000
# Iter 1352000, Minibatch Loss= 0.097086, Training Accuracy= 0.93750
# Iter 1353600, Minibatch Loss= 0.141064, Training Accuracy= 0.87500
# Iter 1355200, Minibatch Loss= 0.011848, Training Accuracy= 1.00000
# Iter 1356800, Minibatch Loss= 0.050496, Training Accuracy= 1.00000
# Iter 1358400, Minibatch Loss= 0.029280, Training Accuracy= 1.00000
# Iter 1360000, Minibatch Loss= 0.008356, Training Accuracy= 1.00000
# Iter 1361600, Minibatch Loss= 0.080740, Training Accuracy= 1.00000
# Iter 1363200, Minibatch Loss= 0.076675, Training Accuracy= 1.00000
# Iter 1364800, Minibatch Loss= 0.354213, Training Accuracy= 0.93750
# Iter 1366400, Minibatch Loss= 0.022837, Training Accuracy= 1.00000
# Iter 1368000, Minibatch Loss= 0.053665, Training Accuracy= 1.00000
# Iter 1369600, Minibatch Loss= 0.038107, Training Accuracy= 1.00000
# Iter 1371200, Minibatch Loss= 0.145215, Training Accuracy= 0.93750
# Iter 1372800, Minibatch Loss= 0.281136, Training Accuracy= 0.87500
# Iter 1374400, Minibatch Loss= 0.203734, Training Accuracy= 0.93750
# Iter 1376000, Minibatch Loss= 0.015287, Training Accuracy= 1.00000
# Iter 1377600, Minibatch Loss= 0.304925, Training Accuracy= 0.93750
# Iter 1379200, Minibatch Loss= 0.058143, Training Accuracy= 1.00000
# Iter 1380800, Minibatch Loss= 0.016725, Training Accuracy= 1.00000
# Iter 1382400, Minibatch Loss= 0.010601, Training Accuracy= 1.00000
# Iter 1384000, Minibatch Loss= 0.029831, Training Accuracy= 1.00000
# Iter 1385600, Minibatch Loss= 0.021355, Training Accuracy= 1.00000
# Iter 1387200, Minibatch Loss= 0.072434, Training Accuracy= 1.00000
# Iter 1388800, Minibatch Loss= 0.120861, Training Accuracy= 0.93750
# Iter 1390400, Minibatch Loss= 0.370451, Training Accuracy= 0.93750
# Iter 1392000, Minibatch Loss= 0.037769, Training Accuracy= 1.00000
# Iter 1393600, Minibatch Loss= 0.197871, Training Accuracy= 0.93750
# Iter 1395200, Minibatch Loss= 0.004890, Training Accuracy= 1.00000
# Iter 1396800, Minibatch Loss= 0.020546, Training Accuracy= 1.00000
# Iter 1398400, Minibatch Loss= 0.012740, Training Accuracy= 1.00000
# Iter 1400000, Minibatch Loss= 0.126036, Training Accuracy= 0.93750
# Iter 1401600, Minibatch Loss= 0.008739, Training Accuracy= 1.00000
# Iter 1403200, Minibatch Loss= 0.118002, Training Accuracy= 0.93750
# Iter 1404800, Minibatch Loss= 0.021268, Training Accuracy= 1.00000
# Iter 1406400, Minibatch Loss= 0.017043, Training Accuracy= 1.00000
# Iter 1408000, Minibatch Loss= 0.452873, Training Accuracy= 0.87500
# Iter 1409600, Minibatch Loss= 0.006450, Training Accuracy= 1.00000
# Iter 1411200, Minibatch Loss= 0.110143, Training Accuracy= 0.93750
# Iter 1412800, Minibatch Loss= 0.021896, Training Accuracy= 1.00000
# Iter 1414400, Minibatch Loss= 0.137233, Training Accuracy= 1.00000
# Iter 1416000, Minibatch Loss= 0.266583, Training Accuracy= 0.93750
# Iter 1417600, Minibatch Loss= 0.019477, Training Accuracy= 1.00000
# Iter 1419200, Minibatch Loss= 0.233106, Training Accuracy= 0.93750
# Iter 1420800, Minibatch Loss= 0.073481, Training Accuracy= 0.93750
# Iter 1422400, Minibatch Loss= 0.000629, Training Accuracy= 1.00000
# Iter 1424000, Minibatch Loss= 0.028125, Training Accuracy= 1.00000
# Iter 1425600, Minibatch Loss= 0.193408, Training Accuracy= 0.93750
# Iter 1427200, Minibatch Loss= 0.055502, Training Accuracy= 1.00000
# Iter 1428800, Minibatch Loss= 0.007557, Training Accuracy= 1.00000
# Iter 1430400, Minibatch Loss= 0.059891, Training Accuracy= 0.93750
# Iter 1432000, Minibatch Loss= 0.020257, Training Accuracy= 1.00000
# Iter 1433600, Minibatch Loss= 0.021387, Training Accuracy= 1.00000
# Iter 1435200, Minibatch Loss= 0.067755, Training Accuracy= 1.00000
# Iter 1436800, Minibatch Loss= 0.006048, Training Accuracy= 1.00000
# Iter 1438400, Minibatch Loss= 0.057993, Training Accuracy= 1.00000
# Iter 1440000, Minibatch Loss= 0.460137, Training Accuracy= 0.87500
# Iter 1441600, Minibatch Loss= 0.004967, Training Accuracy= 1.00000
# Iter 1443200, Minibatch Loss= 0.018328, Training Accuracy= 1.00000
# Iter 1444800, Minibatch Loss= 0.020220, Training Accuracy= 1.00000
# Iter 1446400, Minibatch Loss= 0.070955, Training Accuracy= 0.93750
# Iter 1448000, Minibatch Loss= 0.037713, Training Accuracy= 1.00000
# Iter 1449600, Minibatch Loss= 0.019489, Training Accuracy= 1.00000
# Iter 1451200, Minibatch Loss= 0.486641, Training Accuracy= 0.93750
# Iter 1452800, Minibatch Loss= 0.427621, Training Accuracy= 0.87500
# Iter 1454400, Minibatch Loss= 0.202601, Training Accuracy= 0.93750
# Iter 1456000, Minibatch Loss= 0.019360, Training Accuracy= 1.00000
# Iter 1457600, Minibatch Loss= 0.031715, Training Accuracy= 1.00000
# Iter 1459200, Minibatch Loss= 0.006325, Training Accuracy= 1.00000
# Iter 1460800, Minibatch Loss= 1.069330, Training Accuracy= 0.93750
# Iter 1462400, Minibatch Loss= 0.087191, Training Accuracy= 0.93750
# Iter 1464000, Minibatch Loss= 0.038334, Training Accuracy= 1.00000
# Iter 1465600, Minibatch Loss= 0.012028, Training Accuracy= 1.00000
# Iter 1467200, Minibatch Loss= 0.040382, Training Accuracy= 1.00000
# Iter 1468800, Minibatch Loss= 0.021631, Training Accuracy= 1.00000
# Iter 1470400, Minibatch Loss= 0.009127, Training Accuracy= 1.00000
# Iter 1472000, Minibatch Loss= 0.122729, Training Accuracy= 0.93750
# Iter 1473600, Minibatch Loss= 0.057012, Training Accuracy= 1.00000
# Iter 1475200, Minibatch Loss= 0.022266, Training Accuracy= 1.00000
# Iter 1476800, Minibatch Loss= 0.008481, Training Accuracy= 1.00000
# Iter 1478400, Minibatch Loss= 0.016167, Training Accuracy= 1.00000
# Iter 1480000, Minibatch Loss= 0.231988, Training Accuracy= 0.93750
# Iter 1481600, Minibatch Loss= 0.027754, Training Accuracy= 1.00000
# Iter 1483200, Minibatch Loss= 0.511061, Training Accuracy= 0.93750
# Iter 1484800, Minibatch Loss= 0.070044, Training Accuracy= 1.00000
# Iter 1486400, Minibatch Loss= 1.001444, Training Accuracy= 0.87500
# Iter 1488000, Minibatch Loss= 0.205308, Training Accuracy= 0.87500
# Iter 1489600, Minibatch Loss= 0.012457, Training Accuracy= 1.00000
# Iter 1491200, Minibatch Loss= 0.519911, Training Accuracy= 0.93750
# Iter 1492800, Minibatch Loss= 0.033441, Training Accuracy= 1.00000
# Iter 1494400, Minibatch Loss= 0.383660, Training Accuracy= 0.93750
# Iter 1496000, Minibatch Loss= 0.211085, Training Accuracy= 0.93750
# Iter 1497600, Minibatch Loss= 0.132669, Training Accuracy= 0.93750
# Iter 1499200, Minibatch Loss= 0.160066, Training Accuracy= 0.87500
# Iter 1500800, Minibatch Loss= 0.008948, Training Accuracy= 1.00000
# Iter 1502400, Minibatch Loss= 0.018406, Training Accuracy= 1.00000
# Iter 1504000, Minibatch Loss= 0.090933, Training Accuracy= 0.93750
# Iter 1505600, Minibatch Loss= 0.011961, Training Accuracy= 1.00000
# Iter 1507200, Minibatch Loss= 0.006611, Training Accuracy= 1.00000
# Iter 1508800, Minibatch Loss= 0.137127, Training Accuracy= 0.93750
# Iter 1510400, Minibatch Loss= 0.040432, Training Accuracy= 1.00000
# Iter 1512000, Minibatch Loss= 0.331303, Training Accuracy= 0.93750
# Iter 1513600, Minibatch Loss= 0.004215, Training Accuracy= 1.00000
# Iter 1515200, Minibatch Loss= 0.203330, Training Accuracy= 0.93750
# Iter 1516800, Minibatch Loss= 0.966552, Training Accuracy= 0.87500
# Iter 1518400, Minibatch Loss= 0.054336, Training Accuracy= 1.00000
# Iter 1520000, Minibatch Loss= 0.018029, Training Accuracy= 1.00000
# Iter 1521600, Minibatch Loss= 0.244191, Training Accuracy= 0.93750
# Iter 1523200, Minibatch Loss= 0.095459, Training Accuracy= 1.00000
# Iter 1524800, Minibatch Loss= 0.018146, Training Accuracy= 1.00000
# Iter 1526400, Minibatch Loss= 0.019430, Training Accuracy= 1.00000
# Iter 1528000, Minibatch Loss= 0.066303, Training Accuracy= 0.93750
# Iter 1529600, Minibatch Loss= 0.188354, Training Accuracy= 0.93750
# Iter 1531200, Minibatch Loss= 0.197006, Training Accuracy= 0.93750
# Iter 1532800, Minibatch Loss= 0.040985, Training Accuracy= 1.00000
# Iter 1534400, Minibatch Loss= 0.029275, Training Accuracy= 1.00000
# Iter 1536000, Minibatch Loss= 0.087666, Training Accuracy= 0.93750
# Iter 1537600, Minibatch Loss= 0.009226, Training Accuracy= 1.00000
# Iter 1539200, Minibatch Loss= 0.034378, Training Accuracy= 1.00000
# Iter 1540800, Minibatch Loss= 0.497208, Training Accuracy= 0.93750
# Iter 1542400, Minibatch Loss= 0.002175, Training Accuracy= 1.00000
# Iter 1544000, Minibatch Loss= 0.195847, Training Accuracy= 0.93750
# Iter 1545600, Minibatch Loss= 0.010377, Training Accuracy= 1.00000
# Iter 1547200, Minibatch Loss= 0.008464, Training Accuracy= 1.00000
# Iter 1548800, Minibatch Loss= 0.007892, Training Accuracy= 1.00000
# Iter 1550400, Minibatch Loss= 0.022105, Training Accuracy= 1.00000
# Iter 1552000, Minibatch Loss= 0.004175, Training Accuracy= 1.00000
# Iter 1553600, Minibatch Loss= 0.031292, Training Accuracy= 1.00000
# Iter 1555200, Minibatch Loss= 0.003519, Training Accuracy= 1.00000
# Iter 1556800, Minibatch Loss= 0.540907, Training Accuracy= 0.93750
# Iter 1558400, Minibatch Loss= 0.026035, Training Accuracy= 1.00000
# Iter 1560000, Minibatch Loss= 0.005750, Training Accuracy= 1.00000
# Iter 1561600, Minibatch Loss= 0.011298, Training Accuracy= 1.00000
# Iter 1563200, Minibatch Loss= 0.039304, Training Accuracy= 1.00000
# Iter 1564800, Minibatch Loss= 0.019389, Training Accuracy= 1.00000
# Iter 1566400, Minibatch Loss= 0.158427, Training Accuracy= 0.93750
# Iter 1568000, Minibatch Loss= 0.012439, Training Accuracy= 1.00000
# Iter 1569600, Minibatch Loss= 0.029737, Training Accuracy= 1.00000
# Iter 1571200, Minibatch Loss= 0.030459, Training Accuracy= 1.00000
# Iter 1572800, Minibatch Loss= 0.001511, Training Accuracy= 1.00000
# Iter 1574400, Minibatch Loss= 0.018298, Training Accuracy= 1.00000
# Iter 1576000, Minibatch Loss= 0.019990, Training Accuracy= 1.00000
# Iter 1577600, Minibatch Loss= 0.084180, Training Accuracy= 0.93750
# Iter 1579200, Minibatch Loss= 1.199843, Training Accuracy= 0.93750
# Iter 1580800, Minibatch Loss= 0.082583, Training Accuracy= 1.00000
# Iter 1582400, Minibatch Loss= 0.109951, Training Accuracy= 1.00000
# Iter 1584000, Minibatch Loss= 0.143483, Training Accuracy= 0.93750
# Iter 1585600, Minibatch Loss= 0.041719, Training Accuracy= 1.00000
# Iter 1587200, Minibatch Loss= 0.005591, Training Accuracy= 1.00000
# Iter 1588800, Minibatch Loss= 0.223377, Training Accuracy= 0.93750
# Iter 1590400, Minibatch Loss= 0.019357, Training Accuracy= 1.00000
# Iter 1592000, Minibatch Loss= 0.006767, Training Accuracy= 1.00000
# Iter 1593600, Minibatch Loss= 0.011556, Training Accuracy= 1.00000
# Iter 1595200, Minibatch Loss= 0.010630, Training Accuracy= 1.00000
# Iter 1596800, Minibatch Loss= 0.021426, Training Accuracy= 1.00000
# Iter 1598400, Minibatch Loss= 0.012866, Training Accuracy= 1.00000
# Optimization Finished!
# Testing Accuracy: 0.877523

# %%
saver.save(sess, '../Model/NIN-Model-0619')
with open("../demo/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)
with open("../qt/labels.p", "wb") as fp:
    pickle.dump(signL.labels, fp)

# %%
with open("../demo/labels.p", "rb") as fp:
    labelname = pickle.load(fp)
print labelname
# Out:
# ['name', 'hungry', 'want1', '1', 'd', '7', 's', '2', 'y', 'p', 'me', 'likeb2', 'i', '9', 'q', 'why2', 'nob1', 'sorry1', 'thanku1', 'want2', 'w', 'n', 'c', '3', 'g', 'v', 'time1', 'a', 'come', 'you', 'howd2', 'help_h2', 'unders1', 't', 'nob2', '8', 'u', 'x', '6', 'h', 'why1', 'e', '5', 'o', '4', 'f', 'non', 'unders2', 'm', 'b', 'likeb1', 'r', 'l', 'howd1', 'k']

# %%
def testing(filename):
    stest_images = get_pic(filename)
    print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
def testing_all(path):
    for filename in glob.glob(os.path.join(path, '*.png')):
        print filename
        stest_images = get_pic(filename)
        print sess.run(tf.argmax(pred,1), feed_dict={x: stest_images, keep_prob: 1.})

# %%
filename = 'rgbdata/testing/6_491.png'
testing(filename)

# %%
path = 'rgbdata/testing'
testing_all(path)
